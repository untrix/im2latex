# %%
from IPython.core.display import display, Latex, Pretty, Math, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
import sys
import pandas as pd
sys.path.extend(['../src/commons'])
import pub_commons as pub
# %matplotlib inline
# Out:
# <style>.container { width:90% !important; }</style>

# %%
pub.disp_matched_strs2('I2L-NOPOOL')
# Out:
#     edit_distance  $\mathbf{y}$_len  \
# 0   0.080000       150
# 1   0.060811       148
# 2   0.068966       145
# 3   0.054054       148
# 4   0.000000       147
# 5   0.000000       147
# 6   0.000000       147
# 7   0.034722       144
# 8   0.013699       146
# 9   0.027211       147
# 10  0.006944       144
# 11  0.006897       145
# 12  0.115385       130
# 13  0.000000       143
# 14  0.000000       143
# 15  0.067568       148
# 16  0.007042       142
# 17  0.042553       141
# 18  0.000000       140
# 19  0.021429       140
# 20  0.000000       139
# 21  0.000000       138
# 22  0.042857       140
# 23  0.000000       138
# 24  0.014706       136
# 25  0.007246       138
# 26  0.028169       142
# 27  0.014815       135
# 28  0.050360       139
# 29  0.000000       136
# 30  0.000000       136
# 31  0.029412       136
# 32  0.043165       139
# 33  0.000000       135
# 34  0.069444       144
# 35  0.082707       133
# 36  0.007463       134
# 37  0.007463       134
# 38  0.046875       128
# 39  0.000000       134
# 40  0.000000       133
# 41  0.007519       133
# 42  0.007519       133
# 43  0.062016       129
# 44  0.000000       133
# 45  0.014815       135
# 46  0.057971       138
# 47  0.030769       130
# 48  0.000000       131
# 49  0.150794       126
# 50  0.115108       139
# 51  0.000000       131
# 52  0.000000       131
# 53  0.039062       128
# 54  0.036765       136
# 55  0.000000       131
# 56  0.072000       125
# 57  0.047244       127
# 58  0.044118       136
# 59  0.000000       131
# 60  0.007634       131
# 61  0.000000       130
# 62  0.047619       126
# 63  0.000000       130
# 64  0.000000       130
# 65  0.030075       133
# 66  0.015504       129
# 67  0.015748       127
# 68  0.023622       127
# 69  0.000000       129
# 70  0.067669       133
# 71  0.000000       129
# 72  0.075000       120
# 73  0.007752       129
# 74  0.049180       122
# 75  0.000000       128
# 76  0.053846       130
# 77  0.000000       128
# 78  0.000000       128
# 79  0.000000       127
# 80  0.015748       127
# 81  0.015504       129
# 82  0.015873       126
# 83  0.000000       127
# 84  0.086331       139
# 85  0.096774       124
# 86  0.007812       128
# 87  0.000000       127
# 88  0.106557       122
# 89  0.067797       118
# 90  0.000000       126
# 91  0.063492       126
# 92  0.050000       120
# 93  0.083969       131
# 94  0.032000       125
# 95  0.050420       119
# 96  0.015748       127
# 97  0.049587       121
# 98  0.032000       125
# 99  0.000000       124
#
#    $\mathbf{y}$                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \
# 0   $\sigma _ { i j } ( x ^ { - } , y ^ { - } ; x ^ { + } ) = \int \! \frac { d P ^ { - } } { 4 \pi } \frac { d p ^ { + } } { 4 \pi } \frac { d k ^ { + } } { 4 \pi } e ^ { - \frac { i } { 2 } P ^ { - } x ^ { + } } e ^ { - \frac { i } { 2 } ( p ^ { + } x ^ { -- } k ^ { + } y ^ { - } ) } ~ \sigma _ { i j } ( p ^ { + } , k ^ { + } ; P ^ { - } ) , $
# 1   $\int \frac { \mathrm { d } \Omega } { 4 \, \pi } \; \; { \cal L } _ { \mu _ { 1 } \mu _ { 2 } \mu _ { 3 } } ^ { a _ { 1 } a _ { 2 } a _ { 3 } } \left( k _ { 1 } , k _ { 2 } , k _ { 3 } , \hat { Q } \right) = - i \; f ^ { a _ { 1 } \, a _ { 2 } \, a _ { 3 } } \; { \cal A } _ { \mu _ { 1 } \mu _ { 2 } \mu _ { 3 } } \left( k _ { 1 } , k _ { 2 } , k _ { 3 } \right) . $
# 2   $S _ { 0 } = \sum _ { l } \frac { 1 } { 2 \Delta _ { l } ^ { 2 } } \mathrm { T r } \, \phi _ { l } ^ { a } \phi _ { - l } ^ { a } + \sum _ { l } \frac { 1 } { 2 \epsilon _ { l } ^ { 2 } } \mathrm { T r } \, f _ { l } ^ { a } f _ { - l } ^ { a } + \sum _ { r } \frac { 1 } { g _ { r } } \mathrm { T r } \, \bar { \psi } _ { r } ^ { a } \psi _ { r } ^ { a } \, . $
# 3   $N _ { Q \overline { { Q } } } \: ( W ) \; = \; 2 \: \int _ { M ^ { 2 } } ^ { W ^ { 2 } } \: \frac { d \kappa ^ { 2 } } { \kappa ^ { 2 } } \: \left[ 1 - \frac { M ^ { 2 } } { \kappa ^ { 2 } } \right] \: \int _ { Q _ { 0 } } ^ { \kappa } \: \frac { d k _ { \perp } } { \kappa } \: \Phi _ { F } ^ { G } ( z ) \: \frac { \alpha _ { s } ( k _ { \perp } ) } { 4 \pi } \: N _ { G } ( k _ { \perp } ) , $
# 4   $\Delta ^ { \alpha \beta } = \frac { 1 } { k ^ { 2 } + \Pi _ { t } } \left( \delta ^ { \alpha \beta } - \frac { p _ { 0 } ^ { \alpha } k ^ { \beta } + k ^ { \alpha } p _ { 0 } ^ { \beta } } { p _ { 0 } \cdot k } - \frac { k ^ { 2 } } { k ^ { 2 } - \Pi _ { \ell } } ( \Pi _ { t } + \Pi _ { \ell } ) \frac { p _ { 0 } ^ { \alpha } p _ { 0 } ^ { \beta } } { ( p _ { 0 } \cdot k ) ^ { 2 } } \right) \; . $
# 5   $d s ^ { 2 } = - \frac { t ^ { 2 } } { ( t ^ { 2 } + r _ { - } ^ { 2 } ) ( t ^ { 2 } - r _ { + } ^ { 2 } ) } d t ^ { 2 } + t ^ { 2 } ( d \phi + \frac { r _ { + } r _ { - } } { t ^ { 2 } } d r ) ^ { 2 } + \frac { ( t ^ { 2 } + r _ { - } ^ { 2 } ) ( t ^ { 2 } - r _ { + } ^ { 2 } ) } { t ^ { 2 } } d r ^ { 2 } . $
# 6   ${ \cal L } _ { Y } = - \sum _ { i , j = 1 } ^ { G } \left[ \hat { y } _ { i j } ^ { e } \bar { L } _ { L } ^ { i } \phi \, E _ { R } ^ { j } + \hat { y } _ { i j } ^ { d } \bar { Q } _ { L } ^ { i } \phi \, D _ { R } ^ { j } + \hat { y } _ { i j } ^ { u } \bar { Q } _ { L } ^ { i } \tilde { \phi } \, U _ { R } ^ { j } + \mathrm { h . c . } \right] , $
# 7   $\int d ^ { n } p \, d ^ { n } q \, \frac { p ^ { \mu _ { 1 } } \ldots p ^ { \mu _ { i } } q ^ { \mu _ { i + 1 } } \ldots q ^ { \mu _ { j } } } { ( p ^ { 2 } + m _ { 1 } ^ { 2 } ) ^ { \alpha _ { 1 } } \, ( q ^ { 2 } + m _ { 2 } ^ { 2 } ) ^ { \alpha _ { 2 } } \, [ ( r + k ) ^ { 2 } + m _ { 3 } ^ { 2 } ] ^ { \alpha _ { 3 } } } \; \; . $
# 8   $A _ { 0 } ^ { 3 } ( \alpha ^ { \prime } \rightarrow 0 ) = 2 g _ { d } \, \, \varepsilon _ { \lambda } ^ { ( 1 ) } \varepsilon _ { \mu } ^ { ( 2 ) } \varepsilon _ { \nu } ^ { ( 3 ) } \left\{ \eta ^ { \lambda \mu } \left( p _ { 1 } ^ { \nu } - p _ { 2 } ^ { \nu } \right) + \eta ^ { \lambda \nu } \left( p _ { 3 } ^ { \mu } - p _ { 1 } ^ { \mu } \right) + \eta ^ { \mu \nu } \left( p _ { 2 } ^ { \lambda } - p _ { 3 } ^ { \lambda } \right) \right\} . $
# 9   $\sqrt { - g } g ^ { \mu _ { 1 } \nu _ { 1 } } g ^ { \mu _ { 2 } \nu _ { 2 } } \cdots g ^ { \mu _ { d - p } \nu _ { d - p } } { \tilde { F } } _ { \nu _ { 1 } \nu _ { 2 } \ldots \nu _ { d - p } } = \frac { 1 } { p ! } \epsilon ^ { \mu _ { 1 } \mu _ { 2 } \ldots \mu _ { d - p } \nu _ { 1 } \nu _ { 2 } \ldots \nu _ { p } } F _ { \nu _ { 1 } \nu _ { 2 } \ldots \nu _ { p } } , $
# 10  $V ( H _ { 1 } , H _ { 2 } ) = \frac { 1 } { 8 } ( g _ { 2 } ^ { 2 } + g _ { 1 } ^ { 2 } ) \left( | H _ { 1 } | ^ { 2 } - | H _ { 2 } | ^ { 2 } \right) ^ { 2 } + m _ { 1 } ^ { 2 } | H _ { 1 } | ^ { 2 } + m _ { 2 } ^ { 2 } | H _ { 2 } | ^ { 2 } - m _ { 3 } ^ { 2 } ( H _ { 1 } H _ { 2 } + \mathrm { h . c . } ) $
# 11  $H ( z _ { 2 } ^ { \prime } , z _ { 3 } ^ { \prime } , P _ { 2 } ^ { \prime } , P _ { 3 } ^ { \prime } ) = - \int _ { z _ { 0 } } ^ { z _ { A } ^ { \prime } } \frac { \partial \beta _ { A } } { \partial \mu } ( z _ { 2 } ^ { \prime } , z _ { 3 } ^ { \prime } , z _ { A } ^ { \prime \prime } ) ~ d z _ { A } ^ { \prime \prime } + f ( z _ { 2 } ^ { \prime } , z _ { 3 } ^ { \prime } ) $
# 12  $\frac { d E } { d z } = \frac { d E _ { e l } } { d z } + \frac { d E _ { r a d } } { d z } \approx \frac { C _ { 2 } \alpha _ { s } } { \pi } \mu ^ { 2 } \operatorname { l n } \frac { 3 E T } { 2 \mu ^ { 2 } } \left( \operatorname { l n } \frac { 9 E } { \pi ^ { 3 } T } + \frac { 3 \pi ^ { 2 } \alpha _ { s } } { 2 \mu ^ { 2 } } T ^ { 2 } \right) . $
# 13  $d s ^ { 2 } ~ = ~ \alpha ^ { \prime } \left( \frac { u ^ { 2 } h ( u ) } { R ^ { 2 } } ~ e ^ { \gamma A } d x _ { 0 } ^ { 2 } + \frac { u ^ { 2 } } { R ^ { 2 } } ~ e ^ { \gamma C } d x _ { i } ^ { 2 } + \frac { R ^ { 2 } } { u ^ { 2 } h ( u ) } ~ e ^ { \gamma B } d u ^ { 2 } + R ^ { 2 } ~ e ^ { \gamma D } d \Omega _ { 5 } ^ { 2 } \right) ~ , $
# 14  $\langle J _ { \mu _ { 1 } } ^ { a _ { 1 } } ( P _ { 1 } ) \ldots J _ { \mu _ { n } } ^ { a _ { n } } ( P _ { n } ) \rangle _ { T } \approx ( - i ) ^ { n } \frac { N T ^ { 2 } } { 1 2 } \delta \Gamma _ { \mu _ { 1 } \ldots \mu _ { n } } ^ { a _ { 1 } \ldots a _ { n } } ( P _ { 1 } , \ldots , P _ { n } ) + O ( \frac { 1 } { f _ { \pi } ^ { 2 } } ) \ , $
# 15  $A _ { i } ( T ) = { \frac { 1 } { 3 2 \pi ^ { 4 } } } { \frac { 1 } { n _ { i } ! } } \int _ { 4 m _ { i } ^ { 2 } } ^ { \infty } d s \ \sigma _ { i } ( s ) \ s \ ( s - 4 m _ { i } ^ { 2 } ) \sum _ { l = 2 } ^ { \infty } \ \sum _ { k = - l + 2 } ^ { l - 2 } ( \pm 1 ) ^ { l } { \frac { K _ { 1 } ( a _ { k l } ) } { a _ { k l } } } \ , $
# 16  $m _ { h ^ { 0 } } ^ { 2 } \leq M _ { Z } ^ { 2 } \operatorname { c o s } ^ { 2 } 2 \beta + \frac { 3 \alpha m _ { t } ^ { 4 } } { 4 \pi s ^ { 2 } ( 1 - s ^ { 2 } ) M _ { Z } ^ { 2 } } \left\{ \operatorname { l n } \left( \frac { m _ { \tilde { t } _ { 1 } } ^ { 2 } m _ { \tilde { t } _ { 2 } } ^ { 2 } } { m _ { t } ^ { 4 } } \right) + \Delta _ { \theta _ { t } } \right\} $
# 17  $Q _ { 7 \gamma } = \frac { e } { 8 \pi ^ { 2 } } m _ { b } \bar { q } _ { \alpha } \sigma ^ { \mu \nu } ( 1 + \gamma _ { 5 } ) b _ { \alpha } F _ { \mu \nu } , ~ ~ Q _ { 8 G } = \frac { g } { 8 \pi ^ { 2 } } m _ { b } \bar { q } _ { \alpha } \sigma ^ { \mu \nu } t _ { \alpha \beta } ^ { a } b _ { \beta } G _ { \mu \nu } ^ { a } , ~ ~ ( q = d ~ \mathrm { o r } ~ s ) . $
# 18  $g _ { q } ( y , M ) = { \frac { M } { 1 8 \pi } } x _ { a } x _ { b } \ [ f _ { q } ^ { ( a ) } ( x _ { a } , M ^ { 2 } ) f _ { \bar { q } } ^ { ( b ) } ( x _ { b } , M ^ { 2 } ) + f _ { \bar { q } } ^ { ( a ) } ( x _ { a } , M ^ { 2 } ) f _ { q } ^ { ( b ) } ( x _ { b } , M ^ { 2 } ) ] \ , $
# 19  $\Gamma _ { f } ^ { \mu \nu } = \sum \frac { \alpha \omega _ { i f } \omega _ { j f } m _ { f } } { \pi } { C _ { i j } ^ { f } } \left[ \xi _ { f } ( F _ { 1 } ^ { i j } g ^ { \mu \nu } - F _ { 2 } ^ { i j } p _ { j } ^ { \mu } p _ { i } ^ { \nu } ) + i \eta _ { f } F _ { 3 } ^ { i j } \epsilon ^ { \mu \nu \rho \delta } p _ { i \rho } p _ { j \delta } \right] . $
# 20  $D _ { \mu \nu } ^ { a b } ( p , p _ { 3 } ) = \frac { \delta ^ { a b } \delta ^ { a 3 } } { p ^ { 2 } - p _ { 3 } ^ { 2 } + i \epsilon } \left[ - g _ { \mu \nu } + p _ { \mu } p _ { \nu } \left( ( 1 - \delta _ { p _ { 3 } , 0 } ) \frac { 1 } { p _ { 3 } ^ { 2 } } + \delta _ { p _ { 3 } , 0 } ( 1 - \xi ) \frac { 1 } { p ^ { 2 } + i \epsilon } \right) \right] $
# 21  $p _ { 1 } ^ { 2 } p _ { 2 } ^ { 2 } - ( p _ { 1 } \cdot p _ { 2 } ) ^ { 2 } = - \frac { 1 } { 4 } ( p _ { 1 } ^ { 4 } + p _ { 2 } ^ { 4 } + p _ { 5 } ^ { 4 } - 2 p _ { 1 } ^ { 2 } p _ { 2 } ^ { 2 } - 2 p _ { 1 } ^ { 2 } p _ { 5 } ^ { 2 } - 2 p _ { 2 } ^ { 2 } p _ { 5 } ^ { 2 } ) = 0 $
# 22  $\tilde { S } = \int d ^ { 2 } { x } \left\{ g ^ { 2 } ( 1 + \varphi _ { 1 } ^ { 2 } ) ^ { 2 } ( \partial \tilde { \varphi _ { 0 } } ) ^ { 2 } + 8 \theta g ^ { 2 } \partial _ { a } \tilde { \varphi _ { 0 } } \partial ^ { a } \varphi _ { 1 } + \frac { ( 1 + 1 6 \theta ^ { 2 } g ^ { 4 } ) } { g ^ { 2 } ( 1 + \varphi _ { 1 } ^ { 2 } ) ^ { 2 } } ( \partial \varphi _ { 1 } ) ^ { 2 } \right\} $
# 23  $\frac { 1 } { \operatorname { s i n } \theta } \frac { \partial } { \partial \theta } \left( \operatorname { s i n } \theta \frac { \partial Z } { \partial \theta } \right) + \frac { 1 } { \operatorname { s i n } ^ { 2 } \theta } \frac { \partial ^ { 2 } Z } { \partial \varphi ^ { 2 } } - \left( \frac { c _ { 1 } } { \operatorname { c o s } ^ { 2 } \frac { \theta } { 2 } } + \frac { c _ { 2 } } { \operatorname { s i n } ^ { 2 } \frac { \theta } { 2 } } \right) Z = - A Z , $
# 24  $< p ^ { \prime } | J _ { \mu } ^ { A } | p ^ { \prime } > = \overline { \psi } _ { p ^ { \prime } } \left[ g _ { 1 } ^ { \prime } ( k ^ { 2 } ) \gamma _ { \mu } \gamma _ { 5 } + g _ { 2 } ^ { \prime } ( k ^ { 2 } ) i \sigma _ { \mu \nu } \gamma _ { 5 } k ^ { \nu } + g _ { 3 } ^ { \prime } ( k ^ { 2 } ) i \gamma _ { 5 } k _ { \mu } \right] \psi _ { p ^ { \prime } } . $
# 25  ${ \cal H } ^ { T } = \frac { 4 G _ { F } } { \sqrt { 2 } } V _ { u b } V _ { u q } ^ { * } \sum _ { i = 1 } ^ { 2 } c _ { i } ( \mu ) O _ { i } ^ { ( u ) } , \qquad { \cal H } ^ { P } = - \frac { 4 G _ { F } } { \sqrt { 2 } } V _ { t b } V _ { t q } ^ { * } \sum _ { i = 3 } ^ { 6 } c _ { i } ( \mu ) O _ { i } , $
# 26  $m _ { 0 } = { \frac { m _ { Z } ^ { 2 } \operatorname { c o s } ^ { 2 } \beta ( M _ { 1 } c _ { w } ^ { 2 } + M _ { 2 } s _ { w } ^ { 2 } ) \mu \operatorname { c o s } \xi } { M _ { 1 } M _ { 2 } \mu \operatorname { c o s } \xi - m _ { Z } ^ { 2 } \operatorname { s i n } { 2 \beta } ( M _ { 1 } c _ { w } ^ { 2 } + M _ { 2 } s _ { w } ^ { 2 } ) } } , $
# 27  $\langle \vec { x } = 0 | j _ { 0 } ( \vec { x } ) | \vec { x } = 0 \rangle \equiv \tilde { \varphi } _ { 2 } ^ { \ast } \tilde { \varphi } _ { 1 } \rho ( \vec { x } ) = \tilde { \varphi } _ { 2 } ^ { \ast } \tilde { \varphi } _ { 1 } \int \frac { d ^ { 3 } \vec { \Delta } } { ( 2 \pi ) ^ { 3 } } \mathrm { e } ^ { - i \vec { \Delta } \cdot \vec { x } } G _ { E } ( - \vec { \Delta } ^ { 2 } ) \, , $
# 28  $\frac { \alpha \, ( \mu ) } { 4 \, \pi } \, = \, \frac { 1 } { \beta _ { 0 } \, \lambda _ { 0 } } \, \left\{ 1 \, - \, \frac { 2 \, \beta _ { 1 } } { \beta _ { 0 } ^ { 2 } } \, \left( \frac { \operatorname { l n } \, \lambda _ { 0 } } { \lambda _ { 0 } } \right) \, + \, { \cal { O } } \, \left( \frac { 1 } { \lambda _ { 0 } ^ { 2 } } , \, \frac { \operatorname { l n } \, \lambda _ { 0 } } { \lambda _ { 0 } ^ { 2 } } \right) \right\} $
# 29  $\langle p _ { A } ^ { \prime } k _ { 1 } \rangle \langle k _ { 2 } p _ { B } \rangle \langle p _ { B } ^ { \prime } p _ { A } \rangle = \langle p _ { A } k _ { 1 } \rangle \langle k _ { 2 } p _ { B } ^ { \prime } \rangle \langle p _ { B } p _ { A } ^ { \prime } \rangle = \langle p _ { A } ^ { \prime } k _ { 1 } \rangle \langle k _ { 2 } p _ { B } ^ { \prime } \rangle \langle p _ { B } p _ { A } \rangle \, , $
# 30  $W = Y _ { a b } ^ { e } \hat { L } _ { a } \hat { H } _ { 1 } \hat { E } _ { b } ^ { c } + Y _ { a b } ^ { d } \hat { Q } _ { a } \hat { H } _ { 1 } \hat { D } _ { b } ^ { c } + Y _ { a b } ^ { u } \hat { Q } _ { a } \hat { H } _ { 2 } \hat { U } _ { b } ^ { c } - \mu \hat { H } _ { 1 } \hat { H } _ { 2 } $
# 31  $\begin{array} { l c r } { ( | W _ { 1 } | ^ { 2 } + | Z _ { 2 } | ^ { 2 } ) - ( | Z _ { 1 } | ^ { 2 } + | W _ { 2 } | ^ { 2 } ) = R _ { 2 } } \\ { Z _ { 1 } W _ { 1 } + Z _ { 2 } W _ { 2 } = \overline { { Z } } _ { 1 } \overline { { W } } _ { 1 } + \overline { { Z } } _ { 2 } \overline { { W } } _ { 2 } = 0 , } \\ \end{array} $
# 32  ${ \frac { \omega ^ { 2 } ( \omega ^ { 2 } - k _ { z } ^ { 2 } - m ^ { 2 } ) ^ { 2 } } { ( \omega ^ { 2 } - k _ { z } ^ { 2 } ) ^ { 2 } } } - k _ { T } ^ { 2 } - { \frac { k _ { z } ^ { 2 } ( \omega ^ { 2 } - k _ { z } ^ { 2 } - m ^ { 2 } ) ^ { 2 } } { ( \omega ^ { 2 } - k _ { z } ^ { 2 } ) ^ { 2 } } } = 0 \; , $
# 33  $i { \frac { \mathrm { d } } { \mathrm { d } t } } \left( \begin{array} { c } { \nu _ { \alpha } } \\ { \nu _ { \beta } } \\ \end{array} \right) = { \frac { \Delta E } { 2 } } \left( \begin{array} { c c } { - \operatorname { c o s } ( 2 \vartheta ) } & { \operatorname { s i n } ( 2 \vartheta ) } \\ { \operatorname { s i n } ( 2 \vartheta ) } & { \operatorname { c o s } ( 2 \vartheta ) } \\ \end{array} \right) \left( \begin{array} { c } { \nu _ { \alpha } } \\ { \nu _ { \beta } } \\ \end{array} \right) $
# 34  $\tilde { m } _ { b } = { \frac { \beta ^ { 2 } } { 8 \pi } } ( 1 - { \frac { \tilde { m } _ { 0 } ^ { 2 } } { \tilde { \mu } ^ { 2 } ( \varphi _ { 0 } ) } } ) [ { \frac { 1 } { \sqrt { 1 - \tilde { m } _ { b } ^ { 2 } } } } t a n ^ { - 1 } \sqrt { { \frac { 1 + \tilde { m } _ { b } ^ { 2 } } { 1 - \tilde { m } _ { b } ^ { 2 } } } } - { \frac { \pi } { 4 } } ] $
# 35  $V _ { 1 1 } = V _ { 2 2 } ^ { * } V _ { 3 3 } ^ { * } - V _ { 2 3 } ^ { * } V _ { 3 2 } ^ { * } , \mathrm { ~ o r ~ } V _ { 1 1 } V _ { 2 2 } V _ { 3 3 } = | V _ { 2 2 } | ^ { 2 } | V _ { 3 3 } | ^ { 2 } - V _ { 2 2 } V _ { 3 3 } V _ { 2 3 } ^ { * } V _ { 3 2 } ^ { * } . $
# 36  $\sigma = \frac { \pi \alpha ^ { 2 } \beta ^ { 3 } } { 3 s } \left[ 1 + \frac { s ( - 1 + 4 s _ { W } ^ { 2 } ) } { 2 c _ { W } ^ { 2 } ( s - M _ { Z } ^ { 2 } ) } + \frac { s ^ { 2 } ( - 1 + 4 s _ { W } ^ { 2 } + 8 s _ { W } ^ { 4 } ) } { 4 c _ { W } ^ { 4 } ( s - M _ { Z } ^ { 2 } ) ^ { 2 } } \right] \; , $
# 37  $+ ( U ^ { ( 1 ) } U ^ { ( 2 ) } ) ^ { - 1 } d y _ { 3 } ^ { 2 } + ( H ^ { ( 2 ) } U ^ { ( 2 ) } ) ^ { - 1 } d y _ { 4 } ^ { 2 } + ( H ^ { ( 2 ) } U ^ { ( 1 ) } ) ^ { - 1 } ( d y _ { 5 } ^ { 2 } + d y _ { 6 } ^ { 2 } + d y _ { 7 } ^ { 2 } ) + d x ^ { \alpha } d x ^ { \alpha } ] $
# 38  $\sigma = \int _ { - \infty } ^ { \infty } \mathrm { d } z \left( \frac { f _ { a } ^ { 2 } \dot { a } ^ { 2 } } { 4 } + \frac { f _ { \pi } ^ { 2 } \dot { \phi } _ { T } ^ { 2 } } { 1 6 } + \frac { f _ { \pi } ^ { 2 } \dot { \phi } _ { S } ^ { 2 } } { 1 6 } + V ( \phi _ { S } , \phi _ { T } , a ) - V _ { \mathrm { m i n } } \right) $
# 39  $W ^ { \mathrm { e f f } } = h _ { \alpha \beta H _ { 2 } } ^ { U } \bar { U } ^ { \alpha } H _ { 2 } Q ^ { \beta } + h _ { \alpha \beta H _ { 1 } } ^ { D } \bar { D } ^ { \alpha } H _ { 1 } Q ^ { \beta } + h _ { \alpha \beta H _ { 1 } } ^ { E } \bar { E } ^ { \alpha } H _ { 1 } L ^ { \beta } + \lambda S H _ { 1 } H _ { 2 } + k S g \bar { g } , $
# 40  $V ( x _ { 2 } ) = a + ( \frac { e ^ { 2 } V _ { 1 , 1 } } { 2 } ) \int _ { B } ^ { x _ { 2 } } d y \int _ { A } ^ { y } d z | \phi _ { 0 } ( z ) | ^ { 2 } + ( \frac { e ^ { 2 } V _ { 0 , 0 } } { 2 } ) \int _ { B } ^ { x _ { 2 } } d y \int _ { A } ^ { y } d z | \phi _ { 1 } ( z ) | ^ { 2 } . $
# 41  $\gamma _ { m a x } \simeq \frac { 1 } { 2 } - \frac { N \alpha _ { s } } { \pi } \frac { ( \widetilde { \chi } ^ { ( 1 ) } ( \frac { 1 } { 2 } ) ) ^ { \prime } } { ( \chi ^ { B } ( \frac { 1 } { 2 } ) ) ^ { \prime \prime } } = \frac { 1 } { 2 } + \frac { N \alpha _ { s } } { 4 \pi } ( \frac { 1 1 } { 6 } - \frac { n _ { f } } { 3 N } + 8 \operatorname { l n } 2 ) . $
# 42  $L _ { e f f } ^ { ( 1 ) } = 2 \pi \kappa \frac { \sigma _ { 1 } \sigma _ { 2 } } { q _ { 1 } q _ { 2 } } \sum _ { p _ { 1 } = 1 } ^ { n _ { 1 } } \sum _ { p _ { 2 } = 1 } ^ { n _ { 2 } } \frac { d } { d t } A r g ( \vec { R } _ { p _ { 1 } } ^ { ( 1 ) } - \vec { R } _ { p _ { 2 } } ^ { ( 2 ) } ) \; \; . $
# 43  $d \sigma _ { V } + d \sigma _ { r } + d \sigma _ { v a c } = \frac { \alpha ^ { 3 } } { 4 } \frac { d Q ^ { 2 } } { S ^ { 2 } Q ^ { 4 } } \sum _ { i = 1 } ^ { 4 } [ \theta _ { i } ^ { F } + 4 ( \delta ^ { e l } + \delta _ { v a c } ^ { l } + \delta _ { v a c } ^ { h } ) \theta _ { i } ^ { 0 } ] { \cal F } _ { i } . $
# 44  ${ \cal I } ( A ) = c _ { 1 } a _ { 2 } ^ { i j } \partial _ { i } \partial _ { j } + ( c _ { 2 } a _ { 1 } ^ { k } + c _ { 3 } \partial _ { j } a _ { 2 } ^ { k j } ) \partial _ { k } + c _ { 4 } \partial _ { i } \partial _ { j } a _ { 2 } ^ { i j } + c _ { 5 } \partial _ { i } a _ { 1 } ^ { i } + c _ { 6 } a _ { 0 } $
# 45  $C _ { 0 } = \frac { e \Omega _ { 2 1 } } { 3 2 \pi ^ { 2 } } \frac { m _ { 1 } m _ { 2 } } { m _ { 2 } ^ { 2 } - m _ { 1 } ^ { 2 } } \int _ { 0 } ^ { 1 } t d t \operatorname { l n } { [ \frac { M _ { H } ^ { 2 } + m _ { 1 } ^ { 2 } ( t - 1 ) } { M _ { H } ^ { 2 } + m _ { 2 } ^ { 2 } ( t - 1 ) } ] } \ , $
# 46  ${ \sigma } _ { q } ^ { [ a ] } \left( N , \frac { Q ^ { 2 } } { \kappa ^ { 2 } } , a _ { s } ( Q ^ { 2 } ) \right) = 1 + \sum _ { n = 1 } ^ { \infty } a _ { s } ^ { n } ( Q ^ { 2 } ) \sum _ { m = 0 } ^ { 2 n } c _ { n m } ^ { [ a ] } \left( { Q ^ { 2 } } / { \kappa ^ { 2 } } \right) \operatorname { l n } ^ { m } N + O \left( \frac { 1 } { N } \right) , $
# 47  $Z = \int { \cal D } h _ { \mu \nu } { \cal D } h _ { \mu \nu } ^ { \prime } { \cal D } \theta _ { \mu } { \cal D } b _ { \mu \nu } { \cal D } c _ { \mu \nu } { \cal D } \bar { c } _ { \mu \nu } { \cal D } b _ { \mu } { \cal D } c _ { \mu } { \cal D } \bar { c } _ { \mu } \operatorname { e x p } i \int d ^ { 4 } x \left[ L _ { h } + L _ { \mathrm { B } } \right] . $
# 48  ${ \cal L } _ { f } = \sqrt { 2 } i ( \alpha ^ { \prime } p ^ { + } ) \left\{ \theta _ { + } ^ { \dagger } ( \partial _ { \tau } + \partial _ { \sigma } ) \theta _ { + } + \theta _ { - } ^ { \dagger } ( \partial _ { \tau } - \partial _ { \sigma } ) \theta _ { - } + 2 \theta _ { + } ^ { \dagger } \tilde { \Omega } _ { - } \theta _ { - } + 2 \theta _ { - } ^ { \dagger } \tilde { \Omega } _ { + } \theta _ { + } \right\} $
# 49  $a _ { f } ( p _ { i } , s _ { i } ) \, | \, 0 \, \rangle \; = \; 0 \; \; , \; \; \; \; \; \; n _ { f } ^ { ( i ) } \; = \; \langle \, n _ { f } ^ { ( i ) } \, | \; a _ { f } ( p _ { i } , s _ { i } ) \, a _ { f } ^ { \dagger } ( p _ { i } , s _ { i } ) \, | \, n _ { f } ^ { ( i ) } \, \rangle \; . $
# 50  ${ \frac { \lambda _ { 1 } } { \lambda _ { 2 } } } = { \frac { X _ { 1 } A _ { 3 } } { A _ { 3 } X _ { 2 } } } , \quad { \frac { \lambda _ { 2 } } { \lambda _ { 3 } } } = { \frac { X _ { 2 } A _ { 1 } } { A _ { 1 } X _ { 3 } } } , \quad { \frac { \lambda _ { 3 } } { \lambda _ { 1 } } } = { \frac { X _ { 3 } A _ { 2 } } { A _ { 2 } X _ { 1 } } } $
# 51  $A = \frac { i } { 2 } \{ \frac { 1 } { 2 } d \operatorname { l n } ( \frac { d \overline { { g } } _ { 2 } } { d \overline { { z } } _ { 2 } } \frac { d z _ { 2 } } { d g _ { 2 } } ) + \frac { ( g _ { 2 } d \overline { { g } } _ { 2 } - \overline { { g } } _ { 2 } d g _ { 2 } ) } { ( 1 - g _ { 2 } \overline { { g } } _ { 2 } ) } \} , $
# 52  $B ( z ) = m _ { d } \left( \frac { z _ { 0 } + 1 } { z + 1 } \right) ^ { 1 / 2 } \frac { \operatorname { s i n h } \left[ \frac { \omega } { 2 } \operatorname { l o g } ( z + 1 ) \right] } { \operatorname { s i n h } \left[ \frac { \omega } { 2 } \operatorname { l o g } ( z _ { 0 } + 1 ) \right] } , \quad \omega = \sqrt { 1 - \frac { 8 \pi ^ { 2 } } { e ^ { 2 } N _ { f } ^ { 2 } } } , $
# 53  ${ \cal L } = - \mathrm { T r } \; \operatorname { l o g } ( - i \gamma \cdot \partial + \gamma _ { 0 } \Gamma _ { a } \phi _ { a } ) + \sum _ { p = 1 } ^ { N _ { p } } c _ { p } \mathrm { T r } \; \operatorname { l o g } ( - i \gamma \cdot \partial + g _ { p } \gamma _ { 0 } \Gamma _ { a } \phi _ { a } ) + \frac { a ^ { 2 } } { 2 } \int d ^ { 4 } x \phi ^ { 2 } \; , $
# 54  $Z ^ { I } = Z _ { \infty } ^ { I } + \sum _ { a = 1 } ^ { a = 5 } { \frac { q ^ { I } { } _ { a } } { | \vec { x } - \vec { \underline { { x } } } _ { a } | } } \, \ , \qquad Q ^ { 5 } = \sum _ { a = 1 } ^ { a = 5 } q ^ { 5 } { } _ { a } = Q ^ { 7 } = \sum _ { a = 1 } ^ { a = 5 } q ^ { 7 } { } _ { a } = 0 \ , $
# 55  $R ( \phi ) = \sum _ { n = 0 } ^ { \infty } r _ { m _ { 1 } \ldots m _ { n } } ^ { ( n ) } \phi _ { m _ { 1 } } \ldots \phi _ { m _ { n } } , \; \; \; \; \; \; \tilde { R } ( \tilde { \phi } ) = \sum _ { n = 0 } ^ { \infty } r _ { m _ { 1 } \ldots m _ { n } } ^ { ( n ) } \tilde { \phi } _ { m _ { n } } \ldots \tilde { \phi } _ { m _ { 1 } } $
# 56  $\frac { \Delta M _ { s } } { \Delta M _ { d } } = \frac { M _ { B _ { s } } } { M _ { B _ { d } } } \frac { ( f _ { B _ { s } } ^ { 2 } \hat { B } _ { B _ { s } } ) } { ( f _ { B _ { d } } ^ { 2 } \hat { B } _ { B _ { d } } ) } \vert \frac { V _ { t s } } { V _ { t d } } \vert ^ { 2 } ~ . $
# 57  $\Delta [ n x _ { c l } , e _ { 0 } ] = \left( 1 + \frac { g e _ { 0 } } { 4 } B _ { \alpha \beta } \gamma ^ { [ \alpha } \gamma ^ { \beta ] } + \frac { g ^ { 2 } e _ { 0 } ^ { 2 } } { 1 6 } \bar { B } _ { \alpha \beta } \bar { B } ^ { * \alpha \beta } \gamma ^ { 5 } \right) \bar { \Lambda } ( e _ { 0 } ) + Q _ { \alpha \beta } \gamma ^ { [ \alpha } \gamma ^ { \beta ] } $
# 58  $\int d x ^ { 4 } \phi _ { [ \omega , l , m _ { 1 } , m _ { 2 } ] } ^ { \ast } ( x ) \phi _ { [ \omega ^ { \prime } , l ^ { \prime } , m _ { 1 } ^ { \prime } , m _ { 2 } ^ { \prime } ] } ( x ) = ( 2 \pi ) \delta ( \omega - \omega ^ { \prime } ) \delta _ { l l ^ { \prime } } \delta _ { m _ { 1 } m _ { 1 } ^ { \prime } } \delta _ { m _ { 2 } m _ { 2 } ^ { \prime } } $
# 59  $\delta \gamma = \frac { 2 \lambda _ { c } ( 1 - \gamma _ { 0 } ) [ 1 + b ( 1 - \gamma _ { 0 } ) ( 1 + \lambda _ { c } ) ] } { ( 1 - \gamma _ { 0 } ) ^ { 3 } \chi _ { 0 } ^ { \prime \prime } ( \gamma _ { 0 } ) ( 1 + \lambda _ { c } ) - 2 \lambda _ { c } } = \frac { \lambda _ { c } ( 1 . 8 5 + 0 . 5 9 1 \lambda _ { c } ) } { 1 2 + 1 0 \lambda _ { c } } . $
# 60  $S _ { \mathrm { Y M } } [ A ] = \pm \frac { 8 \pi ^ { 2 } } { g ^ { 2 } } K [ A ] + \frac { 1 } { 8 \pi ^ { 2 } } \int d ^ { 4 } x \left( F _ { \mu \nu } ^ { a } \mp \tilde { F } _ { \mu \nu } ^ { a } \right) \left( F _ { a } ^ { \mu \nu } \mp \tilde { F } _ { a } ^ { \mu \nu } \right) \geq \frac { 8 \pi ^ { 2 } } { g ^ { 2 } } \left| K [ A ] \right| \, . $
# 61  $\langle \Psi _ { 1 } ^ { \prime I _ { 1 } } ( z _ { 1 } ) \Psi _ { 2 } ^ { \prime I _ { 2 } } ( z _ { 2 } ) \cdots \Psi _ { n } ^ { \prime I _ { n } } ( z _ { n } ) \rangle = \langle \Psi _ { 1 } ^ { I _ { 1 } } ( z _ { 1 } ) \Psi _ { 2 } ^ { I _ { 2 } } ( z _ { 2 } ) \cdots \Psi _ { n } ^ { I _ { n } } ( z _ { n } ) \rangle $
# 62  $A _ { i _ { 1 } \ldots i _ { p } } ^ { ( g ) } ( x _ { 0 } , { \bf x } ) = x _ { 0 } ^ { \frac { d } { 2 } } \int { \frac { d ^ { d } k } { ( 2 \pi ) ^ { d } } } e ^ { - i { \bf k } \cdot { \bf x } } a _ { i _ { 1 } \ldots i _ { p } } ( { \bf k } ) K _ { \nu } ( | { \bf k } | x _ { 0 } ) . $
# 63  ${ \cal V } ^ { \prime \prime } + \left[ \frac { \eta _ { c } q ^ { 2 } } { ( \eta _ { c } - \eta ) } + \frac { 1 } { 4 ( \eta _ { c } - \eta ) ^ { 2 } } \right] { \cal V } = 0 , ~ ~ ~ { \cal W } ^ { \prime \prime } + \left[ \frac { \eta _ { c } q ^ { 2 } } { ( \eta _ { c } - \eta ) } + \frac { 1 } { 4 ( \eta _ { c } - \eta ) ^ { 2 } } \right] { \cal W } = 0 $
# 64  $- \frac { d E } { d x } = K z ^ { 2 } \frac { Z } { A } \frac { 1 } { \beta ^ { 2 } } \left[ \frac { 1 } { 2 } \operatorname { l n } \frac { 2 m _ { e } c ^ { 2 } \beta ^ { 2 } \gamma ^ { 2 } T _ { \mathrm { m a x } } } { I ^ { 2 } } - \beta ^ { 2 } - \operatorname { l n } \frac { \hbar \omega _ { p } } { I } - \operatorname { l n } \beta \gamma + \frac { 1 } { 2 } \right] $
# 65  ${ \frac { \operatorname { s i n } ^ { 2 } 2 \theta _ { i } - \operatorname { s i n } ^ { 2 } 2 \theta _ { j } } { ( \operatorname { s i n } ^ { 2 } 2 \theta _ { i } + \operatorname { s i n } ^ { 2 } 2 \theta _ { j } ) / 2 } } \approx 2 { \frac { \theta _ { i } - \theta _ { j } } { ( \theta _ { i } + \theta _ { j } ) / 2 } } = 2 \left( \frac { \Delta \theta } { \bar { \theta } } \right) _ { i j } . $
# 66  $\mu _ { 4 } ^ { 2 } ( | \phi _ { 1 } ^ { \prime } | ^ { 2 } + | \phi _ { 2 } ^ { \prime } | ^ { 2 } ) + \mu _ { 5 } ^ { 2 } ( | \phi _ { 3 } ^ { \prime } | ^ { 2 } + | \phi _ { 4 } ^ { \prime } | ^ { 2 } ) + \mu _ { 6 } ^ { 2 } ( | \phi _ { 5 } ^ { \prime } | ^ { 2 } + | \phi _ { 6 } ^ { \prime } | ^ { 2 } ) , $
# 67  $\phi _ { i j } ( x ^ { - } , 0 ) = \frac { 1 } { \sqrt { 2 \pi } } \int _ { 0 } ^ { \infty } \frac { d k ^ { + } } { \sqrt { 2 k ^ { + } } } \left( a _ { i j } ( k ^ { + } ) \mathrm { e } ^ { - i k ^ { + } x ^ { - } } + a _ { j i } ^ { \dag } ( k ^ { + } ) \mathrm { e } ^ { i k ^ { + } x ^ { - } } \right) , $
# 68  $\frac { \Delta m _ { s } } { \Delta m _ { d } } = \left| \frac { V _ { t s } } { V _ { t d } } \right| ^ { 2 } \frac { m _ { B _ { s } } } { m _ { B _ { d } } } \xi ^ { 2 } , \quad \xi ^ { 2 } = \frac { f _ { B _ { s } } ^ { 2 } B _ { B _ { s } } } { f _ { B _ { d } } ^ { 2 } B _ { B _ { d } } } . $
# 69  $P _ { \ \nu } ^ { \mu } = - { \frac { 1 } { 4 } } R _ { \ \lambda } ^ { \mu } R _ { \ \nu } ^ { \lambda } + { \frac { 1 } { 6 } } R R _ { \ \nu } ^ { \mu } + { \frac { 1 } { 8 } } \delta _ { \nu } ^ { \mu } R _ { \ \beta } ^ { \alpha } R _ { \ \alpha } ^ { \beta } - { \frac { 1 } { 1 6 } } \delta _ { \ \nu } ^ { \mu } R ^ { 2 } \ . $
# 70  $\left| { \widetilde { \cal P } } _ { e e } ^ { r } ( { \bf k } , t ) \right| ^ { 2 } + \left| { \widetilde { \cal P } } _ { \bar { e } e } ^ { r } ( { \bf k } , t ) \right| ^ { 2 } + \left| { \widetilde { \cal P } } _ { \mu e } ^ { r } ( { \bf k } , t ) \right| ^ { 2 } + \left| { \widetilde { \cal P } } _ { \bar { \mu } e } ^ { r } ( { \bf k } , t ) \right| ^ { 2 } = 1 \, , $
# 71  $C _ { 1 } ^ { ( 3 ) } = 1 - 2 i { \frac { { \frac { 1 } { 2 } } \Gamma _ { 2 } } { z _ { 1 } - z _ { 2 } } } - 2 i { \frac { { \frac { 1 } { 2 } } \Gamma _ { 3 } } { z _ { 1 } - z _ { 3 } } } + ( 2 i ) ^ { 2 } ( { \frac { 1 } { 2 } } \Gamma _ { 2 } ) ( { \frac { 1 } { 2 } } \Gamma _ { 3 } ) K _ { 1 } $
# 72  $\frac { g \gamma _ { d } ^ { \alpha } } { \sqrt { 2 } } \left( \begin{array} { c } { 0 } \\ { i W _ { \alpha } ^ { 2 } \psi _ { 2 L } + Z _ { \alpha } \psi _ { 1 L } / \operatorname { c o s } \theta _ { w } } \\ \end{array} \right) + \frac { M _ { i } + \eta _ { i } } { \sqrt { 2 } } \left( \begin{array} { c } { \psi _ { 1 R } } \\ { \psi _ { 1 R } } \\ \end{array} \right) . $
# 73  $T _ { 1 2 3 4 } ( p ^ { 2 } ; m _ { i } ^ { 2 } ) = B _ { 0 } ( p ^ { 2 } ; m _ { 1 } ^ { 2 } , m _ { 2 } ^ { 2 } ) B _ { 0 } ( m _ { 1 } ^ { 2 } ; m _ { 3 } ^ { 2 } , m _ { 4 } ^ { 2 } ) + T _ { 1 2 3 4 } ^ { ( 3 ) } ( p ^ { 2 } ; m _ { i } ^ { 2 } ) \, . \, $
# 74  $V _ { \mathrm { r e n } } ( \chi ) = \frac { 1 } { 2 } m _ { R } ^ { 2 } \chi + \frac { 1 } { 4 } \lambda _ { R } \chi ^ { 2 } + V _ { \mathrm { f i n } } ( \chi ) + \frac { 1 } { 6 4 \pi ^ { 2 } } ( m _ { R } ^ { 2 } + 3 \lambda _ { R } \chi ) ^ { 2 } \operatorname { l n } { \frac { \eta ^ { 2 } } { \mu ^ { 2 } } } $
# 75  $\mu ^ { 2 } = m _ { 0 } ^ { 2 } C _ { 1 } + A _ { 0 } ^ { 2 } C _ { 2 } + m _ { \frac { 1 } { 2 } } ^ { 2 } C _ { 3 } + m _ { \frac { 1 } { 2 } } A _ { 0 } C _ { 4 } - \frac { 1 } { 2 } M _ { Z } ^ { 2 } + \frac { 3 } { 5 } \frac { t ^ { 2 } + 1 } { t ^ { 2 } - 1 } S _ { 0 } p $
# 76  $[ V _ { \alpha } , V _ { \beta } ] = \epsilon _ { \alpha \beta } ^ { ~ ~ ~ \! \gamma } V _ { \gamma } , \; \; \; [ V _ { \alpha } , V _ { m } ^ { a } ] = V _ { m } ^ { b } ( \sigma _ { \alpha } ) _ { b } ^ { ~ a } , \; \; \; \{ V _ { m } ^ { a } , V _ { m } ^ { b } \} = - m ^ { 2 } ( \sigma ^ { \alpha } ) ^ { a b } V _ { \alpha } , $
# 77  $\bar { H } _ { \mathrm { g } } = H _ { \mathrm { g } } ( q ^ { r } , p ^ { r } ) + \lambda _ { a } ^ { ( 1 ) r _ { a } } \pi _ { a } ^ { r _ { a } } + \lambda _ { a } ^ { ( 2 ) r _ { a } } \psi _ { a } ^ { r _ { a } } + \lambda _ { a } ^ { ( 3 ) } \theta _ { a } + \lambda _ { a } ^ { ( 4 ) } \gamma _ { a } , $
# 78  $\sum _ { e } \sum _ { m , n = 0 } ^ { 1 } C _ { e } ( m , n ) \theta ^ { 4 } [ e ] F _ { R , t w s } ^ { m , n } = E ( z , 0 ) ^ { - 2 } \sum _ { i = 2 } ^ { 3 } C _ { i } \theta _ { i } ^ { 1 2 } ( 0 | \tau ) \frac { \theta _ { i } ^ { 2 } ( z | \tau ) } { \theta _ { i } ^ { 2 } ( 0 | \tau ) } , $
# 79  $A _ { 3 } ( z , \bar { z } ) = \frac { 1 } { \theta } \partial _ { \bar { z } } \left( \frac { \chi _ { 3 } } { \theta } \right) = - \frac { 1 } { 2 \operatorname { c o s h } ( l ) } \, , \quad \bar { A } _ { 3 } ( z , \bar { z } ) = \frac { 1 } { \theta } \partial _ { z } \left( \frac { \chi _ { 3 } } { \theta } \right) = - \frac { 1 } { 2 \operatorname { c o s h } ( l ) } \, . $
# 80  $A \; = \; i 4 \pi ^ { 2 } M _ { \psi } \: e _ { c } g _ { J } \: \alpha _ { S } \; \int _ { 0 } ^ { \infty } \; \frac { d k _ { T } ^ { 2 } } { 2 \overline { { Q } } ^ { 2 } ( \overline { { Q } } ^ { 2 } + k _ { T } ^ { 2 } ) } \; \frac { \partial ( x g ( x , k _ { T } ^ { 2 } ) ) } { \partial k _ { T } ^ { 2 } } . $
# 81  $L _ { \nu _ { \alpha } } \simeq { \frac { 1 } { 2 4 \zeta ( 3 ) } } \left[ \pi ^ { 2 } ( \tilde { \mu } _ { \alpha } - \tilde { \mu } _ { \overline { { \alpha } } } ) + 6 ( \tilde { \mu } _ { \alpha } ^ { 2 } - \tilde { \mu } _ { \overline { { \alpha } } } ^ { 2 } ) \operatorname { l n } 2 + ( \tilde { \mu } _ { \alpha } ^ { 3 } - \tilde { \mu } _ { \overline { { \alpha } } } ^ { 3 } ) \right] . $
# 82  $Z = \int { \cal D } A _ { \mu } { \cal D } \pi ^ { \mu } { \cal D } \phi { \cal D } \pi _ { \phi } { \cal D } \theta { \cal D } \pi _ { \theta } { \cal D } \rho { \cal D } \pi _ { \rho } \prod _ { i , j = 1 } ^ { 4 } \delta ( \tilde { \Omega } _ { i } ) \delta ( \Gamma _ { j } ) \operatorname* { d e t } \mid \{ \tilde { \Omega } _ { i } , \Gamma _ { j } \} \mid e ^ { i S } , $
# 83  $\alpha ( \nu \to \nu e ^ { + } e ^ { - } ) = \frac { G _ { F } ^ { 2 } ( g _ { V } ^ { 2 } + g _ { A } ^ { 2 } ) } { ( 3 \pi ) ^ { 3 } } m ^ { 4 } E \left( \frac { B } { B _ { c r } } \right) ^ { 2 } \left( \operatorname { l n } ( \kappa ) - \frac { \operatorname { l n } ( 3 ) } { 2 } - \gamma _ { E } - \frac { 2 9 } { 2 4 } \right) \quad , $
# ...
# 69  P _ { \ \nu } ^ { \mu } = - { \frac { 1 } { 4 } } R _ { \ \lambda } ^ { \mu } R _ { \ \nu } ^ { \lambda } + { \frac { 1 } { 6 } } R R _ { \ \nu } ^ { \mu } + { \frac { 1 } { 8 } } \delta _ { \nu } ^ { \mu } R _ { \ \beta } ^ { \alpha } R _ { \ \alpha } ^ { \beta } - { \frac { 1 } { 1 6 } } \delta _ { \ \nu } ^ { \mu } R ^ { 2 } \ .
# 70  \left| \widetilde { { \cal P } } _ { e e } ^ { r } ( { \bf k } , t ) \right| ^ { 2 } + \left| \widetilde { \cal P } _ { \bar { e } e } ^ { r } ( { \bf k } , t ) \right| ^ { 2 } + \left| \widetilde { \cal P } _ { \mu e } ^ { r } ( { \bf k } , t ) \right| ^ { 2 } + \left| \widetilde { { \cal P } } _ { \tilde { \mu } e } ^ { r } ( { \bf k } , t ) \right| ^ { 2 } = 1 \, ,
# 71  C _ { 1 } ^ { ( 3 ) } = 1 - 2 i { \frac { { \frac { 1 } { 2 } } \Gamma _ { 2 } } { z _ { 1 } - z _ { 2 } } } - 2 i { \frac { { \frac { 1 } { 2 } } \Gamma _ { 3 } } { z _ { 1 } - z _ { 3 } } } + ( 2 i ) ^ { 2 } ( { \frac { 1 } { 2 } } \Gamma _ { 2 } ) ( { \frac { 1 } { 2 } } \Gamma _ { 3 } ) K _ { 1 }
# 72  \frac { g \gamma _ { d } ^ { \alpha } } { \sqrt { 2 } } \left( \begIn{array} { c c } { 0 } & { x _ { d } } \\ { i W _ { \alpha } ^ { 2 } \psi _ { 2 L } + Z _ { \alpha } \psi _ { 1 L } / \operatorname { c o s } \theta _ { w } } \\ \end{array} \right) + \frac { M _ { i } + \eta _ { i } } { \sqrt { 2 } } \left( \begIn{array} { c } { \psi _ { 1 R } } \\ { \psi _ { 1 R } } \\ \end{array} \right) .
# 73  T _ { 1 2 3 4 } ( p ^ { 2 } ; m _ { i } ^ { 2 } ) = B _ { 0 } ( p ^ { 2 } ; m _ { 1 } ^ { 2 } , m _ { 2 } ^ { 2 } ) B _ { 0 } ( m _ { 1 } ^ { 2 } ; m _ { 3 } ^ { 2 } , m _ { 4 } ^ { 2 } ) + T _ { 1 2 3 4 } ^ { ( 3 ) } ( p ^ { 2 } ; m _ { i } ^ { 2 } ) \, .
# 74  V _ { \mathrm { r e n } } ( \chi ) = { \frac { 1 } { 2 } } m _ { R } ^ { 2 } \chi + { \frac { 1 } { 4 } } \lambda _ { R } \chi ^ { 2 } + V _ { \mathrm { f i n } } ( \chi ) + { \frac { 1 } { 6 4 \pi ^ { 2 } } } ( m _ { R } ^ { 2 } + 3 \lambda _ { R } \chi ) ^ { 2 } \operatorname { l n } { \frac { \eta ^ { 2 } } { \mu ^ { 2 } } }
# 75  \mu ^ { 2 } = m _ { 0 } ^ { 2 } C _ { 1 } + A _ { 0 } ^ { 2 } C _ { 2 } + m _ { \frac { 1 } { 2 } } ^ { 2 } C _ { 3 } + m _ { \frac { 1 } { 2 } } A _ { 0 } C _ { 4 } - \frac { 1 } { 2 } M _ { Z } ^ { 2 } + \frac { 3 } { 5 } \frac { t ^ { 2 } + 1 } { t ^ { 2 } - 1 } S _ { 0 } p
# 76  [ V _ { \alpha } , V _ { \beta } ] = \epsilon _ { \alpha \beta } ^ { ~ ~ ~ \gamma } V _ { \gamma } , ~ ~ [ V _ { \alpha } , V _ { m } ^ { a } ] = V _ { m } ^ { b } ( \sigma _ { \alpha } ) _ { b } ^ { ~ a } , ~ ~ ~ \{ V _ { m } ^ { a } , V _ { m } ^ { b } \} = - m ^ { 2 } ( \sigma ^ { \alpha } ) ^ { a b } V _ { \alpha } ,
# 77  \bar { H } _ { \mathrm { g } } = H _ { \mathrm { g } } ( q ^ { r } , p ^ { r } ) + \lambda _ { a } ^ { ( 1 ) r _ { a } } \pi _ { a } ^ { r _ { a } } + \lambda _ { a } ^ { ( 2 ) r _ { a } } \psi _ { a } ^ { r _ { a } } + \lambda _ { a } ^ { ( 3 ) } \theta _ { a } + \lambda _ { a } ^ { ( 4 ) } \gamma _ { a } ,
# 78  \sum _ { e } \sum _ { m , n = 0 } ^ { 1 } C _ { e } ( m , n ) \theta ^ { 4 } [ e ] F _ { R , t w s } ^ { m , n } = E ( z , 0 ) ^ { - 2 } \sum _ { i = 2 } ^ { 3 } C _ { i } \theta _ { i } ^ { 1 2 } ( 0 | \tau ) \frac { \theta _ { i } ^ { 2 } ( z | \tau ) } { \theta _ { i } ^ { 2 } ( 0 | \tau ) } ,
# 79  A _ { 3 } ( z , \bar { z } ) = \frac { 1 } { \theta } \partial _ { \bar { z } } \left( \frac { \chi _ { 3 } } { \theta } \right) = - \frac { 1 } { 2 \operatorname { c o s h } ( l ) } \, , \quad \bar { A } _ { 3 } ( z , \bar { z } ) = \frac { 1 } { \theta } \partial _ { z } \left( \frac { \chi _ { 3 } } { \theta } \right) = - \frac { 1 } { 2 \operatorname { c o s h } ( l ) } \, .
# 80  A \; = \; i 4 \pi ^ { 2 } M _ { \psi } \; e _ { c } g _ { J } \; \alpha _ { S } \; \int _ { 0 } ^ { \infty } \; \frac { d k _ { T } ^ { 2 } } { 2 \overline { { Q } } ^ { 2 } ( \overline { { Q } } ^ { 2 } + k _ { T } ^ { 2 } ) } \; \frac { \partial ( x g ( x , k _ { T } ^ { 2 } ) ) } { \partial k _ { T } ^ { 2 } } .
# 81  L _ { \nu _ { \alpha } } \simeq \frac { 1 } { 2 4 \zeta ( 3 ) } \left[ \pi ^ { 2 } ( \tilde { \mu } _ { \alpha } - \tilde { \mu } _ { \overline { { \alpha } } } ) + 6 ( \tilde { \mu } _ { \alpha } ^ { 2 } - \tilde { \mu } _ { \overline { { \alpha } } } ^ { 2 } ) \operatorname { l n } 2 + ( \tilde { \mu } _ { \alpha } ^ { 3 } - \tilde { \mu } _ { \overline { { \alpha } } } ^ { 3 } ) \right] .
# 82  Z = \int { \cal D } A _ { \mu } { \cal D } \pi ^ { \mu } { \cal D } \phi { \cal D } \pi _ { \phi } { \cal D } \theta { \cal D } \pi _ { \theta } { \cal D } \rho { \cal D } \pi _ { \rho } \prod _ { i , j = 1 } ^ { 4 } \delta ( \tilde { \Omega } _ { i } ) \delta ( \Gamma _ { j } ) \, \mathrm { d e t } \mid \{ \tilde { \Omega } _ { i } , \Gamma _ { j } \} \mid e ^ { i S } ,
# 83  \alpha ( \nu \to \nu e ^ { + } e ^ { - } ) = \frac { G _ { F } ^ { 2 } ( g _ { V } ^ { 2 } + g _ { A } ^ { 2 } ) } { ( 3 \pi ) ^ { 3 } } m ^ { 4 } E \left( \frac { B } { B _ { c r } } \right) ^ { 2 } \left( \operatorname { l n } ( \kappa ) - \frac { \operatorname { l n } ( 3 ) } { 2 } - \gamma _ { E } - \frac { 2 9 } { 2 4 } \right) \quad ,
# 84  \Gamma ^ { ( 1 ) } = \frac { 3 1 } { 1 8 0 } \operatorname { l n } ( \mu ^ { 2 } a ^ { 2 } ) + \frac { 7 } { 4 5 } \operatorname { l n } ( 2 ) + \frac { 1 } { 2 } \operatorname { l n } ( \pi ) + \frac { 6 9 3 1 } { 3 0 2 4 0 } - \frac { 1 } { 3 } \zeta _ { R } ^ { \prime } ( - 3 ) + \frac { 1 1 } { 6 } \zeta _ { R } ^ { \prime } ( - 1 ) .
# 85  \begIn{array} { c c c c } { e _ { 1 } e _ { 2 } = e _ { 3 } ~ , ~ e _ { 2 } e _ { 3 } = e _ { 1 } ~ , ~ e _ { 3 } e _ { 1 } = e _ { 2 } } \\ { e _ { 3 } e _ { 2 } = - e _ { 1 } ~ , ~ e _ { 2 } e _ { 1 } = - e _ { 3 } ~ , ~ e _ { 1 } e _ { 3 } = - e _ { 2 } ~ . } \\ \end{array}
# 86  \delta m _ { B } = \frac { G _ { F } ^ { 2 } M _ { W } ^ { 2 } } { 6 \pi ^ { 2 } } m _ { B } f _ { B } ^ { 2 } B _ { B } \eta _ { t } \left| V _ { t b } V _ { t d } ^ { * } \right| ^ { 2 } \left( A _ { W W } + \operatorname { c o t } ^ { 2 } \beta A _ { W H } + \operatorname { c o t } ^ { 4 } \beta A _ { H H } \right) ,
# 87  { \cal G } = \frac { 1 } { 2 } M _ { i j } d { \bf x } _ { i } \cdot d { \bf x } _ { j } + \frac { g ^ { 4 } } { 2 ( 4 \pi ) ^ { 2 } } ( M ^ { - 1 } ) _ { i j } ( d \xi _ { i } + { \bf W } _ { i k } \cdot d { \bf x } _ { k } ) ( d \xi _ { j } + { \bf W } _ { j l } \cdot d { \bf x } _ { l } ) .
# 88  \alpha _ { 0 0 } + \alpha _ { 1 0 } \, p + \alpha _ { 0 1 } \, \, p ^ { \prime } + \alpha _ { 2 0 } \, \, p ^ { 2 } + \alpha _ { 0 2 } \, p ^ { 2 } + 2 \alpha _ { 1 1 } \, p p ^ { \prime } + \alpha _ { 2 1 } \, \, p ^ { 2 } p ^ { \prime } + \alpha _ { 1 2 } \, \, p p ^ { 2 } + \alpha _ { 2 2 } \, \, p ^ { 2 } p ^ { 2 } = 0 .
# 89  V ( \varphi _ { 0 } , \beta ) = { \frac { 2 } { \beta } } \sum _ { s = 1 } ^ { \infty } \sum _ { n = - \infty } ^ { + \infty } \int { \frac { d ^ { d } p } { ( 2 \pi ) ^ { d } } } { \frac { ( - 1 ) ^ { s } } { s } } { \frac { ( M + g \varphi _ { 0 } ) ^ { 2 s } } { ( \omega _ { n } ^ { 2 } + q ^ { 2 } ) ^ { s } } } .
# 90  \frac { b _ { r } ^ { 2 } } { b _ { s } ^ { 2 } } = \frac { ( 1 + m ^ { 2 } k ^ { 2 } s ^ { 4 } ) r ^ { 4 } \operatorname { s i n } ^ { 2 } \theta _ { r } } { ( 1 + m ^ { 2 } k ^ { 2 } r ^ { 4 } ) s ^ { 4 } \operatorname { s i n } ^ { 2 } \theta _ { s } } e ^ { 2 i ( \varphi _ { r } - \varphi _ { s } ) }
# 91  4 m _ { 1 } ^ { 2 } \lambda ^ { ( M ) } \sim 1 0 ^ { - 1 0 } ~ \mathrm { e V } ^ { 2 } ~ , ~ m _ { 3 } ^ { 2 } - m _ { 2 } ^ { 2 } \sim 3 \times 1 0 ^ { - 3 } ~ \mathrm { e V } ^ { 2 } ~ , ~ m _ { 1 } ^ { 2 } \ll m _ { 2 } ^ { 2 } \simeq m _ { 3 } ^ { 2 } \sim 0 . 5 ~ \mathrm { e V } ^ { 2 } ~ .
# 92  H = { \frac { 1 } { 2 } } e ^ { - 2 A _ { 0 } ( y ) } ( \dot { \phi } ^ { 2 } + ( \vec { \nabla } \phi ) ^ { 2 } ) + { \frac { 1 } { 2 b _ { 0 } ^ { 2 } } } ( \phi ^ { \prime } ) ^ { 2 } e ^ { - 4 A _ { 0 } ( y ) } + { \frac { 1 } { 2 } } m ^ { 2 } \phi ^ { 2 } e ^ { - 4 A _ { 0 } ( y ) } .
# 93  P _ { 0 1 } \; = \; \frac { \alpha } { \pi } | M _ { e l } | ^ { 2 } \int \frac { \mathrm { d ^ { 3 } } k } { 2 \omega } \delta \left( ( p _ { 1 } + p _ { 2 } - k ) ^ { 2 } - Q ^ { 2 } \right) \frac { 2 Q ^ { 2 } } { 2 ( p _ { 1 } \cdot k ) 2 ( p _ { 2 } \cdot k ) } \, \Theta ( k _ { \perp } ^ { 2 } - \lambda ^ { 2 } ) \; ,
# 94  n ^ { 6 _ { 0 } } = \sum _ { i } n _ { i } ^ { \mathrm { e q } } = \sum _ { i } \frac { g _ { i } } { ( 2 \pi ) ^ { 3 } } \int d ^ { 3 } p _ { i } e ^ { - E _ { i } / T } = \frac { T } { 2 \pi ^ { 2 } } \sum _ { i } g _ { i } m _ { i } ^ { 2 } K _ { 2 } \left( \frac { m _ { i } } { T } \right)
# 95  A = 4 Y g ^ { 2 } T _ { Q } ^ { a } T _ { U } ^ { a } \int { \frac { d ^ { 4 } p } { ( 2 \pi ) ^ { 4 } } } { \frac { 1 } { p ^ { 2 } } } \sum _ { n = - \infty } ^ { \infty } { \frac { ( n + q _ { F } ) M _ { c } } { p ^ { 2 } + ( n + q _ { F } ) ^ { 2 } M _ { c } ^ { 2 } } } \, ,
# 96  1 = \int D B _ { + } ^ { 1 } \delta ( B _ { + } ^ { 1 } ) D B _ { + } ^ { 2 } \delta ( B _ { + } ^ { 2 } ) \operatorname { e x p } \{ i \int d ^ { 2 } x \, [ \psi _ { - } ^ { \dagger 1 } B _ { + } ^ { 1 } \psi _ { - } ^ { 1 } + \psi _ { - } ^ { \dagger 2 } B _ { + } ^ { 2 } \psi _ { - } ^ { 2 } ] \} \quad ,
# 97  m _ { \sigma } = - \frac { ( \lambda \rho ) ^ { 2 } } { m _ { \Sigma } } , ~ ~ ~ m _ { \sigma } ^ { \prime } = \frac { ( \lambda \rho ) ^ { 2 } m _ { \Sigma } ^ { \prime } } { ( m _ { \Sigma } + 5 m _ { \Sigma } ^ { \prime } ) \, m _ { \Sigma } } , ~ ~ ~ \mu _ { \sigma } = - \frac { \lambda \rho \mu _ { \Sigma } } { m _ { \Sigma } + 5 m _ { \Sigma } ^ { \prime } } .
# 98  \Delta M = \frac { 1 } { 2 } \sum _ { i } \omega _ { i } + \frac { \langle V \rangle } { 4 \pi } + \frac { 1 } { 2 } \int _ { - \infty } ^ { \infty } \frac { d k } { 2 \pi } \omega ( k ) \frac { d } { d k } \delta ( k ) - \frac { \langle V \rangle } { 4 } \int _ { - \infty } ^ { \infty } \frac { d k } { 2 \pi } \frac { 1 } { \sqrt { k ^ { 2 } + m ^ { 2 } } } \; .
# 99  f ( \nu , x ) = \sum _ { k = 0 } ^ { N } \frac { 1 } { k ! } \frac { \partial ^ { ( k ) } f ( 0 , x ) } { \partial \nu ^ { k } } \nu ^ { k } + \sum _ { m = 1 } ^ { p } \left[ \frac { r _ { m } ( x ) } { \nu - p _ { m } ( x ) } - h _ { m } ^ { ( N ) } ( \nu , x ) \right] + I _ { p } ( \nu , x , N ) \ .
