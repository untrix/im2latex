# %%
import sys
import pandas as pd
sys.path.extend(['../src/commons'])
import pub_commons as pub
# %matplotlib inline
pd.options.display.width = None
# Out:
# <style>.container { width:90% !important; }</style>
# Using TensorFlow backend.

# %%
pub.disp_unmatched('I2L-NOPOOL')
# Out:
#     edit_distance  $\mathbf{y}$_len  \
# 0   0.025641       39
# 1   0.035714       112
# 2   0.075758       66
# 3   0.214953       107
# 4   0.069444       72
# 5   0.041667       48
# 6   0.066667       60
# 7   0.155172       58
# 8   0.138889       36
# 9   0.039604       101
# 10  0.104651       86
# 11  0.041667       72
# 12  0.053571       56
# 13  0.184783       92
# 14  0.113636       132
# 15  0.105263       38
# 16  0.126437       87
# 17  0.088889       90
# 18  0.010638       94
# 19  0.185714       70
# 20  0.009804       102
# 21  0.283784       74
# 22  0.257576       66
# 23  0.048780       41
# 24  0.416667       60
# 25  0.098361       61
# 26  0.261682       107
# 27  0.016949       118
# 28  0.072289       83
# 29  0.117117       111
# 30  0.060606       66
# 31  0.255319       47
# 32  0.132743       113
# 33  0.341085       129
# 34  0.500000       30
# 35  0.127273       55
# 36  0.090909       44
# 37  0.250000       72
# 38  0.070922       141
# 39  0.192982       114
# 40  0.097222       72
# 41  0.070588       85
# 42  0.134752       141
# 43  0.059701       134
# 44  0.073684       95
# 45  0.022727       88
# 46  0.157895       38
# 47  0.107143       84
# 48  0.037037       108
# 49  0.026316       38
# 50  0.042857       70
# 51  0.068182       44
# 52  0.056911       123
# 53  0.009259       108
# 54  0.128571       70
# 55  0.102362       127
# 56  0.317073       82
# 57  0.145161       62
# 58  0.136364       44
# 59  0.041237       97
# 60  0.157895       38
# 61  0.051546       97
# 62  0.035211       142
# 63  0.056180       89
# 64  0.048387       62
# 65  0.111111       99
# 66  0.050847       59
# 67  0.107527       93
# 68  0.022472       89
# 69  0.015152       66
# 70  0.084507       71
# 71  0.074074       81
# 72  0.020000       50
# 73  0.120301       133
# 74  0.046512       43
# 75  0.130435       46
# 76  0.049383       81
# 77  0.048544       103
# 78  0.111111       72
# 79  0.019802       101
# 80  0.063492       63
# 81  0.080460       87
# 82  0.136364       110
# 83  0.115385       26
# 84  0.027027       37
# 85  0.090909       66
# 86  0.136364       22
# 87  0.038462       78
# 88  0.057971       69
# 89  0.181818       33
# 90  0.150685       146
# 91  0.184211       76
# 92  0.122222       90
# 93  0.088889       135
# 94  0.177215       79
# 95  0.018182       55
# 96  0.050505       99
# 97  0.190476       63
# 98  0.100000       40
# 99  0.136364       88
#
#    $\mathbf{y}$                                                                                                                                                                                                                                                                                                                                                                                                                                                             \
# 0   ${ \cal I } | _ { j ^ { a } ( j - 1 7 2 8 ) ^ { b } } \sim ( T - \rho ) ^ { 2 a - 2 } , $
# 1   $\left[ 2 \partial _ { - } F _ { + i } ( x ^ { + } , \vec { x } ) , F _ { + - } ( x ^ { + } , \vec { y } ) \right] = - i \partial _ { i } ^ { x } ( \Delta _ { \perp } ) ^ { 2 } [ \Delta _ { 2 - 2 \delta } ] ^ { - 1 } ( x _ { \perp } - y _ { \perp } ) \delta ( { x ^ { - } } - y ^ { - } ) $
# 2   $\delta _ { K } \left[ j _ { T } ^ { 0 } \bullet R _ { M N } \right] = \left( \mathrm { g l o b a l l y d e f i n e d ~ s m o o t h ~ s u r f a c e ~ t e r m } \right) \quad . $
# 3   $\zeta ( \{ 2 p \} _ { n } ) = \frac { 2 p \cdot ( 2 \pi ) ^ { 2 p n } } { ( 2 p n + p ) ! } \left( \frac { 1 } { 2 \operatorname { s i n } \frac { \pi } { 2 p } } \right) ^ { 2 p n + p } \bigg \{ 1 + \sum _ { k = 2 } ^ { N _ { p } } R _ { p , k } ^ { 2 p n + p } \bigg \} \, , $
# 4   $\widetilde { \phi } ( - x - a ) = \Biggl ( \frac { C ^ { * } ( \omega ) } { C ( \omega ) } \operatorname { e x p } \left( i \int _ { - a + \epsilon } ^ { - \epsilon } d s \, k ( v ( s ) , \omega ) \Biggr ) \right) \, \phi ( x ) . $
# 5   $\Pi ( s ) = \frac { \pi ^ { 2 } R ^ { 4 } } { 2 \kappa _ { 6 } ^ { 2 } } [ s \operatorname { l n } ( - R ^ { 2 } s ) ] , $
# 6   $\epsilon _ { i j k } \epsilon _ { A B } \left( U ^ { i } U ^ { j } U ^ { k } V ^ { A } V ^ { B } \right) _ { \mathrm { c o l o u r ~ s i n g l e t } } $
# 7   $L ( k ) = i \Big \{ \Big ( { \frac { v _ { f } } { k \cdot v _ { f } } } \Big ) - \Big ( { \frac { v _ { i } } { k \cdot v _ { i } } } \Big ) \Big \} . $
# 8   $Z ( A ) = \int { \cal D } h ( x ) \; \mathrm { e } ^ { - N ^ { 2 } S [ h ( x ) ] } , $
# 9   $w _ { \alpha \beta } ^ { ( Q ^ { \prime } Q ) } ( p _ { Q ^ { \prime } } , p _ { Q } ) = \frac { 1 } { 2 } \sum _ { s p i n s } \bar { u } _ { Q ^ { \prime } } O _ { \alpha } u _ { Q } \cdot \bar { u } _ { Q } O _ { \beta } ^ { + } u _ { Q ^ { \prime } } , $
# 10  $\left( \Delta \partial _ { \mu } \partial _ { \nu } \Delta \right) _ { x y } = \frac { - \delta _ { \mu \nu } } { 8 \pi ^ { 2 } ( x - y ) ^ { 2 } } + \frac { ( x - y ) _ { \mu } ( x - y ) _ { \nu } } { 4 \pi ^ { 2 } \left| x - y \right| ^ { 4 } } $
# 11  ${ \frac { ( \Delta m ^ { 2 } ) _ { s o l } ( \Delta m ^ { 2 } ) _ { a t m } } { m _ { \nu } ^ { 4 } ( \operatorname { s i n } ^ { 2 } 2 \theta ) _ { a t m } } } = 2 I ^ { 2 } , $
# 12  $( \nabla _ { x } ^ { 2 } + 1 ) ( B _ { 2 \mu } ^ { ( 1 ) } - \frac { 2 } { \sqrt { 2 } } b _ { \mu } ^ { ( 1 ) [ 1 2 ] } ) = 0 . $
# 13  $O _ { \mu , \mu _ { 1 } , \mu _ { 2 } , \ldots , \mu _ { n } } ^ { n } = \bar { d } ( 0 ) \gamma _ { \mu } \gamma _ { 5 } \, i \! \! \stackrel { \leftrightarrow } { D } _ { \mu _ { 1 } } \ldots \, i \! \! \stackrel { \leftrightarrow } { D } _ { \mu _ { n } } u ( 0 ) \, , $
# 14  $\widehat { M } [ A _ { 1 } ( m _ { 1 } ) A _ { 2 } ( m _ { 2 } ) ] = \left\{ \begin{array} { l l } { A _ { 1 } ( m _ { 1 } ) A _ { 2 } ( m _ { 2 } ) } & { \mathrm { i f ~ m _ 1 ~ \geq ~ m _ 2 ~ } } \\ { A _ { 2 } ( m _ { 2 } ) A _ { 1 } ( m _ { 1 } ) } & { \mathrm { i f ~ m _ 1 ~ < ~ m _ 2 ~ } . } \\ \end{array} \right. $
# 15  $\hat { \hat { k } } ^ { 2 } = e ^ { - \frac { 2 } { 3 } \hat { \phi } } \hat { k } ^ { 2 } \, . $
# 16  $\langle 0 \left| T F _ { \mu \nu } ( x ) F _ { \alpha \beta } ( y ) \right| 0 \rangle \sim \frac { \Lambda _ { \mu \alpha } ( x - y ) \Lambda _ { \nu \beta } ( x - y ) - \Lambda _ { \mu \beta } ( x - y ) \Lambda _ { \nu \alpha } ( x - y ) } { ( x - y ) ^ { 4 } } \, . $
# 17  $\mathrm { I m } Z ^ { \prime } = 2 { \frac { m _ { t } } { m _ { b } } } { \frac { \operatorname { s i n } 2 \theta } { \operatorname { c o s } ^ { 2 } 2 \theta } } \, \mathrm { I m } ( V _ { R t b } V _ { L t b } ^ { * } e ^ { i \delta } ) \; , $
# 18  $V ( | z | ) = \left( \frac { b } { 6 } \right) ^ { 2 } \frac { | z | ^ { 4 } } { ( 1 - | z | ^ { 2 } ) ^ { 2 } } \left\{ 3 \left( \operatorname { l o g } \left| \frac { z } { z _ { t r } } \right| ^ { 3 } \right) ^ { 2 } + C _ { 2 } | z | ^ { 2 } \right\} . $
# 19  $T _ { a } = \left( \begin{matrix} { { \bf R } _ { a } } & { { \bf 0 } } & { 0 } \\ { { \bf 0 } } & { { \bf S } _ { a } } & { 0 } \\ { 0 } & { 0 } & { Q _ { a } } \\ \end{matrix} \right) $
# 20  ${ \cal L } = \frac { 1 } { F ^ { 2 } } \biggl ( \eta _ { L L } ( \bar { l } ^ { \prime } l ) _ { L } \, ( \bar { l } l ) _ { L } + \eta _ { L R } ( \bar { l } ^ { \prime } l ) _ { L } \, ( \bar { l } l ) _ { R } + ( L \leftrightarrow R ) + \mathrm { h . c . } \biggr ) , $
# 21  $\mathrm { I } _ { n } = \int _ { 0 } ^ { 2 \pi } d \varphi \, \frac { \operatorname { c o s } \, ( n \varphi ) } { \left[ 2 \operatorname { c o s } ( \varphi - \theta / 2 ) - \beta \right] \left[ 2 \operatorname { c o s } ( \varphi + \theta / 2 ) - \beta \right] } $
# 22  $a \quad \stackrel { \mathrm { d e f } } { = } \quad \frac { \operatorname* { l i m } _ { n \rightarrow \infty } \frac { M ( n ) } { n } } { \sigma _ { \perp } } \approx \frac { 1 } { G } \left( 0 . 8 3 \pm 0 . 0 2 \right) $
# 23  $f _ { -- } ^ { ~ + + } ( \xi ^ { m } ) = h ( \xi ^ { ( + + ) } ) e ^ { - 2 ( W + L ) } $
# 24  $Z ( M , G ( \underline { x } ) ) = \sum _ { \underline { j } , \underline { { \tilde { J } } } } W ( \underline { j } , \underline { { \tilde { J } } } ) ( X , G ( \underline { x } ) ) . $
# 25  $\sum _ { \mu = 1 } ^ { d + 2 } u _ { \mu } ^ { \frac { D } { \delta _ { \mu } } } + a _ { 0 } \prod _ { \mu = 1 } ^ { d + 2 } \left( u _ { \mu } \right) = 0 . $
# 26  $\frac { q ^ { \frac { r ( r - 1 ) } { 4 } } } { ( q , q ) _ { \infty } } \sum _ { j = - \infty } ^ { \infty } ( q ^ { j [ j \nu ( \nu + 1 ) + r ( \nu + 1 ) - \nu ] } - q ^ { ( j \nu + r ) [ j ( \nu + 1 ) + 1 ] } ) \; ; \; \; \; \; \; r = 1 , 2 , \ldots , \nu - 1 , $
# 27  $V _ { N } \cong \left( \frac { \vec { N } _ { 2 } \times \hat { N } _ { 3 } } { \mid \vec { N } _ { 2 } \times \hat { N } _ { 3 } \mid } , \frac { \vec { N } _ { 2 } - \vec { N } _ { 2 } \cdot \hat { N } _ { 3 } \hat { N } _ { 3 } } { \mid \vec { N } _ { 2 } \times \hat { N } _ { 3 } \mid } , \hat { N } _ { 3 } \right) . $
# 28  $\widetilde { \cal F } ^ { ( 1 ) } ( x ) = - \int d y \int d z \int d w \Phi ^ { j } ( y ) \omega _ { j k } ( y , z ) X ^ { k l } ( z , w ) \{ \Omega _ { l } ( w ) , { \cal F } ( x ) \} _ { ( { \cal F } ) } . $
# 29  $\beta ( r ) _ { N u t } ^ { 2 } = \frac { \lambda \, c \, \, 2 ^ { n } \, r \, ( r - L ) \, L ^ { n } } { ( n + 1 ) ( r + L ) ^ { n } } \, \mathrm { { A p p e l l } } F _ { 1 } [ n + 1 , 2 , - n , n + 2 , 1 - \frac { r } { L } , \frac { L - r } { 2 L } ] . $
# 30  $\sqrt { \bar { \chi } } = 2 \pi \beta _ { c } \hat { \phi } ^ { 2 } \left[ 1 - \frac { 2 4 \pi ^ { 2 } } { \lambda _ { T _ { c } } } \left( \frac { \phi } { T _ { c } } \right) ^ { 2 } \right] . $
# 31  $\hat { K } ^ { 2 } = \hat { J } ^ { 2 } + \frac 1 4 , \ \hat { J } ^ { 2 } = ( L + \frac 1 2 { \bf \sigma ) } ^ { 2 } $
# 32  $\begin{array} { l l } { H _ { e f f } = } & { \frac { 1 } { m _ { X } ^ { J - 1 } } [ f _ { 1 } T r ( X P P ) + f _ { 2 } T r ( X ) T r ( P P ) } \\ { } & { + f _ { 3 } T r ( X P ) T r ( P ) + f _ { 4 } T r ( X ) T r ( P ) T r ( P ) ] , } \\ \end{array} $
# 33  $\left\{ \begin{array} { l } { { \cal F _ { A } } \operatorname* { l i m } _ { \tau ^ { \prime } \rightarrow \infty } { \cal F } _ { { \cal U } _ { \tau ^ { \prime } } { \cal B } } - { \cal F _ { A } F _ { B } } = 0 \; \; \mathrm { f o r } \; \; { \cal A , B } \; \; \mathrm { o f ~ { \bf ~ V } - t y p e } \; , } \\ { 0 \; \; \mathrm { o t h e r w i s e } \; . } \\ \end{array} \right. $
# 34  $a = 1 : \qquad n _ { p h } = \mathrm { { \bf ~ 8 _ b ~ + ~ 1 _ f ~ } } . $
# 35  $D _ { \mu } { \mit \Phi } ^ { A } : = \left( \partial _ { \mu } \delta ^ { A B } + g f ^ { A i B } A _ { \mu } ^ { i } \right) { \mit \Phi } ^ { B } , $
# 36  $\rho ( p , z = 0 ) \approx \mathrm { c o n s t . } \times { \widehat M } _ { P } ^ { 3 - D } \Delta ^ { 2 } T ( p ) ~ . $
# 37  $\vec { p } \vec { \epsilon _ { 1 , 2 } } = | \vec { p } | [ s i n \theta c o s \Phi ( \hat { x } \vec { \epsilon _ { 1 , 2 } } ) + s i n \theta s i n \Phi ( \hat { y } \vec { \epsilon _ { 1 , 2 } } ) ] $
# 38  $m _ { b } ^ { \overline { \mathrm { D R } } } ( m _ { Z } ^ { > } ) = m _ { b } ^ { \overline { \mathrm { M S } } } ( m _ { Z } ^ { > } ) \left( 1 - \frac { 1 } { 3 } \frac { \alpha _ { s } ^ { \overline { \mathrm { M S } } } ( m _ { Z } ) } { \pi } - \frac { 2 9 } { 7 2 } \left( \frac { \alpha _ { s } ^ { \overline { \mathrm { M S } } } ( m _ { Z } ) } { \pi } \right) ^ { 2 } \right) . $
# 39  $\hat { \hat { T } } _ { \hat { \hat { \mu } } \hat { \hat { \nu } } } { } ^ { \hat { \hat { \rho } } } = - \left( i _ { \hat { \hat { k } } _ { ( n ) } } \hat { \hat { C } } \right) _ { \hat { \hat { \mu } } \hat { \hat { \nu } } } Q ^ { n m } \hat { \hat { k } } _ { ( m ) } { } ^ { \hat { \hat { \rho } } } \, . $
# 40  $S _ { B } ^ { i } = \frac { 1 } { \sqrt 2 \kappa _ { 5 } ^ { 2 } } \int d ^ { 4 } x \sqrt { - g _ { E } ^ { ( 4 ) } } \frac { [ \alpha _ { I } ^ { i } ] X ^ { I } } { \cal V } $
# 41  $S = \int _ { M } d ^ { D } x \sqrt { | \tilde { g } | } \left[ \tilde { R } - \left( \omega + { \frac { D - 1 } { D - 2 } } \right) ( \tilde { \nabla } \phi ) ^ { 2 } \right] + 2 \int _ { \partial M } d ^ { D - 1 } x \sqrt { | h | } \tilde { K } \ . $
# 42  $\mathrm { R e } \, \chi _ { T } ^ { \mathrm { D } } ( \omega ) = - \frac { \hbar A } { \pi ^ { 2 } } \int \int _ { R _ { 4 } } d \omega _ { \mathrm { i n } } d k _ { \| } k _ { \| } \sqrt { k _ { \| } ^ { 2 } - ( \omega + \omega _ { \mathrm { i n } } ) ^ { 2 } } \sqrt { \omega _ { \mathrm { i n } } ^ { 2 } - k _ { \| } ^ { 2 } } \; { \overline { n } } ( - \omega _ { \mathrm { i n } } ) $
# 43  $| \alpha , P ^ { + } , P _ { \bot } , \lambda \rangle = \sum _ { n , \lambda _ { i } } \int ^ { \prime } \frac { \, d x _ { i } d ^ { 2 } k _ { \bot i } \, } { 2 ( 2 \pi ) ^ { 3 } } | n , x _ { i } P ^ { + } , x _ { i } P _ { \bot } + k _ { \bot i } , \lambda _ { i } \rangle \Phi _ { n / \alpha } ( x _ { i } , k _ { \bot i } , \lambda _ { i } ) \, , $
# 44  $\chi _ { h } ( q ) = { \frac { q ^ { - c / 2 4 + h } } { ( q ) _ { \infty } } } \sum _ { k = - \infty } ^ { \infty } \big ( q ^ { k ( k p p ^ { \prime } + r p - s p ^ { \prime } ) } - q ^ { ( k p + s ) ( k p ^ { \prime } + r ) } \big ) $
# 45  $\Delta _ { \alpha \beta } = - 4 \sum _ { i < j } \widetilde { J } _ { \alpha \beta } ^ { i j } I m [ A _ { i j } ] = 4 \sum _ { i < j } \widetilde { J } _ { \alpha \beta } ^ { i j } \frac { x _ { i j } } { 1 + x _ { i j } ^ { 2 } } \ . $
# 46  $= \sum _ { i } \tilde { c } _ { i } \tilde { t } _ { i } e _ { \nu _ { i } ^ { * } } { } . $
# 47  ${ \cal L } _ { N J L } \, = \, \bar { q } i \! \not \! \partial q \, + \, \frac { g _ { 0 } } { 4 N _ { c } \Lambda ^ { 2 } } \, \left[ ( \bar { q } q ) ^ { 2 } - ( \bar { q } \gamma _ { 5 } \tau ^ { a } q ) ^ { 2 } \right] . $
# 48  $P ( \nu _ { e } \rightarrow \nu _ { \mu } ) = \frac { 1 } { 2 } ( 1 - \operatorname { c o s } 2 \theta \operatorname { c o s } 2 \bar { \theta } ) - \frac { 1 } { 2 } s i n 2 \theta s i n 2 \bar { \theta } \cdot c o s ( \int _ { 0 } ^ { t } \delta _ { 3 } d t ^ { \prime } ) e ^ { - \frac { \alpha + \gamma } { 2 } t } . $
# 49  $\alpha _ { R } ( Q ) = \frac { \alpha } { 1 - \frac { 2 \alpha } { 3 \pi } \operatorname { l n } \frac { Q } { m } } $
# 50  $A _ { j } = - \frac { 1 } { 2 } \left( \frac { \partial f } { \partial Q _ { j } } \right) ^ { - 1 } \frac { \partial ^ { 2 } f } { \partial { Q _ { j } } ^ { 2 } } \; , \; \; B _ { j } = 0 \; , $
# 51  $H ^ { \mu \nu \rho ^ { \prime } \rho ^ { \prime \prime } } ( 0 ) = g ^ { 2 } U ^ { \mu \nu \rho ^ { \prime } \rho ^ { \prime \prime } } . $
# 52  $e V ^ { \mathrm { Q E D _ { 3 } } } ( \vec { r } ) = \frac { e ^ { 2 } } { 2 \pi } \left( 1 + \frac { e ^ { 2 } } { 8 \pi m } \right) K _ { 0 } \left( \frac { e ^ { 2 } } { 8 \pi } r \right) + \frac { 8 } { m r ^ { 2 } } \left[ 1 - \frac { e ^ { 2 } } { 8 \pi } r K _ { 1 } \left( \frac { e ^ { 2 } } { 8 \pi } r \right) \right] L . $
# 53  $\overline { { | { \cal A } | } } ^ { 2 } = \frac { 2 7 \pi ^ { 2 } \alpha _ { s } ^ { 3 } ( 4 \pi ) ^ { 3 } } { 1 6 } \frac { s ^ { 2 } } { k _ { t } ^ { 2 } } ( 1 - \frac { k _ { T } ^ { 2 } } { M _ { X } ^ { 2 } } ) ^ { 2 } | { \cal I } | ^ { 2 } . $
# 54  $c S _ { a n o m , E u c l } = + { \frac { Q ^ { 2 } } { 4 \pi } } \int \, d ^ { 2 } x \, \sqrt { \bar { g } } \bigl [ ( { \overline { \nabla } } \sigma ) ^ { 2 } + \overline { R } \sigma \bigr ] \, $
# 55  $\Sigma _ { H H } ^ { t t } \left( q ^ { 2 } \right) = - 2 \kappa ( \Lambda ) { \Big \{ } \Lambda ^ { 2 } + \left[ \frac { q ^ { 2 } } { 2 } - 3 m _ { t } ^ { ( 0 ) 2 } ( \Lambda ) \right] \operatorname { l n } \left( \frac { \Lambda ^ { 2 } } { m _ { t } ^ { ( 0 ) 2 } ( \Lambda ) } \right) + { \cal { O } } ( q ^ { 2 } , m _ { t } ^ { 2 } ) { \Big \} } \ . $
# 56  $\frac { d \hat { \sigma } _ { a b \rightarrow c } ^ { ( F - L O ) } } { d p _ { c _ { T } } ^ { 2 } \, d y } = \frac { d \sigma _ { a b \rightarrow c } ^ { ( L O ) } } { d p _ { c _ { T } } ^ { 2 } \, d y } $
# 57  $P _ { q q } ^ { ( 0 ) } ( x ) = C _ { F } \Bigg [ \frac { 1 + x ^ { 2 } } { ( 1 - x ) _ { + } } + \frac { 3 } { 2 } \delta ( 1 - x ) \Bigg ] \; , $
# 58  $F _ { \alpha } ( Q ^ { 2 } ) ( P ^ { \mu } + P ^ { \mu } ) = \left[ { \cal A } _ { 2 } \right] ^ { \mu , \alpha \alpha } . $
# 59  ${ \cal L } = \mathrm { i } \varphi ^ { \dagger } \partial _ { + } \varphi + \mathrm { i } \chi ^ { \dagger } \partial _ { - } \chi + \frac { \mathrm { i } } { \sqrt { 2 } } \left( \varphi ^ { \dagger } \tilde { \partial } _ { m } \chi + \chi ^ { \dagger } \partial _ { m } \varphi \right) + { \cal L } _ { \mathrm { i n t } } ( \varphi , \chi ) $
# 60  $R _ { a } ^ { \bar { b } } ( \beta ) = \delta _ { a } ^ { \bar { b } } R _ { R L } ( \beta ) . $
# 61  ${ \frac { d \ \operatorname { l n } W _ { n p } ^ { I } ( Q ^ { 2 } ) } { d \ \operatorname { l n } Q ^ { 2 } } } = { \frac { \pi ^ { 2 } } { 2 } } \int \! d n ( \rho ) \ \rho ^ { 4 } \operatorname { l n } { \left( \rho ^ { 2 } \lambda ^ { 2 } \right) } \equiv B _ { I } \ . $
# 62  $\left[ \hat { x } ^ { \mu } , \hat { \pi } _ { \nu } \right] _ { - } = i \left\{ x ^ { \mu } , \pi _ { \nu } \right\} _ { D ( \Phi _ { 3 } ^ { ( 1 ) } ) } = i \delta _ { \nu } ^ { \mu } \; , \; \; \left[ \hat { \psi } ^ { \mu } , \hat { \psi } ^ { \nu } \right] _ { + } = i \left\{ \psi ^ { \mu } , \psi ^ { \nu } \right\} _ { D ( \Phi _ { 3 } ^ { ( 1 ) } ) } = - \frac { 1 } { 2 } g ^ { \mu \nu } \; . $
# 63  $g ( z ) = \frac { \theta _ { \tau } ( z , z _ { 0 } ) } { | \theta _ { \tau } ( z , z _ { 0 } ) | } = \sqrt { \frac { \theta _ { \tau } ( z , z _ { 0 } ) } { \overline { { \theta _ { \tau } ( z , z _ { 0 } ) } } } } \in U ( 1 ) \, , $
# 64  $M = { \frac { 2 \bar { \cal R } ^ { 3 } } { 8 \omega + 3 } } \left\{ ( 4 \omega + 3 ) k + 4 ( \omega + 1 ) { \frac { \bar { \cal R } ^ { 2 } } { l ^ { 2 } } } \right\} \, . $
# 65  $C _ { 0 } = { \frac { { \hat { q } } ( q ^ { 2 } \, - \, B ^ { 2 } / 2 ) \, - \, B ^ { 2 } / 2 ( q \gamma ) _ { \perp } } { ( q ^ { 2 } - B ^ { 2 } / 2 ) ^ { 2 } - B ^ { 2 } ( q _ { \perp } ^ { 2 } + B ^ { 2 } / 4 ) } } . $
# 66  $\beta \Omega = - \operatorname { l n } \operatorname { t a n h } ^ { 2 } \epsilon ( p ) \Leftrightarrow \operatorname { s i n h } ^ { 2 } \epsilon ( p ) = \frac { 1 } { e ^ { \beta \Omega } - 1 } \, { . } $
# 67  ${ \cal L } [ \chi , U , U ^ { \dagger } ] \; = \; \frac { 1 } { 2 } \, ( \partial _ { \mu } \chi ) ( \partial ^ { \mu } \chi ) \; + \; \frac { 1 } { 4 } \, T r \left[ \frac { } { } ( \partial _ { \mu } U ) ( \partial ^ { \mu } U ^ { \dagger } ) \right] \; - \; V ( \chi , U ) \; , $
# 68  $T _ { 1 0 } ^ { m \; k } \; = \frac { \Theta } { 4 \ell _ { P } ^ { 7 } } \, < s _ { K } ^ { a } \; \epsilon ^ { i j k } \epsilon ^ { I J K } \langle W , \xi | \hat { A } _ { a } ^ { m } ( v ) \hat { w } _ { i I \Delta } ( v ) $
# 69  $m _ { L R } = \left( \begin{array} { c c c } { \lambda ^ { m } } & { 0 } & { 0 } \\ { 0 } & { \lambda ^ { n } } & { 0 } \\ { 0 } & { 0 } & { 1 } \\ \end{array} \right) m _ { f } , $
# 70  $\operatorname* { l i m } _ { t \rightarrow \infty } B _ { n } ( f _ { n , t } ) \cdots B _ { 1 } ( f _ { 1 , t } ) \, \Omega \doteq \big ( \psi _ { n } \times \cdots \times \psi _ { 1 } \big ) ^ { \mathrm { o u t } } \, $
# 71  $\partial _ { \bar { z } } T _ { 4 } = \lambda \oint _ { z } \frac { d \zeta } { 2 \pi i } \left( \prod _ { i = 1 } ^ { N } \operatorname { c o s } [ { \beta } _ { i } \phi _ { i } ( \zeta , \bar { z } ) ] \right) T _ { 4 } ( z ) \ . $
# 72  $\delta { \cal P } _ { 2 i } = - \tilde { G } _ { i } ^ { ( 2 ) } + \partial _ { i } \pi \equiv - \tilde { \gamma } _ { i } ^ { ( 2 ) } , $
# 73  $\operatorname { s i n } \left( \frac { \tilde { p } _ { 1 } \cdot k } { 2 } \right) \operatorname { s i n } \left( \frac { \tilde { p } _ { 2 } \cdot k } { 2 } \right) \operatorname { s i n } \left( \frac { \tilde { p } _ { 3 } \cdot k } { 2 } \right) = - \frac { 1 } { 4 } \left( \operatorname { s i n } \tilde { p } _ { 1 } \cdot k + \operatorname { s i n } \tilde { p } _ { 2 } \cdot k + \operatorname { s i n } \tilde { p } _ { 3 } \cdot k \right) $
# 74  $\frac { d x ^ { a } } { r d t } = \{ H _ { \mathrm { r e d } } , x ^ { a } \} ^ { \mathrm { r e d } } , $
# 75  $a _ { \mathrm { U V } } - a _ { \mathrm { I R } } = - \int _ { \lambda _ { \mathrm { U V } } } ^ { \lambda _ { \mathrm { I R } } } $
# 76  $\Gamma _ { \gamma \gamma } ( f _ { 0 } ( 1 7 1 0 ) ) : \Gamma _ { \gamma \gamma } ( f _ { 0 } ( 1 5 0 0 ) ) : \Gamma _ { \gamma \gamma } ( f _ { 0 } ( 1 3 7 0 ) ) = 5 9 . 3 8 8 : 2 7 . 9 0 8 : 1 8 . 5 6 4 . $
# 77  $\ m ^ { 2 } ( \beta ) = m _ { 0 } ^ { 2 } + \lambda _ { 0 } F ( D ) \left( m ( \beta ) \right) ^ { D - 2 } \int _ { m ( \beta ) \beta } ^ { \infty } d \tau \left( ( \frac { \tau } { m ( \beta ) \beta } ) ^ { 2 } - 1 \right) ^ { \frac { D - 3 } { 2 } } \frac { 1 } { e ^ { \tau } - 1 } . $
# 78  $G [ u ] _ { n _ { 1 } n _ { 2 } } ^ { - 1 } = \frac { \delta } { \delta \Psi ( n _ { 1 } ) } \frac { \delta } { \delta \overline { { \Psi } } ( n _ { 2 } ) } S _ { f } ^ { \chi w } [ \Psi ] . $
# 79  $\delta _ { i } \simeq { \frac { I m [ \mu _ { 1 } \mu _ { 2 } ^ { * } \sum _ { k , l } f _ { 1 k l } f _ { 2 k l } ^ { * } ] } { 8 \pi ^ { 2 } ( M _ { 1 } ^ { 2 } - M _ { 2 } ^ { 2 } ) } } { \frac { M _ { i } } { \Gamma _ { i } } } , $
# 80  $\langle f _ { Q ^ { * } } ^ { } ( s , b , Q ^ { 2 } ) \rangle = [ \tilde { N } ( s , b ) + ( N - 1 ) ] \, V _ { Q ^ { * } } ( b , Q ^ { 2 } ) . $
# 81  $( p _ { R } - p _ { R } ^ { \mathrm { t u b e } } ) ^ { 2 } = p _ { R } ^ { 2 } - \{ p _ { R } , p _ { R } ^ { \mathrm { t u b e } } \} + ( { p _ { R } ^ { \mathrm { t u b e } } } ) ^ { 2 } \ . $
# 82  ${ R ^ { \alpha } } _ { \beta } = { \frac { 1 } { 4 } } \left( 2 { f ^ { \alpha } } _ { \beta i } { f ^ { i } } _ { \gamma \delta } + { f ^ { \alpha } } _ { \beta \epsilon } { f ^ { \epsilon } } _ { \gamma \delta } - { f ^ { \alpha } } _ { \gamma \epsilon } { f ^ { \epsilon } } _ { \beta \delta } \right) e ^ { \gamma } \wedge e ^ { \delta } . $
# 83  $i \delta { \dot { \cal M } } = [ { \cal H } _ { 0 } , \delta { \cal M } ] $
# 84  $\widehat { q } _ { \perp } \equiv \sqrt { \widehat { q } _ { 1 } ^ { 2 } + \widehat { q } _ { 2 } ^ { 2 } } $
# 85  $J ( T ) = \frac { E _ { 4 } ^ { 3 } ( T ) } { 1 7 2 8 \triangle ( T ) } = 1 + \frac { E _ { 6 } ^ { 2 } ( T ) } { 1 7 2 8 \triangle ( T ) } , ; \; \; \; T \in H $
# 86  $S _ { \mathrm { c l . } } \sim \left( \Delta x \right) ^ { 2 } l \quad , $
# 87  $X _ { n - i + 1 \, i } = \frac { 1 } { q - q ^ { - 1 } } [ X _ { n - i \, i + 1 } , \Phi ( F _ { i } ) ] _ { q } X _ { n - i \, i + 1 } ^ { - 1 } , \; 1 \leq i \leq n - 2 , $
# 88  ${ \cal K } ( A , \bar { A } ) = \alpha { \frac { e ^ { - \varphi ( { \cal G } ( A ) , \overline { { { \cal G } ( A ) } } ) } } { | { \cal G } ^ { 2 } ( A ) - \Lambda ^ { 4 } | } } , $
# 89  $T \sim \frac { m } { L ^ { p } } \sim \frac { 1 } { g \ell _ { s } ^ { p + 1 } } . $
# 90  ${ \bf h _ { \varphi } } = \left( \begin{array} { c c } { e ^ { \varphi / 4 } } & { { \frac { 1 } { 2 } } \, \varphi _ { w } e ^ { - \varphi / 4 } } \\ { 0 } & { e ^ { - \varphi / 4 } } \\ \end{array} \right) , \qquad { \bf \bar { h } _ { \varphi } } = \left( \begin{array} { c c } { e ^ { \varphi / 4 } } & { 0 } \\ { - { \frac { 1 } { 2 } } \, \varphi _ { \bar { w } } e ^ { - \varphi / 4 } } & { e ^ { - \varphi / 4 } } \\ \end{array} \right) . $
# 91  $T r K _ { \bf a } ^ { ( 1 ) } = { \frac { 1 } { 2 } } e ^ { { \frac { 1 6 \pi ^ { 2 } } { { \bf a } ^ { 2 } } } t } \left( 1 - \Phi ( { \frac { 4 \pi } { \bf a } } \sqrt { t } ) \right) ~ ~ , $
# 92  $P ( \ell , \Phi ) = \left[ \ell ^ { 3 } - \frac { \ell ^ { 2 } \, \Phi } { \pi } + \ell \left( \frac { { \Phi } ^ { 2 } } { 2 \, { \pi } ^ { 2 } } - 1 \right) + \frac { 2 \, { \pi } ^ { 2 } \, \Phi - { \Phi } ^ { 3 } } { 8 \, { \pi } ^ { 3 } } \right] , $
# 93  $\tilde { U } _ { N _ { s } N _ { r } } ( \{ \sigma _ { p } \} ) = \int _ { C _ { v _ { r } } } \Psi _ { \sigma , N _ { s } } ( t ) \frac { d \theta d z } { 2 \pi i } P _ { N _ { r } } ( t ) + \int _ { \tilde { C } _ { r } } \Psi _ { \sigma , N _ { s } } ( t ) \frac { d \theta d z } { 2 \pi i } P _ { N _ { r } } ^ { ( a ) } ( t ) $
# ...
# 65  C _ { 0 } = \frac { q ( q ^ { 2 } - B ^ { 2 } / 2 ) - B ^ { 2 } / 2 ( q \gamma ) _ { \perp } } { ( q ^ { 2 } - B ^ { 2 } / 2 ) ^ { 2 } - B ^ { 2 } ( q _ { \perp } ^ { 2 } + B ^ { 2 } / 4 ) } .
# 66  \beta \Omega = - \operatorname { l n } \operatorname { t a n h } ^ { 2 } \epsilon ( p ) \leftrightarrow \operatorname { s i n h } ^ { 2 } \epsilon ( p ) = \frac { 1 } { e ^ { \beta \Omega } - 1 } \, .
# 67  { \cal L } [ \chi , U , U ^ { \dagger } ] \; = \; \frac { 1 } { 2 } \left( \partial _ { \mu } \chi \right) ( \partial ^ { \mu } \chi ) \; + \; \frac { 1 } { 4 } \, T r \left[ \left( \partial _ { \mu } U \right) ( \partial ^ { \mu } U ^ { \dagger } ) \right] \; - \; V ( \chi , U ) \; ,
# 68  T _ { 1 0 } ^ { m \; k } \; = \frac { \Theta } { 4 \ell _ { P } ^ { \prime } } < s _ { K } ^ { a } \; \epsilon ^ { i j k } \epsilon ^ { I J K } \langle W , \xi | \hat { A } _ { a } ^ { m } ( v ) \hat { w } _ { i I \Delta } ( v )
# 69  m _ { L R } = \left( \begIn{array} { c c c } { \lambda ^ { 6 } } & { 0 } & { 0 } \\ { 0 } & { \lambda ^ { n } } & { 0 } \\ { 0 } & { 0 } & { 1 } \\ \end{array} \right) m _ { f } ,
# 70  \operatorname* { l i m } _ { t \rightarrow \infty } B _ { n } ( f _ { n , t } ) \cdots B _ { 1 } ( f _ { 1 , t } ) \, \Omega = \left( \psi _ { n } \times \cdots \times \psi _ { 1 } \right) ^ { \mathrm { o u t } }
# 71  \partial _ { \bar { z } } T _ { 4 } = \lambda \oint { \frac { d \zeta } { 2 \pi i } } \left( \prod _ { i = 1 } ^ { N } \operatorname { c o s } [ \beta _ { i } \phi _ { i } ( \zeta , \bar { z } ) ] \right) T _ { 4 } ( z ) \ .
# 72  \delta { \cal P } _ { 2 i } = - \tilde { G } _ { i } ^ { ( 2 ) } + \partial _ { i } \pi = - \tilde { \gamma } _ { i } ^ { ( 2 ) } ,
# 73  \operatorname { s i n } \left( { \frac { g + k } { 2 } } \right) \operatorname { s i n } \left( { \frac { \tilde { p } _ { 2 } \cdot k } { 2 } } \right) \operatorname { s i n } \left( { \frac { \tilde { p } _ { 3 } \cdot k } { 2 } } \right) = - { \frac { 1 } { 4 } } \left( \operatorname { s i n } \tilde { p } _ { 1 } \cdot k + \operatorname { s i n } \tilde { p } _ { 2 } \cdot k + \operatorname { s i n } \tilde { p } _ { 3 } \cdot k \right)
# 74  \frac { d x ^ { a } } { t c t } = \{ H _ { \mathrm { r e d } } , x ^ { a } \} ^ { \mathrm { r e d } } ,
# 75  a _ { \mathrm { U V } } - a _ { \mathrm { I R } } = - \int _ { \lambda _ { \mathrm { V { 1 } } } } ^ { \lambda _ { \mathrm { R i } } }
# 76  \Gamma _ { \gamma \gamma } ( f _ { 0 } ( 1 7 0 0 ) \} : \Gamma _ { \gamma \gamma } ( f _ { 0 } ( 1 5 0 0 ) ) : \Gamma _ { \gamma \gamma } ( f _ { 0 } ( 1 3 7 0 ) ) = 5 9 . 3 8 8 : 2 7 . 9 0 8 : 1 8 . 5 4 6 .
# 77  m ^ { 2 } ( \beta ) = m _ { 0 } ^ { 2 } + \lambda _ { 0 } F ( D ) \left( m ( \beta ) \right) ^ { D - 2 } \int _ { m ( \beta ) \beta } ^ { \infty } d \tau \left( ( \frac { \tau } { m ( \beta ) \beta } ) ^ { 2 } - 1 \right) ^ { \frac { - p - 2 } { 2 } } \frac { 1 } { e ^ { - } - 1 } .
# 78  G [ u ] _ { n _ { 1 } n _ { 2 } } ^ { - 1 } = { \frac { \delta } { \delta \Psi ( n _ { 1 } ) } } { \frac { \delta } { \delta { \bar { \Psi } } ( n _ { 2 } ) } } S _ { f } ^ { \alpha p } [ \Psi ] .
# 79  \delta _ { i } \simeq { \frac { I m [ \mu _ { 1 } \mu _ { 2 } ^ { * } \sum _ { k , l } f _ { 1 k l } f _ { 2 k } ^ { * } | } { 8 \pi ^ { 2 } ( M _ { 1 } ^ { 2 } - M _ { 2 } ^ { 2 } ) } } { \frac { M _ { i } } { \Gamma _ { i } } } ,
# 80  \langle f _ { Q ^ { \ast } } ( s , b , Q ^ { 2 } ) \rangle = [ \tilde { N } ( s , b ) + ( N - 1 ) ] \, V _ { Q ^ { * } } ( b , Q ^ { 2 } ) .
# 81  ( p _ { R } - p _ { R } ^ { \mathrm { t h o e } } ) ^ { 2 } = p _ { R } ^ { 2 } - \{ p _ { R } , p _ { R } ^ { \mathrm { t h e h } } \} + ( p _ { R } ^ { \mathrm { t u b e } } ) ^ { 2 } \ .
# 82  R ^ { \alpha } { } _ { \beta } = { \frac { 1 } { 4 } } \left( 2 f ^ { \alpha } { } _ { \beta i } f ^ { i } { } _ { \gamma \delta } + f ^ { \alpha } { } _ { \beta \epsilon } f ^ { \epsilon } { } _ { \gamma \delta } - f ^ { \alpha } { } _ { \gamma \epsilon } f ^ { e } { } _ { \beta \delta } \right) e ^ { \gamma } \wedge e ^ { \delta } .
# 83  i \delta { \cal M } = [ { \cal H } _ { 0 } , \delta { \cal M } ]
# 84  \widehat { q } _ { \perp } \equiv \sqrt { \widetilde { q } _ { 1 } ^ { 2 } + \widehat { q } _ { 2 } ^ { 2 } }
# 85  J ( T ) = \frac { E _ { 4 } ^ { 3 } ( T ) } { 1 7 2 8 \Delta ( T ) } = 1 + \frac { E _ { 6 } ^ { 2 } ( T ) } { 1 7 2 8 \Delta ( T ) } ; \, ; \quad T \in H
# 86  S _ { \mathrm { c l . } } \sim ( \Delta x ) ^ { 2 } \, l \quad ,
# 87  X _ { n - i + 1 \, i } = \frac { 1 } { q - q ^ { - 1 } } [ X _ { n - i i + 1 } , \Phi ( F _ { i } ) ] _ { q } X _ { n - i + i 1 } ^ { - 1 } , \; 1 \leq i \leq n - 2 ,
# 88  { \cal K } ( A , \bar { A } ) = \alpha \frac { e ^ { - \varphi ( { \cal G } ( A ) , \overline { { { \cal A } ( M ) } } ) } } { | { \cal G } ^ { 2 } ( A ) - \Lambda ^ { 4 } | } ,
# 89  T \sim \sim \frac { m } { L ^ { p } } \sim \frac { 1 } { g ^ { \phi _ { f } ^ { p + 1 } } } .
# 90  \mathbf { l } _ { \varphi } = \left( \begIn{array} { c c } { e ^ { \varphi / 4 } } & { \frac { 1 } { 2 } \; \varphi _ { w } e ^ { - \varphi / 4 } } \\ { 0 } & { e ^ { - \varphi / 4 } } \\ \end{array} \right) , \qquad \bar { \mathbf { k } } _ { \varphi } = \left( \begIn{array} { c c } { e ^ { \varphi / 4 } } & { \mathrm { a } } \\ { - \frac { 1 } { 2 } \, \varphi _ { w } e ^ { - \varphi / 4 } } & { e ^ { - \varphi / 4 } } \\ \end{array} \right) .
# 91  T r K _ { \bf a } ^ { ( 1 ) } = \frac { 1 } { 2 } e ^ { \frac { 1 6 \pi ^ { 2 } } { 4 ^ { 2 } } } \left( 1 - \Phi ( \frac { 4 \pi } { \bf \bf q } \sqrt { t } ) \right) \; \; ,
# 92  P ( \ell , \Phi ) = \left[ \ell ^ { 3 } - \frac { \ell ^ { 2 } \Phi } { \pi } + \ell \left( \frac { \Phi ^ { 2 } } { 2 \, \pi ^ { 2 } } - 1 \right) + \frac { 2 \, \pi ^ { 2 } \, \Phi - \Phi ^ { 3 } } { 8 \, \pi ^ { 3 } } \right] ,
# 93  \widetilde { U } _ { N _ { s } , N } \{ \{ \sigma _ { p } \} ) = \int _ { C _ { r } } \Psi _ { \sigma , N _ { s } } ( t ) \frac { d \theta d z } { 2 \pi i } P _ { N _ { r } } ( t ) + \int _ { \tilde { C } _ { \tau } } \Psi _ { \sigma , N _ { s } } ( t ) \frac { d \theta d z } { 2 \pi i } P _ { N _ { r } } ^ { ( a ) } ( t )
# 94  \operatorname { s i n } ^ { 2 } 2 \theta = \frac { 4 } { \sqrt { 1 + \Delta \frac { m ^ { 2 } } { m } } } \left( 1 - \frac { 1 } { \sqrt { 1 + \frac { \Delta m ^ { 2 } } { m ^ { 2 } } } } \right)
# 95  D ( x ) = \frac { \Gamma ( N / 2 - 1 ) } { 4 \pi ^ { \frac { N } { 2 } } } \frac { k } { ( x ^ { 2 } - i \varepsilon ) ^ { N / 2 - 1 } } .
# 96  g _ { 3 } ^ { 2 } = T g ^ { 2 } ( \overline { { \mu } } ) \biggl [ 1 + \frac { g ^ { 2 } ( \overline { { \mu } } ) } { 4 8 \pi ^ { 2 } } \biggl ( ( 2 2 N - N _ { s } ) \frac { L _ { b } } { 2 } - N _ { f } L _ { f } + N \biggr ) ] .
# 97  a _ { i } : = \mathrm { d i m } ( J + \omega _ { i } ) = { \frac { ( k + 1 ) \ldots ( | { \overline { k } } + i ) \ldots ( k + N ) } { ( i - 1 ) ! \, ( N - i ) ! } } \ .
# 98  S _ { D } = \frac { 1 } { D - 1 } \sum _ { i \neq j } S ( M _ { i } , M _ { j } )
# 99  u ( p ) = \frac { P ^ { 2 } p - ( P . p ) P } { P ^ { 2 } p ^ { 2 } - ( P ; p ) ^ { 2 } } \quad , \quad v ( p ) = \frac { P \times p } { P ^ { 2 } p ^ { 2 } - ( P , p ) ^ { 2 } } .
