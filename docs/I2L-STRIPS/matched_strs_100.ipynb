# %%
from IPython.core.display import display, Latex, Pretty, Math, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
import sys
import pandas as pd
sys.path.extend(['../src/commons'])
import pub_commons as pub
# %matplotlib inline
# Out:
# <style>.container { width:90% !important; }</style>

# %%
pub.disp_matched_strs2('I2L-STRIPS')
# Out:
#     edit_distance  $\mathbf{y}$_len  \
# 0   0.054422       147
# 1   0.020000       150
# 2   0.000000       150
# 3   0.068966       145
# 4   0.000000       147
# 5   0.000000       147
# 6   0.043165       139
# 7   0.006944       144
# 8   0.020548       146
# 9   0.080537       149
# 10  0.027211       147
# 11  0.107692       130
# 12  0.040268       149
# 13  0.056738       141
# 14  0.048951       143
# 15  0.075188       133
# 16  0.107914       139
# 17  0.006993       143
# 18  0.000000       142
# 19  0.020979       143
# 20  0.000000       142
# 21  0.000000       141
# 22  0.048276       145
# 23  0.113333       150
# 24  0.000000       140
# 25  0.000000       140
# 26  0.042857       140
# 27  0.043165       139
# 28  0.042857       140
# 29  0.000000       138
# 30  0.057971       138
# 31  0.007246       138
# 32  0.157895       133
# 33  0.000000       138
# 34  0.000000       137
# 35  0.045802       131
# 36  0.000000       136
# 37  0.000000       136
# 38  0.037037       135
# 39  0.077465       142
# 40  0.000000       136
# 41  0.028777       139
# 42  0.000000       135
# 43  0.029630       135
# 44  0.014925       134
# 45  0.000000       134
# 46  0.000000       134
# 47  0.000000       134
# 48  0.000000       133
# 49  0.031008       129
# 50  0.000000       133
# 51  0.000000       133
# 52  0.000000       133
# 53  0.022222       135
# 54  0.000000       133
# 55  0.015152       132
# 56  0.043478       138
# 57  0.000000       132
# 58  0.057143       140
# 59  0.000000       132
# 60  0.030769       130
# 61  0.015267       131
# 62  0.140625       128
# 63  0.057554       139
# 64  0.097561       123
# 65  0.044118       136
# 66  0.000000       131
# 67  0.043796       137
# 68  0.097222       144
# 69  0.007634       131
# 70  0.000000       131
# 71  0.031496       127
# 72  0.100840       119
# 73  0.000000       131
# 74  0.058824       136
# 75  0.000000       130
# 76  0.000000       130
# 77  0.000000       130
# 78  0.023622       127
# 79  0.000000       130
# 80  0.105263       133
# 81  0.102564       117
# 82  0.000000       129
# 83  0.015267       131
# 84  0.031008       129
# 85  0.007752       129
# 86  0.000000       128
# 87  0.000000       128
# 88  0.000000       128
# 89  0.023438       128
# 90  0.000000       128
# 91  0.049180       122
# 92  0.031008       129
# 93  0.053846       130
# 94  0.000000       127
# 95  0.024000       125
# 96  0.086331       139
# 97  0.086331       139
# 98  0.015504       129
# 99  0.000000       127
#
#    $\mathbf{y}$                                                                                                                                                                                                                                                                                                                                                                                                                                                             \
# 0   $T _ { + 2 - 2 } ^ { + q } = \frac 1 2 \gamma _ { q \dot { p } } ^ { i } \left( \Omega _ { + 2 } ^ { + 2 i } \psi _ { - 2 \dot { p } } ^ { 1 - } - \Omega _ { - 2 } ^ { + 2 i } \psi _ { + 2 \dot { p } } ^ { 1 - } \right) , \ T _ { + p \pm 2 } ^ { + q } = \frac 1 2 \gamma _ { q \dot { p } } ^ { i } \Omega _ { + p } ^ { + 2 i } \psi _ { \pm 2 \dot { p } } ^ { 1 - } , $
# 1   $\sigma _ { i j } ( x ^ { - } , y ^ { - } ; x ^ { + } ) = \int \! \frac { d P ^ { - } } { 4 \pi } \frac { d p ^ { + } } { 4 \pi } \frac { d k ^ { + } } { 4 \pi } e ^ { - \frac { i } { 2 } P ^ { - } x ^ { + } } e ^ { - \frac { i } { 2 } ( p ^ { + } x ^ { -- } k ^ { + } y ^ { - } ) } ~ \sigma _ { i j } ( p ^ { + } , k ^ { + } ; P ^ { - } ) , $
# 2   $G ( f ) _ { \beta } ^ { ( n ) } = \Sigma _ { m = 0 } ^ { n } \{ \tilde { \Theta } _ { \beta } ^ { ( n - m ) } , \tilde { f } ^ { ( m ) } \} _ { ( q ) } + \Sigma _ { m = 0 } ^ { ( n - 2 ) } \{ \tilde { \Theta } _ { \beta } ^ { ( n - m ) } , \tilde { f } ^ { ( m + 2 ) } \} _ { ( \phi ) } + \{ \tilde { \Theta } _ { \beta } ^ { ( n + 1 ) } , \tilde { f } ^ { ( 1 ) } \} _ { ( \phi ) } $
# 3   $S _ { 0 } = \sum _ { l } \frac { 1 } { 2 \Delta _ { l } ^ { 2 } } \mathrm { T r } \, \phi _ { l } ^ { a } \phi _ { - l } ^ { a } + \sum _ { l } \frac { 1 } { 2 \epsilon _ { l } ^ { 2 } } \mathrm { T r } \, f _ { l } ^ { a } f _ { - l } ^ { a } + \sum _ { r } \frac { 1 } { g _ { r } } \mathrm { T r } \, \bar { \psi } _ { r } ^ { a } \psi _ { r } ^ { a } \, . $
# 4   $d s ^ { 2 } = - \frac { t ^ { 2 } } { ( t ^ { 2 } + r _ { - } ^ { 2 } ) ( t ^ { 2 } - r _ { + } ^ { 2 } ) } d t ^ { 2 } + t ^ { 2 } ( d \phi + \frac { r _ { + } r _ { - } } { t ^ { 2 } } d r ) ^ { 2 } + \frac { ( t ^ { 2 } + r _ { - } ^ { 2 } ) ( t ^ { 2 } - r _ { + } ^ { 2 } ) } { t ^ { 2 } } d r ^ { 2 } . $
# 5   $H = \frac { 1 } { 2 E } U \left( \begin{array} { c c c } { 0 } & { 0 } & { 0 } \\ { 0 } & { \Delta m _ { 2 1 } ^ { 2 } } & { 0 } \\ { 0 } & { 0 } & { \Delta m _ { 3 1 } ^ { 2 } } \\ \end{array} \right) U ^ { \dagger } + \frac { 1 } { 2 E } \left( \begin{array} { c c c } { a } & { \eta b } & { 0 } \\ { \eta ^ { * } b } & { \eta ^ { \prime } b } & { 0 } \\ { 0 } & { 0 } & { 0 } \\ \end{array} \right) , $
# 6   $D _ { \mu \nu } ^ { a b } ( p , p _ { 3 } ) = \frac { \delta ^ { a b } \delta ^ { a 3 } } { p ^ { 2 } - p _ { 3 } ^ { 2 } + i \epsilon } \left[ - g _ { \mu \nu } + p _ { \mu } p _ { \nu } \left( ( 1 - \delta _ { p _ { 3 } , 0 } ) \frac { 1 } { p _ { 3 } ^ { 2 } } + \delta _ { p _ { 3 } , 0 } ( 1 - \xi ) \frac { 1 } { p ^ { 2 } + i \epsilon } \right) \right] $
# 7   $V ( H _ { 1 } , H _ { 2 } ) = \frac { 1 } { 8 } ( g _ { 2 } ^ { 2 } + g _ { 1 } ^ { 2 } ) \left( | H _ { 1 } | ^ { 2 } - | H _ { 2 } | ^ { 2 } \right) ^ { 2 } + m _ { 1 } ^ { 2 } | H _ { 1 } | ^ { 2 } + m _ { 2 } ^ { 2 } | H _ { 2 } | ^ { 2 } - m _ { 3 } ^ { 2 } ( H _ { 1 } H _ { 2 } + \mathrm { h . c . } ) $
# 8   $A _ { 0 } ^ { 3 } ( \alpha ^ { \prime } \rightarrow 0 ) = 2 g _ { d } \, \, \varepsilon _ { \lambda } ^ { ( 1 ) } \varepsilon _ { \mu } ^ { ( 2 ) } \varepsilon _ { \nu } ^ { ( 3 ) } \left\{ \eta ^ { \lambda \mu } \left( p _ { 1 } ^ { \nu } - p _ { 2 } ^ { \nu } \right) + \eta ^ { \lambda \nu } \left( p _ { 3 } ^ { \mu } - p _ { 1 } ^ { \mu } \right) + \eta ^ { \mu \nu } \left( p _ { 2 } ^ { \lambda } - p _ { 3 } ^ { \lambda } \right) \right\} . $
# 9   $U _ { L } ^ { \dagger } M _ { l } U _ { R } ^ { l } = M _ { l } ^ { * } ~ , ~ U _ { L } ^ { \dagger } M _ { L } U _ { L } ^ { * } = M _ { L } ^ { * } ~ , ~ U _ { L } ^ { \dagger } M _ { D } U _ { R } ^ { \nu } = M _ { D } ^ { * } ~ , ~ { U _ { R } ^ { \nu } } ^ { T } M _ { R } U _ { R } ^ { \nu } = M _ { R } ^ { * } ~ . $
# 10  $\sqrt { - g } g ^ { \mu _ { 1 } \nu _ { 1 } } g ^ { \mu _ { 2 } \nu _ { 2 } } \cdots g ^ { \mu _ { d - p } \nu _ { d - p } } { \tilde { F } } _ { \nu _ { 1 } \nu _ { 2 } \ldots \nu _ { d - p } } = \frac { 1 } { p ! } \epsilon ^ { \mu _ { 1 } \mu _ { 2 } \ldots \mu _ { d - p } \nu _ { 1 } \nu _ { 2 } \ldots \nu _ { p } } F _ { \nu _ { 1 } \nu _ { 2 } \ldots \nu _ { p } } , $
# 11  $\frac { d E } { d z } = \frac { d E _ { e l } } { d z } + \frac { d E _ { r a d } } { d z } \approx \frac { C _ { 2 } \alpha _ { s } } { \pi } \mu ^ { 2 } \operatorname { l n } \frac { 3 E T } { 2 \mu ^ { 2 } } \left( \operatorname { l n } \frac { 9 E } { \pi ^ { 3 } T } + \frac { 3 \pi ^ { 2 } \alpha _ { s } } { 2 \mu ^ { 2 } } T ^ { 2 } \right) . $
# 12  $L _ { 0 } = ( 2 n + 1 ) { \frac { | h | } { 2 } } + | h | d _ { 0 } ^ { \dagger } d _ { 0 } - { \frac { | h | } { 2 } } - | h | \sum _ { k = 1 } ^ { \infty } \left( d _ { k } ^ { \dagger } d _ { k } - \tilde { d } _ { k } ^ { \dagger } \tilde { d } _ { k } + a _ { k } ^ { \dagger } a _ { k } - b _ { k } ^ { \dagger } b _ { k } \right) + L _ { 0 } ^ { f r e e } . $
# 13  $Q _ { 7 \gamma } = \frac { e } { 8 \pi ^ { 2 } } m _ { b } \bar { q } _ { \alpha } \sigma ^ { \mu \nu } ( 1 + \gamma _ { 5 } ) b _ { \alpha } F _ { \mu \nu } , ~ ~ Q _ { 8 G } = \frac { g } { 8 \pi ^ { 2 } } m _ { b } \bar { q } _ { \alpha } \sigma ^ { \mu \nu } t _ { \alpha \beta } ^ { a } b _ { \beta } G _ { \mu \nu } ^ { a } , ~ ~ ( q = d ~ \mathrm { o r } ~ s ) . $
# 14  $d s ^ { 2 } ~ = ~ \alpha ^ { \prime } \left( \frac { u ^ { 2 } h ( u ) } { R ^ { 2 } } ~ e ^ { \gamma A } d x _ { 0 } ^ { 2 } + \frac { u ^ { 2 } } { R ^ { 2 } } ~ e ^ { \gamma C } d x _ { i } ^ { 2 } + \frac { R ^ { 2 } } { u ^ { 2 } h ( u ) } ~ e ^ { \gamma B } d u ^ { 2 } + R ^ { 2 } ~ e ^ { \gamma D } d \Omega _ { 5 } ^ { 2 } \right) ~ , $
# 15  $\operatorname { s i n } \left( \frac { \tilde { p } _ { 1 } \cdot k } { 2 } \right) \operatorname { s i n } \left( \frac { \tilde { p } _ { 2 } \cdot k } { 2 } \right) \operatorname { s i n } \left( \frac { \tilde { p } _ { 3 } \cdot k } { 2 } \right) = - \frac { 1 } { 4 } \left( \operatorname { s i n } \tilde { p } _ { 1 } \cdot k + \operatorname { s i n } \tilde { p } _ { 2 } \cdot k + \operatorname { s i n } \tilde { p } _ { 3 } \cdot k \right) $
# 16  $[ { \cal P } _ { 0 } , X _ { 0 } ] = i , \quad [ { \cal P } _ { i } , X _ { j } ] = - i \, \delta _ { i j } \left( 1 - \frac { \vec { { \cal P } } \, { } ^ { 2 } } { \kappa ^ { 2 } } \right) \, e ^ { { \cal P } _ { 0 } / \kappa } , \quad [ { \cal P } _ { 0 } , X _ { i } ] = - \frac { 2 i } \kappa \, { \cal P } _ { i } \, e ^ { { \cal P } _ { 0 } / \kappa } $
# 17  $\langle J _ { \mu _ { 1 } } ^ { a _ { 1 } } ( P _ { 1 } ) \ldots J _ { \mu _ { n } } ^ { a _ { n } } ( P _ { n } ) \rangle _ { T } \approx ( - i ) ^ { n } \frac { N T ^ { 2 } } { 1 2 } \delta \Gamma _ { \mu _ { 1 } \ldots \mu _ { n } } ^ { a _ { 1 } \ldots a _ { n } } ( P _ { 1 } , \ldots , P _ { n } ) + O ( \frac { 1 } { f _ { \pi } ^ { 2 } } ) \ , $
# 18  $\tilde { u } _ { \pi } ( \vec { k } _ { 1 } ^ { \prime } ) ^ { \dagger } \tilde { u } _ { \pi } ( \vec { k } _ { 1 } ) = N _ { \pi } ^ { 2 } \left[ c o s ^ { 2 } \chi ( \vec { k } ) - \frac { | \vec { p } | ^ { 2 } } { 4 } \left( c o s \chi ( \vec { k } ) c _ { 2 } ( \vec { k } ) + \frac { 1 } { 3 } \vec { k } ^ { 2 } b _ { 1 } ( \vec { k } ) ^ { 2 } \right) \right] . $
# 19  $\tau _ { 0 } ( y ) = \sum _ { \sigma _ { 1 } = 0 } ^ { 1 } . . \sum _ { \sigma _ { 4 } = 0 } ^ { 1 } Y _ { \sigma _ { 1 } . . \sigma _ { 4 } } ^ { ( 0 ) } ( t _ { 1 } Z _ { 1 } ) ^ { \sigma _ { 1 } } ( t _ { 2 } Z _ { 2 } ) ^ { \sigma _ { 2 } } ( t _ { 5 } Z _ { 5 } ) ^ { \sigma _ { 3 } } ( t _ { 8 } Z _ { 8 } ) ^ { \sigma _ { 4 } } $
# 20  $\frac { \operatorname { s i n } ( 2 \beta ) } { 3 2 \, \pi ^ { 2 } } \, I ( \tilde { \Omega } ) \rightarrow \frac { \operatorname { s i n } ( 2 \beta ) } { 3 2 \, \pi ^ { 2 } } ( I ( \tilde { \Omega } ) + c _ { 2 } ^ { 2 } c _ { 3 } ^ { 2 } \delta _ { 1 } I ( M _ { G } , M _ { G 1 } ) + c _ { 2 } ^ { 2 } s _ { 3 } ^ { 2 } \delta _ { 2 } I ( M _ { G } , M _ { G 2 } ) ) $
# 21  ${ \cal W } = Y _ { e } L ^ { j } E ^ { c } H _ { 1 } ^ { i } { \epsilon _ { i j } } + Y _ { d } Q ^ { j a } D _ { a } ^ { c } H _ { 1 } ^ { i } { \epsilon _ { i j } } + Y _ { u } Q ^ { j a } U _ { a } ^ { c } H _ { 2 } ^ { i } { \epsilon _ { i j } } + \mu H _ { 1 } ^ { i } H _ { 2 } ^ { j } { \epsilon _ { i j } } $
# 22  $- i \bar { \kappa } _ { ( \alpha ) } \gamma ^ { \mu } \kappa _ { ( \beta ) } \partial _ { \mu } = - i \tilde { \mathcal { C } } _ { \alpha \gamma } \Gamma _ { s } ( T ^ { I } ) ^ { \gamma } { } _ { \beta } \Gamma _ { \mathrm { A d j } } ( u ^ { - 1 } ) ^ { a } { } _ { I } e _ { a } = - i \tilde { \mathcal { C } } _ { \alpha \gamma } \Gamma _ { s } ( T ^ { I } ) ^ { \gamma } { } _ { \beta } k _ { ( I ) } \, , $
# 23  ${ \cal L } _ { \mathrm { e f f } } = \sum _ { i , j } { \frac { 1 } { 2 } } K _ { \phi _ { i } , { \bar { \phi } } _ { j } } \nabla \phi _ { i } \cdot \nabla { \bar { \phi } } _ { j } - \mathrm { e } ^ { K } \left[ \ \sum _ { i , j } K ^ { \phi _ { i } \ { \bar { \phi } } _ { j } } ( D _ { \phi _ { i } } W ) ( D _ { { \bar { \phi } } _ { j } } W ) ^ { \dag } - 3 | W | ^ { 2 } \ \right] $
# 24  $T ^ { ( l ) } = \int \frac { d ^ { 4 } p _ { n } } { ( 2 \pi ) ^ { 4 } } \; \overline { { u } } _ { Y } ( p _ { Y } ^ { \prime } ) \left\{ \left( \sum _ { j = 1 } ^ { 6 } { \cal A } _ { j } { \cal M } _ { j } \right) S ( p _ { p } ) \Gamma _ { d } C S ( p _ { n } ) T _ { Y N } S ( p _ { Y } ) \right\} \overline { { u } } ( p _ { N } ^ { \prime } ) \; . $
# 25  $\sigma _ { q \bar { q } } ^ { ( \pi ^ { 2 } ) } ( s , m ^ { 2 } ) = \sigma _ { q \bar { q } } ^ { ( 0 ) } ( s , m ^ { 2 } ) \left[ \frac { \pi \alpha _ { s } ( \mu ^ { 2 } ) } { 2 \beta } \left( C _ { F } - \frac { C _ { A } } { 2 } \right) + \frac { \alpha _ { s } ( \mu ^ { 2 } ) } { \pi } C _ { F } \left( \frac { 9 } { 2 } + \frac { \pi ^ { 2 } } { 3 } \right) \right] . $
# 26  $2 1 \frac { d \bar { x } _ { 2 } } { d t } + \left( 2 \beta _ { 0 } \bar { x } _ { 0 } ( t ) \right) \bar { x } _ { 2 } = - \beta _ { 2 } \bar { x } _ { 0 } ^ { 4 } ( t ) - 3 \beta _ { 1 } \bar { x } _ { 0 } ^ { 2 } ( t ) \bar { x } _ { 1 } ( t ) - \beta _ { 0 } \bar { x } _ { 1 } ^ { 2 } ( t ) , \; \; \; \bar { x } _ { 2 } ( 0 ) = 0 , $
# 27  $G _ { \mu \nu } ^ { a b } ( p ) = \frac { - i \delta ^ { a b } } { ( 2 \pi ) ^ { 2 \omega } ( p ^ { 2 } + i \epsilon ) } \Big [ g _ { \mu \nu } - \frac { p _ { \mu } n _ { \nu } + p _ { \nu } n _ { \mu } } { p \cdot n } + \frac { n ^ { 2 } p _ { \mu } p _ { \nu } } { ( p \cdot n ) ^ { 2 } } \Big ] , \ \ n ^ { 2 } > 0 , \, e p s i l o n > 0 , $
# 28  $\tilde { S } = \int d ^ { 2 } { x } \left\{ g ^ { 2 } ( 1 + \varphi _ { 1 } ^ { 2 } ) ^ { 2 } ( \partial \tilde { \varphi _ { 0 } } ) ^ { 2 } + 8 \theta g ^ { 2 } \partial _ { a } \tilde { \varphi _ { 0 } } \partial ^ { a } \varphi _ { 1 } + \frac { ( 1 + 1 6 \theta ^ { 2 } g ^ { 4 } ) } { g ^ { 2 } ( 1 + \varphi _ { 1 } ^ { 2 } ) ^ { 2 } } ( \partial \varphi _ { 1 } ) ^ { 2 } \right\} $
# 29  $p _ { 1 } ^ { 2 } p _ { 2 } ^ { 2 } - ( p _ { 1 } \cdot p _ { 2 } ) ^ { 2 } = - \frac { 1 } { 4 } ( p _ { 1 } ^ { 4 } + p _ { 2 } ^ { 4 } + p _ { 5 } ^ { 4 } - 2 p _ { 1 } ^ { 2 } p _ { 2 } ^ { 2 } - 2 p _ { 1 } ^ { 2 } p _ { 5 } ^ { 2 } - 2 p _ { 2 } ^ { 2 } p _ { 5 } ^ { 2 } ) = 0 $
# 30  $g _ { i j , k l } = \frac { - q ^ { - 1 } } { \left[ 2 \right] } D _ { s i } \hat { R } _ { j s , k l } ^ { \epsilon } = \frac { - q ^ { - 1 } } { \left[ 2 \right] } \epsilon _ { i m } \hat { R } _ { j m , k t } \epsilon _ { l t } ^ { - 1 } \quad , \quad ( g = \frac { - q ^ { - 1 } } { \left[ 2 \right] } D _ { 1 } { \cal P } \hat { R } _ { 1 2 } ^ { \epsilon } ) \quad , $
# 31  ${ \cal H } ^ { T } = \frac { 4 G _ { F } } { \sqrt { 2 } } V _ { u b } V _ { u q } ^ { * } \sum _ { i = 1 } ^ { 2 } c _ { i } ( \mu ) O _ { i } ^ { ( u ) } , \qquad { \cal H } ^ { P } = - \frac { 4 G _ { F } } { \sqrt { 2 } } V _ { t b } V _ { t q } ^ { * } \sum _ { i = 3 } ^ { 6 } c _ { i } ( \mu ) O _ { i } , $
# 32  ${ \cal L } _ { N } ( S ) = \frac { G _ { F } } { \sqrt 2 } ~ \frac { m _ { W } ^ { 2 } } { m _ { S } ^ { 2 } } ~ \bar { e } \left[ ~ \kappa _ { \mu e } ~ \left( 1 + \gamma _ { 5 } \right) ~ + ~ ~ \kappa _ { \mu e } ^ { \prime } ~ \left( 1 - \gamma _ { 5 } \right) \right] ~ \mu ~ \frac { \tilde { m } _ { N } } { m _ { W } } ~ \bar { \Psi } _ { N } \Psi _ { N } \ , $
# 33  $\bar { a } _ { i } ^ { b } e _ { b } ^ { \mu } D _ { \mu L } | a \rangle = 0 \, , \quad ( a _ { i } ^ { b } \bar { a } _ { i } ^ { b } - h _ { i } ) | a \rangle = 0 \, , \quad \bar { a } _ { i } ^ { b } \bar { a } _ { i } ^ { b } | a \rangle = 0 \, , \quad \varepsilon ^ { i j } a _ { i } ^ { b } \bar { a } _ { j } ^ { b } | a \rangle = 0 \, , $
# 34  $\frac { 1 } { \rho } \frac { d } { d \rho } \left( \rho \frac { d \psi _ { 4 } } { d \rho } \right) - \frac { a _ { + } ^ { 2 } } { \rho ^ { 2 } } \psi _ { 4 } - g _ { 1 } \eta ^ { 2 } \psi _ { 4 } ( \psi _ { 4 } ^ { 2 } + \psi _ { 6 } ^ { 2 } - 1 ) - g _ { 2 } \eta ^ { 2 } \psi _ { 4 } ( \psi _ { 4 } ^ { 2 } - \psi _ { 6 } ^ { 2 } - c ) = 0 , $
# 35  $A = \frac { i } { 2 } \{ \frac { 1 } { 2 } d \operatorname { l n } ( \frac { d \overline { { g } } _ { 2 } } { d \overline { { z } } _ { 2 } } \frac { d z _ { 2 } } { d g _ { 2 } } ) + \frac { ( g _ { 2 } d \overline { { g } } _ { 2 } - \overline { { g } } _ { 2 } d g _ { 2 } ) } { ( 1 - g _ { 2 } \overline { { g } } _ { 2 } ) } \} , $
# 36  $W = Y _ { a b } ^ { e } \hat { L } _ { a } \hat { H } _ { 1 } \hat { E } _ { b } ^ { c } + Y _ { a b } ^ { d } \hat { Q } _ { a } \hat { H } _ { 1 } \hat { D } _ { b } ^ { c } + Y _ { a b } ^ { u } \hat { Q } _ { a } \hat { H } _ { 2 } \hat { U } _ { b } ^ { c } - \mu \hat { H } _ { 1 } \hat { H } _ { 2 } $
# 37  $< p ^ { \prime } | J _ { \mu } ^ { A } | p ^ { \prime } > = \overline { \psi } _ { p ^ { \prime } } \left[ g _ { 1 } ^ { \prime } ( k ^ { 2 } ) \gamma _ { \mu } \gamma _ { 5 } + g _ { 2 } ^ { \prime } ( k ^ { 2 } ) i \sigma _ { \mu \nu } \gamma _ { 5 } k ^ { \nu } + g _ { 3 } ^ { \prime } ( k ^ { 2 } ) i \gamma _ { 5 } k _ { \mu } \right] \psi _ { p ^ { \prime } } . $
# 38  ${ \cal H } _ { \mathrm { e f f } } \; = \; \frac { G _ { \mathrm { F } } } { \sqrt { 2 } } \left[ ( V _ { c b } V _ { c d } ^ { * } ) \sum _ { i = 1 } ^ { 2 } ( c _ { i } Q _ { i } ^ { c } ) - ( V _ { t b } V _ { t d } ^ { * } ) \sum _ { i = 3 } ^ { 1 0 } ( c _ { i } Q _ { i } ) \right] ~ + ~ \mathrm { h . c . } \; , $
# 39  $G _ { 0 } = \frac { 1 } { 4 \pi ^ { 2 } x ^ { 2 } } \, \rightarrow \, \frac { \Gamma ( \frac { d } { 2 } ) } { ( d - 2 ) 2 \pi ^ { \frac { d } { 2 } } } \, \biggl ( \frac { 1 } { x ^ { 2 } } \biggr ) ^ { ( \frac { d } { 2 } - 1 ) } = \frac { 1 } { 4 \pi ^ { 2 } } \, \frac { \Gamma ( 1 + \epsilon ) } { \pi ^ { \epsilon } } \, \biggl ( \frac { 1 } { x ^ { 2 } } \biggr ) ^ { ( 1 + \epsilon ) } $
# 40  $\langle p _ { A } ^ { \prime } k _ { 1 } \rangle \langle k _ { 2 } p _ { B } \rangle \langle p _ { B } ^ { \prime } p _ { A } \rangle = \langle p _ { A } k _ { 1 } \rangle \langle k _ { 2 } p _ { B } ^ { \prime } \rangle \langle p _ { B } p _ { A } ^ { \prime } \rangle = \langle p _ { A } ^ { \prime } k _ { 1 } \rangle \langle k _ { 2 } p _ { B } ^ { \prime } \rangle \langle p _ { B } p _ { A } \rangle \, , $
# 41  ${ \frac { \omega ^ { 2 } ( \omega ^ { 2 } - k _ { z } ^ { 2 } - m ^ { 2 } ) ^ { 2 } } { ( \omega ^ { 2 } - k _ { z } ^ { 2 } ) ^ { 2 } } } - k _ { T } ^ { 2 } - { \frac { k _ { z } ^ { 2 } ( \omega ^ { 2 } - k _ { z } ^ { 2 } - m ^ { 2 } ) ^ { 2 } } { ( \omega ^ { 2 } - k _ { z } ^ { 2 } ) ^ { 2 } } } = 0 \; , $
# 42  $\langle \vec { x } = 0 | j _ { 0 } ( \vec { x } ) | \vec { x } = 0 \rangle \equiv \tilde { \varphi } _ { 2 } ^ { \ast } \tilde { \varphi } _ { 1 } \rho ( \vec { x } ) = \tilde { \varphi } _ { 2 } ^ { \ast } \tilde { \varphi } _ { 1 } \int \frac { d ^ { 3 } \vec { \Delta } } { ( 2 \pi ) ^ { 3 } } \mathrm { e } ^ { - i \vec { \Delta } \cdot \vec { x } } G _ { E } ( - \vec { \Delta } ^ { 2 } ) \, , $
# 43  $\tilde { U } _ { N _ { s } N _ { r } } ( \{ \sigma _ { p } \} ) = \int _ { C _ { v _ { r } } } \Psi _ { \sigma , N _ { s } } ( t ) \frac { d \theta d z } { 2 \pi i } P _ { N _ { r } } ( t ) + \int _ { \tilde { C } _ { r } } \Psi _ { \sigma , N _ { s } } ( t ) \frac { d \theta d z } { 2 \pi i } P _ { N _ { r } } ^ { ( a ) } ( t ) $
# 44  $U _ { q } ( \tau ) = e ^ { - { \frac { \tau } { 2 \omega } } \; { \frac { \vartheta _ { 2 } ^ { \prime } } { \vartheta _ { 2 } } } ( { \frac { i \alpha } { 2 \omega } } ) } \; { \frac { \vartheta _ { 3 } ( 0 ) \; \vartheta _ { 4 } ( { \frac { i \alpha + \tau } { 2 \omega } } ) } { \vartheta _ { 4 } ( { \frac { i \alpha } { 2 \omega } } ) \; \vartheta _ { 3 } ( { \frac { \tau } { 2 \omega } } ) } } \; . $
# 45  $W ^ { \mathrm { e f f } } = h _ { \alpha \beta H _ { 2 } } ^ { U } \bar { U } ^ { \alpha } H _ { 2 } Q ^ { \beta } + h _ { \alpha \beta H _ { 1 } } ^ { D } \bar { D } ^ { \alpha } H _ { 1 } Q ^ { \beta } + h _ { \alpha \beta H _ { 1 } } ^ { E } \bar { E } ^ { \alpha } H _ { 1 } L ^ { \beta } + \lambda S H _ { 1 } H _ { 2 } + k S g \bar { g } , $
# 46  $\sigma = \frac { \pi \alpha ^ { 2 } \beta ^ { 3 } } { 3 s } \left[ 1 + \frac { s ( - 1 + 4 s _ { W } ^ { 2 } ) } { 2 c _ { W } ^ { 2 } ( s - M _ { Z } ^ { 2 } ) } + \frac { s ^ { 2 } ( - 1 + 4 s _ { W } ^ { 2 } + 8 s _ { W } ^ { 4 } ) } { 4 c _ { W } ^ { 4 } ( s - M _ { Z } ^ { 2 } ) ^ { 2 } } \right] \; , $
# 47  $+ ( U ^ { ( 1 ) } U ^ { ( 2 ) } ) ^ { - 1 } d y _ { 3 } ^ { 2 } + ( H ^ { ( 2 ) } U ^ { ( 2 ) } ) ^ { - 1 } d y _ { 4 } ^ { 2 } + ( H ^ { ( 2 ) } U ^ { ( 1 ) } ) ^ { - 1 } ( d y _ { 5 } ^ { 2 } + d y _ { 6 } ^ { 2 } + d y _ { 7 } ^ { 2 } ) + d x ^ { \alpha } d x ^ { \alpha } ] $
# 48  $L _ { e f f } ^ { ( 1 ) } = 2 \pi \kappa \frac { \sigma _ { 1 } \sigma _ { 2 } } { q _ { 1 } q _ { 2 } } \sum _ { p _ { 1 } = 1 } ^ { n _ { 1 } } \sum _ { p _ { 2 } = 1 } ^ { n _ { 2 } } \frac { d } { d t } A r g ( \vec { R } _ { p _ { 1 } } ^ { ( 1 ) } - \vec { R } _ { p _ { 2 } } ^ { ( 2 ) } ) \; \; . $
# 49  $d \sigma _ { V } + d \sigma _ { r } + d \sigma _ { v a c } = \frac { \alpha ^ { 3 } } { 4 } \frac { d Q ^ { 2 } } { S ^ { 2 } Q ^ { 4 } } \sum _ { i = 1 } ^ { 4 } [ \theta _ { i } ^ { F } + 4 ( \delta ^ { e l } + \delta _ { v a c } ^ { l } + \delta _ { v a c } ^ { h } ) \theta _ { i } ^ { 0 } ] { \cal F } _ { i } . $
# 50  ${ \cal I } ( A ) = c _ { 1 } a _ { 2 } ^ { i j } \partial _ { i } \partial _ { j } + ( c _ { 2 } a _ { 1 } ^ { k } + c _ { 3 } \partial _ { j } a _ { 2 } ^ { k j } ) \partial _ { k } + c _ { 4 } \partial _ { i } \partial _ { j } a _ { 2 } ^ { i j } + c _ { 5 } \partial _ { i } a _ { 1 } ^ { i } + c _ { 6 } a _ { 0 } $
# 51  $V ( x _ { 2 } ) = a + ( \frac { e ^ { 2 } V _ { 1 , 1 } } { 2 } ) \int _ { B } ^ { x _ { 2 } } d y \int _ { A } ^ { y } d z | \phi _ { 0 } ( z ) | ^ { 2 } + ( \frac { e ^ { 2 } V _ { 0 , 0 } } { 2 } ) \int _ { B } ^ { x _ { 2 } } d y \int _ { A } ^ { y } d z | \phi _ { 1 } ( z ) | ^ { 2 } . $
# 52  $E _ { M } \, = \, \frac { l } { 4 } \sum _ { n = 1 } ^ { \infty } \left[ \left( 1 \, + \, \frac { r ^ { 2 } k _ { n 1 } ^ { 2 } } { l ^ { 2 } } \right) \omega _ { n 1 } ^ { 2 } A _ { n 1 } ^ { 2 } \, + \, \left( 1 \, + \, \frac { r ^ { 2 } k _ { n 2 } ^ { 2 } } { l ^ { 2 } } \right) \omega _ { n 2 } ^ { 2 } A _ { n 2 } ^ { 2 } \right] $
# 53  $C _ { 0 } = \frac { e \Omega _ { 2 1 } } { 3 2 \pi ^ { 2 } } \frac { m _ { 1 } m _ { 2 } } { m _ { 2 } ^ { 2 } - m _ { 1 } ^ { 2 } } \int _ { 0 } ^ { 1 } t d t \operatorname { l n } { [ \frac { M _ { H } ^ { 2 } + m _ { 1 } ^ { 2 } ( t - 1 ) } { M _ { H } ^ { 2 } + m _ { 2 } ^ { 2 } ( t - 1 ) } ] } \ , $
# 54  $V _ { 1 1 } = V _ { 2 2 } ^ { * } V _ { 3 3 } ^ { * } - V _ { 2 3 } ^ { * } V _ { 3 2 } ^ { * } , \mathrm { ~ o r ~ } V _ { 1 1 } V _ { 2 2 } V _ { 3 3 } = | V _ { 2 2 } | ^ { 2 } | V _ { 3 3 } | ^ { 2 } - V _ { 2 2 } V _ { 3 3 } V _ { 2 3 } ^ { * } V _ { 3 2 } ^ { * } . $
# 55  $g _ { \pm } \equiv \frac { ( \langle m _ { \nu } \rangle \pm m _ { 2 } s _ { 1 } ^ { 2 } c _ { 3 } ^ { 2 } ) ^ { 2 } - ( m _ { 1 } c _ { 1 } ^ { 2 } c _ { 3 } ^ { 2 } - m _ { 3 } s _ { 3 } ^ { 2 } ) ^ { 2 } } { 4 m _ { 1 } m _ { 3 } c _ { 1 } ^ { 2 } s _ { 3 } ^ { 2 } c _ { 3 } ^ { 2 } } . $
# 56  ${ \sigma } _ { q } ^ { [ a ] } \left( N , \frac { Q ^ { 2 } } { \kappa ^ { 2 } } , a _ { s } ( Q ^ { 2 } ) \right) = 1 + \sum _ { n = 1 } ^ { \infty } a _ { s } ^ { n } ( Q ^ { 2 } ) \sum _ { m = 0 } ^ { 2 n } c _ { n m } ^ { [ a ] } \left( { Q ^ { 2 } } / { \kappa ^ { 2 } } \right) \operatorname { l n } ^ { m } N + O \left( \frac { 1 } { N } \right) , $
# 57  $l ^ { j } - \theta ^ { j i } \hat { F } _ { i i ^ { \prime } } l ^ { i ^ { \prime } } = i \theta ^ { j j ^ { \prime } } ( i k _ { j ^ { \prime } } + i \partial _ { j ^ { \prime } } \hat { A } _ { i ^ { \prime } } l ^ { i ^ { \prime } } ) + \theta ^ { j j ^ { \prime } } l ^ { i ^ { \prime } } D _ { i ^ { \prime } } \hat { A } _ { j ^ { \prime } } , $
# 58  $\psi _ { \alpha } = { \frac { 1 } { 2 \pi i } } \int _ { C _ { + } } d t e ^ { - i x \operatorname { c o s h } t } { \frac { e ^ { ( 1 - \alpha ) t } } { e ^ { t } + e ^ { i \theta } } } + { \frac { 1 } { 2 \pi i } } \int _ { C _ { - } } d t e ^ { - i x \operatorname { c o s h } t } { \frac { e ^ { ( 1 - \alpha ) t } } { e ^ { t } + e ^ { i \theta } } } , $
# 59  $J _ { p } ( E ) = ( \gamma _ { g } - 2 ) \frac { c } { 4 \pi } \frac { { \cal L } _ { 0 } } { H _ { 0 } } E ^ { - \gamma _ { g } } \int _ { 0 } ^ { z _ { m a x } } d z _ { g } ( 1 + z _ { g } ) ^ { m - 5 / 2 } \lambda ^ { - \gamma _ { g } } ( E , z _ { g } ) \frac { d E _ { g } ( z _ { g } ) } { d E } , $
# 60  $Z = \int { \cal D } h _ { \mu \nu } { \cal D } h _ { \mu \nu } ^ { \prime } { \cal D } \theta _ { \mu } { \cal D } b _ { \mu \nu } { \cal D } c _ { \mu \nu } { \cal D } \bar { c } _ { \mu \nu } { \cal D } b _ { \mu } { \cal D } c _ { \mu } { \cal D } \bar { c } _ { \mu } \operatorname { e x p } i \int d ^ { 4 } x \left[ L _ { h } + L _ { \mathrm { B } } \right] . $
# 61  $R ( \phi ) = \sum _ { n = 0 } ^ { \infty } r _ { m _ { 1 } \ldots m _ { n } } ^ { ( n ) } \phi _ { m _ { 1 } } \ldots \phi _ { m _ { n } } , \; \; \; \; \; \; \tilde { R } ( \tilde { \phi } ) = \sum _ { n = 0 } ^ { \infty } r _ { m _ { 1 } \ldots m _ { n } } ^ { ( n ) } \tilde { \phi } _ { m _ { n } } \ldots \tilde { \phi } _ { m _ { 1 } } $
# 62  ${ \bf x _ { 1 } } = \frac { 1 } { \sqrt { N ^ { \prime } } } \left( k ^ { 2 } , 0 , 0 \right) ^ { T } , \; \; { \bf x _ { 2 } } = \frac { 1 } { \sqrt { N ^ { \prime } } } \left( 0 , k ^ { 2 } , 0 \right) ^ { T } \; \; \mathrm { a n d } \; \; { \bf x _ { 3 } } = \frac { 1 } { \sqrt { N ^ { \prime } } } \left( 0 , 0 , k ^ { 2 } \right) ^ { T } , $
# 63  $d s _ { ( 6 ) } ^ { 2 } = - { \frac { h } { f _ { w } f _ { p } } } d t ^ { 2 } + { \frac { f _ { p } } { f _ { w } } } \left( d z - { \frac { r _ { 0 } ^ { 2 } \operatorname { s i n h } 2 \sigma _ { p } } { 2 r ^ { 2 } f _ { p } } } d t \right) ^ { 2 } + { \frac { d r ^ { 2 } } { h } } + r ^ { 2 } d \Omega _ { 3 } ^ { 2 } , $
# 64  $\frac { d } { d \tau } ( g _ { \mu \nu } { \dot { x } } ^ { \nu } ) - \frac { 1 } { 2 } \partial _ { \mu } g _ { \nu \lambda } { \dot { x } } ^ { \nu } { \dot { x } } ^ { \lambda } = ( \frac { k d _ { \tau } } { R } F _ { \mu \nu } + \frac { m k R } { \sqrt { \alpha ^ { \prime } } } \tilde { F } _ { \mu \nu } ) { \dot { x } } ^ { \nu } , $
# 65  $Z ^ { I } = Z _ { \infty } ^ { I } + \sum _ { a = 1 } ^ { a = 5 } { \frac { q ^ { I } { } _ { a } } { | \vec { x } - \vec { \underline { { x } } } _ { a } | } } \, \ , \qquad Q ^ { 5 } = \sum _ { a = 1 } ^ { a = 5 } q ^ { 5 } { } _ { a } = Q ^ { 7 } = \sum _ { a = 1 } ^ { a = 5 } q ^ { 7 } { } _ { a } = 0 \ , $
# 66  $B ( z ) = m _ { d } \left( \frac { z _ { 0 } + 1 } { z + 1 } \right) ^ { 1 / 2 } \frac { \operatorname { s i n h } \left[ \frac { \omega } { 2 } \operatorname { l o g } ( z + 1 ) \right] } { \operatorname { s i n h } \left[ \frac { \omega } { 2 } \operatorname { l o g } ( z _ { 0 } + 1 ) \right] } , \quad \omega = \sqrt { 1 - \frac { 8 \pi ^ { 2 } } { e ^ { 2 } N _ { f } ^ { 2 } } } , $
# 67  $M _ { i j } ^ { \nu } = { \frac { M _ { Z } ^ { 2 } } { F _ { N } } } \xi _ { i } \xi _ { j } c _ { \beta } ^ { 2 } \quad \mathrm { w i t h } \quad F _ { N } = - { \frac { M _ { 1 } M _ { 2 } } { M _ { 1 } c _ { W } ^ { 2 } + M _ { 2 } s _ { W } ^ { 2 } } } - { \frac { M _ { Z } ^ { 2 } } { \mu } } s _ { 2 \beta } $
# 68  $\tilde { m } _ { b } = { \frac { \beta ^ { 2 } } { 8 \pi } } ( 1 - { \frac { \tilde { m } _ { 0 } ^ { 2 } } { \tilde { \mu } ^ { 2 } ( \varphi _ { 0 } ) } } ) [ { \frac { 1 } { \sqrt { 1 - \tilde { m } _ { b } ^ { 2 } } } } t a n ^ { - 1 } \sqrt { { \frac { 1 + \tilde { m } _ { b } ^ { 2 } } { 1 - \tilde { m } _ { b } ^ { 2 } } } } - { \frac { \pi } { 4 } } ] $
# 69  $\frac { d \sigma } { d x _ { c } d x _ { F } } = \int _ { 0 } ^ { x _ { F } - x _ { c } } d x _ { u } \int _ { 0 } ^ { x _ { F } - x _ { c } - x _ { u } } d x _ { d } x _ { c } F _ { 3 } \left( x _ { u } , x _ { d } , x _ { c } \right) R _ { 3 } \left( x _ { u } , x _ { d } , x _ { c } \right) \: . $
# 70  $E _ { 1 } : \quad I _ { g r a v } ^ { ( s ) } + ( \frac { 6 } { \pi ^ { 2 } } ) ^ { 4 } ( x _ { 1 2 } ^ { 2 } x _ { 3 4 } ^ { 2 } ) ^ { - 4 } [ 6 4 u ^ { - 4 } G _ { 4 5 } ( \frac { 1 } { u } , \frac { v } { u } ) - 3 2 u ^ { - 4 } G _ { 4 4 } ( \frac { 1 } { u } , \frac { v } { u } ) ] $
# 71  ${ \cal G } = \frac { 1 } { 2 } M _ { i j } d { \bf x } _ { i } \cdot d { \bf x } _ { j } + \frac { g ^ { 4 } } { 2 ( 4 \pi ) ^ { 2 } } ( M ^ { - 1 } ) _ { i j } ( d \xi _ { i } + { \bf W } _ { i k } \cdot d { \bf x } _ { k } ) ( d \xi _ { j } + { \bf W } _ { j l } \cdot d { \bf x } _ { l } ) . $
# 72  $0 = 4 a \left( \frac { d \bar { \phi } } { d A } \right) ^ { 2 } - \frac { 2 } { P ( A ) } \frac { d P ( A ) } { d A } \frac { d \bar { \phi } } { d A } - \frac { \bar { f } _ { 0 } ^ { 2 } } { 2 P ^ { 2 } ( A ) } + \frac { 2 \bar { Q } + \mu e ^ { - 4 a \bar { \phi } } / \bar { Q } } { 4 P ( A ) } , $
# 73  ${ \cal L } _ { f } = \sqrt { 2 } i ( \alpha ^ { \prime } p ^ { + } ) \left\{ \theta _ { + } ^ { \dagger } ( \partial _ { \tau } + \partial _ { \sigma } ) \theta _ { + } + \theta _ { - } ^ { \dagger } ( \partial _ { \tau } - \partial _ { \sigma } ) \theta _ { - } + 2 \theta _ { + } ^ { \dagger } \tilde { \Omega } _ { - } \theta _ { - } + 2 \theta _ { - } ^ { \dagger } \tilde { \Omega } _ { + } \theta _ { + } \right\} $
# 74  $d s ^ { 2 } = { \frac { x ^ { 2 } } { R _ { 1 } ^ { 2 } } } ( - d t ^ { 2 } + d z ^ { 2 } ) + R _ { 1 } ^ { 2 } { \frac { d x ^ { 2 } } { x ^ { 2 } } } + R _ { 1 } ^ { 2 } d \Omega _ { 3 } ^ { 2 } + H _ { 5 } ^ { \prime } ( y ) ( d y ^ { 2 } + y ^ { 2 } d { \Omega _ { 3 } ^ { \prime } } ^ { 2 } ) , $
# 75  ${ \cal V } ^ { \prime \prime } + \left[ \frac { \eta _ { c } q ^ { 2 } } { ( \eta _ { c } - \eta ) } + \frac { 1 } { 4 ( \eta _ { c } - \eta ) ^ { 2 } } \right] { \cal V } = 0 , ~ ~ ~ { \cal W } ^ { \prime \prime } + \left[ \frac { \eta _ { c } q ^ { 2 } } { ( \eta _ { c } - \eta ) } + \frac { 1 } { 4 ( \eta _ { c } - \eta ) ^ { 2 } } \right] { \cal W } = 0 $
# 76  $U _ { e } = \frac { 1 } { \beta } \left[ \frac { e ^ { 2 } } { 8 } \left( | \sigma _ { 1 } | ^ { 2 } - | \sigma _ { 2 } | ^ { 2 } \right) ^ { 2 } + \left( \beta \tilde { m } ^ { 2 } - \frac { 1 } { 2 } \alpha e \tilde { k } \right) | \sigma _ { 1 } | ^ { 2 } + \left( \beta \tilde { m } ^ { 2 } + \frac { 1 } { 2 } \alpha e \tilde { k } \right) | \sigma _ { 2 } | ^ { 2 } \right] , $
# 77  $- \frac { d E } { d x } = K z ^ { 2 } \frac { Z } { A } \frac { 1 } { \beta ^ { 2 } } \left[ \frac { 1 } { 2 } \operatorname { l n } \frac { 2 m _ { e } c ^ { 2 } \beta ^ { 2 } \gamma ^ { 2 } T _ { \mathrm { m a x } } } { I ^ { 2 } } - \beta ^ { 2 } - \operatorname { l n } \frac { \hbar \omega _ { p } } { I } - \operatorname { l n } \beta \gamma + \frac { 1 } { 2 } \right] $
# 78  $A _ { 3 } ( z , \bar { z } ) = \frac { 1 } { \theta } \partial _ { \bar { z } } \left( \frac { \chi _ { 3 } } { \theta } \right) = - \frac { 1 } { 2 \operatorname { c o s h } ( l ) } \, , \quad \bar { A } _ { 3 } ( z , \bar { z } ) = \frac { 1 } { \theta } \partial _ { z } \left( \frac { \chi _ { 3 } } { \theta } \right) = - \frac { 1 } { 2 \operatorname { c o s h } ( l ) } \, . $
# 79  $\delta ^ { ( 2 ) } S _ { \phi } = - \frac { 3 } { 8 \kappa _ { 5 } ^ { 2 } } \int \sqrt { - g _ { 0 } } \left( \frac { { \cal L } _ { \phi } } { 3 } h _ { a b } h ^ { a b } + ( \partial \delta \phi ) ^ { 2 } + \frac { 1 } { 2 } \frac { \partial ^ { 2 } U } { \partial \phi ^ { 2 } } \delta \phi ^ { 2 } + 2 h ^ { a b } \partial _ { a } \delta \phi \partial _ { b } \phi \right) $
# 80  $+ \, \vert \, ^ { \ast } \tilde { \Gamma } ( p , p _ { 1 } , - p _ { 3 } , - p _ { 2 } ) \vert ^ { 2 } + \mathrm { R e } \, ( \, ^ { \ast } \tilde { \Gamma } ( p , - p _ { 2 } , p _ { 1 } , - p _ { 3 } ) \, ^ { \ast } \tilde { \Gamma } ^ { \dagger } ( p , p _ { 1 } , - p _ { 3 } , - p _ { 2 } ) ) \} \vert _ { \mathrm { o n - s h e l l } } $
# 81  ${ \cal H } _ { c a n } = \Pi ^ { - } \partial _ { + } A _ { - } + \Pi ^ { i } \partial _ { + } A _ { i } - { \cal L } _ { W e y l } = \frac 1 2 \Pi ^ { 2 } + \frac 1 2 ( \partial _ { i } A _ { j } ) ^ { 2 } + \Pi \partial _ { i } A _ { i } - A _ { i } J ^ { i } - A _ { - } J ^ { - } $
# 82  $B _ { 1 } ^ { i n } = ( \int _ { M } d v a _ { 1 } + \int _ { S ^ { 2 } } d s c _ { 1 } ) V ^ { 1 / 2 - s } = \int _ { M } ( \frac { \lambda } { 2 } \hat { \phi } ^ { 2 } ) ^ { 3 / 2 - s } d v + \frac { 2 } { 3 R } \int _ { S ^ { 2 } } ( \frac { \lambda } { 2 } \hat { \phi } ^ { 2 } ) ^ { 1 / 2 - s } d s $
# 83  $X ( p _ { 0 } ) = \frac { i \Gamma } { 2 \pi } \, \left[ \left( p _ { 0 } ^ { 2 } - \frac { 3 m ^ { 2 } } { 2 } + \frac { m ^ { 4 } } { 2 p _ { 0 } ^ { 2 } } \right) \, \operatorname { l o g } \left| \frac { p _ { 0 } ^ { 2 } - m ^ { 2 } } { m ^ { 2 } } \right| + \frac { m ^ { 2 } } { 2 } - \frac { 5 p _ { 0 } ^ { 2 } } { 4 } \right] \, . $
# 84  $\mu _ { 4 } ^ { 2 } ( | \phi _ { 1 } ^ { \prime } | ^ { 2 } + | \phi _ { 2 } ^ { \prime } | ^ { 2 } ) + \mu _ { 5 } ^ { 2 } ( | \phi _ { 3 } ^ { \prime } | ^ { 2 } + | \phi _ { 4 } ^ { \prime } | ^ { 2 } ) + \mu _ { 6 } ^ { 2 } ( | \phi _ { 5 } ^ { \prime } | ^ { 2 } + | \phi _ { 6 } ^ { \prime } | ^ { 2 } ) , $
# 85  $T _ { 1 2 3 4 } ( p ^ { 2 } ; m _ { i } ^ { 2 } ) = B _ { 0 } ( p ^ { 2 } ; m _ { 1 } ^ { 2 } , m _ { 2 } ^ { 2 } ) B _ { 0 } ( m _ { 1 } ^ { 2 } ; m _ { 3 } ^ { 2 } , m _ { 4 } ^ { 2 } ) + T _ { 1 2 3 4 } ^ { ( 3 ) } ( p ^ { 2 } ; m _ { i } ^ { 2 } ) \, . \, $
# 86  $\operatorname { t a n } 2 \tilde { \theta } _ { f } = \frac { 2 m _ { f } ( A _ { f } - \mu \{ \operatorname { c o t } \beta , \operatorname { t a n } \beta \} ) } { M _ { \tilde { f } } ^ { 2 } - M _ { \{ \tilde { U } , \tilde { D } \} } ^ { 2 } + M _ { Z } ^ { 2 } ( I _ { 3 } - 2 Q _ { q } s _ { W } ^ { 2 } ) \operatorname { c o s } 2 \beta } \ . $
# 87  $\mu ^ { 2 } = m _ { 0 } ^ { 2 } C _ { 1 } + A _ { 0 } ^ { 2 } C _ { 2 } + m _ { \frac { 1 } { 2 } } ^ { 2 } C _ { 3 } + m _ { \frac { 1 } { 2 } } A _ { 0 } C _ { 4 } - \frac { 1 } { 2 } M _ { Z } ^ { 2 } + \frac { 3 } { 5 } \frac { t ^ { 2 } + 1 } { t ^ { 2 } - 1 } S _ { 0 } p $
# 88  $\bar { H } _ { \mathrm { g } } = H _ { \mathrm { g } } ( q ^ { r } , p ^ { r } ) + \lambda _ { a } ^ { ( 1 ) r _ { a } } \pi _ { a } ^ { r _ { a } } + \lambda _ { a } ^ { ( 2 ) r _ { a } } \psi _ { a } ^ { r _ { a } } + \lambda _ { a } ^ { ( 3 ) } \theta _ { a } + \lambda _ { a } ^ { ( 4 ) } \gamma _ { a } , $
# 89  ${ \cal L } = - \mathrm { T r } \; \operatorname { l o g } ( - i \gamma \cdot \partial + \gamma _ { 0 } \Gamma _ { a } \phi _ { a } ) + \sum _ { p = 1 } ^ { N _ { p } } c _ { p } \mathrm { T r } \; \operatorname { l o g } ( - i \gamma \cdot \partial + g _ { p } \gamma _ { 0 } \Gamma _ { a } \phi _ { a } ) + \frac { a ^ { 2 } } { 2 } \int d ^ { 4 } x \phi ^ { 2 } \; , $
# 90  $\sum _ { e } \sum _ { m , n = 0 } ^ { 1 } C _ { e } ( m , n ) \theta ^ { 4 } [ e ] F _ { R , t w s } ^ { m , n } = E ( z , 0 ) ^ { - 2 } \sum _ { i = 2 } ^ { 3 } C _ { i } \theta _ { i } ^ { 1 2 } ( 0 | \tau ) \frac { \theta _ { i } ^ { 2 } ( z | \tau ) } { \theta _ { i } ^ { 2 } ( 0 | \tau ) } , $
# 91  $V _ { \mathrm { r e n } } ( \chi ) = \frac { 1 } { 2 } m _ { R } ^ { 2 } \chi + \frac { 1 } { 4 } \lambda _ { R } \chi ^ { 2 } + V _ { \mathrm { f i n } } ( \chi ) + \frac { 1 } { 6 4 \pi ^ { 2 } } ( m _ { R } ^ { 2 } + 3 \lambda _ { R } \chi ) ^ { 2 } \operatorname { l n } { \frac { \eta ^ { 2 } } { \mu ^ { 2 } } } $
# 92  $\sigma _ { ( a _ { i } ^ { \dag } a _ { k } ) } ^ { - } = < { \bf A } _ { - } \mid \frac { 1 } { 2 } ( a _ { i } ^ { \dag } a _ { k } + a _ { k } a _ { i } ^ { \dag } ) \mid { \bf A _ { - } } > = \alpha _ { i } ^ { * } \alpha _ { k } c o t h \mid { \bf A } \mid ^ { 2 } + \frac { 1 } { 2 } \delta _ { i k } . \nonumber \, $
# 93  $[ V _ { \alpha } , V _ { \beta } ] = \epsilon _ { \alpha \beta } ^ { ~ ~ ~ \! \gamma } V _ { \gamma } , \; \; \; [ V _ { \alpha } , V _ { m } ^ { a } ] = V _ { m } ^ { b } ( \sigma _ { \alpha } ) _ { b } ^ { ~ a } , \; \; \; \{ V _ { m } ^ { a } , V _ { m } ^ { b } \} = - m ^ { 2 } ( \sigma ^ { \alpha } ) ^ { a b } V _ { \alpha } , $
# ...
# 67  M _ { i j } ^ { \nu } = \frac { M _ { Z } ^ { 2 } } { F _ { N } } \xi _ { i } \xi _ { j } c _ { \beta } ^ { 2 } \quad \mathrm { w i t h } \quad F _ { N } = - \frac { M _ { 1 } M _ { 2 } } { M _ { 1 } c _ { W } ^ { 2 } + M _ { 2 } s _ { W } ^ { 2 } } - \frac { M _ { Z } ^ { 2 } } { \mu } s _ { 2 \beta }
# 68  \tilde { m } _ { b } = \frac { \beta ^ { 2 } } { 8 \pi } ( 1 - \frac { \tilde { m } _ { 0 } ^ { 2 } } { \hat { \mu } ^ { 2 } ( \varphi _ { 0 } ) } ) [ \frac { 1 } { \sqrt { 1 - m _ { b } ^ { 2 } } } t a n ^ { - 1 } \sqrt { \frac { 1 + \tilde { m } _ { b } ^ { 2 } } { 1 - \tilde { m } _ { b } ^ { 2 } } } - \frac { \pi } { 4 } ]
# 69  \frac { d \sigma } { d x _ { c } d x _ { F } } = \int _ { 0 } ^ { x _ { F } - x _ { c } } d x _ { u } \int _ { 0 } ^ { x _ { F } - x _ { c } - x _ { u } } d x _ { d } x _ { c } F _ { 3 } \left( x _ { u } , x _ { d } , x _ { c } \right) R _ { 3 } \left( x _ { u } , x _ { d } , x _ { c } \right) \; .
# 70  E _ { 1 } : \quad I _ { g r a v } ^ { ( s ) } + ( \frac { 6 } { \pi ^ { 2 } } ) ^ { 4 } ( x _ { 1 2 } ^ { 2 } x _ { 3 4 } ^ { 2 } ) ^ { - 4 } [ 6 4 u ^ { - 4 } G _ { 4 5 } ( \frac { 1 } { u } , \frac { v } { u } ) - 3 2 u ^ { - 4 } G _ { 4 4 } ( \frac { 1 } { u } , \frac { v } { u } ) ]
# 71  { \cal G } = { \frac { 1 } { 2 } } M _ { i j } d { \bf x } _ { i } \cdot d { \bf x } _ { j } + { \frac { g ^ { 4 } } { 2 ( 4 \pi ) ^ { 2 } } } ( M ^ { - 1 } ) _ { i j } ( d \xi _ { i } + { \bf W } _ { i k } \cdot d { \bf x } _ { k } ) ( d \xi _ { j } + { \bf W } _ { j l } \cdot d { \bf x } _ { l } ) .
# 72  0 = 4 a \left( { \frac { d \bar { \phi } } { d A } } \right) ^ { 2 } - { \frac { 2 } { P ( A ) } } { \frac { d P ( A ) } { d A } } { \frac { d \bar { \phi } } { d A } } - { \frac { \bar { f } _ { 0 } ^ { 2 } } { 2 P ^ { 2 } ( A ) } } + { \frac { 2 \bar { Q } + \mu e ^ { - 4 a \bar { \phi } } / \bar { Q } } { 4 P ( A ) } } ,
# 73  { \cal L } _ { f } = \sqrt { 2 } i ( \alpha ^ { \prime } p ^ { + } ) \left\{ \theta _ { + } ^ { \dagger } ( \partial _ { \tau } + \partial _ { \sigma } ) \theta _ { + } + \theta _ { - } ^ { \dagger } ( \partial _ { \tau } - \partial _ { \sigma } ) \theta _ { - } + 2 \theta _ { + } ^ { \dagger } \tilde { \Omega } _ { - } \theta _ { - } + 2 \theta _ { - } ^ { \dagger } \tilde { \Omega } _ { + } \theta _ { + } \right\}
# 74  d s ^ { 2 } = \frac { x ^ { 2 } } { R _ { 1 } ^ { 2 } } ( - d t ^ { 2 } + d z ^ { 2 } ) + R _ { 1 } ^ { 2 } \frac { d x ^ { 2 } } { x ^ { 2 } } + R _ { 1 } ^ { 2 } d \Omega _ { 3 } ^ { 2 } + H _ { 5 } ^ { \prime } ( y ) ( d y ^ { 2 } + y ^ { 2 } d \Omega _ { 3 } ^ { \prime ^ { 2 } } ) ,
# 75  { \cal V } ^ { \prime \prime } + \left[ \frac { \eta _ { c } q ^ { 2 } } { ( \eta _ { c } - \eta ) } + \frac { 1 } { 4 ( \eta _ { c } - \eta ) ^ { 2 } } \right] { \cal V } = 0 , ~ ~ ~ { \cal W } ^ { \prime \prime } + \left[ \frac { \eta _ { c } q ^ { 2 } } { ( \eta _ { c } - \eta ) } + \frac { 1 } { 4 ( \eta _ { c } - \eta ) ^ { 2 } } \right] { \cal W } = 0
# 76  U _ { e } = \frac { 1 } { \beta } \left[ \frac { e ^ { 2 } } { 8 } \left( | \sigma _ { 1 } | ^ { 2 } - | \sigma _ { 2 } | ^ { 2 } \right) ^ { 2 } + \left( \beta \tilde { m } ^ { 2 } - \frac { 1 } { 2 } \alpha e \tilde { k } \right) | \sigma _ { 1 } | ^ { 2 } + \left( \beta \tilde { m } ^ { 2 } + \frac { 1 } { 2 } \alpha e \tilde { k } \right) | \sigma _ { 2 } | ^ { 2 } \right] ,
# 77  - \frac { d E } { d x } = K z ^ { 2 } \frac { Z } { A } \frac { 1 } { \beta ^ { 2 } } \left[ \frac { 1 } { 2 } \operatorname { l n } \frac { 2 m _ { e } c ^ { 2 } \beta ^ { 2 } \gamma ^ { 2 } T _ { \mathrm { m a x } } } { I ^ { 2 } } - \beta ^ { 2 } - \operatorname { l n } \frac { \hbar \omega _ { p } } { I } - \operatorname { l n } \beta \gamma + \frac { 1 } { 2 } \right]
# 78  A _ { 3 } ( z , \bar { z } ) = \frac { 1 } { \theta } \partial _ { \bar { z } } \left( \frac { \chi _ { 3 } } { \theta } \right) = - \frac { 1 } { 2 \operatorname { c o s h } ( l ) } \, , \quad \bar { A } _ { 3 } ( z , \bar { z } ) = \frac { 1 } { \theta } \partial _ { \tilde { z } } \left( \frac { \chi _ { 3 } } { \theta } \right) = - \frac { 1 } { 2 \operatorname { c o s h } ( l ) } \, .
# 79  \delta ^ { ( 2 ) } S _ { \phi } = - \frac { 3 } { 8 \kappa _ { 5 } ^ { 2 } } \int \sqrt { - g _ { 0 } } \left( \frac { { \cal L } _ { \phi } } { 3 } h _ { a b } h ^ { a b } + ( \partial \delta \phi ) ^ { 2 } + \frac { 1 } { 2 } \frac { \partial ^ { 2 } U } { \partial \phi ^ { 2 } } \delta \phi ^ { 2 } + 2 h ^ { a b } \partial _ { a } \delta \phi \partial _ { b } \phi \right)
# 80  + \mid \tilde { \Gamma } ( p , p _ { 1 } , - p _ { 3 } , - p _ { 2 } ) | ^ { 2 } + \mathrm { R e } \, ( \, \, ^ { \ast } \bar { \Gamma } ( p , - p _ { 2 } , p _ { 1 } , - p _ { 3 } ) \, ^ { \ast } \tilde { \Gamma } ^ { \dagger } ( p , p _ { 1 } , - p _ { 3 } , - p _ { 2 } ) ) \} | _ { \mathrm { o n - s n e l l s l } }
# 81  { \cal H } _ { c a n } = \Pi ^ { - } \partial _ { + } A _ { - } + \Pi ^ { i } \partial _ { + } A _ { i } - { \cal L } _ { W e y l } = { \frac { 1 } { 2 } } \Pi ^ { 2 } + { \frac { 1 } { 2 } } ( \partial _ { i } A _ { j } ) ^ { 2 } + \Pi \partial _ { i } A _ { i } - A _ { i } J ^ { i } - A _ { - } J ^ { - }
# 82  B _ { 1 } ^ { i n } = ( \int _ { M } d v a _ { 1 } + \int _ { S ^ { 2 } } d s c _ { 1 } ) V ^ { 1 / 2 - s } = \int _ { M } ( \frac { \lambda } { 2 } \hat { \phi } ^ { 2 } ) ^ { 3 / 2 - s } d v + \frac { 2 } { 3 R } \int _ { S ^ { 2 } } ( \frac { \lambda } { 2 } \hat { \phi } ^ { 2 } ) ^ { 1 / 2 - s } d s
# 83  X ( p _ { 0 } ) = \frac { i \Gamma } { 2 \pi } \left[ \left( p _ { 0 } ^ { 2 } - \frac { 3 m ^ { 2 } } { 2 } + \frac { m ^ { 4 } } { 2 p _ { 0 } ^ { 2 } } \right) \operatorname { l o g } \left| \frac { p _ { 0 } ^ { 2 } - m ^ { 2 } } { m ^ { 2 } } \right| + \frac { m ^ { 2 } } { 2 } - \frac { 5 p _ { 0 } ^ { 2 } } { 4 } \right] \, .
# 84  \mu _ { 4 } ^ { 2 } | ( \phi _ { 1 } ^ { \prime } | ^ { 2 } + | \phi _ { 2 } ^ { \prime } | ^ { 2 } ) + \mu _ { 5 } ^ { 2 } | ( \phi _ { 3 } ^ { \prime } | ^ { 2 } + | \phi _ { 4 } ^ { \prime } | ^ { 2 } ) + \mu _ { 6 } ^ { 2 } ( | \phi _ { 5 } ^ { \prime } | ^ { 2 } + | \phi _ { 6 } ^ { \prime } | ^ { 2 } ) ,
# 85  T _ { 1 2 3 4 } ( p ^ { 2 } ; m _ { i } ^ { 2 } ) = B _ { 0 } ( p ^ { 2 } ; m _ { 1 } ^ { 2 } , m _ { 2 } ^ { 2 } ) B _ { 0 } ( m _ { 1 } ^ { 2 } ; m _ { 3 } ^ { 2 } , m _ { 4 } ^ { 2 } ) + T _ { 1 2 3 4 } ^ { ( 3 ) } ( p ^ { 2 } ; m _ { i } ^ { 2 } ) \, .
# 86  \operatorname { t a n } 2 \tilde { \theta } _ { f } = \frac { 2 m _ { f } ( A _ { f } - \mu \{ \operatorname { c o t } \beta , \operatorname { t a n } \beta \} ) } { M _ { \tilde { f } } ^ { 2 } - M _ { \{ \tilde { U } , \tilde { D } \} } ^ { 2 } + M _ { Z } ^ { 2 } ( I _ { 3 } - 2 Q _ { q } s _ { W } ^ { 2 } ) \operatorname { c o s } 2 \beta } \ .
# 87  \mu ^ { 2 } = m _ { 0 } ^ { 2 } C _ { 1 } + A _ { 0 } ^ { 2 } C _ { 2 } + m _ { \frac { 1 } { 2 } } ^ { 2 } C _ { 3 } + m _ { \frac { 1 } { 2 } } A _ { 0 } C _ { 4 } - \frac { 1 } { 2 } M _ { Z } ^ { 2 } + \frac { 3 } { 5 } \frac { t ^ { 2 } + 1 } { t ^ { 2 } - 1 } S _ { 0 } p
# 88  \bar { H } _ { \mathrm { g } } = H _ { \mathrm { g } } ( q ^ { r } , p ^ { r } ) + \lambda _ { a } ^ { ( 1 ) r _ { a } } \pi _ { a } ^ { r _ { a } } + \lambda _ { a } ^ { ( 2 ) r _ { a } } \psi _ { a } ^ { r _ { a } } + \lambda _ { a } ^ { ( 3 ) } \theta _ { a } + \lambda _ { a } ^ { ( 4 ) } \gamma _ { a } ,
# 89  { \cal L } = - \mathrm { T r } \ \operatorname { l o g } ( - i \gamma \cdot \partial + \gamma _ { 0 } \Gamma _ { a } \phi _ { a } ) + \sum _ { p = 1 } ^ { N _ { p } } c _ { p } \mathrm { T r } \, \operatorname { l o g } ( - i \gamma \cdot \partial + g _ { p } \gamma _ { 0 } \Gamma _ { a } \phi _ { a } ) + \frac { a ^ { 2 } } { 2 } \int d ^ { 4 } x \phi ^ { 2 } \ ,
# 90  \sum _ { e } \sum _ { m , n = 0 } ^ { 1 } C _ { e } ( m , n ) \theta ^ { 4 } [ e ] F _ { R , t w s } ^ { m , n } = E ( z , 0 ) ^ { - 2 } \sum _ { i = 2 } ^ { 3 } C _ { i } \theta _ { i } ^ { 1 2 } ( 0 | \tau ) \frac { \theta _ { i } ^ { 2 } ( z | \tau ) } { \theta _ { i } ^ { 2 } ( 0 | \tau ) } ,
# 91  V _ { \mathrm { r e n } } ( \chi ) = { \frac { 1 } { 2 } } m _ { R } ^ { 2 } \chi + { \frac { 1 } { 4 } } \lambda _ { R } \chi ^ { 2 } + V _ { \mathrm { f i n } } ( \chi ) + { \frac { 1 } { 6 4 \pi ^ { 2 } } } ( m _ { R } ^ { 2 } + 3 \lambda _ { R } \chi ) ^ { 2 } \operatorname { l n } { \frac { \eta ^ { 2 } } { \mu ^ { 2 } } }
# 92  \sigma _ { ( a _ { i } ^ { \dag } a _ { k } ) } ^ { + } = < { \bf A } _ { - } \mid \frac { 1 } { 2 } ( a _ { i } ^ { \dag } a _ { k } + a _ { k } a _ { i } ^ { \dagger } ) \mid { \bf A _ { - } } > = \alpha _ { i } ^ { * } \alpha _ { k } c o t h \mid { \bf A } \mid ^ { 2 } + \frac { 1 } { 2 } \delta _ { i k } .
# 93  [ V _ { \alpha } , V _ { \beta } ] = \epsilon _ { \alpha \beta } ^ { ~ ~ ~ \gamma } V _ { \gamma } , \quad [ V _ { \alpha } , V _ { m } ^ { a } ] = V _ { m } ^ { b } ( \sigma _ { \alpha } ) _ { b } ^ { ~ a } , ~ ~ ~ \{ V _ { m } ^ { a } , V _ { m } ^ { b } \} = - m ^ { 2 } ( \sigma ^ { \alpha } ) ^ { a b } V _ { \alpha } ,
# 94  \Delta [ n x _ { c l } , e _ { 0 } ] = \left( 1 + \frac { g e _ { 0 } } { 4 } B _ { \alpha \beta } \gamma ^ { [ \alpha } \gamma ^ { \beta ] } + \frac { g ^ { 2 } e _ { 0 } ^ { 2 } } { 1 6 } \bar { B } _ { \alpha \beta } \bar { B } ^ { * \alpha \beta } \gamma ^ { 5 } \right) \bar { \Lambda } ( e _ { 0 } ) + Q _ { \alpha \beta } \gamma ^ { [ \alpha } \gamma ^ { \beta ] }
# 95  \frac { 1 } { 2 } i { \psi _ { \pm } ^ { \dagger } } \left( \partial _ { 1 } - i e A ^ { 1 } \right) \psi _ { \pm } - \frac { 1 } { 2 } i \left( \partial _ { 1 } + i e A ^ { 1 } \right) \psi _ { \pm } ^ { \dagger } \psi _ { \pm } = \pm \frac { 1 } { 4 \pi } \left( \partial _ { 1 } \phi _ { \pm } \mp e \lambda A ^ { 1 } \right) ^ { 2 } \mp \frac { \pi } { 1 2 L ^ { 2 } } \; .
# 96  \frac { \lambda _ { 1 } } { \lambda _ { 2 } } = \frac { X _ { 1 } A _ { 3 } } { A _ { 3 } X _ { 2 } } , \quad \frac { \lambda _ { 2 } } { \lambda _ { 3 } } = \frac { X _ { 2 } A _ { 1 } } { A _ { 1 } X _ { 3 } } , \quad \frac { \lambda _ { 3 } } { \lambda _ { 1 } } = \frac { X _ { 3 } A _ { 2 } } { A _ { 2 } X _ { 1 } }
# 97  \Gamma ^ { ( 1 ) } = \frac { 3 1 } { 1 8 0 } \operatorname { l n } ( \mu ^ { 2 } a ^ { 2 } ) + \frac { 7 } { 4 5 } \operatorname { l n } ( 2 ) + \frac { 1 } { 2 } \operatorname { l n } ( \pi ) + \frac { 6 9 3 1 } { 3 0 2 4 0 } - \frac { 1 } { 3 } \zeta _ { R } ^ { \prime } ( - 3 ) + \frac { 1 1 } { 6 } \zeta _ { R } ^ { \prime } ( - 1 ) .
# 98  L _ { \nu _ { \alpha } } \simeq \frac { 1 } { 2 4 \zeta ( 3 ) } \left[ \pi ^ { 2 } ( \tilde { \mu } _ { \alpha } - \tilde { \mu } _ { \overline { { \alpha } } } ) + 6 ( \tilde { \mu } _ { \alpha } ^ { 2 } - \tilde { \mu } _ { \overline { { \alpha } } } ^ { 2 } ) \operatorname { l n } 2 + ( \tilde { \mu } _ { \alpha } ^ { 3 } - \tilde { \mu } _ { \overline { { \alpha } } } ^ { 3 } ) \right] .
# 99  \times { \cal D } h _ { \mu \nu } ^ { a } \operatorname { e x p } \Biggl \{ \int d ^ { 4 } x \Biggl [ - \frac { 1 } { 2 4 \eta ^ { 2 } } \left( H _ { \mu \nu \lambda } ^ { a } \right) ^ { 2 } - \frac { 3 g _ { m } ^ { 2 } } { 8 } \left( h _ { \mu \nu } ^ { a } \right) ^ { 2 } + i \pi h _ { \mu \nu } ^ { a } \bar { \Sigma } _ { \mu \nu } ^ { a } \Biggr ] \Biggr \} .
