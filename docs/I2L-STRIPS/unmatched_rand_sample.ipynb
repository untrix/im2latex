# %%
import sys
import pandas as pd
sys.path.extend(['../src/commons'])
import pub_commons as pub
# %matplotlib inline
pd.options.display.width = None
# Out:
# <style>.container { width:90% !important; }</style>
# Using TensorFlow backend.

# %%
pub.disp_unmatched('I2L-STRIPS')
# Out:
#     edit_distance  $\mathbf{y}$_len  \
# 0   0.064516       31
# 1   0.015385       65
# 2   0.075000       40
# 3   0.138889       36
# 4   0.013889       144
# 5   0.290323       31
# 6   0.058252       103
# 7   0.012987       77
# 8   0.218182       110
# 9   0.029412       68
# 10  0.051282       39
# 11  0.140625       128
# 12  0.281250       32
# 13  0.111111       54
# 14  0.113924       79
# 15  0.157895       114
# 16  0.053763       93
# 17  0.045455       22
# 18  0.042254       71
# 19  0.307692       13
# 20  0.329114       79
# 21  0.064103       78
# 22  0.021053       95
# 23  0.149533       107
# 24  0.070588       85
# 25  0.216495       97
# 26  0.056604       53
# 27  0.093750       128
# 28  0.315789       114
# 29  0.075472       53
# 30  0.198413       126
# 31  0.093750       64
# 32  0.120879       91
# 33  0.077922       77
# 34  0.051020       98
# 35  0.100000       70
# 36  0.089888       89
# 37  0.115385       26
# 38  0.060606       66
# ...
