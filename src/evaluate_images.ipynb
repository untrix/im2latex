# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import pandas as pd
import os
import re
import codecs
from IPython.display import display, Math, Latex
from IPython.display import Image as ipImage
from six.moves import cPickle as pickle
import string
from PIL import Image
import numpy as np
import h5py
import viz_commons as viz
import matplotlib as mpl
from matplotlib import pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid
# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

# %%
pd.options.display.max_rows = 50
pd.options.display.max_colwidth = 600
pd.options.display.expand_frame_repr = False
pd.options.display.colheader_justify = 'left'

# %%
import data_commons as dtc
import dl_commons as dlc
import viz_commons as vc
from viz_commons import VisualizeDir, DiffParams, VisualizeStep

# %% [markdown]
# ### Notebook Arguments
# ----------------------

# %%
# storedir = '/zpool_3TB/i2l/tb_metrics/2017-12-21 02-20-10 PST 140K_score_89.0/test_runs/step_00168100_score89.0_publish/store_2'
storedir = '/zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2'
clobber = False
dump = False

original_image_dir = '/zpool_3TB/i2l/data/dataset5/formula_images'
rel_dumpdir = 'eval_images'
dumpdir = os.path.join(storedir, rel_dumpdir)
rendered_dir = os.path.join(storedir, rel_dumpdir, 'rendered_images')

# %% [markdown]
# ____________________________________

# %%
vd = VisualizeDir(os.path.expanduser(storedir))
last_step = vd.view_steps()[1][-1]
print('last_step = %d' % last_step)
# Out:
# Loaded /zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/hyper.pkl and /zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/args.pkl
# Loaded ../data/dataset5/training_56/df_train.pkl (114408, 3)
# Loaded ../data/dataset5/training_56/df_test.pkl (14280, 3)
# Loaded ../data/dataset5/training_56/df_valid.pkl (14280, 3)
# num eval_steps = 1
# eval_steps = [(167526, 146585)]
# all_steps = []
# last_step = 167526

# %%
vs = VisualizeStep(vd, 'test', last_step)
df, df_result, df_data, sr_label = vs.get_preds(rel_dumpdir=rel_dumpdir, dump=dump, clobber=clobber)
# df = vs.dump_preds(rel_dumpdir=rel_dumpdir, dump=dump)

# %%
df
# Out:
#                     image_name                  iloc   ed        target_len target_seq                                                                                                                                                                                                                                                                                                                                                              pred_len pred_seq
# eval_image_name
# 8eb596be1210429.png  8eb596be1210429_basic.png      0  0.000000   24                                                                                                                                                                                                                                                                                                            h ^ { a } ( \phi ) = \omega ^ { a b } \partial _ { b } H ( \phi )    24                                                                                                                                                                                                                                                                                                                                     h ^ { a } ( \phi ) = \omega ^ { a b } \partial _ { b } H ( \phi )
# 425391c19cc90e6.png  425391c19cc90e6_basic.png      1  0.000000   85                                                                                                                                                      d s _ { 4 } ^ { 2 } = - f ( R ) \left( 1 - \frac { 2 m } { R } \right) d t ^ { 2 } + f ^ { - 1 } ( R ) \left[ \left( 1 - \frac { 2 m } { R } \right) ^ { - 1 } d R ^ { 2 } + R ^ { 2 } d \Omega _ { 2 } ^ { 2 } \right]    85                                                                                                                                                                               d s _ { 4 } ^ { 2 } = - f ( R ) \left( 1 - \frac { 2 m } { R } \right) d t ^ { 2 } + f ^ { - 1 } ( R ) \left[ \left( 1 - \frac { 2 m } { R } \right) ^ { - 1 } d R ^ { 2 } + R ^ { 2 } d \Omega _ { 2 } ^ { 2 } \right]
# 7a939f28e0fd64a.png  7a939f28e0fd64a_basic.png      2  0.000000   58                                                                                                                                                      \left( \mu \frac { \partial } { \partial \mu } + \beta ^ { ( \alpha ) } \frac { \partial } { \partial \alpha } - \gamma _ { m } \, m \frac { \partial } { \partial m } \right) \, { \cal L } ( \alpha , m ; \mu ) = 0 .    58                                                                                                                                                                               \left( \mu \frac { \partial } { \partial \mu } + \beta ^ { ( \alpha ) } \frac { \partial } { \partial \alpha } - \gamma _ { m } \, m \frac { \partial } { \partial m } \right) \, { \cal L } ( \alpha , m ; \mu ) = 0 .
# a03ca65ad0186d6.png  a03ca65ad0186d6_basic.png      3  0.000000   29                                                                                                                                                                                                                                                                                  W = 2 w \operatorname { c o s } \delta _ { 0 } \operatorname { e x p } ( i \delta _ { 0 } )    29                                                                                                                                                                                                                                                                                                           W = 2 w \operatorname { c o s } \delta _ { 0 } \operatorname { e x p } ( i \delta _ { 0 } )
# e4b4876c34c094d.png  e4b4876c34c094d_basic.png      4  0.000000   31                                                                                                                                                                                                                                                                                        Q \equiv M _ { + } - M _ { - } = \frac { 1 } { 2 \pi } \int d x \partial _ { x } \phi    31                                                                                                                                                                                                                                                                                                                 Q \equiv M _ { + } - M _ { - } = \frac { 1 } { 2 \pi } \int d x \partial _ { x } \phi
# 72b26b7d712937b.png  72b26b7d712937b_basic.png      5  0.000000   59                                                                                                                                                                                                                                 \frac { q _ { 1 } ^ { 2 } } { \sigma _ { 3 } ^ { 2 } } + \frac { q _ { 2 } ^ { 2 } } { \sigma _ { 3 } ^ { 2 } - \sigma _ { 2 } ^ { 2 } } = 1    59                                                                                                                                                                                                                                                          \frac { q _ { 1 } ^ { 2 } } { \sigma _ { 3 } ^ { 2 } } + \frac { q _ { 2 } ^ { 2 } } { \sigma _ { 3 } ^ { 2 } - \sigma _ { 2 } ^ { 2 } } = 1
# 0a7747e7015c151.png  0a7747e7015c151_basic.png      6  0.000000   29                                                                                                                                                                                                                                                                                                      \xi _ { R o b i n } ( \kappa ) = \xi _ { d a m p e d } ( \kappa / k ) .    29                                                                                                                                                                                                                                                                                                                               \xi _ { R o b i n } ( \kappa ) = \xi _ { d a m p e d } ( \kappa / k ) .
# 43afdc9657030d0.png  43afdc9657030d0_basic.png      7  0.000000   32                                                                                                                                                                                                                                                                                        \epsilon _ { a b c } \phi _ { b } ^ { m } \partial _ { c } ^ { m } \Gamma _ { i } = 0    32                                                                                                                                                                                                                                                                                                                 \epsilon _ { a b c } \phi _ { b } ^ { m } \partial _ { c } ^ { m } \Gamma _ { i } = 0
# 385cc082a49793d.png  385cc082a49793d_basic.png      8  0.000000   86                                                                                                                                                  M _ { \eta ^ { \prime } } ^ { 2 } = \frac { 2 N _ { f } } { N _ { c } - N _ { f } } \left( \frac { 1 2 } { 1 1 } \right) ^ { 2 } \Lambda ^ { 2 } D \left( N _ { c } \right) ^ { \frac { 1 } { N _ { c } - N _ { f } } } \ .    86                                                                                                                                                                           M _ { \eta ^ { \prime } } ^ { 2 } = \frac { 2 N _ { f } } { N _ { c } - N _ { f } } \left( \frac { 1 2 } { 1 1 } \right) ^ { 2 } \Lambda ^ { 2 } D \left( N _ { c } \right) ^ { \frac { 1 } { N _ { c } - N _ { f } } } \ .
# b4f7b4f31eaf43d.png  b4f7b4f31eaf43d_basic.png      9  0.000000   34                                                                                                                                                                                                                                                                                                     T _ { H } = T _ { H } ^ { H V } \, { \cal Z } _ { H V } ^ { f i n } \, ,    34                                                                                                                                                                                                                                                                                                                              T _ { H } = T _ { H } ^ { H V } \, { \cal Z } _ { H V } ^ { f i n } \, ,
# 480cf9d2543486b.png  480cf9d2543486b_basic.png     10  0.000000   32                                                                                                                                                                                                                                                                                        \mathrm { S y m } ^ { - 1 } ( \mathrm { S y m } ( f ) \cdot \mathrm { S y m } ( g ) )    32                                                                                                                                                                                                                                                                                                                 \mathrm { S y m } ^ { - 1 } ( \mathrm { S y m } ( f ) \cdot \mathrm { S y m } ( g ) )
# 1d3f8f0cf2bf33a.png  1d3f8f0cf2bf33a_basic.png     11  0.000000   31                                                                                                                                                                                                                                                                                          T _ { \mu \nu } = ( \varepsilon + p ) u _ { \mu } u _ { \nu } - p g _ { \mu \nu } .    31                                                                                                                                                                                                                                                                                                                   T _ { \mu \nu } = ( \varepsilon + p ) u _ { \mu } u _ { \nu } - p g _ { \mu \nu } .
# 8dcb942f3c2f8ba.png  8dcb942f3c2f8ba_basic.png     12  0.000000   29                                                                                                                                                                                                                                                                                                        \hat { R } _ { 1 2 } ^ { 2 } - \lambda \hat { R } _ { 1 2 } - 1 = 0 ,    29                                                                                                                                                                                                                                                                                                                                 \hat { R } _ { 1 2 } ^ { 2 } - \lambda \hat { R } _ { 1 2 } - 1 = 0 ,
# 093f9a19555ab13.png  093f9a19555ab13_basic.png     13  0.000000   33                                                                                                                                                                                                                                                                                      \varphi _ { 0 } ( \tau ) = \frac { \varphi _ { B I } } { ( y \tau + 1 ) ^ { 3 / 1 0 } }    33                                                                                                                                                                                                                                                                                                               \varphi _ { 0 } ( \tau ) = \frac { \varphi _ { B I } } { ( y \tau + 1 ) ^ { 3 / 1 0 } }
# ca5509e36b9e7ec.png  ca5509e36b9e7ec_basic.png     14  0.000000   78                                                                                                                                                              V = \alpha \frac { 2 } { R ( \xi + \eta ) } + \frac { 4 } { R ^ { 2 } ( \xi + \eta ) } \left[ c _ { 1 } \frac { 1 } { ( \xi + 1 ) ( 1 + \eta ) } + c _ { 2 } \frac { 1 } { ( \xi - 1 ) ( 1 - \eta ) } \right] .    78                                                                                                                                                                                       V = \alpha \frac { 2 } { R ( \xi + \eta ) } + \frac { 4 } { R ^ { 2 } ( \xi + \eta ) } \left[ c _ { 1 } \frac { 1 } { ( \xi + 1 ) ( 1 + \eta ) } + c _ { 2 } \frac { 1 } { ( \xi - 1 ) ( 1 - \eta ) } \right] .
# 2336f91f9ed6cf5.png  2336f91f9ed6cf5_basic.png     15  0.000000   32                                                                                                                                                                                                                                                                       \partial _ { \lambda } \partial ^ { \lambda } f ( r , t ) = \delta ( \vec { x } ) e ^ { - i \omega t }    32                                                                                                                                                                                                                                                                                                \partial _ { \lambda } \partial ^ { \lambda } f ( r , t ) = \delta ( \vec { x } ) e ^ { - i \omega t }
# 77bd90b9f72d503.png  77bd90b9f72d503_basic.png     16  0.000000   34                                                                                                                                                                                                                                                                                                X ^ { ( 0 ) } = \Delta _ { B } ^ { 2 } \Delta _ { B } ^ { 1 } Y ^ { ( 2 ) } ,    34                                                                                                                                                                                                                                                                                                                         X ^ { ( 0 ) } = \Delta _ { B } ^ { 2 } \Delta _ { B } ^ { 1 } Y ^ { ( 2 ) } ,
# 0d0086add29ad32.png  0d0086add29ad32_basic.png     17  0.000000   33                                                                                                                                                                                                                                                                          \{ p ^ { \delta \omega } , q ^ { \delta \omega } \} = \{ p , q \} + O ( \delta \omega ^ { 2 } ) \ .    33                                                                                                                                                                                                                                                                                                   \{ p ^ { \delta \omega } , q ^ { \delta \omega } \} = \{ p , q \} + O ( \delta \omega ^ { 2 } ) \ .
# 26bfd708f2258b1.png  26bfd708f2258b1_basic.png     18  0.000000   56                                                                                                                                                                                                                                             K _ { 1 } = 3 C _ { 1 } ^ { 2 } + 2 C _ { 1 } C _ { 2 } \approx - 0 . 3 9 \qquad K _ { 2 } = C _ { 2 } ^ { 2 } \approx 1 . 2 5 .    56                                                                                                                                                                                                                                                                      K _ { 1 } = 3 C _ { 1 } ^ { 2 } + 2 C _ { 1 } C _ { 2 } \approx - 0 . 3 9 \qquad K _ { 2 } = C _ { 2 } ^ { 2 } \approx 1 . 2 5 .
# 820736c6ea45c37.png  820736c6ea45c37_basic.png     19  0.000000   34                                                                                                                                                                                                                                                                                       \Phi = b ^ { * } \frac { 1 } { \sqrt { N + 1 } } + \frac { 1 } { \sqrt { N + 1 } } b .    34                                                                                                                                                                                                                                                                                                                \Phi = b ^ { * } \frac { 1 } { \sqrt { N + 1 } } + \frac { 1 } { \sqrt { N + 1 } } b .
# 4f2a0966454c21a.png  4f2a0966454c21a_basic.png     20  0.000000   14                                                                                                                                                                                                                                                                                                                                 \chi \equiv \partial _ { i } \pi _ { i } + n    14                                                                                                                                                                                                                                                                                                                                                          \chi \equiv \partial _ { i } \pi _ { i } + n
# 7b5ea8da87833e6.png  7b5ea8da87833e6_basic.png     21  0.000000   34                                                                                                                                                                                                                                                                                                 \Delta = \prod _ { l < n } ^ { 2 g + 1 } ( e _ { l } - e _ { n } ) ^ { 2 } .    34                                                                                                                                                                                                                                                                                                                          \Delta = \prod _ { l < n } ^ { 2 g + 1 } ( e _ { l } - e _ { n } ) ^ { 2 } .
# 2121eee1775d400.png  2121eee1775d400_basic.png     22  0.000000   57                                                                                                                                                                                                                                                   F ^ { + } { } _ { a + } = - F ^ { - } { } _ { a - } , \qquad Q ^ { \pm + } { } _ { a + } = - Q ^ { \pm - } { } _ { a - } .    57                                                                                                                                                                                                                                                                            F ^ { + } { } _ { a + } = - F ^ { - } { } _ { a - } , \qquad Q ^ { \pm + } { } _ { a + } = - Q ^ { \pm - } { } _ { a - } .
# 62cbf6b34e3c488.png  62cbf6b34e3c488_basic.png     23  0.000000   31                                                                                                                                                                                                                                                                   \Delta = c _ { 2 } \gamma ( \alpha ) - c _ { 1 } \alpha \gamma ^ { \prime } ( \alpha ) \gamma ( \alpha ) .    31                                                                                                                                                                                                                                                                                            \Delta = c _ { 2 } \gamma ( \alpha ) - c _ { 1 } \alpha \gamma ^ { \prime } ( \alpha ) \gamma ( \alpha ) .
# 7bd21384615a543.png  7bd21384615a543_basic.png     24  0.000000   32                                                                                                                                                                                                                                                                                                      B ( u , s ) = \sum _ { n = 0 } ^ { \infty } c _ { n } w ^ { n } ( u ) ,    32                                                                                                                                                                                                                                                                                                                               B ( u , s ) = \sum _ { n = 0 } ^ { \infty } c _ { n } w ^ { n } ( u ) ,
# ...                                        ...    ...       ...         ...                                                                                                                                                                                                                                                                                                                                                                    ...       ...                                                                                                                                                                                                                                                                                                                                                                                               ...
# bacc8145ae89673.png  bacc8145ae89673_basic.png  14255  0.600000   20                                                                                                                                                                                                                                                            \frac 1 2 \left| \left( u d - d u \right) \times \left( \uparrow \downarrow - \downarrow \uparrow \right) \right>    24                                                                                                                                                                                                                                                                                                                      \frac { 1 } { 2 } \left| ( u d - d u ) \times ( \uparrow + - 1 | \rangle \rangle
# c14e7b0c5ce1557.png  c14e7b0c5ce1557_basic.png  14256  0.608333  120                         \overline { { M } } _ { \mathrm { q } } \; = \; \left( \begin{matrix} { E _ { \mathrm { q } } } & { | D _ { \mathrm { q } } | } & { { \bf 0 } } \\ { | D _ { \mathrm { q } } | } & { C _ { \mathrm { q } } } & { | B _ { \mathrm { q } } | } \\ { { \bf 0 } } & { | B _ { \mathrm { q } } | } & { A _ { \mathrm { q } } } \\ \end{matrix} \right) \;    65                                                                                                                                                                                             \overline { { M } } _ { \mathrm { q } } \; = \; \left( \vert D _ { \mathrm { q l } } \vert \quad C _ { { \mathrm { G } } _ { 0 } } \vert ^ { 2 } \left| B _ { { \mathrm { c } } } \right| \right) ^ { s }
# 614cd51f7ba7b99.png  614cd51f7ba7b99_basic.png  14257  0.618557   97                                                                                 \left\{ \begin{array} { c c c } { a } & { b } & { i } \\ { c } & { d } & { j } \\ \end{array} \right\} = \frac { T e t \left[ \begin{array} { c c c } { a } & { b } & { i } \\ { c } & { d } & { j } \\ \end{array} \right] \Delta _ { i } } { \theta ( a , d , i ) \theta ( b , c , i ) } .   109                                                                                    \left\{ \begin{array} { l c l } { a } & { i } \\ { a } & { b } & { i } \\ { b } & { i } & { { \bf 1 } } \\ \end{array} \right\} _ { j } = \frac { T e t \left[ ~ c _ { i } } & { d } & { i } \\ { \underline { { a } } [ \mu , d ) } & { d } & { j } \\ \end{array} { d } & { d } & { j } \\ \end{array} \right) .
# a4886ea1118abce.png  a4886ea1118abce_basic.png  14258  0.625000   32                                                                                                                                                                                                                                                                  \hat { \tau } = \tau + \int ^ { \sigma } A \; d \sigma , \; \; \; \; \; \; \; \; \hat { \sigma } = \sigma ,    14                                                                                                                                                                                                                                                                                                                                                          \hat { \tau } = \tau + \int \ A \ d \sigma ,
# 585581d2895f53c.png  585581d2895f53c_basic.png  14259  0.630137   73                                                                                                                                   \begin{array} { l } { \chi ^ { \ ( + ) } \ ( \ 0 \ ) \ = \ 4 \ n _ { \ f l } ^ { \ 2 } \ \left\langle \ \Omega \ \right| \ \left( \ - \ m _ { \ Q } \ \overline { { Q } } \ Q \ \right) \ \left| \ \Omega \ \right\rangle } \\ \end{array}    57                                                                                                                                                                                                        \chi ^ { \left( + + } \left( 0 \right) \, = \, 4 \, n _ { \, f t } ^ { 2 } \; \; \langle \; \Omega \mid \; ( \; - \; m \; \alpha \; \overline { { Q } } \; Q \; ) \; \mid \; \Omega \; \rangle
# 0f2d21ddbe8e50a.png  0f2d21ddbe8e50a_basic.png  14260  0.636364   99                                                       u _ { i 1 } = \left( \begin{matrix} { - \frac { 1 } { 2 4 } ( 1 + \sqrt { 5 } ) } \\ { \frac { \sqrt { 5 } } { 6 } } \\ { 1 } \\ \end{matrix} \right) , \qquad u _ { i 2 } = \left( \begin{matrix} { \frac { 1 } { 2 4 } ( \sqrt { 5 } - 1 ) } \\ { - \frac { \sqrt { 5 } } { 6 } } \\ { 1 } \\ \end{matrix} \right) .   134       u _ { i 1 } = \left( \begin{array} { c c c } { \frac { 1 } { 2 4 } ( \frac { 1 } { 5 } \sqrt { 5 } ) } \\ { } & { } \\ { \frac { 1 } { \sqrt { 3 } } } & { } \\ \end{array} \right) , \ \ \ \ \ \ u _ { i 2 } = \left( \begin{array} { c l } { \frac { 1 4 } { 4 } ( \sqrt { \frac { 1 } { 5 } } } \\ { \frac { 1 } { \sqrt { 2 } } } \\ { } & { \frac { 1 } { 3 } } \\ \end{array} \right) } .
# 9047c7ede6b4cbc.png  9047c7ede6b4cbc_basic.png  14261  0.638889   36                                                                                                                                                                                                                                                    \left. { \left| { 3 3 { \left[ { 4 2 } \right] } _ { O } { \left[ { 3 3 } \right] } _ { F S } } \right. } \right\rangle \    25                                                                                                                                                                                                                                                                                                                                                | 3 3 [ 4 2 _ { ( O } ^ { \gamma } [ 3 3 ] _ { F S } )
# 61b113233b6c49e.png  61b113233b6c49e_basic.png  14262  0.643564  101                                                                                                            \begin{array} { c } { D ^ { B } H ^ { A } = 0 , \qquad \qquad D ^ { B } D ^ { A } \Phi _ { A } = [ H ^ { A } , \Phi _ { B } ] , } \\ { D ^ { A } K ^ { B } = 0 , \qquad \qquad D ^ { A } D ^ { B } \Phi _ { B } = [ K ^ { B } , \Phi _ { A } ] . } \\ \end{array}    37                                                                                                                                                                                                                                                                                                     \begin{array} { l } { D ^ { B } H ^ { A } = 0 , } \\ { D ^ { A } K ^ { B } = 0 , } \\ \end{array}
# 360f14cc7f0f20f.png  360f14cc7f0f20f_basic.png  14263  0.652174   23                                                                                                                                                                                                                                                                                                      ( \eta - \beta ) + ( \eta - \gamma ) = \alpha , \ \textrm { e t c . , }    33                                                                                                                                                                                                                                                                                     ( \eta - \beta ) + ( \eta - \gamma ) = \alpha , { \mathrm { \boldmath ~ e ~ } } \mathrm { \boldmath ~ c ~ } . \ ,
# 1ccc1eab4e659f5.png  1ccc1eab4e659f5_basic.png  14264  0.654545   55                                                                                                                                                                                                        \mathrm { U V } \ ( g = 0 ) : \qquad \Sigma _ { N } \otimes \Psi _ { r N } \ ; \qquad \qquad \qquad \mathrm { I R \ } ( g = 1 ) : \qquad \Sigma _ { N ( 1 + r ) } \ ;    60                                                                                                                                                                                                                                                     \mathrm { U V } ~ ( g = 0 ) : ~ ~ ~ ~ ~ ~ \Sigma _ { N } \otimes \Psi _ { r N } ~ ; ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ \mathrm { I R } ~ ( g = 1 ) :
# fdc7c7aec9443cc.png  fdc7c7aec9443cc_basic.png  14265  0.654676  139         S _ { 1 ^ { j } } ( z ) = \sum _ { { \scriptstyle k _ { 1 } + 2 k _ { 2 } + \cdots + m k _ { m } = j } \atop { \scriptstyle k _ { 1 } \geq 0 , \cdots , k _ { m } \geq 0 } } ( - 1 ) ^ { k _ { 2 } + k _ { 4 } + \cdots + k _ { 2 \left[ \frac m 2 \right] } } \frac 1 { k _ { 1 } ! \cdots k _ { m } ! } z _ { 1 } ^ { k _ { 1 } } \cdots z _ { m } ^ { k _ { m } }   109                                                                                                                                   \begin{array} { r c l } { f _ { I _ { j } } ( z ) = } & { i } & { ( - 1 ) ^ { k _ { j } + k _ { 4 } + \cdots + k _ { 2 } ( \frac { x _ { 1 } } { 2 } ) } \frac { 1 } { K _ { j } - k _ { n } ] } \\ { ~ } & { + } & { l _ { 2 } \ldots p _ { n } | } \\ \end{array}
# cdeddf2181be187.png  cdeddf2181be187_basic.png  14266  0.666667   15                                                                                                                                                                                                                                                                                                                            { \tilde { l } } { \tilde { l } } \rightarrow l l     7                                                                                                                                                                                                                                                                                                                                                                    \widetilde { l } \Pi \rightarrow l
# ca659bc0b1ffbfd.png  ca659bc0b1ffbfd_basic.png  14267  0.689922  129                                                                    \begin{array} { c } { C _ { 2 } = \frac 1 2 L _ { A B } L ^ { A B } = E _ { o } ( E _ { o } + 3 ) + s ( s + 1 ) } \\ { C _ { 4 } = W _ { A } W ^ { A } = - s ( s + 1 ) ( E _ { o } - 1 ) ( E _ { o } - 2 ) } \\ { W _ { A } = \frac 1 8 \epsilon _ { A B C D E } L ^ { B C } L ^ { D E } } \\ \end{array}    61                                                                                                                                                                                                                                                                    C _ { 4 } = W _ { A } W _ { V } ^ { A A } = - s ( s , + 1 ) _ { F } ( E _ { c } - 1 ) ^ { c } ( 1 ) \bar { c } _ { o } - 2 \right)
# 26b64336b324203.png  26b64336b324203_basic.png  14268  0.692308   65                                                                                                                                                                                                             \cal { A } _ { l } ( E , \vec { p } ) = \frac { 2 E \gamma } { \pi } \frac { 1 } { ( E ^ { 2 } - \Omega _ { p } ^ { 2 } ) ^ { 2 } + 4 E ^ { 2 } \gamma ^ { 2 } }    85                                                                                                                          { \cal A } _ { \zeta } ( { \cal E } , \sqrt { \gamma ^ { \prime } } ) = \frac { \varepsilon { \cal F } } { \pi } _ { \quad } \frac { 1 } { ( { \cal E } ^ { - } - \otimes ^ { Q _ { S } } ) ^ { \epsilon } + \triangle \Delta { \cal E } ^ { \epsilon _ { \tau } } \rangle }
# e5e649488182854.png  e5e649488182854_basic.png  14269  0.696629   89                                                                                                                                        \begin{array} { l } { \displaystyle \frac { 1 } { 1 + q ^ { 2 n - 1 } } C _ { i j } x ^ { i } x ^ { j } = - \frac { 1 } { a ^ { 2 } } ~ , } \\ { { \overline { x } ^ { i } } = C _ { j i } M _ { j k } x ^ { k } ~ , } \\ \end{array}    71                                                                                                                                                                                                                                  \frac { 1 } { 1 _ { + } ^ { + } + q ^ { 2 } } _ { I - 1 } ^ { - 1 } C _ { i j } x ^ { k } \, , \, \, \, \, \, \, \, \, \, \, \, \, \frac { 1 } { a ^ { 2 } } \, \, ,
# e21424ad0a22dfd.png  e21424ad0a22dfd_basic.png  14270  0.698113   53                                                                                                                                                                                                                                             h ^ { 8 } = [ \begin{array} { c c c c c c c c } { 0 } & { 1 } & { 1 } & { 2 } & { 0 } & { 2 } & { 2 } & { 1 } \\ \end{array} ] ,    33                                                                                                                                                                                                                                                                                                                                h ^ { 8 } = \left[ \ 0 \ \ 1 \ \ 1 \ \ 2 \ \ 0 \ \ 2 \ \ 2 \ \ 1 \ ] ,
# e9a3cbb4e6c1658.png  e9a3cbb4e6c1658_basic.png  14271  0.701754   57                                                                                                                                                                                                            E _ { r + 1 } \, \supset \, K _ { r + 1 } ^ { 0 } \, \supset \, K _ { r + 1 } ^ { 1 } \, \supset \, \dots \, \supset \, K _ { r + 1 } ^ { i } \, \supset \, \dots    80                                                                                                                                                E _ { r + 1 } \stackrel { - } { \rightarrow } K _ { r + 1 } ^ { 0 } \stackrel { - } { \rightarrow } K _ { r + 1 } ^ { 1 } \stackrel { - } { \rightarrow } \cdots \stackrel { - } { \rightarrow } \stackrel { N } { K } _ { r + 1 } ^ { i } \; > \; . .
# 93c2d38bafe2efb.png  93c2d38bafe2efb_basic.png  14272  0.703704   27                                                                                                                                                                                                                                                                            \varpi \varpi ^ { \bullet \bullet } - ( \varpi ^ { \bullet } ) ^ { 2 } = 2 \Lambda \varpi ^ { 3 }    39                                                                                                                                                                                                                                                                                                      { \bf z } { \bf \omega } ^ { * } } - ( { \bf x } ^ { * } ) ^ { 2 } = 2 \Lambda { \bf e } ^ { 3 }
# fd5732e726ecbdf.png  fd5732e726ecbdf_basic.png  14273  0.712963  108                                                                                                               n ^ { 2 } ( x ^ { \perp } , t ) = \frac { C ^ { 2 } } { 4 t ^ { 2 } } \frac { \left( 4 t ^ { 2 } - { x ^ { \perp } } ^ { 2 } \right) ^ { 2 } } { C ^ { 2 } { x ^ { \perp } } ^ { 2 } + 4 \sqrt { C ^ { 4 } - 4 I } x ^ { \perp } t + 4 C ^ { 2 } t ^ { 2 } } .   118                                                                                                 \begin{array} { c c c c c c c c c } { } & { } & { } & { } & { } & { n ^ { 2 } ( x ^ { + } , t ) = \frac { C ^ { 2 } } { 4 } d ^ { 2 } \frac { } { } \left( \frac { 1 } { q ^ { 2 } } - \frac { 1 } { q } + ( \frac { 1 } { \sqrt { q ^ { 2 } } / Q ^ { 2 } + 4 H ^ { 2 } } } } \\ \end{array} \right)
# b663d762e435a09.png  b663d762e435a09_basic.png  14274  0.721429  140                                              \begin{array} { r l c } { G _ { B - L } : H ^ { ( 1 ) } ( 1 ) , H ^ { ( 2 ) } ( 1 ) , L ( - 1 ) , E ^ { c } ( 0 ) , } \\ { Q ( - 1 ) , U ^ { c } ( 0 ) , D ^ { c } ( 0 ) , S ( 0 ) , \phi ( 0 ) , \bar { \phi } ( 0 ) , ~ } \\ { N ( - 1 ) , \bar { N } ( 1 ) , T ( 2 ) , \bar { T } ( - 2 ) ; ~ ~ ~ ~ ~ ~ ~ ~ } \\ \end{array}    44                                                                                                                                                                                                                                                                                                 Q ( - 1 ) , U ^ { c } ( 0 ) , D ^ { T } ( 0 ) , S ( 0 ) , \phi ( 0 ) , \overline { { \phi } } ( 0 ) ,
# 86c7e6e54cf188f.png  86c7e6e54cf188f_basic.png  14275  0.779221   77                                                                                                                 M = M _ { 0 } \frac { \displaystyle { \cal I } m \left[ u \left( \frac { a _ { D } ^ { \prime \prime } } { a _ { D } ^ { \prime } } - \frac { a ^ { \prime \prime } } { a ^ { \prime } } \right) \tau \right] } { \displaystyle { \cal I } m \, t a u } \, .   102                                                                                                                             M = { M _ { 0 } { \frac { L } { 1 } } } { \frac { l u \left( u \left( \frac { u ^ { 2 } 0 } { a _ { T } } } - \frac { a ^ { \prime } } { c } \right) ^ { \prime } } { \begin{array} { c } { ( m _ { t } ^ { 2 } ) } { m _ { t } } } a ^ { t } - \mu ^ { 2 } } } \right] .
# 6f84ed434c08a95.png  6f84ed434c08a95_basic.png  14276  0.800000   40                                                                                                                                                                                                                           D \! \! \! / = \partial \! \! \! / + i \sqrt { \pi } \partial \! \! \! / \widetilde \eta + i \sqrt \pi \gamma _ { 5 } \partial \! \! \! / \sigma .    51                                                                                                                                                                                                                                    { \cal { H } } = { \dot { \partial } } + i \sqrt { \pi } { \widetilde { q } } { \widetilde { \eta } } + i \sqrt { \pi } { \gamma } _ { 5 } { \phi } { \partial } .
# ddaae7893e831d0.png  ddaae7893e831d0_basic.png  14277  0.808511   47                                                                                                                                                                                                        \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! { P \, \leftrightarrow \, - Q \, \, \, , \, \, \, \lambda \, \rightarrow \, - \lambda }    15                                                                                                                                                                                                                                                                                                                               P \; \leftrightarrow \; - Q \; \; , \; \; \lambda \rightarrow - \lambda
# 501cbe5f95065d1.png  501cbe5f95065d1_basic.png  14278  0.929204  113                                                       \left( \begin{matrix} { { \bf 1 } } & { 0 } \\ { { \tilde { \bf c } } } & { { \bf 1 } } \\ \end{matrix} \right) \qquad \qquad { \tilde { \bf c } } = \sum _ { i } N _ { i } g _ { i } ^ { t } { \tilde { \bf c } } ^ { v } g _ { i } + \sum _ { j } M _ { j } g _ { j } ^ { t } { \tilde { \bf c } } ^ { h } g _ { j }    15                                                                                                                                                                                                                                                                                                                                                              \Bigl ( { \bf \bar { c } } ~ ~ ~ \bf 1 )
# 306d0ca5d4cda21.png  306d0ca5d4cda21_basic.png  14279  1.000000   19                                                                                                                                                                                                                                                                                                                        \| B ( f ) \| \le \| f \| , \qquad f \in { \cal K } .    32                                                                                                                                                                                                                                                                                                                            \mid B ( f ) | _ { . } \leq | f | _ { 0 } , ~ ~ ~ ~ ~ ~ f \in { \cal K } .
#
# [14280 rows x 7 columns]

# %%
df_result
# Out:
#                     target_seq                                                                                                                                                                                                                                                                                                                                                             pred_seq                                                                                                                                                                                                                                                                                                                                                                                           score_pred  score_gold
# eval_image_name
# 8eb596be1210429.png                                                                                                                                                                                                                                                                                                     h ^ { a } ( \phi ) = \omega ^ { a b } \partial _ { b } H ( \phi )                                                                                                                                                                                                                                                                                                                                 h ^ { a } ( \phi ) = \omega ^ { a b } \partial _ { b } H ( \phi )   0           0
# 425391c19cc90e6.png                                                                                                                                               d s _ { 4 } ^ { 2 } = - f ( R ) \left( 1 - \frac { 2 m } { R } \right) d t ^ { 2 } + f ^ { - 1 } ( R ) \left[ \left( 1 - \frac { 2 m } { R } \right) ^ { - 1 } d R ^ { 2 } + R ^ { 2 } d \Omega _ { 2 } ^ { 2 } \right]                                                                                                                                                                           d s _ { 4 } ^ { 2 } = - f ( R ) \left( 1 - \frac { 2 m } { R } \right) d t ^ { 2 } + f ^ { - 1 } ( R ) \left[ \left( 1 - \frac { 2 m } { R } \right) ^ { - 1 } d R ^ { 2 } + R ^ { 2 } d \Omega _ { 2 } ^ { 2 } \right]   0           0
# 7a939f28e0fd64a.png                                                                                                                                               \left( \mu \frac { \partial } { \partial \mu } + \beta ^ { ( \alpha ) } \frac { \partial } { \partial \alpha } - \gamma _ { m } \, m \frac { \partial } { \partial m } \right) \, { \cal L } ( \alpha , m ; \mu ) = 0 .                                                                                                                                                                           \left( \mu \frac { \partial } { \partial \mu } + \beta ^ { ( \alpha ) } \frac { \partial } { \partial \alpha } - \gamma _ { m } \, m \frac { \partial } { \partial m } \right) \, { \cal L } ( \alpha , m ; \mu ) = 0 .   0           0
# a03ca65ad0186d6.png                                                                                                                                                                                                                                                                           W = 2 w \operatorname { c o s } \delta _ { 0 } \operatorname { e x p } ( i \delta _ { 0 } )                                                                                                                                                                                                                                                                                                       W = 2 w \operatorname { c o s } \delta _ { 0 } \operatorname { e x p } ( i \delta _ { 0 } )   0           0
# e4b4876c34c094d.png                                                                                                                                                                                                                                                                                 Q \equiv M _ { + } - M _ { - } = \frac { 1 } { 2 \pi } \int d x \partial _ { x } \phi                                                                                                                                                                                                                                                                                                             Q \equiv M _ { + } - M _ { - } = \frac { 1 } { 2 \pi } \int d x \partial _ { x } \phi   0           0
# 72b26b7d712937b.png                                                                                                                                                                                                                          \frac { q _ { 1 } ^ { 2 } } { \sigma _ { 3 } ^ { 2 } } + \frac { q _ { 2 } ^ { 2 } } { \sigma _ { 3 } ^ { 2 } - \sigma _ { 2 } ^ { 2 } } = 1                                                                                                                                                                                                                                                      \frac { q _ { 1 } ^ { 2 } } { \sigma _ { 3 } ^ { 2 } } + \frac { q _ { 2 } ^ { 2 } } { \sigma _ { 3 } ^ { 2 } - \sigma _ { 2 } ^ { 2 } } = 1   0           0
# 0a7747e7015c151.png                                                                                                                                                                                                                                                                                               \xi _ { R o b i n } ( \kappa ) = \xi _ { d a m p e d } ( \kappa / k ) .                                                                                                                                                                                                                                                                                                                           \xi _ { R o b i n } ( \kappa ) = \xi _ { d a m p e d } ( \kappa / k ) .   0           0
# 43afdc9657030d0.png                                                                                                                                                                                                                                                                                 \epsilon _ { a b c } \phi _ { b } ^ { m } \partial _ { c } ^ { m } \Gamma _ { i } = 0                                                                                                                                                                                                                                                                                                             \epsilon _ { a b c } \phi _ { b } ^ { m } \partial _ { c } ^ { m } \Gamma _ { i } = 0   0           0
# 385cc082a49793d.png                                                                                                                                           M _ { \eta ^ { \prime } } ^ { 2 } = \frac { 2 N _ { f } } { N _ { c } - N _ { f } } \left( \frac { 1 2 } { 1 1 } \right) ^ { 2 } \Lambda ^ { 2 } D \left( N _ { c } \right) ^ { \frac { 1 } { N _ { c } - N _ { f } } } \ .                                                                                                                                                                       M _ { \eta ^ { \prime } } ^ { 2 } = \frac { 2 N _ { f } } { N _ { c } - N _ { f } } \left( \frac { 1 2 } { 1 1 } \right) ^ { 2 } \Lambda ^ { 2 } D \left( N _ { c } \right) ^ { \frac { 1 } { N _ { c } - N _ { f } } } \ .   0           0
# b4f7b4f31eaf43d.png                                                                                                                                                                                                                                                                                              T _ { H } = T _ { H } ^ { H V } \, { \cal Z } _ { H V } ^ { f i n } \, ,                                                                                                                                                                                                                                                                                                                          T _ { H } = T _ { H } ^ { H V } \, { \cal Z } _ { H V } ^ { f i n } \, ,   0           0
# 480cf9d2543486b.png                                                                                                                                                                                                                                                                                 \mathrm { S y m } ^ { - 1 } ( \mathrm { S y m } ( f ) \cdot \mathrm { S y m } ( g ) )                                                                                                                                                                                                                                                                                                             \mathrm { S y m } ^ { - 1 } ( \mathrm { S y m } ( f ) \cdot \mathrm { S y m } ( g ) )   0           0
# 1d3f8f0cf2bf33a.png                                                                                                                                                                                                                                                                                   T _ { \mu \nu } = ( \varepsilon + p ) u _ { \mu } u _ { \nu } - p g _ { \mu \nu } .                                                                                                                                                                                                                                                                                                               T _ { \mu \nu } = ( \varepsilon + p ) u _ { \mu } u _ { \nu } - p g _ { \mu \nu } .   0           0
# 8dcb942f3c2f8ba.png                                                                                                                                                                                                                                                                                                 \hat { R } _ { 1 2 } ^ { 2 } - \lambda \hat { R } _ { 1 2 } - 1 = 0 ,                                                                                                                                                                                                                                                                                                                             \hat { R } _ { 1 2 } ^ { 2 } - \lambda \hat { R } _ { 1 2 } - 1 = 0 ,   0           0
# 093f9a19555ab13.png                                                                                                                                                                                                                                                                               \varphi _ { 0 } ( \tau ) = \frac { \varphi _ { B I } } { ( y \tau + 1 ) ^ { 3 / 1 0 } }                                                                                                                                                                                                                                                                                                           \varphi _ { 0 } ( \tau ) = \frac { \varphi _ { B I } } { ( y \tau + 1 ) ^ { 3 / 1 0 } }   0           0
# ca5509e36b9e7ec.png                                                                                                                                                       V = \alpha \frac { 2 } { R ( \xi + \eta ) } + \frac { 4 } { R ^ { 2 } ( \xi + \eta ) } \left[ c _ { 1 } \frac { 1 } { ( \xi + 1 ) ( 1 + \eta ) } + c _ { 2 } \frac { 1 } { ( \xi - 1 ) ( 1 - \eta ) } \right] .                                                                                                                                                                                   V = \alpha \frac { 2 } { R ( \xi + \eta ) } + \frac { 4 } { R ^ { 2 } ( \xi + \eta ) } \left[ c _ { 1 } \frac { 1 } { ( \xi + 1 ) ( 1 + \eta ) } + c _ { 2 } \frac { 1 } { ( \xi - 1 ) ( 1 - \eta ) } \right] .   0           0
# 2336f91f9ed6cf5.png                                                                                                                                                                                                                                                                \partial _ { \lambda } \partial ^ { \lambda } f ( r , t ) = \delta ( \vec { x } ) e ^ { - i \omega t }                                                                                                                                                                                                                                                                                            \partial _ { \lambda } \partial ^ { \lambda } f ( r , t ) = \delta ( \vec { x } ) e ^ { - i \omega t }   0           0
# 77bd90b9f72d503.png                                                                                                                                                                                                                                                                                         X ^ { ( 0 ) } = \Delta _ { B } ^ { 2 } \Delta _ { B } ^ { 1 } Y ^ { ( 2 ) } ,                                                                                                                                                                                                                                                                                                                     X ^ { ( 0 ) } = \Delta _ { B } ^ { 2 } \Delta _ { B } ^ { 1 } Y ^ { ( 2 ) } ,   0           0
# 0d0086add29ad32.png                                                                                                                                                                                                                                                                   \{ p ^ { \delta \omega } , q ^ { \delta \omega } \} = \{ p , q \} + O ( \delta \omega ^ { 2 } ) \ .                                                                                                                                                                                                                                                                                               \{ p ^ { \delta \omega } , q ^ { \delta \omega } \} = \{ p , q \} + O ( \delta \omega ^ { 2 } ) \ .   0           0
# 26bfd708f2258b1.png                                                                                                                                                                                                                                      K _ { 1 } = 3 C _ { 1 } ^ { 2 } + 2 C _ { 1 } C _ { 2 } \approx - 0 . 3 9 \qquad K _ { 2 } = C _ { 2 } ^ { 2 } \approx 1 . 2 5 .                                                                                                                                                                                                                                                                  K _ { 1 } = 3 C _ { 1 } ^ { 2 } + 2 C _ { 1 } C _ { 2 } \approx - 0 . 3 9 \qquad K _ { 2 } = C _ { 2 } ^ { 2 } \approx 1 . 2 5 .   0           0
# 820736c6ea45c37.png                                                                                                                                                                                                                                                                                \Phi = b ^ { * } \frac { 1 } { \sqrt { N + 1 } } + \frac { 1 } { \sqrt { N + 1 } } b .                                                                                                                                                                                                                                                                                                            \Phi = b ^ { * } \frac { 1 } { \sqrt { N + 1 } } + \frac { 1 } { \sqrt { N + 1 } } b .   0           0
# 4f2a0966454c21a.png                                                                                                                                                                                                                                                                                                                          \chi \equiv \partial _ { i } \pi _ { i } + n                                                                                                                                                                                                                                                                                                                                                      \chi \equiv \partial _ { i } \pi _ { i } + n   0           0
# 7b5ea8da87833e6.png                                                                                                                                                                                                                                                                                          \Delta = \prod _ { l < n } ^ { 2 g + 1 } ( e _ { l } - e _ { n } ) ^ { 2 } .                                                                                                                                                                                                                                                                                                                      \Delta = \prod _ { l < n } ^ { 2 g + 1 } ( e _ { l } - e _ { n } ) ^ { 2 } .   0           0
# 2121eee1775d400.png                                                                                                                                                                                                                                            F ^ { + } { } _ { a + } = - F ^ { - } { } _ { a - } , \qquad Q ^ { \pm + } { } _ { a + } = - Q ^ { \pm - } { } _ { a - } .                                                                                                                                                                                                                                                                        F ^ { + } { } _ { a + } = - F ^ { - } { } _ { a - } , \qquad Q ^ { \pm + } { } _ { a + } = - Q ^ { \pm - } { } _ { a - } .   0           0
# 62cbf6b34e3c488.png                                                                                                                                                                                                                                                            \Delta = c _ { 2 } \gamma ( \alpha ) - c _ { 1 } \alpha \gamma ^ { \prime } ( \alpha ) \gamma ( \alpha ) .                                                                                                                                                                                                                                                                                        \Delta = c _ { 2 } \gamma ( \alpha ) - c _ { 1 } \alpha \gamma ^ { \prime } ( \alpha ) \gamma ( \alpha ) .   0           0
# 7bd21384615a543.png                                                                                                                                                                                                                                                                                               B ( u , s ) = \sum _ { n = 0 } ^ { \infty } c _ { n } w ^ { n } ( u ) ,                                                                                                                                                                                                                                                                                                                           B ( u , s ) = \sum _ { n = 0 } ^ { \infty } c _ { n } w ^ { n } ( u ) ,   0           0
# ...                                                                                                                                                                                                                                                                                                                                                                                    ...                                                                                                                                                                                                                                                                                                                                                                                               ...         ...         ...
# bacc8145ae89673.png                                                                                                                                                                                                                                                     \frac 1 2 \left| \left( u d - d u \right) \times \left( \uparrow \downarrow - \downarrow \uparrow \right) \right>                                                                                                                                                                                                                                                                                                                  \frac { 1 } { 2 } \left| ( u d - d u ) \times ( \uparrow + - 1 | \rangle \rangle   0           0
# c14e7b0c5ce1557.png                  \overline { { M } } _ { \mathrm { q } } \; = \; \left( \begin{matrix} { E _ { \mathrm { q } } } & { | D _ { \mathrm { q } } | } & { { \bf 0 } } \\ { | D _ { \mathrm { q } } | } & { C _ { \mathrm { q } } } & { | B _ { \mathrm { q } } | } \\ { { \bf 0 } } & { | B _ { \mathrm { q } } | } & { A _ { \mathrm { q } } } \\ \end{matrix} \right) \;                                                                                                                                                                                         \overline { { M } } _ { \mathrm { q } } \; = \; \left( \vert D _ { \mathrm { q l } } \vert \quad C _ { { \mathrm { G } } _ { 0 } } \vert ^ { 2 } \left| B _ { { \mathrm { c } } } \right| \right) ^ { s }   0           0
# 614cd51f7ba7b99.png                                                                          \left\{ \begin{array} { c c c } { a } & { b } & { i } \\ { c } & { d } & { j } \\ \end{array} \right\} = \frac { T e t \left[ \begin{array} { c c c } { a } & { b } & { i } \\ { c } & { d } & { j } \\ \end{array} \right] \Delta _ { i } } { \theta ( a , d , i ) \theta ( b , c , i ) } .                                                                                \left\{ \begin{array} { l c l } { a } & { i } \\ { a } & { b } & { i } \\ { b } & { i } & { { \bf 1 } } \\ \end{array} \right\} _ { j } = \frac { T e t \left[ ~ c _ { i } } & { d } & { i } \\ { \underline { { a } } [ \mu , d ) } & { d } & { j } \\ \end{array} { d } & { d } & { j } \\ \end{array} \right) .   0           0
# a4886ea1118abce.png                                                                                                                                                                                                                                                           \hat { \tau } = \tau + \int ^ { \sigma } A \; d \sigma , \; \; \; \; \; \; \; \; \hat { \sigma } = \sigma ,                                                                                                                                                                                                                                                                                                                                                      \hat { \tau } = \tau + \int \ A \ d \sigma ,   0           0
# 585581d2895f53c.png                                                                                                                            \begin{array} { l } { \chi ^ { \ ( + ) } \ ( \ 0 \ ) \ = \ 4 \ n _ { \ f l } ^ { \ 2 } \ \left\langle \ \Omega \ \right| \ \left( \ - \ m _ { \ Q } \ \overline { { Q } } \ Q \ \right) \ \left| \ \Omega \ \right\rangle } \\ \end{array}                                                                                                                                                                                                    \chi ^ { \left( + + } \left( 0 \right) \, = \, 4 \, n _ { \, f t } ^ { 2 } \; \; \langle \; \Omega \mid \; ( \; - \; m \; \alpha \; \overline { { Q } } \; Q \; ) \; \mid \; \Omega \; \rangle   0           0
# 0f2d21ddbe8e50a.png                                                u _ { i 1 } = \left( \begin{matrix} { - \frac { 1 } { 2 4 } ( 1 + \sqrt { 5 } ) } \\ { \frac { \sqrt { 5 } } { 6 } } \\ { 1 } \\ \end{matrix} \right) , \qquad u _ { i 2 } = \left( \begin{matrix} { \frac { 1 } { 2 4 } ( \sqrt { 5 } - 1 ) } \\ { - \frac { \sqrt { 5 } } { 6 } } \\ { 1 } \\ \end{matrix} \right) .   u _ { i 1 } = \left( \begin{array} { c c c } { \frac { 1 } { 2 4 } ( \frac { 1 } { 5 } \sqrt { 5 } ) } \\ { } & { } \\ { \frac { 1 } { \sqrt { 3 } } } & { } \\ \end{array} \right) , \ \ \ \ \ \ u _ { i 2 } = \left( \begin{array} { c l } { \frac { 1 4 } { 4 } ( \sqrt { \frac { 1 } { 5 } } } \\ { \frac { 1 } { \sqrt { 2 } } } \\ { } & { \frac { 1 } { 3 } } \\ \end{array} \right) } .   0           0
# 9047c7ede6b4cbc.png                                                                                                                                                                                                                                             \left. { \left| { 3 3 { \left[ { 4 2 } \right] } _ { O } { \left[ { 3 3 } \right] } _ { F S } } \right. } \right\rangle \                                                                                                                                                                                                                                                                                                                                            | 3 3 [ 4 2 _ { ( O } ^ { \gamma } [ 3 3 ] _ { F S } )   0           0
# 61b113233b6c49e.png                                                                                                     \begin{array} { c } { D ^ { B } H ^ { A } = 0 , \qquad \qquad D ^ { B } D ^ { A } \Phi _ { A } = [ H ^ { A } , \Phi _ { B } ] , } \\ { D ^ { A } K ^ { B } = 0 , \qquad \qquad D ^ { A } D ^ { B } \Phi _ { B } = [ K ^ { B } , \Phi _ { A } ] . } \\ \end{array}                                                                                                                                                                                                                                                                                                 \begin{array} { l } { D ^ { B } H ^ { A } = 0 , } \\ { D ^ { A } K ^ { B } = 0 , } \\ \end{array}   0           0
# 360f14cc7f0f20f.png                                                                                                                                                                                                                                                                                               ( \eta - \beta ) + ( \eta - \gamma ) = \alpha , \ \textrm { e t c . , }                                                                                                                                                                                                                                                                                 ( \eta - \beta ) + ( \eta - \gamma ) = \alpha , { \mathrm { \boldmath ~ e ~ } } \mathrm { \boldmath ~ c ~ } . \ ,   0           0
# 1ccc1eab4e659f5.png                                                                                                                                                                                                 \mathrm { U V } \ ( g = 0 ) : \qquad \Sigma _ { N } \otimes \Psi _ { r N } \ ; \qquad \qquad \qquad \mathrm { I R \ } ( g = 1 ) : \qquad \Sigma _ { N ( 1 + r ) } \ ;                                                                                                                                                                                                                                                 \mathrm { U V } ~ ( g = 0 ) : ~ ~ ~ ~ ~ ~ \Sigma _ { N } \otimes \Psi _ { r N } ~ ; ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ \mathrm { I R } ~ ( g = 1 ) :   0           0
# fdc7c7aec9443cc.png  S _ { 1 ^ { j } } ( z ) = \sum _ { { \scriptstyle k _ { 1 } + 2 k _ { 2 } + \cdots + m k _ { m } = j } \atop { \scriptstyle k _ { 1 } \geq 0 , \cdots , k _ { m } \geq 0 } } ( - 1 ) ^ { k _ { 2 } + k _ { 4 } + \cdots + k _ { 2 \left[ \frac m 2 \right] } } \frac 1 { k _ { 1 } ! \cdots k _ { m } ! } z _ { 1 } ^ { k _ { 1 } } \cdots z _ { m } ^ { k _ { m } }                                                                                                                               \begin{array} { r c l } { f _ { I _ { j } } ( z ) = } & { i } & { ( - 1 ) ^ { k _ { j } + k _ { 4 } + \cdots + k _ { 2 } ( \frac { x _ { 1 } } { 2 } ) } \frac { 1 } { K _ { j } - k _ { n } ] } \\ { ~ } & { + } & { l _ { 2 } \ldots p _ { n } | } \\ \end{array}   0           0
# cdeddf2181be187.png                                                                                                                                                                                                                                                                                                                     { \tilde { l } } { \tilde { l } } \rightarrow l l                                                                                                                                                                                                                                                                                                                                                                \widetilde { l } \Pi \rightarrow l   0           0
# ca659bc0b1ffbfd.png                                                             \begin{array} { c } { C _ { 2 } = \frac 1 2 L _ { A B } L ^ { A B } = E _ { o } ( E _ { o } + 3 ) + s ( s + 1 ) } \\ { C _ { 4 } = W _ { A } W ^ { A } = - s ( s + 1 ) ( E _ { o } - 1 ) ( E _ { o } - 2 ) } \\ { W _ { A } = \frac 1 8 \epsilon _ { A B C D E } L ^ { B C } L ^ { D E } } \\ \end{array}                                                                                                                                                                                                                                                                C _ { 4 } = W _ { A } W _ { V } ^ { A A } = - s ( s , + 1 ) _ { F } ( E _ { c } - 1 ) ^ { c } ( 1 ) \bar { c } _ { o } - 2 \right)   0           0
# 26b64336b324203.png                                                                                                                                                                                                      \cal { A } _ { l } ( E , \vec { p } ) = \frac { 2 E \gamma } { \pi } \frac { 1 } { ( E ^ { 2 } - \Omega _ { p } ^ { 2 } ) ^ { 2 } + 4 E ^ { 2 } \gamma ^ { 2 } }                                                                                                                      { \cal A } _ { \zeta } ( { \cal E } , \sqrt { \gamma ^ { \prime } } ) = \frac { \varepsilon { \cal F } } { \pi } _ { \quad } \frac { 1 } { ( { \cal E } ^ { - } - \otimes ^ { Q _ { S } } ) ^ { \epsilon } + \triangle \Delta { \cal E } ^ { \epsilon _ { \tau } } \rangle }   0           0
# e5e649488182854.png                                                                                                                                 \begin{array} { l } { \displaystyle \frac { 1 } { 1 + q ^ { 2 n - 1 } } C _ { i j } x ^ { i } x ^ { j } = - \frac { 1 } { a ^ { 2 } } ~ , } \\ { { \overline { x } ^ { i } } = C _ { j i } M _ { j k } x ^ { k } ~ , } \\ \end{array}                                                                                                                                                                                                                              \frac { 1 } { 1 _ { + } ^ { + } + q ^ { 2 } } _ { I - 1 } ^ { - 1 } C _ { i j } x ^ { k } \, , \, \, \, \, \, \, \, \, \, \, \, \, \frac { 1 } { a ^ { 2 } } \, \, ,   0           0
# e21424ad0a22dfd.png                                                                                                                                                                                                                                      h ^ { 8 } = [ \begin{array} { c c c c c c c c } { 0 } & { 1 } & { 1 } & { 2 } & { 0 } & { 2 } & { 2 } & { 1 } \\ \end{array} ] ,                                                                                                                                                                                                                                                                                                                            h ^ { 8 } = \left[ \ 0 \ \ 1 \ \ 1 \ \ 2 \ \ 0 \ \ 2 \ \ 2 \ \ 1 \ ] ,   0           0
# e9a3cbb4e6c1658.png                                                                                                                                                                                                     E _ { r + 1 } \, \supset \, K _ { r + 1 } ^ { 0 } \, \supset \, K _ { r + 1 } ^ { 1 } \, \supset \, \dots \, \supset \, K _ { r + 1 } ^ { i } \, \supset \, \dots                                                                                                                                            E _ { r + 1 } \stackrel { - } { \rightarrow } K _ { r + 1 } ^ { 0 } \stackrel { - } { \rightarrow } K _ { r + 1 } ^ { 1 } \stackrel { - } { \rightarrow } \cdots \stackrel { - } { \rightarrow } \stackrel { N } { K } _ { r + 1 } ^ { i } \; > \; . .   0           0
# 93c2d38bafe2efb.png                                                                                                                                                                                                                                                                     \varpi \varpi ^ { \bullet \bullet } - ( \varpi ^ { \bullet } ) ^ { 2 } = 2 \Lambda \varpi ^ { 3 }                                                                                                                                                                                                                                                                                                  { \bf z } { \bf \omega } ^ { * } } - ( { \bf x } ^ { * } ) ^ { 2 } = 2 \Lambda { \bf e } ^ { 3 }   0           0
# fd5732e726ecbdf.png                                                                                                        n ^ { 2 } ( x ^ { \perp } , t ) = \frac { C ^ { 2 } } { 4 t ^ { 2 } } \frac { \left( 4 t ^ { 2 } - { x ^ { \perp } } ^ { 2 } \right) ^ { 2 } } { C ^ { 2 } { x ^ { \perp } } ^ { 2 } + 4 \sqrt { C ^ { 4 } - 4 I } x ^ { \perp } t + 4 C ^ { 2 } t ^ { 2 } } .                                                                                             \begin{array} { c c c c c c c c c } { } & { } & { } & { } & { } & { n ^ { 2 } ( x ^ { + } , t ) = \frac { C ^ { 2 } } { 4 } d ^ { 2 } \frac { } { } \left( \frac { 1 } { q ^ { 2 } } - \frac { 1 } { q } + ( \frac { 1 } { \sqrt { q ^ { 2 } } / Q ^ { 2 } + 4 H ^ { 2 } } } } \\ \end{array} \right)   0           0
# b663d762e435a09.png                                       \begin{array} { r l c } { G _ { B - L } : H ^ { ( 1 ) } ( 1 ) , H ^ { ( 2 ) } ( 1 ) , L ( - 1 ) , E ^ { c } ( 0 ) , } \\ { Q ( - 1 ) , U ^ { c } ( 0 ) , D ^ { c } ( 0 ) , S ( 0 ) , \phi ( 0 ) , \bar { \phi } ( 0 ) , ~ } \\ { N ( - 1 ) , \bar { N } ( 1 ) , T ( 2 ) , \bar { T } ( - 2 ) ; ~ ~ ~ ~ ~ ~ ~ ~ } \\ \end{array}                                                                                                                                                                                                                                                                                             Q ( - 1 ) , U ^ { c } ( 0 ) , D ^ { T } ( 0 ) , S ( 0 ) , \phi ( 0 ) , \overline { { \phi } } ( 0 ) ,   0           0
# 86c7e6e54cf188f.png                                                                                                          M = M _ { 0 } \frac { \displaystyle { \cal I } m \left[ u \left( \frac { a _ { D } ^ { \prime \prime } } { a _ { D } ^ { \prime } } - \frac { a ^ { \prime \prime } } { a ^ { \prime } } \right) \tau \right] } { \displaystyle { \cal I } m \, t a u } \, .                                                                                                                         M = { M _ { 0 } { \frac { L } { 1 } } } { \frac { l u \left( u \left( \frac { u ^ { 2 } 0 } { a _ { T } } } - \frac { a ^ { \prime } } { c } \right) ^ { \prime } } { \begin{array} { c } { ( m _ { t } ^ { 2 } ) } { m _ { t } } } a ^ { t } - \mu ^ { 2 } } } \right] .   0           0
# 6f84ed434c08a95.png                                                                                                                                                                                                                    D \! \! \! / = \partial \! \! \! / + i \sqrt { \pi } \partial \! \! \! / \widetilde \eta + i \sqrt \pi \gamma _ { 5 } \partial \! \! \! / \sigma .                                                                                                                                                                                                                                { \cal { H } } = { \dot { \partial } } + i \sqrt { \pi } { \widetilde { q } } { \widetilde { \eta } } + i \sqrt { \pi } { \gamma } _ { 5 } { \phi } { \partial } .   0           0
# ddaae7893e831d0.png                                                                                                                                                                                                 \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! { P \, \leftrightarrow \, - Q \, \, \, , \, \, \, \lambda \, \rightarrow \, - \lambda }                                                                                                                                                                                                                                                                                                                           P \; \leftrightarrow \; - Q \; \; , \; \; \lambda \rightarrow - \lambda   0           0
# 501cbe5f95065d1.png                                                \left( \begin{matrix} { { \bf 1 } } & { 0 } \\ { { \tilde { \bf c } } } & { { \bf 1 } } \\ \end{matrix} \right) \qquad \qquad { \tilde { \bf c } } = \sum _ { i } N _ { i } g _ { i } ^ { t } { \tilde { \bf c } } ^ { v } g _ { i } + \sum _ { j } M _ { j } g _ { j } ^ { t } { \tilde { \bf c } } ^ { h } g _ { j }                                                                                                                                                                                                                                                                                                                                                          \Bigl ( { \bf \bar { c } } ~ ~ ~ \bf 1 )   0           0
# 306d0ca5d4cda21.png                                                                                                                                                                                                                                                                                                                 \| B ( f ) \| \le \| f \| , \qquad f \in { \cal K } .                                                                                                                                                                                                                                                                                                                        \mid B ( f ) | _ { . } \leq | f | _ { 0 } , ~ ~ ~ ~ ~ ~ f \in { \cal K } .   0           0
#
# [14280 rows x 4 columns]

# %%
df_data
# Out:
#                      iloc
# eval_image_name
# 8eb596be1210429.png      0
# 425391c19cc90e6.png      1
# 7a939f28e0fd64a.png      2
# a03ca65ad0186d6.png      3
# e4b4876c34c094d.png      4
# 72b26b7d712937b.png      5
# 0a7747e7015c151.png      6
# 43afdc9657030d0.png      7
# 385cc082a49793d.png      8
# b4f7b4f31eaf43d.png      9
# 480cf9d2543486b.png     10
# 1d3f8f0cf2bf33a.png     11
# 8dcb942f3c2f8ba.png     12
# 093f9a19555ab13.png     13
# ca5509e36b9e7ec.png     14
# 2336f91f9ed6cf5.png     15
# 77bd90b9f72d503.png     16
# 0d0086add29ad32.png     17
# 26bfd708f2258b1.png     18
# 820736c6ea45c37.png     19
# 4f2a0966454c21a.png     20
# 7b5ea8da87833e6.png     21
# 2121eee1775d400.png     22
# 62cbf6b34e3c488.png     23
# 7bd21384615a543.png     24
# ...                    ...
# bacc8145ae89673.png  14255
# c14e7b0c5ce1557.png  14256
# 614cd51f7ba7b99.png  14257
# a4886ea1118abce.png  14258
# 585581d2895f53c.png  14259
# 0f2d21ddbe8e50a.png  14260
# 9047c7ede6b4cbc.png  14261
# 61b113233b6c49e.png  14262
# 360f14cc7f0f20f.png  14263
# 1ccc1eab4e659f5.png  14264
# fdc7c7aec9443cc.png  14265
# cdeddf2181be187.png  14266
# ca659bc0b1ffbfd.png  14267
# 26b64336b324203.png  14268
# e5e649488182854.png  14269
# e21424ad0a22dfd.png  14270
# e9a3cbb4e6c1658.png  14271
# 93c2d38bafe2efb.png  14272
# fd5732e726ecbdf.png  14273
# b663d762e435a09.png  14274
# 86c7e6e54cf188f.png  14275
# 6f84ed434c08a95.png  14276
# ddaae7893e831d0.png  14277
# 501cbe5f95065d1.png  14278
# 306d0ca5d4cda21.png  14279
#
# [14280 rows x 1 columns]

# %%
sr_label
# Out:
# eval_image_name
# 8eb596be1210429.png                                                                                                                                                                                                                                                                                                       h ^ { a } ( \phi ) = \omega ^ { a b } \partial _ { b } H ( \phi )
# 425391c19cc90e6.png                                                                                                                                                 d s _ { 4 } ^ { 2 } = - f ( R ) \left( 1 - \frac { 2 m } { R } \right) d t ^ { 2 } + f ^ { - 1 } ( R ) \left[ \left( 1 - \frac { 2 m } { R } \right) ^ { - 1 } d R ^ { 2 } + R ^ { 2 } d \Omega _ { 2 } ^ { 2 } \right]
# 7a939f28e0fd64a.png                                                                                                                                                 \left( \mu \frac { \partial } { \partial \mu } + \beta ^ { ( \alpha ) } \frac { \partial } { \partial \alpha } - \gamma _ { m } \, m \frac { \partial } { \partial m } \right) \, { \cal L } ( \alpha , m ; \mu ) = 0 .
# a03ca65ad0186d6.png                                                                                                                                                                                                                                                                             W = 2 w \operatorname { c o s } \delta _ { 0 } \operatorname { e x p } ( i \delta _ { 0 } )
# e4b4876c34c094d.png                                                                                                                                                                                                                                                                                   Q \equiv M _ { + } - M _ { - } = \frac { 1 } { 2 \pi } \int d x \partial _ { x } \phi
# 72b26b7d712937b.png                                                                                                                                                                                                                            \frac { q _ { 1 } ^ { 2 } } { \sigma _ { 3 } ^ { 2 } } + \frac { q _ { 2 } ^ { 2 } } { \sigma _ { 3 } ^ { 2 } - \sigma _ { 2 } ^ { 2 } } = 1
# 0a7747e7015c151.png                                                                                                                                                                                                                                                                                                 \xi _ { R o b i n } ( \kappa ) = \xi _ { d a m p e d } ( \kappa / k ) .
# 43afdc9657030d0.png                                                                                                                                                                                                                                                                                   \epsilon _ { a b c } \phi _ { b } ^ { m } \partial _ { c } ^ { m } \Gamma _ { i } = 0
# 385cc082a49793d.png                                                                                                                                             M _ { \eta ^ { \prime } } ^ { 2 } = \frac { 2 N _ { f } } { N _ { c } - N _ { f } } \left( \frac { 1 2 } { 1 1 } \right) ^ { 2 } \Lambda ^ { 2 } D \left( N _ { c } \right) ^ { \frac { 1 } { N _ { c } - N _ { f } } } \ .
# b4f7b4f31eaf43d.png                                                                                                                                                                                                                                                                                                T _ { H } = T _ { H } ^ { H V } \, { \cal Z } _ { H V } ^ { f i n } \, ,
# 480cf9d2543486b.png                                                                                                                                                                                                                                                                                   \mathrm { S y m } ^ { - 1 } ( \mathrm { S y m } ( f ) \cdot \mathrm { S y m } ( g ) )
# 1d3f8f0cf2bf33a.png                                                                                                                                                                                                                                                                                     T _ { \mu \nu } = ( \varepsilon + p ) u _ { \mu } u _ { \nu } - p g _ { \mu \nu } .
# 8dcb942f3c2f8ba.png                                                                                                                                                                                                                                                                                                   \hat { R } _ { 1 2 } ^ { 2 } - \lambda \hat { R } _ { 1 2 } - 1 = 0 ,
# 093f9a19555ab13.png                                                                                                                                                                                                                                                                                 \varphi _ { 0 } ( \tau ) = \frac { \varphi _ { B I } } { ( y \tau + 1 ) ^ { 3 / 1 0 } }
# ca5509e36b9e7ec.png                                                                                                                                                         V = \alpha \frac { 2 } { R ( \xi + \eta ) } + \frac { 4 } { R ^ { 2 } ( \xi + \eta ) } \left[ c _ { 1 } \frac { 1 } { ( \xi + 1 ) ( 1 + \eta ) } + c _ { 2 } \frac { 1 } { ( \xi - 1 ) ( 1 - \eta ) } \right] .
# 2336f91f9ed6cf5.png                                                                                                                                                                                                                                                                  \partial _ { \lambda } \partial ^ { \lambda } f ( r , t ) = \delta ( \vec { x } ) e ^ { - i \omega t }
# 77bd90b9f72d503.png                                                                                                                                                                                                                                                                                           X ^ { ( 0 ) } = \Delta _ { B } ^ { 2 } \Delta _ { B } ^ { 1 } Y ^ { ( 2 ) } ,
# 0d0086add29ad32.png                                                                                                                                                                                                                                                                     \{ p ^ { \delta \omega } , q ^ { \delta \omega } \} = \{ p , q \} + O ( \delta \omega ^ { 2 } ) \ .
# 26bfd708f2258b1.png                                                                                                                                                                                                                                        K _ { 1 } = 3 C _ { 1 } ^ { 2 } + 2 C _ { 1 } C _ { 2 } \approx - 0 . 3 9 \qquad K _ { 2 } = C _ { 2 } ^ { 2 } \approx 1 . 2 5 .
# 820736c6ea45c37.png                                                                                                                                                                                                                                                                                  \Phi = b ^ { * } \frac { 1 } { \sqrt { N + 1 } } + \frac { 1 } { \sqrt { N + 1 } } b .
# 4f2a0966454c21a.png                                                                                                                                                                                                                                                                                                                            \chi \equiv \partial _ { i } \pi _ { i } + n
# 7b5ea8da87833e6.png                                                                                                                                                                                                                                                                                            \Delta = \prod _ { l < n } ^ { 2 g + 1 } ( e _ { l } - e _ { n } ) ^ { 2 } .
# 2121eee1775d400.png                                                                                                                                                                                                                                              F ^ { + } { } _ { a + } = - F ^ { - } { } _ { a - } , \qquad Q ^ { \pm + } { } _ { a + } = - Q ^ { \pm - } { } _ { a - } .
# 62cbf6b34e3c488.png                                                                                                                                                                                                                                                              \Delta = c _ { 2 } \gamma ( \alpha ) - c _ { 1 } \alpha \gamma ^ { \prime } ( \alpha ) \gamma ( \alpha ) .
# 7bd21384615a543.png                                                                                                                                                                                                                                                                                                 B ( u , s ) = \sum _ { n = 0 } ^ { \infty } c _ { n } w ^ { n } ( u ) ,
#                                                                                                                                                                                                        ...
# bacc8145ae89673.png                                                                                                                                                                                                                                                       \frac 1 2 \left| \left( u d - d u \right) \times \left( \uparrow \downarrow - \downarrow \uparrow \right) \right>
# c14e7b0c5ce1557.png                    \overline { { M } } _ { \mathrm { q } } \; = \; \left( \begin{matrix} { E _ { \mathrm { q } } } & { | D _ { \mathrm { q } } | } & { { \bf 0 } } \\ { | D _ { \mathrm { q } } | } & { C _ { \mathrm { q } } } & { | B _ { \mathrm { q } } | } \\ { { \bf 0 } } & { | B _ { \mathrm { q } } | } & { A _ { \mathrm { q } } } \\ \end{matrix} \right) \;
# 614cd51f7ba7b99.png                                                                            \left\{ \begin{array} { c c c } { a } & { b } & { i } \\ { c } & { d } & { j } \\ \end{array} \right\} = \frac { T e t \left[ \begin{array} { c c c } { a } & { b } & { i } \\ { c } & { d } & { j } \\ \end{array} \right] \Delta _ { i } } { \theta ( a , d , i ) \theta ( b , c , i ) } .
# a4886ea1118abce.png                                                                                                                                                                                                                                                             \hat { \tau } = \tau + \int ^ { \sigma } A \; d \sigma , \; \; \; \; \; \; \; \; \hat { \sigma } = \sigma ,
# 585581d2895f53c.png                                                                                                                              \begin{array} { l } { \chi ^ { \ ( + ) } \ ( \ 0 \ ) \ = \ 4 \ n _ { \ f l } ^ { \ 2 } \ \left\langle \ \Omega \ \right| \ \left( \ - \ m _ { \ Q } \ \overline { { Q } } \ Q \ \right) \ \left| \ \Omega \ \right\rangle } \\ \end{array}
# 0f2d21ddbe8e50a.png                                                  u _ { i 1 } = \left( \begin{matrix} { - \frac { 1 } { 2 4 } ( 1 + \sqrt { 5 } ) } \\ { \frac { \sqrt { 5 } } { 6 } } \\ { 1 } \\ \end{matrix} \right) , \qquad u _ { i 2 } = \left( \begin{matrix} { \frac { 1 } { 2 4 } ( \sqrt { 5 } - 1 ) } \\ { - \frac { \sqrt { 5 } } { 6 } } \\ { 1 } \\ \end{matrix} \right) .
# 9047c7ede6b4cbc.png                                                                                                                                                                                                                                               \left. { \left| { 3 3 { \left[ { 4 2 } \right] } _ { O } { \left[ { 3 3 } \right] } _ { F S } } \right. } \right\rangle \
# 61b113233b6c49e.png                                                                                                       \begin{array} { c } { D ^ { B } H ^ { A } = 0 , \qquad \qquad D ^ { B } D ^ { A } \Phi _ { A } = [ H ^ { A } , \Phi _ { B } ] , } \\ { D ^ { A } K ^ { B } = 0 , \qquad \qquad D ^ { A } D ^ { B } \Phi _ { B } = [ K ^ { B } , \Phi _ { A } ] . } \\ \end{array}
# 360f14cc7f0f20f.png                                                                                                                                                                                                                                                                                                 ( \eta - \beta ) + ( \eta - \gamma ) = \alpha , \ \textrm { e t c . , }
# 1ccc1eab4e659f5.png                                                                                                                                                                                                   \mathrm { U V } \ ( g = 0 ) : \qquad \Sigma _ { N } \otimes \Psi _ { r N } \ ; \qquad \qquad \qquad \mathrm { I R \ } ( g = 1 ) : \qquad \Sigma _ { N ( 1 + r ) } \ ;
# fdc7c7aec9443cc.png    S _ { 1 ^ { j } } ( z ) = \sum _ { { \scriptstyle k _ { 1 } + 2 k _ { 2 } + \cdots + m k _ { m } = j } \atop { \scriptstyle k _ { 1 } \geq 0 , \cdots , k _ { m } \geq 0 } } ( - 1 ) ^ { k _ { 2 } + k _ { 4 } + \cdots + k _ { 2 \left[ \frac m 2 \right] } } \frac 1 { k _ { 1 } ! \cdots k _ { m } ! } z _ { 1 } ^ { k _ { 1 } } \cdots z _ { m } ^ { k _ { m } }
# cdeddf2181be187.png                                                                                                                                                                                                                                                                                                                       { \tilde { l } } { \tilde { l } } \rightarrow l l
# ca659bc0b1ffbfd.png                                                               \begin{array} { c } { C _ { 2 } = \frac 1 2 L _ { A B } L ^ { A B } = E _ { o } ( E _ { o } + 3 ) + s ( s + 1 ) } \\ { C _ { 4 } = W _ { A } W ^ { A } = - s ( s + 1 ) ( E _ { o } - 1 ) ( E _ { o } - 2 ) } \\ { W _ { A } = \frac 1 8 \epsilon _ { A B C D E } L ^ { B C } L ^ { D E } } \\ \end{array}
# 26b64336b324203.png                                                                                                                                                                                                        \cal { A } _ { l } ( E , \vec { p } ) = \frac { 2 E \gamma } { \pi } \frac { 1 } { ( E ^ { 2 } - \Omega _ { p } ^ { 2 } ) ^ { 2 } + 4 E ^ { 2 } \gamma ^ { 2 } }
# e5e649488182854.png                                                                                                                                   \begin{array} { l } { \displaystyle \frac { 1 } { 1 + q ^ { 2 n - 1 } } C _ { i j } x ^ { i } x ^ { j } = - \frac { 1 } { a ^ { 2 } } ~ , } \\ { { \overline { x } ^ { i } } = C _ { j i } M _ { j k } x ^ { k } ~ , } \\ \end{array}
# e21424ad0a22dfd.png                                                                                                                                                                                                                                        h ^ { 8 } = [ \begin{array} { c c c c c c c c } { 0 } & { 1 } & { 1 } & { 2 } & { 0 } & { 2 } & { 2 } & { 1 } \\ \end{array} ] ,
# e9a3cbb4e6c1658.png                                                                                                                                                                                                       E _ { r + 1 } \, \supset \, K _ { r + 1 } ^ { 0 } \, \supset \, K _ { r + 1 } ^ { 1 } \, \supset \, \dots \, \supset \, K _ { r + 1 } ^ { i } \, \supset \, \dots
# 93c2d38bafe2efb.png                                                                                                                                                                                                                                                                       \varpi \varpi ^ { \bullet \bullet } - ( \varpi ^ { \bullet } ) ^ { 2 } = 2 \Lambda \varpi ^ { 3 }
# fd5732e726ecbdf.png                                                                                                          n ^ { 2 } ( x ^ { \perp } , t ) = \frac { C ^ { 2 } } { 4 t ^ { 2 } } \frac { \left( 4 t ^ { 2 } - { x ^ { \perp } } ^ { 2 } \right) ^ { 2 } } { C ^ { 2 } { x ^ { \perp } } ^ { 2 } + 4 \sqrt { C ^ { 4 } - 4 I } x ^ { \perp } t + 4 C ^ { 2 } t ^ { 2 } } .
# b663d762e435a09.png                                         \begin{array} { r l c } { G _ { B - L } : H ^ { ( 1 ) } ( 1 ) , H ^ { ( 2 ) } ( 1 ) , L ( - 1 ) , E ^ { c } ( 0 ) , } \\ { Q ( - 1 ) , U ^ { c } ( 0 ) , D ^ { c } ( 0 ) , S ( 0 ) , \phi ( 0 ) , \bar { \phi } ( 0 ) , ~ } \\ { N ( - 1 ) , \bar { N } ( 1 ) , T ( 2 ) , \bar { T } ( - 2 ) ; ~ ~ ~ ~ ~ ~ ~ ~ } \\ \end{array}
# 86c7e6e54cf188f.png                                                                                                            M = M _ { 0 } \frac { \displaystyle { \cal I } m \left[ u \left( \frac { a _ { D } ^ { \prime \prime } } { a _ { D } ^ { \prime } } - \frac { a ^ { \prime \prime } } { a ^ { \prime } } \right) \tau \right] } { \displaystyle { \cal I } m \, t a u } \, .
# 6f84ed434c08a95.png                                                                                                                                                                                                                      D \! \! \! / = \partial \! \! \! / + i \sqrt { \pi } \partial \! \! \! / \widetilde \eta + i \sqrt \pi \gamma _ { 5 } \partial \! \! \! / \sigma .
# ddaae7893e831d0.png                                                                                                                                                                                                   \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! \! { P \, \leftrightarrow \, - Q \, \, \, , \, \, \, \lambda \, \rightarrow \, - \lambda }
# 501cbe5f95065d1.png                                                  \left( \begin{matrix} { { \bf 1 } } & { 0 } \\ { { \tilde { \bf c } } } & { { \bf 1 } } \\ \end{matrix} \right) \qquad \qquad { \tilde { \bf c } } = \sum _ { i } N _ { i } g _ { i } ^ { t } { \tilde { \bf c } } ^ { v } g _ { i } + \sum _ { j } M _ { j } g _ { j } ^ { t } { \tilde { \bf c } } ^ { h } g _ { j }
# 306d0ca5d4cda21.png                                                                                                                                                                                                                                                                                                                   \| B ( f ) \| \le \| f \| , \qquad f \in { \cal K } .
# Name: target_seq, Length: 14280, dtype: object

# %% [markdown]
# ### Render Images
# Render images using render_latex.py (https://github.com/untrix/im2latex/blob/master/thirdparty/harvardnlp_im2markup/scripts/evaluation/render_latex.py) which is derived from harvardnlp code base (https://github.com/harvardnlp/im2markup). See their github page for details on how to run the script.

# %%
# for image in df.image_name:
#     os.symlink(os.path.join(original_image_dir, image), os.path.join(golden_image_dir, image))

# %% [markdown]
# ### Evaluate images
# Evaluate image match using evaluate_image.py (https://github.com/untrix/im2latex/blob/master/thirdparty/harvardnlp_im2markup/scripts/evaluation/evaluate_image.py) also from harvard nlp code base. See their github page for details on how to run the script. However, make sure to use the code from this repository because it has been modified to produce an unmatched_files.txt output.

# %% [markdown]
# ### View and save the unmatched images

# %%
with open(os.path.join(rendered_dir, 'unmatched_filenames.txt'), 'r') as f:
    files = []
    for fname in f:
        files.append(os.path.basename(fname.strip()))
    
df_bad = df.loc[files]
targets=[]; preds=[]; index=[]
for row in df_bad[['target_seq', 'pred_seq']].sample(55).itertuples(index=True):
    index.append(row[0])
    targets.append('$%s$'%row[1])
    preds.append('$%s$'%row[2])
df_ = pd.DataFrame(data={'gold': targets, 'pred': preds})
df_
# Out:
#    gold                                                                                                                                                                                                                                                                                                                                                                                                                pred
# 0   $\dot { \epsilon } _ { \delta \sigma } = \epsilon _ { \delta \sigma } \left[ 3 { \frac { \dot { a } } { a } } ( 1 + w ) + 2 { \frac { \dot { c } } { c } } { \frac { 1 + \epsilon _ { \delta \sigma } } { 1 + \epsilon } } + \left( { \frac { \dot { G } _ { 4 } } { G _ { 4 } } } - 4 { \frac { \dot { c } } { c } } \right) ( 1 + \epsilon _ { \delta \sigma } ) \right] . $                                      $\dot { \epsilon } _ { \delta \sigma } = \epsilon _ { \delta \sigma } \left[ 3 \frac { \dot { a } } { a } ( 1 + w ) + 2 \frac { \dot { c } } { c } \frac { 1 + \epsilon _ { \delta \sigma } } { 1 + \epsilon } + \left( \frac { G _ { 4 } } { G _ { 4 } } - 4 \frac { \dot { c } } { c } \right) ( 1 + \epsilon _ { \delta \sigma } ) \right] . $
# 1   $R ^ { - } \equiv \frac { \sigma _ { N C } ^ { \nu N _ { 0 } } - \sigma _ { N C } ^ { \bar { \nu } N _ { 0 } } } { \sigma _ { C C } ^ { \nu N _ { 0 } } - \sigma _ { C C } ^ { \bar { \nu } N _ { 0 } } } = \frac { 1 } { 2 } - \mathrm { s i n } ^ { 2 } ( \theta _ { W } ) \, . $                                                                                                                                 $R ^ { - } \equiv { \frac { \sigma _ { N } ^ { \theta N _ { 0 } } - \sigma _ { N 0 } ^ { \bar { \nu } N } } { \sigma _ { C C } ^ { e N } - \sigma _ { C C } ^ { \bar { D } 0 } } } = { \frac { 1 } { 2 } } - \operatorname { s i n } ^ { 2 } ( \theta _ { W } ) \, . $
# 2   $\eta _ { 0 i j k } = \rho _ { i j k } \quad \mathrm { a n d ~ z e r o ~ e l s e w h e r e } , $                                                                                                                                                                                                                                                                                                                    $\eta _ { 0 i j k } = \rho _ { i j k } \quad \mathrm { a n d } \ \mathrm { z e r o \ e l s e n b e r e } , $
# 3   $\big < \operatorname { e x p } \int _ { \cal M } \Phi _ { 0 } { \cal O } \big > _ { C F T } = \operatorname { e x p } \left( - S _ { A d S } ( \Phi ) \right) , $                                                                                                                                                                                                                                                  $\left\langle \operatorname { e x p } \int _ { \cal M } \Phi _ { 0 } { \cal O } \right> _ { C F T } = \operatorname { e x p } \left( - S _ { A d S } ( \Phi ) \right) , $
# 4   $S _ { \mathrm { e f f } } ^ { \mathrm { r e g } } [ A , m = 0 ] = S _ { \mathrm { e f f } } [ A , m = 0 ] - \operatorname* { l i m } _ { M \to \infty } S _ { \mathrm { e f f } } [ A , M ] $                                                                                                                                                                                                                      $S _ { \mathrm { e f f } } ^ { \mathrm { e r f } } [ A , m = 0 ] = S _ { \mathrm { e f f } } [ A , m = 0 ] - \operatorname* { l i m } _ { M \to \infty } S _ { \mathrm { e f f } } [ A , M ] $
# 5   $\frac { d \mathbf { p } } { d s } = \frac { D p ^ { a } } { d s } \mathbf { e } _ { a } = ( \nabla _ { b } p ^ { a } ) u ^ { b } \mathbf { e } _ { a } $                                                                                                                                                                                                                                                           $\frac { d { \bf p } } { d s } = \frac { D p ^ { 2 } } { d s } { \bf e } _ { a } = ( { \bf \nabla } _ { b } p ^ { a } ) u ^ { b } { \bf e } _ { a } $
# 6   $\Gamma ( a _ { 1 } \to \rho \pi ) = \frac { 1 } { 9 6 \pi } \frac { g _ { a _ { 1 } \rho \pi } ^ { 2 } } { m _ { a _ { 1 } } } \left[ 1 - \frac { m _ { \rho } ^ { 2 } } { m _ { a _ { 1 } } } \right] \left[ 1 0 + \frac { m _ { a _ { 1 } } ^ { 2 } } { m _ { \rho } ^ { 2 } } + \frac { m _ { \rho } ^ { 2 } } { m _ { a _ { 1 } } ^ { 2 } } \ \right] $                                                        $\Gamma ( a _ { 1 } \to \rho \pi ) = { \frac { 1 } { 9 6 \pi } } { \frac { g _ { a _ { 1 } m \pi } ^ { 2 } } { m _ { a _ { 1 } } } } \left[ 1 - { \frac { m _ { \rho } ^ { 2 } } { m _ { a _ { 1 } } } } \right] \left[ 1 0 + { \frac { m _ { a _ { 1 } } ^ { 2 } } { m _ { \rho } ^ { 2 } } } + { \frac { m _ { \rho } ^ { 2 } } { m _ { a _ { 1 } } ^ { 2 } } } \right] $
# 7   ${ H ^ { l f } \equiv P ^ { - } } = \int d x \, \Bigl [ \omega ( \lambda \omega ^ { 2 } - m ^ { 2 } ) \varphi + { \frac { 1 } { 2 } } ( 3 \lambda \omega ^ { 2 } - m ^ { 2 } ) \varphi ^ { 2 } + \lambda \omega \varphi ^ { 3 } + { \frac { \lambda } { 4 } } \varphi ^ { 4 } \Bigr ] . $                                                                                                                           $H ^ { l f } \equiv P ^ { - } = \int d x \left[ \omega ( \lambda \omega ^ { 2 } - m ^ { 2 } ) \varphi + \frac { 1 } { 2 } ( 3 \lambda \omega ^ { 2 } - m ^ { 2 } ) \varphi ^ { 2 } + \lambda \omega \varphi ^ { 3 } + \frac { \lambda } { 4 } \varphi ^ { 4 } \right] . $
# 8   $\frac { 1 } { ( 2 \pi l ) ^ { 2 } } \int _ { S _ { \infty } ^ { 3 } } e _ { a } { \mathrm { \tiny ~ \wedge ~ } } d e ^ { a } = 3 . $                                                                                                                                                                                                                                                                               ${ \frac { 1 } { ( 2 \pi l ) ^ { 2 } } } \int _ { S _ { \infty } ^ { 3 } } e _ { a } { \Lambda } ~ d e ^ { a } = 3 . $
# 9   $\lambda _ { R } = \left( \begin{array} { c c } { 0 } & { 1 _ { \mathcal R } } \\ { 1 _ { \mathcal R } } & { 0 } \\ \end{array} \right) . $                                                                                                                                                                                                                                                                         $\lambda _ { R } = \left( \begin{array} { c c } { 0 } & { 1 \pi } \\ { 1 _ { \Sigma } } & { 0 } \\ \end{array} \right) . $
# 10  $\frac { \sigma ( \nu _ { \mu } \, N \rightarrow \mu \, X ) _ { L Q } } { \sigma ( \nu _ { \mu } \, N \rightarrow \mu \, X ) _ { S M } } \leq 0 . 4 \left( \frac { 2 0 0 \, G e V } { M ( L Q _ { 2 } ) } \right) ^ { 0 . 5 } $                                                                                                                                                                                     $\frac { \sigma ( \nu _ { \mu } \, N \rightarrow \mu X ) _ { L Q } } { \sigma ( \nu _ { \mu } \, N \to \mu \, X ) _ { S M } } \le 0 . 4 4 \left( \frac { 2 0 0 \, G e V } { M ( L Q _ { 2 } ) } \right) ^ { 0 . 5 } $
# 11  $^ N V ( r ) \simeq \frac { 8 \pi } { 3 \beta _ { 0 } } \Lambda \cdot \frac { 1 } { \Lambda r \operatorname { l n } ( \Lambda r ) } , \quad r \to 0 . $                                                                                                                                                                                                                                                             $V ^ { N } ( r ) \simeq \frac { 8 \pi } { 3 \beta _ { 0 } } \Lambda \cdot \frac { 1 } { \Lambda r \operatorname { l n } ( \Lambda r ) } , \quad r \rightarrow 0 . $
# 12  $D ( x ) \to \left( \frac { M _ { S } } { M _ { F } } \right) ^ { ( n + 2 ) } D ( x ) \, \, \, \, \mathrm { f o r } \, \, \, \, n \geq 2 , $                                                                                                                                                                                                                                                                        $D ( x ) \rightarrow \left( \frac { M _ { S } } { M _ { F } } \right) ^ { ( n + 2 ) } D ( x ) \; \; \mathrm { f o r } \; \; n \geq 2 , $
# 13  $i \frac { \partial } { \partial t } \psi _ { v } ( \vec { x ^ { \prime } } , t ) = - \frac { { \nabla } _ { x ^ { \prime } } ^ { 2 } } { 2 a ^ { 2 } ( t ) m } \psi _ { v } ( \vec { x ^ { \prime } } , t ) . $                                                                                                                                                                                                    $i \frac { \partial } { \partial t } \psi _ { v } ( \vec { x ^ { \prime } } , t ) = - \frac { \nabla _ { s ^ { \prime } } ^ { 2 } } { 2 a ^ { 2 } ( t ) m } \psi _ { v } ( \vec { x ^ { \prime } } , t ) . $
# 14  $P _ { \nu _ { \ell } \to \nu _ { \ell } } = P _ { \bar { \nu } _ { \ell } \to \bar { \nu } _ { \ell } } = 1 - \sum _ { \ell ^ { \prime } \not = \ell } P _ { \nu _ { \ell } \to \nu _ { \ell ^ { \prime } } } = 1 - { \frac { 1 } { 2 } } \, B _ { \nu _ { \ell } ; \nu _ { \ell } } \left( 1 - \operatorname { c o s } { \frac { \displaystyle \Delta m ^ { 2 } \, L } { \displaystyle 2 \, p } } \right) \; , $  $P _ { \nu _ { \ell } \to \nu _ { \ell } } = P _ { \bar { \nu } _ { e \to } \bar { t } _ { \ell } } = 1 - \sum _ { \ell ^ { \prime } \ell ^ { \prime } } P _ { t _ { U ^ { + } \to t ^ { \prime } } } = 1 - { \frac { 1 } { 2 } } \, B _ { \nu _ { \ell } ; \nu _ { \ell } } \left( 1 - \operatorname { c o s } { \frac { \Delta m ^ { 2 } \, L } { 2 \, p } } \right) \ , $
# 15  $i ! \zeta _ { g , G } ^ { n , i } = \sum _ { \nu \in \Sigma ( G , n , i ) } \frac { 1 } { | S _ { \nu } | } . $                                                                                                                                                                                                                                                                                                    $i ! _ { g , A } ^ { p , i } = \sum _ { \nu \in X ( L , n , i ) } { \frac { 1 } { | S _ { \nu } | } } . $
# 16  $F _ { 2 } ( x , Q ^ { 2 } ) = \sum _ { i = 1 } ^ { n _ { f } } e _ { i } ^ { 2 } x \bigg \{ C _ { q } ( x , \alpha _ { s } ) \otimes [ q _ { i } ( x , Q ^ { 2 } ) + \bar { q } _ { i } ( x , Q ^ { 2 } ) ] + C _ { g } ( x , \alpha _ { s } ) \otimes g ( x , Q ^ { 2 } ) \bigg \} . $                                                                                                                            $F _ { 2 } ( x , Q ^ { 2 } ) = \sum _ { i = 1 } ^ { n _ { f } } e _ { i } ^ { 2 } x \left\{ C _ { q } ( x , \alpha _ { s } ) \otimes [ q _ { i } ( x , Q ^ { 2 } ) + \bar { q } _ { i } ( x , Q ^ { 2 } ) ] + C _ { g } ( x , \alpha _ { s } ) \otimes g ( x , Q ^ { 2 } ) \right\} . $
# 17  $\Psi ( r , \theta , t ) = \sqrt { { \frac { i } { r } } } \, \, { \frac { 1 } { \sqrt { 2 \pi k _ { 0 } } } } \, \, { \frac { \operatorname { s i n } { \frac { \pi } { \alpha } } } { \operatorname { c o s } { \frac { \pi } { \alpha } } + \operatorname { c o s } \theta } } \, \, e ^ { - { \frac { b ^ { 2 } } { 4 \xi ^ { 2 } } } } \, \, \Psi _ { \mathrm { { f r e e } } } ( r , \alpha ^ { 2 } t ) , $   $\Psi ( r , \theta , t ) = \sqrt { \frac { i } { r } } \, \frac { 1 } { \sqrt { 2 \pi k _ { 0 } } } ~ \frac { \operatorname { s i n } \frac { \pi } { \alpha } } { \operatorname { c o s } \frac { \pi } { 3 } + \operatorname { c o s } \theta } ~ e ^ { - \frac { k ^ { 2 } } { 4 \xi ^ { 2 } } } \, \, \Psi _ { \mathrm { f r e e } } ( r , \alpha ^ { 2 } t ) , $
# 18  $\mathrm { A r e a } = \sqrt { 1 + 4 | \partial y _ { 3 } / \partial y | ^ { 2 } } d y \wedge d \bar { y } = { \frac { \sqrt { W + \overline { { W } } + | W ^ { \prime } | ^ { 2 } - y W ^ { \prime } - \bar { y } \overline { { W ^ { \prime } } } } } { y _ { 3 } } } d y \wedge d \bar { y } $                                                                                                                  $\mathrm { A r e a } = \sqrt { 1 + 4 [ \partial y _ { 3 } / \partial y | ^ { 2 } } d y \wedge d \bar { y } = \frac { \sqrt { W } + \overline { { W } } + | W ^ { \prime } | ^ { 2 } - y W ^ { \prime } - \bar { y } { \bar { W } } ^ { $
# 19  $\rho _ { 1 } ( m _ { \tau } ^ { 2 } e ^ { \mathrm { i } y } ) = \rho _ { 1 } ( m _ { \tau } ^ { 2 } ) + \mathrm { i } \beta _ { 0 } y \quad \Rightarrow $                                                                                                                                                                                                                                                          $\rho _ { 1 } ( m _ { \tau } ^ { 2 } e ^ { i y } ) = \rho _ { 1 } ( m _ { \tau } ^ { 2 } ) + \mathrm { i } \beta _ { 0 } y \quad $
# 20  $\Theta = { \frac { 1 } { 2 } } \oint ( \gamma { \cal J } _ { z } - c ^ { z } { \cal G } _ { z z } ) - { \frac { 1 } { 4 } } \delta _ { s } \oint ( c ^ { z } \gamma \beta _ { z z } + b _ { z } \gamma \gamma ) , $                                                                                                                                                                                                $\Theta = \frac { 1 } { 2 } \oint ( \gamma J _ { z } - c ^ { z } { \cal G } _ { z z } ) - \frac { 1 } { 4 } \delta _ { s } \oint ( c ^ { z } \gamma \beta _ { z z } + b _ { z } \gamma \gamma ) , $
# 21  $P _ { i } ( k _ { \perp } ^ { 2 } ) = d _ { i } ( k _ { \perp } ^ { 2 } ) e ^ { - \int _ { k _ { \perp } ^ { 2 } } ^ { k _ { \perp , \operatorname* { m a x } } ^ { 2 } } \sum _ { j } d _ { j } ( p _ { \perp } ^ { 2 } ) d p _ { \perp } ^ { 2 } } $                                                                                                                                                             $P _ { i } ( k _ { \perp } ^ { 2 } ) = d _ { i } ( k _ { \perp } ^ { 2 } ) \, e ^ { - { \frac { k ^ { 2 } ^ { 2 } } { k _ { 1 } ^ { 2 } } } \operatorname { m * x } } \Sigma _ { j } a _ { j } ( x _ { j } ^ { 2 } , \phi _ { \perp } ^ { 2 } $
# 22  $< H _ { J } > = < \sum _ { x = 1 } ^ { N } ( \vec { S } _ { x } \cdot \vec { S } _ { x + 1 } - \frac { { \cal N } ^ { 2 } + 1 } { 8 \cal N } ) > = < - \frac { 1 } { 2 } \sum _ { x = 1 } ^ { N } L _ { x } R _ { x } > \quad . $                                                                                                                                                                                  $< H _ { J } > = < \sum _ { x = 1 } ^ { N } ( \vec { S } _ { x } \cdot \vec { S } _ { x + 1 } - \frac { \mathcal { N } ^ { 2 } + 1 } { 8 \hat { N } } ) > = < - \frac { 1 } { 2 } \sum _ { x = 1 } ^ { N } L _ { x } R _ { x } > \quad . $
# 23  $V ^ { \left( 3 + 1 \right) } = \left( \begin{array} { l l } { \ U ^ { \left( 3 \right) } \ } & { \ 0 \ } \\ { \ 0 \ } & { \ 1 \ } \\ \end{array} \right) K ^ { \left( 3 + 1 \right) } . $                                                                                                                                                                                                                          $V ^ { ( 3 + 1 ) } = \left( \begin{array} { c c } { U ^ { ( 3 ) } } & { 0 } \\ { 0 } & { 1 } \\ \end{array} \right) K ^ { ( 3 + 1 ) } . $
# 24  $f _ { i } ( x , \alpha ; t ) = h ( x , \alpha ) \, f _ { i } ( x ) \operatorname { e x p } \left\{ \frac { ( \bar { x } ^ { 2 } - \alpha ^ { 2 } ) t } { 4 x \bar { x } \lambda ^ { 2 } } \right\} $                                                                                                                                                                                                               $f _ { i } ( x , \alpha ; t ) = h ( x , \alpha ) \, f _ { i } ( x ) \operatorname { e x p } \left\{ \frac { ( \bar { x } ^ { 2 } - \alpha ^ { 2 } ) t } { 4 x \bar { c } \lambda ^ { 2 } } \right\} $
# ..                                                                                                                                                                                                    ...                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# 30  $\delta L _ { 0 } = i \Lambda ^ { a } D _ { - } \chi _ { a } ( \varphi , \tilde { \varphi } ) + \Lambda ^ { a } A _ { - } ^ { b } \left( \partial _ { \alpha } \chi _ { a } \xi _ { b } ^ { \alpha } + \partial _ { \overline { { \alpha } } } \chi _ { a } A _ { - } ^ { b } \tilde { \xi } _ { b } ^ { \overline { { \alpha } } } \right) ( \varphi , \tilde { \varphi } ) . $                                    $\delta L _ { 0 } = i \Lambda ^ { a } D _ { - } \chi _ { a } ( \varphi , \tilde { \varphi } ) + \Lambda ^ { a } A _ { - } ^ { b } \left( \partial _ { \alpha } \chi _ { a } \xi _ { b } ^ { \alpha } + \partial _ { \overline { { \alpha } } } \chi _ { a } A _ { - } ^ { b } \tilde { \xi } _ { b } ^ { \overline { { a } } } \right) ( \varphi , \tilde { \varphi } ) . $
# 31  $\Gamma _ { g q q } ^ { \sigma } + \widetilde { \Gamma } _ { g q q } ^ { \sigma } = Z _ { 1 1 } \left\langle R _ { 3 , 1 } ^ { \sigma } \right\rangle _ { g q q } ^ { ( 3 ) } \ , \qquad \Gamma _ { g g g } ^ { \sigma } + \widetilde { \Gamma } _ { g g g } ^ { \sigma } = 0 . $                                                                                                                                   $\Gamma _ { g q q } ^ { \sigma } + \widetilde { \Gamma } _ { g q q } ^ { \sigma } = Z _ { 1 1 } \left( R _ { 3 , 1 } ^ { \sigma } \right\rangle _ { g q q } ^ { ( 3 ) } \ , \qquad \Gamma _ { g g g } ^ { \sigma } + \widetilde { \Gamma } _ { g g g } ^ { \sigma } = 0 . $
# 32  $\langle \mathrm { v a c } , A ( t ) | a _ { n } ^ { \dagger } a _ { m } \frac { \delta : \hat { \mathrm { H } _ { \mathrm { F } } } : ( t ) } { \delta A _ { 1 } ( x , t ) } | \mathrm { v a c } , A ( t ) \rangle - ( x \longleftrightarrow y ) \} . $                                                                                                                                                            $\langle \mathrm { v a c } , A ( t ) | a _ { n } ^ { \dagger } a _ { m } \frac { \delta : { \mathrm { H } } _ { \mathrm { F } } : ( t ) } { \delta A _ { 1 } ( x , t ) } | \mathrm { v a c } , A ( t ) \rangle - ( x \leftrightarrow \longrightarrow y ) \} . $
# 33  $- \int d ^ { 4 } x i \bar { \psi } \not { D ( A ) } P _ { L } \psi $                                                                                                                                                                                                                                                                                                                                               $- \int d ^ { 4 } x i \bar { \psi } \not \! D ( A ) P _ { L } \psi $
# 34  $( 1 + i { \bf n } \cdot \mathrm { \boldmath { ~ \gamma ~ } } ) G \bigg | _ { S } = 0 , $                                                                                                                                                                                                                                                                                                                           $( 1 + i { \bf n \cdot \mathrm { \boldmath ~ \gamma ~ } } ) G \vert _ { S } = 0 , $
# 35  $\mathrm { w i t h ~ } \; \; \; \omega _ { l , m , n } \equiv \sqrt { \Biggl ( \frac { l \pi } { 2 L _ { x } } \Biggr ) ^ { 2 } + \Biggl ( \frac { m \pi } { 2 L _ { y } } \Biggr ) ^ { 2 } + \Biggl ( \frac { n \pi } { 2 L _ { z } } \Biggr ) ^ { 2 } } \; \; , $                                                                                                                                                 $\mathrm { w i t h } \quad \omega _ { l , m , n } \equiv \left( \left( \frac { l \pi } { 2 L _ { x } } \right) ^ { 2 } + \left( \frac { m \pi } { 2 L } \right) ^ { 2 } + \left( \frac { n \pi } { 2 L _ { z } } \right) ^ { 2 } \, , $
# 36  $a \mid \alpha _ { + } > = \alpha \sqrt { t a n h \mid \alpha \mid ^ { 2 } } ~ \mid \alpha _ { - } > , $                                                                                                                                                                                                                                                                                                            $a \mid \alpha _ { + } > = \alpha \alpha \sqrt { t a n h \mid 0 \mid ^ { 2 } } \ \mid \alpha _ { - } > , $
# 37  $I ( s , t ) = \frac { 3 ^ { 9 } } { 2 ^ { 1 2 } } \int _ { 0 } ^ { \infty } d T \; e ^ { T } \; \frac { \operatorname* { d e t } ( 1 + S \tilde { X } ( T ) ) } { \operatorname* { d e t } ( 1 - S \tilde { N } ( T ) ) ^ { 1 3 } } \operatorname { e x p } \left( - \frac { 1 } { 2 } p _ { i } Q _ { i j } p _ { j } \right) $                                                                                   $I ( s , t ) = \frac { 3 ^ { 9 } } { 2 ^ { 1 1 } } \int _ { 0 } ^ { \infty } d T ~ e ^ { T } ~ \frac { \operatorname* { d e t } ( 1 + S \tilde { X } ( T ) ) } { \operatorname* { d e t } ( 1 - S \tilde { N } ( T ) ) ^ { 1 3 } } \operatorname { e x p } \left( - \frac { 1 } { 2 } p _ { i } Q _ { i j } p _ { j } \right) $
# 38  $\begin{array} { r c l } { \Delta } & { = } & { ( r - m ) ^ { 2 } - R _ { 0 } { } ^ { 2 } \, , } \\ { } & { } & { } \\ { \Sigma } & { = } & { r ^ { 2 } + \alpha ^ { 2 } \operatorname { c o s } ^ { 2 } \theta - | \Upsilon | ^ { 2 } \, , } \\ \end{array} $                                                                                                                                                      $\begin{array} { r c l } { \Delta } & { = } & { ( r - m ) ^ { 2 } - R _ { 0 } { } ^ { 2 } \, , } \\ { } & { } & { } \\ { } & { } & { { } } & { = } & { r ^ { 2 } + \; \; \; \alpha ^ { 2 } \operatorname { c o s } ^ { 2 } \theta } \\ \end{array} \right] , $
# 39  $\frac { \partial g } { \partial \lambda } = \frac { \partial g ^ { r } } { \partial \lambda } + \frac { 1 } { \lambda } \Biggl ( ( 4 \pi \bigr ) ^ { 2 } \left( \frac { 2 7 2 } { 3 } L _ { 1 } ^ { r } + \frac { 3 5 2 } { 9 } L _ { 2 } ^ { r } + \frac { 9 2 8 } { 2 7 } L _ { 3 } ^ { r } + 4 8 L _ { 4 } ^ { r } + 1 4 L _ { 5 } ^ { r } \right) - \frac { 9 7 8 7 1 } { 6 4 8 0 } \Biggr ) ~ , $             $\frac { \partial \lambda } { \partial \lambda } = \frac { \partial ^ { r } s } { \partial \lambda } + \frac { 1 } { \lambda } \Bigg ( ( 4 \pi ) ^ { 2 } \left( \frac { 2 7 2 } { 3 } L _ { 1 } ^ { r } + \frac { 3 5 2 } { 9 } L _ { 2 } ^ { r } + \frac { 9 2 8 } { 2 7 } L _ { 3 } ^ { r } + 4 8 L _ { 4 } ^ { r } + 1 4 L _ { 5 } ^ { r } \bigg ) - \frac { 9 7 9 7 } { 6 4 8 0 } \right) , $
# 40  ${ \hat { s } } ^ { 2 } = { \frac { 1 } { 4 } } ( { \hat { a } } _ { ( 1 ) ( 1 ) } - { \hat { a } } _ { ( 2 ) ( 2 ) } ) ^ { 2 } + { \frac { 1 } { 2 } } ( { \hat { a } } _ { ( 1 ) ( 2 ) } { \hat { a } } _ { ( 2 ) ( 1 ) } + { \hat { a } } _ { ( 2 ) ( 1 ) } { \hat { a } } _ { ( 1 ) ( 2 ) } ) , $                                                                                                               $\hat { s } ^ { 2 } = \frac { 1 } { 4 } ( \hat { a } _ { ( 1 ) ( 1 ) } - \hat { a } _ { ( 2 ) ( 2 ) } ) ^ { 2 } + \frac { 1 } { 2 } ( \hat { a } _ { ( 1 ) ( 1 ) } \hat { a } _ { ( 2 ) ( 1 ) } + \hat { a } _ { ( 2 ) ( 1 ) } \hat { a } _ { ( 1 ) ( 2 ) ) } , $
# 41  $\left. \frac { \delta ^ { 2 } W } { \delta K _ { a b } \delta K _ { c d } } \right| _ { K = 0 } = \frac i 4 $                                                                                                                                                                                                                                                                                                      $\frac { \delta ^ { 2 } W } { \delta K _ { a b } \delta K _ { c d } } \right| _ { K = 0 } = \frac { i } { 4 } $
# 42  $\xi _ { \pm } ( x ) = N e ^ { m \epsilon ( x - a ^ { \pm } ) } ( \epsilon - \operatorname { t a n h } [ m ( x - a ^ { \pm } ) ] ) \quad . $                                                                                                                                                                                                                                                                        $\xi _ { \pm } ( x ) = N e ^ { m ( z - a ^ { 2 } ) } ( \epsilon - \operatorname { t a n h } [ m ( x - a ^ { \pm } ) ] ) \quad . $
# 43  $m _ { n } ^ { 2 } \equiv \lambda _ { 0 } = c o n s t . \Lambda ^ { 2 } \left( \frac { g ^ { 2 } - g _ { c r } ^ { 2 } } { g _ { c r } ^ { 2 } } \right) ^ { 2 } $                                                                                                                                                                                                                                                  $m _ { n } ^ { 2 } \equiv \lambda _ { 0 } = c o n s t . \Lambda ^ { 2 } \left( \frac { g ^ { 2 } - g _ { c r } ^ { 2 } } { g _ { x r } ^ { 2 } } \right) ^ { 2 } $
# 44  $C _ { i } + C _ { s } \stackrel { K _ { 8 } } { \rightarrow } C _ { i } C _ { s } $                                                                                                                                                                                                                                                                                                                                $C _ { i } + C _ { s } \stackrel { K _ { 8 } } { \longrightarrow } C _ { i } C _ { s } $
# 45  $a = \left\{ \begin{array} { r l } { \chi _ { 1 } z , } & { \; \ \ z < 0 } \\ { \mp \chi _ { 2 } z , } & { \; \ \ z > 0 } \\ \end{array} \right. $                                                                                                                                                                                                                                                                  $a = \left\{ \begin{array} { c } { \chi _ { 1 } z , } & { z < 0 } \\ { \overline { { \tau } } \chi _ { 2 } z , } & { z > 0 } \\ \end{array} \right. $
# 46  $P ^ { - } = 1 + \sum _ { l = 0 } ^ { \infty } N _ { l } \sqrt { 1 + \frac { \eta } { 2 J ^ { 2 } } l ^ { 2 } } , $                                                                                                                                                                                                                                                                                                 $P ^ { - } = 1 + \sum _ { l = 0 } ^ { \infty } N _ { l } \sqrt { 1 + \frac { \eta } { 2 J ^ { 2 } } } l ^ { 2 } , $
# 47  $V _ { L } ( \alpha \cdot q ) = \wp ( \alpha \cdot q | \{ 2 \omega _ { 1 } , 2 \omega _ { 3 } \} ) , \qquad V _ { S } ( \alpha \cdot q ) = \wp ( \alpha \cdot q | \{ \omega _ { 1 } , 2 \omega _ { 3 } \} ) . $                                                                                                                                                                                                     $V _ { L } ( \alpha \cdot q ) = \triangle ( \alpha \cdot q | \{ 2 \omega _ { 1 } , 2 \omega _ { 3 } \} ) , \qquad V _ { S } ( \alpha \cdot q ) = \varepsilon ( \alpha \cdot q | \{ \omega _ { 1 } , 2 \omega _ { 3 } \} ) . $
# 48  $\int \frac { d ^ { 3 } { \cal P } } { ( 2 \pi ) ^ { 3 } } \left[ - \frac { 1 } { 2 } \vec { v } _ { \cal P } \cdot \nabla _ { \cal P } ( f _ { p } + f _ { \overline { p } } ) - \frac { ( 3 - v _ { \cal P } ^ { 2 } ) } { 2 { \cal E } } ( f _ { p } + f _ { \overline { p } } ) \right] $                                                                                                                       $\int { \frac { d ^ { 3 } { \cal P } } { ( 2 \pi ) ^ { 3 } } } \left[ - { \frac { 1 } { 2 } } \vec { v } _ { P } \cdot \nabla _ { P } ( f _ { p } + f _ { \overline { { p } } } ) - { \frac { ( 3 - v _ { T } ^ { 2 } ) } { 2 { \cal E } } } ( f _ { p } + f _ { \overline { { p } } } ) \right] $
# 49  $\frac { d \xi } { d t } = - i \varpi \chi + f _ { 0 } \dot { \varepsilon } _ { A } \sigma ^ { A } \xi , \qquad \frac { d \chi } { d t } = - f _ { 0 } \dot { \varepsilon } _ { A } \sigma ^ { A } \chi , $                                                                                                                                                                                                         $\frac { d \xi } { d t } = - i { \bf z } \chi + f _ { 0 } \dot { \varepsilon } _ { A } \sigma ^ { A } \xi , \qquad \frac { d \chi } { d t } = - f _ { 0 } \dot { \varepsilon } _ { A } \sigma ^ { A } \chi , $
# 50  $U _ { 0 } = \frac { \left( 2 \pi \right) ^ { \frac { 3 } { 2 } } } { \Gamma \left( \frac { 1 } { 4 } \right) ^ { 2 } L } . $                                                                                                                                                                                                                                                                                       $U _ { 0 } = \frac { ( 2 \pi ) ^ { \frac { 3 } { 2 } } } { \Gamma ( \frac { 1 } { 2 } ) ^ { 2 } L } . $
# 51  $\left| \left. a , 1 / 2 \right| n \right\rangle $                                                                                                                                                                                                                                                                                                                                                                  $\left| a , 1 / 2 \right| n \right\rangle $
# 52  $\sum _ { \bar { c } = \pm } R _ { a } ^ { \bar { c } } ( \beta ) R _ { \bar { c } } ^ { b } ( - \beta ) = \delta _ { a } ^ { b } . $                                                                                                                                                                                                                                                                               $\sum _ { m = \pm } R _ { a } ^ { \bar { c } } ( \beta ) R _ { \bar { c } } ^ { b } ( - \beta ) = \delta _ { a } ^ { b } . $
# 53  $\int _ { \pi ^ { - 1 } ( U ) } e ^ { i { \cal S } } = \mathrm { v o l } ( G ) \int _ { \pi ^ { - 1 } ( U ) } \delta ( g ^ { i } ) \; \mathrm { d e t } ( X _ { j } ( g ^ { i } ) ) e ^ { i { \cal S } } , $                                                                                                                                                                                                        $\int _ { \pi ^ { - 1 } ( L ) } e ^ { i S } = \mathrm { v o l } ( G ) \int _ { \pi ^ { - 1 } ( U ) } \delta ( g ^ { i } ) \ \mathrm { d e t } ( X _ { j } ( g ^ { i } ) ) e ^ { i S } , $
# 54  $R ^ { D } ( \lambda ) = R ^ { C } ( \lambda ) \ ; \ L _ { 1 \ell } ^ { D } ( \lambda ) = R _ { 1 \ell } ^ { D } ( \lambda - i / 2 ) = F L _ { 1 \ell } ^ { A } ( \lambda ) F \ ; \, t i l d e { R } ^ { D } ( \lambda ) = \tilde { R } ^ { B } ( \lambda ) \ ; $                                                                                                                                                   $R ^ { D } ( \lambda ) = R ^ { C } ( \lambda ) \ ; \ L _ { 1 \ell } ^ { D } ( \lambda ) = R _ { Q } ^ { D } ( \lambda - i / 2 ) = F I _ { L 4 } ^ { A } ( \lambda ) F : \ t i l d e { R } ^ { D } ( \lambda ) = \tilde { R } ^ { R } ( \lambda ) \ ; $
#
# [55 rows x 2 columns]

# %% [markdown]
# ### In favor of compatibility with publishing tools, remove entries that are not rendered by MathJax
# Though they rendered fine with render_latex.py above, MathJax has difficulty rendering them. Therefore we will remove them for visualization purposes just in case it causes a problem with publishing tools downstream.

# %%
df_2_ = df_.drop([51, 41, 18, 21, 35, 38, 26]).reindex()[:50]

# %%
pd.options.display.latex.repr = True
with open('/tmp/df_2_frag.tex', 'w') as f:
    f.write(df_2_.to_latex(escape=False))

# %%
pd.options.display.latex.repr = True

(df_2_.iloc[0])
# Out:
# gold    $\dot { \epsilon } _ { \delta \sigma } = \epsilon _ { \delta \sigma } \left[ 3 { \frac { \dot { a } } { a } } ( 1 + w ) + 2 { \frac { \dot { c } } { c } } { \frac { 1 + \epsilon _ { \delta \sigma } } { 1 + \epsilon } } + \left( { \frac { \dot { G } _ { 4 } } { G _ { 4 } } } - 4 { \frac { \dot { c } } { c } } \right) ( 1 + \epsilon _ { \delta \sigma } ) \right] . $
# pred    $\dot { \epsilon } _ { \delta \sigma } = \epsilon _ { \delta \sigma } \left[ 3 \frac { \dot { a } } { a } ( 1 + w ) + 2 \frac { \dot { c } } { c } \frac { 1 + \epsilon _ { \delta \sigma } } { 1 + \epsilon } + \left( \frac { G _ { 4 } } { G _ { 4 } } - 4 \frac { \dot { c } } { c } \right) ( 1 + \epsilon _ { \delta \sigma } ) \right] . $
# Name: 0, dtype: object

# %%
num2display = 10
# with open(os.path.join(rendered_dir, 'unmatched_filenames.txt'), 'r') as f:
#     files = np.random.choice(f.readlines(), num2display)
#     for fname in files:
#         fname = os.path.basename(fname.strip())
#         display(df.loc[fname][['target_seq', 'pred_seq']])
#         gold = ipImage(filename=os.path.join(rendered_dir, 'images_gold', fname), unconfined=True)
#         pred = ipImage(filename=os.path.join(rendered_dir, 'images_pred', fname), unconfined=True)
#         display(gold)
#         display(pred)
gold = []; pred = [];
gold_images = []; pred_images = []
with open(os.path.join(rendered_dir, 'unmatched_filenames.txt'), 'r') as f:
    files = np.random.choice(f.readlines(), num2display)
    for fname in files:
        fname = os.path.basename(fname.strip())
        if not os.path.exists(os.path.join(rendered_dir, 'images_pred', fname)):
            continue
        gold_images.append(ipImage(filename=os.path.join(rendered_dir, 'images_gold', fname), format='png', unconfined=True))
        gold.append('<img src=".%s"/>' % os.path.join(rendered_dir, 'images_gold', fname))
        pred_images.append(ipImage(filename=os.path.join(rendered_dir, 'images_pred', fname), format='png', unconfined=True))
        pred.append('<img src=".%s"/>' % os.path.join(rendered_dir, 'images_pred', fname))
df_= pd.DataFrame({'gold': gold, 'pred': pred})
HTML((df_).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th></th>
#       <th>gold</th>
#       <th>pred</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="./zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_gold/e458bdcb9de36eb.png"/></td>
#       <td><img src="./zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_pred/e458bdcb9de36eb.png"/></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="./zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_gold/af2714b1af4cb8f.png"/></td>
#       <td><img src="./zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_pred/af2714b1af4cb8f.png"/></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="./zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_gold/4e6d3bebeaf6a56.png"/></td>
#       <td><img src="./zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_pred/4e6d3bebeaf6a56.png"/></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="./zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_gold/959fe32776ce078.png"/></td>
#       <td><img src="./zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_pred/959fe32776ce078.png"/></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src="./zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_gold/627ff6e1c61280c.png"/></td>
#       <td><img src="./zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_pred/627ff6e1c61280c.png"/></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src="./zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_gold/6b75ec66d2a003b.png"/></td>
#       <td><img src="./zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_pred/6b75ec66d2a003b.png"/></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><img src="./zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_gold/87de515fc8e87a2.png"/></td>
#       <td><img src="./zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_pred/87de515fc8e87a2.png"/></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><img src="./zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_gold/21b45e5da7c92fa.png"/></td>
#       <td><img src="./zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_pred/21b45e5da7c92fa.png"/></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><img src="./zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_gold/fcd1960cac8c17e.png"/></td>
#       <td><img src="./zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_pred/fcd1960cac8c17e.png"/></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><img src="./zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_gold/afbfe0de32ae4ab.png"/></td>
#       <td><img src="./zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_pred/afbfe0de32ae4ab.png"/></td>
#     </tr>
#   </tbody>
# </table>

# %%
def loadImage(path, mode="RGB"):
    img = Image.open(path)
    img = img.convert(mode)
    return np.asarray(img)

def plotImage(path, axes):
    image_data = loadImage(path)
#     title = os.path.splitext(os.path.basename(path))[0] + ' %s'%(image_data.shape,)
#     axes.set_title( title )
    axes.set_xlim(0,1000)
    axes.imshow(image_data, aspect='equal', extent=None, resample=False, interpolation='bilinear')
    return

def plotImages(image_paths, dpi=None):
    """ image_details should be an array of image path and width - [[path, image_data, image_data.shape], ...] """
    ## Display image data loaded as a numpy array
    try:
        plt.close(fig)
    except:
        pass
    orig_dpi = plt.rcParams['figure.dpi']

    for path in (image_paths):
        gold = os.path.join(rendered_dir, 'images_gold', path)
        pred = os.path.join(rendered_dir, 'images_pred', path)
        image_data.append(plotImage(gold, grid[i]))
        i+=1
        image_data.append(plotImage(pred, grid[i]))
        i+=1
        
    with mpl.rc_context(rc={'figure.dpi': dpi or orig_dpi}):
        fig = plt.figure(figsize=(20.,2.*len(image_paths)))
        grid = ImageGrid(fig, 111, nrows_ncols=(len(image_paths),2), axes_pad=(0.1, 0.5), label_mode="L")
        i = 0
        for path in (image_paths):
            gold = os.path.join(rendered_dir, 'images_gold', path)
            pred = os.path.join(rendered_dir, 'images_pred', path)
            plotImage(gold, grid[i])
            i+=1
            plotImage(pred, grid[i])
            i+=1
    return # image_data

num2display = 5
with open(os.path.join(rendered_dir, 'unmatched_filenames.txt'), 'r') as f:
    files = [os.path.basename(fname.strip()) for fname in np.random.choice(f.readlines(), num2display)]
fnames=[]
plotImages(files)

# fig, axes = plt.subplots(nrows=num2display, ncols=2, sharex=True, sharey=True, squeeze=True)
# for i, fname in enumerate(files):
#     fname = os.path.basename(fname.strip())
#     im_gold = loadImage(os.path.join(rendered_dir, 'images_gold', fname))
#     im_pred = loadImage(os.path.join(rendered_dir, 'images_pred', fname))
#     axes[i][0].imshow(im_gold, aspect='equal', extent=None, resample=False, interpolation='bilinear', cmap='gray')
#     axes[i][1].imshow(im_pred, aspect='equal', extent=None, resample=False, interpolation='bilinear', cmap='gray')

# %%
# for fname in files:
#     print os.path.join(rendered_dir,'images_gold', os.path.basename(fname.strip()))
#     print os.path.join(rendered_dir,'images_pred', os.path.basename(fname.strip()))
# Out:
# /zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_gold/f7fce9895d99aac.png
# /zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_pred/f7fce9895d99aac.png
# /zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_gold/21a71f54d6f8f29.png
# /zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_pred/21a71f54d6f8f29.png
# /zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_gold/b396bfc79014cec.png
# /zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_pred/b396bfc79014cec.png
# /zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_gold/9d5194fdda18f82.png
# /zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_pred/9d5194fdda18f82.png
# /zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_gold/1e0629bbfd50930.png
# /zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_pred/1e0629bbfd50930.png
# /zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_gold/882251c17178df5.png
# /zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_pred/882251c17178df5.png
# /zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_gold/e3644dde98b032b.png
# /zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_pred/e3644dde98b032b.png
# /zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_gold/6503a50979a57da.png
# /zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_pred/6503a50979a57da.png
# /zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_gold/3be822bf9ac5a7f.png
# /zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_pred/3be822bf9ac5a7f.png
# /zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_gold/677e6ea9a80b527.png
# /zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2/eval_images/rendered_images/images_pred/677e6ea9a80b527.png

# %% [markdown]
# ### Evaluate Exact Match of Images

# %%
# total_num, matched_num, unmatched, missing = viz.compare_images(os.path.join(rendered_dir, 'images_gold'), os.path.join(rendered_dir, 'images_pred'))
