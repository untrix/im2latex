# %% [markdown]
# This file is to be run from the gallery directory for printing out data for the gallery.

# %%
from IPython.core.display import display, Latex, Pretty, Math, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
import sys
import pandas as pd
sys.path.extend(['../src/commons'])
import pub_commons as pub
# %matplotlib inline
# Out:
# <style>.container { width:90% !important; }</style>

# %%
pub.disp_rand_sample('I2L-NOPOOL')
# Out:
#     edit_distance  $\mathbf{y}$_len  \
# 0   0.169492       59
# 1   0.016393       122
# 2   0.000000       73
# 3   0.182540       126
# 4   0.014085       71
# 5   0.008850       113
# 6   0.105263       57
# 7   0.119048       42
# 8   0.000000       74
# 9   0.086420       81
# 10  0.122642       106
# 11  0.035714       56
# 12  0.013158       76
# 13  0.000000       42
# 14  0.024390       41
# 15  0.000000       15
# 16  0.000000       32
# 17  0.166667       30
# 18  0.000000       23
# 19  0.125000       56
# 20  0.076923       78
# 21  0.000000       52
# 22  0.000000       38
# 23  0.081081       37
# 24  0.000000       74
# 25  0.040000       25
# 26  0.121495       107
# 27  0.076923       65
# 28  0.000000       55
# 29  0.000000       49
# 30  0.022222       45
# 31  0.000000       27
# 32  0.027397       73
# 33  0.000000       44
# 34  0.000000       36
# 35  0.203704       54
# 36  0.019608       51
# 37  0.043478       115
# 38  0.000000       45
# 39  0.056338       71
# 40  0.056338       71
# 41  0.034091       88
# 42  0.156250       64
# 43  0.000000       51
# 44  0.100000       100
# 45  0.000000       68
# 46  0.069767       43
# 47  0.098361       122
# 48  0.000000       21
# 49  0.000000       30
# 50  0.000000       33
# 51  0.131313       99
# 52  0.000000       39
# 53  0.000000       33
# 54  0.034722       144
# 55  0.066667       60
# 56  0.000000       23
# 57  0.000000       41
# 58  0.180000       50
# 59  0.000000       14
# 60  0.000000       30
# 61  0.000000       58
# 62  0.021739       92
# 63  0.000000       50
# 64  0.181818       66
# 65  0.035088       57
# 66  0.093750       64
# 67  0.030769       65
# 68  0.044944       89
# 69  0.187500       16
# 70  0.051724       58
# 71  0.000000       47
# 72  0.000000       76
# 73  0.000000       83
# 74  0.062937       143
# 75  0.068966       29
# 76  0.008403       119
# 77  0.081633       49
# 78  0.000000       23
# 79  0.000000       27
# 80  0.117647       85
# 81  0.000000       122
# 82  0.093023       43
# 83  0.000000       43
# 84  0.011236       89
# 85  0.089286       56
# 86  0.108108       37
# 87  0.157895       38
# 88  0.000000       39
# 89  0.000000       25
# 90  0.028571       35
# 91  0.000000       46
# 92  0.082353       85
# 93  0.000000       39
# 94  0.177215       79
# 95  0.112500       80
# 96  0.009259       108
# 97  0.058824       68
# 98  0.123711       97
# 99  0.067416       89
#
#    $\mathbf{y}$                                                                                                                                                                                                                                                                                                                                                                                    \
# 0   $E ( z + { n } \cdot { \alpha } + { m } \cdot { \beta } , z ) = e ^ { - \pi i m \cdot \Omega \cdot m - 2 \pi i m \cdot \left( I ( z ) - I ( w ) \right) } E ( z , w ) . $
# 1   $\Gamma ( b \rightarrow J / \psi + X ) = \frac { G _ { F } ^ { 2 } } { 1 4 4 \pi } | V _ { c b } | ^ { 2 } m _ { c } m _ { b } ^ { 3 } \left( 1 - \frac { 4 m _ { c } ^ { 2 } } { m _ { b } ^ { 2 } } \right) ^ { 2 } \left[ a \left( 1 + \frac { 8 m _ { c } ^ { 2 } } { m _ { b } ^ { 2 } } \right) + b \right] \, , $
# 2   $S _ { c } ^ { ( 1 ) > } ( x ^ { 0 } - i \beta - y ^ { 0 } , \vec { p } ) = - e ^ { - \beta \mu } S _ { c } ^ { ( 1 ) < } ( x ^ { 0 } - y ^ { 0 } , \vec { p } ) . $
# 3   $\operatorname { l n } \: \frac { E _ { m a x } } { m _ { h } } \; \approx \; \frac { 1 } { 2 } \: \operatorname { l n } \: \frac { E } { m _ { h } \operatorname { s i n } \Theta } \: - \: B \: \left( \sqrt { \frac { b } { 1 6 N _ { C } } \: Y _ { \Theta } } \; - \; \sqrt { \frac { b } { 1 6 N _ { C } } \; \operatorname { l n } \: \frac { m _ { h } } { \Lambda } \: } \right) . $
# 4   $\tilde { A } _ { i } \rightarrow \epsilon _ { i j } \biggl \{ - \alpha \frac { x ^ { j } - q ^ { j } } { | \vec { x } - \vec { q } | ^ { 2 } } + \frac { \rho _ { e } } { 2 \kappa } q ^ { j } \biggr \} , $
# 5   $\omega _ { 0 } ( x ) = 2 \int _ { 0 } ^ { \infty } { \frac { x \rho ( \lambda ) d \lambda } { x ^ { 2 } - \lambda ^ { 2 } } } = \int _ { 0 } ^ { \infty } \rho ( \lambda ) d \lambda \left( { \frac { 1 } { x - \lambda } } + { \frac { 1 } { x + \lambda } } \right) = \int _ { - \infty } ^ { \infty } { \frac { \rho ( \lambda ) d \lambda } { x - \lambda } } , $
# 6   $\left[ i D ^ { \mu } , i D ^ { \nu } \right] h _ { v } ^ { ( \pm ) } \quad \ll \quad \left\{ i D ^ { \mu } , i D ^ { \nu } \right\} h _ { v } ^ { ( \pm ) } \, . $
# 7   $\Delta _ { 1 } \supset \Delta _ { 2 } , \ \ \mathrm { a n d } \ \ \Delta _ { 1 } ^ { * } \subset \Delta _ { 2 } ^ { * } . $
# 8   $[ ( \gamma _ { 4 } P _ { 0 } - \gamma _ { i } P _ { i } ) + \frac { \epsilon } { 2 } ( \gamma _ { 4 } ( P _ { 0 } ^ { 2 } - P _ { i } P _ { i } ) - m P _ { 0 } ) ] \psi = m \psi . $
# 9   $\phi ^ { \prime \prime } - { \frac { 5 \alpha + 1 0 } { 8 } } k \phi ^ { \prime } + \left( m ^ { 2 } - { \frac { l ^ { 2 } } { R ^ { 2 } } } e ^ { { \frac { 5 } { 4 } } ( \alpha - 2 ) k \rho } \right) e ^ { k \rho } \phi = 0 $
# 10  $\alpha _ { q } = \sqrt { \frac { \operatorname { s i n h } \lambda \alpha \alpha ^ { * } } { \alpha \alpha ^ { * } \, \operatorname { s i n h } \lambda } } \alpha , ~ ~ ~ ~ ~ ~ ~ \alpha _ { q } ^ { * } = \sqrt { \frac { \operatorname { s i n h } \, \lambda \alpha \alpha ^ { * } } { \alpha \alpha ^ { * } \, \operatorname { s i n h } \lambda } } \alpha ^ { * } . $
# 11  $\Gamma _ { A _ { n } } ^ { \pm } \, \equiv \, p _ { a _ { n } } \, \pm \, \frac { \omega _ { n + \frac { 1 } { 2 } } } { 2 R } b _ { n } \approx 0 , $
# 12  $n ^ { i } = ( S ^ { t } ) _ { j } ^ { i } e ^ { j } - ( N ^ { t } ) ^ { i j } \sum _ { r = 1 } ^ { d - 1 } \sum _ { \bf k } k _ { j } N _ { r } ( { \bf k } ) \, , $
# 13  $E _ { c } = - 2 \frac { n l r _ { + } ^ { n - 1 } V o l ( \Sigma _ { n } ) } { 1 6 \pi G R } . $
# 14  $- i \int d \theta \lambda _ { a } ^ { \dag } ( A _ { \alpha } ) ^ { a b } \lambda _ { b } \partial _ { \theta } X ^ { \alpha } $
# 15  $\nabla ^ { \mu } T _ { \mu \nu } = 0 \, . $
# 16  $\varphi ^ { \mu } { } _ { i \alpha } = \hat { D } _ { i } \varphi _ { \alpha } ^ { \mu } \, , $
# 17  $y \propto \left[ \operatorname { c o t } ( \eta / 2 ) \right] ^ { ( 1 + \sqrt { 1 3 } ) / 2 } , $
# 18  $\{ a _ { \mu } , a _ { \nu } \} = - \delta _ { \mu \nu } \, , $
# 19  $\left. \partial _ { 0 } \phi ( x _ { 0 } , { \bf x } ) \right| _ { x _ { 0 } = \epsilon } \to \epsilon ^ { - \lambda } \partial _ { \epsilon } \phi _ { h } ( \epsilon , { \bf x } ) . $
# 20  $G _ { N } { \frac { | \hat { h } _ { m } ( 0 ) | ^ { 2 } } { e _ { l } } } \sim { \frac { G _ { N } } { y _ { * } } } \approx { \frac { 1 0 ^ { 1 1 } } { M _ { * } ^ { 2 } } } \, . $
# 21  $T ^ { 3 D } \, = \, - 2 i \pi \, \tau ^ { 2 } \, \beta _ { 1 } \beta _ { 2 } \, T ( s _ { 1 } , s _ { 1 } ) \, \tau ^ { 2 } . $
# 22  $K Q ^ { \dagger } e ^ { V } Q | _ { D } \rightarrow m _ { Q } ^ { 2 } | A _ { Q } | ^ { 2 } $
# 23  $\mathrm { { \bf Q } } = \mathrm { d i a g } ( q _ { 1 } , q _ { 2 } , \cdots , q _ { N } ) . $
# 24  $i \Sigma ^ { \pi N } ( p ^ { 2 } ) = 8 G ^ { 2 } [ p _ { \mu } I _ { l i n } ^ { \mu } ( p ^ { 2 } , m ^ { 2 } ) - I _ { q u a d } ( p ^ { 2 } , m ^ { 2 } ) ] $
# 25  $\rho ( s ) \propto \frac { s } { \operatorname { t a n h } ( 2 \pi s ) } ~ . $
# 26  $z _ { 1 } ^ { ( A ) } \simeq 1 - { \frac { E _ { m i n } } { M } } - { \frac { | \vec { P } _ { A - 1 } | ^ { 2 } } { 2 M M _ { A - 1 } } } + \frac { \eta } { M } | \vec { P } _ { A - 1 } | c o s \theta _ { \widehat { \vec { P } _ { A - 1 } \vec { q } } } ~ $
# 27  $\operatorname* { l i m } _ { b j } ( - p \cdot q ) ^ { 5 + l } \left( \xi ^ { 2 } W _ { 4 } \, ^ { + } - 2 \xi W _ { 5 } \, ^ { + } \right) = c ^ { 2 } \phi ( \xi ) \, . $
# 28  $d _ { m } = { \frac { 1 } { r } } { \frac { \partial } { \partial r } } r { \frac { \partial } { \partial r } } - { \frac { m ^ { 2 } } { r ^ { 2 } } } . $
# 29  $\phi _ { 2 } ( z ) = \frac { a _ { 0 } + \cdots + a _ { N } z ^ { N } } { ( 1 + | z | ^ { 2 } ) ^ { N / 2 } } $
# 30  $[ M _ { + - } , P _ { + } ] = i P _ { + } , \ [ M _ { + - } , P _ { - } ] = - i P _ { - } $
# 31  $\beta _ { n } ( \tau ) = b _ { n } e ^ { - i \omega _ { n } \tau } . $
# 32  $\sigma _ { \mathrm { R } } ^ { 2 } ( t ) = v _ { \mathrm { R } } ^ { 2 } ( t ) - \lambda _ { \mathrm { R } } \tilde { I } _ { 1 } ^ { \zeta } ( t ) + O ( \lambda _ { \mathrm { R } } ^ { 2 } ) \, , $
# 33  $f = i e ^ { m z + C _ { 2 } } \, , \qquad g = m z + C _ { 2 } - \operatorname { l o g } ( C _ { 1 } ) \, . $
# 34  $R ( x ) = e ^ { - k r _ { 0 } } \frac { r ( x ) } { \sqrt { 6 } M _ { P l } } . $
# 35  $Y _ { i j } ^ { \; \; \; k } = \sum _ { m } \frac { S _ { m i } P _ { m j } P _ { m } ^ { k } } { S _ { m 0 } } \; \; . $
# 36  $\Gamma ( B \rightarrow X _ { s } \gamma ) _ { L O } ( \mu = \frac { m _ { b } } { 2 } ) \approx \Gamma ( B \rightarrow X _ { s } \gamma ) _ { N L O } \; . $
# 37  $\langle 0 | ( X ^ { 1 } ( \sigma ) - \overline { { X ^ { 1 } } } ) ^ { 2 } | 0 \rangle \ = \ \sum _ { m = 1 } ^ { \infty } \frac { 1 } { m ^ { 2 } } \langle 0 | ( \alpha _ { m } \alpha _ { - m } + \tilde { \alpha } _ { m } \tilde { \alpha } _ { - m } ) | 0 \rangle \ = 2 \sum _ { m = 1 } ^ { \infty } \frac { 1 } { m } . $
# 38  $F _ { 1 } ^ { i } ( x , Q ^ { 2 } ) = \beta _ { i } ( Q ^ { 2 } ) x ^ { - \alpha _ { i } ( 0 ) } . $
# 39  $d s ^ { 2 } = { \frac { r ^ { 2 } } { R ^ { 2 } } } \left( - f d t ^ { 2 } + d { \bf x } ^ { 2 } \right) + { \frac { R ^ { 2 } } { r ^ { 2 } f } } d r ^ { 2 } \, , $
# 40  $P _ { \mu \, i j } + Q _ { \mu \, i j } \equiv L _ { i } ^ { \alpha } ( \partial _ { \mu } \delta _ { \alpha } ^ { \, \beta } - g \, \epsilon _ { \alpha \beta \gamma } A _ { \mu } ^ { \gamma } ) L _ { \beta \; j } , $
# 41  $\hat { \rho } _ { \mathrm { G } } = \left( \operatorname { s i n } \vartheta _ { \mathrm { G } } \operatorname { c o s } \varphi _ { \mathrm { G } } , \operatorname { s i n } \vartheta _ { \mathrm { G } } \operatorname { s i n } \varphi _ { \mathrm { G } } , \operatorname { c o s } \vartheta _ { \mathrm { G } } \right) \, . $
# 42  $\left[ \gamma _ { n } , \gamma _ { m } \right] \ = \ \left[ \beta _ { n } , \beta _ { m } \right] \, = \, 0 \, , \quad \ \left[ \beta _ { n } , \gamma _ { m } \right] \, = \, \delta _ { n + m , 0 } \ . $
# 43  $\widetilde { F } _ { a b } = \widetilde { F } _ { a b } ^ { r } = \widetilde { H } _ { a b c } = \sigma = \chi _ { A } = \psi _ { A \mu } = 0 $
# 44  $\Omega = \frac { 2 i } { \pi } \left( \frac { \delta m ^ { 2 } } { 4 E \hbar } \right) \int _ { t _ { 0 } } ^ { t _ { 0 } ^ { * } } { d t \sqrt { \operatorname { s i n } ^ { 2 } { 2 \theta _ { v } } + ( \zeta ( t ) - \operatorname { c o s } { 2 \theta _ { v } } ) ^ { 2 } } } \, . $
# 45  $2 \kappa N = 1 + N ^ { 2 } + 2 U ^ { 2 } + V ^ { 2 } - 2 V _ { 2 } + 2 \alpha ^ { 2 } W ^ { 2 } B ^ { 2 } - \alpha ^ { 2 } ( C + B ( \kappa - N ) ) ^ { 2 } $
# 46  $\rho _ { 0 } \propto \left| { \frac { G ^ { \prime \prime } ( x = 0 ) } { G ( x = 0 ) } } \right| ^ { \frac { N } { 2 } } . $
# 47  $\mathrm { D } _ { z } ^ { ( s ) } ( E _ { i } ) = z ^ { s _ { i } } E _ { i } \, , ~ ~ ~ \mathrm { D } _ { z } ^ { ( s ) } ( F _ { i } ) = z ^ { - s _ { i } } F _ { i } \, , ~ ~ ~ \mathrm { D } _ { z } ^ { ( s ) } ( h _ { i } ) = h _ { i } \, , ~ ~ ~ i = 0 , \cdots , r $
# 48  $\Gamma ( b , s ) = 1 - e ^ { i \chi ( b , s ) } . $
# 49  $1 - \sqrt { 1 - ( \beta ^ { 2 } - x ) } \simeq ( \beta ^ { 2 } - x ) / 2 \ , $
# 50  $U ^ { \prime } ( \sigma _ { 0 } ) = 0 \mathrm { ~ a n d ~ } U ( \sigma _ { 0 } ) = 0 , $
# 51  $b _ { k } ^ { \mathrm { s } } = \epsilon _ { k i j } \partial _ { i } a _ { j } ^ { \mathrm { s } } = \epsilon _ { k i j } \partial _ { i } \left( \frac { 1 } { 2 i g } \mathrm { t r } \, \tau _ { 3 } \, \Omega _ { \mathrm { D } } \partial _ { j } \Omega _ { \mathrm { D } } ^ { \dagger } \right) , $
# 52  $R _ { | n \rangle } ^ { ( m ) } ( u ) = b _ { n } ^ { m } ( u ) R ^ { ( m ) } ( u ) $
# 53  $\sigma _ { x x } ^ { 2 } + ( \sigma _ { x y } - 1 / 2 ) ^ { 2 } = 1 / 4 \; , $
# 54  $\int d ^ { n } p \, d ^ { n } q \, \frac { p ^ { \mu _ { 1 } } \ldots p ^ { \mu _ { i } } q ^ { \mu _ { i + 1 } } \ldots q ^ { \mu _ { j } } } { ( p ^ { 2 } + m _ { 1 } ^ { 2 } ) ^ { \alpha _ { 1 } } \, ( q ^ { 2 } + m _ { 2 } ^ { 2 } ) ^ { \alpha _ { 2 } } \, [ ( r + k ) ^ { 2 } + m _ { 3 } ^ { 2 } ] ^ { \alpha _ { 3 } } } \; \; . $
# 55  $S _ { s y m } ^ { q , 1 } = 2 w \int _ { y = y _ { - } } ^ { y = y _ { c } } \sqrt { 4 m _ { q } V _ { q p a i r } } ~ d y \quad , $
# 56  ${ \frac { n _ { M } } { s } } \leq 1 0 ^ { - 3 1 } . $
# 57  $\alpha = - 4 ( 8 e _ { 3 8 } + e _ { 1 1 5 } + e _ { 1 1 6 } ) , \quad \beta = 4 e _ { 2 2 } . $
# 58  $\operatorname* { l i m } _ { \beta \rightarrow \infty } { } _ { 1 } F _ { 1 } ( \beta ; \gamma ; z / \beta ) = { } _ { 0 } F _ { 1 } ( \gamma ; z ) , $
# 59  $j ^ { \nu } \, w _ { \nu \sigma } = 0 $
# 60  $\Psi _ { H } ^ { \pi } = V ^ { \alpha _ { s } } \otimes \Psi _ { S } ^ { \pi } . $
# 61  $G _ { A B } ^ { ( 5 ) } = - \Lambda _ { ( 5 ) } g _ { A B } ^ { ( 5 ) } + \kappa _ { ( 5 ) } ^ { 2 } T _ { A B } ^ { ( 5 ) } , $
# 62  $V _ { e f f } ( b o s o n ) = \frac { 1 } { 2 } t r \ \int \frac { d \omega } { 2 \pi } \int _ { 0 } ^ { \infty } \frac { d s } { s } e ^ { i \omega \tau } e x p [ - s ( - \partial _ { \tau } ^ { 2 } + W ( \tau ) ) ] e ^ { - i \omega \tau } \, $
# 63  $\epsilon = \frac { 1 } { \sqrt { 2 } } ( \frac { I m M _ { 1 2 } } { 2 R e M _ { 1 2 } } + \xi _ { 0 } ) e ^ { i \pi / 4 } $
# 64  $d X ^ { \underline { { m } } } = { \frac { 1 } { 2 } } e ^ { + + } u ^ { -- \underline { { m } } } + { \frac { 1 } { 2 } } e ^ { -- } u ^ { + + \underline { { m } } } , $
# 65  $V ( y ) = { \frac { a ^ { 2 } c _ { 2 } - b ^ { 2 } c _ { 1 } \operatorname { s i n h } ( a y ) } { a b \operatorname { c o s h } ( a y ) } } $
# 66  $m _ { \lambda } \simeq { \frac { \langle F _ { X _ { 1 } } \rangle } { M ^ { 3 } } } \simeq \lambda { \frac { v ^ { 8 } } { M ^ { 7 } } } \sim 1 0 ^ { - 4 } \, \mathrm { G e V } . $
# 67  $\bar { R } ^ { 2 } ( m , R ) \, = \, R _ { c } ^ { 2 } \, \left[ 1 \, - \, \frac { 2 4 } { \pi } \, I \left( \frac { M _ { 0 } ^ { 2 } \, R } { m } \right) \right] \, { . } $
# 68  $L = { \frac { 1 } { 2 } } \bigl ( \dot { r } ^ { 2 } + r ^ { 2 } ( \dot { \theta } ^ { 2 } + \operatorname { s i n } ^ { 2 } \theta \dot { \phi } ^ { 2 } ) \bigr ) - \lambda ( r ^ { 2 } - a ^ { 2 } ) ^ { 2 } - \Delta r \operatorname { c o s } \theta . $
# 69  $\frac { \partial V ( \star \phi ) } { \partial \phi } = 0 . $
# 70  $\langle \Gamma _ { 1 } , \widehat { \Gamma _ { 2 } } \rangle = \langle \Gamma _ { 1 } , * _ { X } \Gamma _ { 2 } \rangle = \int _ { X } \Gamma _ { 1 } \wedge * _ { X } \Gamma _ { 2 } . $
# 71  $Z = 1 + \lambda ^ { 2 } \frac { \hbar } { 3 2 \pi ^ { 2 } } ( 1 + \operatorname { l o g } \frac { M ^ { 2 } } { \mu ^ { 2 } } ) $
# 72  $\tilde { \chi } _ { 1 } ^ { 0 } = N _ { 1 1 } \widetilde { B } + N _ { 1 2 } \widetilde { W } ^ { 3 } + N _ { 1 3 } \widetilde { H } _ { 1 } ^ { 0 } + N _ { 1 4 } \widetilde { H } _ { 2 } ^ { 0 } $
# 73  $( M _ { W } ^ { 0 } ) ^ { 2 } = M _ { W } ^ { 2 } \ + \ \delta M _ { W } ^ { 2 } \, , \qquad ( M _ { Z } ^ { 0 } ) ^ { 2 } \ = \ M _ { Z } ^ { 2 } \ + \ \delta M _ { Z } ^ { 2 } \, , $
# 74  $\tau _ { 0 } ( y ) = \sum _ { \sigma _ { 1 } = 0 } ^ { 1 } . . \sum _ { \sigma _ { 4 } = 0 } ^ { 1 } Y _ { \sigma _ { 1 } . . \sigma _ { 4 } } ^ { ( 0 ) } ( t _ { 1 } Z _ { 1 } ) ^ { \sigma _ { 1 } } ( t _ { 2 } Z _ { 2 } ) ^ { \sigma _ { 2 } } ( t _ { 5 } Z _ { 5 } ) ^ { \sigma _ { 3 } } ( t _ { 8 } Z _ { 8 } ) ^ { \sigma _ { 4 } } $
# 75  $h ^ { \mu } ( P , \rho n - k ) \equiv e ^ { ( a ) \mu } s ( P , k ) \, $
# 76  $0 = 4 a \left( \frac { d \bar { \phi } } { d A } \right) ^ { 2 } - \frac { 2 } { P ( A ) } \frac { d P ( A ) } { d A } \frac { d \bar { \phi } } { d A } - \frac { \bar { f } _ { 0 } ^ { 2 } } { 2 P ^ { 2 } ( A ) } + \frac { 2 \bar { Q } + \mu e ^ { - 4 a \bar { \phi } } / \bar { Q } } { 4 P ( A ) } , $
# 77  ${ \cal M } = \left[ { \frac { S U ( 1 , 1 ) } { U ( 1 ) } } \otimes { \frac { S U ( 1 , 1 ) } { U ( 1 ) } } \right] ^ { 3 } . $
# 78  $( ( \Gamma ^ { ( i n t ) } ) ^ { 2 } = 1 ) | \Phi \rangle , $
# 79  ${ \cal L } = { \cal L } ^ { ( 2 ) } + { \cal L } ^ { ( 4 ) } , $
# 80  $E _ { h y p } \equiv { \frac { 3 2 \pi } { 9 } } \alpha _ { s } ( \mu ) { \frac { \left| \psi ( 0 ) \right| ^ { 2 } } { m _ { h } m _ { n } } } \; \propto \; \alpha _ { s } ( \mu ) \, { \frac { \mu b } { m _ { h } m _ { n } } } $
# 81  $\tilde { a } _ { \tilde { n } } ^ { \alpha } = \int _ { 0 } ^ { \pi } ~ \frac { d \sigma _ { - } } { \pi } \operatorname { e x p } \left[ 4 i \tilde { n } \frac { e _ { \mu } X _ { R } ^ { \mu } ( \sigma _ { - } ) } { e _ { \mu } P _ { R } ^ { \mu } } \right] \xi _ { i } ^ { \alpha } \partial _ { - } X _ { R } ^ { i } ( \sigma _ { - } ) $
# 82  $G _ { \mu } ^ { \pm } ( x , \varepsilon ) = \frac 1 2 ( G _ { \mu } ( x , \varepsilon ) \pm G _ { \mu } ( x , - \varepsilon ) ) , $
# 83  $\Theta _ { t } ( z ) = ( z ; t ) _ { \infty } ( t z ^ { - 1 } ; t ) _ { \infty } ( t ; t ) _ { \infty } , $
# 84  $d s _ { C F T } ^ { 2 } = \operatorname* { l i m } _ { r \to \infty } \left[ { \frac { l ^ { 2 } } { r ^ { 2 } } } d s _ { n + 2 } ^ { 2 } \right] = - d t ^ { 2 } + l ^ { 2 } \gamma _ { i j } d x ^ { i } d x ^ { j } . $
# 85  $\Lambda [ A ^ { I } , J ] \; = \; \varepsilon ^ { k } \frac { 1 } { \Delta } \left[ ( \partial _ { 0 } A _ { k } ^ { I } ) + \partial _ { k } J _ { 0 } \right] \; . $
# 86  $\widetilde \psi ( x ^ { \alpha } , z ^ { \prime } ) = \widetilde \Psi ( x ^ { \alpha } , L _ { 6 } + z ^ { \prime } ) $
# 87  $M _ { \sigma } = 4 6 3 \; \mathrm { M e V } \; \; , \; \; \Gamma _ { \sigma } = 3 9 3 \; \mathrm { M e V } . $
# 88  $W ^ { ( m ) } = e ^ { Q } \, ( X ^ { + } W ^ { - } + X ^ { - } W ^ { + } ) \; . $
# 89  $( F , F ) = \int _ { M ^ { D } } T r ( \tilde { F } \wedge F ) $
# 90  $Z = \int { \cal D } ( g , \Phi ) \; \operatorname { e x p } [ - I _ { E } ( g , \Phi ) / \hbar ] . $
# 91  $\bar { \alpha } _ { R G } ^ { ( 1 ) } ( x , 0 , \alpha ) = \frac { \alpha } { 1 - \frac { \alpha } { 3 \pi } \cdot \operatorname { l n } x } $
# 92  $\Psi _ { ( \omega _ { 0 } , \vec { k } _ { 0 } ) } = e ^ { - i \vec { k } _ { 0 } { \cdot } \vec { x } } \left[ \int e ^ { - i \Delta \vec { k } { \cdot } \vec { x } } e ^ { i \Delta \omega t } d \mu \right] e ^ { i \omega _ { 0 } t } \! $
# 93  $\left( \begin{array} { c c } { a } & { b } \\ { c } & { d } \\ \end{array} \right) \left( \begin{array} { c } { \tau } \\ { 1 } \\ \end{array} \right) $
# 94  $S _ { \varepsilon , \lambda } = { \mathrm T } \operatorname { e x p } \left( - { \mathrm i } \lambda \, \int _ { - \infty } ^ { \infty } { \mathrm d } t \int { \mathrm d } ^ { 3 } x \, \operatorname { e x p } ( - \varepsilon | t | ) \, { \mathcal H } _ { \mathrm I } ( x ) \right) $
# 95  $\xi _ { r } ( t ) \ = \ e ^ { - i r ( t - t _ { i } ) / \rho } \xi _ { i r } \ , \ \xi _ { r } ^ { * } \ = \ e ^ { - i r ( t _ { f } - t ) / \rho } \xi _ { f r } ^ { * } \ , $
# 96  $\vec { T } _ { 0 } ^ { 1 } \vec { T } _ { 1 } ^ { 1 } \; = \; s _ { - 1 } ^ { r - 1 } s _ { 1 } ^ { r - 1 } f _ { - 1 } ^ { 1 } f _ { 1 } ^ { 1 } \, \vec { I } + s _ { 0 } ^ { r - 1 } f _ { 0 } ^ { 1 } \, \vec { T } _ { 0 } ^ { 2 } $
# 97  $2 \, g _ { u v } \, \dot { u } \, \dot { v } = - ( { \frac { p _ { x } ^ { 2 } } { g _ { x x } } } + { \frac { p _ { y } ^ { 2 } } { g _ { y y } } } ) . $
# 98  $\theta _ { 1 3 } = \Gamma _ { 1 } e ^ { - \sum \lambda ^ { n } t _ { n } } \; \; ; \; \; \theta _ { 2 3 } = \Gamma _ { 2 } e ^ { - \sum \lambda ^ { n } t _ { n } } \; \; ; \; \; \theta _ { 3 3 } = \psi _ { B A } e ^ { - \sum \lambda ^ { n } t _ { n } } \, , $
# 99  $f ^ { \prime } ( s ) - f ^ { \prime } ( u ) + \frac { 1 } { 3 } ( 2 g ^ { \prime } ( s ) + g ^ { \prime } ( u ) ) + \frac { 1 } { 3 } ( h ( u ) + 2 h ( t ) ) - \frac { 1 } { 3 } ( s - t ) h ^ { \prime } ( u ) = 0 , $
#
#     $\mathbf{\hat{y}}$_len  \
# 0   51
# 1   121
# 2   73
# 3   125
# 4   71
# 5   113
# 6   59
# 7   42
# 8   74
# 9   75
# 10  102
# 11  56
# 12  75
# 13  42
# 14  41
# 15  15
# 16  32
# 17  30
# 18  23
# 19  55
# 20  72
# 21  52
# 22  38
# 23  34
# 24  74
# 25  25
# 26  104
# 27  67
# 28  55
# 29  49
# 30  45
# 31  27
# 32  75
# 33  44
# 34  36
# 35  55
# 36  50
# 37  115
# 38  45
# 39  67
# 40  68
# 41  88
# 42  63
# 43  51
# 44  90
# 45  68
# 46  42
# 47  113
# 48  21
# 49  30
# 50  33
# 51  87
# 52  39
# 53  33
# 54  145
# 55  57
# 56  23
# 57  41
# 58  42
# 59  14
# 60  30
# 61  58
# 62  91
# 63  50
# 64  61
# 65  55
# 66  64
# 67  63
# 68  85
# 69  18
# 70  58
# 71  47
# 72  76
# 73  83
# 74  141
# 75  28
# 76  119
# 77  45
# 78  23
# 79  27
# 80  79
# 81  122
# 82  47
# 83  43
# 84  89
# 85  58
# 86  41
# 87  38
# 88  39
# 89  25
# 90  35
# 91  46
# 92  80
# 93  39
# 94  80
# 95  80
# 96  108
# 97  64
# 98  100
# 99  95
#
#    $\mathbf{\hat{y}}$                                                                                                                                                                                                                                                                                                                                                                          \
# 0   $E ( z + n \cdot \alpha + m \cdot \beta , z ) = e ^ { - \pi i m \cdot \Omega \cdot m - 2 \pi i m \cdot ( I ( z ) - I ( w ) ) } E ( z , w ) . $
# 1   $\Gamma ( b \to J / \psi + X ) = \frac { G _ { F } ^ { 2 } } { 1 4 4 \pi } | V _ { c b } | ^ { 2 } m _ { c } m _ { b } ^ { 3 } \left( 1 - \frac { 4 m _ { c } ^ { 2 } } { m _ { b } ^ { 2 } } \right) ^ { 2 } \left[ a \left( 1 + \frac { 8 m _ { c } ^ { 2 } } { m _ { b } ^ { 2 } } \right) + b \right] , $
# 2   $S _ { c } ^ { ( 1 ) > } ( x ^ { 0 } - i \beta - y ^ { 0 } , \vec { p } ) = - e ^ { - \beta \mu } S _ { c } ^ { ( 1 ) < } ( x ^ { 0 } - y ^ { 0 } , \vec { p } ) . $
# ...
# 58  \operatorname* { l i m } _ { \beta \rightarrow \infty } \Gamma _ { 1 } ( \beta ; \gamma ; z / \beta ) = _ { 0 } F _ { 1 } ( \gamma ; z ) ,
# 59  j ^ { \nu } \, w _ { \nu \sigma } = 0
# 60  \Psi _ { H } ^ { \pi } = V ^ { \alpha _ { s } } \otimes \Psi _ { S } ^ { \pi } .
# 61  G _ { A B } ^ { ( 5 ) } = - \Lambda _ { ( 5 ) } g _ { A B } ^ { ( 5 ) } + \kappa _ { ( 5 ) } ^ { 2 } T _ { A B } ^ { ( 5 ) } ,
# 62  V _ { e f f } ( b o s o n ) = \frac { 1 } { 2 } t r \; \int \frac { d \omega } { 2 \pi } \int _ { 0 } ^ { \infty } \frac { d s } { s } e ^ { i \omega \tau } e x p [ - s ( - \partial _ { \tau } ^ { 2 } + W ( \tau ) ) ] e ^ { - i \omega \tau }
# 63  \epsilon = \frac { 1 } { \sqrt { 2 } } ( \frac { I m M _ { 1 2 } } { 2 R e M _ { 1 2 } } + \xi _ { 0 } ) e ^ { i \pi / 4 }
# 64  d X ^ { \underline { m } } = { \frac { 1 } { 2 } } e ^ { + + } u ^ { -- } \longrightarrow _ { \underline { m } } + { \frac { 1 } { 2 } } e ^ { -- } u ^ { + + m } ,
# 65  V ( y ) = \frac { a ^ { 2 } c _ { 2 } - b ^ { 2 } c _ { 1 } \operatorname { s i n h } ( a y ) } { a b \operatorname { c o s h } ( a y ) }
# 66  m _ { \lambda } \simeq \frac { \langle F _ { X _ { 1 } } \rangle } { M ^ { 3 } } \simeq \lambda ^ { 2 } \frac { v ^ { 8 } } { M ^ { 7 } } \sim 1 0 ^ { - 4 } \, \mathrm { G e V } .
# 67  \bar { R } ^ { 2 } ( m , R ) \, = \, R _ { c } ^ { 2 } \, \left[ 1 \, - \, \frac { 2 4 } { \pi } \, I \left( \frac { M _ { 0 } ^ { 2 } \, R } { m } \right) \right] \, .
# 68  L = \frac { 1 } { 2 } ( \dot { r } ^ { 2 } + r ^ { 2 } ( \dot { \theta } ^ { 2 } + \operatorname { s i n } ^ { 2 } \theta \dot { \phi } ^ { 2 } ) ) - \lambda ( r ^ { 2 } - a ^ { 2 } ) ^ { 2 } - \Delta r \operatorname { c o s } \theta .
# 69  { \frac { \partial V ( * \phi ) } { \partial \phi } } = 0 .
# 70  \langle \Gamma _ { 1 } , \widetilde { \Gamma } _ { 2 } \rangle = \langle \Gamma _ { 1 } , * _ { X } \Gamma _ { 2 } \rangle = \int _ { X } \Gamma _ { 1 } \wedge * _ { X } \Gamma _ { 2 } .
# 71  Z = 1 + \lambda ^ { 2 } \frac { \hbar } { 3 2 \pi ^ { 2 } } ( 1 + \operatorname { l o g } \frac { M ^ { 2 } } { \mu ^ { 2 } } )
# 72  \tilde { \chi } _ { 1 } ^ { 0 } = N _ { 1 1 } \widetilde { B } + N _ { 1 2 } \widetilde { W } ^ { 3 } + N _ { 1 3 } \widetilde { H } _ { 1 } ^ { 0 } + N _ { 1 4 } \widetilde { H } _ { 2 } ^ { 0 }
# 73  ( M _ { W } ^ { 0 } ) ^ { 2 } = M _ { W } ^ { 2 } \ + \ \delta M _ { W } ^ { 2 } \, , \qquad ( M _ { Z } ^ { 0 } ) ^ { 2 } \ = \ M _ { Z } ^ { 2 } \ + \ \delta M _ { Z } ^ { 2 } \, ,
# 74  \tau _ { 0 } ( y ) = \sum _ { \sigma _ { 1 } = 0 } ^ { 1 } \cdot \lambda _ { e _ { 1 } = 0 } ^ { 1 } Y _ { \sigma _ { 1 } \cdots a _ { 1 } } ^ { ( 0 ) } ( t _ { 1 } Z _ { 1 } ) ^ { \sigma _ { 1 } } ( t _ { 2 } Z _ { 2 } ) ^ { \sigma _ { 2 } } ( t _ { 5 } Z _ { 5 } ) ^ { \sigma _ { 3 } } ( t _ { 8 } Z _ { 8 } ) ^ { \sigma _ { 4 } }
# 75  h ^ { \mu } ( P , \rho m - k ) \equiv e ^ { ( a ) \mu } s ( P , k )
# 76  0 = 4 a \left( \frac { d \bar { \phi } } { d A } \right) ^ { 2 } - \frac { 2 } { P ( A ) } \frac { d P ( A ) } { d A } \frac { d \bar { \phi } } { d A } - \frac { \bar { f } _ { 0 } ^ { 2 } } { 2 P ^ { 2 } ( A ) } + \frac { 2 \bar { Q } + \mu e ^ { - 4 a \vec { \phi } } / \bar { Q } } { 4 P ( A ) } ,
# 77  { \cal M } = \left[ \frac { S U ( 1 , 1 ) } { U ( 1 ) } \otimes \frac { S U ( 1 , 1 ) } { U ( 1 ) } \right] ^ { 3 } .
# 78  ( ( \Gamma ^ { ( i n t ) } ) ^ { 2 } = 1 ) | \Phi \rangle ,
# 79  { \cal L } = { \cal L } ^ { ( 2 ) } + { \cal L } ^ { ( 4 ) } ,
# 80  E _ { l h p } \equiv \frac { 3 2 \pi } { 9 } \alpha _ { s } ( \mu ) \frac { | \psi ( 0 ) | ^ { 2 } } { m _ { h } m _ { n } } \; \propto \; \alpha _ { s } ( \mu ) \, \frac { \mu b } { m _ { h } m _ { n } }
# 81  \tilde { a } _ { \tilde { n } } ^ { \alpha } = \int _ { 0 } ^ { \pi } ~ \frac { d \sigma _ { - } } { \pi } \operatorname { e x p } \left[ 4 i \tilde { n } \frac { e _ { \mu } X _ { R } ^ { \mu } ( \sigma _ { - } ) } { e _ { \mu } P _ { R } ^ { \mu } } \right] \xi _ { i } ^ { \alpha } \partial _ { - } X _ { R } ^ { i } ( \sigma _ { - } )
# 82  G _ { \mu } ^ { \pm } ( x , \varepsilon ) = \frac { 1 } { 2 } ( G _ { \mu } ( x , \varepsilon ) \pm G _ { \mu } ( x , - \varepsilon ) ) ,
# 83  \Theta _ { t } ( z ) = ( z ; t ) _ { \infty } ( t z ^ { - 1 } ; t ) _ { \infty } ( t ; t ) _ { \infty } ,
# 84  d s _ { C F T } ^ { 2 } = \operatorname* { l i m } _ { r \rightarrow \infty } \left[ { \frac { l ^ { 2 } } { r ^ { 2 } } } d s _ { n + 2 } ^ { 2 } \right] = - d t ^ { 2 } + l ^ { 2 } \gamma _ { i j } d x ^ { i } d x ^ { j } .
# 85  \Lambda [ A ^ { I } , J ] ~ = ~ \varepsilon ^ { k } { \frac { 1 } { \Delta } } \left[ ( \partial _ { 0 } A _ { k } ^ { I } ) + \partial _ { k } J _ { 0 } \right] ~ .
# 86  \widetilde { \psi } ( x ^ { \alpha } , z ^ { \prime } ) = \widetilde { \Psi } ( x ^ { \alpha } , L _ { 6 } + z ^ { \prime } )
# 87  M _ { \sigma } = 4 6 3 \ \mathrm { M e V } \ \ , \ \ \Gamma _ { \sigma } = 3 9 3 \ \mathrm { M e V } .
# 88  W ^ { ( m ) } = e ^ { Q } \, ( X ^ { + } W ^ { - } + X ^ { - } W ^ { + } ) \; .
# 89  ( F , F ) = \int _ { M ^ { D } } T r ( \tilde { F } \wedge F )
# 90  Z = \int { \cal D } ( g , \Phi ) \ \operatorname { e x p } [ - I _ { E } ( g , \Phi ) / \hbar ] .
# 91  \bar { \alpha } _ { R G } ^ { ( 1 ) } ( x , 0 , \alpha ) = \frac { \alpha } { 1 - \frac { \alpha } { 3 \pi } \cdot \operatorname { l n } x }
# 92  \Psi _ { ( \omega _ { 0 } , \vec { k } _ { 0 } ) } = e ^ { - i \vec { k } _ { 0 } \cdot \vec { x } } \left[ \int e ^ { - i \Delta \vec { k } \cdot \vec { e } } e ^ { i \omega \omega t } d \mu \right] e ^ { i \omega _ { 0 } t }
# 93  \left( \begIn{array} { c c } { a } & { b } \\ { c } & { d } \\ \end{array} \right) \left( \begIn{array} { c } { \tau } \\ { 1 } \\ \end{array} \right)
# 94  S _ { \varepsilon , \lambda } = \mathrm { T } \operatorname { e x p } \left( - \mathrm { i } \lambda \int _ { - \infty } ^ { \infty } \mathrm { d } t \int \mathrm { d } ^ { 3 } x ~ \operatorname { e x p } ( - \varepsilon | t | ) \, { \cal H } _ { \mathrm { l } } ( x ) \right)
# 95  \xi _ { r } ( t ) \; = \; e ^ { - i r ( t - t _ { i } ) / \rho } \xi _ { i r } \; , \; \xi _ { r } ^ { \ast } \; = \; e ^ { - i r ( t _ { f } - t ) / \rho } \xi _ { f r } ^ { \ast } \; ,
# 96  \vec { T } _ { 0 } ^ { 1 } \vec { T } _ { 1 } ^ { 1 } \; = \; s _ { - 1 } ^ { r - 1 } s _ { 1 } ^ { r - 1 } f _ { - 1 } ^ { 1 } f _ { 1 } ^ { 1 } \; \vec { I } + s _ { 0 } ^ { r - 1 } f _ { 0 } ^ { 1 } \, \vec { T } _ { 0 } ^ { 2 }
# 97  2 \, g _ { u v } \, \dot { u } \, \dot { v } = - ( \frac { p _ { x } ^ { 2 } } { g _ { x x } } + \frac { p _ { y } ^ { 2 } } { g _ { y y } } ) .
# 98  \theta _ { 1 3 } = \Gamma _ { 1 } e ^ { - \sum \lambda ^ { n } t _ { n } } \ \ ; \ \ \theta _ { 2 3 } = \Gamma _ { 2 } e ^ { - \sum \lambda ^ { n } t _ { n } } \ \ ; \ \ \theta _ { 3 3 } = \psi _ { B A } e ^ { - \sum _ { \lambda } ^ { n } l _ { n } } \, ,
# 99  f ^ { \prime } ( s ) - f ^ { \prime } ( u ) + { \frac { 1 } { 3 } } ( 2 g ^ { \prime } ( s ) + g ^ { \prime } ( u ) ) + { \frac { 1 } { 3 } } ( h ( u ) + 2 h ( t ) ) - { \frac { 1 } { 3 } } ( s - t ) h ^ { \prime } ( u ) = 0 ,
