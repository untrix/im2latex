# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import pandas as pd
import os
import re
import codecs
from IPython.display import display
from six.moves import cPickle as pickle
import string
from PIL import Image
import numpy as np
import h5py

# %%
width = None
pd.options.display.max_rows = 600
pd.options.display.max_columns = width
pd.options.display.max_colwidth = 600
pd.options.display.width = width
pd.options.display.max_seq_items = None
pd.options.display.expand_frame_repr = False
pd.options.display.colheader_justify = 'left'

# %%
import data_commons as dtc
import dl_commons as dlc
import viz_commons as vc
from viz_commons import VisualizeDir, DiffParams, VisualizeStep
# Out:
# Using TensorFlow backend.

# %%
# diff = DiffParams('/zpool_3TB/i2l/tb_metrics/2017-11-20 23-11-24 PST 81.76bleu2_3.1LSTM_2init_3OutMLP_3attMLPfull_regroupImage_i=2', '/zpool_3TB/i2l/tb_metrics/2017-11-20 23-11-24 PST 81.76bleu2_3.1LSTM_2init_3OutMLP_3attMLPfull_regroupImage_i=2/82.89_train_snapshot-00087700_target_ase')
# diff = DiffParams('/zpool_3TB/i2l/tb_metrics/2017-11-20 23-11-24 PST 81.76bleu2_3.1LSTM_2init_3OutMLP_3attMLPfull_regroupImage_i=2', './tb_metrics/2017-11-28 15-54-35 PST scanningRNN_regroupImage')
# diff = DiffParams('./tb_metrics/2017-11-27 21-20-46 PST scanningRNN_regroupImage', './tb_metrics/2017-11-28 15-54-35 PST scanningRNN_regroupImage')
diff = DiffParams('/zpool_3TB/i2l/tb_metrics/2017-11-20 23-11-24 PST 81.76bleu2_3.1LSTM_2init_3OutMLP_3attMLPfull_regroupImage_i=2', './tb_metrics/2017-12-04 13-19-02 PST')
# diff = DiffParams('./tb_metrics/2017-11-28 01-40-26 PST scanningRNN_regroupImage', './tb_metrics/2017-11-28 15-54-35 PST scanningRNN_regroupImage')
one, two = diff.get_hyper()
diff.hyper()
# Out:
#   0                                                     1
# 0       CALSTM_STACK_1.feed_clock_to_att ===> undefined             CALSTM_STACK_1.feed_clock_to_att ===> None
# 1                             target_ase ===> undefined                                   target_ase ===> 5.27
# 2  CALSTM_STACK_1.att_layers.layers_1.num_units ===> 99  CALSTM_STACK_1.att_layers.layers_1.num_units ===> 256
# 3              output_layers.layers_2.num_units ===> 64              output_layers.layers_2.num_units ===> 358
# 4                     tf_session_allow_growth ===> True                     tf_session_allow_growth ===> False
# 5        CALSTM_STACK_1.no_clock_to_lstm ===> undefined              CALSTM_STACK_1.no_clock_to_lstm ===> None
# 6              output_layers.layers_1.num_units ===> 64              output_layers.layers_1.num_units ===> 358
# 7  CALSTM_STACK_1.att_layers.layers_2.num_units ===> 99  CALSTM_STACK_1.att_layers.layers_2.num_units ===> 128
#    0                                                                                                                           1
# 0                                             init_model_final_layers.weights_regularizer ===> <function l2 at 0x7fca82c75c80>                                            init_model_final_layers.weights_regularizer ===> <function l2 at 0x7fca82cc4848>
# 1                                                         CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7fca82ccfa90>                                                        CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7fca82ccf890>
# 2                                          CONVNET.layers_2.weights_initializer ===> <function _initializer at 0x7fca82c75f50>                                         CONVNET.layers_2.weights_initializer ===> <function _initializer at 0x7fcad297a398>
# 3                                                                           CALSTM_STACK_1.tb.tb_logdir ===> ./tb_metrics_dev/                                                                               CALSTM_STACK_1.tb.tb_logdir ===> ./tb_metrics
# 4   CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fcad2979610>  CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fca82ccf810>
# 5                                          CONVNET.layers_8.weights_initializer ===> <function _initializer at 0x7fca82c75f50>                                         CONVNET.layers_8.weights_initializer ===> <function _initializer at 0x7fcad297a398>
# 6                                  CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7fca82c75c80>                                 CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7fca82cc4848>
# 7                                          init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7fca82c75c80>                                         init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7fca82cc4848>
# 8                                                       CALSTM_STACK_1.att_layers.layers_1.tb.tb_logdir ===> ./tb_metrics_dev/                                                           CALSTM_STACK_1.att_layers.layers_1.tb.tb_logdir ===> ./tb_metrics
# 9                                                    CONVNET.layers_2.weights_regularizer ===> <function l2 at 0x7fca82c75c80>                                                   CONVNET.layers_2.weights_regularizer ===> <function l2 at 0x7fca82cc4848>
# 10                                                                       init_model_hidden.tb.tb_logdir ===> ./tb_metrics_dev/                                                                            init_model_hidden.tb.tb_logdir ===> ./tb_metrics
# 11                      CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fcad2979610>                      CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fca82ccf810>
# 12              output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fcad2979610>              output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fca82ccf810>
# 13                                         CONVNET.layers_6.weights_initializer ===> <function _initializer at 0x7fca82c75f50>                                         CONVNET.layers_6.weights_initializer ===> <function _initializer at 0x7fcad297a398>
# 14                               init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7fca82c75f50>                               init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7fcad297a398>
# 15                output_layers.layers_1.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/                                                                              output_layers.layers_1.tb.logdir_tag ===> None
# 16                                         CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7fca82c75f50>                                         CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7fcad297a398>
# 17                       CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7fca82c75f50>                       CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7fcad297a398>
# 18                                     biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fcad2979610>                                     biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fca82ccf810>
# 19                                                               CALSTM_STACK_1.att_layers.tb.tb_logdir ===> ./tb_metrics_dev/                                                                    CALSTM_STACK_1.att_layers.tb.tb_logdir ===> ./tb_metrics
# 20          init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fcad2979610>          init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fca82ccf810>
# 21                    CONVNET.layers_6.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fcad2979610>                    CONVNET.layers_6.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fca82ccf810>
# 22                                        CONVNET.layers_10.weights_initializer ===> <function _initializer at 0x7fca82c75f50>                                        CONVNET.layers_10.weights_initializer ===> <function _initializer at 0x7fcad297a398>
# 23                        CALSTM_STACK_1.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/                                                                                      CALSTM_STACK_1.tb.logdir_tag ===> None
# 24                                                   CONVNET.layers_4.weights_regularizer ===> <function l2 at 0x7fca82c75c80>                                                   CONVNET.layers_4.weights_regularizer ===> <function l2 at 0x7fca82cc4848>
# 25                                                       embeddings_initializer ===> <function _initializer at 0x7fca82c75f50>                                                       embeddings_initializer ===> <function _initializer at 0x7fcad297a398>
# 26                                             output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7fca82c75c80>                                             output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7fca82cc4848>
# 27                    CONVNET.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fcad2979610>                    CONVNET.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fca82ccf810>
# 28  CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fcad2979610>  CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fca82ccf810>
# 29                                                                    weights_regularizer ===> <function l2 at 0x7fca82c75c80>                                                                    weights_regularizer ===> <function l2 at 0x7fca82cc4848>
# 30                                                                 init_model_final_layers.tb.tb_logdir ===> ./tb_metrics_dev/                                                                      init_model_final_layers.tb.tb_logdir ===> ./tb_metrics
# 31                                                                  output_layers.layers_3.tb.tb_logdir ===> ./tb_metrics_dev/                                                                       output_layers.layers_3.tb.tb_logdir ===> ./tb_metrics
# 32                       CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7fca82c75f50>                       CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7fcad297a398>
# 33            init_model_hidden.layers_1.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/                                                                          init_model_hidden.layers_1.tb.logdir_tag ===> None
# 34                                 CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7fca82c75c80>                                 CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7fca82cc4848>
# 35                output_layers.layers_3.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/                                                                              output_layers.layers_3.tb.logdir_tag ===> None
# 36               init_model_final_layers.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/                                                                             init_model_final_layers.tb.logdir_tag ===> None
# 37                                         CONVNET.layers_4.weights_initializer ===> <function _initializer at 0x7fca82c75f50>                                         CONVNET.layers_4.weights_initializer ===> <function _initializer at 0x7fcad297a398>
# 38                                 CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7fca82c75c80>                                 CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7fca82cc4848>
# 39                                                                       logger ===> <logging.Logger object at 0x7fca82ccfa90>                                                                       logger ===> <logging.Logger object at 0x7fca82ccf890>
# 40                                                  CONVNET.layers_10.weights_regularizer ===> <function l2 at 0x7fca82c75c80>                                                  CONVNET.layers_10.weights_regularizer ===> <function l2 at 0x7fca82cc4848>
# 41             CALSTM_STACK_1.att_layers.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/                                                                           CALSTM_STACK_1.att_layers.tb.logdir_tag ===> None
# 42                   CONVNET.layers_10.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fcad2979610>                   CONVNET.layers_10.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fca82ccf810>
# 43                         output_layers.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/                                                                                       output_layers.tb.logdir_tag ===> None
# 44                                             output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7fca82c75c80>                                             output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7fca82cc4848>
# 45                                       tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/                                                                                                     tb.logdir_tag ===> None
# 46                                   output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7fca82c75f50>                                   output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7fcad297a398>
# 47                                  init_model_final_layers.weights_initializer ===> <function _initializer at 0x7fca82c75f50>                                  init_model_final_layers.weights_initializer ===> <function _initializer at 0x7fcad297a398>
# 48                                                                           output_layers.tb.tb_logdir ===> ./tb_metrics_dev/                                                                                output_layers.tb.tb_logdir ===> ./tb_metrics
# 49                                                              init_model_hidden.layers_1.tb.tb_logdir ===> ./tb_metrics_dev/                                                                   init_model_hidden.layers_1.tb.tb_logdir ===> ./tb_metrics
# 50                                                     CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7fca82c75c80>                                                     CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7fca82cc4848>
# 51                    CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fcad2979610>                    CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fca82ccf810>
# 52                     init_model_hidden.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/                                                                                   init_model_hidden.tb.logdir_tag ===> None
# 53                                   output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7fca82c75f50>                                   output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7fcad297a398>
# 54    CALSTM_STACK_1.att_layers.layers_1.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/                                                                  CALSTM_STACK_1.att_layers.layers_1.tb.logdir_tag ===> None
# 55                                             output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7fca82c75c80>                                             output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7fca82cc4848>
# 56                               CONVNET.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/                                                                                             CONVNET.tb.logdir_tag ===> None
# 57                                                      CALSTM_STACK_1.att_layers.layers_2.tb.tb_logdir ===> ./tb_metrics_dev/                                                           CALSTM_STACK_1.att_layers.layers_2.tb.tb_logdir ===> ./tb_metrics
# 58                                                      CALSTM_STACK_1.att_layers.layers_3.tb.tb_logdir ===> ./tb_metrics_dev/                                                           CALSTM_STACK_1.att_layers.layers_3.tb.tb_logdir ===> ./tb_metrics
# 59                                           CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7fca82c75f50>                                           CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7fcad297a398>
# 60                                                             CALSTM_STACK_1.decoder_lstm.tb.tb_logdir ===> ./tb_metrics_dev/                                                                  CALSTM_STACK_1.decoder_lstm.tb.tb_logdir ===> ./tb_metrics
# 61           CALSTM_STACK_1.decoder_lstm.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/                                                                         CALSTM_STACK_1.decoder_lstm.tb.logdir_tag ===> None
# 62                                                                                         tb.tb_logdir ===> ./tb_metrics_dev/                                                                                              tb.tb_logdir ===> ./tb_metrics
# 63                                        CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7fca82c75c80>                                        CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7fca82cc4848>
# 64    CALSTM_STACK_1.att_layers.layers_2.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/                                                                  CALSTM_STACK_1.att_layers.layers_2.tb.logdir_tag ===> None
# 65                                                   CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7fca82c75c80>                                                   CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7fca82cc4848>
# 66                                                   CONVNET.layers_6.weights_regularizer ===> <function l2 at 0x7fca82c75c80>                                                   CONVNET.layers_6.weights_regularizer ===> <function l2 at 0x7fca82cc4848>
# 67                    CONVNET.layers_4.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fcad2979610>                    CONVNET.layers_4.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fca82ccf810>
# 68                                                                  output_layers.layers_2.tb.tb_logdir ===> ./tb_metrics_dev/                                                                       output_layers.layers_2.tb.tb_logdir ===> ./tb_metrics
# 69                output_layers.layers_2.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/                                                                              output_layers.layers_2.tb.logdir_tag ===> None
# 70             init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fcad2979610>             init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fca82ccf810>
# 71                              CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7fca82c75f50>                              CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7fcad297a398>
# 72              output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fcad2979610>              output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fca82ccf810>
# 73                       CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7fca82c75f50>                       CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7fcad297a398>
# 74                                                                                 CONVNET.tb.tb_logdir ===> ./tb_metrics_dev/                                                                                      CONVNET.tb.tb_logdir ===> ./tb_metrics
# 75                                   output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7fca82c75f50>                                   output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7fcad297a398>
# 76    CALSTM_STACK_1.att_layers.layers_3.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/                                                                  CALSTM_STACK_1.att_layers.layers_3.tb.logdir_tag ===> None
# 77                                                   CONVNET.layers_8.weights_regularizer ===> <function l2 at 0x7fca82c75c80>                                                   CONVNET.layers_8.weights_regularizer ===> <function l2 at 0x7fca82cc4848>
# 78              output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fcad2979610>              output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fca82ccf810>
# 79                    CONVNET.layers_8.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fcad2979610>                    CONVNET.layers_8.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fca82ccf810>
# 80                                                          weights_initializer ===> <function _initializer at 0x7fca82c75f50>                                                          weights_initializer ===> <function _initializer at 0x7fcad297a398>
# 81  CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fcad2979610>  CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fca82ccf810>
# 82                                                                  output_layers.layers_1.tb.tb_logdir ===> ./tb_metrics_dev/                                                                       output_layers.layers_1.tb.tb_logdir ===> ./tb_metrics
# 83                                                                 embeddings_regularizer ===> <function l2 at 0x7fca82c75c80>                                                                 embeddings_regularizer ===> <function l2 at 0x7fca82cc4848>

# %%
one['REGROUP_IMAGE']
# Out:
# [4, 1]

# %%
diff = DiffParams('./tb_metrics/2017-11-28 08-34-47 PST scanningRNN_regroupImage', './tb_metrics/2017-11-28 01-40-26 PST scanningRNN_regroupImage')
one, two = diff.get_hyper()
print('lambda', one['pLambda'], two['pLambda'])
diff.hyper()

# %%
diff = DiffParams('./tb_metrics/2017-11-28 01-40-26 PST scanningRNN_regroupImage', './tb_metrics/2017-11-28 15-54-35 PST scanningRNN_regroupImage')
one, two = diff.get_hyper()
print('lambda', one['pLambda'], two['pLambda'])
diff.hyper()

# %%
diff = DiffParams('/zpool_3TB/i2l/tb_metrics/2017-11-27 21-20-46 PST scanningRNN_regroupImage', './tb_metrics/2017-12-02 21-07-08 PST scanningRNN_regroupImage')
one, two = diff.get_hyper()
print('pLambda', one['pLambda'], two['pLambda'])
diff.hyper()
# Out:
# ('pLambda', 0.0, 0.05)
#    0                                                     1
# 0                CALSTM_STACK_1.decoder_lstm.i ===> 2051                CALSTM_STACK_1.decoder_lstm.i ===> 2048
# 1                                   target_ase ===> 15.0                                   target_ase ===> 5.27
# 2                                  adam_alpha ===> 0.001                                 adam_alpha ===> 0.0005
# 3   CALSTM_STACK_1.att_layers.layers_1.num_units ===> 99  CALSTM_STACK_1.att_layers.layers_1.num_units ===> 256
# 4        CALSTM_STACK_1.feed_clock_to_att ===> undefined             CALSTM_STACK_1.feed_clock_to_att ===> True
# 5               output_layers.layers_2.num_units ===> 64              output_layers.layers_2.num_units ===> 358
# 6                                       pLambda ===> 0.0                                      pLambda ===> 0.05
# 7         CALSTM_STACK_1.no_clock_to_lstm ===> undefined              CALSTM_STACK_1.no_clock_to_lstm ===> True
# 8               output_layers.layers_1.num_units ===> 64              output_layers.layers_1.num_units ===> 358
# 9                                  target_aae ===> 51.42                              target_aae ===> undefined
# 10  CALSTM_STACK_1.att_layers.layers_2.num_units ===> 99  CALSTM_STACK_1.att_layers.layers_2.num_units ===> 128
#    0                                                                                                                           1
# 0           init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c643490>          init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603812990>
# 1                     CONVNET.layers_6.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c643490>                    CONVNET.layers_6.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603812990>
# 2                                          init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7f4603805320>                                         init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7f46038056e0>
# 3                                                      CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7f4603805320>                                                     CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7f46038056e0>
# 4                                                    CONVNET.layers_2.weights_regularizer ===> <function l2 at 0x7f4603805320>                                                   CONVNET.layers_2.weights_regularizer ===> <function l2 at 0x7f46038056e0>
# 5                       CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c643490>                      CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603812990>
# 6                                             init_model_final_layers.weights_regularizer ===> <function l2 at 0x7f4603805320>                                            init_model_final_layers.weights_regularizer ===> <function l2 at 0x7f46038056e0>
# 7                                          CONVNET.layers_6.weights_initializer ===> <function _initializer at 0x7f4603805b18>                                         CONVNET.layers_6.weights_initializer ===> <function _initializer at 0x7f4603805488>
# 8                                init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7f4603805b18>                               init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7f4603805488>
# 9                                                                  embeddings_regularizer ===> <function l2 at 0x7f4603805320>                                                                 embeddings_regularizer ===> <function l2 at 0x7f46038056e0>
# 10                       CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f4603805b18>                       CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f4603805488>
# 11                                     biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c643490>                                     biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603812990>
# 12                                        CONVNET.layers_10.weights_initializer ===> <function _initializer at 0x7f4603805b18>                                        CONVNET.layers_10.weights_initializer ===> <function _initializer at 0x7f4603805488>
# 13                                                   CONVNET.layers_4.weights_regularizer ===> <function l2 at 0x7f4603805320>                                                   CONVNET.layers_4.weights_regularizer ===> <function l2 at 0x7f46038056e0>
# 14                                                       embeddings_initializer ===> <function _initializer at 0x7f4603805b18>                                                       embeddings_initializer ===> <function _initializer at 0x7f4603805488>
# 15                                             output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f4603805320>                                             output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f46038056e0>
# 16  CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c643490>  CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603812990>
# 17                                                        CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f4603812d90>                                                        CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f4603812f10>
# 18                    CONVNET.layers_8.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c643490>                    CONVNET.layers_8.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603812990>
# 19                       CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f4603805b18>                       CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f4603805488>
# 20                                 CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f4603805320>                                 CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f46038056e0>
# 21                                         CONVNET.layers_2.weights_initializer ===> <function _initializer at 0x7f4603805b18>                                         CONVNET.layers_2.weights_initializer ===> <function _initializer at 0x7f4603805488>
# 22                                  init_model_final_layers.weights_initializer ===> <function _initializer at 0x7f4603805b18>                                  init_model_final_layers.weights_initializer ===> <function _initializer at 0x7f4603805488>
# 23                                         CONVNET.layers_4.weights_initializer ===> <function _initializer at 0x7f4603805b18>                                         CONVNET.layers_4.weights_initializer ===> <function _initializer at 0x7f4603805488>
# 24                                 CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f4603805320>                                 CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f46038056e0>
# 25                                                                       logger ===> <logging.Logger object at 0x7f4603812d90>                                                                       logger ===> <logging.Logger object at 0x7f4603812f10>
# 26                                             output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f4603805320>                                             output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f46038056e0>
# 27                                 CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f4603805320>                                 CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f46038056e0>
# 28                                             output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f4603805320>                                             output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f46038056e0>
# 29                                   output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f4603805b18>                                   output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f4603805488>
# 30  CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c643490>  CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603812990>
# 31                                                  CONVNET.layers_10.weights_regularizer ===> <function l2 at 0x7f4603805320>                                                  CONVNET.layers_10.weights_regularizer ===> <function l2 at 0x7f46038056e0>
# 32                    CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c643490>                    CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603812990>
# 33                    CONVNET.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c643490>                    CONVNET.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603812990>
# 34                                   output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f4603805b18>                                   output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f4603805488>
# 35                   CONVNET.layers_10.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c643490>                   CONVNET.layers_10.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603812990>
# 36  CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c643490>  CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603812990>
# 37                                        CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7f4603805320>                                        CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7f46038056e0>
# 38              output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c643490>              output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603812990>
# 39                                           CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7f4603805b18>                                           CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7f4603805488>
# 40                                                   CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7f4603805320>                                                   CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7f46038056e0>
# 41                                                   CONVNET.layers_6.weights_regularizer ===> <function l2 at 0x7f4603805320>                                                   CONVNET.layers_6.weights_regularizer ===> <function l2 at 0x7f46038056e0>
# 42                    CONVNET.layers_4.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c643490>                    CONVNET.layers_4.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603812990>
# 43                                         CONVNET.layers_8.weights_initializer ===> <function _initializer at 0x7f4603805b18>                                         CONVNET.layers_8.weights_initializer ===> <function _initializer at 0x7f4603805488>
# 44                                   output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f4603805b18>                                   output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f4603805488>
# 45             init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c643490>             init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603812990>
# 46                              CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7f4603805b18>                              CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7f4603805488>
# 47              output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c643490>              output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603812990>
# 48                       CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f4603805b18>                       CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f4603805488>
# 49                                                                    weights_regularizer ===> <function l2 at 0x7f4603805320>                                                                    weights_regularizer ===> <function l2 at 0x7f46038056e0>
# 50                                                   CONVNET.layers_8.weights_regularizer ===> <function l2 at 0x7f4603805320>                                                   CONVNET.layers_8.weights_regularizer ===> <function l2 at 0x7f46038056e0>
# 51              output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c643490>              output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603812990>
# 52                                                          weights_initializer ===> <function _initializer at 0x7f4603805b18>                                                          weights_initializer ===> <function _initializer at 0x7f4603805488>
# 53                                         CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7f4603805b18>                                         CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7f4603805488>
