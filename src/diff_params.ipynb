# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import pandas as pd
import os
import re
import codecs
from IPython.display import display
from six.moves import cPickle as pickle
import string
from PIL import Image
import numpy as np
import h5py

# %%
width = None
pd.options.display.max_rows = 600
pd.options.display.max_columns = width
pd.options.display.max_colwidth = 600
pd.options.display.width = width
pd.options.display.max_seq_items = None
pd.options.display.expand_frame_repr = False
pd.options.display.colheader_justify = 'left'

# %%
import data_commons as dtc
import dl_commons as dlc
import viz_commons as vc
from viz_commons import VisualizeDir, DiffParams, VisualizeStep
# Out:
# Using TensorFlow backend.

# %%
# diff = DiffParams('./tb_metrics/2017-09-26 22-40-18 PDT', './tb_metrics/2017-10-07 14-33-35 PDT_2CALSTMs')
# diff = DiffParams('./tb_metrics/2017-10-07 14-33-35 PDT', './tb_metrics/2017-10-08 12-26-45 PDT')
# diff = DiffParams('./tb_metrics/2017-09-26 22-40-18 PDT', './tb_metrics/2017-10-08 12-26-45 PDT')
# diff = DiffParams('./tb_metrics/2017-09-26 22-40-18 PDT/w=1', './tb_metrics/2017-10-08 12-26-45 PDT')
# diff = DiffParams('./tb_metrics/2017-10-09 16-01-07 PDT_good', './tb_metrics/2017-10-09 17-43-49 PDT')
# diff = DiffParams('./tb_metrics/2017-09-26 22-40-18 PDT', './tb_metrics/2017-10-09 16-01-07 PDT_good')
diff = DiffParams('/zpool_3TB/i2l/tb_metrics/2017-11-06 13-04-35 PST 2best_3.1LSTM_2init_3OutMLP_3AttMLPfull_1beta', '/home/sumeet/im2latex_dev/src/tb_metrics_dev/2017-11-07 16-38-06 PST test_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_regroupImage')
diff.hyper()
# Out:
#    0                                                     1
# 0                 CALSTM_STACK_1.decoder_lstm.i ===> 576               CALSTM_STACK_1.decoder_lstm.i ===> 4672
# 1                       CALSTM_STACK_1.H0 ===> undefined                              CALSTM_STACK_1.H0 ===> 3
# 2            CALSTM_STACK_1.REGROUP_IMAGE ===> undefined              CALSTM_STACK_1.REGROUP_IMAGE ===> [3, 3]
# 3                              CALSTM_STACK_1.D ===> 512                            CALSTM_STACK_1.D ===> 4608
# 4                               CALSTM_STACK_1.W ===> 33                              CALSTM_STACK_1.W ===> 11
# 5                               CALSTM_STACK_1.L ===> 99                              CALSTM_STACK_1.L ===> 11
# 6                                CALSTM_STACK_1.H ===> 3                               CALSTM_STACK_1.H ===> 1
# 7                                              W ===> 33                                             W ===> 11
# 8              outputMLP_skip_connections ===> undefined                  outputMLP_skip_connections ===> True
# 9   CALSTM_STACK_1.att_layers.layers_3.num_units ===> 99  CALSTM_STACK_1.att_layers.layers_3.num_units ===> 11
# 10                                            D ===> 512                                           D ===> 4608
# 11                      CALSTM_STACK_1.W0 ===> undefined                             CALSTM_STACK_1.W0 ===> 33
# 12                                              H ===> 3                                              H ===> 1
# 13                      CALSTM_STACK_1.L0 ===> undefined                             CALSTM_STACK_1.L0 ===> 99
# 14                                             L ===> 99                                             L ===> 11
# 15                                     L0 ===> undefined                                            L0 ===> 99
# 16  CALSTM_STACK_1.att_layers.layers_2.num_units ===> 99  CALSTM_STACK_1.att_layers.layers_2.num_units ===> 11
# 17  CALSTM_STACK_1.att_layers.layers_1.num_units ===> 99  CALSTM_STACK_1.att_layers.layers_1.num_units ===> 11
# 18                                     H0 ===> undefined                                             H0 ===> 3
# 19                      CALSTM_STACK_1.D0 ===> undefined                            CALSTM_STACK_1.D0 ===> 512
# 20         init_model_hidden.layers_1.num_units ===> 512        init_model_hidden.layers_1.num_units ===> 4608
# 21                                     W0 ===> undefined                                            W0 ===> 33
# 22                          REGROUP_IMAGE ===> undefined                             REGROUP_IMAGE ===> [3, 3]
# 23                                     D0 ===> undefined                                           D0 ===> 512
#    0                                                                                                                              1
# 0                                                init_model_final_layers.weights_regularizer ===> <function l2 at 0x7efdff62b140>                                               init_model_final_layers.weights_regularizer ===> <function l2 at 0x7efdbd5021b8>
# 1                                                            CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7efdbd5075d0>                                                           CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7efdbd507a50>
# 2      CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7efe3429efd0>     CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7efdbd507790>
# 3                                     CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7efdff62b140>                                    CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7efdbd5021b8>
# 4                           CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7efe0d0efde8>                          CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7efdbd502230>
# 5                                   CALSTM_STACK_1.att_modulator.tb.logdir_tag ===> reset_3.1LSTM_2init_3OutMLP_3AttMLPfull_1beta                      CALSTM_STACK_1.att_modulator.tb.logdir_tag ===> test_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_regroupImage
# 6                                                                 CALSTM_STACK_1.att_layers.layers_1.tb.tb_logdir ===> tb_metrics                                                            CALSTM_STACK_1.att_layers.layers_1.tb.tb_logdir ===> tb_metrics_dev
# 7                                                                                  init_model_hidden.tb.tb_logdir ===> tb_metrics                                                                             init_model_hidden.tb.tb_logdir ===> tb_metrics_dev
# 8                          CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7efe3429efd0>                         CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7efdbd507790>
# 9                  output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7efe3429efd0>                 output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7efdbd507790>
# 10     CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7efe3429efd0>     CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7efdbd507790>
# 11                                  init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7efe0d0efde8>                                  init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7efdbd502230>
# 12                                        output_layers.layers_1.tb.logdir_tag ===> reset_3.1LSTM_2init_3OutMLP_3AttMLPfull_1beta                            output_layers.layers_1.tb.logdir_tag ===> test_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_regroupImage
# 13                                                                    embeddings_regularizer ===> <function l2 at 0x7efdff62b140>                                                                    embeddings_regularizer ===> <function l2 at 0x7efdbd5021b8>
# 14                                            init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7efdff62b140>                                            init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7efdbd5021b8>
# 15                                        biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7efe3429efd0>                                        biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7efdbd507790>
# 16                                                                         CALSTM_STACK_1.att_layers.tb.tb_logdir ===> tb_metrics                                                                     CALSTM_STACK_1.att_layers.tb.tb_logdir ===> tb_metrics_dev
# 17             init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7efe3429efd0>             init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7efdbd507790>
# 18                                    CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7efdff62b140>                                    CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7efdbd5021b8>
# 19                                                CALSTM_STACK_1.tb.logdir_tag ===> reset_3.1LSTM_2init_3OutMLP_3AttMLPfull_1beta                                    CALSTM_STACK_1.tb.logdir_tag ===> test_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_regroupImage
# 20                                                          embeddings_initializer ===> <function _initializer at 0x7efe0d0efde8>                                                          embeddings_initializer ===> <function _initializer at 0x7efdbd502230>
# 21                                                output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7efdff62b140>                                                output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7efdbd5021b8>
# 22                                           CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7efdff62b140>                                           CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7efdbd5021b8>
# 23     CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7efe3429efd0>     CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7efdbd507790>
# 24                                                                       weights_regularizer ===> <function l2 at 0x7efdff62b140>                                                                       weights_regularizer ===> <function l2 at 0x7efdbd5021b8>
# 25                          CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7efe0d0efde8>                          CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7efdbd502230>
# 26                                                                           init_model_final_layers.tb.tb_logdir ===> tb_metrics                                                                       init_model_final_layers.tb.tb_logdir ===> tb_metrics_dev
# 27                                   CALSTM_STACK_1.decoder_lstm.tb.logdir_tag ===> reset_3.1LSTM_2init_3OutMLP_3AttMLPfull_1beta                       CALSTM_STACK_1.decoder_lstm.tb.logdir_tag ===> test_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_regroupImage
# 28                                                                            output_layers.layers_3.tb.tb_logdir ===> tb_metrics                                                                        output_layers.layers_3.tb.tb_logdir ===> tb_metrics_dev
# 29                          CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7efe0d0efde8>                          CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7efdbd502230>
# 30                                    init_model_hidden.layers_1.tb.logdir_tag ===> reset_3.1LSTM_2init_3OutMLP_3AttMLPfull_1beta                        init_model_hidden.layers_1.tb.logdir_tag ===> test_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_regroupImage
# 31                                        output_layers.layers_3.tb.logdir_tag ===> reset_3.1LSTM_2init_3OutMLP_3AttMLPfull_1beta                            output_layers.layers_3.tb.logdir_tag ===> test_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_regroupImage
# 32                                       init_model_final_layers.tb.logdir_tag ===> reset_3.1LSTM_2init_3OutMLP_3AttMLPfull_1beta                           init_model_final_layers.tb.logdir_tag ===> test_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_regroupImage
# 33                                             init_model_hidden.tb.logdir_tag ===> reset_3.1LSTM_2init_3OutMLP_3AttMLPfull_1beta                                 init_model_hidden.tb.logdir_tag ===> test_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_regroupImage
# 34                                    CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7efdff62b140>                                    CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7efdbd5021b8>
# 35                                                                                                   tb.tb_logdir ===> tb_metrics                                                                                               tb.tb_logdir ===> tb_metrics_dev
# 36                                                             CALSTM_STACK_1.att_modulator.layers_1.tb.tb_logdir ===> tb_metrics                                                         CALSTM_STACK_1.att_modulator.layers_1.tb.tb_logdir ===> tb_metrics_dev
# 37                                     CALSTM_STACK_1.att_layers.tb.logdir_tag ===> reset_3.1LSTM_2init_3OutMLP_3AttMLPfull_1beta                         CALSTM_STACK_1.att_layers.tb.logdir_tag ===> test_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_regroupImage
# 38                                                 output_layers.tb.logdir_tag ===> reset_3.1LSTM_2init_3OutMLP_3AttMLPfull_1beta                                     output_layers.tb.logdir_tag ===> test_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_regroupImage
# 39                                        optimizer ===> <tensorflow.python.training.adam.AdamOptimizer object at 0x7efdbd507410>                                        optimizer ===> <tensorflow.python.training.adam.AdamOptimizer object at 0x7efdbd507890>
# 40                                                output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7efdff62b140>                                                output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7efdbd5021b8>
# 41                                                               tb.logdir_tag ===> reset_3.1LSTM_2init_3OutMLP_3AttMLPfull_1beta                                                   tb.logdir_tag ===> test_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_regroupImage
# 42                                      output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7efe0d0efde8>                                      output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7efdbd502230>
# 43                                     init_model_final_layers.weights_initializer ===> <function _initializer at 0x7efe0d0efde8>                                     init_model_final_layers.weights_initializer ===> <function _initializer at 0x7efdbd502230>
# 44                                                                                     output_layers.tb.tb_logdir ===> tb_metrics                                                                                 output_layers.tb.tb_logdir ===> tb_metrics_dev
# 45                                                                        init_model_hidden.layers_1.tb.tb_logdir ===> tb_metrics                                                                    init_model_hidden.layers_1.tb.tb_logdir ===> tb_metrics_dev
# 46                                                        CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7efdff62b140>                                                        CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7efdbd5021b8>
# 47  CALSTM_STACK_1.att_modulator.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7efe3429efd0>  CALSTM_STACK_1.att_modulator.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7efdbd507790>
# 48                            CALSTM_STACK_1.att_layers.layers_1.tb.logdir_tag ===> reset_3.1LSTM_2init_3OutMLP_3AttMLPfull_1beta                CALSTM_STACK_1.att_layers.layers_1.tb.logdir_tag ===> test_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_regroupImage
# 49                                                                                    CALSTM_STACK_1.tb.tb_logdir ===> tb_metrics                                                                                CALSTM_STACK_1.tb.tb_logdir ===> tb_metrics_dev
# 50                                                                CALSTM_STACK_1.att_layers.layers_2.tb.tb_logdir ===> tb_metrics                                                            CALSTM_STACK_1.att_layers.layers_2.tb.tb_logdir ===> tb_metrics_dev
# 51                                                                CALSTM_STACK_1.att_layers.layers_3.tb.tb_logdir ===> tb_metrics                                                            CALSTM_STACK_1.att_layers.layers_3.tb.tb_logdir ===> tb_metrics_dev
# 52                                              CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7efe0d0efde8>                                              CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7efdbd502230>
# 53                                                                       CALSTM_STACK_1.decoder_lstm.tb.tb_logdir ===> tb_metrics                                                                   CALSTM_STACK_1.decoder_lstm.tb.tb_logdir ===> tb_metrics_dev
# 54                                                                      CALSTM_STACK_1.att_modulator.tb.tb_logdir ===> tb_metrics                                                                  CALSTM_STACK_1.att_modulator.tb.tb_logdir ===> tb_metrics_dev
# 55                         CALSTM_STACK_1.att_modulator.layers_1.tb.logdir_tag ===> reset_3.1LSTM_2init_3OutMLP_3AttMLPfull_1beta             CALSTM_STACK_1.att_modulator.layers_1.tb.logdir_tag ===> test_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_regroupImage
# 56                                                                          logger ===> <logging.Logger object at 0x7efdbd5075d0>                                                                          logger ===> <logging.Logger object at 0x7efdbd507a50>
# 57                            CALSTM_STACK_1.att_layers.layers_2.tb.logdir_tag ===> reset_3.1LSTM_2init_3OutMLP_3AttMLPfull_1beta                CALSTM_STACK_1.att_layers.layers_2.tb.logdir_tag ===> test_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_regroupImage
# 58                                                output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7efdff62b140>                                                output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7efdbd5021b8>
# 59                                                                            output_layers.layers_1.tb.tb_logdir ===> tb_metrics                                                                        output_layers.layers_1.tb.tb_logdir ===> tb_metrics_dev
# 60                                                                            output_layers.layers_2.tb.tb_logdir ===> tb_metrics                                                                        output_layers.layers_2.tb.tb_logdir ===> tb_metrics_dev
# 61                                        output_layers.layers_2.tb.logdir_tag ===> reset_3.1LSTM_2init_3OutMLP_3AttMLPfull_1beta                            output_layers.layers_2.tb.logdir_tag ===> test_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_regroupImage
# 62                init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7efe3429efd0>                init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7efdbd507790>
# 63                                 CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7efe0d0efde8>                                 CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7efdbd502230>
# 64                 output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7efe3429efd0>                 output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7efdbd507790>
# 65                                      output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7efe0d0efde8>                                      output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7efdbd502230>
# 66                                      output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7efe0d0efde8>                                      output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7efdbd502230>
# 67                            CALSTM_STACK_1.att_layers.layers_3.tb.logdir_tag ===> reset_3.1LSTM_2init_3OutMLP_3AttMLPfull_1beta                CALSTM_STACK_1.att_layers.layers_3.tb.logdir_tag ===> test_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_regroupImage
# 68                       CALSTM_STACK_1.att_modulator.layers_1.weights_initializer ===> <function _initializer at 0x7efe0d0efde8>                       CALSTM_STACK_1.att_modulator.layers_1.weights_initializer ===> <function _initializer at 0x7efdbd502230>
# 69                 output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7efe3429efd0>                 output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7efdbd507790>
# 70                                                             weights_initializer ===> <function _initializer at 0x7efe0d0efde8>                                                             weights_initializer ===> <function _initializer at 0x7efdbd502230>
# 71                                 CALSTM_STACK_1.att_modulator.layers_1.weights_regularizer ===> <function l2 at 0x7efdff62b140>                                 CALSTM_STACK_1.att_modulator.layers_1.weights_regularizer ===> <function l2 at 0x7efdbd5021b8>
