# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import pandas as pd
import os
import re
import codecs
from IPython.display import display
from six.moves import cPickle as pickle
import string
from PIL import Image
import numpy as np
import h5py

# %%
width = None
pd.options.display.max_rows = 600
pd.options.display.max_columns = width
pd.options.display.max_colwidth = 600
pd.options.display.width = width
pd.options.display.max_seq_items = None
pd.options.display.expand_frame_repr = False
pd.options.display.colheader_justify = 'left'

# %%
import data_commons as dtc
import dl_commons as dlc
import viz_commons as vc
from viz_commons import VisualizeDir, DiffParams, VisualizeStep
# Out:
# Using TensorFlow backend.

# %%
# diff = DiffParams('/zpool_3TB/i2l/tb_metrics/2017-11-18 20-34-05 PST best_newData_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2', './tb_metrics_dev/2017-11-19 21-31-52 PST noBins_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2')
diff = DiffParams('./tb_metrics_dev/2017-11-20 23-11-24 PST 81.76bleu2_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2', './tb_metrics_dev/2017-11-22 18-48-55 PST 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2_target_ase')
diff.hyper()
# Out:
#   0                          1
# 0  target_ase ===> undefined   target_ase ===> 5.27
# 1  target_aae ===> undefined  target_aae ===> 51.42
#    0                                                                                                                           1
# 0                                                         CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f32a1effc50>                                                                CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f32a1f12110>
# 1                                          CONVNET.layers_2.weights_initializer ===> <function _initializer at 0x7f32f19e8d70>                                                 CONVNET.layers_2.weights_initializer ===> <function _initializer at 0x7f32a1f7de60>
# 2                     CONVNET.layers_6.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3318c35fd0>                            CONVNET.layers_6.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f32a1effe90>
# 3                                          init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7f32a1f7a488>                                                 init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7f32a1f7dde8>
# 4           init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3318c35fd0>                  init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f32a1effe90>
# 5                                                    CONVNET.layers_2.weights_regularizer ===> <function l2 at 0x7f32a1f7a488>                                                           CONVNET.layers_2.weights_regularizer ===> <function l2 at 0x7f32a1f7dde8>
# 6            CALSTM_STACK_1.decoder_lstm.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/         CALSTM_STACK_1.decoder_lstm.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2_target_ase
# 7                       CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3318c35fd0>                              CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f32a1effe90>
# 8                                    output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f32f19e8d70>                                           output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f32a1f7de60>
# 9                                          CONVNET.layers_6.weights_initializer ===> <function _initializer at 0x7f32f19e8d70>                                                 CONVNET.layers_6.weights_initializer ===> <function _initializer at 0x7f32a1f7de60>
# 10                               init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7f32f19e8d70>                                       init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7f32a1f7de60>
# 11                output_layers.layers_1.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/              output_layers.layers_1.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2_target_ase
# 12                                         CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7f32f19e8d70>                                                 CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7f32a1f7de60>
# 13                       CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f32f19e8d70>                               CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f32a1f7de60>
# 14                                     biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3318c35fd0>                                             biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f32a1effe90>
# 15                                 CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f32a1f7a488>                                         CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f32a1f7dde8>
# 16                        CALSTM_STACK_1.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/                      CALSTM_STACK_1.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2_target_ase
# 17                                                   CONVNET.layers_4.weights_regularizer ===> <function l2 at 0x7f32a1f7a488>                                                           CONVNET.layers_4.weights_regularizer ===> <function l2 at 0x7f32a1f7dde8>
# 18                                                       embeddings_initializer ===> <function _initializer at 0x7f32f19e8d70>                                                               embeddings_initializer ===> <function _initializer at 0x7f32a1f7de60>
# 19                                             output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f32a1f7a488>                                                     output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f32a1f7dde8>
# 20  CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3318c35fd0>          CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f32a1effe90>
# 21                    CONVNET.layers_8.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3318c35fd0>                            CONVNET.layers_8.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f32a1effe90>
# 22                       CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f32f19e8d70>                               CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f32a1f7de60>
# 23                       CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f32f19e8d70>                               CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f32a1f7de60>
# 24                                                     CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7f32a1f7a488>                                                             CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7f32a1f7dde8>
# 25                                        CONVNET.layers_10.weights_initializer ===> <function _initializer at 0x7f32f19e8d70>                                                CONVNET.layers_10.weights_initializer ===> <function _initializer at 0x7f32a1f7de60>
# 26                output_layers.layers_3.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/              output_layers.layers_3.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2_target_ase
# 27               init_model_final_layers.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/             init_model_final_layers.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2_target_ase
# 28                                         CONVNET.layers_4.weights_initializer ===> <function _initializer at 0x7f32f19e8d70>                                                 CONVNET.layers_4.weights_initializer ===> <function _initializer at 0x7f32a1f7de60>
# 29                                 CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f32a1f7a488>                                         CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f32a1f7dde8>
# 30                                                                       logger ===> <logging.Logger object at 0x7f32a1effc50>                                                                               logger ===> <logging.Logger object at 0x7f32a1f12110>
# 31             CALSTM_STACK_1.att_layers.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/           CALSTM_STACK_1.att_layers.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2_target_ase
# 32                                 CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f32a1f7a488>                                         CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f32a1f7dde8>
# 33                                             output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f32a1f7a488>                                                     output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f32a1f7dde8>
# 34                                       tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/                                     tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2_target_ase
# 35                                   output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f32f19e8d70>                                           output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f32a1f7de60>
# 36                                  init_model_final_layers.weights_initializer ===> <function _initializer at 0x7f32f19e8d70>                                          init_model_final_layers.weights_initializer ===> <function _initializer at 0x7f32a1f7de60>
# 37                                                  CONVNET.layers_10.weights_regularizer ===> <function l2 at 0x7f32a1f7a488>                                                          CONVNET.layers_10.weights_regularizer ===> <function l2 at 0x7f32a1f7dde8>
# 38    CALSTM_STACK_1.att_layers.layers_3.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/  CALSTM_STACK_1.att_layers.layers_3.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2_target_ase
# 39            init_model_hidden.layers_1.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/          init_model_hidden.layers_1.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2_target_ase
# 40                    CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3318c35fd0>                            CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f32a1effe90>
# 41                    CONVNET.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3318c35fd0>                            CONVNET.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f32a1effe90>
# 42                         output_layers.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/                       output_layers.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2_target_ase
# 43    CALSTM_STACK_1.att_layers.layers_1.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/  CALSTM_STACK_1.att_layers.layers_1.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2_target_ase
# 44                   CONVNET.layers_10.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3318c35fd0>                           CONVNET.layers_10.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f32a1effe90>
# 45  CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3318c35fd0>          CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f32a1effe90>
# 46                                        CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7f32a1f7a488>                                                CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7f32a1f7dde8>
# 47              output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3318c35fd0>                      output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f32a1effe90>
# 48                                           CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7f32f19e8d70>                                                   CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7f32a1f7de60>
# 49                               CONVNET.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/                             CONVNET.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2_target_ase
# 50    CALSTM_STACK_1.att_layers.layers_2.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/  CALSTM_STACK_1.att_layers.layers_2.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2_target_ase
# 51                                                   CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7f32a1f7a488>                                                           CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7f32a1f7dde8>
# 52                                                   CONVNET.layers_6.weights_regularizer ===> <function l2 at 0x7f32a1f7a488>                                                           CONVNET.layers_6.weights_regularizer ===> <function l2 at 0x7f32a1f7dde8>
# 53                    CONVNET.layers_4.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3318c35fd0>                            CONVNET.layers_4.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f32a1effe90>
# 54                                         CONVNET.layers_8.weights_initializer ===> <function _initializer at 0x7f32f19e8d70>                                                 CONVNET.layers_8.weights_initializer ===> <function _initializer at 0x7f32a1f7de60>
# 55                                            init_model_final_layers.weights_regularizer ===> <function l2 at 0x7f32a1f7a488>                                                    init_model_final_layers.weights_regularizer ===> <function l2 at 0x7f32a1f7dde8>
# 56             init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3318c35fd0>                     init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f32a1effe90>
# 57                output_layers.layers_2.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/              output_layers.layers_2.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2_target_ase
# 58              output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3318c35fd0>                      output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f32a1effe90>
# 59                                   output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f32f19e8d70>                                           output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f32a1f7de60>
# 60                                                                    weights_regularizer ===> <function l2 at 0x7f32a1f7a488>                                                                            weights_regularizer ===> <function l2 at 0x7f32a1f7dde8>
# 61                                                   CONVNET.layers_8.weights_regularizer ===> <function l2 at 0x7f32a1f7a488>                                                           CONVNET.layers_8.weights_regularizer ===> <function l2 at 0x7f32a1f7dde8>
# 62              output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3318c35fd0>                      output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f32a1effe90>
# 63                              CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7f32f19e8d70>                                      CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7f32a1f7de60>
# 64                                             output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f32a1f7a488>                                                     output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f32a1f7dde8>
# 65                                                          weights_initializer ===> <function _initializer at 0x7f32f19e8d70>                                                                  weights_initializer ===> <function _initializer at 0x7f32a1f7de60>
# 66  CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3318c35fd0>          CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f32a1effe90>
# 67                     init_model_hidden.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2/                   init_model_hidden.tb.logdir_tag ===> 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2_target_ase
# 68                                                                 embeddings_regularizer ===> <function l2 at 0x7f32a1f7a488>                                                                         embeddings_regularizer ===> <function l2 at 0x7f32a1f7dde8>

# %%
one, two = diff.get_hyper()

# %%
one['adam_alpha']
# Out:
# 0.001
