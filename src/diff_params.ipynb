# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import pandas as pd
import os
import re
import codecs
from IPython.display import display
from six.moves import cPickle as pickle
import string
from PIL import Image
import numpy as np
import h5py

# %%
width = None
pd.options.display.max_rows = 600
pd.options.display.max_columns = width
pd.options.display.max_colwidth = 600
pd.options.display.width = width
pd.options.display.max_seq_items = None
pd.options.display.expand_frame_repr = False
pd.options.display.colheader_justify = 'left'

# %%
import data_commons as dtc
import dl_commons as dlc
import viz_commons as vc
from viz_commons import VisualizeDir, DiffParams, VisualizeStep
# Out:
# Using TensorFlow backend.

# %%
# diff = DiffParams('/zpool_3TB/i2l/tb_metrics/2017-11-18 20-34-05 PST best_newData_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2', './tb_metrics_dev/2017-11-19 21-31-52 PST noBins_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2')
diff = DiffParams('/zpool_3TB/i2l/tb_metrics/2017-11-17 21-30-42 PST best_newData_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2', '/zpool_3TB/i2l/tb_metrics/2017-11-18 13-35-37 PST newData_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2')
diff.hyper()
# Out:
#   0                 1
# 0  pLambda ===> 0.0  pLambda ===> 0.0005
#    0                                                                                                                              1
# 0                                                            CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f6adaa4d550>                                                           CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f6adaa4da10>
# 1                        CONVNET.layers_6.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d390>                       CONVNET.layers_6.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d7d0>
# 2                                             init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7f6adaa37b18>                                            init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7f6adaa37b90>
# 3              init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d390>             init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d7d0>
# 4                                                       CONVNET.layers_2.weights_regularizer ===> <function l2 at 0x7f6adaa37b18>                                                      CONVNET.layers_2.weights_regularizer ===> <function l2 at 0x7f6adaa37b90>
# 5                           CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f6adaa37a28>                          CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f6adaa37c08>
# 6                          CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d390>                         CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d7d0>
# 7                                                init_model_final_layers.weights_regularizer ===> <function l2 at 0x7f6adaa37b18>                                               init_model_final_layers.weights_regularizer ===> <function l2 at 0x7f6adaa37b90>
# 8                                             CONVNET.layers_6.weights_initializer ===> <function _initializer at 0x7f6adaa37a28>                                            CONVNET.layers_6.weights_initializer ===> <function _initializer at 0x7f6adaa37c08>
# 9                                   init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7f6adaa37a28>                                  init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7f6adaa37c08>
# 10                                                                    embeddings_regularizer ===> <function l2 at 0x7f6adaa37b18>                                                                    embeddings_regularizer ===> <function l2 at 0x7f6adaa37b90>
# 11                          CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f6adaa37a28>                          CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f6adaa37c08>
# 12                                        biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d390>                                        biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d7d0>
# 13                                           CONVNET.layers_10.weights_initializer ===> <function _initializer at 0x7f6adaa37a28>                                           CONVNET.layers_10.weights_initializer ===> <function _initializer at 0x7f6adaa37c08>
# 14                                                      CONVNET.layers_4.weights_regularizer ===> <function l2 at 0x7f6adaa37b18>                                                      CONVNET.layers_4.weights_regularizer ===> <function l2 at 0x7f6adaa37b90>
# 15                                                          embeddings_initializer ===> <function _initializer at 0x7f6adaa37a28>                                                          embeddings_initializer ===> <function _initializer at 0x7f6adaa37c08>
# 16                                                output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f6adaa37b18>                                                output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f6adaa37b90>
# 17     CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d390>     CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d7d0>
# 18                       CONVNET.layers_8.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d390>                       CONVNET.layers_8.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d7d0>
# 19                          CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f6adaa37a28>                          CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f6adaa37c08>
# 20                                    CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f6adaa37b18>                                    CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f6adaa37b90>
# 21                                            CONVNET.layers_2.weights_initializer ===> <function _initializer at 0x7f6adaa37a28>                                            CONVNET.layers_2.weights_initializer ===> <function _initializer at 0x7f6adaa37c08>
# 22     CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d390>     CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d7d0>
# 23                                            CONVNET.layers_4.weights_initializer ===> <function _initializer at 0x7f6adaa37a28>                                            CONVNET.layers_4.weights_initializer ===> <function _initializer at 0x7f6adaa37c08>
# 24                                    CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f6adaa37b18>                                    CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f6adaa37b90>
# 25                                                                          logger ===> <logging.Logger object at 0x7f6adaa4d550>                                                                          logger ===> <logging.Logger object at 0x7f6adaa4da10>
# 26                                    CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f6adaa37b18>                                    CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f6adaa37b90>
# 27                                                output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f6adaa37b18>                                                output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f6adaa37b90>
# 28                                      output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f6adaa37a28>                                      output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f6adaa37c08>
# 29                                     init_model_final_layers.weights_initializer ===> <function _initializer at 0x7f6adaa37a28>                                     init_model_final_layers.weights_initializer ===> <function _initializer at 0x7f6adaa37c08>
# 30                                                     CONVNET.layers_10.weights_regularizer ===> <function l2 at 0x7f6adaa37b18>                                                     CONVNET.layers_10.weights_regularizer ===> <function l2 at 0x7f6adaa37b90>
# 31                                                      CONVNET.layers_6.weights_regularizer ===> <function l2 at 0x7f6adaa37b18>                                                      CONVNET.layers_6.weights_regularizer ===> <function l2 at 0x7f6adaa37b90>
# 32                                                        CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7f6adaa37b18>                                                        CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7f6adaa37b90>
# 33                       CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d390>                       CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d7d0>
# 34                       CONVNET.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d390>                       CONVNET.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d7d0>
# 35  CALSTM_STACK_1.att_modulator.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d390>  CALSTM_STACK_1.att_modulator.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d7d0>
# 36                      CONVNET.layers_10.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d390>                      CONVNET.layers_10.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d7d0>
# 37     CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d390>     CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d7d0>
# 38                                                             weights_initializer ===> <function _initializer at 0x7f6adaa37a28>                                                             weights_initializer ===> <function _initializer at 0x7f6adaa37c08>
# 39                 output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d390>                 output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d7d0>
# 40                                              CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7f6adaa37a28>                                              CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7f6adaa37c08>
# 41                                                      CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7f6adaa37b18>                                                      CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7f6adaa37b90>
# 42                                                output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f6adaa37b18>                                                output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f6adaa37b90>
# 43                       CONVNET.layers_4.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d390>                       CONVNET.layers_4.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d7d0>
# 44                                            CONVNET.layers_8.weights_initializer ===> <function _initializer at 0x7f6adaa37a28>                                            CONVNET.layers_8.weights_initializer ===> <function _initializer at 0x7f6adaa37c08>
# 45                                      output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f6adaa37a28>                                      output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f6adaa37c08>
# 46                init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d390>                init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d7d0>
# 47                                 CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7f6adaa37a28>                                 CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7f6adaa37c08>
# 48                 output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d390>                 output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d7d0>
# 49                                      output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f6adaa37a28>                                      output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f6adaa37c08>
# 50                                                                       weights_regularizer ===> <function l2 at 0x7f6adaa37b18>                                                                       weights_regularizer ===> <function l2 at 0x7f6adaa37b90>
# 51                       CALSTM_STACK_1.att_modulator.layers_1.weights_initializer ===> <function _initializer at 0x7f6adaa37a28>                       CALSTM_STACK_1.att_modulator.layers_1.weights_initializer ===> <function _initializer at 0x7f6adaa37c08>
# 52                                                      CONVNET.layers_8.weights_regularizer ===> <function l2 at 0x7f6adaa37b18>                                                      CONVNET.layers_8.weights_regularizer ===> <function l2 at 0x7f6adaa37b90>
# 53                 output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d390>                 output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f6adaa4d7d0>
# 54                                           CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7f6adaa37b18>                                           CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7f6adaa37b90>
# 55                                 CALSTM_STACK_1.att_modulator.layers_1.weights_regularizer ===> <function l2 at 0x7f6adaa37b18>                                 CALSTM_STACK_1.att_modulator.layers_1.weights_regularizer ===> <function l2 at 0x7f6adaa37b90>
# 56                                            CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7f6adaa37a28>                                            CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7f6adaa37c08>

# %%
one, two = diff.get_hyper()

# %%
one['adam_alpha']
# Out:
# 0.001
