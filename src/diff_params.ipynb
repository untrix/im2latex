# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import pandas as pd
import os
import re
import codecs
from IPython.display import display
from six.moves import cPickle as pickle
import string
from PIL import Image
import numpy as np
import h5py

# %%
width = None
pd.options.display.max_rows = 600
pd.options.display.max_columns = width
pd.options.display.max_colwidth = 600
pd.options.display.width = width
pd.options.display.max_seq_items = None
pd.options.display.expand_frame_repr = False
pd.options.display.colheader_justify = 'left'

# %%
import data_commons as dtc
import dl_commons as dlc
import viz_commons as vc
from viz_commons import VisualizeDir, DiffParams, VisualizeStep
# Out:
# Using TensorFlow backend.

# %%
# diff = DiffParams('/zpool_3TB/i2l/tb_metrics/2017-11-18 20-34-05 PST best_newData_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2', './tb_metrics_dev/2017-11-19 21-31-52 PST noBins_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2')
diff = DiffParams('/zpool_3TB/i2l/tb_metrics/2017-11-18 20-34-05 PST best_newData_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2', './tb_metrics_dev/2017-11-20 23-11-24 PST 3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda_regroupImage_i=2')
diff.hyper()
# Out:
#    0                                                                         1
# 0                    CALSTM_STACK_1.att_modulator.layers_1.dropout ===> None             CALSTM_STACK_1.att_modulator.layers_1.dropout ===> undefined
# 1                                                           SFactor ===> 2.0                                                        SFactor ===> None
# 2                                                     adam_alpha ===> 0.0005                                                   adam_alpha ===> 0.0001
# 3                         CALSTM_STACK_1.att_modulator.op_name ===> beta_MLP                      CALSTM_STACK_1.att_modulator.op_name ===> undefined
# 4                 CALSTM_STACK_1.raw_data_dir ===> ../data/dataset3/training           CALSTM_STACK_1.raw_data_dir ===> ../data/dataset3/training_56/
# 5                                              assert_whole_batch ===> False                                             assert_whole_batch ===> True
# ...

# %%
one, two = diff.get_hyper()

# %%
one['adam_alpha']
# Out:
# 0.001
