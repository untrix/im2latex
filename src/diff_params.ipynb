# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import pandas as pd
import os
import re
import codecs
from IPython.display import display
from six.moves import cPickle as pickle
import string
from PIL import Image
import numpy as np
import h5py

# %%
width = None
pd.options.display.max_rows = 600
pd.options.display.max_columns = width
pd.options.display.max_colwidth = 600
pd.options.display.width = width
pd.options.display.max_seq_items = None
pd.options.display.expand_frame_repr = False
pd.options.display.colheader_justify = 'left'

# %%
import data_commons as dtc
import dl_commons as dlc
import viz_commons as vc
from viz_commons import VisualizeDir, DiffParams, VisualizeStep
# Out:
# Using TensorFlow backend.

# %%
one9

# %%
diff = DiffParams('/zpool_3TB/i2l/tb_metrics/2017-12-21 02-20-10 PST 140K_data_score_89.0', './tb_metrics/2017-12-23 22-02-35 PST')
one, two = diff.get_hyper()
head, tail = diff.hyper(show=True)
# head[~head[0].str.contains('CONVNET')]
# Out:
#    0                                                              1
# 0            init_model_final_layers.biases_regularizer ===> None     init_model_final_layers.biases_regularizer ===> undefined
# 1                init_model_final_layers.tb.tb_biases ===> Biases           init_model_final_layers.tb.tb_biases ===> undefined
# 2                                      build_init_model ===> True                                   build_init_model ===> False
# 3             init_model_hidden.layers_1.tb.tb_biases ===> Biases        init_model_hidden.layers_1.tb.tb_biases ===> undefined
# 4                      init_model_hidden.tb.tb_biases ===> Biases                 init_model_hidden.tb.tb_biases ===> undefined
# 5                                   assert_whole_batch ===> False                                  assert_whole_batch ===> True
# 6           init_model_hidden.layers_1.tb.tb_weights ===> Weights       init_model_hidden.layers_1.tb.tb_weights ===> undefined
# 7                    init_model_hidden.tb.tb_weights ===> Weights                init_model_hidden.tb.tb_weights ===> undefined
# 8            init_model_hidden.tb.tb_activations ===> Activations            init_model_hidden.tb.tb_activations ===> undefined
# 9   init_model_hidden.layers_1.tb.tb_activations ===> Activations   init_model_hidden.layers_1.tb.tb_activations ===> undefined
# 10                   init_model_hidden.layers_1.dropout ===> None             init_model_hidden.layers_1.dropout ===> undefined
# 11             init_model_final_layers.tb.tb_weights ===> Weights          init_model_final_layers.tb.tb_weights ===> undefined
# 12                  init_model_hidden.layers_1.num_units ===> 100           init_model_hidden.layers_1.num_units ===> undefined
# 13        init_model_hidden.layers_1.biases_regularizer ===> None  init_model_hidden.layers_1.biases_regularizer ===> undefined
# 14     init_model_final_layers.tb.tb_activations ===> Activations      init_model_final_layers.tb.tb_activations ===> undefined
# 15                      init_model_final_layers.dropout ===> None                init_model_final_layers.dropout ===> undefined
#    0                                                                                                                           1
# 0                                              init_model_hidden.layers_1.activation_fn ===> <function tanh at 0x7fec82f66938>                                                                     init_model_hidden.layers_1.activation_fn ===> undefined
# 1           init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7feced785ed0>                                                                init_model_hidden.layers_1.biases_initializer ===> undefined
# 2                     CONVNET.layers_7.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7feced785ed0>                    CONVNET.layers_7.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fec78bf2350>
# 3                                          CONVNET.layers_7.weights_initializer ===> <function _initializer at 0x7fec7a31ac80>                                         CONVNET.layers_7.weights_initializer ===> <function _initializer at 0x7fec79127a28>
# 4                                                         CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7fec78bf2190>                                                        CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7fec781f3190>
# 5                                          CONVNET.layers_3.weights_initializer ===> <function _initializer at 0x7fec7a31ac80>                                         CONVNET.layers_3.weights_initializer ===> <function _initializer at 0x7fec79127a28>
# 6                       CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7feced785ed0>                      CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fec78bf2350>
# 7                                             init_model_final_layers.weights_regularizer ===> <function l2 at 0x7fec78666848>                                                                  init_model_final_layers.weights_regularizer ===> undefined
# 8                                                 init_model_final_layers.activation_fn ===> <function tanh at 0x7fec82f66938>                                                                        init_model_final_layers.activation_fn ===> undefined
# 9                                init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7fec7a31ac80>                                                               init_model_hidden.layers_1.weights_initializer ===> undefined
# 10                                         CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7fec7a31ac80>                                         CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7fec79127a28>
# 11                       CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7fec7a31ac80>                       CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7fec79127a28>
# 12                                     biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7feced785ed0>                                     biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fec78bf2350>
# 13                                 CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7fec78666848>                                 CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7fec79367848>
# 14                                             output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7fec78666848>                                             output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7fec79367848>
# 15                                                       embeddings_initializer ===> <function _initializer at 0x7fec7a31ac80>                                                       embeddings_initializer ===> <function _initializer at 0x7fec79127a28>
# 16                                             output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7fec78666848>                                             output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7fec79367848>
# 17                                                                   init_model_hidden.layers_1.tb.tb_logdir ===> ./tb_metrics                                                                      init_model_hidden.layers_1.tb.tb_logdir ===> undefined
# 18                                                   CONVNET.layers_5.weights_regularizer ===> <function l2 at 0x7fec78666848>                                                   CONVNET.layers_5.weights_regularizer ===> <function l2 at 0x7fec79367848>
# 19                                                                      init_model_final_layers.tb.tb_logdir ===> ./tb_metrics                                                                         init_model_final_layers.tb.tb_logdir ===> undefined
# 20                                         CONVNET.layers_9.weights_initializer ===> <function _initializer at 0x7fec7a31ac80>                                         CONVNET.layers_9.weights_initializer ===> <function _initializer at 0x7fec79127a28>
# 21                       CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7fec7a31ac80>                       CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7fec79127a28>
# 22                                   output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7fec7a31ac80>                                   output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7fec79127a28>
# 23                    CONVNET.layers_5.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7feced785ed0>                    CONVNET.layers_5.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fec78bf2350>
# 24  CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7feced785ed0>  CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fec78bf2350>
# 25                                                                                   init_model_hidden.tb.logdir_tag ===> None                                                                              init_model_hidden.tb.logdir_tag ===> undefined
# 26                                 CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7fec78666848>                                 CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7fec79367848>
# 27                                                                       logger ===> <logging.Logger object at 0x7fec78bf2190>                                                                       logger ===> <logging.Logger object at 0x7fec781f3190>
# 28                                                          weights_initializer ===> <function _initializer at 0x7fec7a31ac80>                                                          weights_initializer ===> <function _initializer at 0x7fec79127a28>
# 29                                 CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7fec78666848>                                 CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7fec79367848>
# 30                                                                          init_model_hidden.layers_1.tb.logdir_tag ===> None                                                                     init_model_hidden.layers_1.tb.logdir_tag ===> undefined
# 31                                         CONVNET.layers_5.weights_initializer ===> <function _initializer at 0x7fec7a31ac80>                                         CONVNET.layers_5.weights_initializer ===> <function _initializer at 0x7fec79127a28>
# 32                    CONVNET.layers_9.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7feced785ed0>                    CONVNET.layers_9.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fec78bf2350>
# 33                                  init_model_final_layers.weights_initializer ===> <function _initializer at 0x7fec7a31ac80>                                                                  init_model_final_layers.weights_initializer ===> undefined
# 34                                                                             init_model_final_layers.tb.logdir_tag ===> None                                                                        init_model_final_layers.tb.logdir_tag ===> undefined
# 35                                                     CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7fec78666848>                                                     CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7fec79367848>
# 36                    CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7feced785ed0>                    CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fec78bf2350>
# 37                                   output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7fec7a31ac80>                                   output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7fec79127a28>
# 38  CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7feced785ed0>  CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fec78bf2350>
# 39                                                   CONVNET.layers_9.weights_regularizer ===> <function l2 at 0x7fec78666848>                                                   CONVNET.layers_9.weights_regularizer ===> <function l2 at 0x7fec79367848>
# 40              output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7feced785ed0>              output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fec78bf2350>
# 41                                           CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7fec7a31ac80>                                           CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7fec79127a28>
# 42                                                                            init_model_hidden.tb.tb_logdir ===> ./tb_metrics                                                                               init_model_hidden.tb.tb_logdir ===> undefined
# 43  CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7feced785ed0>  CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fec78bf2350>
# 44                                                   CONVNET.layers_7.weights_regularizer ===> <function l2 at 0x7fec78666848>                                                   CONVNET.layers_7.weights_regularizer ===> <function l2 at 0x7fec79367848>
# 45                                                   CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7fec78666848>                                                   CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7fec79367848>
# 46                                             output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7fec78666848>                                             output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7fec79367848>
# 47                    CONVNET.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7feced785ed0>                    CONVNET.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fec78bf2350>
# 48                                   output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7fec7a31ac80>                                   output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7fec79127a28>
# 49             init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7feced785ed0>                                                                   init_model_final_layers.biases_initializer ===> undefined
# 50                              CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7fec7a31ac80>                              CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7fec79127a28>
# 51              output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7feced785ed0>              output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fec78bf2350>
# 52                       CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7fec7a31ac80>                       CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7fec79127a28>
# 53                                                                    weights_regularizer ===> <function l2 at 0x7fec78666848>                                                                    weights_regularizer ===> <function l2 at 0x7fec79367848>
# 54              output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7feced785ed0>              output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fec78bf2350>
# 55                                                                 embeddings_regularizer ===> <function l2 at 0x7fec78666848>                                                                 embeddings_regularizer ===> <function l2 at 0x7fec79367848>
# 56                                        CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7fec78666848>                                        CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7fec79367848>
# 57                                                   CONVNET.layers_3.weights_regularizer ===> <function l2 at 0x7fec78666848>                                                   CONVNET.layers_3.weights_regularizer ===> <function l2 at 0x7fec79367848>
# 58                                         init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7fec78666848>                                                               init_model_hidden.layers_1.weights_regularizer ===> undefined

# %%
(one['init_model_final_layers'])
# Out:
# {'activation_fn': <function tensorflow.python.ops.math_ops.tanh>,
#  'biases_initializer': <tensorflow.python.ops.init_ops.Zeros at 0x7fec7a382b90>,
#  'biases_regularizer': None,
#  'dropout': None,
#  'tb': {'logdir_tag': None,
#   'tb_activations': 'Activations',
#   'tb_biases': 'Biases',
#   'tb_logdir': './tb_metrics',
#   'tb_weights': 'Weights'},
#  'weights_initializer': <function tensorflow.contrib.layers.python.layers.initializers._initializer>,
#  'weights_regularizer': <function tensorflow.contrib.layers.python.layers.regularizers.l2>}

# %%
two['build_init_model']
# Out:
# False

# %%
params = ['2017-12-06 15-40-46 PST score_86.14',
          '2017-12-07 23-23-25 PST score_87.45', 
          '2017-12-10 12-52-23 PST score_88.17',
          '2017-12-11 11-22-31 PST',
          '2017-12-11 22-57-42 PST score_86.54',
          '2017-12-12 19-49-24 PST score_88.10',
          '2017-12-16 18-51-38 PST pLambda=0_score_88.86',
          '2017-12-21 02-20-10 PST 140K_data_score_89.0'
         ]

for p in params:
    vd = VisualizeDir('/zpool_3TB/i2l/tb_metrics/' + p + '/store')
    if 'build_init_model' in vd.hyper:
        b = vd.hyper['build_init_model']
    else:
        b = True
    print('%s:\t%s'%(b, p))
# Out:
# Loaded /zpool_3TB/i2l/tb_metrics/2017-12-06 15-40-46 PST score_86.14/store/hyper.pkl and /zpool_3TB/i2l/tb_metrics/2017-12-06 15-40-46 PST score_86.14/store/args.pkl
# Loaded ../data/dataset3/training_56/df_train.pkl (89096, 3)
# True:	2017-12-06 15-40-46 PST score_86.14
# Loaded /zpool_3TB/i2l/tb_metrics/2017-12-07 23-23-25 PST score_87.45/store/hyper.pkl and /zpool_3TB/i2l/tb_metrics/2017-12-07 23-23-25 PST score_87.45/store/args.pkl
# Loaded ../data/dataset3/training_56/df_train.pkl (89096, 3)
# True:	2017-12-07 23-23-25 PST score_87.45
# Loaded /zpool_3TB/i2l/tb_metrics/2017-12-10 12-52-23 PST score_88.17/store/hyper.pkl and /zpool_3TB/i2l/tb_metrics/2017-12-10 12-52-23 PST score_88.17/store/args.pkl
# Loaded ../data/dataset3/training_56/df_train.pkl (89096, 3)
# True:	2017-12-10 12-52-23 PST score_88.17
# Loaded /zpool_3TB/i2l/tb_metrics/2017-12-11 11-22-31 PST/store/hyper.pkl and /zpool_3TB/i2l/tb_metrics/2017-12-11 11-22-31 PST/store/args.pkl
# Loaded ../data/dataset3/training_56/df_train.pkl (89096, 3)
# False:	2017-12-11 11-22-31 PST
# Loaded /zpool_3TB/i2l/tb_metrics/2017-12-11 22-57-42 PST score_86.54/store/hyper.pkl and /zpool_3TB/i2l/tb_metrics/2017-12-11 22-57-42 PST score_86.54/store/args.pkl
# Loaded ../data/dataset3/training_56/df_train.pkl (89096, 3)
# False:	2017-12-11 22-57-42 PST score_86.54
# Loaded /zpool_3TB/i2l/tb_metrics/2017-12-12 19-49-24 PST score_88.10/store/hyper.pkl and /zpool_3TB/i2l/tb_metrics/2017-12-12 19-49-24 PST score_88.10/store/args.pkl
# Loaded ../data/dataset3/training_56/df_train.pkl (89096, 3)
# False:	2017-12-12 19-49-24 PST score_88.10
# Loaded /zpool_3TB/i2l/tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.86/store/hyper.pkl and /zpool_3TB/i2l/tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.86/store/args.pkl
# Loaded ../data/dataset3/training_56/df_train.pkl (89096, 3)
# True:	2017-12-16 18-51-38 PST pLambda=0_score_88.86
# Loaded /zpool_3TB/i2l/tb_metrics/2017-12-21 02-20-10 PST 140K_data_score_89.0/store/hyper.pkl and /zpool_3TB/i2l/tb_metrics/2017-12-21 02-20-10 PST 140K_data_score_89.0/store/args.pkl
# Loaded ../data/dataset5/training_56/df_train.pkl (114408, 3)
# True:	2017-12-21 02-20-10 PST 140K_data_score_89.0
