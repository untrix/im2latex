# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import pandas as pd
import os
import re
import codecs
from IPython.display import display
from six.moves import cPickle as pickle
import string
from PIL import Image
import numpy as np
import h5py

# %%
width = None
pd.options.display.max_rows = 600
pd.options.display.max_columns = width
pd.options.display.max_colwidth = 600
pd.options.display.width = width
pd.options.display.max_seq_items = None
pd.options.display.expand_frame_repr = False
pd.options.display.colheader_justify = 'left'

# %%
import data_commons as dtc
import dl_commons as dlc
import viz_commons as vc
from viz_commons import VisualizeDir, DiffParams, VisualizeStep
# Out:
# Using TensorFlow backend.

# %%
diff = DiffParams('/zpool_3TB/i2l/tb_metrics/2017-12-12 19-49-24 PST score_88.10', './tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88+')
one, two = diff.get_hyper()
head, tail = diff.hyper(show=True)
# head[~head[0].str.contains('CONVNET')]
# Out:
#    0                                                               1
# 0                                             target_ase ===> 5.27                                                         target_ase ===> None
# 1                                      build_init_model ===> False                                                   build_init_model ===> True
# 2                  output_layers.layers_3.num_units ===> undefined                                    output_layers.layers_3.num_units ===> 358
# 3               output_layers.layers_3.tb.tb_biases ===> undefined                              output_layers.layers_3.tb.tb_biases ===> Biases
# 4   CALSTM_STACK_1.raw_data_dir ===> ../data/dataset3/training_56/                CALSTM_STACK_1.raw_data_dir ===> ../data/dataset3/training_56
# 5          output_layers.layers_3.tb.tb_activations ===> undefined                    output_layers.layers_3.tb.tb_activations ===> Activations
# 6              output_layers.layers_3.activation_fn ===> undefined                               output_layers.layers_3.activation_fn ===> None
# 7                                              pLambda ===> 0.0005                                                             pLambda ===> 0.0
# 8              output_layers.layers_3.tb.tb_weights ===> undefined                            output_layers.layers_3.tb.tb_weights ===> Weights
# 9         output_layers.layers_3.biases_regularizer ===> undefined                          output_layers.layers_3.biases_regularizer ===> None
# 10                 raw_data_dir ===> ../data/dataset3/training_56/                               raw_data_dir ===> ../data/dataset3/training_56
# 11                  output_layers.layers_2.activation_fn ===> None  output_layers.layers_2.activation_fn ===> <function tanh at 0x7f5fb59a8320>
# 12                   output_layers.layers_3.dropout ===> undefined                                     output_layers.layers_3.dropout ===> None
#    0                                                                                                                           1
# 0                                                         CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f5facda2110>                                                        CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f5facda25d0>
# 1                     CONVNET.layers_7.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facd834d0>                    CONVNET.layers_7.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facda2390>
# 2                                          CONVNET.layers_7.weights_initializer ===> <function _initializer at 0x7f5facdd4cf8>                                         CONVNET.layers_7.weights_initializer ===> <function _initializer at 0x7f5facdd4d70>
# 3                                          CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7f5facdd4cf8>                                         CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7f5facdd4d70>
# 4                     CONVNET.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facd834d0>                    CONVNET.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facda2390>
# 5                                          CONVNET.layers_9.weights_initializer ===> <function _initializer at 0x7f5facdd4cf8>                                         CONVNET.layers_9.weights_initializer ===> <function _initializer at 0x7f5facdd4d70>
# 6                                                                    output_layers.layers_3.weights_regularizer ===> undefined                                             output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f5facdd4c08>
# 7                                             init_model_final_layers.weights_regularizer ===> <function l2 at 0x7f5facdd4c80>                                            init_model_final_layers.weights_regularizer ===> <function l2 at 0x7f5facdd4c08>
# 8                                init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7f5facdd4cf8>                               init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7f5facdd4d70>
# 9                                                                  embeddings_regularizer ===> <function l2 at 0x7f5facdd4c80>                                                                 embeddings_regularizer ===> <function l2 at 0x7f5facdd4c08>
# 10                       CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f5facdd4cf8>                       CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f5facdd4d70>
# 11                                     biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facd834d0>                                     biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facda2390>
# 12          init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facd834d0>          init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facda2390>
# 13                                 CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f5facdd4c80>                                 CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f5facdd4c08>
# 14                                         CONVNET.layers_5.weights_initializer ===> <function _initializer at 0x7f5facdd4cf8>                                         CONVNET.layers_5.weights_initializer ===> <function _initializer at 0x7f5facdd4d70>
# 15                                             output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f5facdd4c80>                                             output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f5facdd4c08>
# 16  CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facd834d0>  CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facda2390>
# 17                                                   CONVNET.layers_5.weights_regularizer ===> <function l2 at 0x7f5facdd4c80>                                                   CONVNET.layers_5.weights_regularizer ===> <function l2 at 0x7f5facdd4c08>
# 18                                                                          output_layers.layers_3.tb.tb_logdir ===> undefined                                                                       output_layers.layers_3.tb.tb_logdir ===> ./tb_metrics
# 19                       CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f5facdd4cf8>                       CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f5facdd4d70>
# 20                                                                   output_layers.layers_3.weights_initializer ===> undefined                                   output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f5facdd4d70>
# 21                    CONVNET.layers_5.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facd834d0>                    CONVNET.layers_5.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facda2390>
# 22                                                                         output_layers.layers_3.tb.logdir_tag ===> undefined                                                                              output_layers.layers_3.tb.logdir_tag ===> None
# 23                                  init_model_final_layers.weights_initializer ===> <function _initializer at 0x7f5facdd4cf8>                                  init_model_final_layers.weights_initializer ===> <function _initializer at 0x7f5facdd4d70>
# 24                                                   CONVNET.layers_9.weights_regularizer ===> <function l2 at 0x7f5facdd4c80>                                                   CONVNET.layers_9.weights_regularizer ===> <function l2 at 0x7f5facdd4c08>
# 25                                                                       logger ===> <logging.Logger object at 0x7f5facda2110>                                                                       logger ===> <logging.Logger object at 0x7f5facda25d0>
# 26                                                          weights_initializer ===> <function _initializer at 0x7f5facdd4cf8>                                                          weights_initializer ===> <function _initializer at 0x7f5facdd4d70>
# 27                                 CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f5facdd4c80>                                 CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f5facdd4c08>
# 28                                             output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f5facdd4c80>                                             output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f5facdd4c08>
# 29                                                       embeddings_initializer ===> <function _initializer at 0x7f5facdd4cf8>                                                       embeddings_initializer ===> <function _initializer at 0x7f5facdd4d70>
# 30                    CONVNET.layers_9.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facd834d0>                    CONVNET.layers_9.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facda2390>
# 31  CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facd834d0>  CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facda2390>
# 32                                                     CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7f5facdd4c80>                                                     CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7f5facdd4c08>
# 33                    CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facd834d0>                    CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facda2390>
# 34                                   output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f5facdd4cf8>                                   output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f5facdd4d70>
# 35  CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facd834d0>  CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facda2390>
# 36                                 CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f5facdd4c80>                                 CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f5facdd4c08>
# 37              output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facd834d0>              output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facda2390>
# 38                                           CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7f5facdd4cf8>                                           CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7f5facdd4d70>
# 39                                         CONVNET.layers_3.weights_initializer ===> <function _initializer at 0x7f5facdd4cf8>                                         CONVNET.layers_3.weights_initializer ===> <function _initializer at 0x7f5facdd4d70>
# 40                                                   CONVNET.layers_7.weights_regularizer ===> <function l2 at 0x7f5facdd4c80>                                                   CONVNET.layers_7.weights_regularizer ===> <function l2 at 0x7f5facdd4c08>
# 41                                                   CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7f5facdd4c80>                                                   CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7f5facdd4c08>
# 42                                   output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f5facdd4cf8>                                   output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f5facdd4d70>
# 43             init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facd834d0>             init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facda2390>
# 44                              CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7f5facdd4cf8>                              CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7f5facdd4d70>
# 45                                                                    output_layers.layers_3.biases_initializer ===> undefined              output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facda2390>
# 46                       CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f5facdd4cf8>                       CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f5facdd4d70>
# 47                      CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facd834d0>                      CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facda2390>
# 48                                                                    weights_regularizer ===> <function l2 at 0x7f5facdd4c80>                                                                    weights_regularizer ===> <function l2 at 0x7f5facdd4c08>
# 49              output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facd834d0>              output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5facda2390>
# 50                                        CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7f5facdd4c80>                                        CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7f5facdd4c08>
# 51                                                   CONVNET.layers_3.weights_regularizer ===> <function l2 at 0x7f5facdd4c80>                                                   CONVNET.layers_3.weights_regularizer ===> <function l2 at 0x7f5facdd4c08>
# 52                                         init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7f5facdd4c80>                                         init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7f5facdd4c08>

# %%
len(one['output_layers']['layers'])
# Out:
# 2
