# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import pandas as pd
import os
import re
import codecs
from IPython.display import display
from six.moves import cPickle as pickle
import string
from PIL import Image
import numpy as np
import h5py

# %%
width = None
pd.options.display.max_rows = 600
pd.options.display.max_columns = width
pd.options.display.max_colwidth = 600
pd.options.display.width = width
pd.options.display.max_seq_items = None
pd.options.display.expand_frame_repr = False
pd.options.display.colheader_justify = 'left'

# %%
import data_commons as dtc
import dl_commons as dlc
import viz_commons as vc
from viz_commons import VisualizeDir, DiffParams, VisualizeStep

# %%
# diff = DiffParams('/zpool_3TB/i2l/tb_metrics/2017-11-20 23-11-24 PST 81.76bleu2_3.1LSTM_2init_3OutMLP_3attMLPfull_regroupImage_i=2', '/zpool_3TB/i2l/tb_metrics/2017-11-20 23-11-24 PST 81.76bleu2_3.1LSTM_2init_3OutMLP_3attMLPfull_regroupImage_i=2/82.89_train_snapshot-00087700_target_ase')
# diff = DiffParams('/zpool_3TB/i2l/tb_metrics/2017-11-20 23-11-24 PST 81.76bleu2_3.1LSTM_2init_3OutMLP_3attMLPfull_regroupImage_i=2', './tb_metrics/2017-11-28 15-54-35 PST scanningRNN_regroupImage')
# diff = DiffParams('./tb_metrics/2017-11-27 21-20-46 PST scanningRNN_regroupImage', './tb_metrics/2017-11-28 15-54-35 PST scanningRNN_regroupImage')
diff = DiffParams('./tb_metrics/2017-11-28 08-34-47 PST scanningRNN_regroupImage', './tb_metrics/2017-11-30 11-53-23 PST scanningRNN_regroupImage/SFactor=1.5')
# diff = DiffParams('./tb_metrics/2017-11-28 01-40-26 PST scanningRNN_regroupImage', './tb_metrics/2017-11-28 15-54-35 PST scanningRNN_regroupImage')
one, two = diff.get_hyper()
diff.hyper()
# Out:
#   0                      1
# 0   target_ase ===> 10.0       target_ase ===> None
# 1    pLambda ===> 0.0005           pLambda ===> 0.0
# 2  target_aae ===> 51.42  target_aae ===> undefined
#    0                                                                                                                           1
# 0           init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c629390>          init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038efa10>
# 1                                          CONVNET.layers_2.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                                         CONVNET.layers_2.weights_initializer ===> <function _initializer at 0x7f460384c758>
# 2                     CONVNET.layers_6.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c629390>                    CONVNET.layers_6.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038efa10>
# 3                                          init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                         init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7f460380d758>
# 4                                                      CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                                     CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7f460380d758>
# 5                                                    CONVNET.layers_2.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                                   CONVNET.layers_2.weights_regularizer ===> <function l2 at 0x7f460380d758>
# 6                                                      CALSTM_STACK_1.decoder_lstm.tb.logdir_tag ===> scanningRNN_regroupImage                                        CALSTM_STACK_1.decoder_lstm.tb.logdir_tag ===> scanningRNN_regroupImage/SFactor=1.5/
# 7                                              output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                             output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f460380d758>
# 8                                    output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                                   output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f460384c758>
# 9                                                         CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f46038ef850>                                                        CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f46038ef3d0>
# 10                                                                   output_layers.tb.logdir_tag ===> scanningRNN_regroupImage                                                      output_layers.tb.logdir_tag ===> scanningRNN_regroupImage/SFactor=1.5/
# 11                                                          output_layers.layers_1.tb.logdir_tag ===> scanningRNN_regroupImage                                             output_layers.layers_1.tb.logdir_tag ===> scanningRNN_regroupImage/SFactor=1.5/
# 12                                         CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                                         CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c758>
# 13                       CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                       CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f460384c758>
# 14                                     biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c629390>                                     biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038efa10>
# 15                                 CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                 CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f460380d758>
# 16                                                                  CALSTM_STACK_1.tb.logdir_tag ===> scanningRNN_regroupImage                                                     CALSTM_STACK_1.tb.logdir_tag ===> scanningRNN_regroupImage/SFactor=1.5/
# 17                                                   CONVNET.layers_4.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                                   CONVNET.layers_4.weights_regularizer ===> <function l2 at 0x7f460380d758>
# 18                                                       embeddings_initializer ===> <function _initializer at 0x7f460384c7d0>                                                       embeddings_initializer ===> <function _initializer at 0x7f460384c758>
# 19                                             output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                             output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f460380d758>
# 20                                         CONVNET.layers_6.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                                         CONVNET.layers_6.weights_initializer ===> <function _initializer at 0x7f460384c758>
# 21  CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c629390>  CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038efa10>
# 22  CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c629390>  CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038efa10>
# 23                    CONVNET.layers_8.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c629390>                    CONVNET.layers_8.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038efa10>
# 24                       CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                       CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f460384c758>
# 25                                        CONVNET.layers_10.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                                        CONVNET.layers_10.weights_initializer ===> <function _initializer at 0x7f460384c758>
# 26                                                          output_layers.layers_3.tb.logdir_tag ===> scanningRNN_regroupImage                                             output_layers.layers_3.tb.logdir_tag ===> scanningRNN_regroupImage/SFactor=1.5/
# 27                                                         init_model_final_layers.tb.logdir_tag ===> scanningRNN_regroupImage                                            init_model_final_layers.tb.logdir_tag ===> scanningRNN_regroupImage/SFactor=1.5/
# 28                                         CONVNET.layers_4.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                                         CONVNET.layers_4.weights_initializer ===> <function _initializer at 0x7f460384c758>
# 29                                 CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                 CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f460380d758>
# 30                                                                       logger ===> <logging.Logger object at 0x7f46038ef850>                                                                       logger ===> <logging.Logger object at 0x7f46038ef3d0>
# 31                                                       CALSTM_STACK_1.att_layers.tb.logdir_tag ===> scanningRNN_regroupImage                                          CALSTM_STACK_1.att_layers.tb.logdir_tag ===> scanningRNN_regroupImage/SFactor=1.5/
# 32                                 CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                 CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f460380d758>
# 33                                             output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                             output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f460380d758>
# 34                                                                                 tb.logdir_tag ===> scanningRNN_regroupImage                                                                    tb.logdir_tag ===> scanningRNN_regroupImage/SFactor=1.5/
# 35                                   output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                                   output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f460384c758>
# 36                                  init_model_final_layers.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                                  init_model_final_layers.weights_initializer ===> <function _initializer at 0x7f460384c758>
# 37                                                  CONVNET.layers_10.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                                  CONVNET.layers_10.weights_regularizer ===> <function l2 at 0x7f460380d758>
# 38                                              CALSTM_STACK_1.att_layers.layers_3.tb.logdir_tag ===> scanningRNN_regroupImage                                 CALSTM_STACK_1.att_layers.layers_3.tb.logdir_tag ===> scanningRNN_regroupImage/SFactor=1.5/
# 39                                                      init_model_hidden.layers_1.tb.logdir_tag ===> scanningRNN_regroupImage                                         init_model_hidden.layers_1.tb.logdir_tag ===> scanningRNN_regroupImage/SFactor=1.5/
# 40                    CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c629390>                    CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038efa10>
# 41                    CONVNET.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c629390>                    CONVNET.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038efa10>
# 42                                   output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                                   output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c758>
# 43                                              CALSTM_STACK_1.att_layers.layers_1.tb.logdir_tag ===> scanningRNN_regroupImage                                 CALSTM_STACK_1.att_layers.layers_1.tb.logdir_tag ===> scanningRNN_regroupImage/SFactor=1.5/
# 44                   CONVNET.layers_10.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c629390>                   CONVNET.layers_10.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038efa10>
# 45                                                                         CONVNET.tb.logdir_tag ===> scanningRNN_regroupImage                                                            CONVNET.tb.logdir_tag ===> scanningRNN_regroupImage/SFactor=1.5/
# 46                                        CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                        CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7f460380d758>
# 47              output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c629390>              output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038efa10>
# 48                                           CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                                           CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7f460384c758>
# 49                                              CALSTM_STACK_1.att_layers.layers_2.tb.logdir_tag ===> scanningRNN_regroupImage                                 CALSTM_STACK_1.att_layers.layers_2.tb.logdir_tag ===> scanningRNN_regroupImage/SFactor=1.5/
# 50                                                   CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                                   CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7f460380d758>
# 51                                                   CONVNET.layers_6.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                                   CONVNET.layers_6.weights_regularizer ===> <function l2 at 0x7f460380d758>
# 52                    CONVNET.layers_4.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c629390>                    CONVNET.layers_4.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038efa10>
# 53                                         CONVNET.layers_8.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                                         CONVNET.layers_8.weights_initializer ===> <function _initializer at 0x7f460384c758>
# 54                                            init_model_final_layers.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                            init_model_final_layers.weights_regularizer ===> <function l2 at 0x7f460380d758>
# 55             init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c629390>             init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038efa10>
# 56                              CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                              CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7f460384c758>
# 57                                                          output_layers.layers_2.tb.logdir_tag ===> scanningRNN_regroupImage                                             output_layers.layers_2.tb.logdir_tag ===> scanningRNN_regroupImage/SFactor=1.5/
# 58                       CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                       CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c758>
# 59                      CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c629390>                      CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038efa10>
# 60                                                                    weights_regularizer ===> <function l2 at 0x7f460384cb18>                                                                    weights_regularizer ===> <function l2 at 0x7f460380d758>
# 61              output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c629390>              output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038efa10>
# 62                                                               init_model_hidden.tb.logdir_tag ===> scanningRNN_regroupImage                                                  init_model_hidden.tb.logdir_tag ===> scanningRNN_regroupImage/SFactor=1.5/
# 63              output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c629390>              output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038efa10>
# 64                                                          weights_initializer ===> <function _initializer at 0x7f460384c7d0>                                                          weights_initializer ===> <function _initializer at 0x7f460384c758>
# 65  CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c629390>  CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038efa10>
# 66                                                   CONVNET.layers_8.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                                   CONVNET.layers_8.weights_regularizer ===> <function l2 at 0x7f460380d758>
# 67                               init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                               init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c758>
# 68                                                                 embeddings_regularizer ===> <function l2 at 0x7f460384cb18>                                                                 embeddings_regularizer ===> <function l2 at 0x7f460380d758>

# %%
print(one['pLambda'])
# Out:
# 0.0

# %%
diff = DiffParams('./tb_metrics/2017-11-28 08-34-47 PST scanningRNN_regroupImage', './tb_metrics/2017-11-28 01-40-26 PST scanningRNN_regroupImage')
one, two = diff.get_hyper()
print('lambda', one['pLambda'], two['pLambda'])
diff.hyper()
# Out:
# ('lambda', 0.0005, 0.0)
#   0                                         1
# 0                      target_ase ===> 10.0                       target_ase ===> 15.0
# 1  output_layers.layers_1.num_units ===> 64  output_layers.layers_1.num_units ===> 358
# 2                       pLambda ===> 0.0005                           pLambda ===> 0.0
# 3  output_layers.layers_2.num_units ===> 64  output_layers.layers_2.num_units ===> 358
#    0                                                                                                                           1
# 0                                                         CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f4603883e10>                                                        CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f46038efad0>
# 1                     CONVNET.layers_6.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038fecd0>                    CONVNET.layers_6.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef050>
# 2                                          init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7f460384ca28>                                         init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7f460384c758>
# 3                                                      CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7f460384ca28>                                                     CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7f460384c758>
# 4                                                    CONVNET.layers_2.weights_regularizer ===> <function l2 at 0x7f460384ca28>                                                   CONVNET.layers_2.weights_regularizer ===> <function l2 at 0x7f460384c758>
# 5                                              output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f460384ca28>                                             output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f460384c758>
# 6                                             init_model_final_layers.weights_regularizer ===> <function l2 at 0x7f460384ca28>                                            init_model_final_layers.weights_regularizer ===> <function l2 at 0x7f460384c758>
# 7                                          CONVNET.layers_6.weights_initializer ===> <function _initializer at 0x7f460384c6e0>                                         CONVNET.layers_6.weights_initializer ===> <function _initializer at 0x7f460384c410>
# 8                                init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c6e0>                               init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c410>
# 9                                          CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c6e0>                                         CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c410>
# 10                       CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f460384c6e0>                       CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f460384c410>
# 11                                     biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038fecd0>                                     biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef050>
# 12          init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038fecd0>          init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef050>
# 13                                        CONVNET.layers_10.weights_initializer ===> <function _initializer at 0x7f460384c6e0>                                        CONVNET.layers_10.weights_initializer ===> <function _initializer at 0x7f460384c410>
# 14                                                   CONVNET.layers_4.weights_regularizer ===> <function l2 at 0x7f460384ca28>                                                   CONVNET.layers_4.weights_regularizer ===> <function l2 at 0x7f460384c758>
# 15                                                       embeddings_initializer ===> <function _initializer at 0x7f460384c6e0>                                                       embeddings_initializer ===> <function _initializer at 0x7f460384c410>
# 16                                             output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f460384ca28>                                             output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f460384c758>
# 17  CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038fecd0>  CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef050>
# 18                    CONVNET.layers_8.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038fecd0>                    CONVNET.layers_8.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef050>
# 19                       CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f460384c6e0>                       CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f460384c410>
# 20                                 CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f460384ca28>                                 CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f460384c758>
# 21                                         CONVNET.layers_2.weights_initializer ===> <function _initializer at 0x7f460384c6e0>                                         CONVNET.layers_2.weights_initializer ===> <function _initializer at 0x7f460384c410>
# 22  CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038fecd0>  CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef050>
# 23                                         CONVNET.layers_4.weights_initializer ===> <function _initializer at 0x7f460384c6e0>                                         CONVNET.layers_4.weights_initializer ===> <function _initializer at 0x7f460384c410>
# 24                                 CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f460384ca28>                                 CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f460384c758>
# 25                                                                       logger ===> <logging.Logger object at 0x7f4603883e10>                                                                       logger ===> <logging.Logger object at 0x7f46038efad0>
# 26                                 CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f460384ca28>                                 CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f460384c758>
# 27                                             output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f460384ca28>                                             output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f460384c758>
# 28                                   output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f460384c6e0>                                   output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f460384c410>
# 29                                  init_model_final_layers.weights_initializer ===> <function _initializer at 0x7f460384c6e0>                                  init_model_final_layers.weights_initializer ===> <function _initializer at 0x7f460384c410>
# 30                                                  CONVNET.layers_10.weights_regularizer ===> <function l2 at 0x7f460384ca28>                                                  CONVNET.layers_10.weights_regularizer ===> <function l2 at 0x7f460384c758>
# 31                    CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038fecd0>                    CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef050>
# 32                    CONVNET.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038fecd0>                    CONVNET.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef050>
# 33                                   output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c6e0>                                   output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c410>
# 34                   CONVNET.layers_10.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038fecd0>                   CONVNET.layers_10.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef050>
# 35  CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038fecd0>  CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef050>
# 36                                                          weights_initializer ===> <function _initializer at 0x7f460384c6e0>                                                          weights_initializer ===> <function _initializer at 0x7f460384c410>
# 37              output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038fecd0>              output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef050>
# 38                                           CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7f460384c6e0>                                           CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7f460384c410>
# 39                                                   CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7f460384ca28>                                                   CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7f460384c758>
# 40                                                   CONVNET.layers_6.weights_regularizer ===> <function l2 at 0x7f460384ca28>                                                   CONVNET.layers_6.weights_regularizer ===> <function l2 at 0x7f460384c758>
# 41                    CONVNET.layers_4.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038fecd0>                    CONVNET.layers_4.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef050>
# 42                                         CONVNET.layers_8.weights_initializer ===> <function _initializer at 0x7f460384c6e0>                                         CONVNET.layers_8.weights_initializer ===> <function _initializer at 0x7f460384c410>
# 43                                   output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f460384c6e0>                                   output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f460384c410>
# 44             init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038fecd0>             init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef050>
# 45                              CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7f460384c6e0>                              CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7f460384c410>
# 46              output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038fecd0>              output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef050>
# 47                       CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c6e0>                       CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c410>
# 48                      CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038fecd0>                      CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef050>
# 49                                                                    weights_regularizer ===> <function l2 at 0x7f460384ca28>                                                                    weights_regularizer ===> <function l2 at 0x7f460384c758>
# 50                                                   CONVNET.layers_8.weights_regularizer ===> <function l2 at 0x7f460384ca28>                                                   CONVNET.layers_8.weights_regularizer ===> <function l2 at 0x7f460384c758>
# 51              output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038fecd0>              output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef050>
# 52                                        CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7f460384ca28>                                        CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7f460384c758>
# 53                                                                 embeddings_regularizer ===> <function l2 at 0x7f460384ca28>                                                                 embeddings_regularizer ===> <function l2 at 0x7f460384c758>

# %%
diff = DiffParams('./tb_metrics/2017-11-28 01-40-26 PST scanningRNN_regroupImage', './tb_metrics/2017-11-28 15-54-35 PST scanningRNN_regroupImage')
one, two = diff.get_hyper()
print('lambda', one['pLambda'], two['pLambda'])
diff.hyper()
# Out:
# ('lambda', 0.0, 0.0)
#   0                                          1
# 0                           SFactor ===> 1.5                          SFactor ===> 1.0
# 1                       target_ase ===> 15.0                      target_ase ===> None
# 2  output_layers.layers_2.num_units ===> 358  output_layers.layers_2.num_units ===> 64
# 3                              MaxS ===> 226                             MaxS ===> 151
# 4  output_layers.layers_1.num_units ===> 358  output_layers.layers_1.num_units ===> 64
# 5                      target_aae ===> 51.42                 target_aae ===> undefined
#    0                                                                                                                           1
# 0           init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46536a6990>          init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef110>
# 1                     CONVNET.layers_6.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46536a6990>                    CONVNET.layers_6.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef110>
# 2                                          init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                         init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7f460384c668>
# 3                                                      CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                                     CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7f460384c668>
# 4                                                    CONVNET.layers_2.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                                   CONVNET.layers_2.weights_regularizer ===> <function l2 at 0x7f460384c668>
# 5                                              output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                             output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f460384c668>
# 6                                    output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                                   output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f460384c320>
# 7                                          CONVNET.layers_6.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                                         CONVNET.layers_6.weights_initializer ===> <function _initializer at 0x7f460384c320>
# 8                                init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                               init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c320>
# 9                                          CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                                         CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c320>
# 10                       CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                       CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f460384c320>
# 11                                     biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46536a6990>                                     biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef110>
# 12                                        CONVNET.layers_10.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                                        CONVNET.layers_10.weights_initializer ===> <function _initializer at 0x7f460384c320>
# 13                                                   CONVNET.layers_4.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                                   CONVNET.layers_4.weights_regularizer ===> <function l2 at 0x7f460384c668>
# 14                                                       embeddings_initializer ===> <function _initializer at 0x7f460384c7d0>                                                       embeddings_initializer ===> <function _initializer at 0x7f460384c320>
# 15                                             output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                             output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f460384c668>
# 16  CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46536a6990>  CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef110>
# 17                                                        CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f46038ef7d0>                                                        CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f46038efa50>
# 18                    CONVNET.layers_8.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46536a6990>                    CONVNET.layers_8.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef110>
# 19                       CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                       CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f460384c320>
# 20                                 CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                 CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f460384c668>
# 21                                         CONVNET.layers_2.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                                         CONVNET.layers_2.weights_initializer ===> <function _initializer at 0x7f460384c320>
# 22                                  init_model_final_layers.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                                  init_model_final_layers.weights_initializer ===> <function _initializer at 0x7f460384c320>
# 23                                         CONVNET.layers_4.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                                         CONVNET.layers_4.weights_initializer ===> <function _initializer at 0x7f460384c320>
# 24                                 CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                 CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f460384c668>
# 25                                                                       logger ===> <logging.Logger object at 0x7f46038ef7d0>                                                                       logger ===> <logging.Logger object at 0x7f46038efa50>
# 26                                 CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                 CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f460384c668>
# 27                                             output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                             output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f460384c668>
# 28                                   output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                                   output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f460384c320>
# 29  CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46536a6990>  CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef110>
# 30                                                  CONVNET.layers_10.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                                  CONVNET.layers_10.weights_regularizer ===> <function l2 at 0x7f460384c668>
# 31                    CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46536a6990>                    CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef110>
# 32                    CONVNET.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46536a6990>                    CONVNET.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef110>
# 33                                   output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                                   output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c320>
# 34                   CONVNET.layers_10.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46536a6990>                   CONVNET.layers_10.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef110>
# 35  CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46536a6990>  CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef110>
# 36                                                          weights_initializer ===> <function _initializer at 0x7f460384c7d0>                                                          weights_initializer ===> <function _initializer at 0x7f460384c320>
# 37              output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46536a6990>              output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef110>
# 38                                           CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                                           CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7f460384c320>
# 39                                                   CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                                   CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7f460384c668>
# 40                                                   CONVNET.layers_6.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                                   CONVNET.layers_6.weights_regularizer ===> <function l2 at 0x7f460384c668>
# 41                    CONVNET.layers_4.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46536a6990>                    CONVNET.layers_4.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef110>
# 42                                         CONVNET.layers_8.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                                         CONVNET.layers_8.weights_initializer ===> <function _initializer at 0x7f460384c320>
# 43                                            init_model_final_layers.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                            init_model_final_layers.weights_regularizer ===> <function l2 at 0x7f460384c668>
# 44             init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46536a6990>             init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef110>
# 45                              CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                              CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7f460384c320>
# 46              output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46536a6990>              output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef110>
# 47                       CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c7d0>                       CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c320>
# 48                      CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46536a6990>                      CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef110>
# 49                                                                    weights_regularizer ===> <function l2 at 0x7f460384cb18>                                                                    weights_regularizer ===> <function l2 at 0x7f460384c668>
# 50                                                   CONVNET.layers_8.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                                   CONVNET.layers_8.weights_regularizer ===> <function l2 at 0x7f460384c668>
# 51              output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46536a6990>              output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef110>
# 52                                        CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7f460384cb18>                                        CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7f460384c668>
# 53                                                                 embeddings_regularizer ===> <function l2 at 0x7f460384cb18>                                                                 embeddings_regularizer ===> <function l2 at 0x7f460384c668>

# %%
diff = DiffParams('./tb_metrics/2017-11-27 21-20-46 PST scanningRNN_regroupImage', './tb_metrics/2017-11-28 01-40-26 PST scanningRNN_regroupImage')
one, two = diff.get_hyper()
print('lambda', one['pLambda'], two['pLambda'])
diff.hyper()
# Out:
# ('lambda', 0.0, 0.0)
#   0                                         1
# 0  output_layers.layers_2.num_units ===> 64  output_layers.layers_2.num_units ===> 358
# 1                     adam_alpha ===> 0.001                     adam_alpha ===> 0.0001
# 2  output_layers.layers_1.num_units ===> 64  output_layers.layers_1.num_units ===> 358
#    0                                                                                                                           1
# 0                                                         CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f4603807890>                                                        CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f46039006d0>
# 1                     CONVNET.layers_6.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c6293d0>                    CONVNET.layers_6.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603807290>
# 2                        CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f460384c8c0>                       CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f460384c578>
# 3                                                      CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7f460384c6e0>                                                     CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7f460384c5f0>
# 4                                                    CONVNET.layers_2.weights_regularizer ===> <function l2 at 0x7f460384c6e0>                                                   CONVNET.layers_2.weights_regularizer ===> <function l2 at 0x7f460384c5f0>
# 5                                              output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f460384c6e0>                                             output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f460384c5f0>
# 6                                    output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f460384c8c0>                                   output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f460384c578>
# 7                                          CONVNET.layers_6.weights_initializer ===> <function _initializer at 0x7f460384c8c0>                                         CONVNET.layers_6.weights_initializer ===> <function _initializer at 0x7f460384c578>
# 8                                init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c8c0>                               init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c578>
# 9                                                                  embeddings_regularizer ===> <function l2 at 0x7f460384c6e0>                                                                 embeddings_regularizer ===> <function l2 at 0x7f460384c5f0>
# 10                                         init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7f460384c6e0>                                         init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7f460384c5f0>
# 11                                     biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c6293d0>                                     biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603807290>
# 12          init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c6293d0>          init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603807290>
# 13                                        CONVNET.layers_10.weights_initializer ===> <function _initializer at 0x7f460384c8c0>                                        CONVNET.layers_10.weights_initializer ===> <function _initializer at 0x7f460384c578>
# 14                                                   CONVNET.layers_4.weights_regularizer ===> <function l2 at 0x7f460384c6e0>                                                   CONVNET.layers_4.weights_regularizer ===> <function l2 at 0x7f460384c5f0>
# 15                                                       embeddings_initializer ===> <function _initializer at 0x7f460384c8c0>                                                       embeddings_initializer ===> <function _initializer at 0x7f460384c578>
# 16                                             output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f460384c6e0>                                             output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f460384c5f0>
# 17  CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c6293d0>  CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603807290>
# 18                    CONVNET.layers_8.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c6293d0>                    CONVNET.layers_8.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603807290>
# 19                       CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f460384c8c0>                       CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f460384c578>
# 20                                 CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f460384c6e0>                                 CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f460384c5f0>
# 21                                         CONVNET.layers_2.weights_initializer ===> <function _initializer at 0x7f460384c8c0>                                         CONVNET.layers_2.weights_initializer ===> <function _initializer at 0x7f460384c578>
# 22                                  init_model_final_layers.weights_initializer ===> <function _initializer at 0x7f460384c8c0>                                  init_model_final_layers.weights_initializer ===> <function _initializer at 0x7f460384c578>
# 23                                         CONVNET.layers_4.weights_initializer ===> <function _initializer at 0x7f460384c8c0>                                         CONVNET.layers_4.weights_initializer ===> <function _initializer at 0x7f460384c578>
# 24                                 CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f460384c6e0>                                 CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f460384c5f0>
# 25                                                                       logger ===> <logging.Logger object at 0x7f4603807890>                                                                       logger ===> <logging.Logger object at 0x7f46039006d0>
# 26                                 CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f460384c6e0>                                 CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f460384c5f0>
# 27                                             output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f460384c6e0>                                             output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f460384c5f0>
# 28                                   output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f460384c8c0>                                   output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f460384c578>
# 29  CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c6293d0>  CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603807290>
# 30                                                  CONVNET.layers_10.weights_regularizer ===> <function l2 at 0x7f460384c6e0>                                                  CONVNET.layers_10.weights_regularizer ===> <function l2 at 0x7f460384c5f0>
# 31                    CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c6293d0>                    CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603807290>
# 32                    CONVNET.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c6293d0>                    CONVNET.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603807290>
# 33                                   output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c8c0>                                   output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c578>
# 34                   CONVNET.layers_10.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c6293d0>                   CONVNET.layers_10.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603807290>
# 35  CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c6293d0>  CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603807290>
# 36                                        CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7f460384c6e0>                                        CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7f460384c5f0>
# 37              output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c6293d0>              output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603807290>
# 38                                           CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7f460384c8c0>                                           CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7f460384c578>
# 39                                                   CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7f460384c6e0>                                                   CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7f460384c5f0>
# 40                                                   CONVNET.layers_6.weights_regularizer ===> <function l2 at 0x7f460384c6e0>                                                   CONVNET.layers_6.weights_regularizer ===> <function l2 at 0x7f460384c5f0>
# 41                    CONVNET.layers_4.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c6293d0>                    CONVNET.layers_4.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603807290>
# 42                                         CONVNET.layers_8.weights_initializer ===> <function _initializer at 0x7f460384c8c0>                                         CONVNET.layers_8.weights_initializer ===> <function _initializer at 0x7f460384c578>
# 43                                            init_model_final_layers.weights_regularizer ===> <function l2 at 0x7f460384c6e0>                                            init_model_final_layers.weights_regularizer ===> <function l2 at 0x7f460384c5f0>
# 44             init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c6293d0>             init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603807290>
# 45                              CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7f460384c8c0>                              CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7f460384c578>
# 46              output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c6293d0>              output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603807290>
# 47                       CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c8c0>                       CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c578>
# 48                      CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c6293d0>                      CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603807290>
# 49                                                                    weights_regularizer ===> <function l2 at 0x7f460384c6e0>                                                                    weights_regularizer ===> <function l2 at 0x7f460384c5f0>
# 50                                                   CONVNET.layers_8.weights_regularizer ===> <function l2 at 0x7f460384c6e0>                                                   CONVNET.layers_8.weights_regularizer ===> <function l2 at 0x7f460384c5f0>
# 51              output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c6293d0>              output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603807290>
# 52                                                          weights_initializer ===> <function _initializer at 0x7f460384c8c0>                                                          weights_initializer ===> <function _initializer at 0x7f460384c578>
# 53                                         CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c8c0>                                         CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7f460384c578>
