# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import pandas as pd
import os
import re
import codecs
from IPython.display import display
from six.moves import cPickle as pickle
import string
from PIL import Image
import numpy as np
import h5py

# %%
width = None
pd.options.display.max_rows = 600
pd.options.display.max_columns = width
pd.options.display.max_colwidth = 600
pd.options.display.width = width
pd.options.display.max_seq_items = None
pd.options.display.expand_frame_repr = False
pd.options.display.colheader_justify = 'left'

# %%
import data_commons as dtc
import dl_commons as dlc
import viz_commons as vc
from viz_commons import VisualizeDir, DiffParams, VisualizeStep
# Out:
# Using TensorFlow backend.

# %%
# diff = DiffParams('./tb_metrics/2017-09-26 22-40-18 PDT', './tb_metrics/2017-10-07 14-33-35 PDT_2CALSTMs')
# diff = DiffParams('./tb_metrics/2017-10-07 14-33-35 PDT', './tb_metrics/2017-10-08 12-26-45 PDT')
# diff = DiffParams('./tb_metrics/2017-09-26 22-40-18 PDT', './tb_metrics/2017-10-08 12-26-45 PDT')
# diff = DiffParams('./tb_metrics/2017-09-26 22-40-18 PDT/w=1', './tb_metrics/2017-10-08 12-26-45 PDT')
# diff = DiffParams('./tb_metrics/2017-10-09 16-01-07 PDT_good', './tb_metrics/2017-10-09 17-43-49 PDT')
# diff = DiffParams('./tb_metrics/2017-09-26 22-40-18 PDT', './tb_metrics/2017-10-09 16-01-07 PDT_good')
# diff = DiffParams('./tb_metrics_dev/2017-11-07 23-39-38 PST test_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_regroupImage_0pLambda', os.path.expanduser('~/im2latex/src/tb_metrics/2017-11-15 23-39-56 PST newData_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_regroupImage_0pLambda'))
# diff = DiffParams('/zpool_3TB/i2l/tb_metrics/2017-11-06 13-04-35 PST 2best_3.1LSTM_2init_3OutMLP_3AttMLPfull_1beta', os.path.expanduser('~/im2latex/src/tb_metrics/2017-11-15 23-39-56 PST newData_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_regroupImage_0pLambda'))
diff = DiffParams('/zpool_3TB/i2l/tb_metrics/2017-11-15 23-39-56 PST newData_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_regroupImage_0pLambda', os.path.expanduser('~/im2latex/src/tb_metrics/2017-11-16 18-32-47 PST newData_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_0pLambda'))

diff.hyper()
# Out:
#    0                                                     1
# 0                CALSTM_STACK_1.decoder_lstm.i ===> 4160                 CALSTM_STACK_1.decoder_lstm.i ===> 576
# 1                             CALSTM_STACK_1.D ===> 4096                              CALSTM_STACK_1.D ===> 512
# 2               CALSTM_STACK_1.REGROUP_IMAGE ===> [4, 2]                 CALSTM_STACK_1.REGROUP_IMAGE ===> None
# 3   CALSTM_STACK_1.att_layers.layers_1.num_units ===> 99  CALSTM_STACK_1.att_layers.layers_1.num_units ===> 136
# 4                                 SFactor ===> undefined                                       SFactor ===> 2.0
# 5                          assert_whole_batch ===> False                           assert_whole_batch ===> True
# 6       CALSTM_STACK_1.build_scanning_RNN ===> undefined           CALSTM_STACK_1.build_scanning_RNN ===> False
# 7                                CALSTM_STACK_1.H ===> 1                                CALSTM_STACK_1.H ===> 4
# ...

# %%
os.path.expanduser('~/im2latex/src/tb_metrics/2017-11-15 23-39-56 PST newData_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_regroupImage_0pLambda')
# Out:
# '/home/sumeet/im2latex/src/tb_metrics/2017-11-15 23-39-56 PST newData_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_regroupImage_0pLambda'

# %%
print diff.keys()
