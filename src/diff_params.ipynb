# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import pandas as pd
import os
import re
import codecs
from IPython.display import display
from six.moves import cPickle as pickle
import string
from PIL import Image
import numpy as np
import h5py

# %%
width = None
pd.options.display.max_rows = 600
pd.options.display.max_columns = width
pd.options.display.max_colwidth = 600
pd.options.display.width = width
pd.options.display.max_seq_items = None
pd.options.display.expand_frame_repr = False
pd.options.display.colheader_justify = 'left'

# %%
import data_commons as dtc
import dl_commons as dlc
import viz_commons as vc
from viz_commons import VisualizeDir, DiffParams, VisualizeStep

# %%
# diff = DiffParams('/zpool_3TB/i2l/tb_metrics/2017-11-20 23-11-24 PST 81.76bleu2_3.1LSTM_2init_3OutMLP_3attMLPfull_regroupImage_i=2', '/zpool_3TB/i2l/tb_metrics/2017-11-20 23-11-24 PST 81.76bleu2_3.1LSTM_2init_3OutMLP_3attMLPfull_regroupImage_i=2/82.89_train_snapshot-00087700_target_ase')
# diff = DiffParams('/zpool_3TB/i2l/tb_metrics/2017-11-20 23-11-24 PST 81.76bleu2_3.1LSTM_2init_3OutMLP_3attMLPfull_regroupImage_i=2/82.89_train_snapshot-00087700_target_ase', './tb_metrics/2017-11-28 01-40-26 PST scanningRNN_regroupImage')
# diff = DiffParams('./tb_metrics/2017-11-28 01-40-26 PST scanningRNN_regroupImage', './tb_metrics/2017-11-28 08-34-47 PST scanningRNN_regroupImage')
diff = DiffParams('./tb_metrics/2017-11-27 21-20-46 PST scanningRNN_regroupImage', './tb_metrics/2017-11-28 08-34-47 PST scanningRNN_regroupImage')
# diff = DiffParams('/zpool_3TB/i2l/tb_metrics/2017-11-20 23-11-24 PST 81.76bleu2_3.1LSTM_2init_3OutMLP_3attMLPfull_regroupImage_i=2', './tb_metrics/2017-11-28 08-34-47 PST scanningRNN_regroupImage')
diff.hyper()
# Out:
#   0                      1
# 0   target_ase ===> 15.0    target_ase ===> 10.0
# 1  adam_alpha ===> 0.001  adam_alpha ===> 0.0001
# 2       pLambda ===> 0.0     pLambda ===> 0.0005
#    0                                                                                                                           1
# 0                                                         CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f4603883810>                                                        CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f4603900710>
# 1                     CONVNET.layers_6.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038fef90>                    CONVNET.layers_6.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f4603900f50>
# ...

# %%
one, two = diff.get_hyper()
print(one['output_layers']['layers'][0]['num_units'], two['output_layers']['layers'][0]['num_units'])
# Out:
# (64, 64)

# %%
diff2 = DiffParams('./tb_metrics/2017-11-28 01-40-26 PST scanningRNN_regroupImage', './tb_metrics/2017-11-28 08-34-47 PST scanningRNN_regroupImage')
diff2.hyper()
# Out:
#   0                                          1
# 0                       target_ase ===> 15.0                      target_ase ===> 10.0
# 1  output_layers.layers_1.num_units ===> 358  output_layers.layers_1.num_units ===> 64
# 2                           pLambda ===> 0.0                       pLambda ===> 0.0005
# 3  output_layers.layers_2.num_units ===> 358  output_layers.layers_2.num_units ===> 64
#    0                                                                                                                           1
# 0                                                         CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f4603900f10>                                                        CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f4603883590>
# ...

# %%
one, two = diff2.get_hyper()
print(one['output_layers']['layers'][0]['num_units'], two['output_layers']['layers'][0]['num_units'])
# Out:
# (358, 64)

# %%
two['pLambda']
# two['pLambda']
# Out:
# 0.0005

# %%
diff3 = DiffParams('./tb_metrics/2017-11-27 21-20-46 PST scanningRNN_regroupImage', './tb_metrics/2017-11-28 01-40-26 PST scanningRNN_regroupImage')
diff3.hyper()
# Out:
#   0                                         1
# 0  output_layers.layers_2.num_units ===> 64  output_layers.layers_2.num_units ===> 358
# 1                     adam_alpha ===> 0.001                     adam_alpha ===> 0.0001
# 2  output_layers.layers_1.num_units ===> 64  output_layers.layers_1.num_units ===> 358
#    0                                                                                                                           1
# 0                                                         CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f46038ef590>                                                        CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f46038e6650>
# 1                     CONVNET.layers_6.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f467c6293d0>                    CONVNET.layers_6.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f46038ef850>
# ...
