# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import pandas as pd
import os
import re
import codecs
from IPython.display import display
from six.moves import cPickle as pickle
import string
from PIL import Image
import numpy as np
import h5py

# %%
width = None
pd.options.display.max_rows = 600
pd.options.display.max_columns = width
pd.options.display.max_colwidth = 600
pd.options.display.width = width
pd.options.display.max_seq_items = None
pd.options.display.expand_frame_repr = False
pd.options.display.colheader_justify = 'left'

# %%
import data_commons as dtc
import dl_commons as dlc
import viz_commons as vc
from viz_commons import VisualizeDir, DiffParams, VisualizeStep
# Out:
# Using TensorFlow backend.

# %%
diff = DiffParams('/zpool_3TB/i2l/tb_metrics/2017-12-23 22-02-35 PST 140K_noInitModel_score_88.74/store', './tb_metrics/2017-12-31 11-32-42 PST 140K_noRegroup_noInitModel_beta2=0.99_beta1=0.25/store')
one, two = diff.get_hyper()
head, tail = diff.hyper(show=True)
# head[~head[0].str.contains('CONVNET')]
# Out:
# Loaded /zpool_3TB/i2l/tb_metrics/2017-12-23 22-02-35 PST 140K_noInitModel_score_88.74/store
# Loaded ./tb_metrics/2017-12-31 11-32-42 PST 140K_noRegroup_noInitModel_beta2=0.99_beta1=0.25/store
# Loaded /zpool_3TB/i2l/tb_metrics/2017-12-23 22-02-35 PST 140K_noInitModel_score_88.74/store
# Loaded ./tb_metrics/2017-12-31 11-32-42 PST 140K_noRegroup_noInitModel_beta2=0.99_beta1=0.25/store
#    0                                                      1
# 0                 CALSTM_STACK_1.decoder_lstm.i ===> 2112                 CALSTM_STACK_1.decoder_lstm.i ===> 576
# 1                              CALSTM_STACK_1.D ===> 2048                              CALSTM_STACK_1.D ===> 512
# 2                                             D ===> 2048                                             D ===> 512
# 3                                CALSTM_STACK_1.L ===> 34                              CALSTM_STACK_1.L ===> 136
# 4                                                H ===> 1                                               H ===> 4
# 5                CALSTM_STACK_1.REGROUP_IMAGE ===> [4, 1]                 CALSTM_STACK_1.REGROUP_IMAGE ===> None
# 6                                 CALSTM_STACK_1.H ===> 1                                CALSTM_STACK_1.H ===> 4
# 7                                               L ===> 34                                             L ===> 136
# 8                                     adam_beta1 ===> 0.5                                   adam_beta1 ===> 0.25
# 9    CALSTM_STACK_1.att_layers.layers_3.num_units ===> 34  CALSTM_STACK_1.att_layers.layers_3.num_units ===> 136
# 10  CALSTM_STACK_1.att_layers.layers_2.num_units ===> 128  CALSTM_STACK_1.att_layers.layers_2.num_units ===> 136
# 11                              REGROUP_IMAGE ===> [4, 1]                                REGROUP_IMAGE ===> None
#    0                                                                                                                           1
# 0                                                         CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f63b008c850>                                                        CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f63b008c410>
# 1   CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f63b008ca10>  CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f63b008c0d0>
# 2                                          CONVNET.layers_7.weights_initializer ===> <function _initializer at 0x7f63b00809b0>                                         CONVNET.layers_7.weights_initializer ===> <function _initializer at 0x7f63b0087938>
# 3                                                      CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7f63ff965e60>                                                     CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7f63b00878c0>
# 4                                          CONVNET.layers_3.weights_initializer ===> <function _initializer at 0x7f63b00809b0>                                         CONVNET.layers_3.weights_initializer ===> <function _initializer at 0x7f63b0087938>
# 5                       CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f63b008ca10>                      CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f63b008c0d0>
# 6                                    output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f63b00809b0>                                   output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f63b0087938>
# 7                                  CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f63ff965e60>                                 CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f63b00878c0>
# 8                                                                               output_layers.layers_1.tb.logdir_tag ===> None                                  output_layers.layers_1.tb.logdir_tag ===> 140K_noRegroup_noInitModel_beta2=0.99_beta1=0.25
# 9                                          CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7f63b00809b0>                                         CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7f63b0087938>
# 10                       CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f63b00809b0>                       CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f63b0087938>
# 11                                     biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f63b008ca10>                                     biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f63b008c0d0>
# 12                                 CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f63ff965e60>                                 CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f63b00878c0>
# 13                                                                                      CALSTM_STACK_1.tb.logdir_tag ===> None                                          CALSTM_STACK_1.tb.logdir_tag ===> 140K_noRegroup_noInitModel_beta2=0.99_beta1=0.25
# 14                                         CONVNET.layers_5.weights_initializer ===> <function _initializer at 0x7f63b00809b0>                                         CONVNET.layers_5.weights_initializer ===> <function _initializer at 0x7f63b0087938>
# 15                                             output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f63ff965e60>                                             output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f63b00878c0>
# 16                                        CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7f63ff965e60>                                        CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7f63b00878c0>
# 17  CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f63b008ca10>  CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f63b008c0d0>
# 18                                                   CONVNET.layers_5.weights_regularizer ===> <function l2 at 0x7f63ff965e60>                                                   CONVNET.layers_5.weights_regularizer ===> <function l2 at 0x7f63b00878c0>
# 19                                                                    weights_regularizer ===> <function l2 at 0x7f63ff965e60>                                                                    weights_regularizer ===> <function l2 at 0x7f63b00878c0>
# 20                                                                                                     tb.logdir_tag ===> None                                                         tb.logdir_tag ===> 140K_noRegroup_noInitModel_beta2=0.99_beta1=0.25
# 21                                         CONVNET.layers_9.weights_initializer ===> <function _initializer at 0x7f63b00809b0>                                         CONVNET.layers_9.weights_initializer ===> <function _initializer at 0x7f63b0087938>
# 22                       CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f63b00809b0>                       CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f63b0087938>
# 23                    CONVNET.layers_9.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f63b008ca10>                    CONVNET.layers_9.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f63b008c0d0>
# 24                    CONVNET.layers_5.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f63b008ca10>                    CONVNET.layers_5.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f63b008c0d0>
# 25                                                                              output_layers.layers_3.tb.logdir_tag ===> None                                  output_layers.layers_3.tb.logdir_tag ===> 140K_noRegroup_noInitModel_beta2=0.99_beta1=0.25
# 26                                 CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f63ff965e60>                                 CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f63b00878c0>
# 27                                                                       logger ===> <logging.Logger object at 0x7f63b008c850>                                                                       logger ===> <logging.Logger object at 0x7f63b008c410>
# 28                                                                           CALSTM_STACK_1.att_layers.tb.logdir_tag ===> None                               CALSTM_STACK_1.att_layers.tb.logdir_tag ===> 140K_noRegroup_noInitModel_beta2=0.99_beta1=0.25
# 29                                                                                       output_layers.tb.logdir_tag ===> None                                           output_layers.tb.logdir_tag ===> 140K_noRegroup_noInitModel_beta2=0.99_beta1=0.25
# 30                                             output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f63ff965e60>                                             output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f63b00878c0>
# 31                                                       embeddings_initializer ===> <function _initializer at 0x7f63b00809b0>                                                       embeddings_initializer ===> <function _initializer at 0x7f63b0087938>
# 32                                   output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f63b00809b0>                                   output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f63b0087938>
# 33  CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f63b008ca10>  CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f63b008c0d0>
# 34                    CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f63b008ca10>                    CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f63b008c0d0>
# 35                                   output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f63b00809b0>                                   output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f63b0087938>
# 36                                                                  CALSTM_STACK_1.att_layers.layers_1.tb.logdir_tag ===> None                      CALSTM_STACK_1.att_layers.layers_1.tb.logdir_tag ===> 140K_noRegroup_noInitModel_beta2=0.99_beta1=0.25
# 37                                                                                             CONVNET.tb.logdir_tag ===> None                                                 CONVNET.tb.logdir_tag ===> 140K_noRegroup_noInitModel_beta2=0.99_beta1=0.25
# 38                                                   CONVNET.layers_9.weights_regularizer ===> <function l2 at 0x7f63ff965e60>                                                   CONVNET.layers_9.weights_regularizer ===> <function l2 at 0x7f63b00878c0>
# 39              output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f63b008ca10>              output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f63b008c0d0>
# 40                                           CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7f63b00809b0>                                           CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7f63b0087938>
# 41                                                                         CALSTM_STACK_1.decoder_lstm.tb.logdir_tag ===> None                             CALSTM_STACK_1.decoder_lstm.tb.logdir_tag ===> 140K_noRegroup_noInitModel_beta2=0.99_beta1=0.25
# 42                    CONVNET.layers_7.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f63b008ca10>                    CONVNET.layers_7.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f63b008c0d0>
# 43                                                   CONVNET.layers_7.weights_regularizer ===> <function l2 at 0x7f63ff965e60>                                                   CONVNET.layers_7.weights_regularizer ===> <function l2 at 0x7f63b00878c0>
# 44                                                                  CALSTM_STACK_1.att_layers.layers_2.tb.logdir_tag ===> None                      CALSTM_STACK_1.att_layers.layers_2.tb.logdir_tag ===> 140K_noRegroup_noInitModel_beta2=0.99_beta1=0.25
# 45                                                   CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7f63ff965e60>                                                   CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7f63b00878c0>
# 46                                             output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f63ff965e60>                                             output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f63b00878c0>
# 47                    CONVNET.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f63b008ca10>                    CONVNET.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f63b008c0d0>
# 48                                                                              output_layers.layers_2.tb.logdir_tag ===> None                                  output_layers.layers_2.tb.logdir_tag ===> 140K_noRegroup_noInitModel_beta2=0.99_beta1=0.25
# 49                              CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7f63b00809b0>                              CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7f63b0087938>
# 50              output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f63b008ca10>              output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f63b008c0d0>
# 51                       CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f63b00809b0>                       CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f63b0087938>
# 52                                                                  CALSTM_STACK_1.att_layers.layers_3.tb.logdir_tag ===> None                      CALSTM_STACK_1.att_layers.layers_3.tb.logdir_tag ===> 140K_noRegroup_noInitModel_beta2=0.99_beta1=0.25
# 53              output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f63b008ca10>              output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f63b008c0d0>
# 54                                                          weights_initializer ===> <function _initializer at 0x7f63b00809b0>                                                          weights_initializer ===> <function _initializer at 0x7f63b0087938>
# 55                                                   CONVNET.layers_3.weights_regularizer ===> <function l2 at 0x7f63ff965e60>                                                   CONVNET.layers_3.weights_regularizer ===> <function l2 at 0x7f63b00878c0>
# 56                                                                 embeddings_regularizer ===> <function l2 at 0x7f63ff965e60>                                                                 embeddings_regularizer ===> <function l2 at 0x7f63b00878c0>

# %%
(one['init_model_final_layers'])
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-1-59302b29a14f> in <module>()
# ----> 1 (one['init_model_final_layers'])
#
# NameError: name 'one' is not defined

# %%
two['build_init_model']

# %%
params = ['2017-12-06 15-40-46 PST score_86.14',
          '2017-12-07 23-23-25 PST score_87.45', 
          '2017-12-10 12-52-23 PST score_88.17',
          '2017-12-11 11-22-31 PST',
          '2017-12-11 22-57-42 PST score_86.54',
          '2017-12-12 19-49-24 PST score_88.10',
          '2017-12-16 18-51-38 PST pLambda=0_score_88.86',
          '2017-12-21 02-20-10 PST 140K_data_score_89.0'
         ]

for p in params:
    vd = VisualizeDir('/zpool_3TB/i2l/tb_metrics/' + p + '/store')
    if 'build_init_model' in vd.hyper:
        b = vd.hyper['build_init_model']
    else:
        b = True
    print('%s:\t%s'%(b, p))
