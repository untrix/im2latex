# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import pandas as pd
import os
import re
import codecs
from IPython.display import display
from six.moves import cPickle as pickle
import string
from PIL import Image
import numpy as np
import h5py

# %%
width = None
pd.options.display.max_rows = 600
pd.options.display.max_columns = width
pd.options.display.max_colwidth = 600
pd.options.display.width = width
pd.options.display.max_seq_items = None
pd.options.display.expand_frame_repr = False
pd.options.display.colheader_justify = 'left'

# %%
import data_commons as dtc
import dl_commons as dlc
import viz_commons as vc
from viz_commons import VisualizeDir, DiffParams, VisualizeStep
# Out:
# Using TensorFlow backend.

# %%
# diff = DiffParams('./tb_metrics/2017-09-26 22-40-18 PDT', './tb_metrics/2017-10-07 14-33-35 PDT_2CALSTMs')
# diff = DiffParams('./tb_metrics/2017-10-07 14-33-35 PDT', './tb_metrics/2017-10-08 12-26-45 PDT')
# diff = DiffParams('./tb_metrics/2017-09-26 22-40-18 PDT', './tb_metrics/2017-10-08 12-26-45 PDT')
# diff = DiffParams('./tb_metrics/2017-09-26 22-40-18 PDT/w=1', './tb_metrics/2017-10-08 12-26-45 PDT')
# diff = DiffParams('./tb_metrics/2017-10-09 16-01-07 PDT_good', './tb_metrics/2017-10-09 17-43-49 PDT')
# diff = DiffParams('./tb_metrics/2017-09-26 22-40-18 PDT', './tb_metrics/2017-10-09 16-01-07 PDT_good')
diff = DiffParams('./tb_metrics_dev/2017-11-07 23-39-38 PST test_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_regroupImage_0pLambda', './tb_metrics_dev/2017-11-15 13-40-54 PST test_3.1LSTM_2init_3OutMLP_3attMLPfull_1beta_regroupImage_0pLambda')
diff.hyper()
# Out:
#   0                                           1
# 0                       StartTokenID ===> 556                                           StartTokenID ===> 1
# 1        CALSTM_STACK_1.StartTokenID ===> 556                            CALSTM_STACK_1.StartTokenID ===> 1
# 2                 raw_data_dir ===> undefined                 raw_data_dir ===> ../data/generated2/training
# 3  CALSTM_STACK_1.raw_data_dir ===> undefined  CALSTM_STACK_1.raw_data_dir ===> ../data/generated2/training
#    0                                                                                                                              1
# 0                                                            CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7feba587fd50>                                                           CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7feba587f650>
# 1                                             init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7feba58fc9b0>                                            init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7feba580ede8>
# 2              init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7febf56398d0>             init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7feba587f310>
# 3                           CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7feba580ee60>                          CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7feba580eed8>
# 4                          CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7febf56398d0>                         CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7feba587f310>
# 5                                                init_model_final_layers.weights_regularizer ===> <function l2 at 0x7feba58fc9b0>                                               init_model_final_layers.weights_regularizer ===> <function l2 at 0x7feba580ede8>
# 6                                   init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7feba580ee60>                                  init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7feba580eed8>
# 7                                                                     embeddings_regularizer ===> <function l2 at 0x7feba58fc9b0>                                                                    embeddings_regularizer ===> <function l2 at 0x7feba580ede8>
# 8                           CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7feba580ee60>                          CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7feba580eed8>
# 9                                         biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7febf56398d0>                                        biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7feba587f310>
# 10                                    CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7feba58fc9b0>                                    CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7feba580ede8>
# 11                                                          embeddings_initializer ===> <function _initializer at 0x7feba580ee60>                                                          embeddings_initializer ===> <function _initializer at 0x7feba580eed8>
# 12                                                output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7feba58fc9b0>                                                output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7feba580ede8>
# 13     CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7febf56398d0>     CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7feba587f310>
# 14                          CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7feba580ee60>                          CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7feba580eed8>
# 15     CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7febf56398d0>     CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7feba587f310>
# 16                                    CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7feba58fc9b0>                                    CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7feba580ede8>
# 17                                                                          logger ===> <logging.Logger object at 0x7feba587fd50>                                                                          logger ===> <logging.Logger object at 0x7feba587f650>
# 18                                    CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7feba58fc9b0>                                    CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7feba580ede8>
# 19                                        optimizer ===> <tensorflow.python.training.adam.AdamOptimizer object at 0x7feba587f350>                                                                                                            optimizer ===> adam
# 20                                                output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7feba58fc9b0>                                                output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7feba580ede8>
# 21                                      output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7feba580ee60>                                      output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7feba580eed8>
# 22                                     init_model_final_layers.weights_initializer ===> <function _initializer at 0x7feba580ee60>                                     init_model_final_layers.weights_initializer ===> <function _initializer at 0x7feba580eed8>
# 23                                                        CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7feba58fc9b0>                                                        CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7feba580ede8>
# 24  CALSTM_STACK_1.att_modulator.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7febf56398d0>  CALSTM_STACK_1.att_modulator.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7feba587f310>
# 25     CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7febf56398d0>     CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7feba587f310>
# 26                                           CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7feba58fc9b0>                                           CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7feba580ede8>
# 27                 output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7febf56398d0>                 output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7feba587f310>
# 28                                              CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7feba580ee60>                                              CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7feba580eed8>
# 29                                                output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7feba58fc9b0>                                                output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7feba580ede8>
# 30                                      output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7feba580ee60>                                      output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7feba580eed8>
# 31                init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7febf56398d0>                init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7feba587f310>
# 32                                 CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7feba580ee60>                                 CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7feba580eed8>
# 33                 output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7febf56398d0>                 output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7feba587f310>
# 34                                      output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7feba580ee60>                                      output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7feba580eed8>
# 35                                                                       weights_regularizer ===> <function l2 at 0x7feba58fc9b0>                                                                       weights_regularizer ===> <function l2 at 0x7feba580ede8>
# 36                       CALSTM_STACK_1.att_modulator.layers_1.weights_initializer ===> <function _initializer at 0x7feba580ee60>                       CALSTM_STACK_1.att_modulator.layers_1.weights_initializer ===> <function _initializer at 0x7feba580eed8>
# 37                 output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7febf56398d0>                 output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7feba587f310>
# 38                                                             weights_initializer ===> <function _initializer at 0x7feba580ee60>                                                             weights_initializer ===> <function _initializer at 0x7feba580eed8>
# 39                                 CALSTM_STACK_1.att_modulator.layers_1.weights_regularizer ===> <function l2 at 0x7feba58fc9b0>                                 CALSTM_STACK_1.att_modulator.layers_1.weights_regularizer ===> <function l2 at 0x7feba580ede8>
