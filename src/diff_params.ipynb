# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import pandas as pd
import os
import re
import codecs
from IPython.display import display
from six.moves import cPickle as pickle
import string
from PIL import Image
import numpy as np
import h5py

# %%
width = None
pd.options.display.max_rows = 600
pd.options.display.max_columns = width
pd.options.display.max_colwidth = 600
pd.options.display.width = width
pd.options.display.max_seq_items = None
pd.options.display.expand_frame_repr = False
pd.options.display.colheader_justify = 'left'

# %%
import data_commons as dtc
import dl_commons as dlc
import viz_commons as vc
from viz_commons import VisualizeDir, DiffParams, VisualizeStep
# Out:
# Using TensorFlow backend.

# %%
diff = DiffParams('/zpool_3TB/i2l/tb_metrics/2017-12-11 22-57-42 PST score_86.54_noInitModel/store', '/zpool_3TB/i2l/tb_metrics/2017-12-12 19-49-24 PST score_88.10/store')
one, two = diff.get_hyper()
head, tail = diff.hyper(show=True)
# head[~head[0].str.contains('CONVNET')]
# Out:
# Loaded /zpool_3TB/i2l/tb_metrics/2017-12-11 22-57-42 PST score_86.54_noInitModel/store
# Loaded /zpool_3TB/i2l/tb_metrics/2017-12-12 19-49-24 PST score_88.10/store
# Loaded /zpool_3TB/i2l/tb_metrics/2017-12-11 22-57-42 PST score_86.54_noInitModel/store
# Loaded /zpool_3TB/i2l/tb_metrics/2017-12-12 19-49-24 PST score_88.10/store
#   0                                                          1
# 0                  output_layers.layers_3.num_units ===> 358           output_layers.layers_3.num_units ===> undefined
# 1            output_layers.layers_3.tb.tb_biases ===> Biases        output_layers.layers_3.tb.tb_biases ===> undefined
# 2  output_layers.layers_3.tb.tb_activations ===> Activations   output_layers.layers_3.tb.tb_activations ===> undefined
# 3          output_layers.layers_3.tb.tb_weights ===> Weights       output_layers.layers_3.tb.tb_weights ===> undefined
# 4             output_layers.layers_3.activation_fn ===> None       output_layers.layers_3.activation_fn ===> undefined
# 5                   output_layers.layers_3.dropout ===> None             output_layers.layers_3.dropout ===> undefined
# 6        output_layers.layers_3.biases_regularizer ===> None  output_layers.layers_3.biases_regularizer ===> undefined
#    0                                                                                                                           1
# 0                                                         CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f291f309a50>                                                        CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f291f325ed0>
# 1                     CONVNET.layers_7.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f291f312f90>                    CONVNET.layers_7.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f296ec955d0>
# 2                                          CONVNET.layers_7.weights_initializer ===> <function _initializer at 0x7f291f359cf8>                                         CONVNET.layers_7.weights_initializer ===> <function _initializer at 0x7f291f2da1b8>
# 3                                          CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7f291f359cf8>                                         CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7f291f2da1b8>
# 4                                                      CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7f291f3b8b90>                                                     CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7f291f339b90>
# 5                                          CONVNET.layers_9.weights_initializer ===> <function _initializer at 0x7f291f359cf8>                                         CONVNET.layers_9.weights_initializer ===> <function _initializer at 0x7f291f2da1b8>
# 6                       CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f291f312f90>                      CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f296ec955d0>
# 7                                    output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f291f359cf8>                                   output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f291f2da1b8>
# 8                                init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7f291f359cf8>                               init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7f291f2da1b8>
# 9                                                                  embeddings_regularizer ===> <function l2 at 0x7f291f3b8b90>                                                                 embeddings_regularizer ===> <function l2 at 0x7f291f339b90>
# 10                       CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f291f359cf8>                       CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f291f2da1b8>
# 11                                     biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f291f312f90>                                     biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f296ec955d0>
# 12          init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f291f312f90>          init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f296ec955d0>
# 13                                 CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f291f3b8b90>                                 CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f291f339b90>
# 14                                         CONVNET.layers_5.weights_initializer ===> <function _initializer at 0x7f291f359cf8>                                         CONVNET.layers_5.weights_initializer ===> <function _initializer at 0x7f291f2da1b8>
# 15                                             output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f291f3b8b90>                                             output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f291f339b90>
# 16                                        CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7f291f3b8b90>                                        CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7f291f339b90>
# 17  CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f291f312f90>  CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f296ec955d0>
# 18                                                   CONVNET.layers_5.weights_regularizer ===> <function l2 at 0x7f291f3b8b90>                                                   CONVNET.layers_5.weights_regularizer ===> <function l2 at 0x7f291f339b90>
# 19                                                                       output_layers.layers_3.tb.tb_logdir ===> ./tb_metrics                                                                          output_layers.layers_3.tb.tb_logdir ===> undefined
# 20                       CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f291f359cf8>                       CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f291f2da1b8>
# 21                    CONVNET.layers_9.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f291f312f90>                    CONVNET.layers_9.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f296ec955d0>
# 22                    CONVNET.layers_5.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f291f312f90>                    CONVNET.layers_5.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f296ec955d0>
# 23                                                                              output_layers.layers_3.tb.logdir_tag ===> None                                                                         output_layers.layers_3.tb.logdir_tag ===> undefined
# 24                                  init_model_final_layers.weights_initializer ===> <function _initializer at 0x7f291f359cf8>                                  init_model_final_layers.weights_initializer ===> <function _initializer at 0x7f291f2da1b8>
# 25                                 CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f291f3b8b90>                                 CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f291f339b90>
# 26                                                                       logger ===> <logging.Logger object at 0x7f291f309a50>                                                                       logger ===> <logging.Logger object at 0x7f291f325ed0>
# 27                                 CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f291f3b8b90>                                 CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f291f339b90>
# 28                                             output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f291f3b8b90>                                             output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f291f339b90>
# 29                                                       embeddings_initializer ===> <function _initializer at 0x7f291f359cf8>                                                       embeddings_initializer ===> <function _initializer at 0x7f291f2da1b8>
# 30                                   output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f291f359cf8>                                                                   output_layers.layers_3.weights_initializer ===> undefined
# 31  CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f291f312f90>  CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f296ec955d0>
# 32                    CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f291f312f90>                    CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f296ec955d0>
# 33                                   output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f291f359cf8>                                   output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f291f2da1b8>
# 34  CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f291f312f90>  CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f296ec955d0>
# 35                                                   CONVNET.layers_9.weights_regularizer ===> <function l2 at 0x7f291f3b8b90>                                                   CONVNET.layers_9.weights_regularizer ===> <function l2 at 0x7f291f339b90>
# 36              output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f291f312f90>              output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f296ec955d0>
# 37                                           CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7f291f359cf8>                                           CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7f291f2da1b8>
# 38                                         CONVNET.layers_3.weights_initializer ===> <function _initializer at 0x7f291f359cf8>                                         CONVNET.layers_3.weights_initializer ===> <function _initializer at 0x7f291f2da1b8>
# 39                                                   CONVNET.layers_7.weights_regularizer ===> <function l2 at 0x7f291f3b8b90>                                                   CONVNET.layers_7.weights_regularizer ===> <function l2 at 0x7f291f339b90>
# 40                                                   CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7f291f3b8b90>                                                   CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7f291f339b90>
# 41                                             output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f291f3b8b90>                                                                   output_layers.layers_3.weights_regularizer ===> undefined
# 42                    CONVNET.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f291f312f90>                    CONVNET.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f296ec955d0>
# 43                                            init_model_final_layers.weights_regularizer ===> <function l2 at 0x7f291f3b8b90>                                            init_model_final_layers.weights_regularizer ===> <function l2 at 0x7f291f339b90>
# 44             init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f291f312f90>             init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f296ec955d0>
# 45                              CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7f291f359cf8>                              CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7f291f2da1b8>
# 46              output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f291f312f90>                                                                    output_layers.layers_3.biases_initializer ===> undefined
# 47                       CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f291f359cf8>                       CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f291f2da1b8>
# 48                                                                    weights_regularizer ===> <function l2 at 0x7f291f3b8b90>                                                                    weights_regularizer ===> <function l2 at 0x7f291f339b90>
# 49              output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f291f312f90>              output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f296ec955d0>
# 50                                                          weights_initializer ===> <function _initializer at 0x7f291f359cf8>                                                          weights_initializer ===> <function _initializer at 0x7f291f2da1b8>
# 51                                                 output_layers.layers_2.activation_fn ===> <function tanh at 0x7f2927f6de60>                                                                              output_layers.layers_2.activation_fn ===> None
# 52                                                   CONVNET.layers_3.weights_regularizer ===> <function l2 at 0x7f291f3b8b90>                                                   CONVNET.layers_3.weights_regularizer ===> <function l2 at 0x7f291f339b90>
# 53                                         init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7f291f3b8b90>                                         init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7f291f339b90>

# %%
# (one['build_init_model'])
len(two['output_layers']['layers'])
# Out:
# 2

# %%
one['build_init_model']
# Out:
# False

# %%
params = ['2017-12-06 15-40-46 PST score_86.14',
          '2017-12-07 23-23-25 PST score_87.45', 
          '2017-12-10 12-52-23 PST score_88.17',
          '2017-12-11 11-22-31 PST',
          '2017-12-11 22-57-42 PST score_86.54',
          '2017-12-12 19-49-24 PST score_88.10',
          '2017-12-16 18-51-38 PST pLambda=0_score_88.86',
          '2017-12-21 02-20-10 PST 140K_data_score_89.0'
         ]

for p in params:
    vd = VisualizeDir('/zpool_3TB/i2l/tb_metrics/' + p + '/store')
    if 'build_init_model' in vd.hyper:
        b = vd.hyper['build_init_model']
    else:
        b = True
    print('%s:\t%s'%(b, p))
