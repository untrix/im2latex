# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import pandas as pd
import os
import re
import codecs
from IPython.display import display
from six.moves import cPickle as pickle
import string
from PIL import Image
import numpy as np
import h5py

# %%
width = None
pd.options.display.max_rows = 600
pd.options.display.max_columns = width
pd.options.display.max_colwidth = 600
pd.options.display.width = width
pd.options.display.max_seq_items = None
pd.options.display.expand_frame_repr = False
pd.options.display.colheader_justify = 'left'

# %%
import data_commons as dtc
import dl_commons as dlc
import viz_commons as vc
from viz_commons import VisualizeDir, DiffParams, VisualizeStep

# %%
diff = DiffParams('/zpool_3TB/i2l/tb_metrics/2017-12-07 23-23-25 PST score_87.45', './tb_metrics/2017-12-10 12-52-23 PST')
one, two = diff.get_hyper()
head, tail = diff.hyper(show=True)
# head[~head[0].str.contains('CONVNET')]
# Out:
#   0                                                                 1
# 0                                        CALSTM_STACK_1.n ===> 1000                                  CALSTM_STACK_1.n ===> 1500
# 1                                         adam_beta1 ===> undefined                                         adam_beta1 ===> 0.5
# 2                                         adam_beta2 ===> undefined                                         adam_beta2 ===> 0.9
# 3                                                       n ===> 1000                                                 n ===> 1500
# 4                                 tf_session_allow_growth ===> True                          tf_session_allow_growth ===> False
# 5  CALSTM_STACK_1.decoder_lstm.layers_units ===> [1000, 1000, 1000]  CALSTM_STACK_1.decoder_lstm.layers_units ===> [1500, 1500]
#    0                                                                                                                           1
# 0           init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99fd0>          init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced750>
# 1   CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99fd0>  CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced750>
# 2                                          CONVNET.layers_7.weights_initializer ===> <function _initializer at 0x7f5d61cc9050>                                         CONVNET.layers_7.weights_initializer ===> <function _initializer at 0x7f5d61cc9de8>
# 3                                                      CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7f5d61cc9cf8>                                                     CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7f5d61ce0320>
# 4                                          CONVNET.layers_3.weights_initializer ===> <function _initializer at 0x7f5d61cc9050>                                         CONVNET.layers_3.weights_initializer ===> <function _initializer at 0x7f5d61cc9de8>
# 5                                              output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f5d61cc9cf8>                                             output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f5d61ce0320>
# 6                                             init_model_final_layers.weights_regularizer ===> <function l2 at 0x7f5d61cc9cf8>                                            init_model_final_layers.weights_regularizer ===> <function l2 at 0x7f5d61ce0320>
# 7                                                         CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f5d61ced950>                                                        CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f5d61c53890>
# 8                                init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7f5d61cc9050>                               init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7f5d61cc9de8>
# 9                                          CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7f5d61cc9050>                                         CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7f5d61cc9de8>
# 10                       CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f5d61cc9050>                       CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f5d61cc9de8>
# 11                                     biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99fd0>                                     biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced750>
# 12                                 CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f5d61cc9cf8>                                 CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f5d61ce0320>
# 13                                                       embeddings_initializer ===> <function _initializer at 0x7f5d61cc9050>                                                       embeddings_initializer ===> <function _initializer at 0x7f5d61cc9de8>
# 14                                             output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f5d61cc9cf8>                                             output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f5d61ce0320>
# 15  CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99fd0>  CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced750>
# 16                                                   CONVNET.layers_5.weights_regularizer ===> <function l2 at 0x7f5d61cc9cf8>                                                   CONVNET.layers_5.weights_regularizer ===> <function l2 at 0x7f5d61ce0320>
# 17                                                                 embeddings_regularizer ===> <function l2 at 0x7f5d61cc9cf8>                                                                 embeddings_regularizer ===> <function l2 at 0x7f5d61ce0320>
# 18                                         CONVNET.layers_9.weights_initializer ===> <function _initializer at 0x7f5d61cc9050>                                         CONVNET.layers_9.weights_initializer ===> <function _initializer at 0x7f5d61cc9de8>
# 19                       CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f5d61cc9050>                       CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f5d61cc9de8>
# 20                    CONVNET.layers_9.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99fd0>                    CONVNET.layers_9.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced750>
# 21                    CONVNET.layers_5.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99fd0>                    CONVNET.layers_5.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced750>
# 22                                  init_model_final_layers.weights_initializer ===> <function _initializer at 0x7f5d61cc9050>                                  init_model_final_layers.weights_initializer ===> <function _initializer at 0x7f5d61cc9de8>
# 23                                                   CONVNET.layers_9.weights_regularizer ===> <function l2 at 0x7f5d61cc9cf8>                                                   CONVNET.layers_9.weights_regularizer ===> <function l2 at 0x7f5d61ce0320>
# 24                                                                       logger ===> <logging.Logger object at 0x7f5d61ced950>                                                                       logger ===> <logging.Logger object at 0x7f5d61c53890>
# 25                                                          weights_initializer ===> <function _initializer at 0x7f5d61cc9050>                                                          weights_initializer ===> <function _initializer at 0x7f5d61cc9de8>
# 26                                 CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f5d61cc9cf8>                                 CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f5d61ce0320>
# 27                                             output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f5d61cc9cf8>                                             output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f5d61ce0320>
# 28                                         CONVNET.layers_5.weights_initializer ===> <function _initializer at 0x7f5d61cc9050>                                         CONVNET.layers_5.weights_initializer ===> <function _initializer at 0x7f5d61cc9de8>
# 29                                   output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f5d61cc9050>                                   output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f5d61cc9de8>
# 30  CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99fd0>  CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced750>
# 31                    CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99fd0>                    CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced750>
# 32                                   output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f5d61cc9050>                                   output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f5d61cc9de8>
# 33                    CONVNET.layers_7.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99fd0>                    CONVNET.layers_7.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced750>
# 34                                 CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f5d61cc9cf8>                                 CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f5d61ce0320>
# 35              output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99fd0>              output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced750>
# 36                                           CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7f5d61cc9050>                                           CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7f5d61cc9de8>
# 37                                                   CONVNET.layers_7.weights_regularizer ===> <function l2 at 0x7f5d61cc9cf8>                                                   CONVNET.layers_7.weights_regularizer ===> <function l2 at 0x7f5d61ce0320>
# 38                                                   CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7f5d61cc9cf8>                                                   CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7f5d61ce0320>
# 39                    CONVNET.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99fd0>                    CONVNET.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced750>
# 40                                   output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f5d61cc9050>                                   output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f5d61cc9de8>
# 41             init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99fd0>             init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced750>
# 42                              CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7f5d61cc9050>                              CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7f5d61cc9de8>
# 43              output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99fd0>              output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced750>
# 44                       CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f5d61cc9050>                       CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f5d61cc9de8>
# 45                      CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99fd0>                      CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced750>
# 46                                                                    weights_regularizer ===> <function l2 at 0x7f5d61cc9cf8>                                                                    weights_regularizer ===> <function l2 at 0x7f5d61ce0320>
# 47              output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99fd0>              output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced750>
# 48                                        CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7f5d61cc9cf8>                                        CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7f5d61ce0320>
# 49                                                   CONVNET.layers_3.weights_regularizer ===> <function l2 at 0x7f5d61cc9cf8>                                                   CONVNET.layers_3.weights_regularizer ===> <function l2 at 0x7f5d61ce0320>
# 50                                         init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7f5d61cc9cf8>                                         init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7f5d61ce0320>

# %%
(two['output_layers']['layers'])
# Out:
# [{'activation_fn': <function tensorflow.python.ops.gen_nn_ops.relu>,
#   'biases_initializer': <tensorflow.python.ops.init_ops.Zeros at 0x7f5d61db8a90>,
#   'biases_regularizer': None,
#   'dropout': None,
#   'num_units': 358,
#   'tb': {'logdir_tag': None,
#    'tb_activations': 'Activations',
#    'tb_biases': 'Biases',
#    'tb_logdir': './tb_metrics',
#    'tb_weights': 'Weights'},
#   'weights_initializer': <function tensorflow.contrib.layers.python.layers.initializers._initializer>,
#   'weights_regularizer': <function tensorflow.contrib.layers.python.layers.regularizers.l2>},
#  {'activation_fn': <function tensorflow.python.ops.gen_nn_ops.relu>,
#   'biases_initializer': <tensorflow.python.ops.init_ops.Zeros at 0x7f5d61db8a90>,
#   'biases_regularizer': None,
#   'dropout': None,
#   'num_units': 358,
#   'tb': {'logdir_tag': None,
#    'tb_activations': 'Activations',
#    'tb_biases': 'Biases',
#    'tb_logdir': './tb_metrics',
#    'tb_weights': 'Weights'},
#   'weights_initializer': <function tensorflow.contrib.layers.python.layers.initializers._initializer>,
#   'weights_regularizer': <function tensorflow.contrib.layers.python.layers.regularizers.l2>},
#  {'activation_fn': None,
#   'biases_initializer': <tensorflow.python.ops.init_ops.Zeros at 0x7f5d61db8a90>,
#   'biases_regularizer': None,
#   'dropout': None,
#   'num_units': 358,
#   'tb': {'logdir_tag': None,
#    'tb_activations': 'Activations',
#    'tb_biases': 'Biases',
#    'tb_logdir': './tb_metrics',
#    'tb_weights': 'Weights'},
#   'weights_initializer': <function tensorflow.contrib.layers.python.layers.initializers._initializer>,
#   'weights_regularizer': <function tensorflow.contrib.layers.python.layers.regularizers.l2>}]
