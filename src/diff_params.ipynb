# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import pandas as pd
import os
import re
import codecs
from IPython.display import display
from six.moves import cPickle as pickle
import string
from PIL import Image
import numpy as np
import h5py

# %%
width = None
pd.options.display.max_rows = 600
pd.options.display.max_columns = width
pd.options.display.max_colwidth = 600
pd.options.display.width = width
pd.options.display.max_seq_items = None
pd.options.display.expand_frame_repr = False
pd.options.display.colheader_justify = 'left'

# %%
import data_commons as dtc
import dl_commons as dlc
import viz_commons as vc
from viz_commons import VisualizeDir, DiffParams, VisualizeStep
# Out:
# Using TensorFlow backend.

# %%
diff = DiffParams('/zpool_3TB/i2l/tb_metrics/2017-12-10 12-52-23 PST score_87.46', './tb_metrics/2017-12-12 19-49-24 PST')
one, two = diff.get_hyper()
head, tail = diff.hyper(show=True)
# head[~head[0].str.contains('CONVNET')]
# Out:
#   0                                                          1
# 0                                 build_init_model ===> True                               build_init_model ===> False
# 1                  output_layers.layers_3.num_units ===> 358           output_layers.layers_3.num_units ===> undefined
# 2            output_layers.layers_3.tb.tb_biases ===> Biases        output_layers.layers_3.tb.tb_biases ===> undefined
# 3  output_layers.layers_3.tb.tb_activations ===> Activations   output_layers.layers_3.tb.tb_activations ===> undefined
# 4          output_layers.layers_3.tb.tb_weights ===> Weights       output_layers.layers_3.tb.tb_weights ===> undefined
# 5             output_layers.layers_3.activation_fn ===> None       output_layers.layers_3.activation_fn ===> undefined
# 6                   output_layers.layers_3.dropout ===> None             output_layers.layers_3.dropout ===> undefined
# 7        output_layers.layers_3.biases_regularizer ===> None  output_layers.layers_3.biases_regularizer ===> undefined
#    0                                                                                                                           1
# 0                        CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7fa091643488>                       CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7fa091643500>
# 1                                                         CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7fa09164bc10>                                                        CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7fa091661110>
# 2   CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa0916b9f10>  CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa09164be90>
# 3                                          CONVNET.layers_7.weights_initializer ===> <function _initializer at 0x7fa091643488>                                         CONVNET.layers_7.weights_initializer ===> <function _initializer at 0x7fa091643500>
# 4                                                      CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7fa091643410>                                                     CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7fa091643398>
# 5                                          CONVNET.layers_9.weights_initializer ===> <function _initializer at 0x7fa091643488>                                         CONVNET.layers_9.weights_initializer ===> <function _initializer at 0x7fa091643500>
# 6                                              output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7fa091643410>                                                                   output_layers.layers_3.weights_regularizer ===> undefined
# 7                                    output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7fa091643488>                                   output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7fa091643500>
# 8                                init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7fa091643488>                               init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7fa091643500>
# 9                                          CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7fa091643488>                                         CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7fa091643500>
# 10                                         init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7fa091643410>                                         init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7fa091643398>
# 11                                     biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa0916b9f10>                                     biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa09164be90>
# 12          init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa0916b9f10>          init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa09164be90>
# 13                                 CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7fa091643410>                                 CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7fa091643398>
# 14                                                       embeddings_initializer ===> <function _initializer at 0x7fa091643488>                                                       embeddings_initializer ===> <function _initializer at 0x7fa091643500>
# 15                                             output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7fa091643410>                                             output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7fa091643398>
# 16                                        CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7fa091643410>                                        CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7fa091643398>
# 17  CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa0916b9f10>  CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa09164be90>
# 18                                                   CONVNET.layers_5.weights_regularizer ===> <function l2 at 0x7fa091643410>                                                   CONVNET.layers_5.weights_regularizer ===> <function l2 at 0x7fa091643398>
# 19                                                                       output_layers.layers_3.tb.tb_logdir ===> ./tb_metrics                                                                          output_layers.layers_3.tb.tb_logdir ===> undefined
# 20                       CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7fa091643488>                       CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7fa091643500>
# 21                    CONVNET.layers_9.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa0916b9f10>                    CONVNET.layers_9.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa09164be90>
# 22                    CONVNET.layers_5.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa0916b9f10>                    CONVNET.layers_5.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa09164be90>
# 23                                                                              output_layers.layers_3.tb.logdir_tag ===> None                                                                         output_layers.layers_3.tb.logdir_tag ===> undefined
# 24                                  init_model_final_layers.weights_initializer ===> <function _initializer at 0x7fa091643488>                                  init_model_final_layers.weights_initializer ===> <function _initializer at 0x7fa091643500>
# 25                                 CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7fa091643410>                                 CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7fa091643398>
# 26                                                                       logger ===> <logging.Logger object at 0x7fa09164bc10>                                                                       logger ===> <logging.Logger object at 0x7fa091661110>
# 27                                 CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7fa091643410>                                 CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7fa091643398>
# 28                                             output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7fa091643410>                                             output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7fa091643398>
# 29                                         CONVNET.layers_5.weights_initializer ===> <function _initializer at 0x7fa091643488>                                         CONVNET.layers_5.weights_initializer ===> <function _initializer at 0x7fa091643500>
# 30                                   output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7fa091643488>                                                                   output_layers.layers_3.weights_initializer ===> undefined
# 31  CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa0916b9f10>  CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa09164be90>
# 32                    CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa0916b9f10>                    CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa09164be90>
# 33                                   output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7fa091643488>                                   output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7fa091643500>
# 34                    CONVNET.layers_7.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa0916b9f10>                    CONVNET.layers_7.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa09164be90>
# 35                                                   CONVNET.layers_9.weights_regularizer ===> <function l2 at 0x7fa091643410>                                                   CONVNET.layers_9.weights_regularizer ===> <function l2 at 0x7fa091643398>
# 36              output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa0916b9f10>              output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa09164be90>
# 37                                           CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7fa091643488>                                           CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7fa091643500>
# 38                                         CONVNET.layers_3.weights_initializer ===> <function _initializer at 0x7fa091643488>                                         CONVNET.layers_3.weights_initializer ===> <function _initializer at 0x7fa091643500>
# 39                                                   CONVNET.layers_7.weights_regularizer ===> <function l2 at 0x7fa091643410>                                                   CONVNET.layers_7.weights_regularizer ===> <function l2 at 0x7fa091643398>
# 40                                                   CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7fa091643410>                                                   CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7fa091643398>
# 41                    CONVNET.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa0916b9f10>                    CONVNET.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa09164be90>
# 42                                            init_model_final_layers.weights_regularizer ===> <function l2 at 0x7fa091643410>                                            init_model_final_layers.weights_regularizer ===> <function l2 at 0x7fa091643398>
# 43             init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa0916b9f10>             init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa09164be90>
# 44                              CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7fa091643488>                              CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7fa091643500>
# 45              output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa0916b9f10>                                                                    output_layers.layers_3.biases_initializer ===> undefined
# 46                       CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7fa091643488>                       CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7fa091643500>
# 47                      CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa0916b9f10>                      CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa09164be90>
# 48                                                                    weights_regularizer ===> <function l2 at 0x7fa091643410>                                                                    weights_regularizer ===> <function l2 at 0x7fa091643398>
# 49              output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa0916b9f10>              output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7fa09164be90>
# 50                                                          weights_initializer ===> <function _initializer at 0x7fa091643488>                                                          weights_initializer ===> <function _initializer at 0x7fa091643500>
# 51                                                 output_layers.layers_2.activation_fn ===> <function tanh at 0x7fa09a227500>                                                                              output_layers.layers_2.activation_fn ===> None
# 52                                                   CONVNET.layers_3.weights_regularizer ===> <function l2 at 0x7fa091643410>                                                   CONVNET.layers_3.weights_regularizer ===> <function l2 at 0x7fa091643398>
# 53                                                                 embeddings_regularizer ===> <function l2 at 0x7fa091643410>                                                                 embeddings_regularizer ===> <function l2 at 0x7fa091643398>

# %%
(two['output_layers']['layers'])
# Out:
# [{'activation_fn': <function tensorflow.python.ops.gen_nn_ops.relu>,
#   'biases_initializer': <tensorflow.python.ops.init_ops.Zeros at 0x7f5d61db8a90>,
#   'biases_regularizer': None,
#   'dropout': None,
#   'num_units': 358,
#   'tb': {'logdir_tag': None,
#    'tb_activations': 'Activations',
#    'tb_biases': 'Biases',
#    'tb_logdir': './tb_metrics',
#    'tb_weights': 'Weights'},
#   'weights_initializer': <function tensorflow.contrib.layers.python.layers.initializers._initializer>,
#   'weights_regularizer': <function tensorflow.contrib.layers.python.layers.regularizers.l2>},
#  {'activation_fn': <function tensorflow.python.ops.gen_nn_ops.relu>,
#   'biases_initializer': <tensorflow.python.ops.init_ops.Zeros at 0x7f5d61db8a90>,
#   'biases_regularizer': None,
#   'dropout': None,
#   'num_units': 358,
#   'tb': {'logdir_tag': None,
#    'tb_activations': 'Activations',
#    'tb_biases': 'Biases',
#    'tb_logdir': './tb_metrics',
#    'tb_weights': 'Weights'},
#   'weights_initializer': <function tensorflow.contrib.layers.python.layers.initializers._initializer>,
#   'weights_regularizer': <function tensorflow.contrib.layers.python.layers.regularizers.l2>},
#  {'activation_fn': None,
#   'biases_initializer': <tensorflow.python.ops.init_ops.Zeros at 0x7f5d61db8a90>,
#   'biases_regularizer': None,
#   'dropout': None,
#   'num_units': 358,
#   'tb': {'logdir_tag': None,
#    'tb_activations': 'Activations',
#    'tb_biases': 'Biases',
#    'tb_logdir': './tb_metrics',
#    'tb_weights': 'Weights'},
#   'weights_initializer': <function tensorflow.contrib.layers.python.layers.initializers._initializer>,
#   'weights_regularizer': <function tensorflow.contrib.layers.python.layers.regularizers.l2>}]
