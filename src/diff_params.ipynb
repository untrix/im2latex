# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import pandas as pd
import os
import re
import codecs
from IPython.display import display
from six.moves import cPickle as pickle
import string
from PIL import Image
import numpy as np
import h5py

# %%
width = None
pd.options.display.max_rows = 600
pd.options.display.max_columns = width
pd.options.display.max_colwidth = 600
pd.options.display.width = width
pd.options.display.max_seq_items = None
pd.options.display.expand_frame_repr = False
pd.options.display.colheader_justify = 'left'

# %%
import data_commons as dtc
import dl_commons as dlc
import viz_commons as viz
from viz_commons import VisualizeDir, DiffParams, VisualizeStep
# Out:
# Using TensorFlow backend.

# %%
diff = viz.DiffParams('/zpool_3TB/i2l/tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.86/store', '/zpool_3TB/i2l/tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.86/test_runs/step_00132200')
one, two = diff.get_hyper()
head, tail = diff.hyper(show=True)
# head[~head[0].str.contains('CONVNET')]
# Out:
# Loaded /zpool_3TB/i2l/tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.86/store/hyper.pkl
# Loaded /zpool_3TB/i2l/tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.86/test_runs/step_00132200/store/hyper.pkl
# Loaded /zpool_3TB/i2l/tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.86/store/hyper.pkl
# Loaded /zpool_3TB/i2l/tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.86/test_runs/step_00132200/store/hyper.pkl
#   /zpool_3TB/i2l/tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.86/store/hyper.pkl /zpool_3TB/i2l/tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.86/test_runs/step_00132200/store/hyper.pkl
# 0                            dataset ===> 3                                                               dataset ===> undefined
# 1             assert_whole_batch ===> False                                                         assert_whole_batch ===> True
# 2                 image_size ===> undefined                                                                  image_size ===> big
# 3  CALSTM_STACK_1.image_size ===> undefined                                                   CALSTM_STACK_1.image_size ===> big
# 4             CALSTM_STACK_1.dataset ===> 3                                                CALSTM_STACK_1.dataset ===> undefined
#    /zpool_3TB/i2l/tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.86/store/hyper.pkl                                     /zpool_3TB/i2l/tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.86/test_runs/step_00132200/store/hyper.pkl
# 0           init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbe18d90>                                    init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbd9d990>
# 1   CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbe18d90>                            CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbd9d990>
# 2                                          CONVNET.layers_7.weights_initializer ===> <function _initializer at 0x7f3cfbd066e0>                                                                   CONVNET.layers_7.weights_initializer ===> <function _initializer at 0x7f3cfbcedc08>
# 3                                          CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7f3cfbd066e0>                                                                   CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7f3cfbcedc08>
# 4                     CONVNET.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbe18d90>                                              CONVNET.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbd9d990>
# 5                                          CONVNET.layers_9.weights_initializer ===> <function _initializer at 0x7f3cfbd066e0>                                                                   CONVNET.layers_9.weights_initializer ===> <function _initializer at 0x7f3cfbcedc08>
# 6                       CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbe18d90>                                                CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbd9d990>
# 7              CALSTM_STACK_1.att_layers.layers_3.tb.tb_logdir ===> ./tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.47  CALSTM_STACK_1.att_layers.layers_3.tb.tb_logdir ===> /zpool_3TB/i2l/tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.86/test_runs/step_00132200
# 8                                                         CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f3cfbd9dad0>                                                                                  CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f3cfbd9db10>
# 9                                init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7f3cfbd066e0>                                                         init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7f3cfbcedc08>
# 10                                                                 embeddings_regularizer ===> <function l2 at 0x7f3cfbd06500>                                                                                           embeddings_regularizer ===> <function l2 at 0x7f3cfbcedc80>
# 11                       CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f3cfbd066e0>                                                 CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f3cfbcedc08>
# 12                                     biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbe18d90>                                                               biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbd9d990>
# 13                      CALSTM_STACK_1.att_layers.tb.tb_logdir ===> ./tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.47           CALSTM_STACK_1.att_layers.tb.tb_logdir ===> /zpool_3TB/i2l/tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.86/test_runs/step_00132200
# 14                                 CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f3cfbd06500>                                                           CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f3cfbcedc80>
# 15                                         CONVNET.layers_5.weights_initializer ===> <function _initializer at 0x7f3cfbd066e0>                                                                   CONVNET.layers_5.weights_initializer ===> <function _initializer at 0x7f3cfbcedc08>
# 16                                             output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f3cfbd06500>                                                                       output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f3cfbcedc80>
# 17                     init_model_hidden.layers_1.tb.tb_logdir ===> ./tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.47          init_model_hidden.layers_1.tb.tb_logdir ===> /zpool_3TB/i2l/tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.86/test_runs/step_00132200
# 18                                                   CONVNET.layers_5.weights_regularizer ===> <function l2 at 0x7f3cfbd06500>                                                                             CONVNET.layers_5.weights_regularizer ===> <function l2 at 0x7f3cfbcedc80>
# 19                        init_model_final_layers.tb.tb_logdir ===> ./tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.47             init_model_final_layers.tb.tb_logdir ===> /zpool_3TB/i2l/tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.86/test_runs/step_00132200
# 20                         output_layers.layers_3.tb.tb_logdir ===> ./tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.47              output_layers.layers_3.tb.tb_logdir ===> /zpool_3TB/i2l/tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.86/test_runs/step_00132200
# 21                       CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f3cfbd066e0>                                                 CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f3cfbcedc08>
# 22                                   output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f3cfbd066e0>                                                             output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f3cfbcedc08>
# 23                    CONVNET.layers_5.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbe18d90>                                              CONVNET.layers_5.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbd9d990>
# 24                                  init_model_final_layers.weights_initializer ===> <function _initializer at 0x7f3cfbd066e0>                                                            init_model_final_layers.weights_initializer ===> <function _initializer at 0x7f3cfbcedc08>
# 25                                 CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f3cfbd06500>                                                           CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f3cfbcedc80>
# 26                                                                       logger ===> <logging.Logger object at 0x7f3cfbd9dad0>                                                                                                 logger ===> <logging.Logger object at 0x7f3cfbd9db10>
# 27                                                          weights_initializer ===> <function _initializer at 0x7f3cfbd066e0>                                                                                    weights_initializer ===> <function _initializer at 0x7f3cfbcedc08>
# 28                              init_model_hidden.tb.tb_logdir ===> ./tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.47                   init_model_hidden.tb.tb_logdir ===> /zpool_3TB/i2l/tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.86/test_runs/step_00132200
# 29                                 CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f3cfbd06500>                                                           CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f3cfbcedc80>
# 30                                             output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f3cfbd06500>                                                                       output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f3cfbcedc80>
# 31             CALSTM_STACK_1.att_layers.layers_1.tb.tb_logdir ===> ./tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.47  CALSTM_STACK_1.att_layers.layers_1.tb.tb_logdir ===> /zpool_3TB/i2l/tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.86/test_runs/step_00132200
# 32                                                       embeddings_initializer ===> <function _initializer at 0x7f3cfbd066e0>                                                                                 embeddings_initializer ===> <function _initializer at 0x7f3cfbcedc08>
# 33                    CONVNET.layers_9.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbe18d90>                                              CONVNET.layers_9.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbd9d990>
# 34  CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbe18d90>                            CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbd9d990>
# 35                                  output_layers.tb.tb_logdir ===> ./tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.47                       output_layers.tb.tb_logdir ===> /zpool_3TB/i2l/tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.86/test_runs/step_00132200
# 36                                                     CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7f3cfbd06500>                                                                               CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7f3cfbcedc80>
# 37                    CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbe18d90>                                              CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbd9d990>
# 38                                   output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f3cfbd066e0>                                                             output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f3cfbcedc08>
# 39                                 CALSTM_STACK_1.tb.tb_logdir ===> ./tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.47                      CALSTM_STACK_1.tb.tb_logdir ===> /zpool_3TB/i2l/tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.86/test_runs/step_00132200
# 40                                                   CONVNET.layers_9.weights_regularizer ===> <function l2 at 0x7f3cfbd06500>                                                                             CONVNET.layers_9.weights_regularizer ===> <function l2 at 0x7f3cfbcedc80>
# 41              output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbe18d90>                                        output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbd9d990>
# 42                                           CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7f3cfbd066e0>                                                                     CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7f3cfbcedc08>
# 43                    CALSTM_STACK_1.decoder_lstm.tb.tb_logdir ===> ./tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.47         CALSTM_STACK_1.decoder_lstm.tb.tb_logdir ===> /zpool_3TB/i2l/tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.86/test_runs/step_00132200
# 44                                         CONVNET.layers_3.weights_initializer ===> <function _initializer at 0x7f3cfbd066e0>                                                                   CONVNET.layers_3.weights_initializer ===> <function _initializer at 0x7f3cfbcedc08>
# 45                    CONVNET.layers_7.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbe18d90>                                              CONVNET.layers_7.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbd9d990>
# 46                                                tb.tb_logdir ===> ./tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.47                                     tb.tb_logdir ===> /zpool_3TB/i2l/tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.86/test_runs/step_00132200
# 47  CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbe18d90>                            CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbd9d990>
# 48                                                   CONVNET.layers_7.weights_regularizer ===> <function l2 at 0x7f3cfbd06500>                                                                             CONVNET.layers_7.weights_regularizer ===> <function l2 at 0x7f3cfbcedc80>
# 49                                                   CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7f3cfbd06500>                                                                             CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7f3cfbcedc80>
# 50                                             output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f3cfbd06500>                                                                       output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f3cfbcedc80>
# 51                         output_layers.layers_1.tb.tb_logdir ===> ./tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.47              output_layers.layers_1.tb.tb_logdir ===> /zpool_3TB/i2l/tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.86/test_runs/step_00132200
# 52                         output_layers.layers_2.tb.tb_logdir ===> ./tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.47              output_layers.layers_2.tb.tb_logdir ===> /zpool_3TB/i2l/tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.86/test_runs/step_00132200
# 53                                            init_model_final_layers.weights_regularizer ===> <function l2 at 0x7f3cfbd06500>                                                                      init_model_final_layers.weights_regularizer ===> <function l2 at 0x7f3cfbcedc80>
# 54             init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbe18d90>                                       init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbd9d990>
# 55                              CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7f3cfbd066e0>                                                        CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7f3cfbcedc08>
# 56              output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbe18d90>                                        output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbd9d990>
# 57                       CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f3cfbd066e0>                                                 CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f3cfbcedc08>
# 58                                        CONVNET.tb.tb_logdir ===> ./tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.47                             CONVNET.tb.tb_logdir ===> /zpool_3TB/i2l/tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.86/test_runs/step_00132200
# 59                                   output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f3cfbd066e0>                                                             output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f3cfbcedc08>
# 60                                                                    weights_regularizer ===> <function l2 at 0x7f3cfbd06500>                                                                                              weights_regularizer ===> <function l2 at 0x7f3cfbcedc80>
# 61              output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbe18d90>                                        output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f3cfbd9d990>
# 62                                        CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7f3cfbd06500>                                                                  CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7f3cfbcedc80>
# 63                                                   CONVNET.layers_3.weights_regularizer ===> <function l2 at 0x7f3cfbd06500>                                                                             CONVNET.layers_3.weights_regularizer ===> <function l2 at 0x7f3cfbcedc80>
# 64             CALSTM_STACK_1.att_layers.layers_2.tb.tb_logdir ===> ./tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.47  CALSTM_STACK_1.att_layers.layers_2.tb.tb_logdir ===> /zpool_3TB/i2l/tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.86/test_runs/step_00132200
# 65                                         init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7f3cfbd06500>                                                                   init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7f3cfbcedc80>

# %%
# (one['build_init_model'])
len(two['output_layers']['layers'])
# Out:
# 3

# %%
one['build_init_model']
# Out:
# True
