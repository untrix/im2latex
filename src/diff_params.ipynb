# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import pandas as pd
import os
import re
import codecs
from IPython.display import display
from six.moves import cPickle as pickle
import string
from PIL import Image
import numpy as np
import h5py

# %%
width = None
pd.options.display.max_rows = 600
pd.options.display.max_columns = width
pd.options.display.max_colwidth = 600
pd.options.display.width = width
pd.options.display.max_seq_items = None
pd.options.display.expand_frame_repr = False
pd.options.display.colheader_justify = 'left'

# %%
import data_commons as dtc
import dl_commons as dlc
import viz_commons as vc
from viz_commons import VisualizeDir, DiffParams, VisualizeStep
# Out:
# Using TensorFlow backend.

# %%
diff = DiffParams('./tb_metrics/2017-12-04 13-19-02 PST score_83.27', './tb_metrics/2017-12-06 15-40-46 PST')
one, two = diff.get_hyper()
head, tail = diff.hyper(show=True, filter_head='CONVNET')
# head[~head[0].str.contains('CONVNET')]
# Out:
#    0                                                   1
# 0            CONVNET.layers_8.kernel_shape ===> [3, 3]            CONVNET.layers_8.kernel_shape ===> [2, 2]
# 3      CONVNET.layers_9.output_channels ===> undefined            CONVNET.layers_9.output_channels ===> 512
# 4                  CONVNET.layers_11.padding ===> SAME             CONVNET.layers_11.padding ===> undefined
# 5      CONVNET.layers_7.output_channels ===> undefined            CONVNET.layers_7.output_channels ===> 512
# 6           CONVNET.layers_11.kernel_shape ===> [2, 2]        CONVNET.layers_11.kernel_shape ===> undefined
# 7             CONVNET.layers_2.output_channels ===> 64      CONVNET.layers_2.output_channels ===> undefined
# 8                  CONVNET.layers_3.stride ===> [2, 2]                  CONVNET.layers_3.stride ===> [1, 1]
# 9       CONVNET.layers_10.biases_regularizer ===> None  CONVNET.layers_10.biases_regularizer ===> undefined
# 10           CONVNET.layers_7.kernel_shape ===> [2, 2]            CONVNET.layers_7.kernel_shape ===> [3, 3]
# 11           CONVNET.layers_4.output_channels ===> 128      CONVNET.layers_4.output_channels ===> undefined
# 12     CONVNET.layers_5.output_channels ===> undefined            CONVNET.layers_5.output_channels ===> 256
# 13          CONVNET.layers_10.kernel_shape ===> [3, 3]           CONVNET.layers_10.kernel_shape ===> [2, 2]
# 15       CONVNET.layers_8.biases_regularizer ===> None   CONVNET.layers_8.biases_regularizer ===> undefined
# 16       CONVNET.layers_4.biases_regularizer ===> None   CONVNET.layers_4.biases_regularizer ===> undefined
# 17          CONVNET.layers_10.output_channels ===> 512     CONVNET.layers_10.output_channels ===> undefined
# 18                 CONVNET.layers_6.stride ===> [1, 1]                  CONVNET.layers_6.stride ===> [2, 2]
# 19  CONVNET.layers_9.biases_regularizer ===> undefined        CONVNET.layers_9.biases_regularizer ===> None
# 20                 CONVNET.layers_4.stride ===> [1, 1]                  CONVNET.layers_4.stride ===> [2, 2]
# 21  CONVNET.layers_5.biases_regularizer ===> undefined        CONVNET.layers_5.biases_regularizer ===> None
# 22           CONVNET.layers_9.kernel_shape ===> [2, 2]            CONVNET.layers_9.kernel_shape ===> [3, 3]
# 23           CONVNET.layers_6.output_channels ===> 256      CONVNET.layers_6.output_channels ===> undefined
# 24                 CONVNET.layers_2.stride ===> [1, 1]                  CONVNET.layers_2.stride ===> [2, 2]
# 25  CONVNET.layers_7.biases_regularizer ===> undefined        CONVNET.layers_7.biases_regularizer ===> None
# 26           CONVNET.layers_8.output_channels ===> 512      CONVNET.layers_8.output_channels ===> undefined
# 27                 CONVNET.layers_5.stride ===> [2, 2]                  CONVNET.layers_5.stride ===> [1, 1]
# 28  CONVNET.layers_3.biases_regularizer ===> undefined        CONVNET.layers_3.biases_regularizer ===> None
# 29                CONVNET.layers_11.stride ===> [2, 2]              CONVNET.layers_11.stride ===> undefined
# 30                 CONVNET.layers_9.stride ===> [2, 2]                  CONVNET.layers_9.stride ===> [1, 1]
# 31           CONVNET.layers_4.kernel_shape ===> [3, 3]            CONVNET.layers_4.kernel_shape ===> [2, 2]
# 32                CONVNET.layers_10.stride ===> [1, 1]                 CONVNET.layers_10.stride ===> [2, 2]
# 33                 CONVNET.layers_7.stride ===> [2, 2]                  CONVNET.layers_7.stride ===> [1, 1]
# 34           CONVNET.layers_5.kernel_shape ===> [2, 2]            CONVNET.layers_5.kernel_shape ===> [3, 3]
# 35       CONVNET.layers_6.biases_regularizer ===> None   CONVNET.layers_6.biases_regularizer ===> undefined
# 36           CONVNET.layers_2.kernel_shape ===> [3, 3]            CONVNET.layers_2.kernel_shape ===> [2, 2]
# 37     CONVNET.layers_3.output_channels ===> undefined            CONVNET.layers_3.output_channels ===> 128
# 38                 CONVNET.layers_8.stride ===> [1, 1]                  CONVNET.layers_8.stride ===> [2, 2]
# 40           CONVNET.layers_6.kernel_shape ===> [3, 3]            CONVNET.layers_6.kernel_shape ===> [2, 2]
# 43       CONVNET.layers_2.biases_regularizer ===> None   CONVNET.layers_2.biases_regularizer ===> undefined
# 44           CONVNET.layers_3.kernel_shape ===> [2, 2]            CONVNET.layers_3.kernel_shape ===> [3, 3]
#    0                                                                                                                           1
# 0                                             init_model_final_layers.weights_regularizer ===> <function l2 at 0x7f5d61c5eaa0>                                            init_model_final_layers.weights_regularizer ===> <function l2 at 0x7f5d61c5e050>
# 1                                                         CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f5d61c998d0>                                                        CALSTM_STACK_1.logger ===> <logging.Logger object at 0x7f5d61c995d0>
# 2   CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced2d0>  CALSTM_STACK_1.att_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99ed0>
# 3                                                                          CONVNET.layers_7.weights_initializer ===> undefined                                         CONVNET.layers_7.weights_initializer ===> <function _initializer at 0x7f5d61c5e410>
# 4                                                                           CONVNET.layers_3.biases_initializer ===> undefined                    CONVNET.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99ed0>
# 5                                                                                CONVNET.layers_5.activation_fn ===> undefined                                                       CONVNET.layers_5.activation_fn ===> <function relu at 0x7f5d6aa06d70>
# 6                                                                          CONVNET.layers_3.weights_initializer ===> undefined                                         CONVNET.layers_3.weights_initializer ===> <function _initializer at 0x7f5d61c5e410>
# 7                                          init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7f5d61c5eaa0>                                         init_model_hidden.layers_1.weights_regularizer ===> <function l2 at 0x7f5d61c5e050>
# 8                                                        CONVNET.layers_6.activation_fn ===> <function relu at 0x7f5d6aa06d70>                                                                               CONVNET.layers_6.activation_fn ===> undefined
# 9                                          CONVNET.layers_6.weights_initializer ===> <function _initializer at 0x7f5d61c5e938>                                                                         CONVNET.layers_6.weights_initializer ===> undefined
# 10                               init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7f5d61c5e938>                               init_model_hidden.layers_1.weights_initializer ===> <function _initializer at 0x7f5d61c5e410>
# 11                                         CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7f5d61c5e938>                                         CONVNET.layers_1.weights_initializer ===> <function _initializer at 0x7f5d61c5e410>
# 12                       CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f5d61c5e938>                       CALSTM_STACK_1.att_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f5d61c5e410>
# 13                                     biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced2d0>                                     biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99ed0>
# 14          init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced2d0>          init_model_hidden.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99ed0>
# 15                                        CONVNET.layers_10.weights_initializer ===> <function _initializer at 0x7f5d61c5e938>                                                                        CONVNET.layers_10.weights_initializer ===> undefined
# 16                    CONVNET.layers_6.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced2d0>                                                                          CONVNET.layers_6.biases_initializer ===> undefined
# 17                                                   CONVNET.layers_4.weights_regularizer ===> <function l2 at 0x7f5d61c5eaa0>                                                                         CONVNET.layers_4.weights_regularizer ===> undefined
# 18                                                       embeddings_initializer ===> <function _initializer at 0x7f5d61c5e938>                                                       embeddings_initializer ===> <function _initializer at 0x7f5d61c5e410>
# 19                                             output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f5d61c5eaa0>                                             output_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f5d61c5e050>
# 20                                                       CONVNET.layers_8.activation_fn ===> <function relu at 0x7f5d6aa06d70>                                                                               CONVNET.layers_8.activation_fn ===> undefined
# 21  CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced2d0>  CALSTM_STACK_1.att_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99ed0>
# 22                                                                         CONVNET.layers_5.weights_regularizer ===> undefined                                                   CONVNET.layers_5.weights_regularizer ===> <function l2 at 0x7f5d61c5e050>
# 23                    CONVNET.layers_8.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced2d0>                                                                          CONVNET.layers_8.biases_initializer ===> undefined
# 24                                                                         CONVNET.layers_9.weights_initializer ===> undefined                                         CONVNET.layers_9.weights_initializer ===> <function _initializer at 0x7f5d61c5e410>
# 25                       CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f5d61c5e938>                       CALSTM_STACK_1.att_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f5d61c5e410>
# 26                                                                          CONVNET.layers_9.biases_initializer ===> undefined                    CONVNET.layers_9.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99ed0>
# 27                                                                          CONVNET.layers_5.biases_initializer ===> undefined                    CONVNET.layers_5.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99ed0>
# 28                                 CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f5d61c5eaa0>                                 CALSTM_STACK_1.att_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f5d61c5e050>
# 29                                         CONVNET.layers_2.weights_initializer ===> <function _initializer at 0x7f5d61c5e938>                                                                         CONVNET.layers_2.weights_initializer ===> undefined
# 30  CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced2d0>  CALSTM_STACK_1.att_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99ed0>
# 31                                         CONVNET.layers_4.weights_initializer ===> <function _initializer at 0x7f5d61c5e938>                                                                         CONVNET.layers_4.weights_initializer ===> undefined
# 32                                                                         CONVNET.layers_9.weights_regularizer ===> undefined                                                   CONVNET.layers_9.weights_regularizer ===> <function l2 at 0x7f5d61c5e050>
# 33                                                                       logger ===> <logging.Logger object at 0x7f5d61c998d0>                                                                       logger ===> <logging.Logger object at 0x7f5d61c995d0>
# 34                                             output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f5d61c5eaa0>                                             output_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f5d61c5e050>
# 35                                                      CONVNET.layers_10.activation_fn ===> <function relu at 0x7f5d6aa06d70>                                                                              CONVNET.layers_10.activation_fn ===> undefined
# 36                                 CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f5d61c5eaa0>                                 CALSTM_STACK_1.att_layers.layers_3.weights_regularizer ===> <function l2 at 0x7f5d61c5e050>
# 37                                             output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f5d61c5eaa0>                                             output_layers.layers_2.weights_regularizer ===> <function l2 at 0x7f5d61c5e050>
# 38                                                                         CONVNET.layers_5.weights_initializer ===> undefined                                         CONVNET.layers_5.weights_initializer ===> <function _initializer at 0x7f5d61c5e410>
# 39                                   output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f5d61c5e938>                                   output_layers.layers_3.weights_initializer ===> <function _initializer at 0x7f5d61c5e410>
# 40                                  init_model_final_layers.weights_initializer ===> <function _initializer at 0x7f5d61c5e938>                                  init_model_final_layers.weights_initializer ===> <function _initializer at 0x7f5d61c5e410>
# 41                                                  CONVNET.layers_10.weights_regularizer ===> <function l2 at 0x7f5d61c5eaa0>                                                                        CONVNET.layers_10.weights_regularizer ===> undefined
# 42                                                                               CONVNET.layers_7.activation_fn ===> undefined                                                       CONVNET.layers_7.activation_fn ===> <function relu at 0x7f5d6aa06d70>
# 43                                                                               CONVNET.layers_9.activation_fn ===> undefined                                                       CONVNET.layers_9.activation_fn ===> <function relu at 0x7f5d6aa06d70>
# 44                                                     CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7f5d61c5eaa0>                                                     CALSTM_STACK_1.weights_regularizer ===> <function l2 at 0x7f5d61c5e050>
# 45                    CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced2d0>                    CONVNET.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99ed0>
# 46                    CONVNET.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced2d0>                                                                          CONVNET.layers_2.biases_initializer ===> undefined
# 47                                   output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f5d61c5e938>                                   output_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f5d61c5e410>
# 48                                                   CONVNET.layers_2.weights_regularizer ===> <function l2 at 0x7f5d61c5eaa0>                                                                         CONVNET.layers_2.weights_regularizer ===> undefined
# 49                                                                          CONVNET.layers_7.biases_initializer ===> undefined                    CONVNET.layers_7.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99ed0>
# 50                                 CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f5d61c5eaa0>                                 CALSTM_STACK_1.att_layers.layers_1.weights_regularizer ===> <function l2 at 0x7f5d61c5e050>
# 51              output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced2d0>              output_layers.layers_2.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99ed0>
# 52                                           CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7f5d61c5e938>                                           CALSTM_STACK_1.weights_initializer ===> <function _initializer at 0x7f5d61c5e410>
# 53                   CONVNET.layers_10.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced2d0>                                                                         CONVNET.layers_10.biases_initializer ===> undefined
# 54                                        CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7f5d61c5eaa0>                                        CALSTM_STACK_1.decoder_lstm.weights_regularizer ===> <function l2 at 0x7f5d61c5e050>
# 55                                                                         CONVNET.layers_7.weights_regularizer ===> undefined                                                   CONVNET.layers_7.weights_regularizer ===> <function l2 at 0x7f5d61c5e050>
# 56                                                   CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7f5d61c5eaa0>                                                   CONVNET.layers_1.weights_regularizer ===> <function l2 at 0x7f5d61c5e050>
# 57                                                   CONVNET.layers_6.weights_regularizer ===> <function l2 at 0x7f5d61c5eaa0>                                                                         CONVNET.layers_6.weights_regularizer ===> undefined
# 58                    CONVNET.layers_4.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced2d0>                                                                          CONVNET.layers_4.biases_initializer ===> undefined
# 59                                         CONVNET.layers_8.weights_initializer ===> <function _initializer at 0x7f5d61c5e938>                                                                         CONVNET.layers_8.weights_initializer ===> undefined
# 60                                   output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f5d61c5e938>                                   output_layers.layers_2.weights_initializer ===> <function _initializer at 0x7f5d61c5e410>
# 61             init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced2d0>             init_model_final_layers.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99ed0>
# 62                              CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7f5d61c5e938>                              CALSTM_STACK_1.decoder_lstm.weights_initializer ===> <function _initializer at 0x7f5d61c5e410>
# 63              output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced2d0>              output_layers.layers_3.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99ed0>
# 64                       CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f5d61c5e938>                       CALSTM_STACK_1.att_layers.layers_1.weights_initializer ===> <function _initializer at 0x7f5d61c5e410>
# 65                      CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced2d0>                      CALSTM_STACK_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99ed0>
# 66                                                       CONVNET.layers_4.activation_fn ===> <function relu at 0x7f5d6aa06d70>                                                                               CONVNET.layers_4.activation_fn ===> undefined
# 67                                                                               CONVNET.layers_3.activation_fn ===> undefined                                                       CONVNET.layers_3.activation_fn ===> <function relu at 0x7f5d6aa06d70>
# 68                                                                    weights_regularizer ===> <function l2 at 0x7f5d61c5eaa0>                                                                    weights_regularizer ===> <function l2 at 0x7f5d61c5e050>
# 69                                                   CONVNET.layers_8.weights_regularizer ===> <function l2 at 0x7f5d61c5eaa0>                                                                         CONVNET.layers_8.weights_regularizer ===> undefined
# 70              output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61ced2d0>              output_layers.layers_1.biases_initializer ===> <tensorflow.python.ops.init_ops.Zeros object at 0x7f5d61c99ed0>
# 71                                                          weights_initializer ===> <function _initializer at 0x7f5d61c5e938>                                                          weights_initializer ===> <function _initializer at 0x7f5d61c5e410>
# 72                                                       CONVNET.layers_2.activation_fn ===> <function relu at 0x7f5d6aa06d70>                                                                               CONVNET.layers_2.activation_fn ===> undefined
# 73                                                                         CONVNET.layers_3.weights_regularizer ===> undefined                                                   CONVNET.layers_3.weights_regularizer ===> <function l2 at 0x7f5d61c5e050>
# 74                                                                 embeddings_regularizer ===> <function l2 at 0x7f5d61c5eaa0>                                                                 embeddings_regularizer ===> <function l2 at 0x7f5d61c5e050>

# %%
(two['output_layers']['layers'])
# Out:
# [{'activation_fn': <function tensorflow.python.ops.gen_nn_ops.relu>,
#   'biases_initializer': <tensorflow.python.ops.init_ops.Zeros at 0x7f5d61db8a90>,
#   'biases_regularizer': None,
#   'dropout': None,
#   'num_units': 358,
#   'tb': {'logdir_tag': None,
#    'tb_activations': 'Activations',
#    'tb_biases': 'Biases',
#    'tb_logdir': './tb_metrics',
#    'tb_weights': 'Weights'},
#   'weights_initializer': <function tensorflow.contrib.layers.python.layers.initializers._initializer>,
#   'weights_regularizer': <function tensorflow.contrib.layers.python.layers.regularizers.l2>},
#  {'activation_fn': <function tensorflow.python.ops.gen_nn_ops.relu>,
#   'biases_initializer': <tensorflow.python.ops.init_ops.Zeros at 0x7f5d61db8a90>,
#   'biases_regularizer': None,
#   'dropout': None,
#   'num_units': 358,
#   'tb': {'logdir_tag': None,
#    'tb_activations': 'Activations',
#    'tb_biases': 'Biases',
#    'tb_logdir': './tb_metrics',
#    'tb_weights': 'Weights'},
#   'weights_initializer': <function tensorflow.contrib.layers.python.layers.initializers._initializer>,
#   'weights_regularizer': <function tensorflow.contrib.layers.python.layers.regularizers.l2>},
#  {'activation_fn': None,
#   'biases_initializer': <tensorflow.python.ops.init_ops.Zeros at 0x7f5d61db8a90>,
#   'biases_regularizer': None,
#   'dropout': None,
#   'num_units': 358,
#   'tb': {'logdir_tag': None,
#    'tb_activations': 'Activations',
#    'tb_biases': 'Biases',
#    'tb_logdir': './tb_metrics',
#    'tb_weights': 'Weights'},
#   'weights_initializer': <function tensorflow.contrib.layers.python.layers.initializers._initializer>,
#   'weights_regularizer': <function tensorflow.contrib.layers.python.layers.regularizers.l2>}]
