# %% [markdown]
# # im2latex(S): Tokenizer
#
# &copy; Copyright 2017 Sumeet S Singh
#
#     This file is part of im2latex solution by Sumeet S Singh.
#
#     This program is free software: you can redistribute it and/or modify
#     it under the terms of the Affero GNU General Public License as published by
#     the Free Software Foundation, either version 3 of the License, or
#     (at your option) any later version.
#
#     This program is distributed in the hope that it will be useful,
#     but WITHOUT ANY WARRANTY; without even the implied warranty of
#     MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.  See the
#     Affero GNU General Public License for more details.
#
#     You should have received a copy of the Affero GNU General Public License
#     along with this program.  If not, see <http://www.gnu.org/licenses/>.

# %%
import pandas as pd
import os
import re
import codecs
from IPython.display import display
from six.moves import cPickle as pickle
import string
from PIL import Image

# %%
pd.options.display.max_rows = 999
pd.options.display.max_columns = 20
pd.options.display.max_colwidth = 100
pd.options.display.width = 160
data_dir = data_folder = '../data/dataset3'
image_folder = image_dir = os.path.join(data_dir,'formula_images')
notebook_dir = 'step2'

# %% [markdown]
# #### Characterset Chart for Reference
# ##### ASCII Control Characters
#
#                         CTRL   (^D means to hold the CTRL key and hit d)
#     Oct  Dec Char  Hex  Key     Comments
#     \000   0  NUL  \x00  ^@ \0 (Null byte)
#     \001   1  SOH  \x01  ^A    (Start of heading)
#     \002   2  STX  \x02  ^B    (Start of text)
#     \003   3  ETX  \x03  ^C    (End of text) (see: UNIX keyboard CTRL)
#     \004   4  EOT  \x04  ^D    (End of transmission) (see: UNIX keyboard CTRL)
#     \005   5  ENQ  \x05  ^E    (Enquiry)
#     \006   6  ACK  \x06  ^F    (Acknowledge)
#     \007   7  BEL  \x07  ^G    (Ring terminal bell)
#     \010   8   BS  \x08  ^H \b (Backspace)  (\b matches backspace inside [] only)
#                                             (see: UNIX keyboard CTRL)
#     \011   9   HT  \x09  ^I \t (Horizontal tab)
#     \012  10   LF  \x0A  ^J \n (Line feed)  (Default UNIX NL) (see End of Line below)
#     \013  11   VT  \x0B  ^K    (Vertical tab)
#     \014  12   FF  \x0C  ^L \f (Form feed)
#     \015  13   CR  \x0D  ^M \r (Carriage return)  (see: End of Line below)
#     \016  14   SO  \x0E  ^N    (Shift out)
#     \017  15   SI  \x0F  ^O    (Shift in)
#     \020  16  DLE  \x10  ^P    (Data link escape)
#     \021  17  DC1  \x11  ^Q    (Device control 1) (XON) (Default UNIX START char.)
#     \022  18  DC2  \x12  ^R    (Device control 2)
#     \023  19  DC3  \x13  ^S    (Device control 3) (XOFF)  (Default UNIX STOP char.)
#     \024  20  DC4  \x14  ^T    (Device control 4)
#     \025  21  NAK  \x15  ^U    (Negative acknowledge)  (see: UNIX keyboard CTRL)
#     \026  22  SYN  \x16  ^V    (Synchronous idle)
#     \027  23  ETB  \x17  ^W    (End of transmission block)
#     \030  24  CAN  \x18  ^X    (Cancel)
#     \031  25  EM   \x19  ^Y    (End of medium)
#     \032  26  SUB  \x1A  ^Z    (Substitute character)
#     \033  27  ESC  \x1B  ^[    (Escape)
#     \034  28  FS   \x1C  ^\    (File separator, Information separator four)
#     \035  29  GS   \x1D  ^]    (Group separator, Information separator three)
#     \036  30  RS   \x1E  ^^    (Record separator, Information separator two)
#     \037  31  US   \x1F  ^_    (Unit separator, Information separator one)
#     \177 127  DEL  \x7F  ^?    (Delete)  (see: UNIX keyboard CTRL)
#
#     string.printable = '0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c'
#     string.whitespace = '\t\n\x0b\x0c\r '

# %%
def makeDatasetDetails(data_dir, overwrite=False):
    pickle_path = os.path.join(data_dir, notebook_dir, 'df2_dataset_details.pkl')
    if (not overwrite) and os.path.exists(pickle_path):
        raise Exception('File %s already exists'%pickle_path)
        
    widths=[]
    heights=[]
    formula_lens=[]
    datasetDF = pd.read_pickle(os.path.join(data_dir,'im2latex_dataset_map.df.pkl'))
    for _, row in datasetDF.iterrows():
        image_name = row.image
        im = Image.open(os.path.join(image_folder,image_name))
        widths.append(im.size[0])
        heights.append(im.size[1])
        formula_lens.append(len(row.latex))
    print(len(widths), len(heights))
    datasetDF = datasetDF.assign(width=widths, height=heights, formula_len=formula_lens)
    if not os.path.exists(os.path.join(data_dir, notebook_dir)):
        os.makedirs(os.path.join(data_dir, notebook_dir))
    datasetDF.to_pickle(pickle_path)
    return datasetDF
    
def getDatasetDetails(data_dir):
    image_details = pd.read_pickle(os.path.join(data_dir, notebook_dir, 'df2_dataset_details.pkl'))
    return image_details

# %%
# df2_image_details = makeDatasetDetails(data_dir)
df2_image_details = getDatasetDetails(data_dir)

# %%
def get_df_clean(data_dir_, df_image_details_):
    NONPRINTABLE_CHARS_RE = r'[^\\' + string.printable + r']'
    DELETE_RE = re.compile(r".\x7F")
    PERCENTS_RE = r'%'
    return pd.read_pickle(os.path.join(data_dir_, notebook_dir, 'df3_clean.pkl'))
    
def make_df_clean(data_dir_, df_image_details_, overwrite=False):
    NONPRINTABLE_CHARS_RE = r'[^\\' + string.printable + r']'
    DELETE_RE = re.compile(r".\x7F")
    PERCENTS_RE = r'%'
    pickle_path = os.path.join(data_dir_, notebook_dir, 'df3_clean.pkl')
    if (overwrite==False) and (os.path.exists(pickle_path)):
        raise Exception('File %s already exits'%pickle_path)
    else:
        df = df_image_details_
        # Make sure everything's ascii
        # Coalesce whitespace to a single space
        # Strip whitespace from the sides
        # Strip percent signs from the sides
        # Discard strings with non-printable characters
        # Discard strings with embedded percent signs (because textogif ignores everything after the % sign)
        cleaned = df.latex.str.decode('ascii').str.encode('ascii').str.replace(r"\s+", ' ').str.strip().str.strip('%')
        df = df.assign(latex_ascii=cleaned, latex_ascii_len=cleaned.str.len())
        bad1 = df.latex.str.contains(NONPRINTABLE_CHARS_RE)
        print 'nonprintables #: ', bad1.sum()
        bad2 = df.latex.str.contains(PERCENTS_RE)
        print 'percents #: ', bad1.sum()
        good = ~(bad1 | bad2)
        print 'good #: ', good.sum()
        df = df[good]
        df.to_pickle(pickle_path)
        return df

# %%
df3_clean = get_df_clean(data_dir, df2_image_details)
display(df3_clean.shape)
# Out:
# (100700, 8)

# %%
df3_clean
# Out:
#                             image           formula_name                                                                                                latex  \
# 0       23be72ded29e9b4_basic.png  23be72ded29e9b4_basic  \int _ { - \epsilon } ^ { \infty } d l \: \mathrm { e } ^ { - l \zeta } \int _ { - \epsilon } ^ ...
# 1       8c904c5d9c7bd63_basic.png  8c904c5d9c7bd63_basic  d s ^ { 2 } = ( 1 - { \frac { q c o s \theta } { r } } ) ^ { \frac { 2 } { 1 + \alpha ^ { 2 } } ...
# 2       1f111caa1be3516_basic.png  1f111caa1be3516_basic  \widetilde \gamma _ { \mathrm { h o p f } } \simeq \sum _ { n > 0 } \widetilde { G } _ { n } { \...
# 3       76287b1b483a0d2_basic.png  76287b1b483a0d2_basic          ( { \cal L } _ { a } g ) _ { i j } = 0 , \ \ \ \ ( { \cal L } _ { a } H ) _ { i j k } = 0 ,
# 4       7483d06c1e14dcb_basic.png  7483d06c1e14dcb_basic  S _ { s t a t } = 2 \pi \sqrt { N _ { 5 } ^ { ( 1 ) } N _ { 5 } ^ { ( 2 ) } N _ { 5 } ^ { ( 3 ) ...
# 5       8135cab7e6b93ae_basic.png  8135cab7e6b93ae_basic                 \hat { N } _ { 3 } = \sum \sp f _ { j = 1 } a _ { j } \sp { \dagger } a _ { j } \, .
# 6       67808bc314fa181_basic.png  67808bc314fa181_basic  + \int \! \! d ^ { D } \! z _ { 1 } d ^ { D } \! z _ { 2 } d ^ { D } \! z _ { 3 } \left. \frac {...
# 7       2278ffa4860ed9b_basic.png  2278ffa4860ed9b_basic                                   \, ^ { * } d \, ^ { * } H = \kappa \, ^ { * } d \phi = J _ { B } .
# 8       1d7098797009973_basic.png  1d7098797009973_basic  { \frac { \phi ^ { \prime \prime } } { A } } + { \frac { 1 } { A } } \left( - { \frac { 1 } { 2 ...
# 9       f4f265238eb9724_basic.png  f4f265238eb9724_basic                             \partial _ { \mu } ( F ^ { \mu \nu } - e j ^ { \mu } x ^ { \nu } ) = 0 .
# 10      ebf76c96dda24fb_basic.png  ebf76c96dda24fb_basic  E _ { A D M } = \frac { 1 } { 1 6 \pi G _ { 1 0 } } \oint _ { \infty } d \Sigma ^ { m } \lbrace ...
# 11      10f52bac8085939_basic.png  10f52bac8085939_basic  P _ { ( 2 ) } ^ { - } = \int \beta d \beta d ^ { 9 } p d ^ { 8 } \lambda \Phi ( - p , - \lambda ...
# 12      e365c97c0e7cfba_basic.png  e365c97c0e7cfba_basic  V _ { n s } ( { \tilde { x } } ) = \left( \frac { { \tilde { m } } N ^ { 2 } } { 1 6 \pi } \righ...
# 13      6e0423b8338ceaa_basic.png  6e0423b8338ceaa_basic  g _ { i j } ( x ) = { \frac { 1 } { a ^ { 2 } } } \, \delta _ { i j } , ~ ~ \phi ^ { a } ( x ) =...
# 14      f6234aa4de66f01_basic.png  f6234aa4de66f01_basic  \begin{array} { l l } { \sigma ^ { 0 } = - { \bf 1 } _ { 2 \times 2 } = { \bar { \sigma } } ^ { ...
# 15      cf5fceabedc6809_basic.png  cf5fceabedc6809_basic  \rho _ { L } ( q ) = \sum _ { m = 1 } ^ { L } \ P _ { L } ( m ) \ { \frac { 1 } { q ^ { m - 1 } ...
# 16      f756628eae4368f_basic.png  f756628eae4368f_basic  \Lambda _ { - 1 , 1 } = \lambda ^ { - 1 } ( e _ { 1 , 2 p } - e _ { 2 , 2 p + 1 } ) + ( e _ { 2 ...
# 17      5371d1643eb09a9_basic.png  5371d1643eb09a9_basic  e x p \left( - \frac { \partial } { \partial \alpha _ { j } } \theta ^ { j k } \frac { \partial ...
# 18      bd9281732ed06ba_basic.png  bd9281732ed06ba_basic                                                 L _ { 0 } = \Phi ( w ) = \bigtriangleup \Phi ( w ) ,
# 19      45f26fd118114ef_basic.png  45f26fd118114ef_basic                                        \left( D ^ { * } D ^ { * } + m ^ { 2 } \right) { \cal H } = 0
# 20      cc218744908e01e_basic.png  cc218744908e01e_basic         { \frac { d V } { d \Phi } } = - { \frac { w \Phi } { \Phi _ { \! _ { 0 } } ^ { 2 } } } \, .
# 21      2c4f23c09396b83_basic.png  2c4f23c09396b83_basic  g ( z , \bar { z } ) = - \frac { 1 } { 2 } \left[ x ( z , \bar { z } ) \, s + x ^ { * } ( z , \b...
# 22      0785e9241fb7831_basic.png  0785e9241fb7831_basic                                                    x _ { \mu } ^ { c } = x _ { \mu } + A _ { \mu } .
# 23      55401122caf971c_basic.png  55401122caf971c_basic  s = { \frac { S } { V } } = { \frac { A _ { H } } { l _ { p } ^ { 8 } V } } = { \frac { T ^ { 2 ...
# 24      3968850bd523cae_basic.png  3968850bd523cae_basic  \psi ( \gamma ) = \operatorname { e x p } { - ( { \textstyle { \frac { g ^ { 2 } } { 2 } } } ) \...
# 25      16ceefff20ce3eb_basic.png  16ceefff20ce3eb_basic  E = E _ { 0 } + \frac { 1 } { 2 \operatorname { s i n h } ( \gamma ( 0 ) / 2 ) } \operatorname {...
# 26      80d1a58ea0f1314_basic.png  80d1a58ea0f1314_basic  \dot { z } _ { 1 } = - N ^ { z } ( z _ { 1 } ) = - g ( z _ { 1 } ) = - \frac { z _ { 1 } } { P _...
# 27      ff6e22cdc339ecf_basic.png  ff6e22cdc339ecf_basic               \langle T _ { z z } \rangle = - 3 \times \frac { \pi ^ { 2 } } { 1 4 4 0 a ^ { 4 } } .
# 28      3d416c04b9f3019_basic.png  3d416c04b9f3019_basic  \partial _ { u } \xi _ { z } ^ { ( 1 ) } + { \frac { 1 } { u } } \xi _ { z } ^ { ( 1 ) } = { \fr...
# 29      1f40b4e12edae2b_basic.png  1f40b4e12edae2b_basic  { \cal L } = - { \frac { 1 } { 4 } } F _ { \mu \nu } F ^ { \mu \nu } + { \bar { \psi } } ( i \ga...
# 30      a17843976571824_basic.png  a17843976571824_basic  S \sim \tilde { \psi } Q _ { o } \tilde { \psi } + g _ { s } ^ { 1 / 2 } \tilde { \psi } ^ { 3 }...
# 31      d8c5a94e51be877_basic.png  d8c5a94e51be877_basic  C ( x ^ { \prime } , x ^ { \prime \prime } ) = C \Phi ( x ^ { \prime } , x ^ { \prime \prime } )...
# 32      f065cbcb48371ce_basic.png  f065cbcb48371ce_basic  \tilde { \alpha } = \alpha \beta ^ { - m } = \left( \begin{array} { c c c } { \omega _ { k } ^ {...
# 33      c6955090ed8544d_basic.png  c6955090ed8544d_basic  d s ^ { 2 } = H ^ { - 2 } f ( r ) d t ^ { 2 } + H ^ { 2 / ( n - 1 ) } ( f ( r ) ^ { - 1 } d r ^ ...
# 34      0ba5003bb83cfc2_basic.png  0ba5003bb83cfc2_basic  y ^ { 2 } = \rho \; \operatorname { c o s h } \beta \; \operatorname { s i n } \theta \; \operat...
# 35      ad76690325a70c1_basic.png  ad76690325a70c1_basic  e ^ { A } = e ^ { A _ { 0 } } \left( t _ { 0 } - \mathrm { s i g n } ( m ) t \right) ^ { - \frac...
# 36      37b67e098d43860_basic.png  37b67e098d43860_basic  \gamma _ { j } { \cal P } _ { j i } = \frac { 4 } { 3 } \{ [ A d \, T ] [ t _ { 8 } ^ { c } , [ ...
# 37      2971f391887c7aa_basic.png  2971f391887c7aa_basic  \Omega _ { k } ^ { ( l ) } = \sum _ { s = 0 } \int d ^ { 3 } y \left( ( - 1 ) ^ { s + 1 } \frac ...
# 38      30c638170d64b5d_basic.png  30c638170d64b5d_basic                                   K _ { \mu \nu } ~ = ~ \frac { 1 } { 2 } \dot { g } _ { \mu \nu } .
# 39      972fc9d76fcb7c4_basic.png  972fc9d76fcb7c4_basic  X ( u ) = { \frac { \left( \pm i + e ^ { 3 \eta } \right) \left( - 1 + { e ^ { u } } \right) \le...
# 40      691d06e268b4e63_basic.png  691d06e268b4e63_basic  \beta ( g ) \frac { \partial } { \partial g } = 2 g \beta ( g ) \frac { \partial } { \partial g ...
# 41      b27e4903066bdc8_basic.png  b27e4903066bdc8_basic  A = a r ^ { \beta } , \quad B = b r ^ { \beta + 2 } ; \qquad a / b = c ( \beta + 2 ) / ( \beta -...
# 42      0f8bb81cea5d413_basic.png  0f8bb81cea5d413_basic      \delta W _ { P \mu } = A _ { \mu } \Phi + B _ { P \mu } ^ { \alpha } K _ { P } ^ { \alpha } \ .
# 43      1a6cf13efc5c05e_basic.png  1a6cf13efc5c05e_basic  \frac { 1 } { d - 2 } \tilde { \Pi } ^ { 2 } - \tilde { \Pi } _ { a b } \tilde { \Pi } ^ { a b }...
# 44      c872241c44f0521_basic.png  c872241c44f0521_basic                    \hat { e } = e / \varepsilon , \ \ \ \ \ \ \ \ \ \hat { G } _ { 4 } = G _ { 4 } ,
# 45      bed413c26163ed1_basic.png  bed413c26163ed1_basic  R ( e _ { 1 } ) = \epsilon ^ { - J _ { 6 7 } + J _ { 8 9 } } , \quad R ( e _ { 2 } ) = \epsilon ...
# 46      eead76314b82a7b_basic.png  eead76314b82a7b_basic  { \tilde { \cal { E } } } _ { m < 0 } = { \cal { E } } _ { m < 0 } ( B ) - { \cal { E } } ( 0 ) ...
# 47      356de7d67f7d7da_basic.png  356de7d67f7d7da_basic  V _ { ( n , \, m ) } ( z , \overline { { z } } ) = : \operatorname { e x p } i ( p _ { + } \phi ...
# 48      19842dd0c77b8e5_basic.png  19842dd0c77b8e5_basic  \langle f | g \rangle _ { { \cal L } ^ { 1 | 2 } } = \langle f _ { 0 } | g _ { 0 } \rangle _ { \...
# 49      08bb8118e963e11_basic.png  08bb8118e963e11_basic  g _ { n } ^ { > } ( r , r ^ { \prime } ) = E _ { n } K _ { | n / \alpha | } ( \beta r ) , \quad ...
# 50      e201da8f406e4b7_basic.png  e201da8f406e4b7_basic  \tilde { s } ^ { 0 } ( x , y ) = i e ^ { 2 } \int \! d ^ { 4 } \! z \, S _ { \mathrm { F } } ( x...
# 51      6be06b34ae096b6_basic.png  6be06b34ae096b6_basic  { \cal P } _ { \delta x } \equiv { \frac { k ^ { 3 } } { 2 \pi ^ { 2 } } } | \delta x | ^ { 2 } ...
# 52      435b729493645ec_basic.png  435b729493645ec_basic                                                     \psi ( x ) = - 2 \phi ( x ) + 2 \phi ( L ) + c ,
# 53      ef52e1cbcb9aa29_basic.png  ef52e1cbcb9aa29_basic  { } ^ { ( { } ^ { \scriptstyle x } y ) } ( { } ^ { x } z ) = { } ^ { x } ( { } ^ { y } z ) , \qq...
# 54      908b823bc4c7746_basic.png  908b823bc4c7746_basic  \delta ( L _ { 1 } + L _ { 2 } ) = 2 \delta \bar { \theta } ( 1 + \gamma ^ { ( p ) } ) T _ { ( p...
# 55      79835c888ad8107_basic.png  79835c888ad8107_basic  \frac { 1 } { 2 \lambda f ^ { 2 } } \int \; d ^ { 4 } X \, \frac { d ^ { 4 } q } { \left( 2 \pi ...
# 56      2dfef7a1cad2fa7_basic.png  2dfef7a1cad2fa7_basic  ( K ^ { - 1 } ) _ { S } ^ { U } = - \frac { z ^ { * 3 } ( 1 - A | z | ^ { 2 } ) P ^ { \prime } (...
# 57      01f0192af10eee7_basic.png  01f0192af10eee7_basic  G ^ { \mu \nu \mu ^ { \prime } \nu ^ { \prime } } = g ^ { \mu \mu ^ { \prime } } g ^ { \nu \nu ^...
# 58      bb73efa1aa31260_basic.png  bb73efa1aa31260_basic  [ M _ { \mu \nu } , M _ { \rho \tau } ] = g _ { \mu \tau } \, M _ { \nu \rho } - g _ { \nu \tau ...
# 59      d611dcb8ca652f7_basic.png  d611dcb8ca652f7_basic       A _ { 0 } = \pm \sqrt { { \frac { 4 } { 3 ( 1 - \alpha ) } } } e ^ { ( \alpha - 1 ) \phi } \ .
# 60      1aba9a05be49c27_basic.png  1aba9a05be49c27_basic  \left\{ \Psi \circ \mu , f \right\} = ( \overline { X } _ { i } f ) \, ( Y ^ { i } \Psi ) \circ ...
# 61      60c7f545a6f82d2_basic.png  60c7f545a6f82d2_basic  C _ { m } ( \mu ) = { \frac { 1 } { 2 \pi i } } \int _ { \Gamma _ { r } } { \frac { C _ { m } ( ...
# 62      27cbd085a07e90d_basic.png  27cbd085a07e90d_basic  \xi = \alpha ^ { - 1 } \sqrt { \rho } \operatorname { c o s h } ( 2 \alpha ^ { 2 } t ) \, , \qua...
# 63      d4d809dc03ef8ef_basic.png  d4d809dc03ef8ef_basic  a _ { 1 } = \frac { 2 \tilde { q } } { \alpha ^ { 2 } ( D - 2 ) + 2 q \tilde { q } } , ~ ~ ~ ~ a...
# 64      0644b9322b84f13_basic.png  0644b9322b84f13_basic  { e _ { \hat { \mu } } ^ { \ \hat { m } } = \left( \begin{matrix} { e _ { \sigma } ^ { \ s } } &...
# 65      00b503a11b4c2fd_basic.png  00b503a11b4c2fd_basic  \theta \epsilon ^ { i } = \zeta ^ { i } \, ; \qquad \theta \zeta ^ { i } = \epsilon ^ { i } \, ;...
# 66      252dd48bd917b55_basic.png  252dd48bd917b55_basic  { \cal A } _ { f i } ( s ) = - i \frac { Q _ { \mu \nu } V _ { f } ^ { \mu } ( \bar { s } ) V _ ...
# 67      c1db14ccb3662c9_basic.png  c1db14ccb3662c9_basic  S = \frac { 1 } { G } \int d x d t \: \sqrt { - \bar { g } } \: e ^ { - 2 \bar { \phi } } ( \bar...
# 68      072ae6c10183b65_basic.png  072ae6c10183b65_basic  S = { \frac { \pi ^ { 3 } R ^ { 5 } } { 2 \kappa _ { 1 0 } ^ { 2 } } } \left[ \; \int _ { 0 } ^ ...
# 69      c9607abff4087c4_basic.png  c9607abff4087c4_basic  g _ { J _ { 1 } \, J _ { 2 } } ^ { J } \bigl ( J _ { 1 } , M _ { 1 } ; J _ { 2 } , M _ { 2 } \ve...
# 70      b84d5be40941632_basic.png  b84d5be40941632_basic  Q ^ { M } = \dot { g } _ { 0 } \int _ { \phi ( \Sigma ) } \sum _ { i = 1 } ^ { l } \beta _ { i }...
# 71      3650b86994da076_basic.png  3650b86994da076_basic  \psi ( x ) = [ 2 \pi \sigma ^ { 2 } ] ^ { - 1 / 4 } \operatorname { e x p } \left[ - \left( \fra...
# 72      1d5031457a76964_basic.png  1d5031457a76964_basic                                        A _ { \mu } = \bar { A } _ { \mu } ( \phi ) + a _ { \mu } \ ,
# 73      59b31e41c16b17a_basic.png  59b31e41c16b17a_basic                                                                \left[ D _ { f } , D \right] = 0 \, .
# 74      86955305236bc9f_basic.png  86955305236bc9f_basic  G = \! e ^ { i \tau L _ { - 1 } } e ^ { i U ^ { ( 1 ) } L _ { 1 } } e ^ { i U ^ { ( 2 ) } L _ { ...
# 75      bae1a5e58e76cd7_basic.png  bae1a5e58e76cd7_basic    \operatorname { e x p } _ { q } A = \sum _ { n = 0 } ^ { \infty } \frac { A ^ { n } } { [ n ] ! }
# 76      a76561b0b353851_basic.png  a76561b0b353851_basic  \langle b _ { 1 } ( z , \bar { z } ) a _ { 1 } ( z ^ { \prime } , \bar { z } ^ { \prime } ) \ran...
# 77      8de9f3c68d1ab92_basic.png  8de9f3c68d1ab92_basic  \lambda _ { + } = \frac { 1 + i \omega } { 2 } , \quad \lambda _ { - } = \frac { 1 - i \omega } ...
# 78      12b289a693fb653_basic.png  12b289a693fb653_basic                                                       1 + \frac { 2 \pi \Lambda G } { 9 \alpha } > 0
# 79      26a2e859d51f838_basic.png  26a2e859d51f838_basic       e ^ { - K } = \pm \frac { W ^ { 3 / 2 } } { \omega _ { 1 } \omega _ { 2 } \omega _ { 3 } } \ ,
# 80      a3182c30596b937_basic.png  a3182c30596b937_basic  { \cal { Z } } ( \tau { } ) = \sum _ { m } \int { \cal { D } } \Omega { \cal { D } } V { \mathrm...
# 81      630e37552985655_basic.png  630e37552985655_basic   | 0 ( t ) \rangle _ { e , \mu } \equiv G _ { \theta } ^ { - 1 } ( t ) | 0 \rangle _ { 1 , 2 } \, ,
# 82      bceb582323b57d1_basic.png  bceb582323b57d1_basic  R ^ { ( 1 ) } = R _ { 1 2 } \, \mathrm { o r } \, R _ { 2 1 } ^ { - 1 } \, , \quad R ^ { ( 2 ) }...
# 83      6d57ce97baf2179_basic.png  6d57ce97baf2179_basic  \left( \alpha ^ { \prime } \right) ^ { - 1 } e ^ { - \phi / 2 } f _ { 1 6 } \, s i m \ g ^ { - 2...
# 84      f7809edcab5e73e_basic.png  f7809edcab5e73e_basic  \Gamma _ { i j } ^ { k } = ( \partial _ { i } G _ { j { \bar { l } } } ) G ^ { { \bar { l } } k ...
# 85      19b39a96fa5deac_basic.png  19b39a96fa5deac_basic  { \cal { F } } : \ < g > = \int d ^ { 3 } \theta \ g ( { \vec { \theta } } ) f ( { \vec { \theta...
# 86      b13ca1503148f63_basic.png  b13ca1503148f63_basic  \tilde { S } _ { r , \Lambda } ( t _ { 2 } , t _ { 1 } ; g ) = - 2 i \delta ( t _ { 2 } - t _ { ...
# 87      d28868c4ac119c1_basic.png  d28868c4ac119c1_basic  \nu _ { R } ( E ) = \int _ { \mu } ^ { E - \mu _ { Q } } \nu ( E ^ { \prime } ) \nu _ { Q } ( E ...
# 88      cff4f7deec68924_basic.png  cff4f7deec68924_basic  { \mathrm { \boldmath ~ e ~ } } ( t ) = \dot { { \mathrm { \boldmath ~ x ~ } } } / \sqrt { { \do...
# 89      22904e906732dd0_basic.png  22904e906732dd0_basic  V _ { e f f } ( z ) = \frac { 3 ( 5 \alpha + 4 ) k ^ { 2 } } { 6 4 \left( { \frac { k z } { 2 } ...
# 90      c14c5fc8edea5df_basic.png  c14c5fc8edea5df_basic  Z _ { \mathrm { F } } [ A ] = \int \! D { \bar { \psi } } D \psi e ^ { - \int \! d ^ { 2 } x \, ...
# 91      3062fd3fdf08432_basic.png  3062fd3fdf08432_basic  R : ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ \alpha ^ { \prime } M ^ { 2 } = - 1 , 0 , ...
# 92      67944af50a7128b_basic.png  67944af50a7128b_basic  f _ { i j } ( u ) = f _ { j i } ( u ) = c \, \mathrm { s g n } ( u ) = c \, [ \theta ( u ) - \th...
# 93      c7afc593ffe559b_basic.png  c7afc593ffe559b_basic  E q ( 5 . 2 ) T _ { R } \; \sim \; 5 \left( \frac { m } { \mathrm { T e V } } \right) ^ { 3 / 2 ...
# 94      8202a86c62612fa_basic.png  8202a86c62612fa_basic  P _ { n } ^ { p } = \frac { ( - 1 ) ^ { p + n } } { n ! ( p - n ) ! } \mathop { { \prod } ^ { \p...
# 95      79ade88038d6361_basic.png  79ade88038d6361_basic                  T _ { { \cal G } } ( - t , - t ^ { - 1 } ) = \sum x ^ { i ( B ) } x ^ { - e ( B ) }
# 96      e5533d1d80e8f0e_basic.png  e5533d1d80e8f0e_basic  \left. \begin{array} { c c c } { S _ { \sigma \sigma ^ { \prime } } \nonumber } \\ { S _ { \Delt...
# 97      e46fa53ac0478f2_basic.png  e46fa53ac0478f2_basic   \Phi _ { 0 } ( Z ) = \delta ^ { - 1 } \alpha , \qquad \Phi _ { 0 } ( Z ) = \alpha ^ { - 1 } \delta
# 98      8bada7acf64ad89_basic.png  8bada7acf64ad89_basic                  { \xi } _ { i } ^ { \ast } , { p } _ { i } ^ { \ast } , \quad i = 2 , \dots , l + 1
# 99      7009bf9e7c6c960_basic.png  7009bf9e7c6c960_basic  \varrho _ { L } - { \cal L } _ { E } = [ 2 \dot { \Phi } ^ { 2 } ] \; K ^ { \prime } ( \dot { \P...
# 100     ddd45de53b2c11e_basic.png  ddd45de53b2c11e_basic         b ( k ) b ^ { \dagger } ( l ) - q _ { e } b ^ { \dagger } ( l ) b ( k ) = \delta ( k - l ) ,
# 101     95216580cf1495d_basic.png  95216580cf1495d_basic  { \cal L } = - \mathrm { \small ~ \frac { 1 } { 2 } ~ } f ^ { 2 } \, \partial _ { \mu } \pi _ { ...
# 102     14aa53d25f15baa_basic.png  14aa53d25f15baa_basic  < \frac { 1 } { 2 } , m _ { s } | { \psi } _ { - } ^ { ( \frac { 1 } { 2 } ) } ( g ) > \equiv D ...
# 103     a3194af4fb6cc4d_basic.png  a3194af4fb6cc4d_basic  E _ { \mathrm { q u a s i l o c a l } } = E _ { + } - E _ { - } = \left( r \left[ 1 - \left| r ,...
# 104     7f28f8e6252a255_basic.png  7f28f8e6252a255_basic  I = 2 \left( { \frac { \alpha } { \operatorname { s i n h } ^ { 2 } A + \operatorname { s i n } ...
# 105     b456e3c56f5cb78_basic.png  b456e3c56f5cb78_basic                  \delta \chi _ { \mu \nu } = i b _ { \mu \nu } , \qquad \delta b _ { \mu \nu } = 0 .
# 106     facb47939f0655f_basic.png  facb47939f0655f_basic  V _ { a b \ \ m n } ^ { k } = \frac { 1 } { g } \ E _ { a } ^ { r } \ E _ { b } ^ { s } \epsilon...
# 107     744826807150a23_basic.png  744826807150a23_basic                                                  W ( x ) = \frac { x ^ { 3 } } { 3 } - a ^ { 2 } x ,
# 108     18b9ded2265d626_basic.png  18b9ded2265d626_basic  Z _ { M } = \sum _ { j _ { s } } \int d U _ { f } \Pi _ { s } \left( 2 j _ { s } + 1 \right) T r...
# 109     2977b79ee03dd32_basic.png  2977b79ee03dd32_basic  f ( x , p ; t ) = \int \! d a d b ~ \tilde { f } ( a , b ) ~ e ^ { i a x ( - t ) } e ^ { i b p (...
# 110     8ed68c5ab7b5bc7_basic.png  8ed68c5ab7b5bc7_basic                               \{ \langle n | O | p \rangle \: | n \in \Sigma _ { s } ^ { \prime } \}
# 111     c2b43868c488de6_basic.png  c2b43868c488de6_basic                                { \cal L } ^ { ( 0 ) } ( B ) = - { \frac { 1 } { 2 } } B ^ { 2 } \; ,
# 112     b04eb084b50c8a9_basic.png  b04eb084b50c8a9_basic  \phi ( \rho ) = \left\{ \begin{cases} { \phi ^ { ( 1 ) } ( \rho ) } & { i n r e g i o n 1 } \\ {...
# 113     67c3b976d0e83ea_basic.png  67c3b976d0e83ea_basic                                                                  \ddot { h } = - \nabla _ { h } \Phi
# 114     f6340334b4f460a_basic.png  f6340334b4f460a_basic  \langle 0 | T _ { \mu \nu } | 0 \rangle _ { \mathrm { \tiny ~ R e n . } } = \mathrm { d i a g } ...
# 115     154967bef233d86_basic.png  154967bef233d86_basic  \frac { 1 } { 2 4 . 8 \pi ^ { 2 } } \, \int _ { \cal M } R \wedge R = \frac { 1 } { 2 4 . 8 \pi ...
# 116     24a07ec7069b093_basic.png  24a07ec7069b093_basic  \quad | A _ { 1 } | ^ { 2 } + | A _ { 2 } | ^ { 2 } - | B _ { 1 } | ^ { 2 } - | B _ { 2 } | ^ { ...
# 117     2874ecd494665e8_basic.png  2874ecd494665e8_basic                    e ^ { \phi _ { c } ^ { 6 } } = - { \frac { v _ { a } } { \tilde { v } _ { a } } }
# 118     85d98623a893cfa_basic.png  85d98623a893cfa_basic                                      \mathrm { \boldmath ~ \pi ~ } = \mu ^ { - 1 } \, { \bf p } \; .
# 119     3304ba405879c5d_basic.png  3304ba405879c5d_basic  S = \int _ { \mathcal M } \left( { \frac { i } { 2 } } \left[ \overline { \psi } \gamma ^ { a } ...
# 120     874738ade6a26f4_basic.png  874738ade6a26f4_basic  \Psi \sim \operatorname { e x p } \left\{ - \frac { 1 } { \hbar } \int _ { a } ^ { x } \sqrt { 2...
# 121     d316113ede2af58_basic.png  d316113ede2af58_basic  \ddot { R } ^ { k } ( t ) = \omega ^ { k l } \dot { R } ^ { l } ( t ) + O ( \dot { R } ^ { k } \...
# 122     8452f0863971e00_basic.png  8452f0863971e00_basic  \mathrm { T r } \, \operatorname { l o g } ( 1 - \sum _ { i = 0 } ^ { N } A _ { i } ) ~ = ~ \mat...
# 123     c1b379c1ca08d96_basic.png  c1b379c1ca08d96_basic  H _ { i j } ^ { a } = F _ { i j } ^ { a } - g f _ { \; \; b c } ^ { a } A _ { i } ^ { b } A _ { ...
# 124     0d95ed41d21da07_basic.png  0d95ed41d21da07_basic          { \cal L } \rightarrow { \cal L } + \frac { \alpha N } { 1 6 \pi ^ { 2 } } F \tilde { F } .
# 125     3bc33ca9732a414_basic.png  3bc33ca9732a414_basic                                       \partial _ { 0 } { \cal E } + { \bf d i v } { \bf S } = 0 \, .
# 126     22b6e1248dbd440_basic.png  22b6e1248dbd440_basic                                 \phi ( x , y ) = \lambda ^ { 2 s } \, \phi ( \lambda x , \lambda y )
# 127     d14acf78e541154_basic.png  d14acf78e541154_basic  { \bf N } ( { \bf p } , { \bf s } ) : = i p _ { 0 } { \nabla } _ { \bf p } - \frac { { \bf s } \...
# 128     aba666f371a4442_basic.png  aba666f371a4442_basic  S _ { B } [ A ] \; = \; i \, \frac { 1 } { \eta } \, S _ { C S } [ A ] \; + \; R [ \widetilde { ...
# 129     a3cbd91afbe740e_basic.png  a3cbd91afbe740e_basic  { \frac { \partial \bar { g } _ { \mu \nu } } { \partial l _ { i } } } \in \mathrm { K e r } ( \...
# 130     7ffda16fc0a0d38_basic.png  7ffda16fc0a0d38_basic                                 m _ { H } \approx 2 7 2 \, \lambda ^ { 1 / 4 } \ \mathrm { G e V } .
# 131     89a004c96dd4447_basic.png  89a004c96dd4447_basic  A _ { \mu } \; = \; \partial _ { \mu } \varphi + \epsilon _ { \mu \nu } \, \partial _ { \nu } \s...
# 132     4a642eef48c9c50_basic.png  4a642eef48c9c50_basic  M _ { p _ { e } , q _ { m } } = { \frac { 2 \pi } { g _ { \mathrm { Y M } } ^ { 2 } } } { \frac ...
# 133     ed1dbe847d69fdd_basic.png  ed1dbe847d69fdd_basic             { \frac { d ^ { 2 } \varphi } { d \tau ^ { 2 } } } = \operatorname { s i n } \varphi \ ,
# 134     52fd3b6659c58a2_basic.png  52fd3b6659c58a2_basic  \hat { I } _ { 1 2 } = - \frac { 1 } { 9 6 ( 2 \pi ) ^ { 5 } } \hat { I } _ { 4 } \wedge ( \frac...
# 135     2e5f0b136685103_basic.png  2e5f0b136685103_basic  \frac { 1 } { k ^ { 2 } } ( g ^ { \mu \nu } - \frac { \tilde { k } _ { \mu } \tilde { k } _ { \n...
# 136     b7bad470c033f54_basic.png  b7bad470c033f54_basic  \begin{array} { l c r } { q J _ { 1 } J _ { 2 } - q ^ { - 1 } J _ { 2 } J _ { 1 } } & { = } & { ...
# 137     40ccb7117aa6983_basic.png  40ccb7117aa6983_basic                     S _ { \Omega ^ { \prime } , \Omega } x \Omega = x ^ { * } \Omega , \, \, x \in M
# 138     0fb887f88c788ca_basic.png  0fb887f88c788ca_basic  C _ { J } ( \nu _ { 1 } , \nu _ { 2 } ) = ( 2 J + \nu _ { 1 } + \nu _ { 2 } + 1 ) \frac { { \mit...
# 139     b02a8fdc0564fd7_basic.png  b02a8fdc0564fd7_basic  a _ { 1 } = - 2 \pi I _ { 2 \alpha } ( 0 ) = - \frac { \pi } { 3 } \left( \frac { \pi } { \alpha...
# 140     6bd857e935d6c53_basic.png  6bd857e935d6c53_basic  { \cal L } = { \frac { 1 } { 2 } } \partial _ { \mu } \phi _ { x } \partial ^ { \mu } \phi _ { x...
# 141     1873144e0210616_basic.png  1873144e0210616_basic  \langle P ^ { \prime } | J ^ { \mu } ( 0 ) | P \rangle = \bar { u } ( P ^ { \prime } ) \, \Big [...
# 142     85de9aa1b3c9b58_basic.png  85de9aa1b3c9b58_basic  u _ { 0 } ( k , r ) = \sqrt { { \displaystyle { \frac { \pi } { 2 } } } } \, i \sqrt { r } \, J ...
# 143     c95959a733fd9b5_basic.png  c95959a733fd9b5_basic  f \star g = \operatorname { e x p } \Bigg [ \hbar \Bigg ( \frac { \partial ~ } { \partial q } \f...
# 144     7ce48361f579011_basic.png  7ce48361f579011_basic                                                    \Delta { \cal A } = \frac { 1 } { 2 } ( 1 + g ) .
# 145     e38b3cd9b1fca14_basic.png  e38b3cd9b1fca14_basic  \operatorname { e x p } \left( i p _ { \mu } X ^ { \mu } \right) \rightarrow \hat { v } _ { p } ...
# 146     7d27a2618027268_basic.png  7d27a2618027268_basic  ( \partial _ { \gamma } , \partial _ { \gamma } ) _ { ( 1 0 ) } = \sqrt { \tilde { \Delta } } e ...
# 147     13a18a5e7376c55_basic.png  13a18a5e7376c55_basic  3 . 8 G = \eta _ { a b } d z ^ { a } \otimes d z ^ { b } = - d z ^ { 0 } \otimes d z ^ { 0 } + \...
# 148     91ee24b9b15b50f_basic.png  91ee24b9b15b50f_basic  T _ { [ \mu \nu ] } ^ { \ a } = \partial _ { \mu } E _ { \nu } ^ { \underline { { a } } } - \par...
# 149     2471e878a26f184_basic.png  2471e878a26f184_basic                                                   \eta _ { \mu \nu } = \mathrm { d i a g ( - , + ) }
# 150     328950dae902592_basic.png  328950dae902592_basic                                                  \langle f , f \rangle = \langle g , g \rangle = 0 .
# 151     76496a53b654801_basic.png  76496a53b654801_basic  \Big ( L ^ { \frac { 3 } { 2 } } \Big ) _ { + } = p ^ { 3 } + \frac { 3 } { 2 } u \star p - \fra...
# 152     63e9d32b8731d87_basic.png  63e9d32b8731d87_basic  Q _ { a , b } ( \mu , \nu ; N ) = p _ { a , b } ( \mu , \nu ; 0 ; N ) + \sum _ { \lambda = 1 } ^...
# 153     bb5916e100f64d1_basic.png  bb5916e100f64d1_basic  \vec { A } _ { \mu } ( x ) \! = \! \partial _ { \mu } \vec { n } ( x ) \wedge \vec { n } ( x ) +...
# 154     e28f42360e7e705_basic.png  e28f42360e7e705_basic  { \cal E } = \frac { { \bf D } ^ { 2 } + { \bf H } ^ { 2 } } { 2 } - \left( { \bf \theta } \cdot...
# 155     1794ddd75c0724e_basic.png  1794ddd75c0724e_basic  \frac 1 { \nabla ^ { 2 } } \, \delta _ { \Sigma } ^ { ( 2 ) } ( z - z _ { 0 } ) = - \frac 1 \pi ...
# 156     8dc02b65fac3e7a_basic.png  8dc02b65fac3e7a_basic     \delta _ { A } \widehat { \phi } \smallskip ( \widehat { x } ) = i [ \widehat { A } \smallskip ,
# 157     21e211c401fdd97_basic.png  21e211c401fdd97_basic  { \cal M } = M ( \infty ) = 4 \pi \int _ { 0 } ^ { \infty } \left[ r ^ { 2 } \left( { \cal U } (...
# 158     2d879f1f18ac63d_basic.png  2d879f1f18ac63d_basic  y \sqrt { c } \operatorname { s i n h } \alpha = \operatorname { c o s h } \alpha - \operatornam...
# 159     3dd6b36fabca502_basic.png  3dd6b36fabca502_basic                    \lambda t K _ { \left| n \right| } ( \mu t ) I _ { \left| n \right| } ( \mu t ) .
# 160     f1541f5a3783fff_basic.png  f1541f5a3783fff_basic  g x ( \alpha \cdot q , \xi ) \to \left\{ \begin{array} { c l } { \mathrm { f i n i t e } , } & {...
# 161     a13e36e878a3d74_basic.png  a13e36e878a3d74_basic      r _ { h } ^ { 2 } = \frac { l ^ { 2 } } { 2 } ( \sqrt { K ^ { 2 } + 4 l ^ { - 2 } \mu } - K ) .
# 162     c9ede5b4cecf2f1_basic.png  c9ede5b4cecf2f1_basic  \dot { G } _ { \pm } + \frac { i } { 2 } \phi ^ { \pm } D _ { \pm } ^ { 2 } G _ { \pm } + \frac ...
# 163     fb8969f2c32d4dd_basic.png  fb8969f2c32d4dd_basic  \mathcal { L } = \sum _ { i = 1 } ^ { N } \bar { \psi } ^ { i } \left( \partial \! \! \! \slash ...
# 164     77ea86127d40f77_basic.png  77ea86127d40f77_basic  \left\langle \operatorname { e x p } \left( \; 2 \sum _ { b = 1 } ^ { N } \beta ^ { ( b ) } \int...
# 165     cdd2517e91b019b_basic.png  cdd2517e91b019b_basic                           \chi _ { a } ( A ) = \varepsilon _ { a b i } \, A _ { b i } ( x ) = 0 \, ,
# 166     eee297ada10378b_basic.png  eee297ada10378b_basic           \omega ( \varepsilon ) = { \frac { e ^ { \beta _ { H } \varepsilon } } { \varepsilon } } ,
# 167     889b09d3c08df42_basic.png  889b09d3c08df42_basic   G ^ { ( N , M ) } ( z _ { 1 } , S _ { M + 1 } , \cdots , S _ { N } ; z _ { 1 } , z _ { 2 } ) = 0 .
# 168     44e2e0c7013a47c_basic.png  44e2e0c7013a47c_basic  P ^ { 2 } = \bigg ( \frac { 4 } { \pi h ^ { 2 } N } \bigg ) ^ { 2 } \bigg [ 1 + O \bigg ( \frac ...
# 169     26e4992855477b8_basic.png  26e4992855477b8_basic                       \varphi \sim A + B \mathrm { s i g n } ( t ) | \vec { k } t | ^ { \epsilon } .
# 170     b7a8a4f6ad09a73_basic.png  b7a8a4f6ad09a73_basic               \stackrel { \rightarrow } { x } ( \tau ) = m ^ { - 2 } \stackrel { \rightarrow } { V }
# 171     315db5caab32dfd_basic.png  315db5caab32dfd_basic  R _ { i j , k l } = \delta _ { i k } \delta _ { j l } ( 1 + \delta _ { i j } ( q - 1 ) ) + \lamb...
# 172     091fae7ba734138_basic.png  091fae7ba734138_basic  S = - T _ { ( p - 1 ) } \int d ^ { p } \sigma \sqrt { - \operatorname* { d e t } ( \mathcal { G ...
# 173     35bc11224a856ca_basic.png  35bc11224a856ca_basic  S _ { p , m } = \prod _ { A < B } \prod _ { I < J } ( z _ { I } ^ { A } - z _ { J } ^ { B } ) ^ ...
# 174     eb9c9dcbcae4e0a_basic.png  eb9c9dcbcae4e0a_basic  H _ { L C } = \int _ { 0 } ^ { l } \mathcal { H } _ { L C } = \int _ { 0 } ^ { l } d \sigma \, \...
# 175     cd25809bae07bc8_basic.png  cd25809bae07bc8_basic      { \theta _ { n } ^ { \alpha \Lambda } } { ^ \dagger } = \theta _ { - n } ^ { \alpha \Lambda } ,
# 176     d0af5fd68e3e916_basic.png  d0af5fd68e3e916_basic  \frac { d \, \operatorname { l o g } \widetilde \mathcal { P } _ { \{ N _ { \nu _ { \alpha _ { 1...
# 177     6b787086f28f280_basic.png  6b787086f28f280_basic  a _ { M } = { \frac { ( - ) ^ { { \frac { 1 } { 2 } } M ( M + 1 ) } } { M ! [ ( M - 1 ) ! \ldots...
# 178     6a5c89b3194c17b_basic.png  6a5c89b3194c17b_basic  { \cal H } ( p ) = - 2 i \varepsilon ^ { \mu \nu \rho } \varepsilon ^ { \alpha \beta \lambda } g...
# 179     28910a77d8077ba_basic.png  28910a77d8077ba_basic  d T ( x ) = \left( \begin{array} { c c } { \delta ( x ) 1 _ { N - k } } & { 0 } \\ { 0 } & { - \...
# 180     d73d9e3fbb8dc8f_basic.png  d73d9e3fbb8dc8f_basic  { \cal S } ^ { \mu \nu } \equiv \epsilon ^ { \mu \nu \rho \sigma } \theta _ { \rho } P _ { \sigm...
# 181     945a7ff11464f4d_basic.png  945a7ff11464f4d_basic  \mathrm { T r } _ { N S - R } = \frac { V _ { 0 } } { 2 \pi } \int \d E \, \sum _ { m = 0 } ^ { ...
# 182     f27a8f59d5775de_basic.png  f27a8f59d5775de_basic                                            R _ { \mu \nu } - \frac { 1 } { 2 } R g _ { \mu \nu } = 0
# 183     4764a0ae7f6e8d5_basic.png  4764a0ae7f6e8d5_basic  { \frac { \alpha } { p ( N ) } } \ \left( { \frac { 1 } { c ( N ) } } - 1 \right) \approx { \fra...
# 184     c7b7c6171f005f1_basic.png  c7b7c6171f005f1_basic  { \cal W } ^ { ( 1 ) } = { \frac { 1 } { { \cal Z } ^ { ( 1 ) } N } } \sum _ { R , S } \frac { d...
# 185     01c7a43690e7659_basic.png  01c7a43690e7659_basic  A _ { p a r e n t } ^ { \mathrm { I V } } = - \frac { T _ { p } } { 2 } \int d ^ { p + 1 } { \xi...
# 186     0fe1619fc5d3fdf_basic.png  0fe1619fc5d3fdf_basic  F ( z ) \; = \; F ( 0 ) \, + \, \sum _ { m = 1 } ^ { \infty } \, \left\{ \frac { b _ { m } } { z...
# 187     0004c78cdb20d64_basic.png  0004c78cdb20d64_basic  \{ Q ^ { \alpha } , \bar { Q } _ { \beta } \} = - i ( \Gamma ^ { a } ) _ { \beta } ^ { \alpha } ...
# 188     2d85f387bea21f9_basic.png  2d85f387bea21f9_basic   \left[ Q _ { \bar { \theta } } , Q _ { \bar { \theta } } \right] _ { + } = ( - \frac { 5 } { 3 2 }
# 189     722d9f375701433_basic.png  722d9f375701433_basic  \frac { \xi } { \sqrt { 1 - \dot { r } ^ { 2 } } } = \sqrt { x _ { 1 } ^ { 2 } + x _ { 2 } ^ { 2...
# 190     8a5c4dbd83e4729_basic.png  8a5c4dbd83e4729_basic  \left( A _ { 0 } , A _ { 1 } , \phi , \pi _ { 0 } , \pi _ { 1 } , \pi _ { \phi } \right) \longle...
# 191     7d4f96c5d6505fa_basic.png  7d4f96c5d6505fa_basic           E ( L ) - E _ { 0 } ( L ) = E _ { R } + E _ { L } + M \operatorname { c o s h } \theta \ ,
# 192     edef6c6066577cd_basic.png  edef6c6066577cd_basic  v _ { e f f } = \left( { \frac { y _ { i } } { y _ { 0 } } } + 1 \right) ^ { 1 / 3 } e ^ { - n }...
# 193     81ab285388770e3_basic.png  81ab285388770e3_basic  \Pi _ { \mu \nu \rho \sigma } ^ { r } ( p , q , k ) = \Pi _ { \mu \nu \rho \sigma } ( p , q , k ...
# 194     a2c06a645feb80b_basic.png  a2c06a645feb80b_basic  \frac { t } { d } = \oint \frac { d z } { 2 \pi \imath } U _ { e f f } ^ { \prime } \left( z + \...
# 195     0e9caf9dc106cbf_basic.png  0e9caf9dc106cbf_basic  w : = \left( \begin{array} { c } { \tilde { x } _ { 1 } } \\ { . } \\ { . } \\ { . } \\ { \tilde...
# 196     fc9931c3c441d93_basic.png  fc9931c3c441d93_basic  p _ { \nu } ^ { \prime } T _ { \mu \nu } ^ { S \rightarrow A A } = 2 m i [ T _ { \mu } ^ { S \ri...
# 197     afa483102132c93_basic.png  afa483102132c93_basic  \sum _ { j = 1 } ^ { n } [ I _ { i j } ] _ { \hat { q } } \, m _ { j } = 2 \operatorname { c o s...
# 198     f68d5c233fd4e78_basic.png  f68d5c233fd4e78_basic  { \tilde { f } } ^ { ( 0 ) } = \left( \begin{array} { c c c c c c } { 0 } & { - 1 } & { 0 } & { ...
# 199     21897d253c8b3f8_basic.png  21897d253c8b3f8_basic  W ^ { a } = \frac { 1 } { I E } \big ( | Z | ^ { 2 } H ^ { a } - A ^ { a } A _ { b } H ^ { b } +...
# 200     40a03d14c697f72_basic.png  40a03d14c697f72_basic  \Delta + \bar { \Delta } = \frac { ( m + n k / 4 ) ^ { 2 } } { k } + \frac { ( m - n k / 4 ) ^ {...
# 201     ddbdd677697885f_basic.png  ddbdd677697885f_basic  \Delta _ { a } ^ { \! l i n } = - \int \frac { k ^ { \prime } } { 2 l } \, d l - \frac { 1 } { 2...
# 202     980d6923b7cc68c_basic.png  980d6923b7cc68c_basic  \Sigma _ { - } = a _ { 1 } ( x ) \operatorname { e x p } { ( 3 ( \gamma - 1 ) \tau ) } , ~ ~ \Si...
# 203     c41b1392a9ebc34_basic.png  c41b1392a9ebc34_basic  \left[ \widehat { x } _ { 0 } , \widehat { x } _ { i } \right] = { \frac { i } { \kappa } } \wid...
# 204     d0d6d93acd6e1d2_basic.png  d0d6d93acd6e1d2_basic  \begin{array} { l l l l l l } { \displaystyle D } & { = 3 } & { : \quad } & { S p ( 4 ; R ) } & ...
# 205     0c257cb81a2ae4d_basic.png  0c257cb81a2ae4d_basic  S _ { E } = \int _ { 0 } ^ { \tau } d \tau \left( { \frac { 1 } { 2 } } x _ { \tau } ^ { 2 } + {...
# 206     c468e638b7eb300_basic.png  c468e638b7eb300_basic  \int _ { 0 } ^ { \infty } d k \sqrt { k ^ { 2 } + 4 } \left( \frac { 4 \operatorname { c o s } \...
# 207     6ac36a0c1aefe5a_basic.png  6ac36a0c1aefe5a_basic  \displaystyle { \frac { 8 } { \kappa } } V _ { \mu \nu , \, \alpha \beta } ^ { ^ 2 g h o s t } (...
# 208     076d12a4cb5ed5c_basic.png  076d12a4cb5ed5c_basic                          \left( 1 + i \gamma \right) ^ { - 1 } \approx \left( 1 - i \gamma \right) .
# 209     2055dc0fef44262_basic.png  2055dc0fef44262_basic                                                                                   { \cal P } : \quad
# 210     8364ac8a9824e43_basic.png  8364ac8a9824e43_basic  M = \int _ { r \rightarrow \infty } d ^ { p } x r ^ { p / 2 } f ^ { - 1 / 2 } T _ { t t } = \fra...
# 211     88a5f506a2d1b5e_basic.png  88a5f506a2d1b5e_basic  ( \Delta S ) ^ { 0 } = T r \left[ \left( \begin{matrix} { K ^ { \mu } { } _ { \nu } } & { K ^ { ...
# 212     2479b2a95faaeb5_basic.png  2479b2a95faaeb5_basic      j _ { H W } ( x ) = W _ { i } ( x ) T ^ { i } \; , \; T ^ { i } \in k e r ( A d ( M _ { - } ) )
# 213     dc372cfdaa1f884_basic.png  dc372cfdaa1f884_basic  [ \Pi ( { \bf { x } } \sigma ) , \rho ( { \bf { y } } \sigma ^ { ' } ) ] = i \mathrm { ~ } \delt...
# 214     d32138c5f2011dc_basic.png  d32138c5f2011dc_basic  E ^ { ( R ) } = { \frac { n _ { R } } { | G | } } \sum _ { g \in G } \chi ^ { ( R ) } ( g ) U ( ...
# 215     6112f34b33a34ce_basic.png  6112f34b33a34ce_basic  E _ { \small C a s i m i r } ^ { \small b u l k } = { \frac { 1 } { 8 \pi ^ { 2 } } } \; V \; \h...
# 216     3c4a88d30f69553_basic.png  3c4a88d30f69553_basic  H _ { 0 } = \int _ { 0 } ^ { \infty } d p \, p [ A ^ { \dag } ( p ) A ( p ) - B ^ { \dag } ( p )...
# 217     b113be8ed2bd241_basic.png  b113be8ed2bd241_basic  \Omega ^ { J } \equiv ( v _ { i } ^ { J } ) ^ { T } \frac { \partial V ( q ) } { \partial q _ { ...
# 218     194c8a052a89b03_basic.png  194c8a052a89b03_basic  \frac { 1 } { 2 } \left( 1 + \sqrt { \frac { j \left( j + 1 \right) - \alpha ^ { 2 } } { 4 } } \...
# 219     81251688d24098b_basic.png  81251688d24098b_basic  \{ Q ^ { + } , Q ^ { - } \} = H _ { n } + k ( R - 1 ) , \quad [ H _ { n } , Q ^ { \pm } ] = \mp ...
# 220     1d3d1ea941915ae_basic.png  1d3d1ea941915ae_basic  \frac { \partial g _ { k } } { \partial x _ { j } } = \frac { \partial h _ { k } } { \partial y ...
# 221     7b4b7905f5cf745_basic.png  7b4b7905f5cf745_basic  { \cal D } [ \partial ] : = 1 + { \frac { \partial ^ { 2 } } { \eta ^ { 2 } } } - { \frac { \par...
# 222     a77d4dd557de727_basic.png  a77d4dd557de727_basic  Z _ { 0 } ^ { F } ( T , L ) \equiv \operatorname { e x p } \left( \frac { \pi L T } { 6 } \right) .
# 223     52281dcabbc98d2_basic.png  52281dcabbc98d2_basic                                          x \mapsto \omega ( \Xi ) ( x ) , \quad \ x \in { \cal O } ,
# 224     6354f3c230d6413_basic.png  6354f3c230d6413_basic  \left. \begin{array} { l } { \rho ( 1 ) = 1 } \\ { \rho ( 2 ) = 2 } \\ { \ldots } \\ { \rho ( p ...
# 225     aecdacec7d5bc76_basic.png  aecdacec7d5bc76_basic  S ^ { \mu \nu } \equiv { \frac { \partial L } { \partial \sigma _ { \mu \nu } } } = L ^ { - 1 } ...
# 226     2397cef622bdda1_basic.png  2397cef622bdda1_basic  H = 1 + Q _ { 1 } \sum _ { n = - \infty } ^ { \infty } \frac { 1 } { \mid \vec { y } - 2 \pi n a...
# 227     dc0fc847934d29c_basic.png  dc0fc847934d29c_basic  z ( \varepsilon , \tau ) \; = \; u \: + \: 2 \tau v \: + \: ( 1 - \varepsilon ^ { 2 } ) \: \tau ...
# 228     4557772c69150ac_basic.png  4557772c69150ac_basic  V ( \Phi ) = - m ^ { 2 } \mathrm { T r } [ \Phi ^ { 2 } ] + h ( \mathrm { T r } [ \Phi ^ { 2 } ]...
# 229     2836f0e9a7e0141_basic.png  2836f0e9a7e0141_basic                                           g \approx 3 - \sqrt 3 - 0 . 9 1 7 7 f _ { 0 } ^ { 2 } \; .
# 230     bd4359da321c590_basic.png  bd4359da321c590_basic  \hat { g } = - ( d x ^ { 0 } ) ^ { 2 } + ( d x ^ { 1 } ) ^ { 2 } + \Big ( d r ^ { 2 } + r ^ { 2 ...
# 231     4b24e7ebf49319b_basic.png  4b24e7ebf49319b_basic  \varepsilon ( p ^ { 0 } ) = \theta ( p ^ { 0 } ) - \theta ( - p ^ { 0 } ) = \frac { p ^ { 0 } } ...
# 232     ae39a4135242426_basic.png  ae39a4135242426_basic  \tilde { \omega } _ { m a b } = \hat { \omega } _ { m a b } - \frac { i \kappa ^ { 2 } } { 4 } \...
# 233     9bf0532ea268167_basic.png  9bf0532ea268167_basic                             s p ^ { \mu } = \eta ^ { \alpha } e _ { \alpha } ^ { \mu } ( P _ { 0 } )
# 234     63c001a98f08d02_basic.png  63c001a98f08d02_basic  q ^ { ( \frac { L } { 2 } - \frac { r } { N } ) } \sum _ { k = l + 1 } ^ { N } q ^ { - m _ { 0 }...
# 235     81a9cccd63bbd68_basic.png  81a9cccd63bbd68_basic  ( - 1 ) ^ { m \cdot | a | } [ a , b \cup c ] = [ a , b ] \cup c + ( - 1 ) ^ { ( | b | \cdot | c ...
# 236     7b72db03aa561a3_basic.png  7b72db03aa561a3_basic  [ \Phi ( x ; a _ { 1 } , . . . , a _ { n } ) ] _ { R } = \Phi ( x ; a _ { 1 } , . . . , a _ { n ...
# 237     91c3fd16c61dd02_basic.png  91c3fd16c61dd02_basic  Z = { \operatorname* { d e t } } _ { T } ^ { - \frac 1 2 } ( - \Delta ) \times { \operatorname* ...
# 238     6955b58fe812045_basic.png  6955b58fe812045_basic                        \Omega ( z ) = \int _ { \c C } d w \rho ( w ) \operatorname { l n } ( z - w )
# 239     80b83eb06ddaef0_basic.png  80b83eb06ddaef0_basic  \mathbf { J } ^ { 2 } = ( \mathbf { J } ^ { 2 } ) ^ { \dagger } = G ( \mathbf { J } ^ { 2 } ) ^ ...
# 240     92b3138bb662468_basic.png  92b3138bb662468_basic  m ^ { 1 ; 1 ; 9 } , \ m ^ { 1 ; 4 ; 9 } , \ m ^ { 2 ; 6 ; 9 } , \ m ^ { 4 ; 7 ; 9 } , \ m ^ { 7 ...
# 241     741bd8e741dfbe0_basic.png  741bd8e741dfbe0_basic                           E _ { \pm } \approx \pm m e ^ { - \frac { \mu ^ { 2 } } { m } \Delta x } .
# 242     9a8c069fe4f1442_basic.png  9a8c069fe4f1442_basic  M ( S , R ) _ { n } = \left( \begin{matrix} { 1 } & { 0 } \\ { 1 } & { 1 } \\ \end{matrix} \righ...
# 243     069391f94941c3d_basic.png  069391f94941c3d_basic  C _ { \mu } ^ { + } \equiv \frac { 1 } { 2 } ( C _ { \mu } + ^ { * } C _ { \mu } ) = \frac { 1 }...
# 244     2cdb9cada9254ae_basic.png  2cdb9cada9254ae_basic  \left[ - \left( 1 - \frac { 2 M } { \rho } \right) \frac { d ^ { 2 } } { d \rho ^ { 2 } } - \fra...
# 245     6218b1d06fa3467_basic.png  6218b1d06fa3467_basic  G _ { \alpha \beta } ( \tau , \tau ^ { \prime } ) = \frac { 1 } { 2 } \int \Sigma _ { \alpha \be...
# 246     59997059f26b61b_basic.png  59997059f26b61b_basic  \gamma _ { 1 } = - \gamma - 1 - \gamma ( - 2 - a - b ) - \delta ( 2 - a / \delta - b / \delta - ...
# 247     c844d4d6a91f23f_basic.png  c844d4d6a91f23f_basic  j ^ { m i } \equiv \frac { \delta I _ { S I } } { \delta v _ { m } ^ { i } } , \quad K ^ { m i }...
# 248     7d0b396f1178b88_basic.png  7d0b396f1178b88_basic  [ \hat { x } _ { \mu } , \hat { x } _ { \nu } ] = \frac { i } { \kappa } ( a _ { \mu } \hat { x ...
# 249     3c68230cb432721_basic.png  3c68230cb432721_basic  G _ { \mu \nu } ^ { 0 } = \frac { \epsilon _ { \mu \nu \lambda } p _ { \lambda } + \delta _ { \m...
# 250     8293a4fcb72d6f1_basic.png  8293a4fcb72d6f1_basic    \left\{ Q _ { a } , Q _ { b } \right\} _ { { \footnotesize P B } } = f _ { a b c } Q _ { c } \; ,
# 251     b42c7d438ea8add_basic.png  b42c7d438ea8add_basic          U ( \vec { x } ) = { \mathrm e } ^ { { \mathrm i } \hat { r } \cdot \vec { \tau } f ( r ) }
# 252     7b9497b86fd008b_basic.png  7b9497b86fd008b_basic  A d j ( S p ( 2 n _ { H } ) ) \to A d j ( U ( k ) ) + A d j ( U ( n _ { H } - k ) ) + 2 ( k , n ...
# 253     9544c775a8e3c1f_basic.png  9544c775a8e3c1f_basic  C _ { 0 } ( k , q ) = < k , q | \sum _ { j = 0 } ^ { m - 1 } R ^ { - j } \omega ^ { j s } | \phi...
# 254     b7c2edd8764d8a3_basic.png  b7c2edd8764d8a3_basic                    G ^ { \dagger } = G , \; \; \; \; \; \; \tilde { G } ^ { \dagger } = \tilde { G }
# 255     176ee1a5990b382_basic.png  176ee1a5990b382_basic  I _ { n } ( x ) = \int _ { 0 } ^ { x } d x _ { n } \int _ { 0 } ^ { x _ { n } } d x _ { n - 1 } ...
# 256     e67b5a15b2c0ae3_basic.png  e67b5a15b2c0ae3_basic  N ^ { \mu \nu } = L ^ { i } n ^ { [ \mu } { } _ { i } X ^ { \nu ] } { } ^ { \prime } = L ^ { * }...
# 257     58046e2992179dc_basic.png  58046e2992179dc_basic  X ^ { + } = { \frac { * ( 2 { \cal D } X ^ { i } \wedge f ^ { + i } ) } { * ( f ^ { + i } \wedge...
# 258     6cb03e6e5c3ef32_basic.png  6cb03e6e5c3ef32_basic                                            T ( z ) = L ^ { a b } : J _ { a } ( z ) J _ { b } ( z ) :
# 259     41a5542ed0632e1_basic.png  41a5542ed0632e1_basic  R ( b ) = \frac { 4 } { k - 2 } \; \frac { k ( k - 4 ) + k ( k - 2 ) b } { [ k + 2 + ( k - 2 ) b...
# 260     33f2bc5c4679661_basic.png  33f2bc5c4679661_basic                          n ! \prod _ { i = 1 } ^ { k } d _ { i } ! { \frac { 1 } { ( n - m ) ! } } .
# 261     3cc03fc25786590_basic.png  3cc03fc25786590_basic  [ R , M ] = - \mathrm { \frac { i } { 2 } } \sum _ { \rho \in \Delta _ { + } } g _ { | \rho | } ...
# 262     b45d9f1c54cb615_basic.png  b45d9f1c54cb615_basic       D ^ { + + } L ^ { + + } = 0 \quad \Leftrightarrow \quad ( D ^ { -- } ) ^ { 3 } L ^ { + + } = 0
# 263     e52b0fd78ca082d_basic.png  e52b0fd78ca082d_basic                 l n d e t = \frac { | e \Phi | } { 2 \pi } \operatorname { l n } ( m a ) + R ( m ) ,
# 264     3eccb134cbc087a_basic.png  3eccb134cbc087a_basic                            B ( 0 ) = B _ { \mathrm { f } } ( 0 ) + B _ { \mathrm { b } } ( 0 ) = 0 ,
# 265     5917e3566f375e7_basic.png  5917e3566f375e7_basic                         H \, { \cal U } = i { \frac { \partial } { \partial t } } \, { \cal U } \, ,
# 266     5326fbe99a37c80_basic.png  5326fbe99a37c80_basic  \Sigma _ { \pm } ( q _ { 3 } , \left| { \bf q } \right| ) = - \frac { 1 } { 4 \pi } \operatornam...
# 267     ba734be0e9a08b0_basic.png  ba734be0e9a08b0_basic  \frac { g _ { Y M } ^ { 2 } N } { J ^ { 3 } } \frac { J ^ { 4 } } { N ^ { 2 } } \frac { g ^ { 2 ...
# 268     b132c4e4a23fd60_basic.png  b132c4e4a23fd60_basic  { \cal L } _ { n } ( H _ { n } ) = ( - T _ { H _ { n } } \bar { R } _ { H _ { n } } ) \phi ^ { n...
# 269     80efe639716119d_basic.png  80efe639716119d_basic  { \delta _ { \rho } } { \mathcal { F } _ { D } ^ { 1 } } = { \delta _ { \rho } } { \mathcal { F ...
# 270     3cd5d5313b0277e_basic.png  3cd5d5313b0277e_basic  D \sum _ { I \neq J } ( - 1 ) ^ { p _ { I } p _ { J } } e _ { J I } \otimes e _ { I J } D ^ { - ...
# 271     758a0341525bc53_basic.png  758a0341525bc53_basic             H ( t ) | n ; t > = E _ { n } ( t ) | n ; t > , ~ ~ < m ; t | n ; t > = \delta _ { m n }
# 272     d18e672516e3d9b_basic.png  d18e672516e3d9b_basic     E _ { c } = \frac { 4 k l } { R } \left( k - \frac { r _ { + } ^ { 2 } } { l ^ { 2 } } \right) ,
# 273     7b84eff23aae811_basic.png  7b84eff23aae811_basic         P \sim \operatorname { e x p } \left( - y _ { 0 } ^ { 3 } / M _ { p } ^ { 2 } \ell \right) ,
# 274     a122715475c076c_basic.png  a122715475c076c_basic  \tilde { W } [ \eta | t ] = \int _ { \eta _ { 0 } } ^ { \eta ( t ) } \delta \eta ^ { ' \nu } ( t...
# 275     ce634f84753d72a_basic.png  ce634f84753d72a_basic  \partial _ { z } \partial _ { \bar { z } } \theta = \{ n ( n + 1 ) \eta ^ { 2 } + a \} \theta \,...
# 276     eb294b4fbdd55fb_basic.png  eb294b4fbdd55fb_basic  C _ { 0 } ^ { o p } = g _ { o } ^ { - 2 } \frac { 1 } { \left( 2 \alpha ^ { ^ { \prime } } \righ...
# 277     013898680b64ac3_basic.png  013898680b64ac3_basic                \alpha ^ { 2 } \partial _ { x ^ { - } } ^ { 3 } g _ { a } ( x ) = 0 ~ ; \alpha \neq 0
# 278     f6021eadddc9e8b_basic.png  f6021eadddc9e8b_basic  J _ { g f } = \left( \begin{array} { c c } { 0 } & { J _ { + } } \\ { 1 } & { 0 } \\ \end{array}...
# 279     5ec2e76aba6c849_basic.png  5ec2e76aba6c849_basic  Z ^ { i n t } ( s ) = \int { \cal D } A _ { \mu } ~ e ^ { - S _ { b o s } ( A ) - i \int d ^ { 3...
# 280     ae41ae5d0dbf1ff_basic.png  ae41ae5d0dbf1ff_basic                                     \hat { \Gamma } _ { 0 } \ldots \hat { \Gamma } _ { ( 1 0 ) } = 1
# 281     5f4adf12bbcec7d_basic.png  5f4adf12bbcec7d_basic             { \cal L } = - V ( T ) \sqrt { - \operatorname* { d e t } ( g + F ) } { \cal F } ( z ) ,
# 282     1f75d616bcc095f_basic.png  1f75d616bcc095f_basic  W _ { \infty } ^ { 3 , D } = { \frac { 1 } { 1 6 } } ( 1 - \gamma ) ^ { - 1 } \sum _ { k = 0 } ^...
# 283     54622e9f03757ae_basic.png  54622e9f03757ae_basic  \begin{array} { c } { \left\{ M _ { 1 } , M _ { 2 } \right\} = a M _ { 1 } M _ { 2 } - M _ { 1 }...
# 284     4d58e563e243b4d_basic.png  4d58e563e243b4d_basic            B ( T ) = - \; { \frac { b _ { 2 } ( V , T ) } { [ b _ { 1 } ( V , T ) ] ^ { 2 } } } \; ,
# 285     d506cfef521f9c9_basic.png  d506cfef521f9c9_basic            \epsilon _ { \mathrm { v a c } } = \left< \frac { \beta ( g ) } { 8 g } G \cdot G \right>
# 286     438572fb5ac8a07_basic.png  438572fb5ac8a07_basic              { \cal H } = { \cal H } _ { a } \otimes { \cal H } _ { A } \otimes { \cal H } _ { c } .
# 287     95c4ac5db4fd231_basic.png  95c4ac5db4fd231_basic  H r ( \tau ) = \frac { k } { \sqrt { 1 + k ^ { 2 } } } \mid \mathrm { s n } [ \frac { \tau } { \...
# 288     ca42b642e77b66a_basic.png  ca42b642e77b66a_basic  \delta _ { \beta } \left( \alpha \right) = \alpha \wedge \beta = \alpha _ { a b } \cdot \beta _ ...
# 289     3a2a863334f60d5_basic.png  3a2a863334f60d5_basic                   T \sim \frac { m } { L ^ { p } } \sim \frac { 1 } { g \ell _ { s } ^ { p + 1 } } .
# 290     ea6328fd686c5b6_basic.png  ea6328fd686c5b6_basic  ( - 1 ) ^ { | X | | Z | } [ X , [ Y , Z ] ] + ( - 1 ) ^ { | X | | Y | } [ Y , [ Z , X ] ] + ( - ...
# 291     81fe7d3cfd2c49b_basic.png  81fe7d3cfd2c49b_basic  { \cal M } _ { b } ^ { u u } = \frac { i g ^ { 4 } } { 2 } [ T ^ { a } T ^ { b } \otimes T _ { a...
# 292     f5f3a617847b66d_basic.png  f5f3a617847b66d_basic  \int _ { C } \frac { d \nu \: \nu } { i 4 \sqrt { 2 } \operatorname { s i n } \pi \nu } \left[ J...
# 293     dc00068cf525ba3_basic.png  dc00068cf525ba3_basic  \frac { 1 } { 2 } \int d ^ { 2 } x \; \mathrm { T r } ( \partial _ { + } \Phi \partial _ { - } \...
# 294     636d5a9bc527fb1_basic.png  636d5a9bc527fb1_basic  C \, = \, \mu _ { \mathrm { I I } } ( \eta _ { 2 } ) \frac { \vert \eta _ { 2 } \vert } { l _ { ...
# 295     13ace3a301e61fc_basic.png  13ace3a301e61fc_basic  \zeta _ { 0 } ( \nu ) = - { \frac { \nu \varrho ^ { - 2 \nu } } { \pi } } \int _ { \mu } ^ { \in...
# 296     94e92d17476dc4c_basic.png  94e92d17476dc4c_basic                                                                    \Psi = { C } \Psi ^ { \ast } \, .
# ...
# 100597           89      34    484            2 \Omega = - 5 ( z _ { 1 } + z _ { 2 } ) , \quad 2 \Omega _ { 0 } = z _ { 1 } - z _ { 2 }               89
# 100598          316      80    949  \Psi _ { \kappa } ^ { ( P ) } = \frac { i } { 2 ^ { 3 / 2 } } \, \operatorname { e x p } \left( ...              316
# 100599          149      61    758  F ( r ) \equiv - A ^ { 2 } r ^ { 2 } \, G ( - 1 / A r ) = ( 1 - \frac { r _ { - } } { r } ) ( 1 ...              149
# 100600          369      80   1027  S _ { B H } = \frac { 2 \pi A _ { 9 } } { \kappa ^ { 2 } } = \frac { 2 \pi A _ { 2 } } { \kappa ...              369
# 100601          337      98    896  F ( x ^ { + } , x ^ { - } , 0 ) = \frac { 1 } { 2 \pi } \sum _ { K , N _ { \perp } , \alpha } \f...              337
# 100602          177      68    676  { \cal W } = { \cal W } _ { \mathrm { h a r m o n i c } } + \frac { 1 } { 2 } \, \mu \, \phi _ {...              177
# 100603           98      74    414   S = \int d ^ { 2 } x \, [ e ^ { \lambda } \nabla ^ { 2 } \sigma - e ^ { \sigma } V ( \lambda ) ] .               98
# 100604          295      40   1018  d s _ { \mathrm { C F T } } ^ { 2 } = \gamma _ { a b } d x ^ { a } d x ^ { b } = - r _ { + } ^ {...              295
# 100605          446     143    701  \begin{array} { l c l } { p ~ \partial _ { \sigma } V ^ { ( J ) } } & { = } & { { \displaystyle ...              446
# 100606          157      60    732  \hat { A } _ { \mu } ( z , - \kappa ) = U ^ { - 1 } ( z ) \left( \partial _ { \mu } + \hat { A }...              157
# 100607          201      68   1019  V ( A ) = V ( A _ { 0 } ) + V ^ { \prime } ( A _ { 0 } ) ( A - A _ { 0 } ) + \frac { 1 } { 2 } V...              201
# 100608           98      39    498   \tau = \sqrt { 2 } \operatorname { l o g } ( 1 + \sqrt { 2 } ) , \; \; \; H T _ { - } = - \infty ,               98
# 100609          143      35    740  X _ { R } ^ { \mu } ( \tau - \pi ) = X _ { L } ^ { \mu } ( \tau + \pi ) \mathrm { ~ ~ ~ ~ ~ ~ ~ ...              143
# 100610          269     100    875  { \cal S } _ { E } = \frac { \pi } { 4 } \tau \nu \sum _ { n = 0 } n ^ { 2 } X _ { n 0 } ^ { 2 }...              269
# 100611          142      47    491  { \cal P } _ { A } ^ { ( 2 \nu ) B } ( x ) \equiv \left[ U ^ { \dagger } ( x ) \, h ^ { ( 2 \nu ...              142
# 100612          118      86    357  { \cal T } _ { p } ^ { s } = \prod _ { r \in P } \frac { 1 } { ( k _ { p } ^ { s } - p _ { r } )...              118
# 100613          115      76    351  e ^ { A } = \frac { 6 c } { { \sqrt { - \Lambda } } } \frac { 1 } { \operatorname { s i n h } c ...              115
# 100614          127      36    380  \bar { H } _ { d } = i \bar { \gamma _ { 0 } } ( \bar { \gamma } ^ { a } \bar { \nabla } _ { a }...              127
# 100615          279     100    904  { \vec { f } } _ { i } ( x ) = \sum _ { j = 1 } ^ { N } \, \sum _ { k = 1 } ^ { n } \, \left( 1 ...              279
# 100616          166      80    558  E = 2 m + \frac { 1 } { 4 \pi } \operatorname { l n } m + \frac { 1 } { 2 \pi } \left( \lambda -...              166
# 100617          103      79    341  \beta _ { B o l t } = \frac { 7 0 \pi ( r _ { b } ^ { 2 } - N ^ { 2 } ) ^ { 5 } \ell ^ { 2 } } {...              103
# 100618          110      68    326  L = \frac { 1 } { 2 A ^ { 2 2 } } \dot { x } ^ { \mu } \dot { x } ^ { \nu } g _ { \mu \nu } \lef...              110
# 100619           75      73    253                          E _ { i } \ge \frac { m N _ { i } ( v _ { i } ^ { C M } ) ^ { 2 } } { 2 } .               75
# 100620          175      77    456  H _ { \infty } ^ { 2 } \equiv \frac { \kappa _ { 4 } ^ { 2 } } { 3 } \, \Lambda _ { 4 } < \frac ...              175
# 100621          198      81    762  S ( q < 1 ) \approx \lambda k ^ { 2 } \sqrt { \mu _ { 0 } } T \left[ 1 . 0 8 ( q ^ { 3 } + 1 ) -...              198
# 100622          285      75   1033  N \mu ^ { - 1 } ( \sum _ { i } V ( \lambda _ { i } ) ) + \sum _ { i < j } [ - 2 \operatorname { ...              285
# 100623          169      83    577  \int _ { K _ { - } } ^ { K _ { + } } d K \operatorname { l o g } K \left[ 8 \pi i K - 3 k _ { 0 ...              169
# 100624          135      80    324  \psi _ { 2 k } = \left\{ \begin{array} { l l } { \mathrm { c o n s t . } } & { k = 3 } \\ { 0 } ...              135
# 100625          151      75    480  A = \frac { 1 } { g } ( 1 + \omega ) [ - \widehat \tau _ { \varphi } d \theta + \widehat \tau _ ...              151
# 100626          103      93    370  Z ( x ) = 2 ^ { 8 } \prod _ { n } \left( \frac { 1 + x ^ { n } } { 1 - x ^ { n } } \right) ^ { 8...              103
# 100627           82      80    243                   \nu ^ { 2 } = \left( \frac { 2 m b } { \hbar ^ { 2 } } + \frac { 1 } { 4 } \right)               82
# 100628           95      38    271      E ^ { a } = d X ^ { \underline { { m } } } ( \xi ) u _ { \underline { { m } } } ^ { a } ( \xi )               95
# 100629           68      34    248                                 L _ { 4 } = \epsilon _ { a b c d } R ^ { a b } e ^ { c } e ^ { d } .               68
# 100630           90      80    247           T = \left( \begin{array} { c c } { A } & { B } \\ { C } & { D } \\ \end{array} \right) \ ,               90
# 100631          209      48    664  \left\langle \phi ( \xi ) \right\rangle _ { m , n } = - Q \operatorname { l o g } \left| \xi - \...              209
# 100632          135      75    481  H _ { T } = H + \sum _ { a } \lambda _ { a } \phi _ { a } ^ { ( 0 ) } + \sum _ { \rho } \xi _ { ...              135
# 100633           55      61    266                                              E _ { n l } = \frac { \alpha } { \kappa } ( n + l + 1 )               55
# 100634          460      80   1057  \partial _ { \alpha } h ^ { \alpha } { } _ { \mu } - \frac { 1 } { 2 } \partial _ { \mu } h ^ { ...              460
# 100635           82      34    442                   \langle B W L \rangle = \operatorname { e x p } [ - K A _ { \Delta } / ( N - 1 ) ]               82
# 100636          173      68    738  I _ { d S } | E _ { 0 } , s , E _ { \Lambda } > = [ E _ { 0 } ^ { 2 } + E _ { \Lambda } ^ { 2 } ...              173
# 100637           85      32    217                \epsilon _ { a b c } \phi _ { b } ^ { m } \partial _ { c } ^ { m } \Gamma _ { i } = 0               85
# 100638          134      83    489  V ( \varphi _ { 0 } ) = - \sum _ { n } \frac { 1 } { n ! } \tilde { \Gamma } ^ { ( n ) } ( 0 , 0...              134
# 100639           89      67    304            A = { \frac { i } { 2 } } \left( A _ { 0 } 1 \! \! 1 + A _ { a } \sigma ^ { a } \right) ,               89
# 100640          300      60    713  C _ { \theta } ( \tau ) : = \operatorname* { l i m } _ { \tau \rightarrow \infty } \Big [ \; \la...              300
# 100641          114      60    543  \{ G _ { r } , G _ { s } \} = 2 L _ { r + s } + \frac { c } { 1 2 } ( 4 r ^ { 2 } - 1 ) \delta _...              114
# 100642           96      75    437     \frac { d } { d p ^ { 2 } } A _ { 2 } ( p ) \Big | _ { p ^ { 2 } = 0 } = B _ { 2 } ( p = 0 ) = 0               96
# 100643          211      87    868  V ^ { 2 - 2 h } \sum _ { e n } [ \mathrm { e x p } ( i \pi e / k ) - \mathrm { e x p } ( - i \pi...              211
# 100644          253      39    767  \Lambda _ { a } ^ { i } = \lambda _ { - a } ^ { i 4 } - \sqrt 2 \theta ^ { + } G _ { a } ^ { i }...              253
# 100645          287      82    853  = { \displaystyle \sum _ { i , j } } \eta \left( { \phi } _ { i } , { \phi } _ { j } , \xi _ { 1...              287
# 100646          132      44    292  D _ { m _ { a } m _ { d } } ^ { J _ { E } } ( U _ { 4 } ) \; D _ { i _ { d } i _ { a } } ^ { J _...              132
# 100647           89      34    216            \delta _ { \epsilon } ( \mathcal { P } _ { - } \Theta ) = \mathcal { P } _ { - } \epsilon               89
# 100648           77      75    257                        F _ { N = 2 } ^ { S S } ( \beta ) = \frac { \beta - i \pi } { \beta + i \pi }               77
# 100649           60      29    243                                         X ^ { \mu } = x ^ { \mu } + \theta ^ { \mu \nu } A _ { \nu }               60
# 100650          262      78    762  A ( Y _ { 1 } - Y _ { 2 } ) = \int _ { 0 } ^ { \infty } \frac { d l ^ { \prime } } { l ^ { \prim...              262
# 100651          264      41    709  \mathrm { e i t h e r } \quad \tilde { \gamma } ^ { a } : = i \; d x ^ { 0 } \; \tilde { \tilde ...              264
# 100652           85      34    386                b ) \, \, \, \, \, \, \, \, \, \, \, \, \, \, \, \, \Phi = ( 2 n + 1 - \alpha ) \pi ,               85
# 100653           42      28    220                                                           d \Psi _ { e } \wedge d \Psi _ { m } = 0 .               42
# 100654          112      81    542  h _ { ( p , q ) } = \bar { h } _ { ( p , q ) } = \frac { ( ( m + 1 ) p - m q ) ^ { 2 } - 1 } { 4...              112
# 100655          250      79   1070  ( A N x ^ { 2 } \phi ^ { \prime } ) ^ { \prime } = 2 \gamma A e ^ { 2 \gamma \phi } \left[ N ( K...              250
# 100656          220      36    874  \Phi ^ { \mu } ( \xi , \theta _ { + } , \theta _ { - } ) = X ^ { \mu } ( \xi ) + i \theta _ { + ...              220
# 100657          173      88    322  { \frac { \alpha } { n } } \bigg ( { \frac { ( 2 \pi ) ^ { 2 } } { 2 m } } { \frac { \kappa ^ { ...              173
# 100658          133      75    440  \frac { 2 j } { \alpha _ { + } } ( j - m ) \partial \phi \partial \gamma \gamma ^ { ( j - m - 1 ...              133
# 100659          124      73    410  \frac { d S ^ { i } } { d \tau } + \{ _ { j k } ^ { i } \} u ^ { j } S ^ { k } = - G _ { j k } ^...              124
# 100660           91      43    232          n _ { a } ^ { ( E _ { 7 } \, D _ { 1 0 } ) } \ n _ { b } ^ { ( E _ { 7 } \, D _ { 1 0 } ) }               91
# 100661          116      36    321  { \check { x } } ^ { - n } = { \check { x } } _ { + } ^ { - n } + ( - 1 ) ^ { n } { \check { x }...              116
# 100662           88      41    493             ^ { ( N / 2 ) } \chi ^ { ( N / 2 ) } = ( N - 1 ) ! ! 2 ^ { N / 2 } ( d / 2 ) _ { N / 2 }               88
# 100663           86      79    183               v _ { S } ^ { 2 } = \frac { \partial p / \partial T } { \partial \rho / \partial T } .               86
# 100664          110      76    549  b ( p ) a _ { S } { } ^ { \dag } ( m ) = - \theta ( m > p ) \frac { 1 } { \sqrt { m } } b ^ { \d...              110
# 100665          160      74    643  I _ { 6 } = \frac { 1 } { 2 \kappa ^ { 2 } } \int d ^ { 6 } x \sqrt { - G } e ^ { - \Phi } [ R _...              160
# 100666          119      39    561  ( A _ { 1 } ^ { C S } ) _ { i } = ( A _ { 1 } ) _ { i } + ( A _ { 1 , \beta } ) _ { i } ~ ~ ~ , ...              119
# 100667           75      39    366                          \delta { \ddot { R } } + h ^ { 2 } ( 1 - h ^ { 2 } D ^ { 2 } ) \delta R = 0               75
# 100668           87      34    505              X _ { i k } \to ( i , k ) X _ { i k } , \quad Q _ { \pm k } \to ( 1 , k ) Q _ { \pm k }               87
# 100669          262     220    325  \left( \begin{array} { c c c c c c } { 0 } & { 1 } & { } & { } & { } & { } \\ { } & { 0 } & { 1 ...              262
# 100670          146      81    486  d \bar { s } ^ { 2 } \sim \frac { a ^ { 2 } } { ( r - r _ { 1 } ) ^ { 2 } } \, d t ^ { 2 } - d r...              146
# 100671           58      79    216                                           v \leq \left[ { \frac { V } { 4 \pi } } \right] \equiv N .               58
# 100672          268      71    738  | \phi ( \alpha ^ { z } , \alpha ^ { i } ) \rangle = \operatorname { c o s } ( \omega \alpha ^ {...              268
# 100673          202      41    528  \langle \phi _ { 2 } | \phi _ { 1 } \rangle _ { J } ^ { \dagger } = \langle \phi _ { 1 } | \phi ...              202
# 100674          157      47    645  < H H > = < \sum ( c \hat { \sigma } _ { i } . \vec { p } _ { i } ) ( c \hat { \sigma } _ { i } ...              157
# 100675          117      33    490  \lbrack J _ { + } , J _ { - } ] = 2 J _ { 3 } \; , \quad \quad \lbrack J _ { 3 } , J _ { \pm } ]...              117
# 100676          171      77    480  \frac { \partial \phi } { \partial { \cal R } } = \frac { \sqrt { 3 ( 1 + \omega ) } } { { \cal ...              171
# 100677          147      39    459  \phi \mapsto \phi _ { g } , \quad ( { q ^ { g } } ^ { T } ) _ { \Lambda } = ( q ^ { T } ) _ { \S...              147
# 100678          154      74    490  \Delta ( { \bf x } - { \bf x } ^ { \prime } ; t ) = \int d k e ^ { - i { \bf k } ( { \bf x } - {...              154
# 100679          252      80    736  f _ { w } \left( T _ { a } ( z ) \right) = T _ { a } ^ { \prime } ( z ) \left[ f _ { w } ( z ) +...              252
# 100680          235     104    643  \sigma _ { 0 } ^ { n } ( \lambda ) = s ( \lambda - { \frac { ( - ) ^ { n } } { \alpha _ { 0 } } ...              235
# 100681          105      68    268  - \frac { 1 } { 2 } \left( \theta ^ { - 1 } \delta \theta \theta ^ { - 1 } \right) _ { i j } \, ...              105
# 100682          127      41    485  B { \cal F } ^ { \prime } = 0 = { ^ t B } { \cal F } ^ { \prime } = ( q ^ { N - \bar { N } } - 1...              127
# 100683           64      24    158                                     \gamma _ { t } \gamma _ { t } \longleftrightarrow \sigma _ { t }               64
# 100684           70      39    288                               \ddot { \phi } + 3 H \dot { \phi } = - { V ^ { \prime } ( \phi ) } \ ,               70
# 100685           60      29    350                                         A = - \partial X X ^ { - 1 } = - \partial \theta T ^ { 3 } .               60
# 100686          198      35    756  { \cal L } = \partial _ { \mu } V _ { i } ^ { * } \partial ^ { \mu } V _ { i } + h _ { 1 } ( V _...              198
# 100687           65      35    304                                    { \cal L } ( M _ { m + 1 \, j } ) = \lambda M _ { m + 1 \, j } \,               65
# 100688           94      34    331       \lambda _ { \mu } \, \dot { z } ^ { \mu } = 1 , ~ ~ ~ \lambda ^ { \mu } \, R _ { , \mu } = 1 .               94
# 100689           81      68    412                    R _ { M N } - \frac { 1 } { 2 } g _ { M N } \diamondsuit R = - T _ { F \, M N } ,               81
# 100690          357      33    652  \acute { o } ^ { A } \bar { o } ^ { A ^ { \prime } } + o ^ { A } \acute { \bar { o } } { } ^ { A...              357
# 100691          123      38    674  ( \dot { x } _ { \mu } - v J _ { \mu } ) ^ { 2 } + e ^ { 2 } m ^ { 2 } = 0 , \quad \dot { x } J ...              123
# 100692           69      37    258                                \{ x ^ { i } , x ^ { j } \} = \Theta \epsilon ^ { i j k } x _ { k } ,               69
# 100693          233      68    990  \varphi ^ { \prime } = ( 1 - \alpha _ { + } ) \varphi ^ { + } + ( 1 - \alpha _ { - } ) \varphi ^...              233
# 100694          155      80    574  \epsilon ^ { a _ { + } } ( x ) T ^ { a _ { + } } , \qquad \qquad \Xi ( x , 0 ) = \left( \begin{a...              155
# 100695          170      35    427  A ^ { \prime } = e ^ { \rho \mathbf { J } _ { 2 } } d e ^ { - \rho \mathbf { J } _ { 2 } } + e ^...              170
# 100696          109      37    622  G = d U ^ { 1 } d V ^ { 1 } + d U ^ { 2 } d V ^ { 2 } + ( d Y ^ { 1 } ) ^ { 2 } + ( d Y ^ { 2 } ...              109
# 100697           74      50    297                           \psi * \chi \equiv V _ { ( \infty , - 1 ) } ^ { ( 0 ) } ( \psi ) \chi \, ,               74
# 100698           77      37    254                        \Psi [ A _ { i } ^ { a } ] \rightarrow \Psi [ ( A ^ { U } ) _ { i } ^ { a } ]               77
# 100699          165     101    640  L = L _ { \mathrm { C M } } ( x , p ) = \sum _ { k = 1 } ^ { N } p _ { k } E _ { k k } + \sum _ ...              165
#
# [100700 rows x 8 columns]

# %%
df_clean = df3_clean[['image', 'formula_name', 'height', 'width', 'latex_ascii', 'latex_ascii_len']]

# %%
class TokenDict(object):
    def __init__(self):
        self._tokens = {}
    
    def account(self, token_list):
        for token in token_list:
            self._count(token)
            
    def _count(self, token):
        if token in self._tokens:
            self._tokens[token] += 1
        else:
            self._tokens[token] = 1
        return 1
    
    @property
    def dict(self):
        return self._tokens
    
    @property
    def tokens(self):
        return sorted(self._tokens.keys())
            
def make_vocabulary(df_, data_dir_, overwrite=False):
    pickle_path_vocab = os.path.join(data_dir_, notebook_dir, 'df4_vocab.pkl')
    pickle_path_tokenized = os.path.join(data_dir_, notebook_dir, 'df4_tokenized.pkl')
    if (not overwrite) and (os.path.exists(pickle_path_vocab) or os.path.exists(pickle_path_tokenized)):
        raise Exception('Files already exist')
    else:
        ## Split latex into tokens. Isolate latex commands first - i.e.
        ## (optionally even number of backslashes) followed by one backslash followed by letters.
        ## Everything else is a one-character token in itself.
        LATEX_RE = re.compile(r"(?:(?<=\\\\\\\\\\\\)\\[a-zA-Z]+)|(?:(?<=\\\\\\\\)\\[a-zA-Z]+)|(?:(?<=\\\\)\\[a-zA-Z]+)|(?:(?<!\\)\\[a-zA-Z]+)|.")
        sr_token = df_.latex_ascii.str.findall(LATEX_RE)
        df_tokenized = df_.assign(latex_tokenized=sr_token)
        ## Aggregate the tokens
        vocab = TokenDict()
        sr_token.agg(lambda l: vocab.account(l))
        ## Sort and save
        tokens = []; 
        count = []
        for t in vocab.tokens:
            tokens.append(t)
            count.append(vocab.dict[t])
        ## Assign token-ids. Start with 2. RESERVE 0 as a 'NULL' token, 1 as BEGIN-SEQUENCE token
        df_vocab = pd.DataFrame({'id':range(2,len(tokens)+2), 'freq':count}, index=tokens, columns=['id', 'freq'])
        ## Now ensure that space is the last ID.
        ## This is required by the CTC decoder if we wanted to use space as blank-token for CTC
        max_id = df_vocab.id.max()
        #print 'max_id =', max_id, type(max_id)
        max_idx = df_vocab[df_vocab.id == max_id].index[0]
        #print 'max_idx=', max_idx, type(max_idx)
        space_id = df_vocab.loc[' '].id
        #print 'space_id=', space_id, type(space_id)
        df_vocab.loc[' '].id = max_id
        df_vocab.loc[max_idx].id = space_id
        print 'swapped ids %d and %d'%(max_id, space_id)
        display(df_vocab.loc[' '])
        display(df_vocab.loc[max_idx])
        df_vocab.to_pickle(pickle_path_vocab)
        df_tokenized.to_pickle(pickle_path_tokenized)
        
    return df_vocab, df_tokenized

def get_vocabulary(df_, data_dir_):
    df_vocab = pd.read_pickle(os.path.join(data_dir_, notebook_dir, 'df_vocab.pkl'))
    df_tokenized = pd.read_pickle(os.path.join(data_dir_, notebook_dir, 'df_tokenized.pkl'))        
    return df_vocab, df_tokenized

# %%
try:
    df_vocab, df_tokenized = get_vocabulary(df_clean, data_dir)
except:
    df_vocab, df_tokenized = make_vocabulary(df_clean, data_dir)
# Out:
# swapped ids 449 and 2
# id          449
# freq    6491267
# Name:  , dtype: int64
# id          2
# freq    30529
# Name: ~, dtype: int64

# %%
df_vocab.sort_values(by='freq', ascending=False)
# Out:
#                       id     freq
#                      449  6491267
# {                    446  1135182
# }                    448  1134337
# _                    418   356353
# ^                    417   303405
# (                      8   204056
# )                      9   203870
# 2                     18   191219
# \                     60   165742
# ,                     12   162299
# 1                     17   144130
# -                     13   134812
# =                     29   128043
# +                     11    99643
# \frac                193    95085
# i                    428    79067
# a                    420    78994
# 0                     16    68927
# r                    437    63185
# x                    443    60372
# n                    433    54449
# d                    423    50294
# .                     14    49438
# \mu                  263    45215
# \right               321    42487
# \left                231    42487
# k                    430    38129
# e                    424    37433
# m                    432    35788
# c                    422    34938
# p                    435    33135
# ;                     27    33039
# t                    439    32745
# \partial             295    30901
# \alpha               101    30736
# &                      6    30709
# 3                     19    30568
# ~                      2    30529
# A                     33    29341
# s                    438    29165
# y                    444    28601
# j                    429    28201
# 4                     20    27669
# l                    431    26622
# g                    426    25384
# \prime               305    25237
# ]                    416    24951
# [                     59    24851
# \nu                  274    23465
# |                    447    23282
# \pi                  299    22777
# z                    445    22774
# b                    421    22221
# \phi                 298    20682
# \mathrm              256    19165
# q                    436    18808
# \operatorname        285    18704
# \cal                 144    18528
# N                     46    18521
# f                    425    18193
# \delta               165    18121
# \lambda              222    17931
# \beta                115    17188
# \int                 214    16988
# T                     52    16900
# \bar                 113    16871
# R                     50    16767
# D                     36    16570
# S                     51    16474
# M                     45    15700
# L                     44    15594
# B                     34    15079
# \sigma               339    14700
# \theta               379    14686
# F                     38    14562
# /                     15    14043
# h                    427    13754
# \gamma               195    13700
# \hat                 200    12940
# \psi                 309    12891
# \sum                 363    12872
# \sqrt                354    12770
# u                    440    12585
# H                     40    12246
# \rho                 320    12184
# o                    434    12079
# \tilde               381    11881
# \tau                 369    11348
# C                     35    11325
# P                     48    10832
# G                     39    10806
# V                     54    10557
# X                     56    10544
# I                     41    10481
# \omega               283    10476
# \epsilon             180    10036
# E                     37     9991
# J                     42     9636
# \bf                  116     9611
# \eta                 182     9279
# v                    441     8869
# \xi                  414     8863
# Q                     49     8760
# \quad                311     8741
# \Phi                  86     8724
# *                     10     8434
# \vec                 404     8372
# \Gamma                72     8061
# \end                 176     7978
# \begin               114     7978
# !                      3     7977
# K                     43     7961
# \infty               213     7835
# 5                     21     7393
# U                     53     7046
# \rangle              312     6997
# 6                     22     6949
# \dot                 170     6928
# W                     55     6869
# \pm                  300     6693
# Z                     58     6660
# \Lambda               77     6642
# \varphi              397     6502
# \Delta                70     6427
# w                    442     6095
# \chi                 150     5949
# \Omega                84     5609
# :                     26     5533
# 8                     24     5518
# \kappa               219     5456
# \qquad               310     5177
# \cdot                146     5171
# \Psi                  88     4707
# \langle              224     4498
# \equiv               181     4491
# >                     30     4134
# \overline            291     4108
# \dagger              159     3734
# <                     28     3721
# \zeta                415     3634
# \cdots               148     3529
# \varepsilon          396     3516
# \rightarrow          322     3411
# O                     47     3384
# \nabla               264     3377
# Y                     57     3291
# \ldots               229     3182
# \Sigma                93     2916
# \ell                 174     2816
# \mathcal             248     2747
# 7                     23     2526
# \otimes              288     2407
# \prod                306     2387
# \wedge               410     2319
# 9                     25     2192
# \Pi                   87     2174
# \hbar                201     2159
# \sim                 340     2071
# \vert                407     2001
# \Big                  62     1976
# \in                  212     1952
# \widetilde           412     1908
# \displaystyle        168     1856
# \times               382     1814
# \Theta                94     1777
# \to                  384     1628
# \mid                 260     1623
# \underline           392     1587
# \dots                172     1499
# \mathbf              246     1461
# \ast                 107     1362
# \leq                 235     1192
# \star                357     1177
# \approx              103     1164
# \stackrel            356     1102
# \perp                296     1089
# \widehat             411     1068
# \big                 117     1059
# \vartheta            401      914
# \Bigr                 69      874
# \dag                 158      847
# \mp                  262      838
# \geq                 197      837
# \Bigl                 67      829
# \neq                 268      758
# \simeq               341      742
# \bigg                121      695
# \biggl               122      688
# \circ                151      684
# \biggr               124      683
# \textstyle           376      683
# \oint                281      665
# '                      7      647
# \longrightarrow      243      614
# \not                 272      546
# \ddot                162      532
# \boldmath            137      531
# \oplus               286      527
# \bigr                129      520
# \bigl                125      509
# \nonumber            270      449
# \Xi                   97      438
# \le                  230      384
# \check               149      376
# \propto              307      376
# \triangle            386      365
# \imath               211      331
# \varrho              399      328
# \sp                  350      322
# \vdots               403      321
# \ge                  196      317
# \Bigg                 63      302
# \iota                215      287
# \forall              192      278
# \bot                 138      278
# \leftrightarrow      234      275
# \lbrack              227      262
# \parallel            294      241
# \hline               204      240
# \scriptscriptstyle   331      237
# \subset              359      228
# \textrm              374      224
# \it                  216      221
# \Rightarrow           90      221
# \phantom             297      215
# \mapsto              245      213
# \jmath               218      205
# \scriptsize          332      200
# \binom               135      196
# \Biggr                66      191
# \l                   221      190
# \Biggl                64      184
# \ne                  266      177
# \sf                  337      176
# \ddots               163      174
# \d                   157      174
# \Upsilon              95      174
# \wp                  413      172
# \overrightarrow      292      167
# \ll                  238      162
# \bullet              142      157
# \gg                  198      150
# \downarrow           173      148
# \tiny                383      148
# \breve               141      147
# \atop                109      143
# \vee                 405      142
# \L                    75      141
# \cong                154      140
# \uparrow             393      138
# \o                   278      131
# \Im                   74      130
# \bigoplus            127      129
# \rbrack              314      124
# \underbrace          391      118
# \small               345      118
# \varpi               398      117
# \sb                  329      117
# \scriptstyle         333      112
# \cap                 145      112
# \rbrace              313      103
# \lbrace              226      103
# \upsilon             395      100
# \cup                 156       99
# \mathsf              257       97
# #                      5       95
# \Re                   89       95
# \slash               344       91
# \Longrightarrow       82       89
# \mit                 261       86
# \supset              364       85
# \acute                98       84
# \rightharpoonup      323       82
# \varsigma            400       81
# \Leftrightarrow       79       74
# \S                    91       74
# \bigtriangleup       132       68
# \longleftrightarrow  241       68
# \O                    83       65
# \large               225       64
# \null                275       64
# "                      4       60
# \i                   209       58
# \Large                78       58
# \footnotesize        191       54
# \protect             308       54
# \Vert                 96       52
# \leftarrow           232       52
# \vphantom            409       50
# \overleftarrow       290       49
# \Longleftrightarrow   81       49
# \enspace             178       49
# \sl                  343       46
# \rfloor              318       46
# \P                    85       44
# \doteq               171       43
# \tt                  389       43
# \diamond             166       42
# \bigotimes           128       42
# \cdotp               147       41
# `                    419       38
# \hfill               203       37
# \emptyset            175       36
# \ref                 316       35
# \mathop              252       34
# \textbf              370       34
# \backslash           112       33
# \sharp               338       31
# \overbrace           289       30
# \longmapsto          242       30
# \mathit              250       29
# \flat                188       28
# \subseteq            360       28
# \c                   143       26
# \bigcup              120       26
# \odot                279       26
# \vline               408       25
# \colon               153       25
# \strut               358       25
# \ni                  269       25
# \thinspace           380       24
# \aleph               100       24
# \lfloor              236       22
# \rule                328       22
# \makebox             244       22
# \pounds              302       22
# \bigwedge            134       21
# \ominus              284       21
# \textup              378       20
# \bmod                136       19
# \j                   217       19
# \enskip              177       18
# \bigtriangledown     131       18
# \land                223       17
# ?                     31       17
# \hookrightarrow      205       17
# \setminus            336       16
# \bigcap              118       14
# \b                   111       14
# \searrow             335       13
# \natural             265       13
# \longleftarrow       240       12
# \space               351       12
# \diamondsuit         167       12
# \ddagger             161       11
# \pmod                301       11
# \top                 385       10
# \textit              372        9
# \rlap                325        9
# \smash               348        9
# \smallskip           347        9
# \medskip             259        9
# \LARGE                76        9
# \sc                  330        9
# \triangleright       388        9
# \bigm                126        8
# \exists              184        8
# \bigcirc             119        8
# \vdash               402        8
# \surd                366        8
# \textnormal          373        7
# \hphantom            206        7
# \nearrow             267        7
# \sqcup               353        7
# \mathrel             255        6
# \normalsize          271        6
# \Downarrow            71        6
# \cite                152        6
# \AA                   61        5
# \lefteqn             233        5
# \textsf              375        5
# \unboldmath          390        5
# \hfil                202        5
# \sqcap               352        5
# \swarrow             367        5
# \supseteq            365        5
# \Longleftarrow        80        4
# \kern                220        4
# \amalg               102        4
# \Huge                 73        4
# \Biggm                65        4
# \arraycolsep         104        4
# @                     32        4
# \llap                239        4
# \ae                   99        4
# \lceil               228        4
# \triangleleft        387        4
# \nulldelimiterspace  276        4
# \mathclose           249        4
# \ss                  355        4
# \mathopen            253        4
# \fbox                186        4
# \prec                303        4
# \hskip               207        4
# \ensuremath          179        4
# \do                  169        4
# \rgroup              319        3
# \skew                342        3
# \bigsqcup            130        3
# \oslash              287        3
# \lgroup              237        3
# \mathtt              258        3
# \ddag                160        3
# \preceq              304        3
# \succeq              362        3
# \Bigm                 68        3
# \grave               199        3
# \smile               349        3
# \framebox            194        3
# \succ                361        3
# \notin               273        3
# \smallint            346        3
# \SS                   92        2
# \texttt              377        2
# \symbol              368        2
# \verb                406        2
# \arrowvert           106        2
# \asymp               108        2
# \footnote            189        2
# \atopwithdelims      110        2
# \footnotemark        190        2
# \mathnormal          251        2
# \ointop              282        2
# \fill                187        1
# \of                  280        1
# \expandafter         185        1
# \nwarrow             277        1
# \overwithdelims      293        1
# \everymath           183        1
# \romannumeral        326        1
# \def                 164        1
# \rceil               315        1
# \ij                  210        1
# \bigvee              133        1
# \textcircled         371        1
# \uppercase           394        1
# \brace               139        1
# \brack               140        1
# \biggm               123        1
# \mathbin             247        1
# \scshape             334        1
# \coprod              155        1
# \arraystretch        105        1
# \mathord             254        1
# \root                327        1
# \rightleftharpoons   324        1
# \relax               317        1
# \hspace              208        1

# %%
dict_vocab = df_vocab.to_dict()
if not os.path.exists(os.path.join(data_dir, 'dict_vocab.pkl')):
    with open(os.path.join(data_dir, 'dict_vocab.pkl'), 'wb') as f:
        pickle.dump(dict_vocab, f, pickle.HIGHEST_PROTOCOL)

# %%
def reverse_dict(d):
    r = {}
    for k in d.keys():
        v = d[k]
        r[v] = k
    return r
if not os.path.exists(os.path.join(data_dir, 'dict_id2word.pkl')):
    with open(os.path.join(data_dir, 'dict_id2word.pkl'), 'wb') as f:
        dict_id2word = reverse_dict(dict_vocab['id'])
        dict_id2word[0] = '\\eos'
        dict_id2word[1] = '\\bos'
        pickle.dump(dict_id2word, f, pickle.HIGHEST_PROTOCOL)

# %%
df_vocab[df_vocab.id==525]

# %%
df_vocab[df_vocab.id==18]

# %%
df_vocab[df_vocab.id==553]

# %%
df_vocab[df_vocab.id==555]

# %%
display('NULL=0, BEGIN=1, space=%d'%(df_vocab.loc[' '].id,))
display(df_vocab.sort_values(by='freq', ascending=False))

# %%
#df_vocab[df_vocab.index.str.contains(r'\\')]

# %%
print df_clean.latex_ascii[df_clean.latex.str.contains(r'\\\\\\\\\\\\\\\\\\\\')].count()

# %%
def get_word2id(df_tokenized_, df_vocab_, data_dir_):
    try:
        return pd.read_pickle(os.path.join(data_dir, 'df_word2id.pkl'))
    except Exception as e:
        print e        
        word2id = df_vocab_.id.to_dict()
        sr_word2id = df_tokenized_.latex_tokenized.apply(lambda l: map(lambda t: word2id[t], l))
        df_ = df_tokenized_.assign(word2id=sr_word2id, word2id_len=sr_word2id.str.len())
        df_.to_pickle(os.path.join(data_dir_, 'df_word2id.pkl'))
        return df_

# %%
df_word2id = get_word2id(df_tokenized, df_vocab, data_dir)

# %% [markdown]
# ### Temp

# %%
df_vocab = pd.read_pickle(os.path.join(data_dir,'df_vocab.pkl'))

# %%
df_vocab

# %%
df_vocab.id.loc[':']

# %%
df_word2id = pd.read_pickle(os.path.join(data_dir, 'df_word2id.pkl'))
df_word2id

# %%
dict_id2word = pd.read_pickle(os.path.join(data_dir, 'dict_id2word.pkl'))

# %%
dict_id2word
