# %% [markdown]
# # im2latex(S): Deep Learning Model
#
# &copy; Copyright 2017 Sumeet S Singh
#
#     This file is part of the im2latex solution (by Sumeet S Singh in particular since there are other solutions out there).
#
#     This program is free software: you can redistribute it and/or modify
#     it under the terms of the Affero GNU General Public License as published by
#     the Free Software Foundation, either version 3 of the License, or
#     (at your option) any later version.
#
#     This program is distributed in the hope that it will be useful,
#     but WITHOUT ANY WARRANTY; without even the implied warranty of
#     MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.  See the
#     Affero GNU General Public License for more details.
#
#     You should have received a copy of the Affero GNU General Public License
#     along with this program.  If not, see <http://www.gnu.org/licenses/>.

# %% [markdown]
# ## The Model
# * Follows the [Show, Attend and Tell paper](https://www.semanticscholar.org/paper/Show-Attend-and-Tell-Neural-Image-Caption-Generati-Xu-Ba/146f6f6ed688c905fb6e346ad02332efd5464616)
# * [VGG ConvNet (16 or 19)](http://www.robots.ox.ac.uk/~vgg/research/very_deep/) without the top-3 layers
#     * Pre-initialized with the VGG weights but allowed to train
#     * The ConvNet outputs $D$ dimensional vectors in a WxH grid where W and H are 1/16th of the input image size (due to 4 max-pool layers). Defining $W.H \equiv L$ the ConvNet output represents L locations of the image $i \in [1,L]$ and correspondingly outputs to L annotation vectors $a_i$, each of size $D$.
# * A dense (FC) attention model: The deterministic soft-attention model of the paper computes $\alpha_{t,i}$ which is used to select or blend the $a_i$ vectors before being fed as inputs to the decoder LSTM network (see below).
#     * Inputs to the attention model are $a_i$ and $h_{t-1}$ (previous hidden state of LSTM network - see below)
#     and $$\alpha_{t,i} = softmax ( f_{att}(a_i, h_{t-1}) )$$
# * A Decoder model: A conditioned LSTM that outputs probabilities of the text tokens $y_t$ at each step. The LSTM is conditioned upon $z_t = \sum_i^L(\alpha_{t,i}.a_i)$ and takes the previous hidden state $h_{t-1}$ as input. In addition, an embedding of the previous output $Ey_{t-1}$ is also input to the LSTM. At training time, $y_{t-1}$ would be derived from the training samples, while at inferencing time it would be fed-back from the previous predicted word.
#     * $y$ is taken from a fixed vocabulary of K words. An embedding matrix $E$ is used to narrow its representation. The embedding weights $E$ are learnt end-to-end by the model as well.
#     * The decoder LSTM uses a deep layer between $h_t$ and $y_t$. It is called a deep output layer and is described in [section 3.2.2 of this paper](https://www.semanticscholar.org/paper/How-to-Construct-Deep-Recurrent-Neural-Networks-Pascanu-G%C3%BCl%C3%A7ehre/533ee188324b833e059cb59b654e6160776d5812). That is:
#     $$ p(y_t) = Softmax \Big( f_out(Ey_{t-1}, h_t, \hat{z}_t) \Big) $$
# * Initialization MLPs: Two MLPs are used to produce the initial memory-state of the LSTM as well as $h_{t-1}$ value. Each MLP takes in the entire image's features (i.e. average of $a_i$) as its input and is trained end-to-end.
#     $$ c_o = f_{init,c}\Big( \sum_i^L a_i \Big) $$
#     $$ h_o = f_{init,h}\Big( \sum_i^L a_i \Big) $$
# * Training:
#     * 3 models from above - all except the conv-net - are trained end-to-end using SGD
#     * The model is trained for a variable number of time steps - depending on each batch

# %% [markdown]
# ## References
# 1. Show, Attend and Tell
#     * [Paper](https://www.semanticscholar.org/paper/Show-Attend-and-Tell-Neural-Image-Caption-Generati-Xu-Ba/146f6f6ed688c905fb6e346ad02332efd5464616)
#     * [Slides](https://pdfs.semanticscholar.org/b336/f6215c3c15802ca5327cd7cc1747bd83588c.pdf?_ga=2.52116077.559595598.1498604153-2037060338.1496182671)
#     * [Author's Theano code](https://github.com/kelvinxu/arctic-captions)
# 1. [Simonyan, Karen and Andrew Zisserman. “Very Deep Convolutional Networks for Large-Scale Image Recognition.” CoRR abs/1409.1556 (2014): n. pag.](http://www.robots.ox.ac.uk/~vgg/research/very_deep/)
# 1. [im2latex solution of Harvard NLP](http://lstm.seas.harvard.edu/latex/)
# 1. [im2latex-dataset tools forked from Harvard NLP](https://github.com/untrix/im2latex-dataset)

# %%
import pandas as pd
import os
from six.moves import cPickle as pickle
import dl_commons as dlc
import tf_commons as tfc
import tensorflow as tf
from keras.applications.vgg16 import VGG16
from keras.layers import Input, Embedding, Dense, Activation, Dropout, Concatenate, Permute
from keras.callbacks import LambdaCallback
from keras.models import Model
from keras import backend as K
from keras.engine import Layer
import keras
import threading
import numpy as np
import collections
# from Im2LatexDecoderRNNParams import D_RNN
# from Im2LatexDecoderRNN import Im2LatexDecoderRNN
# from Im2LatexModel import Im2LatexModel, HYPER
from data_reader import BatchIterator
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # TODOs
# * Implement the beta scalar ('selector') that scales alpha.

# %%
data_folder = '../data/generated2'
image_folder = os.path.join(data_folder,'formula_images')
raw_data_folder = os.path.join(data_folder, 'training')

# %% [markdown]
# ### HyperParams

# %%
def get_vocab_size(data_dir_):
    df_vocab = pd.read_pickle(os.path.join(data_folder, 'df_vocab.pkl'))
    return df_vocab.id.max() + 1

# %% [markdown]
# ### Encoder Model
# [VGG ConvNet (16 or 19)](http://www.robots.ox.ac.uk/~vgg/research/very_deep/) without the top-3 layers
# * Pre-initialized with the VGG weights but allowed to train
# * The ConvNet outputs $D$ dimensional vectors in a WxH grid where W and H are scaled-down dimensions of the input image size (due to 5 max-pool layers). Defining $W.H \equiv L$ the ConvNet output represents L locations of the image $i \in [1,L]$ and correspondingly outputs to L annotation vectors $a_i$, each of size $D$.
#
# The conv-net is *not trained* in the original paper and therefore the files can be separately preprocessed and their outputs directly fed into the model.

# %% [markdown]
# #### Decoder Model
# A dense (FC) attention model: The deterministic soft-attention model of the paper computes $\alpha_{t,i}$ which is used to select or blend the $a_i$ vectors before being fed as inputs to the decoder LSTM network (see below).
# * Inputs to the attention model are $a_i$ and $h_{t-1}$ (previous hidden state of LSTM network - see below) and $$\alpha_{t,i} = softmax ( f_{att}(a_i, h_{t-1}) )$$
# * Note that the model $f_{att}$ shares weights across all values of a_i (i.e. for all i = 1-L). Therefore the shared weight matrix for all a_i has shape (D, D), while shape of a is (B, L, D) where is B=batch-size. Weight matrix of h_i is separate and has the expected shape (n, D). This sharing of weights across a_i is interesting.
#
# A Decoder model: A conditioned LSTM that outputs probabilities of the text tokens $y_t$ at each step. The LSTM is conditioned upon $z_t = \sum_i^L(\alpha_{t,i}.a_i)$ and takes the previous hidden state $h_{t-1}$ as input. In addition, an embedding of the previous output $Ey_{t-1}$ is also input to the LSTM. At training time, $y_{t-1}$ would be derived from the training samples, while at inferencing time it would be fed-back from the previous predicted word.
# * $y$ is taken from a fixed vocabulary of K words. An embedding matrix $E$ is used to narrow its representation to an $m$ dimensional dense vector. The embedding weights $E$ are learnt end-to-end by the model as well.
# * The decoder LSTM uses a deep layer between $h_t$ and $y_t$. It is called a deep output layer and is described in [section 3.2.2 of this paper](https://www.semanticscholar.org/paper/How-to-Construct-Deep-Recurrent-Neural-Networks-Pascanu-G%C3%BCl%C3%A7ehre/533ee188324b833e059cb59b654e6160776d5812). That is:
# $$ p(y_t) = Softmax \Big( f_out(Ey_{t-1}, h_t, \hat{z}_t) \Big) $$
# * Optionally $z_t = \beta \sum_i^L(\alpha_{t,i}.a_i)$ where $\beta = \sigma(f_{\beta}(h_{t-1}))$ is a scalar used to modulate the strength of the context. It turns out that for the original use-case of caption generation, the network would learn to emphasize objects by turning up the value of this scalar when it was focusing on objects. It is not clear at this time whether we'll need this feature for im2latex.

# %% [markdown]
# ### Input Generator

# %%
# df_train = pd.read_pickle(os.path.join(data_folder, 'training', 'df_train.pkl'))
# df_train

# %%
# df_train.shape

# %%
# raw_seq_train = pd.read_pickle(os.path.join(data_folder, 'training', 'raw_seq_train.pkl'))
# raw_seq_train.keys()

# %%
# with open(os.path.join(data_folder, 'training', 'padded_image_dim.pkl'), 'rb') as f:
#   padded_image_dim = pickle.load(f)
# print(padded_image_dim)

# %%
print ('starting')
it = BatchIterator(raw_data_folder, image_folder)
print ('created batch iterator')
# Out:
# starting
# created batch iterator

# %%
for i in range(684):
    batch = it.next()
# Out:
# ShuffleIterator epoch 1, iter 3, bin-batch id (31, 23)
# ShuffleIterator epoch 1, iter 4, bin-batch id (111, 52)
# ShuffleIterator epoch 1, iter 5, bin-batch id (61, 49)
# ShuffleIterator epoch 1, iter 6, bin-batch id (151, 39)
# ShuffleIterator epoch 1, iter 7, bin-batch id (41, 71)
# ShuffleIterator epoch 1, iter 8, bin-batch id (41, 2)
# ShuffleIterator epoch 1, iter 9, bin-batch id (91, 50)
# ShuffleIterator epoch 1, iter 10, bin-batch id (91, 14)
# ShuffleIterator epoch 1, iter 11, bin-batch id (111, 3)
# ShuffleIterator epoch 1, iter 12, bin-batch id (151, 46)
# ShuffleIterator epoch 1, iter 13, bin-batch id (51, 43)
# ShuffleIterator epoch 1, iter 14, bin-batch id (91, 1)
# ShuffleIterator epoch 1, iter 15, bin-batch id (61, 72)
# ShuffleIterator epoch 1, iter 16, bin-batch id (41, 89)
# ShuffleIterator epoch 1, iter 17, bin-batch id (41, 1)
# ShuffleIterator epoch 1, iter 18, bin-batch id (41, 69)
# ShuffleIterator epoch 1, iter 19, bin-batch id (31, 2)
# ShuffleIterator epoch 1, iter 20, bin-batch id (31, 7)
# ShuffleIterator epoch 1, iter 21, bin-batch id (151, 35)
# ShuffleIterator epoch 1, iter 22, bin-batch id (61, 62)
# ShuffleIterator epoch 1, iter 23, bin-batch id (81, 34)
# ShuffleIterator epoch 1, iter 24, bin-batch id (61, 77)
# ShuffleIterator epoch 1, iter 25, bin-batch id (81, 7)
# ShuffleIterator epoch 1, iter 26, bin-batch id (41, 3)
# ShuffleIterator epoch 1, iter 27, bin-batch id (111, 2)
# ShuffleIterator epoch 1, iter 28, bin-batch id (71, 3)
# ShuffleIterator epoch 1, iter 29, bin-batch id (91, 42)
# ShuffleIterator epoch 1, iter 30, bin-batch id (111, 6)
# ShuffleIterator epoch 1, iter 31, bin-batch id (81, 42)
# ShuffleIterator epoch 1, iter 32, bin-batch id (51, 108)
# ShuffleIterator epoch 1, iter 33, bin-batch id (51, 64)
# ShuffleIterator epoch 1, iter 34, bin-batch id (41, 33)
# ShuffleIterator epoch 1, iter 35, bin-batch id (111, 14)
# ShuffleIterator epoch 1, iter 36, bin-batch id (61, 58)
# ShuffleIterator epoch 1, iter 37, bin-batch id (61, 98)
# ShuffleIterator epoch 1, iter 38, bin-batch id (31, 20)
# ShuffleIterator epoch 1, iter 39, bin-batch id (31, 46)
# ShuffleIterator epoch 1, iter 40, bin-batch id (111, 34)
# ShuffleIterator epoch 1, iter 41, bin-batch id (31, 45)
# ShuffleIterator epoch 1, iter 42, bin-batch id (51, 15)
# ShuffleIterator epoch 1, iter 43, bin-batch id (41, 99)
# ShuffleIterator epoch 1, iter 44, bin-batch id (151, 31)
# ShuffleIterator epoch 1, iter 45, bin-batch id (151, 22)
# ShuffleIterator epoch 1, iter 46, bin-batch id (41, 28)
# ShuffleIterator epoch 1, iter 47, bin-batch id (91, 7)
# ShuffleIterator epoch 1, iter 48, bin-batch id (41, 30)
# ShuffleIterator epoch 1, iter 49, bin-batch id (81, 6)
# ShuffleIterator epoch 1, iter 50, bin-batch id (51, 72)
# ShuffleIterator epoch 1, iter 51, bin-batch id (51, 82)
# ShuffleIterator epoch 1, iter 52, bin-batch id (31, 5)
# ShuffleIterator epoch 1, iter 53, bin-batch id (61, 18)
# ShuffleIterator epoch 1, iter 54, bin-batch id (71, 4)
# ShuffleIterator epoch 1, iter 55, bin-batch id (51, 7)
# ShuffleIterator epoch 1, iter 56, bin-batch id (91, 36)
# ShuffleIterator epoch 1, iter 57, bin-batch id (51, 85)
# ShuffleIterator epoch 1, iter 58, bin-batch id (71, 13)
# ShuffleIterator epoch 1, iter 59, bin-batch id (71, 29)
# ShuffleIterator epoch 1, iter 60, bin-batch id (61, 88)
# ShuffleIterator epoch 1, iter 61, bin-batch id (81, 43)
# ShuffleIterator epoch 1, iter 62, bin-batch id (151, 37)
# ShuffleIterator epoch 1, iter 63, bin-batch id (151, 17)
# ShuffleIterator epoch 1, iter 64, bin-batch id (71, 77)
# ShuffleIterator epoch 1, iter 65, bin-batch id (111, 67)
# ShuffleIterator epoch 1, iter 66, bin-batch id (51, 86)
# ShuffleIterator epoch 1, iter 67, bin-batch id (71, 45)
# ShuffleIterator epoch 1, iter 68, bin-batch id (61, 68)
# ShuffleIterator epoch 1, iter 69, bin-batch id (71, 15)
# ShuffleIterator epoch 1, iter 70, bin-batch id (41, 77)
# ShuffleIterator epoch 1, iter 71, bin-batch id (61, 36)
# ShuffleIterator epoch 1, iter 72, bin-batch id (41, 100)
# ShuffleIterator epoch 1, iter 73, bin-batch id (61, 79)
# ShuffleIterator epoch 1, iter 74, bin-batch id (81, 44)
# ShuffleIterator epoch 1, iter 75, bin-batch id (51, 65)
# ShuffleIterator epoch 1, iter 76, bin-batch id (151, 6)
# ShuffleIterator epoch 1, iter 77, bin-batch id (61, 44)
# ShuffleIterator epoch 1, iter 78, bin-batch id (91, 48)
# ShuffleIterator epoch 1, iter 79, bin-batch id (51, 35)
# ShuffleIterator epoch 1, iter 80, bin-batch id (61, 89)
# ShuffleIterator epoch 1, iter 81, bin-batch id (31, 22)
# ShuffleIterator epoch 1, iter 82, bin-batch id (51, 95)
# ShuffleIterator epoch 1, iter 83, bin-batch id (111, 69)
# ShuffleIterator epoch 1, iter 84, bin-batch id (151, 36)
# ShuffleIterator epoch 1, iter 85, bin-batch id (61, 80)
# ShuffleIterator epoch 1, iter 86, bin-batch id (41, 74)
# ShuffleIterator epoch 1, iter 87, bin-batch id (61, 87)
# ShuffleIterator epoch 1, iter 88, bin-batch id (111, 9)
# ShuffleIterator epoch 1, iter 89, bin-batch id (61, 7)
# ShuffleIterator epoch 1, iter 90, bin-batch id (61, 14)
# ShuffleIterator epoch 1, iter 91, bin-batch id (81, 50)
# ShuffleIterator epoch 1, iter 92, bin-batch id (111, 53)
# ShuffleIterator epoch 1, iter 93, bin-batch id (41, 102)
# ShuffleIterator epoch 1, iter 94, bin-batch id (51, 52)
# ShuffleIterator epoch 1, iter 95, bin-batch id (41, 13)
# ShuffleIterator epoch 1, iter 96, bin-batch id (111, 24)
# ShuffleIterator epoch 1, iter 97, bin-batch id (91, 10)
# ShuffleIterator epoch 1, iter 98, bin-batch id (91, 12)
# ShuffleIterator epoch 1, iter 99, bin-batch id (31, 19)
# ShuffleIterator epoch 1, iter 100, bin-batch id (51, 48)
# ShuffleIterator epoch 1, iter 101, bin-batch id (51, 23)
# ShuffleIterator epoch 1, iter 102, bin-batch id (111, 49)
# ShuffleIterator epoch 1, iter 103, bin-batch id (71, 25)
# ShuffleIterator epoch 1, iter 104, bin-batch id (81, 10)
# ShuffleIterator epoch 1, iter 105, bin-batch id (111, 68)
# ShuffleIterator epoch 1, iter 106, bin-batch id (81, 19)
# ShuffleIterator epoch 1, iter 107, bin-batch id (61, 24)
# ShuffleIterator epoch 1, iter 108, bin-batch id (41, 50)
# ShuffleIterator epoch 1, iter 109, bin-batch id (91, 9)
# ShuffleIterator epoch 1, iter 110, bin-batch id (111, 30)
# ShuffleIterator epoch 1, iter 111, bin-batch id (71, 58)
# ShuffleIterator epoch 1, iter 112, bin-batch id (71, 49)
# ShuffleIterator epoch 1, iter 113, bin-batch id (41, 72)
# ShuffleIterator epoch 1, iter 114, bin-batch id (61, 66)
# ShuffleIterator epoch 1, iter 115, bin-batch id (111, 37)
# ShuffleIterator epoch 1, iter 116, bin-batch id (111, 16)
# ShuffleIterator epoch 1, iter 117, bin-batch id (51, 106)
# ShuffleIterator epoch 1, iter 118, bin-batch id (81, 13)
# ShuffleIterator epoch 1, iter 119, bin-batch id (71, 40)
# ShuffleIterator epoch 1, iter 120, bin-batch id (51, 81)
# ShuffleIterator epoch 1, iter 121, bin-batch id (71, 74)
# ShuffleIterator epoch 1, iter 122, bin-batch id (51, 44)
# ShuffleIterator epoch 1, iter 123, bin-batch id (61, 76)
# ShuffleIterator epoch 1, iter 124, bin-batch id (81, 29)
# ShuffleIterator epoch 1, iter 125, bin-batch id (31, 39)
# ShuffleIterator epoch 1, iter 126, bin-batch id (81, 14)
# ShuffleIterator epoch 1, iter 127, bin-batch id (151, 24)
# ShuffleIterator epoch 1, iter 128, bin-batch id (81, 8)
# ShuffleIterator epoch 1, iter 129, bin-batch id (41, 25)
# ShuffleIterator epoch 1, iter 130, bin-batch id (51, 41)
# ShuffleIterator epoch 1, iter 131, bin-batch id (41, 32)
# ShuffleIterator epoch 1, iter 132, bin-batch id (41, 79)
# ShuffleIterator epoch 1, iter 133, bin-batch id (151, 33)
# ShuffleIterator epoch 1, iter 134, bin-batch id (41, 6)
# ShuffleIterator epoch 1, iter 135, bin-batch id (61, 84)
# ShuffleIterator epoch 1, iter 136, bin-batch id (71, 22)
# ShuffleIterator epoch 1, iter 137, bin-batch id (61, 81)
# ShuffleIterator epoch 1, iter 138, bin-batch id (91, 3)
# ShuffleIterator epoch 1, iter 139, bin-batch id (111, 31)
# ShuffleIterator epoch 1, iter 140, bin-batch id (51, 111)
# ShuffleIterator epoch 1, iter 141, bin-batch id (61, 1)
# ShuffleIterator epoch 1, iter 142, bin-batch id (61, 20)
# ShuffleIterator epoch 1, iter 143, bin-batch id (51, 0)
# ShuffleIterator epoch 1, iter 144, bin-batch id (71, 75)
# ShuffleIterator epoch 1, iter 145, bin-batch id (51, 47)
# ShuffleIterator epoch 1, iter 146, bin-batch id (41, 39)
# ShuffleIterator epoch 1, iter 147, bin-batch id (51, 58)
# ShuffleIterator epoch 1, iter 148, bin-batch id (41, 67)
# ShuffleIterator epoch 1, iter 149, bin-batch id (111, 65)
# ShuffleIterator epoch 1, iter 150, bin-batch id (51, 101)
# ShuffleIterator epoch 1, iter 151, bin-batch id (41, 85)
# ShuffleIterator epoch 1, iter 152, bin-batch id (31, 17)
# ShuffleIterator epoch 1, iter 153, bin-batch id (61, 63)
# ShuffleIterator epoch 1, iter 154, bin-batch id (151, 23)
# ShuffleIterator epoch 1, iter 155, bin-batch id (151, 42)
# ShuffleIterator epoch 1, iter 156, bin-batch id (81, 22)
# ShuffleIterator epoch 1, iter 157, bin-batch id (61, 74)
# ShuffleIterator epoch 1, iter 158, bin-batch id (61, 75)
# ShuffleIterator epoch 1, iter 159, bin-batch id (51, 63)
# ShuffleIterator epoch 1, iter 160, bin-batch id (61, 37)
# ShuffleIterator epoch 1, iter 161, bin-batch id (81, 37)
# ShuffleIterator epoch 1, iter 162, bin-batch id (71, 37)
# ShuffleIterator epoch 1, iter 163, bin-batch id (71, 9)
# ShuffleIterator epoch 1, iter 164, bin-batch id (81, 15)
# ShuffleIterator epoch 1, iter 165, bin-batch id (81, 12)
# ShuffleIterator epoch 1, iter 166, bin-batch id (51, 20)
# ShuffleIterator epoch 1, iter 167, bin-batch id (51, 6)
# ShuffleIterator epoch 1, iter 168, bin-batch id (151, 32)
# ShuffleIterator epoch 1, iter 169, bin-batch id (71, 23)
# ShuffleIterator epoch 1, iter 170, bin-batch id (111, 27)
# ShuffleIterator epoch 1, iter 171, bin-batch id (81, 61)
# ShuffleIterator epoch 1, iter 172, bin-batch id (31, 24)
# ShuffleIterator epoch 1, iter 173, bin-batch id (51, 34)
# ShuffleIterator epoch 1, iter 174, bin-batch id (61, 69)
# ShuffleIterator epoch 1, iter 175, bin-batch id (81, 58)
# ShuffleIterator epoch 1, iter 176, bin-batch id (61, 40)
# ShuffleIterator epoch 1, iter 177, bin-batch id (51, 96)
# ShuffleIterator epoch 1, iter 178, bin-batch id (51, 3)
# ShuffleIterator epoch 1, iter 179, bin-batch id (111, 23)
# ShuffleIterator epoch 1, iter 180, bin-batch id (61, 47)
# ShuffleIterator epoch 1, iter 181, bin-batch id (81, 27)
# ShuffleIterator epoch 1, iter 182, bin-batch id (31, 31)
# ShuffleIterator epoch 1, iter 183, bin-batch id (81, 57)
# ShuffleIterator epoch 1, iter 184, bin-batch id (151, 44)
# ShuffleIterator epoch 1, iter 185, bin-batch id (61, 65)
# ShuffleIterator epoch 1, iter 186, bin-batch id (41, 88)
# ShuffleIterator epoch 1, iter 187, bin-batch id (111, 60)
# ShuffleIterator epoch 1, iter 188, bin-batch id (71, 43)
# ShuffleIterator epoch 1, iter 189, bin-batch id (61, 71)
# ShuffleIterator epoch 1, iter 190, bin-batch id (81, 25)
# ShuffleIterator epoch 1, iter 191, bin-batch id (111, 43)
# ShuffleIterator epoch 1, iter 192, bin-batch id (61, 92)
# ShuffleIterator epoch 1, iter 193, bin-batch id (61, 56)
# ShuffleIterator epoch 1, iter 194, bin-batch id (31, 4)
# ShuffleIterator epoch 1, iter 195, bin-batch id (151, 9)
# ShuffleIterator epoch 1, iter 196, bin-batch id (51, 51)
# ShuffleIterator epoch 1, iter 197, bin-batch id (71, 31)
# ShuffleIterator epoch 1, iter 198, bin-batch id (111, 66)
# ShuffleIterator epoch 1, iter 199, bin-batch id (111, 41)
# ShuffleIterator epoch 1, iter 200, bin-batch id (151, 25)
# ShuffleIterator epoch 1, iter 201, bin-batch id (51, 57)
# ShuffleIterator epoch 1, iter 202, bin-batch id (71, 76)
# ShuffleIterator epoch 1, iter 203, bin-batch id (111, 29)
# ShuffleIterator epoch 1, iter 204, bin-batch id (61, 54)
# ShuffleIterator epoch 1, iter 205, bin-batch id (111, 1)
# ShuffleIterator epoch 1, iter 206, bin-batch id (81, 45)
# ShuffleIterator epoch 1, iter 207, bin-batch id (71, 38)
# ShuffleIterator epoch 1, iter 208, bin-batch id (71, 5)
# ShuffleIterator epoch 1, iter 209, bin-batch id (91, 26)
# ShuffleIterator epoch 1, iter 210, bin-batch id (81, 41)
# ShuffleIterator epoch 1, iter 211, bin-batch id (51, 25)
# ShuffleIterator epoch 1, iter 212, bin-batch id (111, 56)
# ShuffleIterator epoch 1, iter 213, bin-batch id (41, 20)
# ShuffleIterator epoch 1, iter 214, bin-batch id (71, 34)
# ShuffleIterator epoch 1, iter 215, bin-batch id (81, 60)
# ShuffleIterator epoch 1, iter 216, bin-batch id (151, 14)
# ShuffleIterator epoch 1, iter 217, bin-batch id (31, 26)
# ShuffleIterator epoch 1, iter 218, bin-batch id (61, 50)
# ShuffleIterator epoch 1, iter 219, bin-batch id (31, 32)
# ShuffleIterator epoch 1, iter 220, bin-batch id (61, 53)
# ShuffleIterator epoch 1, iter 221, bin-batch id (151, 34)
# ShuffleIterator epoch 1, iter 222, bin-batch id (41, 62)
# ShuffleIterator epoch 1, iter 223, bin-batch id (81, 53)
# ShuffleIterator epoch 1, iter 224, bin-batch id (71, 67)
# ShuffleIterator epoch 1, iter 225, bin-batch id (91, 18)
# ShuffleIterator epoch 1, iter 226, bin-batch id (61, 31)
# ShuffleIterator epoch 1, iter 227, bin-batch id (31, 16)
# ShuffleIterator epoch 1, iter 228, bin-batch id (41, 56)
# ShuffleIterator epoch 1, iter 229, bin-batch id (51, 12)
# ShuffleIterator epoch 1, iter 230, bin-batch id (151, 20)
# ShuffleIterator epoch 1, iter 231, bin-batch id (61, 67)
# ShuffleIterator epoch 1, iter 232, bin-batch id (151, 43)
# ShuffleIterator epoch 1, iter 233, bin-batch id (111, 12)
# ShuffleIterator epoch 1, iter 234, bin-batch id (41, 53)
# ShuffleIterator epoch 1, iter 235, bin-batch id (51, 87)
# ShuffleIterator epoch 1, iter 236, bin-batch id (71, 53)
# ShuffleIterator epoch 1, iter 237, bin-batch id (31, 35)
# ShuffleIterator epoch 1, iter 238, bin-batch id (111, 64)
# ShuffleIterator epoch 1, iter 239, bin-batch id (71, 36)
# ShuffleIterator epoch 1, iter 240, bin-batch id (71, 8)
# ShuffleIterator epoch 1, iter 241, bin-batch id (41, 41)
# ShuffleIterator epoch 1, iter 242, bin-batch id (51, 77)
# ShuffleIterator epoch 1, iter 243, bin-batch id (61, 19)
# ShuffleIterator epoch 1, iter 244, bin-batch id (51, 61)
# ShuffleIterator epoch 1, iter 245, bin-batch id (71, 56)
# ShuffleIterator epoch 1, iter 246, bin-batch id (81, 48)
# ShuffleIterator epoch 1, iter 247, bin-batch id (31, 13)
# ShuffleIterator epoch 1, iter 248, bin-batch id (151, 8)
# ShuffleIterator epoch 1, iter 249, bin-batch id (151, 5)
# ShuffleIterator epoch 1, iter 250, bin-batch id (61, 55)
# ShuffleIterator epoch 1, iter 251, bin-batch id (91, 23)
# ShuffleIterator epoch 1, iter 252, bin-batch id (111, 48)
# ShuffleIterator epoch 1, iter 253, bin-batch id (71, 26)
# ShuffleIterator epoch 1, iter 254, bin-batch id (41, 8)
# ShuffleIterator epoch 1, iter 255, bin-batch id (151, 51)
# ShuffleIterator epoch 1, iter 256, bin-batch id (81, 35)
# ShuffleIterator epoch 1, iter 257, bin-batch id (61, 4)
# ShuffleIterator epoch 1, iter 258, bin-batch id (31, 33)
# ShuffleIterator epoch 1, iter 259, bin-batch id (111, 47)
# ShuffleIterator epoch 1, iter 260, bin-batch id (151, 55)
# ShuffleIterator epoch 1, iter 261, bin-batch id (151, 47)
# ShuffleIterator epoch 1, iter 262, bin-batch id (61, 90)
# ShuffleIterator epoch 1, iter 263, bin-batch id (51, 68)
# ShuffleIterator epoch 1, iter 264, bin-batch id (51, 21)
# ShuffleIterator epoch 1, iter 265, bin-batch id (61, 95)
# ShuffleIterator epoch 1, iter 266, bin-batch id (51, 19)
# ShuffleIterator epoch 1, iter 267, bin-batch id (111, 51)
# ShuffleIterator epoch 1, iter 268, bin-batch id (31, 8)
# ShuffleIterator epoch 1, iter 269, bin-batch id (151, 52)
# ShuffleIterator epoch 1, iter 270, bin-batch id (111, 13)
# ShuffleIterator epoch 1, iter 271, bin-batch id (61, 38)
# ShuffleIterator epoch 1, iter 272, bin-batch id (151, 19)
# ShuffleIterator epoch 1, iter 273, bin-batch id (41, 64)
# ShuffleIterator epoch 1, iter 274, bin-batch id (41, 14)
# ShuffleIterator epoch 1, iter 275, bin-batch id (31, 6)
# ShuffleIterator epoch 1, iter 276, bin-batch id (41, 26)
# ShuffleIterator epoch 1, iter 277, bin-batch id (31, 30)
# ShuffleIterator epoch 1, iter 278, bin-batch id (31, 9)
# ShuffleIterator epoch 1, iter 279, bin-batch id (81, 17)
# ShuffleIterator epoch 1, iter 280, bin-batch id (151, 16)
# ShuffleIterator epoch 1, iter 281, bin-batch id (151, 21)
# ShuffleIterator epoch 1, iter 282, bin-batch id (91, 0)
# ShuffleIterator epoch 1, iter 283, bin-batch id (51, 40)
# ShuffleIterator epoch 1, iter 284, bin-batch id (61, 11)
# ShuffleIterator epoch 1, iter 285, bin-batch id (51, 37)
# ShuffleIterator epoch 1, iter 286, bin-batch id (71, 18)
# ShuffleIterator epoch 1, iter 287, bin-batch id (51, 33)
# ShuffleIterator epoch 1, iter 288, bin-batch id (81, 55)
# ShuffleIterator epoch 1, iter 289, bin-batch id (51, 18)
# ShuffleIterator epoch 1, iter 290, bin-batch id (151, 1)
# ShuffleIterator epoch 1, iter 291, bin-batch id (61, 0)
# ShuffleIterator epoch 1, iter 292, bin-batch id (61, 33)
# ShuffleIterator epoch 1, iter 293, bin-batch id (41, 68)
# ShuffleIterator epoch 1, iter 294, bin-batch id (31, 3)
# ShuffleIterator epoch 1, iter 295, bin-batch id (81, 46)
# ShuffleIterator epoch 1, iter 296, bin-batch id (81, 1)
# ShuffleIterator epoch 1, iter 297, bin-batch id (81, 18)
# ShuffleIterator epoch 1, iter 298, bin-batch id (111, 36)
# ShuffleIterator epoch 1, iter 299, bin-batch id (81, 3)
# ShuffleIterator epoch 1, iter 300, bin-batch id (91, 19)
# ShuffleIterator epoch 1, iter 301, bin-batch id (71, 10)
# ShuffleIterator epoch 1, iter 302, bin-batch id (41, 84)
# ShuffleIterator epoch 1, iter 303, bin-batch id (91, 46)
# ShuffleIterator epoch 1, iter 304, bin-batch id (111, 28)
# ShuffleIterator epoch 1, iter 305, bin-batch id (61, 34)
# ShuffleIterator epoch 1, iter 306, bin-batch id (61, 94)
# ShuffleIterator epoch 1, iter 307, bin-batch id (71, 27)
# ShuffleIterator epoch 1, iter 308, bin-batch id (41, 60)
# ShuffleIterator epoch 1, iter 309, bin-batch id (51, 98)
# ShuffleIterator epoch 1, iter 310, bin-batch id (151, 27)
# ShuffleIterator epoch 1, iter 311, bin-batch id (51, 32)
# ShuffleIterator epoch 1, iter 312, bin-batch id (71, 79)
# ShuffleIterator epoch 1, iter 313, bin-batch id (111, 50)
# ShuffleIterator epoch 1, iter 314, bin-batch id (151, 45)
# ShuffleIterator epoch 1, iter 315, bin-batch id (81, 33)
# ShuffleIterator epoch 1, iter 316, bin-batch id (111, 0)
# ShuffleIterator epoch 1, iter 317, bin-batch id (91, 6)
# ShuffleIterator epoch 1, iter 318, bin-batch id (91, 22)
# ShuffleIterator epoch 1, iter 319, bin-batch id (41, 48)
# ShuffleIterator epoch 1, iter 320, bin-batch id (91, 16)
# ShuffleIterator epoch 1, iter 321, bin-batch id (61, 91)
# ShuffleIterator epoch 1, iter 322, bin-batch id (41, 91)
# ShuffleIterator epoch 1, iter 323, bin-batch id (51, 84)
# ShuffleIterator epoch 1, iter 324, bin-batch id (61, 70)
# ShuffleIterator epoch 1, iter 325, bin-batch id (61, 12)
# ShuffleIterator epoch 1, iter 326, bin-batch id (81, 40)
# ShuffleIterator epoch 1, iter 327, bin-batch id (111, 17)
# ShuffleIterator epoch 1, iter 328, bin-batch id (61, 52)
# ShuffleIterator epoch 1, iter 329, bin-batch id (71, 19)
# ShuffleIterator epoch 1, iter 330, bin-batch id (81, 20)
# ShuffleIterator epoch 1, iter 331, bin-batch id (41, 10)
# ShuffleIterator epoch 1, iter 332, bin-batch id (41, 96)
# ShuffleIterator epoch 1, iter 333, bin-batch id (41, 95)
# ShuffleIterator epoch 1, iter 334, bin-batch id (151, 28)
# ShuffleIterator epoch 1, iter 335, bin-batch id (111, 59)
# ShuffleIterator epoch 1, iter 336, bin-batch id (61, 96)
# ShuffleIterator epoch 1, iter 337, bin-batch id (91, 39)
# ShuffleIterator epoch 1, iter 338, bin-batch id (71, 21)
# ShuffleIterator epoch 1, iter 339, bin-batch id (71, 44)
# ShuffleIterator epoch 1, iter 340, bin-batch id (41, 87)
# ShuffleIterator epoch 1, iter 341, bin-batch id (51, 16)
# ShuffleIterator epoch 1, iter 342, bin-batch id (71, 78)
# ShuffleIterator epoch 1, iter 343, bin-batch id (61, 15)
# ShuffleIterator epoch 1, iter 344, bin-batch id (61, 39)
# ShuffleIterator epoch 1, iter 345, bin-batch id (31, 44)
# ShuffleIterator epoch 1, iter 346, bin-batch id (111, 61)
# ShuffleIterator epoch 1, iter 347, bin-batch id (61, 48)
# ShuffleIterator epoch 1, iter 348, bin-batch id (61, 73)
# ShuffleIterator epoch 1, iter 349, bin-batch id (71, 63)
# ShuffleIterator epoch 1, iter 350, bin-batch id (51, 60)
# ShuffleIterator epoch 1, iter 351, bin-batch id (61, 17)
# ShuffleIterator epoch 1, iter 352, bin-batch id (81, 11)
# ShuffleIterator epoch 1, iter 353, bin-batch id (41, 5)
# ShuffleIterator epoch 1, iter 354, bin-batch id (81, 28)
# ShuffleIterator epoch 1, iter 355, bin-batch id (151, 12)
# ShuffleIterator epoch 1, iter 356, bin-batch id (71, 64)
# ShuffleIterator epoch 1, iter 357, bin-batch id (41, 83)
# ShuffleIterator epoch 1, iter 358, bin-batch id (111, 40)
# ShuffleIterator epoch 1, iter 359, bin-batch id (51, 110)
# ShuffleIterator epoch 1, iter 360, bin-batch id (41, 58)
# ShuffleIterator epoch 1, iter 361, bin-batch id (91, 27)
# ShuffleIterator epoch 1, iter 362, bin-batch id (51, 26)
# ShuffleIterator epoch 1, iter 363, bin-batch id (51, 27)
# ShuffleIterator epoch 1, iter 364, bin-batch id (71, 57)
# ShuffleIterator epoch 1, iter 365, bin-batch id (41, 90)
# ShuffleIterator epoch 1, iter 366, bin-batch id (71, 61)
# ShuffleIterator epoch 1, iter 367, bin-batch id (91, 11)
# ShuffleIterator epoch 1, iter 368, bin-batch id (91, 2)
# ShuffleIterator epoch 1, iter 369, bin-batch id (61, 23)
# ShuffleIterator epoch 1, iter 370, bin-batch id (41, 19)
# ShuffleIterator epoch 1, iter 371, bin-batch id (151, 7)
# ShuffleIterator epoch 1, iter 372, bin-batch id (61, 85)
# ShuffleIterator epoch 1, iter 373, bin-batch id (41, 18)
# ShuffleIterator epoch 1, iter 374, bin-batch id (91, 8)
# ShuffleIterator epoch 1, iter 375, bin-batch id (41, 35)
# ShuffleIterator epoch 1, iter 376, bin-batch id (41, 7)
# ShuffleIterator epoch 1, iter 377, bin-batch id (31, 25)
# ShuffleIterator epoch 1, iter 378, bin-batch id (111, 15)
# ShuffleIterator epoch 1, iter 379, bin-batch id (91, 33)
# ShuffleIterator epoch 1, iter 380, bin-batch id (51, 100)
# ShuffleIterator epoch 1, iter 381, bin-batch id (91, 47)
# ShuffleIterator epoch 1, iter 382, bin-batch id (51, 36)
# ShuffleIterator epoch 1, iter 383, bin-batch id (71, 73)
# ShuffleIterator epoch 1, iter 384, bin-batch id (51, 49)
# ShuffleIterator epoch 1, iter 385, bin-batch id (91, 40)
# ShuffleIterator epoch 1, iter 386, bin-batch id (71, 6)
# ShuffleIterator epoch 1, iter 387, bin-batch id (51, 67)
# ShuffleIterator epoch 1, iter 388, bin-batch id (51, 104)
# ShuffleIterator epoch 1, iter 389, bin-batch id (41, 94)
# ShuffleIterator epoch 1, iter 390, bin-batch id (41, 98)
# ShuffleIterator epoch 1, iter 391, bin-batch id (31, 27)
# ShuffleIterator epoch 1, iter 392, bin-batch id (51, 10)
# ShuffleIterator epoch 1, iter 393, bin-batch id (31, 42)
# ShuffleIterator epoch 1, iter 394, bin-batch id (51, 109)
# ShuffleIterator epoch 1, iter 395, bin-batch id (51, 88)
# ShuffleIterator epoch 1, iter 396, bin-batch id (71, 52)
# ShuffleIterator epoch 1, iter 397, bin-batch id (31, 21)
# ShuffleIterator epoch 1, iter 398, bin-batch id (41, 82)
# ShuffleIterator epoch 1, iter 399, bin-batch id (71, 65)
# ShuffleIterator epoch 1, iter 400, bin-batch id (41, 65)
# ShuffleIterator epoch 1, iter 401, bin-batch id (41, 57)
# ShuffleIterator epoch 1, iter 402, bin-batch id (41, 97)
# ShuffleIterator epoch 1, iter 403, bin-batch id (51, 53)
# ShuffleIterator epoch 1, iter 404, bin-batch id (41, 63)
# ShuffleIterator epoch 1, iter 405, bin-batch id (91, 43)
# ShuffleIterator epoch 1, iter 406, bin-batch id (61, 57)
# ShuffleIterator epoch 1, iter 407, bin-batch id (71, 72)
# ShuffleIterator epoch 1, iter 408, bin-batch id (41, 47)
# ShuffleIterator epoch 1, iter 409, bin-batch id (151, 38)
# ShuffleIterator epoch 1, iter 410, bin-batch id (41, 78)
# ShuffleIterator epoch 1, iter 411, bin-batch id (41, 17)
# ShuffleIterator epoch 1, iter 412, bin-batch id (111, 19)
# ShuffleIterator epoch 1, iter 413, bin-batch id (91, 30)
# ShuffleIterator epoch 1, iter 414, bin-batch id (91, 45)
# ShuffleIterator epoch 1, iter 415, bin-batch id (51, 92)
# ShuffleIterator epoch 1, iter 416, bin-batch id (61, 26)
# ShuffleIterator epoch 1, iter 417, bin-batch id (91, 25)
# ShuffleIterator epoch 1, iter 418, bin-batch id (51, 5)
# ShuffleIterator epoch 1, iter 419, bin-batch id (61, 22)
# ShuffleIterator epoch 1, iter 420, bin-batch id (71, 59)
# ShuffleIterator epoch 1, iter 421, bin-batch id (81, 2)
# ShuffleIterator epoch 1, iter 422, bin-batch id (51, 105)
# ShuffleIterator epoch 1, iter 423, bin-batch id (71, 60)
# ShuffleIterator epoch 1, iter 424, bin-batch id (151, 48)
# ShuffleIterator epoch 1, iter 425, bin-batch id (51, 93)
# ShuffleIterator epoch 1, iter 426, bin-batch id (71, 62)
# ShuffleIterator epoch 1, iter 427, bin-batch id (31, 15)
# ShuffleIterator epoch 1, iter 428, bin-batch id (81, 54)
# ShuffleIterator epoch 1, iter 429, bin-batch id (51, 76)
# ShuffleIterator epoch 1, iter 430, bin-batch id (111, 26)
# ShuffleIterator epoch 1, iter 431, bin-batch id (91, 17)
# ShuffleIterator epoch 1, iter 432, bin-batch id (71, 47)
# ShuffleIterator epoch 1, iter 433, bin-batch id (51, 90)
# ShuffleIterator epoch 1, iter 434, bin-batch id (151, 10)
# ShuffleIterator epoch 1, iter 435, bin-batch id (51, 39)
# ShuffleIterator epoch 1, iter 436, bin-batch id (41, 24)
# ShuffleIterator epoch 1, iter 437, bin-batch id (31, 29)
# ShuffleIterator epoch 1, iter 438, bin-batch id (31, 38)
# ShuffleIterator epoch 1, iter 439, bin-batch id (51, 74)
# ShuffleIterator epoch 1, iter 440, bin-batch id (71, 24)
# ShuffleIterator epoch 1, iter 441, bin-batch id (51, 70)
# ShuffleIterator epoch 1, iter 442, bin-batch id (91, 24)
# ShuffleIterator epoch 1, iter 443, bin-batch id (41, 40)
# ShuffleIterator epoch 1, iter 444, bin-batch id (81, 38)
# ShuffleIterator epoch 1, iter 445, bin-batch id (31, 40)
# ShuffleIterator epoch 1, iter 446, bin-batch id (111, 32)
# ShuffleIterator epoch 1, iter 447, bin-batch id (41, 86)
# ShuffleIterator epoch 1, iter 448, bin-batch id (41, 80)
# ShuffleIterator epoch 1, iter 449, bin-batch id (41, 81)
# ShuffleIterator epoch 1, iter 450, bin-batch id (71, 30)
# ShuffleIterator epoch 1, iter 451, bin-batch id (51, 38)
# ShuffleIterator epoch 1, iter 452, bin-batch id (151, 11)
# ShuffleIterator epoch 1, iter 453, bin-batch id (91, 15)
# ShuffleIterator epoch 1, iter 454, bin-batch id (51, 45)
# ShuffleIterator epoch 1, iter 455, bin-batch id (81, 49)
# ShuffleIterator epoch 1, iter 456, bin-batch id (111, 58)
# ShuffleIterator epoch 1, iter 457, bin-batch id (61, 35)
# ShuffleIterator epoch 1, iter 458, bin-batch id (71, 39)
# ShuffleIterator epoch 1, iter 459, bin-batch id (91, 13)
# ShuffleIterator epoch 1, iter 460, bin-batch id (91, 34)
# ShuffleIterator epoch 1, iter 461, bin-batch id (151, 30)
# ShuffleIterator epoch 1, iter 462, bin-batch id (81, 24)
# ShuffleIterator epoch 1, iter 463, bin-batch id (31, 48)
# ShuffleIterator epoch 1, iter 464, bin-batch id (51, 1)
# ShuffleIterator epoch 1, iter 465, bin-batch id (61, 29)
# ShuffleIterator epoch 1, iter 466, bin-batch id (71, 66)
# ShuffleIterator epoch 1, iter 467, bin-batch id (51, 24)
# ShuffleIterator epoch 1, iter 468, bin-batch id (41, 27)
# ShuffleIterator epoch 1, iter 469, bin-batch id (91, 4)
# ShuffleIterator epoch 1, iter 470, bin-batch id (51, 31)
# ShuffleIterator epoch 1, iter 471, bin-batch id (41, 59)
# ShuffleIterator epoch 1, iter 472, bin-batch id (71, 32)
# ShuffleIterator epoch 1, iter 473, bin-batch id (91, 49)
# ShuffleIterator epoch 1, iter 474, bin-batch id (61, 27)
# ShuffleIterator epoch 1, iter 475, bin-batch id (91, 35)
# ShuffleIterator epoch 1, iter 476, bin-batch id (111, 55)
# ShuffleIterator epoch 1, iter 477, bin-batch id (81, 23)
# ShuffleIterator epoch 1, iter 478, bin-batch id (61, 64)
# ShuffleIterator epoch 1, iter 479, bin-batch id (61, 41)
# ShuffleIterator epoch 1, iter 480, bin-batch id (81, 16)
# ShuffleIterator epoch 1, iter 481, bin-batch id (61, 86)
# ShuffleIterator epoch 1, iter 482, bin-batch id (51, 89)
# ShuffleIterator epoch 1, iter 483, bin-batch id (61, 78)
# ShuffleIterator epoch 1, iter 484, bin-batch id (41, 37)
# ShuffleIterator epoch 1, iter 485, bin-batch id (81, 59)
# ShuffleIterator epoch 1, iter 486, bin-batch id (111, 46)
# ShuffleIterator epoch 1, iter 487, bin-batch id (51, 55)
# ShuffleIterator epoch 1, iter 488, bin-batch id (41, 66)
# ShuffleIterator epoch 1, iter 489, bin-batch id (111, 38)
# ShuffleIterator epoch 1, iter 490, bin-batch id (151, 2)
# ShuffleIterator epoch 1, iter 491, bin-batch id (31, 11)
# ShuffleIterator epoch 1, iter 492, bin-batch id (41, 22)
# ShuffleIterator epoch 1, iter 493, bin-batch id (61, 97)
# ShuffleIterator epoch 1, iter 494, bin-batch id (61, 28)
# ShuffleIterator epoch 1, iter 495, bin-batch id (71, 54)
# ShuffleIterator epoch 1, iter 496, bin-batch id (31, 34)
# ShuffleIterator epoch 1, iter 497, bin-batch id (51, 4)
# ShuffleIterator epoch 1, iter 498, bin-batch id (41, 43)
# ShuffleIterator epoch 1, iter 499, bin-batch id (61, 6)
# ShuffleIterator epoch 1, iter 500, bin-batch id (61, 8)
# ShuffleIterator epoch 1, iter 501, bin-batch id (71, 68)
# ShuffleIterator epoch 1, iter 502, bin-batch id (31, 41)
# ShuffleIterator epoch 1, iter 503, bin-batch id (61, 83)
# ShuffleIterator epoch 1, iter 504, bin-batch id (111, 5)
# ShuffleIterator epoch 1, iter 505, bin-batch id (51, 50)
# ShuffleIterator epoch 1, iter 506, bin-batch id (51, 46)
# ShuffleIterator epoch 1, iter 507, bin-batch id (81, 5)
# ShuffleIterator epoch 1, iter 508, bin-batch id (41, 34)
# ShuffleIterator epoch 1, iter 509, bin-batch id (81, 51)
# ShuffleIterator epoch 1, iter 510, bin-batch id (71, 55)
# ShuffleIterator epoch 1, iter 511, bin-batch id (31, 14)
# ShuffleIterator epoch 1, iter 512, bin-batch id (151, 50)
# ShuffleIterator epoch 1, iter 513, bin-batch id (91, 44)
# ShuffleIterator epoch 1, iter 514, bin-batch id (31, 36)
# ShuffleIterator epoch 1, iter 515, bin-batch id (61, 82)
# ShuffleIterator epoch 1, iter 516, bin-batch id (41, 92)
# ShuffleIterator epoch 1, iter 517, bin-batch id (81, 21)
# ShuffleIterator epoch 1, iter 518, bin-batch id (71, 1)
# ShuffleIterator epoch 1, iter 519, bin-batch id (61, 46)
# ShuffleIterator epoch 1, iter 520, bin-batch id (111, 20)
# ShuffleIterator epoch 1, iter 521, bin-batch id (81, 36)
# ShuffleIterator epoch 1, iter 522, bin-batch id (61, 45)
# ShuffleIterator epoch 1, iter 523, bin-batch id (41, 16)
# ShuffleIterator epoch 1, iter 524, bin-batch id (61, 13)
# ShuffleIterator epoch 1, iter 525, bin-batch id (51, 107)
# ShuffleIterator epoch 1, iter 526, bin-batch id (81, 47)
# ShuffleIterator epoch 1, iter 527, bin-batch id (91, 38)
# ShuffleIterator epoch 1, iter 528, bin-batch id (51, 79)
# ShuffleIterator epoch 1, iter 529, bin-batch id (71, 35)
# ShuffleIterator epoch 1, iter 530, bin-batch id (151, 4)
# ShuffleIterator epoch 1, iter 531, bin-batch id (41, 29)
# ShuffleIterator epoch 1, iter 532, bin-batch id (111, 18)
# ShuffleIterator epoch 1, iter 533, bin-batch id (71, 51)
# ShuffleIterator epoch 1, iter 534, bin-batch id (151, 41)
# ShuffleIterator epoch 1, iter 535, bin-batch id (51, 78)
# ShuffleIterator epoch 1, iter 536, bin-batch id (151, 49)
# ShuffleIterator epoch 1, iter 537, bin-batch id (41, 31)
# ShuffleIterator epoch 1, iter 538, bin-batch id (71, 69)
# ShuffleIterator epoch 1, iter 539, bin-batch id (71, 50)
# ShuffleIterator epoch 1, iter 540, bin-batch id (81, 62)
# ShuffleIterator epoch 1, iter 541, bin-batch id (81, 9)
# ShuffleIterator epoch 1, iter 542, bin-batch id (151, 18)
# ShuffleIterator epoch 1, iter 543, bin-batch id (41, 76)
# ShuffleIterator epoch 1, iter 544, bin-batch id (111, 8)
# ShuffleIterator epoch 1, iter 545, bin-batch id (71, 2)
# ShuffleIterator epoch 1, iter 546, bin-batch id (41, 44)
# ShuffleIterator epoch 1, iter 547, bin-batch id (71, 48)
# ShuffleIterator epoch 1, iter 548, bin-batch id (71, 71)
# ShuffleIterator epoch 1, iter 549, bin-batch id (61, 2)
# ShuffleIterator epoch 1, iter 550, bin-batch id (91, 28)
# ShuffleIterator epoch 1, iter 551, bin-batch id (61, 43)
# ShuffleIterator epoch 1, iter 552, bin-batch id (81, 26)
# ShuffleIterator epoch 1, iter 553, bin-batch id (61, 25)
# ShuffleIterator epoch 1, iter 554, bin-batch id (111, 35)
# ShuffleIterator epoch 1, iter 555, bin-batch id (31, 37)
# ShuffleIterator epoch 1, iter 556, bin-batch id (41, 46)
# ShuffleIterator epoch 1, iter 557, bin-batch id (61, 61)
# ShuffleIterator epoch 1, iter 558, bin-batch id (41, 4)
# ShuffleIterator epoch 1, iter 559, bin-batch id (51, 30)
# ShuffleIterator epoch 1, iter 560, bin-batch id (61, 10)
# ShuffleIterator epoch 1, iter 561, bin-batch id (31, 1)
# ShuffleIterator epoch 1, iter 562, bin-batch id (41, 21)
# ShuffleIterator epoch 1, iter 563, bin-batch id (51, 28)
# ShuffleIterator epoch 1, iter 564, bin-batch id (51, 83)
# ShuffleIterator epoch 1, iter 565, bin-batch id (61, 5)
# ShuffleIterator epoch 1, iter 566, bin-batch id (71, 42)
# ShuffleIterator epoch 1, iter 567, bin-batch id (41, 42)
# ShuffleIterator epoch 1, iter 568, bin-batch id (151, 54)
# ShuffleIterator epoch 1, iter 569, bin-batch id (71, 46)
# ShuffleIterator epoch 1, iter 570, bin-batch id (41, 15)
# ShuffleIterator epoch 1, iter 571, bin-batch id (51, 103)
# ShuffleIterator epoch 1, iter 572, bin-batch id (71, 12)
# ShuffleIterator epoch 1, iter 573, bin-batch id (111, 10)
# ShuffleIterator epoch 1, iter 574, bin-batch id (61, 16)
# ShuffleIterator epoch 1, iter 575, bin-batch id (51, 73)
# ShuffleIterator epoch 1, iter 576, bin-batch id (111, 57)
# ShuffleIterator epoch 1, iter 577, bin-batch id (81, 56)
# ShuffleIterator epoch 1, iter 578, bin-batch id (61, 93)
# ShuffleIterator epoch 1, iter 579, bin-batch id (111, 25)
# ShuffleIterator epoch 1, iter 580, bin-batch id (31, 0)
# ShuffleIterator epoch 1, iter 581, bin-batch id (51, 75)
# ShuffleIterator epoch 1, iter 582, bin-batch id (91, 32)
# ShuffleIterator epoch 1, iter 583, bin-batch id (91, 37)
# ShuffleIterator epoch 1, iter 584, bin-batch id (71, 41)
# ShuffleIterator epoch 1, iter 585, bin-batch id (81, 32)
# ShuffleIterator epoch 1, iter 586, bin-batch id (91, 20)
# ShuffleIterator epoch 1, iter 587, bin-batch id (111, 44)
# ShuffleIterator epoch 1, iter 588, bin-batch id (71, 14)
# ShuffleIterator epoch 1, iter 589, bin-batch id (71, 17)
# ShuffleIterator epoch 1, iter 590, bin-batch id (51, 29)
# ShuffleIterator epoch 1, iter 591, bin-batch id (61, 3)
# ShuffleIterator epoch 1, iter 592, bin-batch id (111, 21)
# ShuffleIterator epoch 1, iter 593, bin-batch id (51, 66)
# ShuffleIterator epoch 1, iter 594, bin-batch id (41, 23)
# ShuffleIterator epoch 1, iter 595, bin-batch id (51, 97)
# ShuffleIterator epoch 1, iter 596, bin-batch id (61, 42)
# ShuffleIterator epoch 1, iter 597, bin-batch id (41, 75)
# ShuffleIterator epoch 1, iter 598, bin-batch id (51, 69)
# ShuffleIterator epoch 1, iter 599, bin-batch id (41, 61)
# ShuffleIterator epoch 1, iter 600, bin-batch id (151, 0)
# ShuffleIterator epoch 1, iter 601, bin-batch id (51, 17)
# ShuffleIterator epoch 1, iter 602, bin-batch id (61, 9)
# ShuffleIterator epoch 1, iter 603, bin-batch id (151, 3)
# ShuffleIterator epoch 1, iter 604, bin-batch id (51, 99)
# ShuffleIterator epoch 1, iter 605, bin-batch id (41, 51)
# ShuffleIterator epoch 1, iter 606, bin-batch id (41, 101)
# ShuffleIterator epoch 1, iter 607, bin-batch id (111, 11)
# ShuffleIterator epoch 1, iter 608, bin-batch id (51, 22)
# ShuffleIterator epoch 1, iter 609, bin-batch id (41, 11)
# ShuffleIterator epoch 1, iter 610, bin-batch id (41, 45)
# ShuffleIterator epoch 1, iter 611, bin-batch id (61, 59)
# ShuffleIterator epoch 1, iter 612, bin-batch id (71, 7)
# ShuffleIterator epoch 1, iter 613, bin-batch id (111, 45)
# ShuffleIterator epoch 1, iter 614, bin-batch id (51, 8)
# ShuffleIterator epoch 1, iter 615, bin-batch id (51, 102)
# ShuffleIterator epoch 1, iter 616, bin-batch id (41, 38)
# ShuffleIterator epoch 1, iter 617, bin-batch id (51, 71)
# ShuffleIterator epoch 1, iter 618, bin-batch id (31, 28)
# ShuffleIterator epoch 1, iter 619, bin-batch id (61, 21)
# ShuffleIterator epoch 1, iter 620, bin-batch id (151, 40)
# ShuffleIterator epoch 1, iter 621, bin-batch id (81, 31)
# ShuffleIterator epoch 1, iter 622, bin-batch id (41, 52)
# ShuffleIterator epoch 1, iter 623, bin-batch id (41, 93)
# ShuffleIterator epoch 1, iter 624, bin-batch id (51, 94)
# ShuffleIterator epoch 1, iter 625, bin-batch id (151, 26)
# ShuffleIterator epoch 1, iter 626, bin-batch id (31, 43)
# ShuffleIterator epoch 1, iter 627, bin-batch id (111, 4)
# ShuffleIterator epoch 1, iter 628, bin-batch id (51, 91)
# ShuffleIterator epoch 1, iter 629, bin-batch id (51, 62)
# ShuffleIterator epoch 1, iter 630, bin-batch id (61, 30)
# ShuffleIterator epoch 1, iter 631, bin-batch id (41, 0)
# ShuffleIterator epoch 1, iter 632, bin-batch id (81, 4)
# ShuffleIterator epoch 1, iter 633, bin-batch id (151, 15)
# ShuffleIterator epoch 1, iter 634, bin-batch id (41, 9)
# ShuffleIterator epoch 1, iter 635, bin-batch id (111, 33)
# ShuffleIterator epoch 1, iter 636, bin-batch id (31, 47)
# ShuffleIterator epoch 1, iter 637, bin-batch id (61, 32)
# ShuffleIterator epoch 1, iter 638, bin-batch id (51, 80)
# ShuffleIterator epoch 1, iter 639, bin-batch id (71, 0)
# ShuffleIterator epoch 1, iter 640, bin-batch id (91, 21)
# ShuffleIterator epoch 1, iter 641, bin-batch id (71, 28)
# ShuffleIterator epoch 1, iter 642, bin-batch id (81, 63)
# ShuffleIterator epoch 1, iter 643, bin-batch id (51, 14)
# ShuffleIterator epoch 1, iter 644, bin-batch id (81, 30)
# ShuffleIterator epoch 1, iter 645, bin-batch id (71, 70)
# ShuffleIterator epoch 1, iter 646, bin-batch id (151, 29)
# ShuffleIterator epoch 1, iter 647, bin-batch id (91, 31)
# ShuffleIterator epoch 1, iter 648, bin-batch id (71, 16)
# ShuffleIterator epoch 1, iter 649, bin-batch id (151, 13)
# ShuffleIterator epoch 1, iter 650, bin-batch id (41, 12)
# ShuffleIterator epoch 1, iter 651, bin-batch id (81, 52)
# ShuffleIterator epoch 1, iter 652, bin-batch id (51, 59)
# ShuffleIterator epoch 1, iter 653, bin-batch id (61, 51)
# ShuffleIterator epoch 1, iter 654, bin-batch id (111, 7)
# ShuffleIterator epoch 1, iter 655, bin-batch id (51, 9)
# ShuffleIterator epoch 1, iter 656, bin-batch id (111, 42)
# ShuffleIterator epoch 1, iter 657, bin-batch id (41, 70)
# ShuffleIterator epoch 1, iter 658, bin-batch id (51, 11)
# ShuffleIterator epoch 1, iter 659, bin-batch id (111, 39)
# ShuffleIterator epoch 1, iter 660, bin-batch id (41, 73)
# ShuffleIterator epoch 1, iter 661, bin-batch id (111, 22)
# ShuffleIterator epoch 1, iter 662, bin-batch id (41, 36)
# ShuffleIterator epoch 1, iter 663, bin-batch id (111, 54)
# ShuffleIterator epoch 1, iter 664, bin-batch id (91, 29)
# ShuffleIterator epoch 1, iter 665, bin-batch id (81, 39)
# ShuffleIterator epoch 1, iter 666, bin-batch id (71, 33)
# ShuffleIterator epoch 1, iter 667, bin-batch id (51, 13)
# ShuffleIterator epoch 1, iter 668, bin-batch id (41, 49)
# ShuffleIterator epoch 1, iter 669, bin-batch id (71, 11)
# ShuffleIterator epoch 1, iter 670, bin-batch id (61, 60)
# ShuffleIterator epoch 1, iter 671, bin-batch id (51, 54)
# ShuffleIterator epoch 1, iter 672, bin-batch id (151, 53)
# ShuffleIterator epoch 1, iter 673, bin-batch id (41, 55)
# ShuffleIterator epoch 1, iter 674, bin-batch id (31, 12)
# ShuffleIterator epoch 1, iter 675, bin-batch id (51, 56)
# ShuffleIterator epoch 1, iter 676, bin-batch id (111, 63)
# ShuffleIterator epoch 1, iter 677, bin-batch id (91, 41)
# ShuffleIterator epoch 1, iter 678, bin-batch id (81, 0)
# ShuffleIterator epoch 1, iter 679, bin-batch id (31, 18)
# ShuffleIterator epoch 1, iter 680, bin-batch id (71, 20)
# ShuffleIterator epoch 1, iter 681, bin-batch id (51, 2)
# ShuffleIterator epoch 1, iter 682, bin-batch id (91, 5)
# ShuffleIterator epoch 1, iter 683, bin-batch id (51, 42)
# ShuffleIterator epoch 1, iter 684, bin-batch id (111, 62)
# ShuffleIterator finished epoch 1
# ShuffleIterator epoch 2, iter 1, bin-batch id (111, 42)
# ShuffleIterator epoch 2, iter 2, bin-batch id (71, 61)

# %%
# Out:
# <data_reader.BatchIterator object at 0x1040bdb90>

# %% [markdown]
# # End
