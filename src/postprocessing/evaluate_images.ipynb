# %% [markdown]
# # im2latex
#
# &copy; Copyright 2017-2018 Sumeet S Singh
#
#     This file is part of im2latex solution by Sumeet S Singh.
#
#     This program is free software: you can redistribute it and/or modify
#     it under the terms of the Affero GNU General Public License as published by
#     the Free Software Foundation, either version 3 of the License, or
#     (at your option) any later version.
#
#     This program is distributed in the hope that it will be useful,
#     but WITHOUT ANY WARRANTY; without even the implied warranty of
#     MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.  See the
#     Affero GNU General Public License for more details.
#
#     You should have received a copy of the Affero GNU General Public License
#     along with this program.  If not, see <http://www.gnu.org/licenses/>.

# %%
import sys
sys.path.extend(['../commons'])

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import pandas as pd
import os
import re
import codecs
from IPython.display import display, Math, Latex
from IPython.display import Image as ipImage
from six.moves import cPickle as pickle
import string
from PIL import Image
import numpy as np
import h5py
import matplotlib as mpl
from matplotlib import pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid
# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

# %%
pd.options.display.max_rows = 50
pd.options.display.max_colwidth = 600
pd.options.display.expand_frame_repr = False
pd.options.display.colheader_justify = 'left'

# %%
import data_commons as dtc
import dl_commons as dlc
import viz_commons as viz
from viz_commons import VisualizeDir, DiffParams, VisualizeStep
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Notebook Arguments
# ----------------------

# %%
# storedir = '/zpool_3TB/i2l/tb_metrics/2017-12-21 02-20-10 PST 140K_score_89.0/test_runs/step_00168100_score89.0_publish/store_2'
storedir = '/zpool_3TB/i2l/tb_metrics/2017-12-25 21-04-15 PST 140K_noRegroup_score89.09/test_runs/step_00167526_score89.0_publish/store_2'
# storedir = '/zpool_3TB/i2l/tb_metrics/2017-12-16 18-51-38 PST pLambda=0_score_88.86/test_runs/step_00132200_score88.19_publish/store_2'

clobber = False
dump = False

original_image_dir = '/zpool_3TB/i2l/data/dataset5/formula_images'
rel_dumpdir = 'eval_images'
dumpdir = os.path.join(storedir, rel_dumpdir)
rendered_dir = os.path.join(storedir, rel_dumpdir, 'rendered_images')

# %% [markdown]
# ____________________________________

# %%
vd = VisualizeDir(os.path.expanduser(storedir))
last_step = vd.view_steps()[1][-1]
print('last_step = %d' % last_step)
vs = VisualizeStep(vd, 'test', last_step)
df, df_result, df_data, sr_label = vs.get_preds(rel_dumpdir=rel_dumpdir, dump=dump, clobber=clobber)
# df = vs.dump_preds(rel_dumpdir=rel_dumpdir, dump=dump)
# Out:
# num eval_steps = 1
# eval_steps = [(167526, 146585)]
# all_steps = []
# last_step = 167526

# %%
df
# Out:
#                     image_name                  _iloc  ed        target_len target_seq                                                                                                                                                                                                                                                                                                                                                                                                                                                                          pred_len pred_seq
# eval_image_name
# eee6617cd7a8537.png  eee6617cd7a8537_basic.png     0   0.000000   44                                                                                                                                                                                                                                                                                                                                                                                            d s ^ { 2 } = d \chi ^ { 2 } + ( \chi ^ { 2 } + a ^ { 2 } ) d s _ { S _ { 3 } } ^ { 2 } ~ ~ .    44                                                                                                                                                                                                                                   d s ^ { 2 } = d \chi ^ { 2 } + ( \chi ^ { 2 } + a ^ { 2 } ) d s _ { S _ { 3 } } ^ { 2 } ~ ~ .
# 0b2f97c436e19de.png  0b2f97c436e19de_basic.png     1   0.000000   29                                                                                                                                                                                                                                                                                                                                                                                                    3 \nu ( \alpha - \beta ) = - ( \alpha + \beta ) \kappa _ { 5 } ^ { 2 } \rho _ { b } ,    29                                                                                                                                                                                                                                           3 \nu ( \alpha - \beta ) = - ( \alpha + \beta ) \kappa _ { 5 } ^ { 2 } \rho _ { b } ,
# 2f2cf9337c1061e.png  2f2cf9337c1061e_basic.png     2   0.000000   28                                                                                                                                                                                                                                                                                                                                                                                                               \gamma \Theta _ { \mu } ^ { a } = D _ { \mu } ^ { ( \Theta ) } C ^ { a } ,    28                                                                                                                                                                                                                                                      \gamma \Theta _ { \mu } ^ { a } = D _ { \mu } ^ { ( \Theta ) } C ^ { a } ,
# 31dd9e32c121762.png  31dd9e32c121762_basic.png     3   0.000000   25                                                                                                                                                                                                                                                                                                                                                                                                \epsilon ^ { \beta \gamma \delta } V _ { \alpha } C _ { \beta \gamma } ^ { \alpha } = 0 ,    25                                                                                                                                                                                                                                       \epsilon ^ { \beta \gamma \delta } V _ { \alpha } C _ { \beta \gamma } ^ { \alpha } = 0 ,
# 829ca274c518285.png  829ca274c518285_basic.png     4   0.000000   28                                                                                                                                                                                                                                                                                                                                                                                                             \mathrm { T r } ( \gamma _ { \theta } ) = - ( - 1 ) ^ { b / 2 } \times 4 ~ .    28                                                                                                                                                                                                                                                    \mathrm { T r } ( \gamma _ { \theta } ) = - ( - 1 ) ^ { b / 2 } \times 4 ~ .
# cdfb4e859f2c15c.png  cdfb4e859f2c15c_basic.png     5   0.000000   27                                                                                                                                                                                                                                                                                                                                                                                                            \frac { d I _ { 0 } ( \Omega ) } { d \Omega } = 2 \Omega I _ { 1 } ( \Omega )    27                                                                                                                                                                                                                                                   \frac { d I _ { 0 } ( \Omega ) } { d \Omega } = 2 \Omega I _ { 1 } ( \Omega )
# dafcf1e98dcf83b.png  dafcf1e98dcf83b_basic.png     6   0.000000   28                                                                                                                                                                                                                                                                                                                                                                                                   \omega _ { \mu \nu } = q _ { \mu } \epsilon _ { \nu } - \epsilon _ { \mu } q _ { \nu }    28                                                                                                                                                                                                                                          \omega _ { \mu \nu } = q _ { \mu } \epsilon _ { \nu } - \epsilon _ { \mu } q _ { \nu }
# a7f9dd30b186886.png  a7f9dd30b186886_basic.png     7   0.000000   27                                                                                                                                                                                                                                                                                                                                                                                                       J _ { \alpha \beta } = \frac { 2 ^ { n - 1 } } { f } \epsilon _ { \alpha \beta } ,    27                                                                                                                                                                                                                                              J _ { \alpha \beta } = \frac { 2 ^ { n - 1 } } { f } \epsilon _ { \alpha \beta } ,
# cca243fdbdcab18.png  cca243fdbdcab18_basic.png     8   0.000000   28                                                                                                                                                                                                                                                                                                                                                                                                                      x _ { \mu } \to R x _ { \mu } = \frac { x _ { \mu } } { x ^ { 2 } }    28                                                                                                                                                                                                                                                             x _ { \mu } \to R x _ { \mu } = \frac { x _ { \mu } } { x ^ { 2 } }
# fc9e5e734810e87.png  fc9e5e734810e87_basic.png     9   0.000000   27                                                                                                                                                                                                                                                                                                                                                                                                   \sigma _ { 2 } ( x ) = \lambda \left[ \delta ( x + a ) + \delta ( x - a ) \right] \, .    27                                                                                                                                                                                                                                          \sigma _ { 2 } ( x ) = \lambda \left[ \delta ( x + a ) + \delta ( x - a ) \right] \, .
# 84f6bad789b4ba6.png  84f6bad789b4ba6_basic.png    10   0.000000   26                                                                                                                                                                                                                                                                                                                                                                                                                             { \cal R } = { \cal D } _ { 1 } ^ { - 1 } { \cal D } _ { 2 }    26                                                                                                                                                                                                                                                                    { \cal R } = { \cal D } _ { 1 } ^ { - 1 } { \cal D } _ { 2 }
# 6743b9b0707a42f.png  6743b9b0707a42f_basic.png    11   0.000000   21                                                                                                                                                                                                                                                                                                                                                                                                                                 i \hat { V } _ { 4 } = - i \lambda \hat { \tau } _ { 3 }    21                                                                                                                                                                                                                                                                        i \hat { V } _ { 4 } = - i \lambda \hat { \tau } _ { 3 }
# acf900b1e36f0af.png  acf900b1e36f0af_basic.png    12   0.000000   27                                                                                                                                                                                                                                                                                                                                                                                                            { \cal D } _ { 2 } \rightarrow { \cal D } _ { 2 } + \alpha { \cal D } _ { 1 }    27                                                                                                                                                                                                                                                   { \cal D } _ { 2 } \rightarrow { \cal D } _ { 2 } + \alpha { \cal D } _ { 1 }
# e98b7ff35296825.png  e98b7ff35296825_basic.png    13   0.000000   29                                                                                                                                                                                                                                                                                                                                                                                       H \left( \Theta _ { \varepsilon } ( - X ^ { 0 } ) + \Theta _ { \varepsilon } ( X ^ { 0 } ) \right)    29                                                                                                                                                                                                                              H \left( \Theta _ { \varepsilon } ( - X ^ { 0 } ) + \Theta _ { \varepsilon } ( X ^ { 0 } ) \right)
# 255949d2e2eda44.png  255949d2e2eda44_basic.png    14   0.000000   27                                                                                                                                                                                                                                                                                                                                                                                                                              Z _ { 1 } ^ { * } W _ { S U ( 2 ) \otimes U ( 1 ) } ( K ) Z    27                                                                                                                                                                                                                                                                     Z _ { 1 } ^ { * } W _ { S U ( 2 ) \otimes U ( 1 ) } ( K ) Z
# e81ea076750ea2c.png  e81ea076750ea2c_basic.png    15   0.000000   28                                                                                                                                                                                                                                                                                                                                                                                                                     S _ { k I } = 4 - \frac { 4 \beta _ { k } } { a } + 2 \gamma _ { k }    28                                                                                                                                                                                                                                                            S _ { k I } = 4 - \frac { 4 \beta _ { k } } { a } + 2 \gamma _ { k }
# 42134c473e4a039.png  42134c473e4a039_basic.png    16   0.000000   29                                                                                                                                                                                                                                                                                                                                                                                   Q ^ { \alpha \beta } = \frac { 1 } { 2 } \left( \eta ^ { \alpha \beta } + D ^ { \alpha \beta } \right)    29                                                                                                                                                                                                                          Q ^ { \alpha \beta } = \frac { 1 } { 2 } \left( \eta ^ { \alpha \beta } + D ^ { \alpha \beta } \right)
# cf65a0e92c068bf.png  cf65a0e92c068bf_basic.png    17   0.000000   27                                                                                                                                                                                                                                                                                                                                                                                                                        \lambda _ { m } ^ { ( n - p - 1 ) } = \lambda _ { m } ^ { ( p ) }    27                                                                                                                                                                                                                                                               \lambda _ { m } ^ { ( n - p - 1 ) } = \lambda _ { m } ^ { ( p ) }
# 801659f3060f71b.png  801659f3060f71b_basic.png    18   0.000000   28                                                                                                                                                                                                                                                                                                                                                                                                         g _ { \mu } = \langle p h y s | A _ { \mu } M ^ { \dagger } ( k ) | \psi \rangle    28                                                                                                                                                                                                                                                g _ { \mu } = \langle p h y s | A _ { \mu } M ^ { \dagger } ( k ) | \psi \rangle
# 01d8937373bd071.png  01d8937373bd071_basic.png    19   0.000000   28                                                                                                                                                                                                                                                                                                                                                                                               S T = \left( \begin{array} { c c } { 0 } & { - 1 } \\ { 1 } & { 1 } \\ \end{array} \right)    28                                                                                                                                                                                                                                      S T = \left( \begin{array} { c c } { 0 } & { - 1 } \\ { 1 } & { 1 } \\ \end{array} \right)
# b17c890b3a46c47.png  b17c890b3a46c47_basic.png    20   0.000000   20                                                                                                                                                                                                                                                                                                                                                                                                    D = \frac { \partial } { \partial \theta } - \theta \frac { \partial } { \partial t }    20                                                                                                                                                                                                                                           D = \frac { \partial } { \partial \theta } - \theta \frac { \partial } { \partial t }
# d822acc2bccf7a5.png  d822acc2bccf7a5_basic.png    21   0.000000   20                                                                                                                                                                                                                                                                                                                                                                                                                                \Lambda ( i ) = \int _ { \Gamma ( i ) } d x \cdot A ( x )    20                                                                                                                                                                                                                                                                       \Lambda ( i ) = \int _ { \Gamma ( i ) } d x \cdot A ( x )
# 8424b245d97354d.png  8424b245d97354d_basic.png    22   0.000000   25                                                                                                                                                                                                                                                                                                                                                                                                         \kappa \left( \frac { 1 } { X } \right) ^ { \prime \prime } X ^ { - 2 } = c \, .    25                                                                                                                                                                                                                                                \kappa \left( \frac { 1 } { X } \right) ^ { \prime \prime } X ^ { - 2 } = c \, .
# 76be821cff8d49c.png  76be821cff8d49c_basic.png    23   0.000000    4                                                                                                                                                                                                                                                                                                                                                                                                                                                                             \Delta = 0 ,     4                                                                                                                                                                                                                                                                                                                    \Delta = 0 ,
# 54f6c2a7325e9df.png  54f6c2a7325e9df_basic.png    24   0.000000   20                                                                                                                                                                                                                                                                                                                                                                                                                                              x ^ { T } ( z ) = x ( \frac { 1 } { f z } )    20                                                                                                                                                                                                                                                                                     x ^ { T } ( z ) = x ( \frac { 1 } { f z } )
# ...                                        ...    ...       ...         ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...       ...                                                                                                                                                                                                                                                                                                                         ...
# 7397e09327bb521.png  7397e09327bb521_basic.png  4623   0.482759   29                                                                                                                                                                                                                                                                                                                                                                                                                   \eta \sp { i n } _ { j } = \eta \sp { o u t } _ { j } = \eta _ { j } ,    29                                                                                                                                                                                                                                                              \eta _ { j } ^ { i n } = \eta _ { j } ^ { o u t } = \eta _ { j } ,
# dbaed8f752f9348.png  dbaed8f752f9348_basic.png  4624   0.484848  132                                                                                           \begin{array} { c } { \Gamma ^ { M } \Gamma ^ { N } + \Gamma ^ { N } \Gamma ^ { M } = 2 \eta ^ { M N } , \qquad \eta ^ { M N } = ( + , - , - , \dots ) , } \\ { ( \Gamma ^ { M } ) ^ { * } = - \Gamma ^ { M } , \qquad ( \Gamma ^ { 0 } ) ^ { \mathrm { T } } = - \Gamma ^ { 0 } , \qquad ( \Gamma ^ { i } ) ^ { \mathrm { T } } = \Gamma ^ { i } , \quad i = 1 , \dots , 9 . } \\ \end{array}   113              ( n ^ { 1 M } ) ^ { \mathbf { M } ^ { M } \Gamma ^ { N } + \Gamma ^ { N } \Gamma ^ { M } = 2 \eta ^ { M N } . } \\ { + - \Gamma ^ { M } , } & { \Gamma ^ { 0 } \Gamma ^ { - } = - \Gamma ^ { 0 } , } & { \quad ( \Gamma ^ { i } ) ^ { T } = \Gamma ^ { i } , } & { i = 1 , z , \ldots , 2 } \\ \end{array} \right.
# d81ef356b8daac4.png  d81ef356b8daac4_basic.png  4625   0.485714   70                                                                                                                                                                                                                                                                                       \sum _ { \sigma \, \in \, S _ { M } } \; c _ { \vec { a } _ { \sigma 1 } \, + \, 2 ( \vec { a } _ { \sigma 2 } + \cdots + \vec { a } _ { \sigma M } ) , \vec { a } _ { \sigma 1 } } \; = \; 0 \; .    63                                                                                                                                                                \sum _ { \sigma \in S _ { M } } \; c _ { \sigma _ { a + 1 } + 2 ( q _ { 2 \kappa + 1 } , \dots + i _ { \sigma _ { M } ) } , d _ { \sigma _ { 1 } } } \ = \ 0 \ .
# a9bdbc6854bb0fd.png  a9bdbc6854bb0fd_basic.png  4626   0.486486   74                                                                                                                                                                                                                                                                             { F _ { \underline { { a b } } \mu \nu } } = { A _ { \underline { { a b } } [ \mu , \nu ] } } + { A _ { \underline { { c a } } [ \mu } A ^ { \underline { { c } } } { } _ { \underline { { b } } \nu ] } } .    76                                                                                             F _ { \underline { { a b } } \underline { d } \nu } = A _ { \underline { { a } } \underline { { b } } , d ) } + A _ { \underline { { c } } \underline { { a } } ] } A _ { ~ \underline { { b } } \underline { { \nu } } } ^ { [ } .
# 229334b1d025ca4.png  229334b1d025ca4_basic.png  4627   0.487179   39                                                                                                                                                                                                                                                                                                                                                                           { \cal G } / { \cal H } = \frac { \mathrm { O ( 5 , n ) } } { \mathrm { O ( 5 ) } \times \mathrm { O ( n ) } }    48                                                                                                                                                                                        { \cal G } / { \cal H } = \frac { ( { \bf 5 } ( \mathrm { v } _ { 1 } ) } { \mathrm { O } ( 5 ) \times \mathrm { O } ( \mathrm { m } ) }
# 00b02fc405ab9d7.png  00b02fc405ab9d7_basic.png  4628   0.487179   39                                                                                                                                                                                                                                                                                                                                                                                      z _ { k } = i e ^ { - \theta _ { k } } e ^ { - i \pi \frac { \left( 1 + c ( k ) \right) } { 2 h } }    49                                                                                                                                                                                                             { z _ { k } } = i e ^ { - \theta _ { k } } e ^ { - i { \frac { 1 } { 2 R } } { \frac { ( \alpha + b ) } { 2 } } ) }
# d9a554e11488fc4.png  d9a554e11488fc4_basic.png  4629   0.494737   95                                                                                                                                                                                                                                   E _ { T O T } \ \sim \ \underbrace { \frac { \beta ^ { 2 } { \cal A } } { \alpha R ^ { 2 } } } _ { E _ { c l a s s } } \ + \ \underbrace { \frac { \beta ^ { 2 } { \cal B } + \beta ^ { 4 } { \cal C } } { R ^ { 2 } } } _ { E _ { v a c u u m } } \ ,    83                                                                                                                E _ { T O T } \ \sim \ \frac { \rho _ { + } ^ { 2 } A } { \operatorname { d } { E _ { e } ^ { 2 } } } \, - \frac { \beta ^ { 2 } \vec { R } + \beta ^ { 4 } - } { - \frac { R } { R a ^ { 2 } e _ { n } } } \, ,
# bbd665197a0b6c7.png  bbd665197a0b6c7_basic.png  4630   0.500000   26                                                                                                                                                                                                                                                                                                                                                                                                                             { \bf H ( b ^ { + } , b ) } = \omega { \bf b ^ { + } b } \ .    35                                                                                                                                                                                                                                            { \bf H } ( { \bf B } ^ { + } , { \bf b } ) = \omega { \bf b } ^ { + } { \bf b } ~ .
# e1f964b4e7817bb.png  e1f964b4e7817bb_basic.png  4631   0.500000   36                                                                                                                                                                                                                                                                                                                                                                          a _ { z } = \partial _ { z } a \qquad \qquad a _ { \overline { { z } } } = \partial _ { \overline { { z } } } a    42                                                                                                                                                                                                                       a _ { z } = \partial _ { z } a ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ a _ { \tilde { z } } = \partial _ { \bar { z } } a
# e9d31abe4e880e7.png  e9d31abe4e880e7_basic.png  4632   0.518519   54                                                                                                                                                                                                                                                                                                                                                              \kappa L _ { G \; 4 k - 1 } ^ { A d S } + \beta _ { \{ r _ { j } \} } L _ { T \; \{ r _ { j } \} \; 4 k - 1 } ^ { A d S } ,    42                                                                                                                                                                                                                                  \kappa L _ { G } ^ { A d S } = + \beta _ { \{ r \} } L _ { I F } ^ { A d S } u _ { d k - 1 } ,
# 60e08cc1da0f92e.png  60e08cc1da0f92e_basic.png  4633   0.525000   40                                                                                                                                                                                                                                                                                                                                               [ { \bf H } , E _ { \mathrm { \boldmath ~ \alpha ~ } } ] = { \mathrm { \boldmath ~ \alpha ~ } } E _ { \mathrm { \boldmath ~ \alpha ~ } } ,    27                                                                                                                                                                                                                                                          [ { \bf H } , E ~ _ { \alpha } ~ ] ~ = ~ \alpha ~ E ~ _ { \alpha } ~ ,
# 8a4ae69e1fd3dce.png  8a4ae69e1fd3dce_basic.png  4634   0.526316   95                                                                                                                                                                                                                                       \begin{array} { c } { b _ { i } = a _ { i } e ^ { - \sum _ { j } c _ { i j } N _ { j } } \sqrt { \frac { N _ { i } } { \varphi _ { i } ( n _ { i } ) } } , \quad \forall i \in S } \\ { N _ { i } = b _ { i } ^ { + } b _ { i } . } \\ \end{array}    93                                                                                                   b _ { i } = a _ { i } e ^ { - \sum \sum _ { i } \gamma _ { i j } ^ { N } n _ { i } } { \sqrt { k _ { i } ^ { 2 } \psi _ { i } } } } { \partial _ { i } ^ { 2 } \psi _ { i } ( 0 _ { i } ) } } , ~ ~ ~ \forall ~ i \in S ~ ~ ~
# c1a50cf56a85498.png  c1a50cf56a85498_basic.png  4635   0.529412   34                                                                                                                                                                                                                                                                                                                                                                                              \vec { x } = \vec { z } _ { i } ( t ) \, \, \, \, \, \, \, \, \, \, \, \, \, \, \, \, \, \,    16                                                                                                                                                                                                                                                                                           \vec { x } = \vec { z } _ { i } ( t )
# ed2920f699d4aaf.png  ed2920f699d4aaf_basic.png  4636   0.531915   47                                                                                                                                                                                                                                                                                                                                                                                 \mathrm { H \to H _ { 0 } ^ { ( 2 ) } = ( 1 - y ) \vec { p } ^ { 2 } + ( x - G ) p _ { 4 } ^ { 2 } ~ . }    66                                                                                                                            \mathrm { H } \rightarrow \mathrm { H } _ { 0 } ^ { ( 2 ) } = ( 1 - \mathrm { y } ) \tilde { \mathrm { \lambda } } ^ { 2 } + ( \mathrm { \bf x } - \mathrm { G } ) \mathrm { p } _ { 4 } ^ { 2 } \ .
# 29c49bb9d73b854.png  29c49bb9d73b854_basic.png  4637   0.534351  131         \operatorname* { l i m } _ { \vec { p } \rightarrow 0 } \frac { \left( C _ { 1 } \left( \left| \vec { p } \right| \right) + C _ { 1 } ^ { * } \left( \left| \vec { p } \right| \right) + 2 \left| C _ { 1 } \left( \left| \vec { p } \right| \right) \right| ^ { 2 } \right) \left| \vec { p } \right| ^ { 3 } \frac 1 { \left( 1 - \left( 1 - \kappa \left| \vec { p } \right| ^ { 2 } \right) ^ { 2 } \right) } } { 4 p _ { 0 } } = \frac C { 2 \left( 2 \pi \right) ^ { 4 } }   116                                                      { \frac { 1 i } { j m _ { 0 } } } { \frac { C _ { 1 } ( A p | + C _ { 1 } ^ { - } \big ( | p ^ { + } ) + 2 C _ { 1 } \big ( | \vec { | \partial } | ) ^ { 2 } \mid \vec { p } | ^ { 3 } q _ { 1 } ( - 1 ^ { 1 } \pi \vec { p } ^ { 2 } ) ^ { 2 } } { 4 p _ { 0 } } } } = 1
# 4046f96b38af968.png  4046f96b38af968_basic.png  4638   0.538462   52                                                                                                                                                                                                                                                                                                                                                          X _ { 4 } = X _ { 5 } = 0 \quad \quad X _ { 1 } ^ { 2 } = X \quad \quad X _ { 2 } ^ { 2 } = Y \quad \quad X _ { 3 } ^ { 2 } = Z    25                                                                                                                                                                                                                                                                          X _ { 4 } = X _ { 5 } = 0 \qquad X _ { 1 } ^ { 2 } = X
# e218dd1fdf04484.png  e218dd1fdf04484_basic.png  4639   0.545455   22                                                                                                                                                                                                                                                                                                                                                                                                                              \Omega _ { \dot { I } \dot { J } K \dot { L } } \, = \, 0 .    11                                                                                                                                                                                                                                                                                                      \Omega _ { I j K L } = 0 .
# acc09f56a7dc4d6.png  acc09f56a7dc4d6_basic.png  4640   0.564103   39                                                                                                                                                                                                                                                                                                                                                                           \frac { \partial \bar { F } _ { A _ { J / 1 } } } { \partial q ^ { b _ { i | J } \left[ i + J \right] } } \, .    41                                                                                                                                                                                                                         { \frac { \partial { \bar { E } } _ { A / 1 } } { \partial q _ { l ^ { 2 } } ^ { l ( j + 1 ) } } } \, .
# 0a73fac2df36f3e.png  0a73fac2df36f3e_basic.png  4641   0.576923   26                                                                                                                                                                                                                                                                                                                                                                                                                      \Omega _ { ~ A B } ^ { ~ ~ \dagger } ~ = ~ \Omega _ { ~ A B } ~ ~ .    25                                                                                                                                                                                                                                                        \Omega \stackrel { A } { t } _ { B } \; = \; \Omega \; _ { A B } \; \; .
# 58a6b9f62f720dd.png  58a6b9f62f720dd_basic.png  4642   0.588235   51                                                                                                                                                                                                                                                                                                                        ( \stackrel { j } { \otimes } \! \mathbf { u } ^ { \dag } ) ( \stackrel { j } { \otimes } \! \mathbf { u } ) = ( \mathbf { u } ^ { \dag } \mathbf { u } ) ^ { j }    53                                                                                                                                                                                           ( \hat { \phi } ^ { \frac { 1 } { 2 } } ) ^ { \dagger } ( \hat { \phi } ^ { 1 } { \bf a } ) = ( { \bf n } ^ { 1 } { \bf u } _ { 1 } )
# 24a49cd648db889.png  24a49cd648db889_basic.png  4643   0.600000   20                                                                                                                                                                                                                                                                                                                                                                                                             T \overline { { T } } \overline { { \phi } } \overline { { \phi } } \protect     8                                                                                                                                                                                                                                                                                                      T \overline { { T } } \phi
# ddd8dee4714217b.png  ddd8dee4714217b_basic.png  4644   0.714286   21                                                                                                                                                                                                                                                                                                                                                                                                              \left[ \begin{array} { c c c } { 0 } & { 0 } & { 0 } \\ \end{array} \right]    12                                                                                                                                                                                                                                                                                        \left[ 0 \; \; \; 0 } \; \; 0 \; \right]
# 1ba8bf95d0744cf.png  1ba8bf95d0744cf_basic.png  4645   0.719101   89                                                                                                                                                                                                                                          \delta _ { j l } = \left\{ \begin{array} { l l l l } { 1 } & { \textrm { i f } \, \, \, j - l = 3 N } & { ( N \textrm { i s a n a r b i t r a r y i n t e g e r } ) } \\ { 0 } & { \textrm { o t h e r w i s e } } & { } \\ \end{array} \right.   121       \delta _ { j l } = \left\{ \begin{array} { l l } { 1 } & { \mathrm { i f ~ f ~ j - l = 3 ~ } } \\ { 0 } & { \mathrm { o r ~ t e r ~ s ~ e } e } & { , } & { \mathrm { i } s ~ \mathrm { ~ a ~ 1 ~ a ~ r ~ b + 1 ~ x ~ s ~ r ~ i n ~ s ~ e ~ x ~ } } \\ { 0 } & { \mathrm { o t h e r w i s e . } } \\ \end{array} \right.
# 3ccd9612f35cc1c.png  3ccd9612f35cc1c_basic.png  4646   0.785714   70                                                                                                                                                                                                                                                                               F _ { ~ ~ ~ ~ \mu \nu ~ \alpha \beta } ^ { - 1 \sigma ~ ~ \rho } = - F _ { ~ ~ ~ ~ \nu \mu ~ \alpha \beta } ^ { - 1 \sigma ~ ~ \rho } = - F _ { ~ ~ ~ ~ \mu \nu ~ \beta \alpha } ^ { - 1 \sigma ~ ~ \rho }    77                                                                                                                  F ^ { - 1 } { } _ { \mu \nu } ^ { \sigma ~ \rho } { } _ { \alpha \beta } = - F ^ { - 1 \sigma } { } _ { \mu \nu } ^ { } \, \, _ { \alpha \beta } = - F ^ { - 1 } { } _ { \mu \nu } ^ { } \, _ { \rho \ \beta }
# 676b9d2371199fa.png  676b9d2371199fa_basic.png  4647   0.800000   30                                                                                                                                                                                                                                                                                                                                                                                             \overbrace { S U ( 5 ) \otimes R ^ { 3 } } ^ { 2 7 } \otimes \overbrace { \phi } ^ { - 1 } ,    41                                                                                                                                                                                                                        { \cal G } \frac { S ( 5 ) } { { \cal S } U ( 5 ) \otimes R ^ { 3 } } ~ { \frac { - 1 } { \phi } } { , }
#
# [4648 rows x 7 columns]

# %%
df_result
# Out:
#                     target_seq                                                                                                                                                                                                                                                                                                                                                                                                                                                                         pred_seq                                                                                                                                                                                                                                                                                                                     score_pred  score_gold
# eval_image_name
# eee6617cd7a8537.png                                                                                                                                                                                                                                                                                                                                                                                     d s ^ { 2 } = d \chi ^ { 2 } + ( \chi ^ { 2 } + a ^ { 2 } ) d s _ { S _ { 3 } } ^ { 2 } ~ ~ .                                                                                                                                                                                                                               d s ^ { 2 } = d \chi ^ { 2 } + ( \chi ^ { 2 } + a ^ { 2 } ) d s _ { S _ { 3 } } ^ { 2 } ~ ~ .   0           0
# 0b2f97c436e19de.png                                                                                                                                                                                                                                                                                                                                                                                             3 \nu ( \alpha - \beta ) = - ( \alpha + \beta ) \kappa _ { 5 } ^ { 2 } \rho _ { b } ,                                                                                                                                                                                                                                       3 \nu ( \alpha - \beta ) = - ( \alpha + \beta ) \kappa _ { 5 } ^ { 2 } \rho _ { b } ,   0           0
# 2f2cf9337c1061e.png                                                                                                                                                                                                                                                                                                                                                                                                        \gamma \Theta _ { \mu } ^ { a } = D _ { \mu } ^ { ( \Theta ) } C ^ { a } ,                                                                                                                                                                                                                                                  \gamma \Theta _ { \mu } ^ { a } = D _ { \mu } ^ { ( \Theta ) } C ^ { a } ,   0           0
# 31dd9e32c121762.png                                                                                                                                                                                                                                                                                                                                                                                         \epsilon ^ { \beta \gamma \delta } V _ { \alpha } C _ { \beta \gamma } ^ { \alpha } = 0 ,                                                                                                                                                                                                                                   \epsilon ^ { \beta \gamma \delta } V _ { \alpha } C _ { \beta \gamma } ^ { \alpha } = 0 ,   0           0
# 829ca274c518285.png                                                                                                                                                                                                                                                                                                                                                                                                      \mathrm { T r } ( \gamma _ { \theta } ) = - ( - 1 ) ^ { b / 2 } \times 4 ~ .                                                                                                                                                                                                                                                \mathrm { T r } ( \gamma _ { \theta } ) = - ( - 1 ) ^ { b / 2 } \times 4 ~ .   0           0
# cdfb4e859f2c15c.png                                                                                                                                                                                                                                                                                                                                                                                                     \frac { d I _ { 0 } ( \Omega ) } { d \Omega } = 2 \Omega I _ { 1 } ( \Omega )                                                                                                                                                                                                                                               \frac { d I _ { 0 } ( \Omega ) } { d \Omega } = 2 \Omega I _ { 1 } ( \Omega )   0           0
# dafcf1e98dcf83b.png                                                                                                                                                                                                                                                                                                                                                                                            \omega _ { \mu \nu } = q _ { \mu } \epsilon _ { \nu } - \epsilon _ { \mu } q _ { \nu }                                                                                                                                                                                                                                      \omega _ { \mu \nu } = q _ { \mu } \epsilon _ { \nu } - \epsilon _ { \mu } q _ { \nu }   0           0
# a7f9dd30b186886.png                                                                                                                                                                                                                                                                                                                                                                                                J _ { \alpha \beta } = \frac { 2 ^ { n - 1 } } { f } \epsilon _ { \alpha \beta } ,                                                                                                                                                                                                                                          J _ { \alpha \beta } = \frac { 2 ^ { n - 1 } } { f } \epsilon _ { \alpha \beta } ,   0           0
# cca243fdbdcab18.png                                                                                                                                                                                                                                                                                                                                                                                                               x _ { \mu } \to R x _ { \mu } = \frac { x _ { \mu } } { x ^ { 2 } }                                                                                                                                                                                                                                                         x _ { \mu } \to R x _ { \mu } = \frac { x _ { \mu } } { x ^ { 2 } }   0           0
# fc9e5e734810e87.png                                                                                                                                                                                                                                                                                                                                                                                            \sigma _ { 2 } ( x ) = \lambda \left[ \delta ( x + a ) + \delta ( x - a ) \right] \, .                                                                                                                                                                                                                                      \sigma _ { 2 } ( x ) = \lambda \left[ \delta ( x + a ) + \delta ( x - a ) \right] \, .   0           0
# 84f6bad789b4ba6.png                                                                                                                                                                                                                                                                                                                                                                                                                      { \cal R } = { \cal D } _ { 1 } ^ { - 1 } { \cal D } _ { 2 }                                                                                                                                                                                                                                                                { \cal R } = { \cal D } _ { 1 } ^ { - 1 } { \cal D } _ { 2 }   0           0
# 6743b9b0707a42f.png                                                                                                                                                                                                                                                                                                                                                                                                                          i \hat { V } _ { 4 } = - i \lambda \hat { \tau } _ { 3 }                                                                                                                                                                                                                                                                    i \hat { V } _ { 4 } = - i \lambda \hat { \tau } _ { 3 }   0           0
# acf900b1e36f0af.png                                                                                                                                                                                                                                                                                                                                                                                                     { \cal D } _ { 2 } \rightarrow { \cal D } _ { 2 } + \alpha { \cal D } _ { 1 }                                                                                                                                                                                                                                               { \cal D } _ { 2 } \rightarrow { \cal D } _ { 2 } + \alpha { \cal D } _ { 1 }   0           0
# e98b7ff35296825.png                                                                                                                                                                                                                                                                                                                                                                                H \left( \Theta _ { \varepsilon } ( - X ^ { 0 } ) + \Theta _ { \varepsilon } ( X ^ { 0 } ) \right)                                                                                                                                                                                                                          H \left( \Theta _ { \varepsilon } ( - X ^ { 0 } ) + \Theta _ { \varepsilon } ( X ^ { 0 } ) \right)   0           0
# 255949d2e2eda44.png                                                                                                                                                                                                                                                                                                                                                                                                                       Z _ { 1 } ^ { * } W _ { S U ( 2 ) \otimes U ( 1 ) } ( K ) Z                                                                                                                                                                                                                                                                 Z _ { 1 } ^ { * } W _ { S U ( 2 ) \otimes U ( 1 ) } ( K ) Z   0           0
# e81ea076750ea2c.png                                                                                                                                                                                                                                                                                                                                                                                                              S _ { k I } = 4 - \frac { 4 \beta _ { k } } { a } + 2 \gamma _ { k }                                                                                                                                                                                                                                                        S _ { k I } = 4 - \frac { 4 \beta _ { k } } { a } + 2 \gamma _ { k }   0           0
# 42134c473e4a039.png                                                                                                                                                                                                                                                                                                                                                                            Q ^ { \alpha \beta } = \frac { 1 } { 2 } \left( \eta ^ { \alpha \beta } + D ^ { \alpha \beta } \right)                                                                                                                                                                                                                      Q ^ { \alpha \beta } = \frac { 1 } { 2 } \left( \eta ^ { \alpha \beta } + D ^ { \alpha \beta } \right)   0           0
# cf65a0e92c068bf.png                                                                                                                                                                                                                                                                                                                                                                                                                 \lambda _ { m } ^ { ( n - p - 1 ) } = \lambda _ { m } ^ { ( p ) }                                                                                                                                                                                                                                                           \lambda _ { m } ^ { ( n - p - 1 ) } = \lambda _ { m } ^ { ( p ) }   0           0
# 801659f3060f71b.png                                                                                                                                                                                                                                                                                                                                                                                                  g _ { \mu } = \langle p h y s | A _ { \mu } M ^ { \dagger } ( k ) | \psi \rangle                                                                                                                                                                                                                                            g _ { \mu } = \langle p h y s | A _ { \mu } M ^ { \dagger } ( k ) | \psi \rangle   0           0
# 01d8937373bd071.png                                                                                                                                                                                                                                                                                                                                                                                        S T = \left( \begin{array} { c c } { 0 } & { - 1 } \\ { 1 } & { 1 } \\ \end{array} \right)                                                                                                                                                                                                                                  S T = \left( \begin{array} { c c } { 0 } & { - 1 } \\ { 1 } & { 1 } \\ \end{array} \right)   0           0
# b17c890b3a46c47.png                                                                                                                                                                                                                                                                                                                                                                                             D = \frac { \partial } { \partial \theta } - \theta \frac { \partial } { \partial t }                                                                                                                                                                                                                                       D = \frac { \partial } { \partial \theta } - \theta \frac { \partial } { \partial t }   0           0
# d822acc2bccf7a5.png                                                                                                                                                                                                                                                                                                                                                                                                                         \Lambda ( i ) = \int _ { \Gamma ( i ) } d x \cdot A ( x )                                                                                                                                                                                                                                                                   \Lambda ( i ) = \int _ { \Gamma ( i ) } d x \cdot A ( x )   0           0
# 8424b245d97354d.png                                                                                                                                                                                                                                                                                                                                                                                                  \kappa \left( \frac { 1 } { X } \right) ^ { \prime \prime } X ^ { - 2 } = c \, .                                                                                                                                                                                                                                            \kappa \left( \frac { 1 } { X } \right) ^ { \prime \prime } X ^ { - 2 } = c \, .   0           0
# 76be821cff8d49c.png                                                                                                                                                                                                                                                                                                                                                                                                                                                                      \Delta = 0 ,                                                                                                                                                                                                                                                                                                                \Delta = 0 ,   0           0
# 54f6c2a7325e9df.png                                                                                                                                                                                                                                                                                                                                                                                                                                       x ^ { T } ( z ) = x ( \frac { 1 } { f z } )                                                                                                                                                                                                                                                                                 x ^ { T } ( z ) = x ( \frac { 1 } { f z } )   0           0
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...                                                                                                                                                                                                                                                                                                                         ...         ...         ...
# 7397e09327bb521.png                                                                                                                                                                                                                                                                                                                                                                                                            \eta \sp { i n } _ { j } = \eta \sp { o u t } _ { j } = \eta _ { j } ,                                                                                                                                                                                                                                                          \eta _ { j } ^ { i n } = \eta _ { j } ^ { o u t } = \eta _ { j } ,   0           0
# dbaed8f752f9348.png                                                                                    \begin{array} { c } { \Gamma ^ { M } \Gamma ^ { N } + \Gamma ^ { N } \Gamma ^ { M } = 2 \eta ^ { M N } , \qquad \eta ^ { M N } = ( + , - , - , \dots ) , } \\ { ( \Gamma ^ { M } ) ^ { * } = - \Gamma ^ { M } , \qquad ( \Gamma ^ { 0 } ) ^ { \mathrm { T } } = - \Gamma ^ { 0 } , \qquad ( \Gamma ^ { i } ) ^ { \mathrm { T } } = \Gamma ^ { i } , \quad i = 1 , \dots , 9 . } \\ \end{array}          ( n ^ { 1 M } ) ^ { \mathbf { M } ^ { M } \Gamma ^ { N } + \Gamma ^ { N } \Gamma ^ { M } = 2 \eta ^ { M N } . } \\ { + - \Gamma ^ { M } , } & { \Gamma ^ { 0 } \Gamma ^ { - } = - \Gamma ^ { 0 } , } & { \quad ( \Gamma ^ { i } ) ^ { T } = \Gamma ^ { i } , } & { i = 1 , z , \ldots , 2 } \\ \end{array} \right.   0           0
# d81ef356b8daac4.png                                                                                                                                                                                                                                                                                \sum _ { \sigma \, \in \, S _ { M } } \; c _ { \vec { a } _ { \sigma 1 } \, + \, 2 ( \vec { a } _ { \sigma 2 } + \cdots + \vec { a } _ { \sigma M } ) , \vec { a } _ { \sigma 1 } } \; = \; 0 \; .                                                                                                                                                            \sum _ { \sigma \in S _ { M } } \; c _ { \sigma _ { a + 1 } + 2 ( q _ { 2 \kappa + 1 } , \dots + i _ { \sigma _ { M } ) } , d _ { \sigma _ { 1 } } } \ = \ 0 \ .   0           0
# a9bdbc6854bb0fd.png                                                                                                                                                                                                                                                                      { F _ { \underline { { a b } } \mu \nu } } = { A _ { \underline { { a b } } [ \mu , \nu ] } } + { A _ { \underline { { c a } } [ \mu } A ^ { \underline { { c } } } { } _ { \underline { { b } } \nu ] } } .                                                                                         F _ { \underline { { a b } } \underline { d } \nu } = A _ { \underline { { a } } \underline { { b } } , d ) } + A _ { \underline { { c } } \underline { { a } } ] } A _ { ~ \underline { { b } } \underline { { \nu } } } ^ { [ } .   0           0
# 229334b1d025ca4.png                                                                                                                                                                                                                                                                                                                                                                    { \cal G } / { \cal H } = \frac { \mathrm { O ( 5 , n ) } } { \mathrm { O ( 5 ) } \times \mathrm { O ( n ) } }                                                                                                                                                                                    { \cal G } / { \cal H } = \frac { ( { \bf 5 } ( \mathrm { v } _ { 1 } ) } { \mathrm { O } ( 5 ) \times \mathrm { O } ( \mathrm { m } ) }   0           0
# 00b02fc405ab9d7.png                                                                                                                                                                                                                                                                                                                                                                               z _ { k } = i e ^ { - \theta _ { k } } e ^ { - i \pi \frac { \left( 1 + c ( k ) \right) } { 2 h } }                                                                                                                                                                                                         { z _ { k } } = i e ^ { - \theta _ { k } } e ^ { - i { \frac { 1 } { 2 R } } { \frac { ( \alpha + b ) } { 2 } } ) }   0           0
# d9a554e11488fc4.png                                                                                                                                                                                                                            E _ { T O T } \ \sim \ \underbrace { \frac { \beta ^ { 2 } { \cal A } } { \alpha R ^ { 2 } } } _ { E _ { c l a s s } } \ + \ \underbrace { \frac { \beta ^ { 2 } { \cal B } + \beta ^ { 4 } { \cal C } } { R ^ { 2 } } } _ { E _ { v a c u u m } } \ ,                                                                                                            E _ { T O T } \ \sim \ \frac { \rho _ { + } ^ { 2 } A } { \operatorname { d } { E _ { e } ^ { 2 } } } \, - \frac { \beta ^ { 2 } \vec { R } + \beta ^ { 4 } - } { - \frac { R } { R a ^ { 2 } e _ { n } } } \, ,   0           0
# bbd665197a0b6c7.png                                                                                                                                                                                                                                                                                                                                                                                                                      { \bf H ( b ^ { + } , b ) } = \omega { \bf b ^ { + } b } \ .                                                                                                                                                                                                                                        { \bf H } ( { \bf B } ^ { + } , { \bf b } ) = \omega { \bf b } ^ { + } { \bf b } ~ .   0           0
# e1f964b4e7817bb.png                                                                                                                                                                                                                                                                                                                                                                   a _ { z } = \partial _ { z } a \qquad \qquad a _ { \overline { { z } } } = \partial _ { \overline { { z } } } a                                                                                                                                                                                                                   a _ { z } = \partial _ { z } a ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ a _ { \tilde { z } } = \partial _ { \bar { z } } a   0           0
# e9d31abe4e880e7.png                                                                                                                                                                                                                                                                                                                                                       \kappa L _ { G \; 4 k - 1 } ^ { A d S } + \beta _ { \{ r _ { j } \} } L _ { T \; \{ r _ { j } \} \; 4 k - 1 } ^ { A d S } ,                                                                                                                                                                                                                              \kappa L _ { G } ^ { A d S } = + \beta _ { \{ r \} } L _ { I F } ^ { A d S } u _ { d k - 1 } ,   0           0
# 60e08cc1da0f92e.png                                                                                                                                                                                                                                                                                                                                        [ { \bf H } , E _ { \mathrm { \boldmath ~ \alpha ~ } } ] = { \mathrm { \boldmath ~ \alpha ~ } } E _ { \mathrm { \boldmath ~ \alpha ~ } } ,                                                                                                                                                                                                                                                      [ { \bf H } , E ~ _ { \alpha } ~ ] ~ = ~ \alpha ~ E ~ _ { \alpha } ~ ,   0           0
# 8a4ae69e1fd3dce.png                                                                                                                                                                                                                                \begin{array} { c } { b _ { i } = a _ { i } e ^ { - \sum _ { j } c _ { i j } N _ { j } } \sqrt { \frac { N _ { i } } { \varphi _ { i } ( n _ { i } ) } } , \quad \forall i \in S } \\ { N _ { i } = b _ { i } ^ { + } b _ { i } . } \\ \end{array}                                                                                               b _ { i } = a _ { i } e ^ { - \sum \sum _ { i } \gamma _ { i j } ^ { N } n _ { i } } { \sqrt { k _ { i } ^ { 2 } \psi _ { i } } } } { \partial _ { i } ^ { 2 } \psi _ { i } ( 0 _ { i } ) } } , ~ ~ ~ \forall ~ i \in S ~ ~ ~   0           0
# c1a50cf56a85498.png                                                                                                                                                                                                                                                                                                                                                                                       \vec { x } = \vec { z } _ { i } ( t ) \, \, \, \, \, \, \, \, \, \, \, \, \, \, \, \, \, \,                                                                                                                                                                                                                                                                                       \vec { x } = \vec { z } _ { i } ( t )   0           0
# ed2920f699d4aaf.png                                                                                                                                                                                                                                                                                                                                                                          \mathrm { H \to H _ { 0 } ^ { ( 2 ) } = ( 1 - y ) \vec { p } ^ { 2 } + ( x - G ) p _ { 4 } ^ { 2 } ~ . }                                                                                                                        \mathrm { H } \rightarrow \mathrm { H } _ { 0 } ^ { ( 2 ) } = ( 1 - \mathrm { y } ) \tilde { \mathrm { \lambda } } ^ { 2 } + ( \mathrm { \bf x } - \mathrm { G } ) \mathrm { p } _ { 4 } ^ { 2 } \ .   0           0
# 29c49bb9d73b854.png  \operatorname* { l i m } _ { \vec { p } \rightarrow 0 } \frac { \left( C _ { 1 } \left( \left| \vec { p } \right| \right) + C _ { 1 } ^ { * } \left( \left| \vec { p } \right| \right) + 2 \left| C _ { 1 } \left( \left| \vec { p } \right| \right) \right| ^ { 2 } \right) \left| \vec { p } \right| ^ { 3 } \frac 1 { \left( 1 - \left( 1 - \kappa \left| \vec { p } \right| ^ { 2 } \right) ^ { 2 } \right) } } { 4 p _ { 0 } } = \frac C { 2 \left( 2 \pi \right) ^ { 4 } }                                                  { \frac { 1 i } { j m _ { 0 } } } { \frac { C _ { 1 } ( A p | + C _ { 1 } ^ { - } \big ( | p ^ { + } ) + 2 C _ { 1 } \big ( | \vec { | \partial } | ) ^ { 2 } \mid \vec { p } | ^ { 3 } q _ { 1 } ( - 1 ^ { 1 } \pi \vec { p } ^ { 2 } ) ^ { 2 } } { 4 p _ { 0 } } } } = 1   0           0
# 4046f96b38af968.png                                                                                                                                                                                                                                                                                                                                                   X _ { 4 } = X _ { 5 } = 0 \quad \quad X _ { 1 } ^ { 2 } = X \quad \quad X _ { 2 } ^ { 2 } = Y \quad \quad X _ { 3 } ^ { 2 } = Z                                                                                                                                                                                                                                                                      X _ { 4 } = X _ { 5 } = 0 \qquad X _ { 1 } ^ { 2 } = X   0           0
# e218dd1fdf04484.png                                                                                                                                                                                                                                                                                                                                                                                                                       \Omega _ { \dot { I } \dot { J } K \dot { L } } \, = \, 0 .                                                                                                                                                                                                                                                                                                  \Omega _ { I j K L } = 0 .   0           0
# acc09f56a7dc4d6.png                                                                                                                                                                                                                                                                                                                                                                    \frac { \partial \bar { F } _ { A _ { J / 1 } } } { \partial q ^ { b _ { i | J } \left[ i + J \right] } } \, .                                                                                                                                                                                                                     { \frac { \partial { \bar { E } } _ { A / 1 } } { \partial q _ { l ^ { 2 } } ^ { l ( j + 1 ) } } } \, .   0           0
# 0a73fac2df36f3e.png                                                                                                                                                                                                                                                                                                                                                                                                               \Omega _ { ~ A B } ^ { ~ ~ \dagger } ~ = ~ \Omega _ { ~ A B } ~ ~ .                                                                                                                                                                                                                                                    \Omega \stackrel { A } { t } _ { B } \; = \; \Omega \; _ { A B } \; \; .   0           0
# 58a6b9f62f720dd.png                                                                                                                                                                                                                                                                                                                 ( \stackrel { j } { \otimes } \! \mathbf { u } ^ { \dag } ) ( \stackrel { j } { \otimes } \! \mathbf { u } ) = ( \mathbf { u } ^ { \dag } \mathbf { u } ) ^ { j }                                                                                                                                                                                       ( \hat { \phi } ^ { \frac { 1 } { 2 } } ) ^ { \dagger } ( \hat { \phi } ^ { 1 } { \bf a } ) = ( { \bf n } ^ { 1 } { \bf u } _ { 1 } )   0           0
# 24a49cd648db889.png                                                                                                                                                                                                                                                                                                                                                                                                      T \overline { { T } } \overline { { \phi } } \overline { { \phi } } \protect                                                                                                                                                                                                                                                                                                  T \overline { { T } } \phi   0           0
# ddd8dee4714217b.png                                                                                                                                                                                                                                                                                                                                                                                                       \left[ \begin{array} { c c c } { 0 } & { 0 } & { 0 } \\ \end{array} \right]                                                                                                                                                                                                                                                                                    \left[ 0 \; \; \; 0 } \; \; 0 \; \right]   0           0
# 1ba8bf95d0744cf.png                                                                                                                                                                                                                                   \delta _ { j l } = \left\{ \begin{array} { l l l l } { 1 } & { \textrm { i f } \, \, \, j - l = 3 N } & { ( N \textrm { i s a n a r b i t r a r y i n t e g e r } ) } \\ { 0 } & { \textrm { o t h e r w i s e } } & { } \\ \end{array} \right.   \delta _ { j l } = \left\{ \begin{array} { l l } { 1 } & { \mathrm { i f ~ f ~ j - l = 3 ~ } } \\ { 0 } & { \mathrm { o r ~ t e r ~ s ~ e } e } & { , } & { \mathrm { i } s ~ \mathrm { ~ a ~ 1 ~ a ~ r ~ b + 1 ~ x ~ s ~ r ~ i n ~ s ~ e ~ x ~ } } \\ { 0 } & { \mathrm { o t h e r w i s e . } } \\ \end{array} \right.   0           0
# 3ccd9612f35cc1c.png                                                                                                                                                                                                                                                                        F _ { ~ ~ ~ ~ \mu \nu ~ \alpha \beta } ^ { - 1 \sigma ~ ~ \rho } = - F _ { ~ ~ ~ ~ \nu \mu ~ \alpha \beta } ^ { - 1 \sigma ~ ~ \rho } = - F _ { ~ ~ ~ ~ \mu \nu ~ \beta \alpha } ^ { - 1 \sigma ~ ~ \rho }                                                                                                              F ^ { - 1 } { } _ { \mu \nu } ^ { \sigma ~ \rho } { } _ { \alpha \beta } = - F ^ { - 1 \sigma } { } _ { \mu \nu } ^ { } \, \, _ { \alpha \beta } = - F ^ { - 1 } { } _ { \mu \nu } ^ { } \, _ { \rho \ \beta }   0           0
# 676b9d2371199fa.png                                                                                                                                                                                                                                                                                                                                                                                      \overbrace { S U ( 5 ) \otimes R ^ { 3 } } ^ { 2 7 } \otimes \overbrace { \phi } ^ { - 1 } ,                                                                                                                                                                                                                    { \cal G } \frac { S ( 5 ) } { { \cal S } U ( 5 ) \otimes R ^ { 3 } } ~ { \frac { - 1 } { \phi } } { , }   0           0
#
# [4648 rows x 4 columns]

# %%
df_data
# Out:
#                      _iloc
# eval_image_name
# eee6617cd7a8537.png     0
# 0b2f97c436e19de.png     1
# 2f2cf9337c1061e.png     2
# 31dd9e32c121762.png     3
# 829ca274c518285.png     4
# cdfb4e859f2c15c.png     5
# dafcf1e98dcf83b.png     6
# a7f9dd30b186886.png     7
# cca243fdbdcab18.png     8
# fc9e5e734810e87.png     9
# 84f6bad789b4ba6.png    10
# 6743b9b0707a42f.png    11
# acf900b1e36f0af.png    12
# e98b7ff35296825.png    13
# 255949d2e2eda44.png    14
# e81ea076750ea2c.png    15
# 42134c473e4a039.png    16
# cf65a0e92c068bf.png    17
# 801659f3060f71b.png    18
# 01d8937373bd071.png    19
# b17c890b3a46c47.png    20
# d822acc2bccf7a5.png    21
# 8424b245d97354d.png    22
# 76be821cff8d49c.png    23
# 54f6c2a7325e9df.png    24
# ...                    ...
# 7397e09327bb521.png  4623
# dbaed8f752f9348.png  4624
# d81ef356b8daac4.png  4625
# a9bdbc6854bb0fd.png  4626
# 229334b1d025ca4.png  4627
# 00b02fc405ab9d7.png  4628
# d9a554e11488fc4.png  4629
# bbd665197a0b6c7.png  4630
# e1f964b4e7817bb.png  4631
# e9d31abe4e880e7.png  4632
# 60e08cc1da0f92e.png  4633
# 8a4ae69e1fd3dce.png  4634
# c1a50cf56a85498.png  4635
# ed2920f699d4aaf.png  4636
# 29c49bb9d73b854.png  4637
# 4046f96b38af968.png  4638
# e218dd1fdf04484.png  4639
# acc09f56a7dc4d6.png  4640
# 0a73fac2df36f3e.png  4641
# 58a6b9f62f720dd.png  4642
# 24a49cd648db889.png  4643
# ddd8dee4714217b.png  4644
# 1ba8bf95d0744cf.png  4645
# 3ccd9612f35cc1c.png  4646
# 676b9d2371199fa.png  4647
#
# [4648 rows x 1 columns]

# %%
sr_label
# Out:
# eval_image_name
# eee6617cd7a8537.png                                                                                                                                                                                                                                                                                                                                                                                       d s ^ { 2 } = d \chi ^ { 2 } + ( \chi ^ { 2 } + a ^ { 2 } ) d s _ { S _ { 3 } } ^ { 2 } ~ ~ .
# 0b2f97c436e19de.png                                                                                                                                                                                                                                                                                                                                                                                               3 \nu ( \alpha - \beta ) = - ( \alpha + \beta ) \kappa _ { 5 } ^ { 2 } \rho _ { b } ,
# 2f2cf9337c1061e.png                                                                                                                                                                                                                                                                                                                                                                                                          \gamma \Theta _ { \mu } ^ { a } = D _ { \mu } ^ { ( \Theta ) } C ^ { a } ,
# 31dd9e32c121762.png                                                                                                                                                                                                                                                                                                                                                                                           \epsilon ^ { \beta \gamma \delta } V _ { \alpha } C _ { \beta \gamma } ^ { \alpha } = 0 ,
# 829ca274c518285.png                                                                                                                                                                                                                                                                                                                                                                                                        \mathrm { T r } ( \gamma _ { \theta } ) = - ( - 1 ) ^ { b / 2 } \times 4 ~ .
# cdfb4e859f2c15c.png                                                                                                                                                                                                                                                                                                                                                                                                       \frac { d I _ { 0 } ( \Omega ) } { d \Omega } = 2 \Omega I _ { 1 } ( \Omega )
# dafcf1e98dcf83b.png                                                                                                                                                                                                                                                                                                                                                                                              \omega _ { \mu \nu } = q _ { \mu } \epsilon _ { \nu } - \epsilon _ { \mu } q _ { \nu }
# a7f9dd30b186886.png                                                                                                                                                                                                                                                                                                                                                                                                  J _ { \alpha \beta } = \frac { 2 ^ { n - 1 } } { f } \epsilon _ { \alpha \beta } ,
# cca243fdbdcab18.png                                                                                                                                                                                                                                                                                                                                                                                                                 x _ { \mu } \to R x _ { \mu } = \frac { x _ { \mu } } { x ^ { 2 } }
# fc9e5e734810e87.png                                                                                                                                                                                                                                                                                                                                                                                              \sigma _ { 2 } ( x ) = \lambda \left[ \delta ( x + a ) + \delta ( x - a ) \right] \, .
# 84f6bad789b4ba6.png                                                                                                                                                                                                                                                                                                                                                                                                                        { \cal R } = { \cal D } _ { 1 } ^ { - 1 } { \cal D } _ { 2 }
# 6743b9b0707a42f.png                                                                                                                                                                                                                                                                                                                                                                                                                            i \hat { V } _ { 4 } = - i \lambda \hat { \tau } _ { 3 }
# acf900b1e36f0af.png                                                                                                                                                                                                                                                                                                                                                                                                       { \cal D } _ { 2 } \rightarrow { \cal D } _ { 2 } + \alpha { \cal D } _ { 1 }
# e98b7ff35296825.png                                                                                                                                                                                                                                                                                                                                                                                  H \left( \Theta _ { \varepsilon } ( - X ^ { 0 } ) + \Theta _ { \varepsilon } ( X ^ { 0 } ) \right)
# 255949d2e2eda44.png                                                                                                                                                                                                                                                                                                                                                                                                                         Z _ { 1 } ^ { * } W _ { S U ( 2 ) \otimes U ( 1 ) } ( K ) Z
# e81ea076750ea2c.png                                                                                                                                                                                                                                                                                                                                                                                                                S _ { k I } = 4 - \frac { 4 \beta _ { k } } { a } + 2 \gamma _ { k }
# 42134c473e4a039.png                                                                                                                                                                                                                                                                                                                                                                              Q ^ { \alpha \beta } = \frac { 1 } { 2 } \left( \eta ^ { \alpha \beta } + D ^ { \alpha \beta } \right)
# cf65a0e92c068bf.png                                                                                                                                                                                                                                                                                                                                                                                                                   \lambda _ { m } ^ { ( n - p - 1 ) } = \lambda _ { m } ^ { ( p ) }
# 801659f3060f71b.png                                                                                                                                                                                                                                                                                                                                                                                                    g _ { \mu } = \langle p h y s | A _ { \mu } M ^ { \dagger } ( k ) | \psi \rangle
# 01d8937373bd071.png                                                                                                                                                                                                                                                                                                                                                                                          S T = \left( \begin{array} { c c } { 0 } & { - 1 } \\ { 1 } & { 1 } \\ \end{array} \right)
# b17c890b3a46c47.png                                                                                                                                                                                                                                                                                                                                                                                               D = \frac { \partial } { \partial \theta } - \theta \frac { \partial } { \partial t }
# d822acc2bccf7a5.png                                                                                                                                                                                                                                                                                                                                                                                                                           \Lambda ( i ) = \int _ { \Gamma ( i ) } d x \cdot A ( x )
# 8424b245d97354d.png                                                                                                                                                                                                                                                                                                                                                                                                    \kappa \left( \frac { 1 } { X } \right) ^ { \prime \prime } X ^ { - 2 } = c \, .
# 76be821cff8d49c.png                                                                                                                                                                                                                                                                                                                                                                                                                                                                        \Delta = 0 ,
# 54f6c2a7325e9df.png                                                                                                                                                                                                                                                                                                                                                                                                                                         x ^ { T } ( z ) = x ( \frac { 1 } { f z } )
#                                                                                                                                                                                                                                                              ...
# 7397e09327bb521.png                                                                                                                                                                                                                                                                                                                                                                                                              \eta \sp { i n } _ { j } = \eta \sp { o u t } _ { j } = \eta _ { j } ,
# dbaed8f752f9348.png                                                                                      \begin{array} { c } { \Gamma ^ { M } \Gamma ^ { N } + \Gamma ^ { N } \Gamma ^ { M } = 2 \eta ^ { M N } , \qquad \eta ^ { M N } = ( + , - , - , \dots ) , } \\ { ( \Gamma ^ { M } ) ^ { * } = - \Gamma ^ { M } , \qquad ( \Gamma ^ { 0 } ) ^ { \mathrm { T } } = - \Gamma ^ { 0 } , \qquad ( \Gamma ^ { i } ) ^ { \mathrm { T } } = \Gamma ^ { i } , \quad i = 1 , \dots , 9 . } \\ \end{array}
# d81ef356b8daac4.png                                                                                                                                                                                                                                                                                  \sum _ { \sigma \, \in \, S _ { M } } \; c _ { \vec { a } _ { \sigma 1 } \, + \, 2 ( \vec { a } _ { \sigma 2 } + \cdots + \vec { a } _ { \sigma M } ) , \vec { a } _ { \sigma 1 } } \; = \; 0 \; .
# a9bdbc6854bb0fd.png                                                                                                                                                                                                                                                                        { F _ { \underline { { a b } } \mu \nu } } = { A _ { \underline { { a b } } [ \mu , \nu ] } } + { A _ { \underline { { c a } } [ \mu } A ^ { \underline { { c } } } { } _ { \underline { { b } } \nu ] } } .
# 229334b1d025ca4.png                                                                                                                                                                                                                                                                                                                                                                      { \cal G } / { \cal H } = \frac { \mathrm { O ( 5 , n ) } } { \mathrm { O ( 5 ) } \times \mathrm { O ( n ) } }
# 00b02fc405ab9d7.png                                                                                                                                                                                                                                                                                                                                                                                 z _ { k } = i e ^ { - \theta _ { k } } e ^ { - i \pi \frac { \left( 1 + c ( k ) \right) } { 2 h } }
# d9a554e11488fc4.png                                                                                                                                                                                                                              E _ { T O T } \ \sim \ \underbrace { \frac { \beta ^ { 2 } { \cal A } } { \alpha R ^ { 2 } } } _ { E _ { c l a s s } } \ + \ \underbrace { \frac { \beta ^ { 2 } { \cal B } + \beta ^ { 4 } { \cal C } } { R ^ { 2 } } } _ { E _ { v a c u u m } } \ ,
# bbd665197a0b6c7.png                                                                                                                                                                                                                                                                                                                                                                                                                        { \bf H ( b ^ { + } , b ) } = \omega { \bf b ^ { + } b } \ .
# e1f964b4e7817bb.png                                                                                                                                                                                                                                                                                                                                                                     a _ { z } = \partial _ { z } a \qquad \qquad a _ { \overline { { z } } } = \partial _ { \overline { { z } } } a
# e9d31abe4e880e7.png                                                                                                                                                                                                                                                                                                                                                         \kappa L _ { G \; 4 k - 1 } ^ { A d S } + \beta _ { \{ r _ { j } \} } L _ { T \; \{ r _ { j } \} \; 4 k - 1 } ^ { A d S } ,
# 60e08cc1da0f92e.png                                                                                                                                                                                                                                                                                                                                          [ { \bf H } , E _ { \mathrm { \boldmath ~ \alpha ~ } } ] = { \mathrm { \boldmath ~ \alpha ~ } } E _ { \mathrm { \boldmath ~ \alpha ~ } } ,
# 8a4ae69e1fd3dce.png                                                                                                                                                                                                                                  \begin{array} { c } { b _ { i } = a _ { i } e ^ { - \sum _ { j } c _ { i j } N _ { j } } \sqrt { \frac { N _ { i } } { \varphi _ { i } ( n _ { i } ) } } , \quad \forall i \in S } \\ { N _ { i } = b _ { i } ^ { + } b _ { i } . } \\ \end{array}
# c1a50cf56a85498.png                                                                                                                                                                                                                                                                                                                                                                                         \vec { x } = \vec { z } _ { i } ( t ) \, \, \, \, \, \, \, \, \, \, \, \, \, \, \, \, \, \,
# ed2920f699d4aaf.png                                                                                                                                                                                                                                                                                                                                                                            \mathrm { H \to H _ { 0 } ^ { ( 2 ) } = ( 1 - y ) \vec { p } ^ { 2 } + ( x - G ) p _ { 4 } ^ { 2 } ~ . }
# 29c49bb9d73b854.png    \operatorname* { l i m } _ { \vec { p } \rightarrow 0 } \frac { \left( C _ { 1 } \left( \left| \vec { p } \right| \right) + C _ { 1 } ^ { * } \left( \left| \vec { p } \right| \right) + 2 \left| C _ { 1 } \left( \left| \vec { p } \right| \right) \right| ^ { 2 } \right) \left| \vec { p } \right| ^ { 3 } \frac 1 { \left( 1 - \left( 1 - \kappa \left| \vec { p } \right| ^ { 2 } \right) ^ { 2 } \right) } } { 4 p _ { 0 } } = \frac C { 2 \left( 2 \pi \right) ^ { 4 } }
# 4046f96b38af968.png                                                                                                                                                                                                                                                                                                                                                     X _ { 4 } = X _ { 5 } = 0 \quad \quad X _ { 1 } ^ { 2 } = X \quad \quad X _ { 2 } ^ { 2 } = Y \quad \quad X _ { 3 } ^ { 2 } = Z
# e218dd1fdf04484.png                                                                                                                                                                                                                                                                                                                                                                                                                         \Omega _ { \dot { I } \dot { J } K \dot { L } } \, = \, 0 .
# acc09f56a7dc4d6.png                                                                                                                                                                                                                                                                                                                                                                      \frac { \partial \bar { F } _ { A _ { J / 1 } } } { \partial q ^ { b _ { i | J } \left[ i + J \right] } } \, .
# 0a73fac2df36f3e.png                                                                                                                                                                                                                                                                                                                                                                                                                 \Omega _ { ~ A B } ^ { ~ ~ \dagger } ~ = ~ \Omega _ { ~ A B } ~ ~ .
# 58a6b9f62f720dd.png                                                                                                                                                                                                                                                                                                                   ( \stackrel { j } { \otimes } \! \mathbf { u } ^ { \dag } ) ( \stackrel { j } { \otimes } \! \mathbf { u } ) = ( \mathbf { u } ^ { \dag } \mathbf { u } ) ^ { j }
# 24a49cd648db889.png                                                                                                                                                                                                                                                                                                                                                                                                        T \overline { { T } } \overline { { \phi } } \overline { { \phi } } \protect
# ddd8dee4714217b.png                                                                                                                                                                                                                                                                                                                                                                                                         \left[ \begin{array} { c c c } { 0 } & { 0 } & { 0 } \\ \end{array} \right]
# 1ba8bf95d0744cf.png                                                                                                                                                                                                                                     \delta _ { j l } = \left\{ \begin{array} { l l l l } { 1 } & { \textrm { i f } \, \, \, j - l = 3 N } & { ( N \textrm { i s a n a r b i t r a r y i n t e g e r } ) } \\ { 0 } & { \textrm { o t h e r w i s e } } & { } \\ \end{array} \right.
# 3ccd9612f35cc1c.png                                                                                                                                                                                                                                                                          F _ { ~ ~ ~ ~ \mu \nu ~ \alpha \beta } ^ { - 1 \sigma ~ ~ \rho } = - F _ { ~ ~ ~ ~ \nu \mu ~ \alpha \beta } ^ { - 1 \sigma ~ ~ \rho } = - F _ { ~ ~ ~ ~ \mu \nu ~ \beta \alpha } ^ { - 1 \sigma ~ ~ \rho }
# 676b9d2371199fa.png                                                                                                                                                                                                                                                                                                                                                                                        \overbrace { S U ( 5 ) \otimes R ^ { 3 } } ^ { 2 7 } \otimes \overbrace { \phi } ^ { - 1 } ,
# Name: target_seq, Length: 4648, dtype: object

# %% [markdown]
# ### Render Images
# Render images using render_latex.py (https://github.com/untrix/im2latex/blob/master/thirdparty/harvardnlp_im2markup/scripts/evaluation/render_latex.py) which is derived from harvardnlp code base (https://github.com/harvardnlp/im2markup). See their github page for details on how to run the script.

# %%
# for image in df.image_name:
#     os.symlink(os.path.join(original_image_dir, image), os.path.join(golden_image_dir, image))

# %% [markdown]
# ### Evaluate images
# Evaluate image match using evaluate_image.py (https://github.com/untrix/im2latex/blob/master/thirdparty/harvardnlp_im2markup/scripts/evaluation/evaluate_image.py) also from harvard nlp code base. See their github page for details on how to run the script. However, make sure to use the code from this repository because it has been modified to produce an unmatched_files.txt output.
