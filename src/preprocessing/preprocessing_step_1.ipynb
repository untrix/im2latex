# %% [markdown]
# # im2latex
#
# &copy; Copyright 2017-2018 Sumeet S Singh
#
#     This file is part of im2latex solution by Sumeet S Singh.
#
#     This program is free software: you can redistribute it and/or modify
#     it under the terms of the Affero GNU General Public License as published by
#     the Free Software Foundation, either version 3 of the License, or
#     (at your option) any later version.
#
#     This program is distributed in the hope that it will be useful,
#     but WITHOUT ANY WARRANTY; without even the implied warranty of
#     MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.  See the
#     Affero GNU General Public License for more details.
#
#     You should have received a copy of the Affero GNU General Public License
#     along with this program.  If not, see <http://www.gnu.org/licenses/>.

# %%
import pandas as pd
import os

# %%
# pd.options.display.max_rows = 60
# pd.options.display.max_columns = 20
pd.options.display.max_colwidth = 200
pd.options.display.width = 160

# %%
input_dir = '../data/dataset_tmp/step0'
formula_file = os.path.join(input_dir, 'formulas.norm.filtered.txt')
output_dir = '../data/dataset3/step1'
output_fname = 'im2latex_dataset_map.df.pkl'
dump = False

# %% [markdown]
# ### Perform Manual Steps
#
# #### Download Github repos
# Download contents of [untrix/im2latex](https://github.com/untrix/im2latex) to ~/im2latex and [untrix/im2latex-dataset](https://github.com/untrix/im2latex-dataset) to ~/im2latex-dataset.
#
# #### Render LaTeX Formula Images
#
# > `DATA_DIR=~/im2latex/data/dataset_tmp`
# > `mkdir $DATA_DIR/formula_images`
#
# We will use the script formula2image.py from [untrix/im2latex-dataset](https://github.com/untrix/im2latex-dataset) for details for rendering the formulas into images.
#
# > Download and copy textogif to the formula_images directory you just created above. Then run the script.
# > `cd $DATA_DIR`
# > `python ~/im2latex-dataset/src/formula2image.py step0/formulas.norm.rendered.txt formula_images/`
#
# #### Eliminate Formulas that Didn't Render or are Duplicates
# Some formulas didn't render, therefore we need to remove those.
# > `cd $DATA_DIR`
# > `mkdir step1`
# > `python ~/im2latex-dataset/src/formula_list.py step0/formulas.norm.rendered.txt formula_images/ -o step1 `
# This will produce the file step1/im2latex_dataset_map.df.pkl

# %%
df = pd.read_pickle(os.path.join(output_dir, 'im2latex_dataset_map.df.pkl'))
print df.shape
df
# Out:
# (100700, 3)
#                             image           formula_name  \
# 0       23be72ded29e9b4_basic.png  23be72ded29e9b4_basic
# 1       8c904c5d9c7bd63_basic.png  8c904c5d9c7bd63_basic
# 2       1f111caa1be3516_basic.png  1f111caa1be3516_basic
# 3       76287b1b483a0d2_basic.png  76287b1b483a0d2_basic
# 4       7483d06c1e14dcb_basic.png  7483d06c1e14dcb_basic
# 5       8135cab7e6b93ae_basic.png  8135cab7e6b93ae_basic
# 6       67808bc314fa181_basic.png  67808bc314fa181_basic
# 7       2278ffa4860ed9b_basic.png  2278ffa4860ed9b_basic
# 8       1d7098797009973_basic.png  1d7098797009973_basic
# 9       f4f265238eb9724_basic.png  f4f265238eb9724_basic
# 10      ebf76c96dda24fb_basic.png  ebf76c96dda24fb_basic
# 11      10f52bac8085939_basic.png  10f52bac8085939_basic
# 12      e365c97c0e7cfba_basic.png  e365c97c0e7cfba_basic
# 13      6e0423b8338ceaa_basic.png  6e0423b8338ceaa_basic
# 14      f6234aa4de66f01_basic.png  f6234aa4de66f01_basic
# 15      cf5fceabedc6809_basic.png  cf5fceabedc6809_basic
# 16      f756628eae4368f_basic.png  f756628eae4368f_basic
# 17      5371d1643eb09a9_basic.png  5371d1643eb09a9_basic
# 18      bd9281732ed06ba_basic.png  bd9281732ed06ba_basic
# 19      45f26fd118114ef_basic.png  45f26fd118114ef_basic
# 20      cc218744908e01e_basic.png  cc218744908e01e_basic
# 21      2c4f23c09396b83_basic.png  2c4f23c09396b83_basic
# 22      0785e9241fb7831_basic.png  0785e9241fb7831_basic
# 23      55401122caf971c_basic.png  55401122caf971c_basic
# 24      3968850bd523cae_basic.png  3968850bd523cae_basic
# 25      16ceefff20ce3eb_basic.png  16ceefff20ce3eb_basic
# 26      80d1a58ea0f1314_basic.png  80d1a58ea0f1314_basic
# 27      ff6e22cdc339ecf_basic.png  ff6e22cdc339ecf_basic
# 28      3d416c04b9f3019_basic.png  3d416c04b9f3019_basic
# 29      1f40b4e12edae2b_basic.png  1f40b4e12edae2b_basic
# ...                           ...                    ...
# 100670  84e9fca01cc9351_basic.png  84e9fca01cc9351_basic
# 100671  ecd0215b7eba951_basic.png  ecd0215b7eba951_basic
# 100672  dd141ddbdc2d63e_basic.png  dd141ddbdc2d63e_basic
# 100673  5d84cf930b38a41_basic.png  5d84cf930b38a41_basic
# 100674  a84c73c4d0cb2d2_basic.png  a84c73c4d0cb2d2_basic
# 100675  9d2cf3dabad68c9_basic.png  9d2cf3dabad68c9_basic
# 100676  71d800d1431c0fc_basic.png  71d800d1431c0fc_basic
# 100677  a85d5abce241ce2_basic.png  a85d5abce241ce2_basic
# 100678  78baa7dd74657d6_basic.png  78baa7dd74657d6_basic
# 100679  74238e6fc2e3e1b_basic.png  74238e6fc2e3e1b_basic
# 100680  38ffe3c1e641d9a_basic.png  38ffe3c1e641d9a_basic
# 100681  1fc07870336a37e_basic.png  1fc07870336a37e_basic
# 100682  b04dabb9126e383_basic.png  b04dabb9126e383_basic
# 100683  c54ef25e536ef64_basic.png  c54ef25e536ef64_basic
# 100684  f4b0bf8206ff227_basic.png  f4b0bf8206ff227_basic
# 100685  8e6f8244e270a2c_basic.png  8e6f8244e270a2c_basic
# 100686  e8acd658a4c96e1_basic.png  e8acd658a4c96e1_basic
# 100687  c42086796d6d2b8_basic.png  c42086796d6d2b8_basic
# 100688  9685bb0fe348732_basic.png  9685bb0fe348732_basic
# 100689  3110381150ebb12_basic.png  3110381150ebb12_basic
# 100690  69f322113a01260_basic.png  69f322113a01260_basic
# 100691  fb5d393835fcafa_basic.png  fb5d393835fcafa_basic
# 100692  fd32f67518a0c15_basic.png  fd32f67518a0c15_basic
# 100693  7170887dced8d1a_basic.png  7170887dced8d1a_basic
# 100694  2a842a4de56b4c9_basic.png  2a842a4de56b4c9_basic
# 100695  690b25d8ff2f1ca_basic.png  690b25d8ff2f1ca_basic
# 100696  ea24f9de83bc687_basic.png  ea24f9de83bc687_basic
# 100697  df2183febf06bfb_basic.png  df2183febf06bfb_basic
# 100698  b71f03eadeed614_basic.png  b71f03eadeed614_basic
# 100699  3523d300d24ed92_basic.png  3523d300d24ed92_basic
#
#                                                                                                                                                                                                           latex
# 0       \int _ { - \epsilon } ^ { \infty } d l \: \mathrm { e } ^ { - l \zeta } \int _ { - \epsilon } ^ { \infty } d l ^ { \prime } \mathrm { e } ^ { - l ^ { \prime } \zeta } l l ^ { \prime } { \frac { l ...
# 1       d s ^ { 2 } = ( 1 - { \frac { q c o s \theta } { r } } ) ^ { \frac { 2 } { 1 + \alpha ^ { 2 } } } \lbrace d r ^ { 2 } + r ^ { 2 } d \theta ^ { 2 } + r ^ { 2 } s i n ^ { 2 } \theta d \varphi ^ { 2 ...
# 2                                                                \widetilde \gamma _ { \mathrm { h o p f } } \simeq \sum _ { n > 0 } \widetilde { G } _ { n } { \frac { ( - a ) ^ { n } } { 2 ^ { 2 n - 1 } } }
# 3                                                                                                                   ( { \cal L } _ { a } g ) _ { i j } = 0 , \ \ \ \ ( { \cal L } _ { a } H ) _ { i j k } = 0 ,
# 4                                                         S _ { s t a t } = 2 \pi \sqrt { N _ { 5 } ^ { ( 1 ) } N _ { 5 } ^ { ( 2 ) } N _ { 5 } ^ { ( 3 ) } } \left( \sqrt { n } + \sqrt { \bar { n } } \right)
# 5                                                                                                                          \hat { N } _ { 3 } = \sum \sp f _ { j = 1 } a _ { j } \sp { \dagger } a _ { j } \, .
# 6       + \int \! \! d ^ { D } \! z _ { 1 } d ^ { D } \! z _ { 2 } d ^ { D } \! z _ { 3 } \left. \frac { \delta ^ { 2 } W } { \delta j ( x ) \delta j ( z _ { 1 } ) } \, \frac { \delta ^ { 2 } W } { \delta...
# 7                                                                                                                                            \, ^ { * } d \, ^ { * } H = \kappa \, ^ { * } d \phi = J _ { B } .
# 8       { \frac { \phi ^ { \prime \prime } } { A } } + { \frac { 1 } { A } } \left( - { \frac { 1 } { 2 } } { \frac { A ^ { \prime } } { A } } + 2 { \frac { B ^ { \prime } } { B } } + { \frac { 2 } { r } ...
# 9                                                                                                                                      \partial _ { \mu } ( F ^ { \mu \nu } - e j ^ { \mu } x ^ { \nu } ) = 0 .
# 10      E _ { A D M } = \frac { 1 } { 1 6 \pi G _ { 1 0 } } \oint _ { \infty } d \Sigma ^ { m } \lbrace { } ^ { \circ } D _ { n } g _ { m p } - { } ^ { \circ } D _ { m } g _ { n p } \rbrace { } ^ { \circ ...
# 11                       P _ { ( 2 ) } ^ { - } = \int \beta d \beta d ^ { 9 } p d ^ { 8 } \lambda \Phi ( - p , - \lambda ) \left( - \frac { p ^ { I } p ^ { I } } { 2 \beta } \right) \Phi ( p , \lambda ) \, .
# 12      V _ { n s } ( { \tilde { x } } ) = \left( \frac { { \tilde { m } } N ^ { 2 } } { 1 6 \pi } \right) N g ^ { 2 n s - 1 } { \tilde { x } } ^ { 2 } \left\{ { \tilde { x } } ^ { 2 } - \frac { 2 { \tild...
# 13                                    g _ { i j } ( x ) = { \frac { 1 } { a ^ { 2 } } } \, \delta _ { i j } , ~ ~ \phi ^ { a } ( x ) = \phi ^ { a } , \quad ( a , \phi ^ { a } \! : ~ \mathrm { c o n s t . } )
# 14      \begin{array} { l l } { \sigma ^ { 0 } = - { \bf 1 } _ { 2 \times 2 } = { \bar { \sigma } } ^ { 0 } , } & { \sigma ^ { 1 } = \tau _ { z } = - { \bar { \sigma } } ^ { 1 } , } \\ { \sigma ^ { 2 } = ...
# 15                                                                                                    \rho _ { L } ( q ) = \sum _ { m = 1 } ^ { L } \ P _ { L } ( m ) \ { \frac { 1 } { q ^ { m - 1 } } } \ \ .
# 16      \Lambda _ { - 1 , 1 } = \lambda ^ { - 1 } ( e _ { 1 , 2 p } - e _ { 2 , 2 p + 1 } ) + ( e _ { 2 , 1 } - e _ { 2 p + 1 , 2 p } ) + 2 \sum _ { k = 1 } ^ { p - 1 } e _ { 2 + k , 1 + k } - 2 \sum _ { ...
# 17                                                                        e x p \left( - \frac { \partial } { \partial \alpha _ { j } } \theta ^ { j k } \frac { \partial } { \partial \alpha _ { k } } \right)
# 18                                                                                                                                                         L _ { 0 } = \Phi ( w ) = \bigtriangleup \Phi ( w ) ,
# 19                                                                                                                                                \left( D ^ { * } D ^ { * } + m ^ { 2 } \right) { \cal H } = 0
# 20                                                                                                                 { \frac { d V } { d \Phi } } = - { \frac { w \Phi } { \Phi _ { \! _ { 0 } } ^ { 2 } } } \, .
# 21      g ( z , \bar { z } ) = - \frac { 1 } { 2 } \left[ x ( z , \bar { z } ) \, s + x ^ { * } ( z , \bar { z } ) \, s ^ { * } + u ^ { * } ( z , \bar { z } ) \, t + u ( z , \bar { z } ) \, t ^ { * } \rig...
# 22                                                                                                                                                            x _ { \mu } ^ { c } = x _ { \mu } + A _ { \mu } .
# 23                                                                                           s = { \frac { S } { V } } = { \frac { A _ { H } } { l _ { p } ^ { 8 } V } } = { \frac { T ^ { 2 } } { \gamma } } .
# 24      \psi ( \gamma ) = \operatorname { e x p } { - ( { \textstyle { \frac { g ^ { 2 } } { 2 } } } ) \int _ { \gamma } d y ^ { a } \int _ { \gamma } d y ^ { a ^ { \prime } } D _ { 1 } ( y - y ^ { \prime...
# 25      E = E _ { 0 } + \frac { 1 } { 2 \operatorname { s i n h } ( \gamma ( 0 ) / 2 ) } \operatorname { s i n h } \left( \gamma ( 0 ) \left( \frac { 1 } { 2 } + c ( 0 ) \right) \right) h c \nu _ { \mathr...
# 26      \dot { z } _ { 1 } = - N ^ { z } ( z _ { 1 } ) = - g ( z _ { 1 } ) = - \frac { z _ { 1 } } { P _ { z } ( z _ { 2 } - z _ { 1 } ) } ; ~ ~ ~ \dot { z } _ { 2 } = - \frac { z _ { 2 } } { P _ { z } ( ...
# 27                                                                                                                       \langle T _ { z z } \rangle = - 3 \times \frac { \pi ^ { 2 } } { 1 4 4 0 a ^ { 4 } } .
# 28      \partial _ { u } \xi _ { z } ^ { ( 1 ) } + { \frac { 1 } { u } } \xi _ { z } ^ { ( 1 ) } = { \frac { 1 } { ( \pi T R ) ^ { 2 } u } } \left[ C _ { z } H _ { z z } ^ { \prime } + C _ { t } H _ { t z...
# 29                                                                    { \cal L } = - { \frac { 1 } { 4 } } F _ { \mu \nu } F ^ { \mu \nu } + { \bar { \psi } } ( i \gamma ^ { \mu } D _ { \mu } - m ) \psi \, ,
# ...                                                                                                                                                                                                         ...
# 100670                                                       d \bar { s } ^ { 2 } \sim \frac { a ^ { 2 } } { ( r - r _ { 1 } ) ^ { 2 } } \, d t ^ { 2 } - d r ^ { 2 } - r _ { 1 } ^ { 2 } \, d \Omega ^ { 2 } .
# 100671                                                                                                                                               v \leq \left[ { \frac { V } { 4 \pi } } \right] \equiv N .
# 100672  | \phi ( \alpha ^ { z } , \alpha ^ { i } ) \rangle = \operatorname { c o s } ( \omega \alpha ^ { z } ) | \phi _ { s } ( \alpha ^ { i } ) \rangle + \frac { \operatorname { s i n } ( \omega \alpha ^...
# 100673  \langle \phi _ { 2 } | \phi _ { 1 } \rangle _ { J } ^ { \dagger } = \langle \phi _ { 1 } | \phi _ { 2 } \rangle _ { J } = \langle \phi _ { 1 } | T ^ { \dagger } e ^ { - i J \phi } | \phi _ { 2 } \...
# 100674                                            < H H > = < \sum ( c \hat { \sigma } _ { i } . \vec { p } _ { i } ) ( c \hat { \sigma } _ { i } . \vec { p } _ { i } ) > = - \sum c ^ { 2 } p _ { i } ^ { 2 }
# 100675                                                                                    \lbrack J _ { + } , J _ { - } ] = 2 J _ { 3 } \; , \quad \quad \lbrack J _ { 3 } , J _ { \pm } ] = \pm J _ { \pm } \;
# 100676                              \frac { \partial \phi } { \partial { \cal R } } = \frac { \sqrt { 3 ( 1 + \omega ) } } { { \cal R } } , ~ ~ ~ \rho \sim \frac { 1 } { { \cal R } ^ { 3 ( 1 + \omega ) } } .
# 100677                                                      \phi \mapsto \phi _ { g } , \quad ( { q ^ { g } } ^ { T } ) _ { \Lambda } = ( q ^ { T } ) _ { \Sigma } ( g ^ { - 1 } ) _ { \Lambda } ^ { \Sigma } ,
# 100678                                               \Delta ( { \bf x } - { \bf x } ^ { \prime } ; t ) = \int d k e ^ { - i { \bf k } ( { \bf x } - { \bf x } ^ { \prime } ) } e ^ { - i \omega _ { \bf k } t }
# 100679  f _ { w } \left( T _ { a } ( z ) \right) = T _ { a } ^ { \prime } ( z ) \left[ f _ { w } ( z ) + \frac { ( z - \alpha _ { a } ) ( z - \beta _ { a } ) } { w _ { a } ( \alpha _ { a } - \beta _ { a }...
# 100680  \sigma _ { 0 } ^ { n } ( \lambda ) = s ( \lambda - { \frac { ( - ) ^ { n } } { \alpha _ { 0 } } } ) = { \frac { 1 } { 2 \operatorname { c o s h } \Bigl ( \pi ( \lambda - { \frac { ( - ) ^ { n } } ...
# 100681                                                                                                - \frac { 1 } { 2 } \left( \theta ^ { - 1 } \delta \theta \theta ^ { - 1 } \right) _ { i j } \, x ^ { j }
# 100682                                                                          B { \cal F } ^ { \prime } = 0 = { ^ t B } { \cal F } ^ { \prime } = ( q ^ { N - \bar { N } } - 1 ) { \cal F } ^ { \prime } \, ;
# 100683                                                                                                                                         \gamma _ { t } \gamma _ { t } \longleftrightarrow \sigma _ { t }
# 100684                                                                                                                                   \ddot { \phi } + 3 H \dot { \phi } = - { V ^ { \prime } ( \phi ) } \ ,
# 100685                                                                                                                                             A = - \partial X X ^ { - 1 } = - \partial \theta T ^ { 3 } .
# 100686   { \cal L } = \partial _ { \mu } V _ { i } ^ { * } \partial ^ { \mu } V _ { i } + h _ { 1 } ( V _ { 1 } V _ { 2 } ^ { * } + V _ { 1 } ^ { * } V _ { 2 } ) + h _ { 2 } ( V _ { 1 } + V _ { 2 } + c . c )
# 100687                                                                                                                                        { \cal L } ( M _ { m + 1 \, j } ) = \lambda M _ { m + 1 \, j } \,
# 100688                                                                                                           \lambda _ { \mu } \, \dot { z } ^ { \mu } = 1 , ~ ~ ~ \lambda ^ { \mu } \, R _ { , \mu } = 1 .
# 100689                                                                                                                        R _ { M N } - \frac { 1 } { 2 } g _ { M N } \diamondsuit R = - T _ { F \, M N } ,
# 100690  \acute { o } ^ { A } \bar { o } ^ { A ^ { \prime } } + o ^ { A } \acute { \bar { o } } { } ^ { A ^ { \prime } } = o ^ { A } \dot { \bar { \iota } } { } ^ { A ^ { \prime } } + \dot { o } ^ { A } \b...
# 100691                                                                              ( \dot { x } _ { \mu } - v J _ { \mu } ) ^ { 2 } + e ^ { 2 } m ^ { 2 } = 0 , \quad \dot { x } J - v J ^ { 2 } - s m e = 0 .
# 100692                                                                                                                                    \{ x ^ { i } , x ^ { j } \} = \Theta \epsilon ^ { i j k } x _ { k } ,
# 100693  \varphi ^ { \prime } = ( 1 - \alpha _ { + } ) \varphi ^ { + } + ( 1 - \alpha _ { - } ) \varphi ^ { - } + ~ \mathrm { c o n s t } . = { \frac { 1 } { 1 - u ^ { 2 } } } ( \varphi - u \tilde { \varph...
# 100694                                              \epsilon ^ { a _ { + } } ( x ) T ^ { a _ { + } } , \qquad \qquad \Xi ( x , 0 ) = \left( \begin{array} { c } { \xi ( x ) } \\ { 0 } \\ \end{array} \right) ,
# 100695                               A ^ { \prime } = e ^ { \rho \mathbf { J } _ { 2 } } d e ^ { - \rho \mathbf { J } _ { 2 } } + e ^ { \rho \mathbf { J } _ { 2 } } A e ^ { - \rho \mathbf { J } _ { 2 } } ~ ,
# 100696                                                                                            G = d U ^ { 1 } d V ^ { 1 } + d U ^ { 2 } d V ^ { 2 } + ( d Y ^ { 1 } ) ^ { 2 } + ( d Y ^ { 2 } ) ^ { 2 } ~ ,
# 100697                                                                                                                               \psi * \chi \equiv V _ { ( \infty , - 1 ) } ^ { ( 0 ) } ( \psi ) \chi \, ,
# 100698                                                                                                                            \Psi [ A _ { i } ^ { a } ] \rightarrow \Psi [ ( A ^ { U } ) _ { i } ^ { a } ]
# 100699                                    L = L _ { \mathrm { C M } } ( x , p ) = \sum _ { k = 1 } ^ { N } p _ { k } E _ { k k } + \sum _ { k \neq j } \frac { \gamma } { x _ { k } - x _ { j } } E _ { k j } .
#
# [100700 rows x 3 columns]

# %% [markdown]
# ## END
